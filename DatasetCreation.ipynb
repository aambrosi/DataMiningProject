# %%
import pandas as pd
import numpy  as np
import time   # To calculate the execution time
import bisect # For the WeightedRandomGenerator
import random # For the generation of random numbers
from numpy.random import choice # For generation of ordered list based on weight
from collections import defaultdict  # For dictionary that memorize the cumulative probability of import/expor
import copy # For function deepcopy
import math # For function floor that convert float numbers in integers

# The dataset was created by using a food dataset and saved outside because the original dataset was huge (1GB).
product_list = pd.read_csv('categories.csv', 
                           delimiter = ',', 
                           encoding  = 'utf-8')

# I delete few strange strings
product_list = product_list.drop([123, 157, 440, 442])

final_product_list                     = pd.DataFrame(product_list['Name'])
final_product_list['Popularity']       = np.random.random_sample(len(final_product_list))

# Index reset due to problems with non-consecutive indexes
final_product_list.reset_index(drop    = True, 
                               inplace = True)

# %%
final_product_list["DerivativeFrom"] = np.empty((len(final_product_list), 0)).tolist()

# %%
# Set the maximum and minimum number of derivates that each product can have
def derivativeGeneration(products, end, start = 0, minDerivative = 0, maxDerivative = 2):
    global final_product_list
    rndSelection = random.sample(products, random.randint(minDerivative, maxDerivative))
    # Check with two consecutive loops which product derives from our sample and add them
    for i in range(0, 1):
        olderDerivative = [(products[i], final_product_list.loc[i, 'DerivativeFrom']) for i in range(start, end)
                           if products[i] in rndSelection]
        if olderDerivative:
            for derivative in olderDerivative:
                rndSelection.extend(derivative[1])
                rndSelection = list(set(rndSelection))
    return rndSelection

# %%
# Generate all the derivatives
derivatives = np.empty((len(final_product_list), 0)).tolist()
for i in range(0, len(final_product_list)):
    derivatives[i] = derivativeGeneration(list(product_list["Name"]), i)
    final_product_list['DerivativeFrom'] = derivatives

# %%
cities = pd.read_csv('world-cities.csv', 
                     delimiter = ',', 
                     encoding  = 'utf-8')

# Set the number of cities to 100
nCities = 100
cities  = cities.sample(nCities)

# Use of manual created list of Northern Italy cities

cities = pd.DataFrame({'name': ['Milano', 'Bergamo', "Brescia", "Verona", "Padova", "Treviso", "Venezia",
                                "Trento", "Bolzano", "Bologna", "Parma", "Mantova", "Rovigo", "Modena",
                                "Ravenna"]})


# Index reset due to problems with non-consecutive indexes
cities.reset_index(drop    = True, 
                   inplace = True)
city_list         = pd.DataFrame(cities.name)
city_list.columns = ['Name']

# %%
# Creation of a probability vector for each city based on popularity of products and random coefficient
# from 0 to 1
rand = [np.random.random_sample(len(final_product_list)) for i in range(0,len(city_list))]
popularity = final_product_list.Popularity
name = final_product_list.Name

priorityExp = [popularity * rand[i] for i in range(0,len(city_list))]
probabilityExport = [p / sum(p) for p in priorityExp]

# List of each product in order of probability and then insert it in the dataset his coefficient
productsOrderExp = [choice(name, len(final_product_list), p = prob, replace = False)
                 for prob in probabilityExport]
city_list["ImportanceExport"] = [[(l[i], (1 - i / len(l))) for i in range(0,len(l))] for l in productsOrderExp]

# Collect derivatives for each product
possibleDerivatives = [[(importance[1],
  final_product_list.loc[final_product_list.Name == importance[0], 'DerivativeFrom']) for importance in city]
                       for city in city_list.ImportanceExport]

coefficients =   [[(elements[0] * (final_product_list.loc[final_product_list.Name == el, 'Popularity']**2), el)
                 for elements in city
                 for elem in  elements[1]
                 for el in elem] 
                 for city in possibleDerivatives]
probabilityIncrease = []
for city in coefficients:
    prob = defaultdict(int)
    for value, key in city:
        prob[key] += value
    probabilityIncrease.append(prob)
priorityImp = [[probabilityIncrease[i][final_product_list.Name[n]] + (1 - rand[i][n]) for n in range(0,len(final_product_list))] for i in range(0,len(city_list))]
priorityImpCleaned = []
for p in priorityImp:
    tmp = []
    for val in p:
        tmp.append(float(val))
    priorityImpCleaned.append(tmp)
probabilityImport = [[val / sum(p) for val in p] for p in priorityImpCleaned]

productsOrderImp = [choice(name, len(final_product_list), p = prob, replace = False)
                 for prob in probabilityImport]
city_list["ImportanceImport"] = [[(l[i], (1 - i / len(l))) for i in range(0,len(l))] for l in productsOrderImp]

# %%
def standard_info(i, rid, tcd, trip, final_trip):
    final_trip.loc[i, 'RouteId']   = rid
    final_trip.loc[i, 'Order']     = i
    final_trip.loc[i, 'TruckCode'] = tcd
    final_trip.loc[i, 'StartCity'] = trip.loc[i    , 'IdCity']
    final_trip.loc[i, 'EndCity']   = trip.loc[i + 1, 'IdCity']

def first_step_creation(rid, tcd, length, trip):
    final_trip   = pd.DataFrame(columns = ['RouteId', 'Order', 'TruckCode', 'StartCity', 'EndCity', 'Items'])
    standard_info(0, rid, tcd, trip, final_trip)
    itemsToImport = [(item[0], item[1]*item2[1]) for item in trip.loc[length - 2, "ProductImportance"]
                                 for item2 in trip.loc[length - 2, "PopularImport"] if item[0] == item2[0]]
    tot = sum(i[1] for i in itemsToImport)
    itemList = [i[0] for i in itemsToImport]
    itemValues = [i[1]/tot for i in itemsToImport]
    # I set the range to be not fixed to 5-15 for the first trip cities that have few exportable items and I set
    # them to half to all the possible exportable items
    numItems = np.random.randint(5,15)
    exportedItems = choice(itemList, numItems, p = itemValues, replace = False)
    final_trip.loc[length - 2, 'Items'] = set(exportedItems)
    return final_trip
    
def trip_creation(i, rid, tcd, length, trip, final_trip):
    standard_info(i - 1, rid, tcd, trip, final_trip)
    crev            = length - i - 1
    exportPriority = city_list.loc[(list(city_list.Name).index(trip.loc[crev + 1, 'IdCity'])),
                                   'ImportanceExport']
    removeItems = [expPriority[0] for expPriority in exportPriority if random.random() < expPriority[1]]
    possibleExports = list(final_trip.loc[crev + 1, 'Items'])
    itemsToDelete   = set(possibleExports).intersection(removeItems)
    for item in itemsToDelete:
        possibleExports.remove(item)
    # Number of new exported items
    numItems = np.random.randint(3, 15)
    itemsToImport = [(item[0], item[1]*item2[1]) for item in trip.loc[length - 2, "ProductImportance"]
                                 for item2 in trip.loc[length - 2, "PopularImport"] if item[0] == item2[0]]
    tot = sum(i[1] for i in itemsToImport)
    itemList = [i[0] for i in itemsToImport]
    itemValues = [i[1]/tot for i in itemsToImport]
    exportedItems = choice(itemList, numItems, p = itemValues, replace = False)
    final_trip.loc[crev, 'Items'] = set(possibleExports).union(exportedItems)
    return final_trip

# %%
# Range of trip length setted at 3:10. We set the number of trucks to 1000
minLen   = 3
maxLen   = 10
numTruck = 50

def generate_trip(i):
    length = np.random.randint(minLen, maxLen)
    trip   = pd.DataFrame(columns = ['IdCity', 'ProductImportance', 'PopularImport'])
    Exports = defaultdict(int)
    Imports = defaultdict(int)
    cities = []
    for c in range(0, length):
        city     = np.random.randint(0, len(city_list))
        while city in cities:
            city = np.random.randint(0, len(city_list))
        cities.append(city)
        trip.loc[c, 'IdCity'] = city_list.loc[city, 'Name']
        for cl in city_list.loc[city, 'ImportanceExport']:
            Exports[cl[0]] += cl[1]
        trip.loc[c, 'ProductImportance'] = [(item, Exports[item]) for item in Exports]
        trip.loc[c, 'PopularImport']   = city_list.loc[city, 'ImportanceImport']
    rid = i
    tcd = np.random.randint(0, numTruck)
    final_trip = first_step_creation(rid, tcd, length, trip)
    for c in range(2,length):
        final_trip = trip_creation(c, rid, tcd, length, trip, final_trip)
    final_trip = final_trip.sort_values('Order')
    return final_trip

# %%
# Generate n trips
def generate_trips(n):
    return [generate_trip(i) for i in range(0, n)]

# %%
numberOfRoutes = 150
routes         = generate_trips(numberOfRoutes)

# %%
routes
# Out:
# [  RouteId Order TruckCode StartCity  EndCity  \
#  0       0     0        16   Bolzano   Rovigo
#  1       0     1        16    Rovigo   Verona
#  2       0     2        16    Verona    Parma
#  3       0     3        16     Parma  Ravenna
#  4       0     4        16   Ravenna  Venezia
#
#                                                 Items
#  0  {Sardines-in-brine, Cauliflower-cheese, Mayona...
#  1  {Kombucha, Mango-drink, Mayonaise, Bouillonter...
#  2  {Ale, Burrito-kit, Mayonaise, Dindes, Senate-b...
#  3  {Miels, Dolminades, Ale, Yaourts-aux-fruits, C...
#  4  {Fuet-met-zwarte-peper, Kase, Beef-broth, Yaou...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       1     0        30   Bolzano  Ravenna
#  1       1     1        30   Ravenna   Rovigo
#  2       1     2        30    Rovigo    Parma
#  3       1     3        30     Parma  Bergamo
#  4       1     4        30   Bergamo  Venezia
#  5       1     5        30   Venezia   Verona
#
#                                                 Items
#  0  {Corn-snacks, Indian-food-mixes, Pousses-de-ba...
#  1  {Corn-snacks, Indian-food-mixes, Chili-con-car...
#  2  {Corn-snacks, Indian-food-mixes, Ghee, San-cho...
#  3  {Corn-snacks, Fruits-frais, Frozen-peas, Ghee,...
#  4  {Corn-snacks, Cardamom-pods, Cigarettes, Garli...
#  5  {Corn-snacks, Microwave-popcorn, Cigarettes, C...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       2     0        23    Rovigo  Treviso
#  1       2     1        23   Treviso  Bolzano
#
#                                                 Items
#  0  {Fromages, Fresh-juices, Creme-chocolat, Iced-...
#  1  {Ale, Bonbons-au-chocolat, Fresh-juices, Pates...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       3     0        22   Bolzano  Mantova
#  1       3     1        22   Mantova   Rovigo
#  2       3     2        22    Rovigo  Bologna
#  3       3     3        22   Bologna  Brescia
#  4       3     4        22   Brescia  Bergamo
#  5       3     5        22   Bergamo    Parma
#  6       3     6        22     Parma   Trento
#
#                                                 Items
#  0  {Sparkling-water-beverage, Formulated-suppleme...
#  1  {Peanut-butter-and-chocolat-chip-cereal-bar, F...
#  2  {Peanut-butter-and-chocolat-chip-cereal-bar, C...
#  3  {Chocolate-coins, Lime-marmalades, Turkish-fer...
#  4  {Christmas-food, Guava-juice, Taco-shells, Bri...
#  5  {Pate, Goat-milk, Sweet-biscuits, Baking-powde...
#  6  {Sambuca, Chicken-eggs, Remoulade, Fresh foods...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       4     0         9    Trento   Padova
#  1       4     1         9    Padova  Mantova
#  2       4     2         9   Mantova  Venezia
#
#                                                 Items
#  0  {Aoli-sauce, Fruit-spread, Asian-grocery, Brus...
#  1  {Fruit-spread, Sugarsnap-peas, Prawn-crackers,...
#  2  {Pancakes-and-waffles, Fruit-spread, Sliced-ch...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       5     0        48   Treviso  Venezia
#  1       5     1        48   Venezia   Verona
#
#                                                 Items
#  0  {Cardamom-pods, Peanut-butter-and-chocolat-chi...
#  1  {Cardamom-pods, Peanut-butter-and-chocolat-chi...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       6     0        39    Milano  Treviso
#  1       6     1        39   Treviso   Rovigo
#
#                                                 Items
#  0  {Baking, Boisson-sucree-non-alcoolisee, Sandiw...
#  1  {Sandiwch, Pasteurized-milk, Olive-ciabatta, M...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       7     0        16    Rovigo   Milano
#  1       7     1        16    Milano  Bologna
#  2       7     2        16   Bologna   Padova
#  3       7     3        16    Padova  Bolzano
#  4       7     4        16   Bolzano  Bergamo
#  5       7     5        16   Bergamo  Venezia
#  6       7     6        16   Venezia   Modena
#
#                                                 Items
#  0  {Baby-peas, Dilute-drink, Penne, Salted-snack,...
#  1  {Persimmon, Juice-drinks, Pitta-breads, Chicke...
#  2  {Plats-prepares-surgeles, Fruit-sticks, Loseng...
#  3  {Losenges, Sirop-de-fruits, Sandwichs, Pitta-b...
#  4  {Tuiles-salees, Losenges, Sirop-de-fruits, Con...
#  5  {Non-dairy-soymilk, Tuiles-salees, Chocolate-b...
#  6  {Plats-prepares-surgeles, Tuiles-salees, Pinea...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       8     0         1    Rovigo   Padova
#  1       8     1         1    Padova  Brescia
#  2       8     2         1   Brescia  Ravenna
#  3       8     3         1   Ravenna   Milano
#  4       8     4         1    Milano  Bolzano
#  5       8     5         1   Bolzano  Treviso
#
#                                                 Items
#  0  {Egg-salad, Frozen-snacks, Powder, Goat-cheese...
#  1  {Soupes, Fruit juices, Nane-limon, Baked-beans...
#  2  {Burrito-kit, Jus, Balsamic-vinaigrette, Farmi...
#  3  {Fruit juices, Madeleines-au-chocolat, Canned-...
#  4  {Fruit juices, Marshmallow-creme, Aceite-de-co...
#  5  {Cigarettes, Frozen-ice-creams, Sardines-in-br...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       9     0        49    Trento  Bergamo
#  1       9     1        49   Bergamo  Mantova
#
#                                                 Items
#  0  {Baked-beans-in-tomato-sauce, Precision-instru...
#  1  {Precision-instruments, Boisson-sucree-non-alc...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      10     0         8    Milano  Mantova
#  1      10     1         8   Mantova  Bolzano
#
#                                                 Items
#  0  {Conservation, Quso-duro, Cottage-cheese, Toma...
#  1  {Piccalilli, Fromage-frais, Senate-bean-soup, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      11     0        32   Ravenna  Bergamo
#  1      11     1        32   Bergamo  Venezia
#
#                                                 Items
#  0  {Products sold before year 2000, Sables, Purif...
#  1  {Chocolats, Fruit-bread, Fruit-sticks, Cheese-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      12     0         0   Bergamo   Milano
#  1      12     1         0    Milano  Bolzano
#  2      12     2         0   Bolzano   Verona
#  3      12     3         0    Verona   Modena
#  4      12     4         0    Modena   Trento
#  5      12     5         0    Trento   Rovigo
#
#                                                 Items
#  0  {Baking, Wholefood, Dumplings, Hot-cocoa-powde...
#  1  {Baking, Pate, Dumplings, Salads, Fat-free-mil...
#  2  {Frozen-potato-products, Pate, Dumplings, Fat-...
#  3  {Pate, Dumplings, Asperges, Curd-cheese, Genoa...
#  4  {Mini-portobello-mushrooms, Asperges, Chicken-...
#  5  {Pancakes-and-waffles, Mini-portobello-mushroo...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      13     0        33    Padova   Verona
#  1      13     1        33    Verona  Venezia
#  2      13     2        33   Venezia  Mantova
#  3      13     3        33   Mantova   Modena
#  4      13     4        33    Modena  Bolzano
#  5      13     5        33   Bolzano  Brescia
#
#                                                 Items
#  0  {Topping, Marie-rose-sauce, Mackerel-fillets-i...
#  1  {Flavouring-extract, Gravy, White-rhum, Marie-...
#  2  {Flavouring-extract, Cardamom-pods, Chocolate-...
#  3  {Canned-mussels, Bison, Caramel-dessert, Framb...
#  4  {Fresh-lemons, Danette-chocolate-dessert, Whol...
#  5  {Sussungsmittel, Chocolate-drops, Spearmint-su...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      14     0        46    Padova   Modena
#  1      14     1        46    Modena    Parma
#  2      14     2        46     Parma  Venezia
#
#                                                 Items
#  0  {Peanut-sauce, Prosecco, Gateau, Prepackaged-s...
#  1  {Sambuca, Roasted-and-ground-coffee, Barres-de...
#  2  {Sambuca, Roasted-and-ground-coffee, Produits-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      15     0        37   Mantova   Milano
#  1      15     1        37    Milano   Verona
#  2      15     2        37    Verona  Treviso
#  3      15     3        37   Treviso  Bergamo
#
#                                                 Items
#  0  {Strawberry-mousse, Garden-peas, Easter-buns, ...
#  1  {Garden-peas, Marie-rose-sauce, Cosmetics, Can...
#  2  {Frozen-asian-food, Dilute-drink, Fudge, Eaux-...
#  3  {Frozen-asian-food, Meat-pie, Banana-chips, Fr...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      16     0        10   Brescia  Venezia
#  1      16     1        10   Venezia  Mantova
#  2      16     2        10   Mantova  Bolzano
#  3      16     3        10   Bolzano    Parma
#  4      16     4        10     Parma  Treviso
#
#                                                 Items
#  0  {Breakfast-granola, Mackerel-fillets-in-sunflo...
#  1  {Non-dairy-soymilk, Grana-padano, Prawn-cockta...
#  2  {Non-dairy-soymilk, Fresh-juices, Biscuits-cho...
#  3  {Fruit-bar, Beef-burgers, Biskuvi, Boissons, O...
#  4  {Groundnut-bar, Fruit-bar, Crems-glacees, Bisc...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      17     0        35    Verona  Brescia
#  1      17     1        35   Brescia   Milano
#  2      17     2        35    Milano    Parma
#
#                                                 Items
#  0  {Multiseeded-sliced-bread, Cancoillottes, Vege...
#  1  {Snack-bar, Cancoillottes, Tarama, Chicken-keb...
#  2  {Snack-bar, Sirop, Fruits-frais, Tarama, Cordi...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      18     0        14   Treviso  Ravenna
#  1      18     1        14   Ravenna  Bolzano
#  2      18     2        14   Bolzano   Padova
#  3      18     3        14    Padova   Trento
#  4      18     4        14    Trento   Verona
#
#                                                 Items
#  0  {Pancakes-and-waffles, Tom-yum-soup, Topping, ...
#  1  {Topping, Cremes-desserts, Tomato-chilli-relis...
#  2  {Lemongrass-paste, Juice-beverage, Topping, Sn...
#  3  {Non food products, Gravy, Vinho-tinto, Juice,...
#  4  {Caramel-popcorn, Frozen-battered-fish, Gravy,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      19     0        22    Rovigo   Milano
#  1      19     1        22    Milano  Brescia
#  2      19     2        22   Brescia   Verona
#  3      19     3        22    Verona  Treviso
#  4      19     4        22   Treviso  Bergamo
#  5      19     5        22   Bergamo   Padova
#
#                                                 Items
#  0  {Latticini, Chocolate-ice-cream, Creme-chocola...
#  1  {Frozen-snacks-aperitifs, Chocolate-ice-cream,...
#  2  {Cappuccino-swiss-roll, Frozen-snacks-aperitif...
#  3  {Cappuccino-swiss-roll, Chocolate-ice-cream, F...
#  4  {Beers-from-stralsund, Produits-ssans-gluten, ...
#  5  {Porridge-oats, Canned-crab-meat, Mashed-potat...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      20     0        22   Brescia  Bologna
#  1      20     1        22   Bologna  Mantova
#  2      20     2        22   Mantova  Venezia
#  3      20     3        22   Venezia   Rovigo
#  4      20     4        22    Rovigo    Parma
#
#                                                 Items
#  0  {Pear-and-blackcurrant-juice, Trail-mix, Biscu...
#  1  {Thons-en-conserve, Splendid-artistry-coffee, ...
#  2  {Canned-coconut-milk, Haferflocken, Goat-milk-...
#  3  {Non-dairy-soymilk, Haferflocken, Goat-milk, M...
#  4  {Haferflocken, Sambuca, Mashed-potatoes, Pecan...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      21     0        36   Ravenna  Treviso
#  1      21     1        36   Treviso   Milano
#  2      21     2        36    Milano  Bolzano
#
#                                                 Items
#  0  {Boisson-sucree-non-alcoolisee, Crevettes, Pea...
#  1  {Fresh-asparagus, Crevettes, Kits, Jus, San-ch...
#  2  {Root-beer, Confitures-allegees, Dolce-gusto-c...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      22     0        13   Brescia   Modena
#  1      22     1        13    Modena  Mantova
#  2      22     2        13   Mantova  Treviso
#  3      22     3        13   Treviso  Bergamo
#  4      22     4        13   Bergamo  Ravenna
#  5      22     5        13   Ravenna   Rovigo
#
#                                                 Items
#  0  {Cooked-vegetables, Frozen-prawns, Frozen-pota...
#  1  {Cooked-vegetables, Frozen-potato-products, Fr...
#  2  {Sugary snacks, Cactus, Cooked-vegetables, Med...
#  3  {Cactus, Spices-seasoning-mixes, Chinese-cinna...
#  4  {Schwarztees, Peanut-sauce, Steak-pie, Chinese...
#  5  {Peanut-butter-and-chocolat-chip-cereal-bar, S...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      23     0        34    Rovigo  Bolzano
#  1      23     1        34   Bolzano  Treviso
#  2      23     2        34   Treviso   Padova
#  3      23     3        34    Padova  Bologna
#  4      23     4        34   Bologna    Parma
#  5      23     5        34     Parma  Venezia
#  6      23     6        34   Venezia  Bergamo
#
#                                                 Items
#  0  {Baking, Asian-condiments, Fruits-en-conserve,...
#  1  {Baking, Crevettes, Dessert-mixes, Biscuits-ch...
#  2  {Frozen-snacks-aperitifs, Moutardes, Dessert-m...
#  3  {Frozen-snacks-aperitifs, Cardamom-tea, Canned...
#  4  {Cooked-vegetables, Chicken-breast-fillets, Pa...
#  5  {Pains-d-epices, Bbq-relish, Coconut-cream, Pi...
#  6  {Raspberries-in-syrup, Custard-tarts, Pork-pie...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      24     0        33   Bergamo   Verona
#  1      24     1        33    Verona   Padova
#  2      24     2        33    Padova   Modena
#  3      24     3        33    Modena   Rovigo
#  4      24     4        33    Rovigo  Treviso
#  5      24     5        33   Treviso  Bolzano
#  6      24     6        33   Bolzano  Venezia
#
#                                                 Items
#  0  {Flavouring-extract, Fizzy-drinks, Beer-batter...
#  1  {Ground-cinnamon, Beer-batter-fries, Pear-cide...
#  2  {Ginseng-tea, Pear-cider, Penne-rigate, Confis...
#  3  {Ginseng-tea, Barres-de-cereales, Pear-cider, ...
#  4  {Biscuits-au-chocolat, Ginseng-tea, Goat-s-che...
#  5  {Biscuits-au-chocolat, Diced-tomatoes, Lemon-c...
#  6  {Cookies-chocolate, Diced-tomatoes, Garlic-naa...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      25     0         7    Padova  Bolzano
#  1      25     1         7   Bolzano   Verona
#  2      25     2         7    Verona  Bergamo
#  3      25     3         7   Bergamo  Venezia
#  4      25     4         7   Venezia  Bologna
#  5      25     5         7   Bologna   Rovigo
#
#                                                 Items
#  0  {Fromages, Goat-milk, Peanut-butter-cup, Chick...
#  1  {Peanut-butter-cup, Corn-kernels, Corn-thins, ...
#  2  {Chicoree, Pousses-de-bambou, Sirop, Fizzy-dri...
#  3  {Chicoree, Pousses-de-bambou, Sirop, Swiss-cho...
#  4  {Dolce-gusto-compatible-coffee-capsules, Powde...
#  5  {Dolce-gusto-compatible-coffee-capsules, Grape...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      26     0        25    Milano   Trento
#  1      26     1        25    Trento  Mantova
#
#                                                 Items
#  0  {Mini-portobello-mushrooms, Ice-tea, Maasdam-c...
#  1  {Mini-portobello-mushrooms, Ice-tea, Maasdam-c...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      27     0        45    Trento   Rovigo
#  1      27     1        45    Rovigo   Padova
#  2      27     2        45    Padova  Bolzano
#  3      27     3        45   Bolzano   Milano
#
#                                                 Items
#  0  {Products sold before year 2000, Crevettes, Ch...
#  1  {Aoli-sauce, Beers-from-stralsund, Ribbon-nood...
#  2  {Fruit juices, Corn-kernels, Turkish-delight, ...
#  3  {Fruit juices, Chocolate-ice-cream, Edam, Hot-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      28     0        45    Padova   Milano
#  1      28     1        45    Milano  Mantova
#  2      28     2        45   Mantova    Parma
#  3      28     3        45     Parma   Modena
#  4      28     4        45    Modena  Bolzano
#  5      28     5        45   Bolzano  Treviso
#  6      28     6        45   Treviso   Verona
#  7      28     7        45    Verona   Trento
#
#                                                 Items
#  0  {Pannekoeken, Fruit-spread, Hidden-valley, San...
#  1  {Soupes, Spring-roll-pastry, Boeuf-bourguignon...
#  2  {Soupes, Spring-roll-pastry, Boeuf-bourguignon...
#  3  {Tea-lemonade, Sandiwch, Salad, Distilled-malt...
#  4  {Green-basil, Kakaopulver, Tea-lemonade, Gourm...
#  5  {Green-basil, Kakaopulver, Gourmet-pie, Sandiw...
#  6  {Green-basil, Sandiwch, Gourmet-pie, Fruit-con...
#  7  {Frozen-baby-octopus, Fresh foods, Non-alcohol...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      29     0         9   Mantova  Bologna
#  1      29     1         9   Bologna   Milano
#  2      29     2         9    Milano  Treviso
#  3      29     3         9   Treviso   Rovigo
#  4      29     4         9    Rovigo   Padova
#  5      29     5         9    Padova  Bolzano
#  6      29     6         9   Bolzano    Parma
#  7      29     7         9     Parma   Trento
#
#                                                 Items
#  0  {Honey-ham, Fecules, Minestrone, Green olives,...
#  1  {Nectar-de-pommes, Groundnut-bar, Multiseeded-...
#  2  {Multiseeded-sliced-bread, Mais, Minestrone, V...
#  3  {Baby-peas, Syrups, Colorants-alimentaires, Fr...
#  4  {Kakaopulver, Cured-sausage, Baby-peas, Minest...
#  5  {Vegetarian-mock-meat, Pastrami, Cured-sausage...
#  6  {Groundnut-bar, Dairies, Gateau, Pains-au-choc...
#  7  {Infant-powder-milk, Juices, Juice-from-concen...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      30     0        43    Verona  Ravenna
#  1      30     1        43   Ravenna  Bologna
#  2      30     2        43   Bologna  Mantova
#  3      30     3        43   Mantova  Treviso
#  4      30     4        43   Treviso   Rovigo
#
#                                                 Items
#  0  {Fresh-garlic, Fresh-drinking-coconut, Sambuca...
#  1  {Sambuca, Dumplings, Indian, Luice, Apple-cide...
#  2  {South-african-merlot, Fruit juices, Sambuca, ...
#  3  {Fruit juices, Indian-sauces, Luice, Whole-bea...
#  4  {Fromages, Whole-bean-sprouts-canned, Ground-c...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      31     0        39    Milano  Bergamo
#  1      31     1        39   Bergamo  Venezia
#  2      31     2        39   Venezia   Trento
#
#                                                 Items
#  0  {Tejszin, Whole-bean-sprouts-canned, Vitamins,...
#  1  {Tejszin, Sambuca, Cornbreads, Chocolate-block...
#  2  {Cappuccino-swiss-roll, Fruit juices, Fromages...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      32     0        18    Trento  Treviso
#  1      32     1        18   Treviso   Rovigo
#  2      32     2        18    Rovigo   Padova
#  3      32     3        18    Padova  Venezia
#  4      32     4        18   Venezia  Bergamo
#  5      32     5        18   Bergamo  Bolzano
#  6      32     6        18   Bolzano    Parma
#
#                                                 Items
#  0  {Products sold before year 2000, Turkey-bacon,...
#  1  {Products sold before year 2000, Effervescent-...
#  2  {Products sold before year 2000, Frucht-und-ge...
#  3  {Biscuits-au-chocolat, Tisane, Dolce-gusto-com...
#  4  {Biscuits-au-chocolat, Natural-spring-water, D...
#  5  {Biscuits-au-chocolat, Mini-portobello-mushroo...
#  6  {Biscuits-au-chocolat, Strawberry-mousse, Form...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      33     0        10    Milano   Padova
#  1      33     1        10    Padova   Verona
#  2      33     2        10    Verona  Ravenna
#  3      33     3        10   Ravenna  Brescia
#  4      33     4        10   Brescia  Mantova
#  5      33     5        10   Mantova  Bolzano
#  6      33     6        10   Bolzano  Venezia
#  7      33     7        10   Venezia  Bergamo
#
#                                                 Items
#  0  {Canned-lamb-tongue, Fruit-cups, Dilute-drink,...
#  1  {Nectar-de-pommes, Baking, Canned-lamb-tongue,...
#  2  {Nectar-de-pommes, Chocolat, Crevettes, Brie-c...
#  3  {Mais, Dilute-drink, Apple-cider-vinegar, Toma...
#  4  {Wasabi, Mais, Dilute-drink, Carbonated-soda-w...
#  5  {Mais, Readymeals, Apple-cider-vinegar, Tomato...
#  6  {Biscuits-au-chocolat, Beans, Fat-free-milk, V...
#  7  {Indian-food-mixes, Alkoholische-getranke, Fro...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      34     0        38    Modena  Mantova
#  1      34     1        38   Mantova  Bolzano
#
#                                                 Items
#  0  {Fruit-bread, Parve, Labeled products, Nane-li...
#  1  {Pineapple-slices-in-juice, Fruit-bread, Milks...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      35     0        31   Brescia   Milano
#  1      35     1        31    Milano  Treviso
#  2      35     2        31   Treviso   Verona
#  3      35     3        31    Verona  Bolzano
#  4      35     4        31   Bolzano   Trento
#  5      35     5        31    Trento  Bergamo
#  6      35     6        31   Bergamo   Rovigo
#  7      35     7        31    Rovigo   Padova
#
#                                                 Items
#  0  {Rice-cakes, Fruit-bar, Chocolate-trifle, Cann...
#  1  {Kase, Canned foods, Hot-cross-buns, Purees-de...
#  2  {Chicken-thighs-fillets, Vegetarian-mock-meat,...
#  3  {Chicken-thighs-fillets, Vegetarian-mock-meat,...
#  4  {Salads, Corn-tortilla, Produits-laitiers, Fru...
#  5  {Non-dairy-soymilk, Salads, Pates, Mackerel-fi...
#  6  {Salads, Baby-peas, Pates, Thes-glaces, Umbric...
#  7  {Conservation, Egg-salad, Baby-peas, Aperitif,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      36     0        40   Ravenna  Bergamo
#  1      36     1        40   Bergamo  Brescia
#  2      36     2        40   Brescia   Padova
#
#                                                 Items
#  0  {Sunflower-spread, Sandwichs, Non-alcoholic-so...
#  1  {Cappuccino-swiss-roll, Peanut-butter-cup, Str...
#  2  {Cappuccino-swiss-roll, Indian-food-mixes, Yao...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      37     0         6    Rovigo  Brescia
#  1      37     1         6   Brescia  Ravenna
#
#                                                 Items
#  0  {Piccalilli, Non-dairy-soymilk, Dolce-gusto-co...
#  1  {Piccalilli, Non-dairy-soymilk, Whole-chicken,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      38     0        39   Bergamo  Bolzano
#  1      38     1        39   Bolzano    Parma
#  2      38     2        39     Parma   Milano
#  3      38     3        39    Milano  Treviso
#  4      38     4        39   Treviso   Trento
#  5      38     5        39    Trento  Venezia
#  6      38     6        39   Venezia  Ravenna
#
#                                                 Items
#  0  {Chocolats, Goat-milk, Frozen-snacks, Pains-d-...
#  1  {Baking, Chocolats, Fruits-frais, Pan-di-spagn...
#  2  {Crevettes, Mulled-wine-spice, Orange-chocolat...
#  3  {Multiseeded-sliced-bread, Senate-bean-soup, F...
#  4  {Fresh-drinking-coconut, Multiseeded-sliced-br...
#  5  {Groundnut-bar, Corn-thins, Prepackaged-sandwi...
#  6  {Canned-lamb-tongue, Garlic-naan-breads, Charc...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      39     0        43    Rovigo  Brescia
#  1      39     1        43   Brescia   Verona
#  2      39     2        43    Verona  Venezia
#  3      39     3        43   Venezia  Ravenna
#
#                                                 Items
#  0  {Fruit-bar, Whole-chicken, Crab-pate, Extracto...
#  1  {Products sold before year 2000, Crab-pate, Ex...
#  2  {Flavoured-milk-drink, Mackeral, Distilled-mal...
#  3  {Dolminades, Medium-cheddar, Grape-juice-drink...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      40     0        15    Modena  Mantova
#  1      40     1        15   Mantova   Trento
#  2      40     2        15    Trento  Brescia
#  3      40     3        15   Brescia    Parma
#  4      40     4        15     Parma   Padova
#  5      40     5        15    Padova   Milano
#
#                                                 Items
#  0  {Multifruits, Sirop, Groceries, San-choy-bao, ...
#  1  {Multifruits, Sirop, Shrimp-paste, Bison, Salt...
#  2  {Multifruits, Crevettes, Pains-precuits, Baked...
#  3  {Crevettes, Fruchtschnitte, Edam, Pear-and-bla...
#  4  {Mango-drink, Edam, Pear-and-blackcurrant-juic...
#  5  {Corn-tortilla, Algues-et-derives, Edam, Oatca...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      41     0        26   Bergamo   Padova
#  1      41     1        26    Padova  Brescia
#  2      41     2        26   Brescia  Venezia
#  3      41     3        26   Venezia   Milano
#  4      41     4        26    Milano   Modena
#  5      41     5        26    Modena    Parma
#  6      41     6        26     Parma   Verona
#  7      41     7        26    Verona  Mantova
#
#                                                 Items
#  0  {Sugary snacks, Ribbon-noodles, Cremes-dessert...
#  1  {White-quinoa, Sugary snacks, Fruit-bar, Fresh...
#  2  {White-quinoa, Sugary snacks, Confitures-alleg...
#  3  {Confitures-allegees, Radish, Bhakarwadi, Mais...
#  4  {Confitures-allegees, Radish, Sweetcorn-relish...
#  5  {White-quinoa, Madeira-cake, Radish, Swede, Wh...
#  6  {Whole-chicken, Mackerel-fillets-in-sunflower-...
#  7  {Beans, Salad, Stir-fry-sauce, Mackerel-fillet...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      42     0        14    Verona  Mantova
#  1      42     1        14   Mantova  Brescia
#  2      42     2        14   Brescia  Bergamo
#
#                                                 Items
#  0  {Salads, Flavoured-cranberries, Bison, Wraps, ...
#  1  {Salads, Corn-tortilla, Canned-lamb-tongue, Fu...
#  2  {Salads, Corn-tortilla, Confitures-allegees, P...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      43     0         2    Rovigo   Padova
#  1      43     1         2    Padova  Bergamo
#  2      43     2         2   Bergamo   Verona
#  3      43     3         2    Verona  Brescia
#  4      43     4         2   Brescia  Ravenna
#  5      43     5         2   Ravenna    Parma
#  6      43     6         2     Parma  Bologna
#  7      43     7         2   Bologna   Milano
#
#                                                 Items
#  0  {Honey-ham, Flavoured-milk-drink, Fresh-dates,...
#  1  {Chocolate-ice-cream, Senate-bean-soup, Energy...
#  2  {Frozen-snacks-aperitifs, Donuts, Carots, Chic...
#  3  {Natural-spring-water, Topping, Donuts, Carots...
#  4  {Aoli-sauce, Topping, Donuts, Chick-peas, Caps...
#  5  {Topping, Chick-peas, Sandwiches, Thons-en-con...
#  6  {Donuts, Chick-peas, Sandwiches, Instant-mashe...
#  7  {Plant-based foods and beverages, Ground-cinna...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      44     0        30   Bologna   Padova
#  1      44     1        30    Padova  Ravenna
#  2      44     2        30   Ravenna  Mantova
#
#                                                 Items
#  0  {Almond-fingers, Cactus, Confitures-allegees, ...
#  1  {Almond-fingers, Confitures-allegees, Dolce-gu...
#  2  {Dolce-gusto-compatible-coffee-capsules, Low-f...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      45     0        19    Verona    Parma
#  1      45     1        19     Parma   Milano
#  2      45     2        19    Milano   Modena
#  3      45     3        19    Modena  Bologna
#  4      45     4        19   Bologna   Padova
#  5      45     5        19    Padova  Mantova
#  6      45     6        19   Mantova  Venezia
#
#                                                 Items
#  0  {Almond-powder, Fresh-cabbage, Penne-rigate, A...
#  1  {Multifruits, Almond-powder, Ranja, Penne-riga...
#  2  {Multifruits, Sambuca, Whole-wheat-tortillas, ...
#  3  {Products sold before year 2000, Feuilletes-ch...
#  4  {Products sold before year 2000, Boisson-sucre...
#  5  {Vleeswaren, Frozen-peas, Chillies, Pauillac, ...
#  6  {Roasted-garlic, Vleeswaren, Pancake-syrup, Sm...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      46     0        34    Padova  Ravenna
#  1      46     1        34   Ravenna   Verona
#  2      46     2        34    Verona  Bergamo
#  3      46     3        34   Bergamo   Trento
#  4      46     4        34    Trento   Milano
#  5      46     5        34    Milano  Brescia
#  6      46     6        34   Brescia  Bolzano
#
#                                                 Items
#  0  {Baking, Canned foods, Tuiles-salees, Biscuits...
#  1  {Baking, Canned foods, Tuiles-salees, Coconut-...
#  2  {Ground-cinnamon, Mixed-chillies, Prosecco, Bl...
#  3  {Ground-cinnamon, Mixed-chillies, Prosecco, Bl...
#  4  {Fresh-drinking-coconut, Basa-fish, White-rhum...
#  5  {Easter-egg, Honey-ham, Basa-fish, Lindt-sea-s...
#  6  {Pousses-de-bambou, Blended-scotch-whiskey, Ch...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      47     0        24   Treviso   Verona
#  1      47     1        24    Verona   Padova
#  2      47     2        24    Padova  Venezia
#  3      47     3        24   Venezia   Milano
#  4      47     4        24    Milano   Modena
#  5      47     5        24    Modena  Bolzano
#
#                                                 Items
#  0  {Chocolats, Soft-cheese, Bhakarwadi, Crisp-rol...
#  1  {Minced-garlic, Kidney-beans, Chocolats, Bhaka...
#  2  {Fresh-raspberries, Mint-chocolate, All-steak-...
#  3  {Dolminades, Peach-drink, Cafe-moulu, Peanut-i...
#  4  {Bison, Prepackaged-sandwiches, Peanut-in-choc...
#  5  {Dolminades, Wholefood, Parve, Pasteurized-mil...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      48     0        41   Mantova   Modena
#  1      48     1        41    Modena   Rovigo
#  2      48     2        41    Rovigo  Treviso
#  3      48     3        41   Treviso    Parma
#  4      48     4        41     Parma   Verona
#
#                                                 Items
#  0  {Nectar-de-pommes, Products sold before year 2...
#  1  {Klebreiskuchen, Chocolate-rice-cakes, Poisson...
#  2  {Wortelsappen, Klebreiskuchen, Confitures-alle...
#  3  {Wortelsappen, Sirop, Canned-oysters, Canned-p...
#  4  {Chocolate-rice-cakes, Poissons, Frozen-snacks...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      49     0        28   Ravenna  Bolzano
#  1      49     1        28   Bolzano   Padova
#
#                                                 Items
#  0  {Products sold before year 2000, Piccalilli, M...
#  1  {Cookies-chocolate, Churned-cream, Diced-tomat...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      50     0        45    Rovigo  Bolzano
#  1      50     1        45   Bolzano    Parma
#  2      50     2        45     Parma   Milano
#  3      50     3        45    Milano  Bologna
#  4      50     4        45   Bologna   Trento
#  5      50     5        45    Trento   Verona
#
#                                                 Items
#  0  {Klebreiskuchen, Sunstream-tomatoes, Swede, Ba...
#  1  {Fresh-drinking-coconut, Gin, Creme-brulee, Hi...
#  2  {Swede, Porridge-oats, Lemon-curd, Bathroom, H...
#  3  {Swede, Porridge-oats, Lemon-curd, Banana-flav...
#  4  {Ice-tea, Creme-caramel, Lemon-curd, Pain-pita...
#  5  {Chow-mein, Groundnut-bar, Saucissons, Thes-gl...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      51     0        29   Bergamo  Bologna
#  1      51     1        29   Bologna   Verona
#
#                                                 Items
#  0  {Chocolate-drops, Green olives, Cordial, Raw-o...
#  1  {Frozen-baby-octopus, Flavoured-cranberries, C...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      52     0        15   Venezia  Brescia
#  1      52     1        15   Brescia  Ravenna
#
#                                                 Items
#  0  {Precision-instruments, Frozen-peas, Christmas...
#  1  {Grape-juice-drink, Aliments-d-origine-vegetal...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      53     0        46   Brescia  Mantova
#  1      53     1        46   Mantova   Modena
#  2      53     2        46    Modena  Treviso
#  3      53     3        46   Treviso   Padova
#  4      53     4        46    Padova   Milano
#  5      53     5        46    Milano  Venezia
#
#                                                 Items
#  0  {Barres-de-cereales, Sirloin-steak, Egg-lasagn...
#  1  {Graines, Pains-precuits, Prosecco, Curd-chees...
#  2  {Graines, Egg-white-powder, Prawn-cocktail, De...
#  3  {Mandarin-juice, Barres-de-cereales, Labeled p...
#  4  {Barres-de-cereales, Fusilli, Avocadoes, Dehyd...
#  5  {Barres-de-cereales, Spices-seasoning-mixes, P...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      54     0        10   Treviso   Padova
#  1      54     1        10    Padova   Verona
#  2      54     2        10    Verona  Ravenna
#  3      54     3        10   Ravenna   Milano
#  4      54     4        10    Milano    Parma
#  5      54     5        10     Parma  Bolzano
#  6      54     6        10   Bolzano  Bologna
#
#                                                 Items
#  0  {Corn-snacks, Pains-au-chocolat, Citrus-punch,...
#  1  {Fruit-bar, Effervescent-vitamin, Vinho-tinto,...
#  2  {Garlic-naan-breads, Bonbons-au-chocolat, Frui...
#  3  {Lait, Pork-sausages, Effervescent-vitamin, Ma...
#  4  {Products sold before year 2000, Leite, Garlic...
#  5  {Groceries, Chopeed-tomatoes, Fresh-asparagus,...
#  6  {Nane-limon, Fruit-bar, Kale-salads, Effervesc...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      55     0         3    Milano   Trento
#  1      55     1         3    Trento  Bologna
#  2      55     2         3   Bologna   Modena
#  3      55     3         3    Modena   Verona
#  4      55     4         3    Verona    Parma
#  5      55     5         3     Parma  Treviso
#  6      55     6         3   Treviso   Rovigo
#  7      55     7         3    Rovigo  Venezia
#
#                                                 Items
#  0  {Lemongrass-paste, Almond-fingers, Baked-beans...
#  1  {Lemongrass-paste, Almond-fingers, Sussungsmit...
#  2  {Lemongrass-paste, Almond-fingers, Caramel-pop...
#  3  {Lemongrass-paste, Fromages, Almond-fingers, S...
#  4  {Indian, Salted-peanuts, Legumes-prepares, Cra...
#  5  {Fecules, Indian, Legumes-prepares, Jus-de-fru...
#  6  {Jus-de-fruits, French-fries, Fecules, Mct-oil...
#  7  {Curd-cheese, Jus-de-fruits, Legumes-prepares,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      56     0        20    Trento   Modena
#  1      56     1        20    Modena  Brescia
#  2      56     2        20   Brescia   Padova
#  3      56     3        20    Padova  Bolzano
#  4      56     4        20   Bolzano  Bologna
#  5      56     5        20   Bologna    Parma
#  6      56     6        20     Parma  Mantova
#
#                                                 Items
#  0  {Vegetarian-mock-meat, Rice-cake, Corn-kernels...
#  1  {Vegetarian-mock-meat, Cardamom-pods, Peanut-b...
#  2  {Mini-portobello-mushrooms, Peach-juice-drink,...
#  3  {Mini-portobello-mushrooms, Dark-soy-sauce, Pu...
#  4  {Mini-portobello-mushrooms, Wholefood, Jus, Pa...
#  5  {Mini-portobello-mushrooms, Peach-juice-drink,...
#  6  {Boeuf, Bhakarwadi, Snackfoods, Frozen-vegetab...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      57     0         0    Trento   Verona
#  1      57     1         0    Verona  Bologna
#  2      57     2         0   Bologna   Rovigo
#  3      57     3         0    Rovigo  Ravenna
#  4      57     4         0   Ravenna  Bergamo
#
#                                                 Items
#  0  {Remoulade, Fruit-cups, Chocolate-ice-cream, C...
#  1  {Fromages, Snack-bar, Fruit-cups, Remoulade, C...
#  2  {Pear-cider, San-choy-bao, Mint-jellies, Quene...
#  3  {Kidney-beans, Fruit-cups, Kits, Chocolate-blo...
#  4  {Kidney-beans, Snack-bar, Nane-limon, Fruit-cu...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      58     0        11   Ravenna   Padova
#  1      58     1        11    Padova  Mantova
#  2      58     2        11   Mantova   Rovigo
#  3      58     3        11    Rovigo   Modena
#  4      58     4        11    Modena  Venezia
#  5      58     5        11   Venezia   Verona
#  6      58     6        11    Verona  Bologna
#
#                                                 Items
#  0  {Plant-based foods and beverages, Oeufs-de-poi...
#  1  {Cookies-chocolate, Plant-based foods and beve...
#  2  {Cookies-chocolate, Basa-fish, Banana-nut-loaf...
#  3  {Precision-instruments, Turkey-bacon, Damn-if-...
#  4  {Turkey-bacon, Garlic-naan-breads, Pannekoeken...
#  5  {Precision-instruments, Natural-spring-water, ...
#  6  {Frozen-potato-products, Precision-instruments...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      59     0        49   Brescia  Ravenna
#  1      59     1        49   Ravenna  Bergamo
#  2      59     2        49   Bergamo  Bolzano
#  3      59     3        49   Bolzano   Verona
#  4      59     4        49    Verona  Treviso
#  5      59     5        49   Treviso   Rovigo
#  6      59     6        49    Rovigo  Venezia
#
#                                                 Items
#  0  {Banana-nut-loaf, Licensed products, Pumpkin-s...
#  1  {Beers-from-stralsund, Creme-chocolat, White-r...
#  2  {Smoked-cheese, Whole-chicken, Creme-chocolat,...
#  3  {Corn-tortilla, Beef-broth, Tortilla-chips, Cr...
#  4  {Specialite-a-tartiner, Soeppoeder, Soft-chees...
#  5  {Cottage-cheeses, Honey-ham, Soft-cheese, Medi...
#  6  {Cottage-cheeses, Cafe-en-dosettes-compatible-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      60     0        38    Rovigo   Milano
#  1      60     1        38    Milano   Verona
#  2      60     2        38    Verona  Mantova
#  3      60     3        38   Mantova  Venezia
#  4      60     4        38   Venezia   Trento
#  5      60     5        38    Trento  Ravenna
#
#                                                 Items
#  0  {Root-beer, Goat-milk, Pineapple-slices, Ancho...
#  1  {Havarti-cheese, Kidney-beans, Root-beer, Caca...
#  2  {Chicken-kebabs, Sliced-jalapenos, Mackerel-fi...
#  3  {Vinaigres, Basa-fish, Porridge-oats, Bathroom...
#  4  {Vinaigres, Chicoree, Corn-tortilla, Chocolate...
#  5  {Corn-tortilla, Kale-salads, Vegan-chicken-nug...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      61     0        45    Rovigo  Bergamo
#  1      61     1        45   Bergamo  Mantova
#  2      61     2        45   Mantova   Modena
#  3      61     3        45    Modena  Treviso
#  4      61     4        45   Treviso  Bologna
#
#                                                 Items
#  0  {Wasabi, Kase, Coca-cola, Minced-beef-steak, B...
#  1  {Kase, Minced-beef-steak, Asian-cooking, Mulle...
#  2  {Kase, Minced-beef-steak, Asian-cooking, Olive...
#  3  {Plats-prepares-surgeles, Minced-beef-steak, C...
#  4  {Minced-beef-steak, Curd-cheese, Pains-au-choc...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      62     0        36    Trento   Padova
#  1      62     1        36    Padova  Brescia
#  2      62     2        36   Brescia   Milano
#  3      62     3        36    Milano  Bologna
#
#                                                 Items
#  0  {Turkey-bacon, Eggplant-dip, Curd-cheese, Froz...
#  1  {Groundnut-bar, Pork-sausages, Eggplant-dip, F...
#  2  {Multifruits, Groundnut-bar, Coconut-milk-powd...
#  3  {Groundnut-bar, Coconut-milk-powder, Caramel-p...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      63     0        24   Bologna   Modena
#  1      63     1        24    Modena  Ravenna
#  2      63     2        24   Ravenna  Brescia
#  3      63     3        24   Brescia   Verona
#  4      63     4        24    Verona   Rovigo
#  5      63     5        24    Rovigo  Bergamo
#  6      63     6        24   Bergamo   Milano
#  7      63     7        24    Milano   Trento
#
#                                                 Items
#  0  {Chow-mein, Groundnut-bar, Klebreiskuchen, Spi...
#  1  {Chow-mein, Groundnut-bar, Klebreiskuchen, Bis...
#  2  {Salades-strasbourgeoises, Legumes-prepares, C...
#  3  {Crab-pate, Salades-strasbourgeoises, Colorant...
#  4  {Cremes-desserts, Beef-lasagne, Salades-strasb...
#  5  {Pineapple-slices-in-juice, Frozen-peas, Fizzy...
#  6  {Cardamom-pods, Aperitif, Biscottes, Steak-pie...
#  7  {Chocolate-coins, Carbonated-soda-water, Bbq-r...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      64     0        30    Trento  Venezia
#  1      64     1        30   Venezia   Verona
#
#                                                 Items
#  0  {Wortelsappen, Sirloin-steak, Fromage-frais, B...
#  1  {Goat-cheese-log, Tandoori-chicken-masala, Car...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      65     0        46    Trento  Bologna
#  1      65     1        46   Bologna  Ravenna
#  2      65     2        46   Ravenna  Bolzano
#  3      65     3        46   Bolzano   Verona
#  4      65     4        46    Verona  Mantova
#  5      65     5        46   Mantova  Bergamo
#  6      65     6        46   Bergamo   Rovigo
#
#                                                 Items
#  0  {Baking, Whole-chicken, Flavoured-milk-drink, ...
#  1  {Baking, Whole-chicken, Mate, Draje-sakız, Che...
#  2  {Fresh-garlic, Sirop, Aloe-vera-drink, Power-d...
#  3  {Biscuits-aperitifs-sales, Minestrone, Spring-...
#  4  {Radish, Chips, Green-beans, Cherry-juice, Fru...
#  5  {Cottage-cheeses, Cooked-vegetables, Flavoured...
#  6  {Prosecco, Bieres, Cafe-moulu, Port, Bottled-s...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      66     0        44   Venezia   Modena
#  1      66     1        44    Modena   Padova
#  2      66     2        44    Padova  Bergamo
#
#                                                 Items
#  0  {Fresh-herbs, Complements-alimentaires, Pain-p...
#  1  {Frozen-baby-octopus, Chocolat, Baby-peas, Can...
#  2  {Frozen-baby-octopus, Black-rice, Liszt, Ribbo...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      67     0        15    Padova  Mantova
#  1      67     1        15   Mantova  Ravenna
#  2      67     2        15   Ravenna  Brescia
#  3      67     3        15   Brescia   Modena
#
#                                                 Items
#  0  {Cigarettes, Sweetelle-tomatoes, Pasta-bake-sa...
#  1  {Cigarettes, Chocolate-rice-cakes, Fecules, Ve...
#  2  {Fecules, Marie-rose-sauce, Chocolate-muffin, ...
#  3  {Garlic-and-coriander-naan, Chocolate-rice-cak...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      68     0        21    Rovigo   Padova
#  1      68     1        21    Padova   Milano
#  2      68     2        21    Milano  Bologna
#  3      68     3        21   Bologna  Treviso
#  4      68     4        21   Treviso  Venezia
#  5      68     5        21   Venezia  Bolzano
#  6      68     6        21   Bolzano   Modena
#  7      68     7        21    Modena  Mantova
#
#                                                 Items
#  0  {Redcurrant-tea, Turkey-bacon, Prosecco, Plats...
#  1  {Peeled-plum-tomatoes, Salad, Sugarsnap-peas, ...
#  2  {Peeled-plum-tomatoes, Profiteroles, Hagelslag...
#  3  {Lait-de-vache-concentre-non-sucre, Kase, Bisc...
#  4  {Kakaopulver, Turkey-bacon, Barres-de-cereales...
#  5  {Havarti-cheese, Smoked-cheese, Turkey-bacon, ...
#  6  {Prepared-foods, Pousses-de-bambou, Biscuits-s...
#  7  {Prepared-foods, Pousses-de-bambou, Pan-di-spa...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      69     0        29   Bergamo  Venezia
#  1      69     1        29   Venezia  Mantova
#  2      69     2        29   Mantova   Verona
#  3      69     3        29    Verona  Treviso
#
#                                                 Items
#  0  {Fruit-bar, Bhakarwadi, Sunflower-oil-spread, ...
#  1  {Cured-sausage, Whole-bean-sprouts-canned, Pur...
#  2  {Nectar-de-pommes, Rice-cakes, Fresh-juices, V...
#  3  {Caramel-flavored-topping, Fresh-juices, Veget...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      70     0        13    Padova  Bergamo
#  1      70     1        13   Bergamo   Trento
#  2      70     2        13    Trento  Ravenna
#  3      70     3        13   Ravenna  Bologna
#  4      70     4        13   Bologna  Brescia
#  5      70     5        13   Brescia  Mantova
#  6      70     6        13   Mantova   Modena
#  7      70     7        13    Modena  Venezia
#
#                                                 Items
#  0  {Dairies, Canned-oysters, Frozen-sweetcorn, Sa...
#  1  {Frozen-potato-products, Dried-meat, Rice-wine...
#  2  {Raw, Wholefood, Peanut-butter-and-chocolat-ch...
#  3  {Wholefood, Pina-colada, Confitures-allegees, ...
#  4  {Wholefood, Crsips, Yellow-peaches, Cream-hors...
#  5  {Raw, Almond-fingers, Pannekoeken, Barres-de-c...
#  6  {Barres-de-cereales, Pannekoeken, Caramel-flav...
#  7  {Raw, Barres-de-cereales, Brie-cheese, Mashed-...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      71     0        23    Rovigo  Modena
#  1      71     1        23    Modena  Verona
#  2      71     2        23    Verona  Milano
#
#                                                 Items
#  0  {Pannekoeken, Bonbons-au-chocolat, Saumons-fum...
#  1  {Galettes-de-polenta, Pannekoeken, Poivre-noir...
#  2  {Multifruits, Latticini, Pannekoeken, Plats-pr...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      72     0         8    Trento   Modena
#  1      72     1         8    Modena  Bologna
#  2      72     2         8   Bologna  Venezia
#  3      72     3         8   Venezia  Bergamo
#
#                                                 Items
#  0  {Ale, Jus-de-fruits, Losenges, Marshmallow-cre...
#  1  {Miels, Organic-certified, Gourmet-pie, Porc, ...
#  2  {Fresh-lemons, Pates-a-tartiner-aux-noisettes-...
#  3  {Fresh-lemons, Organic-certified, Graines, Spa...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      73     0        40    Verona   Milano
#  1      73     1        40    Milano   Trento
#  2      73     2        40    Trento  Bergamo
#  3      73     3        40   Bergamo  Treviso
#  4      73     4        40   Treviso   Modena
#  5      73     5        40    Modena   Rovigo
#  6      73     6        40    Rovigo  Mantova
#
#                                                 Items
#  0  {Minestrone, Gin, Tea-drinks, Quenelles, Roast...
#  1  {Rice-cakes, Minestrone, Roasted-eggplant, Cho...
#  2  {Minestrone, Balsamic-vinaigrette, Genoa-salam...
#  3  {Minestrone, Biscuits-chocolates, Lamb-breast,...
#  4  {Minestrone, Peeled-plum-tomatoes, Rice-candy,...
#  5  {Piccalilli, Peeled-plum-tomatoes, Hot-cross-b...
#  6  {Frozen-snacks, Peeled-plum-tomatoes, Dried-pa...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      74     0         9   Treviso  Brescia
#  1      74     1         9   Brescia   Padova
#  2      74     2         9    Padova   Modena
#  3      74     3         9    Modena    Parma
#  4      74     4         9     Parma  Venezia
#  5      74     5         9   Venezia   Verona
#
#                                                 Items
#  0  {Chicken-thighs-fillets, Almond-powder, Ciabat...
#  1  {Chicken-thighs-fillets, Bean-flour, Almond-po...
#  2  {Chicken-thighs-fillets, Dairies, Rice-cake, C...
#  3  {Chicken-thighs-fillets, Biere, Bean-flour, Ge...
#  4  {Chicken-thighs-fillets, Indian-food-mixes, Po...
#  5  {Indian-food-mixes, Whole-wheat-tortillas, Lic...  ,
# ...
#  0  {Corn-tortilla, Frozen-asian-food, Bbq-relish,...
#  1  {Peanut-butter-and-chocolat-chip-cereal-bar, S...
#  2  {Peanut-butter-and-chocolat-chip-cereal-bar, P...
#  3  {Groundnut-bar, Sparkling-water-beverage, Turk...
#  4  {Turkey-burgers, Genoa-salami, Pancake-mix, Se...
#  5  {Poissons, Organic-certified, Minced-beef-stea...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     127     0        11    Modena   Padova
#  1     127     1        11    Padova  Bologna
#  2     127     2        11   Bologna  Ravenna
#  3     127     3        11   Ravenna  Bergamo
#  4     127     4        11   Bergamo   Verona
#  5     127     5        11    Verona  Venezia
#  6     127     6        11   Venezia  Treviso
#
#                                                 Items
#  0  {Groundnut-bar, Deshydrated-fruit, Fruit-drink...
#  1  {Haferflocken, Mushroom-in-sunflower-oil, Fats...
#  2  {Blue-cheese-yogurt-dressing, Haferflocken, Fi...
#  3  {Chocolate-ice-cream, Senate-bean-soup, Blinis...
#  4  {Multifruits, Microwave-popcorn, Sandwich, Bar...
#  5  {Multifruits, Microwave-popcorn, Blended-scotc...
#  6  {Asperges-en-conserve, Bbq-relish, Pancake-mix...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     128     0        15    Verona  Brescia
#  1     128     1        15   Brescia   Trento
#  2     128     2        15    Trento   Padova
#  3     128     3        15    Padova  Bologna
#  4     128     4        15   Bologna  Bolzano
#  5     128     5        15   Bolzano   Rovigo
#  6     128     6        15    Rovigo  Mantova
#
#                                                 Items
#  0  {Beef-jerky, Beef-stroganoff, Tiefkuhlpizza, G...
#  1  {Yaourts-aux-fruits, Goat-s-cheese, Olive-ciab...
#  2  {Goat-s-cheese, Kale-salads, Olive-ciabatta, S...
#  3  {Indian-food-mixes, White-rhum, Sweet-biscuits...
#  4  {Ground-cinnamon, Sun-dried-tomatoes, Porridge...
#  5  {Sun-dried-tomatoes, Produits-ssans-gluten, Me...
#  6  {Vegetarian-mock-meat, Chicken-powder, Donuts,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     129     0         5    Verona  Treviso
#  1     129     1         5   Treviso   Trento
#  2     129     2         5    Trento  Brescia
#  3     129     3         5   Brescia  Bologna
#  4     129     4         5   Bologna   Rovigo
#  5     129     5         5    Rovigo  Venezia
#
#                                                 Items
#  0  {Canned-mussels, Marie-rose-sauce, Bircarbonat...
#  1  {Pancake-mix, Food additives, Cough-lozenges, ...
#  2  {Groundnut-bar, Cough-lozenges, Whipping-fresh...
#  3  {Nectar-de-pommes, Groundnut-bar, Dried-meat, ...
#  4  {Groundnut-bar, Fruit-sticks, Prepackaged-sand...
#  5  {Porc, Pure-cod-liver-oil, Fruit-sticks, Froze...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     130     0        46   Venezia  Bologna
#  1     130     1        46   Bologna  Brescia
#  2     130     2        46   Brescia   Trento
#  3     130     3        46    Trento  Treviso
#  4     130     4        46   Treviso   Padova
#  5     130     5        46    Padova  Ravenna
#
#                                                 Items
#  0  {Mini-portobello-mushrooms, Cottage-cheeses, B...
#  1  {Mini-portobello-mushrooms, Cured-sausage, Fro...
#  2  {Mini-portobello-mushrooms, Danette-chocolate-...
#  3  {Levures, Burrito-kit, Colorants-alimentaires,...
#  4  {Fat-free-milk, Sweet-biscuits, Dried-sausages...
#  5  {Levures, Fresh-bread, Colorants-alimentaires,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     131     0        35   Venezia  Bologna
#  1     131     1        35   Bologna  Bolzano
#  2     131     2        35   Bolzano   Verona
#  3     131     3        35    Verona   Padova
#  4     131     4        35    Padova  Bergamo
#  5     131     5        35   Bergamo  Mantova
#  6     131     6        35   Mantova   Milano
#
#                                                 Items
#  0  {Mini-portobello-mushrooms, Indian-food-mixes,...
#  1  {Plant-based foods and beverages, Frozen foods...
#  2  {Baby-peas, Lime-pickle, Milkshake, Biryani, G...
#  3  {Multifruits, Dried-mango, Baby-peas, Milkshak...
#  4  {Multifruits, Frozen-prawns, Ground-cinnamon, ...
#  5  {Frozen-prawns, Ground-cinnamon, Low-fat-high-...
#  6  {Mini-portobello-mushrooms, Madeira-cake, Beef...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     132     0        43   Bologna   Padova
#  1     132     1        43    Padova  Bergamo
#  2     132     2        43   Bergamo  Venezia
#  3     132     3        43   Venezia   Verona
#
#                                                 Items
#  0  {Cottage-cheeses, Salads, Schwarztees, Pineapp...
#  1  {Cooking-chocolate, Seed-mix, Horseradish-sauc...
#  2  {Sirop-de-fruits, Jambons-blancs, Roquefort-ch...
#  3  {Plant-based foods and beverages, Frozen-potat...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     133     0         0   Mantova  Brescia
#  1     133     1         0   Brescia  Ravenna
#  2     133     2         0   Ravenna   Verona
#  3     133     3         0    Verona   Trento
#  4     133     4         0    Trento   Padova
#  5     133     5         0    Padova   Rovigo
#
#                                                 Items
#  0  {Cured-sausage, Indian-sauces, Baking-powder, ...
#  1  {Pancakes-and-waffles, Protein, Coconut-water,...
#  2  {Confitures-allegees, Protein, Tomkin-tomatoes...
#  3  {Pork-chipolatas, Rose-water, Ice-tea, Milk-ch...
#  4  {Pork-chipolatas, Ice-tea, Spice-red-pepper, C...
#  5  {Multiseeded-sliced-bread, Spice-red-pepper, F...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     134     0        28    Verona   Padova
#  1     134     1        28    Padova  Venezia
#  2     134     2        28   Venezia    Parma
#
#                                                 Items
#  0  {Vegetarian-mock-meat, Chicken-tikka-masala, D...
#  1  {Vegetarian-mock-meat, Crsips, Chutney, Peeled...
#  2  {Bathroom, Mackerel-fillets-in-sunflower-oil, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     135     0        33   Bolzano  Venezia
#  1     135     1        33   Venezia  Bergamo
#  2     135     2        33   Bergamo  Mantova
#  3     135     3        33   Mantova  Treviso
#  4     135     4        33   Treviso   Trento
#
#                                                 Items
#  0  {Chicken-burgers, Salads, Vleeswaren, Rice-pap...
#  1  {Chocolat, Corn-tortilla, Feuilletes-chevre-ep...
#  2  {Chocolat, Pasta-bake-sauces, Feuilletes-chevr...
#  3  {Peanut-butter-and-chocolat-chip-cereal-bar, F...
#  4  {Mandarin-juice, Sirloin-steak, Milk-chocolate...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     136     0        18   Bergamo  Mantova
#  1     136     1        18   Mantova  Bologna
#  2     136     2        18   Bologna  Bolzano
#
#                                                 Items
#  0  {Mini-portobello-mushrooms, Indian-sauces, Nat...
#  1  {Kale-salads, Indian, Chicken-pies, Coffee-cre...
#  2  {Carbonated-soda-water, Milk substitute, Cranb...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     137     0        17   Ravenna   Milano
#  1     137     1        17    Milano  Brescia
#  2     137     2        17   Brescia   Modena
#  3     137     3        17    Modena  Mantova
#  4     137     4        17   Mantova  Bolzano
#
#                                                 Items
#  0  {Madeleines-au-chocolat, Nane-limon, Non food ...
#  1  {Fresh-lemons, Madeleines-au-chocolat, Nane-li...
#  2  {Madeleines-au-chocolat, Beers-from-stralsund,...
#  3  {Juices, Peeled-plum-tomatoes, Frozen-readymea...
#  4  {Dilute-drink, Peeled-plum-tomatoes, Frozen-re...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     138     0        43    Trento    Parma
#  1     138     1        43     Parma   Rovigo
#  2     138     2        43    Rovigo  Treviso
#
#                                                 Items
#  0  {Egg-salad, Pannekoeken, Goat-milk, Radish, Go...
#  1  {Pannekoeken, Radish, Vegetable-fat-spread, Ch...
#  2  {Snack-bar, Prepackaged-lettuce, Radish, Choco...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     139     0        48     Parma  Bologna
#  1     139     1        48   Bologna  Venezia
#  2     139     2        48   Venezia  Ravenna
#  3     139     3        48   Ravenna  Treviso
#  4     139     4        48   Treviso   Padova
#  5     139     5        48    Padova   Rovigo
#  6     139     6        48    Rovigo   Milano
#
#                                                 Items
#  0  {Coconut-milk-powder, Pork-chops, Penne, Penne...
#  1  {Coconut-milk-powder, Radish, Parve, Almond-po...
#  2  {Wortelsappen, Pork-chops, Penne, Peanut-butte...
#  3  {Pierogies, Blinis, Glaces, Peanut-butter-blis...
#  4  {Trimmed-beans, Cured-sausage, Root-beer, Pier...
#  5  {Curries, Raspberries-in-syrup, Pierogies, Sup...
#  6  {Suppenwurfel, Sables, Indian, Nectar-de-fruit...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     140     0        24     Parma   Milano
#  1     140     1        24    Milano   Trento
#  2     140     2        24    Trento  Mantova
#  3     140     3        24   Mantova  Brescia
#
#                                                 Items
#  0  {Beef-stroganoff, Tuiles-salees, Fresh-cabbage...
#  1  {Beef-stroganoff, Vegetable-fat-spread, Apple-...
#  2  {Schwarztees, Beef-stroganoff, Thes-glaces, Ap...
#  3  {Crevettes, Bean-flour, Spearmint-sugarfree-gu...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     141     0        30   Bergamo  Bologna
#  1     141     1        30   Bologna   Rovigo
#  2     141     2        30    Rovigo  Treviso
#  3     141     3        30   Treviso   Trento
#  4     141     4        30    Trento   Modena
#  5     141     5        30    Modena  Bolzano
#
#                                                 Items
#  0  {Plats-prepares-surgeles, Frozen-sweetcorn, Sw...
#  1  {Baguettes-de-pain, Garlic-and-coriander-naan,...
#  2  {Vinaigres, Miels, Garlic-and-coriander-naan, ...
#  3  {Lager-beer, Vinaigres, Lemon-curd, Susswaren,...
#  4  {Lager-beer, Vinaigres, Meat-pies, Gin, Lemon-...
#  5  {Lager-beer, Charcuteries, Horseradish-sauce, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     142     0        47     Parma  Brescia
#  1     142     1        47   Brescia  Bergamo
#  2     142     2        47   Bergamo  Mantova
#  3     142     3        47   Mantova  Treviso
#  4     142     4        47   Treviso   Rovigo
#  5     142     5        47    Rovigo  Ravenna
#  6     142     6        47   Ravenna   Verona
#
#                                                 Items
#  0  {Citrus-punch, Chocolate-ice-cream, Ribbon-noo...
#  1  {Lait-de-vache-concentre-non-sucre, Chocolate-...
#  2  {Rice-cakes, Wholefood, Kase, Medium-cheddar, ...
#  3  {Rice-cakes, Kase, Lait, Bambusstreifen, Yello...
#  4  {Profiteroles, Chicken-burger, Malt-vinegar, G...
#  5  {Dried-mango, Pork-sausages, Edible-decoration...
#  6  {Snack-bar, Dolce-gusto-compatible-coffee-caps...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     143     0        46   Treviso  Bolzano
#  1     143     1        46   Bolzano   Padova
#  2     143     2        46    Padova  Bologna
#  3     143     3        46   Bologna  Bergamo
#  4     143     4        46   Bergamo   Milano
#  5     143     5        46    Milano   Modena
#  6     143     6        46    Modena   Verona
#
#                                                 Items
#  0  {Pork-chipolatas, Pina-colada, Coconut-milk-po...
#  1  {Baking, Pina-colada, Chocolate-rice-cakes, Fr...
#  2  {Baking, Pina-colada, Canned-mussels, Saucisse...
#  3  {Pina-colada, Organic-tomatoes, Mulled-wine-sp...
#  4  {Beers-from-stralsund, Parve, Crab-pate, Sweet...
#  5  {Cooked-vegetables, Roasted-and-ground-coffee,...
#  6  {Frozen-sweetcorn, Sunflower-spread, Green oli...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     144     0        22   Ravenna  Mantova
#  1     144     1        22   Mantova  Bologna
#  2     144     2        22   Bologna   Verona
#  3     144     3        22    Verona   Trento
#  4     144     4        22    Trento  Venezia
#
#                                                 Items
#  0  {Chow-mein, Moutardes, Pan-di-spagna, Algues-e...
#  1  {Chow-mein, Moutardes, Pan-di-spagna, Algues-e...
#  2  {Frozen-snacks-aperitifs, Porridge-oats, Powde...
#  3  {Frozen-snacks-aperitifs, Mushroom-in-sunflowe...
#  4  {Canned-coconut-milk, Mais, Dark-soy-sauce, Su...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     145     0        31   Ravenna   Padova
#  1     145     1        31    Padova   Milano
#  2     145     2        31    Milano   Verona
#  3     145     3        31    Verona  Bergamo
#  4     145     4        31   Bergamo    Parma
#
#                                                 Items
#  0  {Rice-cakes, Whole-chicken, Peanut-butter-cup,...
#  1  {Baking, Fresh-brown-onions, Latticini, Peanut...
#  2  {Baking, Goat-milk, Tortilla-chips, Vitamins, ...
#  3  {Baking, Kase, Goat-milk, Biryani, Schokoladen...
#  4  {Groundnut-bar, Biryani, Schokoladen, Mexican-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     146     0        15   Bergamo  Venezia
#  1     146     1        15   Venezia  Bologna
#  2     146     2        15   Bologna   Padova
#  3     146     3        15    Padova   Verona
#  4     146     4        15    Verona   Trento
#  5     146     5        15    Trento   Rovigo
#  6     146     6        15    Rovigo  Brescia
#
#                                                 Items
#  0  {Turkey-bacon, Garlic-naan-breads, Sirop, Radi...
#  1  {Turkey-bacon, Fizzy-drinks, Camembert-cheese,...
#  2  {Plant-based foods and beverages, Crumpets, Go...
#  3  {Plant-based foods and beverages, Sweetcorn, F...
#  4  {Chocolate-rice-cakes, Flour-tortillas, Crumpe...
#  5  {Chocolate-rice-cakes, Snack-sale, Chicken-mea...
#  6  {Diced-tomatoes, Snack-sale, Sparkling-water-b...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     147     0         8    Padova  Brescia
#  1     147     1         8   Brescia   Verona
#  2     147     2         8    Verona   Rovigo
#
#                                                 Items
#  0  {Mashed-potatoes, Tomato-chilli-relish, Guava-...
#  1  {Non food products, Salad, Asian-foods, Prepac...
#  2  {Peanut-butter-and-chocolat-chip-cereal-bar, M...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     148     0        41    Rovigo  Venezia
#  1     148     1        41   Venezia   Padova
#  2     148     2        41    Padova  Bolzano
#  3     148     3        41   Bolzano  Brescia
#  4     148     4        41   Brescia  Bergamo
#
#                                                 Items
#  0  {Non-dairy-soymilk, Nane-limon, Pasteurized-mi...
#  1  {Groundnut-bar, Non-dairy-soymilk, Sun-dried-t...
#  2  {Dairies, Wraps, Egg-lasagne, Lemon-extract, S...
#  3  {Dairies, Spring-roll-pastry, Penne, Energy-ba...
#  4  {Vegetarian-frozen-food, Crisp-rolls, Banana-c...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     149     0        28    Rovigo  Bologna
#  1     149     1        28   Bologna  Bergamo
#  2     149     2        28   Bergamo    Parma
#  3     149     3        28     Parma   Trento
#  4     149     4        28    Trento  Venezia
#  5     149     5        28   Venezia   Verona
#  6     149     6        28    Verona  Brescia
#
#                                                 Items
#  0  {Smoked-cheese, Canned-mussels, Sweetcorn-reli...
#  1  {Chicken-burgers, Rice-cakes, Smoked-cheese, T...
#  2  {Chicken-burgers, Rice-cakes, Smoked-cheese, N...
#  3  {Paves-de-saumon, Natural-yoghurts, Bbq-relish...
#  4  {Bbq-relish, Manuka-honey, Juice-drinks, Vins-...
#  5  {Natural-yoghurts, Pasteurized-milk, Quso-duro...
#  6  {Pasteurized-milk, Lamb-breast, Pates-a-tartin...  ]

# %%
all_trips = pd.concat(routes)

# %%
# Save the trips for the mining part
all_trips.to_csv("route_trips.csv")
