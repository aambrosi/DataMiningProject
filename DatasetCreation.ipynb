# %%
import pandas as pd
import numpy  as np
import time   # To calculate the execution time
import bisect # For the WeightedRandomGenerator
import random # For the generation of random numbers

# The dataset was created by using a food dataset and saved outside because the original dataset was huge (1GB).
product_list = pd.read_csv('categories.csv', 
                           delimiter = ',', 
                           encoding  = 'utf-8')

# I delete few strange strings
product_list = product_list.drop([123, 157, 440, 442])

final_product_list                     = pd.DataFrame(product_list['Name'])
final_product_list['Popularity']       = np.random.random_sample(len(final_product_list))

# Index reset due to problems with non-consecutive indexes
final_product_list.reset_index(drop    = True, 
                               inplace = True)

# %%
cities = pd.read_csv('world-cities.csv', 
                     delimiter = ',', 
                     encoding  = 'utf-8')

# Set the number of cities to 100
nCities = 100
cities  = cities.sample(nCities)

# Index reset due to problems with non-consecutive indexes
cities.reset_index(drop    = True, 
                   inplace = True)
city_list         = pd.DataFrame(cities.name)
city_list.columns = ['Name']

# %%
#city_list["Export"] = ""
#city_list["Import"] = ""

# %%
# range of exported and imported for each city setted respectively at 3:20 and 10:50
minExp = 5
maxExp = 40
minImp = 20
maxImp = 100

# THIS PART CAN BE RUN IN PARALLEL (SPARK)
#start = time.time()
#for c in range(0,len(city_list)):
#    num_exp = np.random.randint(minExp,maxExp)
#    num_imp = np.random.randint(minImp,maxImp)
#    exp = np.unique(final_product_list.sample(num_exp, weights=final_product_list.Popularity).Name)
#    possible_imp_products = final_product_list[~final_product_list['Name'].isin(exp)]
#    imp = np.unique(possible_imp_products.sample(num_imp, weights=possible_imp_products.Popularity).Name)
#    city_list.loc[c,'Export'] = exp
#    city_list.loc[c,'Import'] = imp
#print(time.time()-start)

# %%
# A class for the generation of random weighted lists of products
class WeightedRandomGenerator(object):
    def __init__(self, weights):
        self.totals   = []
        running_total = 0
        for weight in weights:
            running_total += weight
            self.totals.append(running_total)

    def next(self):
        rnd = random.random() * self.totals[-1]
        return bisect.bisect_right(self.totals, rnd)

    def __call__(self):
        return self.next()

# Produce a list of import and export for a trip
def importExportGenerator():
    num_exp = np.random.randint(minExp, maxExp) # How many export
    num_imp = np.random.randint(minImp, maxImp) # How many import
    result  = {} # The final result to return
    exp     = [] # Export
    imp     = [] # Import
    
    # Generate a list of indexes of product to export
    for ne in range(0, num_exp):
        rg = final_product_list.Name[int(randomGenerator())]
        if(rg not in exp):
            exp.append(rg)
        else:
            ne -= 1
    
    # Generate a list of indexes of product to import
    for ni in range(0, num_imp):
        rg = final_product_list.Name[int(randomGenerator())]
        # We check if the products are already in the export list 
        # in order to avoid the import of them
        if((rg not in imp) & (rg not in exp)):
            imp.append(rg)
        else:
            ni -= 1
            
    result['exp'] = exp
    result['imp'] = imp
    return result
    
start           = time.time()
randomGenerator = WeightedRandomGenerator(final_product_list.Popularity)
values          = [(value['exp'], value['imp'])
                   for value in [importExportGenerator()
                                 for i in range(0, len(city_list))]]
exp             = []
imp             = []

for index in range(0, len(values)):
    exp.append(values[index][0])
    imp.append(values[index][1])
city_list['Export'] = exp
city_list['Import'] = imp

print(time.time() - start)
# Out:
# 0.20741724967956543

# %%
def standard_info(i, rid, tcd, trip, final_trip):
    final_trip.loc[i, 'RouteId']   = rid
    final_trip.loc[i, 'Order']     = i
    final_trip.loc[i, 'TruckCode'] = tcd
    final_trip.loc[i, 'StartCity'] = trip.loc[i    , 'IdCity']
    final_trip.loc[i, 'EndCity']   = trip.loc[i + 1, 'IdCity']

def first_step_creation(rid, tcd, length, trip):
    final_trip   = pd.DataFrame(columns = ['RouteId', 'Order', 'TruckCode', 'StartCity', 'EndCity', 'Items'])
    standard_info(0, rid, tcd, trip, final_trip)
    maxProbItems = list(set(trip.loc[length - 1, "PopularImport"]).intersection(trip.loc[length - 2, "ExportableItems"]))
    maxProbItems = maxProbItems * 5
    trip.loc[length - 2, "ExportableItems"].extend(maxProbItems)
    # I set the range to be not fixed to 5-20 for the first trip cities that have few exportable items and I set
    # them to half to all the possible exportable items
    numItems = np.random.randint(min(5, len(trip.loc[length - 2, "ExportableItems"]) / 2), 
                                 min(15, len(trip.loc[length - 2, "ExportableItems"])))
    sample   = set(random.sample(trip.loc[length - 2, "ExportableItems"], numItems))
    final_trip.loc[length - 2, 'Items'] = sample
    return final_trip
    
def trip_creation(i, rid, tcd, length, trip, final_trip):
    standard_info(i - 1, rid, tcd, trip, final_trip)
    crev            = length - i - 1
    possibleExports = list(final_trip.loc[crev + 1, 'Items'])
    itemsToDelete   = set(possibleExports).intersection(list(city_list.loc[list(city_list.Name).index(trip.loc[crev + 1, 
                                                                                                               'IdCity']), 
                                                                           'Export']))
    for item in itemsToDelete:
        possibleExports.remove(item)
        
        
    #############
    ############# 3 e 15 da mettere come variabili?
    #############
    numItems = np.random.randint(3, min(15, len(trip.loc[crev, "ExportableItems"])))
    #############
    sample   = set(random.sample(trip.loc[crev, "ExportableItems"], numItems))
    final_trip.loc[crev, 'Items'] = set(possibleExports).union(sample)
    return final_trip

# %%
# Range of trip length setted at 3:10. We set the number of trucks to 1000
minLen   = 3
maxLen   = 10
numTruck = 1000

def generate_trip(i):
    length = np.random.randint(minLen, maxLen)
    trip   = pd.DataFrame(columns = ['IdCity', 'ExportableItems', 'PopularImport'])
    items  = []
    cities = []
    for c in range(0, length):
        city     = np.random.randint(0, len(city_list))
        while city in cities:
            city = np.random.randint(0, len(city_list))
        cities.append(city)
        trip.loc[c, 'IdCity'] = city_list.loc[city, 'Name']
        items.extend(city_list.loc[city, 'Export'])
        trip.loc[c, 'ExportableItems'] = items.copy()
        trip.loc[c, 'PopularImport']   = city_list.loc[city, 'Import']
    rid = i
    tcd = np.random.randint(0, numTruck)
    final_trip = first_step_creation(rid, tcd, length, trip)
    for c in range(2,length):
        final_trip = trip_creation(c, rid, tcd, length, trip, final_trip)
    final_trip = final_trip.sort_values('Order')
    return final_trip

# %%
# Generate n trips
def generate_trips(n):
    return [generate_trip(i) for i in range(0, n)]

# %%
numberOfTrips = 100
trips         = generate_trips(numberOfTrips)

# %%
trips
# Out:
# [  RouteId Order TruckCode         StartCity           EndCity  \
#  0       0     0       602            Shiyan          Zirndorf
#  1       0     1       602          Zirndorf              Ippy
#  2       0     2       602              Ippy            Azazga
#  3       0     3       602            Azazga  Sesto Fiorentino
#  4       0     4       602  Sesto Fiorentino            Kakata
#
#                                                 Items
#  0  {Pralines, Scottish-shortbread, Olives-denoyau...
#  1  {Pralines, White-coconut-chocolate, Scottish-s...
#  2  {Pralines, White-coconut-chocolate, Scottish-s...
#  3  {Piccalilli, Sundried-tomatoes, Turkish-fermen...
#  4  {Peanut-in-chocolate, Low-fat-high-calcium-mil...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0       1     0       626        Caracas   Korrewegwijk
#  1       1     1       626   Korrewegwijk      Chandauli
#  2       1     2       626      Chandauli  McKinleyville
#  3       1     3       626  McKinleyville          Rubio
#  4       1     4       626          Rubio         Dwārka
#  5       1     5       626         Dwārka       Merouana
#  6       1     6       626       Merouana     Giv‘atayim
#
#                                                 Items
#  0  {Baking, Gelati, Chia-seeds, Whisky-ecossais, ...
#  1  {Sweet-chilli-sauce, Steak-kidney-pie, Asian-g...
#  2  {Sweet-chilli-sauce, Asian-grocery, Dry-meat, ...
#  3  {Sweet-chilli-sauce, Asian-grocery, Chia-samen...
#  4  {Sweet-chilli-sauce, Asian-grocery, Chia-samen...
#  5  {Corned-beef, Asian-grocery, Hoisin-sauce, Cor...
#  6  {Corned-beef, Green-beans, Cioccolatini, Froze...  ,
#    RouteId Order TruckCode      StartCity    EndCity  \
#  0       2     0        40  Dar es Salaam   Kamloops
#  1       2     1        40       Kamloops  Hashimoto
#  2       2     2        40      Hashimoto    Atbasar
#  3       2     3        40        Atbasar   Pennādam
#  4       2     4        40       Pennādam       León
#
#                                                 Items
#  0  {Compota, Salades-strasbourgeoises, Biere, Cra...
#  1  {Compota, Piccalilli, Salades-strasbourgeoises...
#  2  {Compota, Piccalilli, Salades-strasbourgeoises...
#  3  {Compota, Piccalilli, Salades-strasbourgeoises...
#  4  {Piccalilli, Prosciutto, Cremes-vegetales-a-ba...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0       3     0       405             La Paz      Grottaferrata
#  1       3     1       405      Grottaferrata             Kakata
#  2       3     2       405             Kakata           Chingola
#  3       3     3       405           Chingola           Victoria
#  4       3     4       405           Victoria       Korrewegwijk
#  5       3     5       405       Korrewegwijk  São Pedro da Cova
#  6       3     6       405  São Pedro da Cova       Puerto Aisén
#  7       3     7       405       Puerto Aisén             Neston
#
#                                                 Items
#  0  {Chicken-mushroom-pie, Peels, Asian-sauces, Ea...
#  1  {Root-beer, Plant-based foods and beverages, C...
#  2  {Beer-batter-fries, Root-beer, Plant-based foo...
#  3  {Beer-batter-fries, Cordials, Plant-based food...
#  4  {Cake-mix, Beer-batter-fries, Kartoffelchips, ...
#  5  {Beer-batter-fries, Asian-grocery, Pitta-bread...
#  6  {Beer-batter-fries, Asian-grocery, Pains-d-epi...
#  7  {Toppings, Asian-grocery, Kartoffelchips, Fres...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0       4     0       823              León        Willenhall
#  1       4     1       823        Willenhall          Stamford
#  2       4     2       823          Stamford        Libreville
#  3       4     3       823        Libreville           Redmond
#  4       4     4       823           Redmond  Sault Ste. Marie
#  5       4     5       823  Sault Ste. Marie           Propriá
#
#                                                 Items
#  0  {Capsicums, Corn-tortilla, Pays-d-oc, Powder, ...
#  1  {Slaty-snack, Capsicums, Corn-tortilla, Powder...
#  2  {Capsicums, Slaty-snack, Corn-tortilla, Concom...
#  3  {Pitta-breads, Capsicums, Corn-tortilla, Conco...
#  4  {Pitta-breads, Capsicums, Corn-tortilla, Conco...
#  5  {Skim-milk, Spice-red-pepper, Bruschetta, Caps...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0       5     0       716   Yatağan  Neston
#  1       5     1       716    Neston   Maisí
#
#                                                 Items
#  0  {Condiment-en-poudre, Sugar-free-confectionary...
#  1  {Barbeque-sauce, Trail-mix, Raw-organic-honey,...  ,
#    RouteId Order TruckCode      StartCity           EndCity  \
#  0       6     0       395           Fuyo            Orange
#  1       6     1       395         Orange           Cormano
#  2       6     2       395        Cormano          Victoria
#  3       6     3       395       Victoria     Grottaferrata
#  4       6     4       395  Grottaferrata  Sault Ste. Marie
#
#                                                 Items
#  0  {Mixed-nuts, Blackcurrent-juice-drink, Gelee-d...
#  1  {Amaretto, Mixed-nuts, Milchprodukt, Barritas,...
#  2  {Lasagne-sheets, Amaretto, Produits-ssans-glut...
#  3  {Lasagne-sheets, Amaretto, Frozen-chicken, Bis...
#  4  {Frozen-chicken, Garlic-mashed-potatoes, Milch...  ,
#    RouteId Order TruckCode  StartCity           EndCity  \
#  0       7     0       169     Zouila         Singosari
#  1       7     1       169  Singosari          Marratxí
#  2       7     2       169   Marratxí  Sesto Fiorentino
#
#                                                 Items
#  0  {Curry, Malt-vinegar, Minced-lamb, Coleslaw-dr...
#  1  {Curry, Plastic-surgery, Parve, Organic-spelt-...
#  2  {Curry, Plastic-surgery, Parve, Organic-spelt-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0       8     0       752     Mislata    Pennādam
#  1       8     1       752    Pennādam     Barabai
#  2       8     2       752     Barabai  Willenhall
#  3       8     3       752  Willenhall   Rio Negro
#  4       8     4       752   Rio Negro    Pitalito
#
#                                                 Items
#  0  {Cauliflower-cheese, Noix-de-paprika, Parve, G...
#  1  {Noix-de-paprika, Parve, Kaffir-lime-leaves, M...
#  2  {Noix-de-paprika, Instant-mashed-potato, Kaffi...
#  3  {Swede, Fruit juices, Instant-mashed-potato, S...
#  4  {Fruit juices, Carots, Eau-de-vie, Schwarztees...  ,
#    RouteId Order TruckCode    StartCity    EndCity  \
#  0       9     0       582  Livingstone      Maisí
#  1       9     1       582        Maisí  Rio Negro
#  2       9     2       582    Rio Negro    Polanco
#  3       9     3       582      Polanco     La Paz
#
#                                                 Items
#  0  {Steak-kidney-pie, Beer-batter-fries, Sweetene...
#  1  {Legumes-au-vinaigre, Cordial, Flavoured-rice-...
#  2  {Olive-ciabatta, Flavoured-rice-cakes, Custard...
#  3  {Olive-ciabatta, Legumes-au-vinaigre, Fresh-ju...  ,
#    RouteId Order TruckCode  StartCity              EndCity  \
#  0      10     0       516    Aquiraz            Neryungri
#  1      10     1       516  Neryungri               Orange
#  2      10     2       516     Orange              Yichang
#  3      10     3       516    Yichang              Mislata
#  4      10     4       516    Mislata             Pennādam
#  5      10     5       516   Pennādam             Kozyatyn
#  6      10     6       516   Kozyatyn  Venustiano Carranza
#
#                                                 Items
#  0  {Kartoffelchips, Tortilla-chips, Aliments-d-or...
#  1  {Fuet-met-zwarte-peper, Mixed-nuts, Churned-cr...
#  2  {Amaretto, Mixed-nuts, Churned-cream, Bbq-reli...
#  3  {Kartoffelchips, Mixed-nuts, Churned-cream, Re...
#  4  {Kartoffelchips, Mixed-nuts, Parve, Redcurrant...
#  5  {Kartoffelchips, Parve, Redcurrant-tea, Cactus...
#  6  {Cinamon-donuts, Yellow-mustard, Lime-marmalad...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      11     0       592       Vyborg  Perth Amboy
#  1      11     1       592  Perth Amboy     Trindade
#
#                                                 Items
#  0  {Pitta-breads, Lingonberry-jams, Olives-denoya...
#  1  {Pitta-breads, Lingonberry-jams, Sugar-cane-dr...  ,
#    RouteId Order TruckCode      StartCity   EndCity  \
#  0      12     0        89  McKinleyville    Bariri
#  1      12     1        89         Bariri     Rubio
#  2      12     2        89          Rubio  Stamford
#  3      12     3        89       Stamford     Daura
#
#                                                 Items
#  0  {Rye-pale-ale, Chia-samen, Corn-tortilla, Crem...
#  1  {Pineapple-slices-in-juice, Chia-samen, Corn-t...
#  2  {Chia-samen, Orange-chocolate, Cioccolatini, F...
#  3  {Chia-samen, Orange-chocolate, Artisan product...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      13     0       283         Kawit       Cormano
#  1      13     1       283       Cormano      Pitalito
#  2      13     2       283      Pitalito       Caracas
#  3      13     3       283       Caracas      Kozyatyn
#  4      13     4       283      Kozyatyn  Korrewegwijk
#  5      13     5       283  Korrewegwijk        Bariri
#  6      13     6       283        Bariri         Daura
#
#                                                 Items
#  0  {Jus-d-orange, Lingonberry-jams, Hot-cross-bun...
#  1  {Fruit-drinks, Jus-d-orange, Frozen-snacks, Ch...
#  2  {Produits-ssans-gluten, Fruit-drinks, Jus-d-or...
#  3  {Produits-ssans-gluten, Fruit-drinks, Jus-d-or...
#  4  {Pate, Produits-ssans-gluten, Fruit-drinks, Ju...
#  5  {Jus-d-orange, Concombres, Cheese-singles, Chi...
#  6  {Jus-d-orange, Concombres, Beef-jerky, Cheese-...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      14     0       304    Lovisa  Neston
#  1      14     1       304    Neston  Orange
#
#                                                 Items
#  0  {White-pitta-bread, Root-beer, Bhakarwadi, Bri...
#  1  {Roma-tomatoes, Barbeque-sauce, Plats-prepares...  ,
#    RouteId Order TruckCode  StartCity        EndCity  \
#  0      15     0       657    Morales      Neryungri
#  1      15     1       657  Neryungri        Cormano
#  2      15     2       657    Cormano  Lomas del Sur
#
#                                                 Items
#  0  {Spice-red-pepper, Plats-prepares-surgeles, Su...
#  1  {Spice-red-pepper, Farming products, Pate-a-ta...
#  2  {Double-chocolate-milk, Farming products, Effe...  ,
#    RouteId Order TruckCode   StartCity    EndCity  \
#  0      16     0       313  Tönisvorst   Pitalito
#  1      16     1       313    Pitalito     Kakata
#  2      16     2       313      Kakata  Hashimoto
#
#                                                 Items
#  0  {Scotch-eggs, Gin, Eau-de-vie, Preparations-de...
#  1  {Scotch-eggs, Gin, Eau-de-vie, Capers, Honey-r...
#  2  {Beer-batter-fries, Sweetelle-tomatoes, Frozen...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      17     0       688    El Hadjar   Libreville
#  1      17     1       688   Libreville       Zouila
#  2      17     2       688       Zouila  Perth Amboy
#  3      17     3       688  Perth Amboy      Sheohar
#  4      17     4       688      Sheohar     Zhaodong
#  5      17     5       688     Zhaodong    Mau Aimma
#
#                                                 Items
#  0  {Milkshake, Spare-pork-ribs, Pates-a-tartiner-...
#  1  {Pitta-breads, Saucisses-aux-lentilles, Mulled...
#  2  {Pitta-breads, Saucisses-aux-lentilles, Malt-v...
#  3  {Natural-spring-water, Pitta-breads, Saucisses...
#  4  {Milk-chocolate-digestives, Pitta-breads, Asia...
#  5  {White-pitta-bread, Mackerel-fillets-in-brine,...  ,
#    RouteId Order TruckCode  StartCity   EndCity  \
#  0      18     0        52  Chandauli  Muskogee
#  1      18     1        52   Muskogee   Aquiraz
#  2      18     2        52    Aquiraz  Pitalito
#  3      18     3        52   Pitalito   Redmond
#  4      18     4        52    Redmond  Zhaodong
#
#                                                 Items
#  0  {Bottled-still-water, Frozen-spring-rolls, Car...
#  1  {Bottled-still-water, Preparations-de-viande-s...
#  2  {Bottled-still-water, Mixed-nuts, Frozen-sprin...
#  3  {Mixed-nuts, Bottled-still-water, Frozen-sprin...
#  4  {Fruit-spreads, Bottled-still-water, Mixed-nut...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      19     0       558       Maisí  Willenhall
#  1      19     1       558  Willenhall   Singosari
#  2      19     2       558   Singosari  Tönisvorst
#  3      19     3       558  Tönisvorst      Vyborg
#
#                                                 Items
#  0  {Mackerel-fillets-in-sunflower-oil, Ratatouill...
#  1  {Chia-samen, Ratatouille, Dessert-mixes, Chine...
#  2  {Chia-samen, Ratatouille, Deep-fried, Dessert-...
#  3  {Sweetelle-tomatoes, Artisan products, Dessert...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      20     0       177      Acharnés        Dwārka
#  1      20     1       177        Dwārka  Puerto Aisén
#  2      20     2       177  Puerto Aisén          Ippy
#
#                                                 Items
#  0  {Bread-rolls, Chocolate-mints, Crackers-sans-g...
#  1  {Bread-rolls, Strawberry-mousse, Chocolate-min...
#  2  {Bread-rolls, Cured-sausage, Brussels-pate, Sm...  ,
#    RouteId Order TruckCode StartCity             EndCity  \
#  0      21     0       992  Muskogee             Cormano
#  1      21     1       992   Cormano                León
#  2      21     2       992      León  Middleburg Heights
#
#                                                 Items
#  0  {Preparations-de-viande-surgelees, Quesos, Fre...
#  1  {Toppings, Kauwgom, Dessert-lacte, Chilli-con-...
#  2  {Condiment-en-poudre, Kauwgom, Skim-milk, Muff...  ,
#    RouteId Order TruckCode      StartCity   EndCity  \
#  0      22     0       610  Rocca di Papa  Chingola
#  1      22     1       610       Chingola    La Paz
#  2      22     2       610         La Paz  Muskogee
#
#                                                 Items
#  0  {Maris-piper-potatoes, Beer-batter-fries, Froz...
#  1  {Maris-piper-potatoes, Beer-batter-fries, Froz...
#  2  {Beer-batter-fries, Kartoffelchips, Frozen-asi...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      23     0       283     Rwamagana  Korrewegwijk
#  1      23     1       283  Korrewegwijk       Atbasar
#  2      23     2       283       Atbasar       Morales
#
#                                                 Items
#  0  {Sucres, Kase, Pet food, Hot-chocolate, Mayona...
#  1  {Sucres, Sweet-chilli-sauce, Kase, Mayonaise, ...
#  2  {Muffin-mix, Sweet-chilli-sauce, Carots, Groce...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      24     0       404    Lovisa   Redmond
#  1      24     1       404   Redmond  Kozyatyn
#  2      24     2       404  Kozyatyn  Rochford
#  3      24     3       404  Rochford   Silifke
#  4      24     4       404   Silifke    Mwanza
#  5      24     5       404    Mwanza  Zhaodong
#  6      24     6       404  Zhaodong   Guaiúba
#  7      24     7       404   Guaiúba    Kibiti
#
#                                                 Items
#  0  {White-pitta-bread, Root-beer, Brie-cheese, Co...
#  1  {White-pitta-bread, Root-beer, Brie-cheese, Go...
#  2  {Pate, Root-beer, Frozen-ice-creams, Bbq-relis...
#  3  {Root-beer, Fruit-cups, Bbq-relish, Minced-lam...
#  4  {Bbq-relish, Fruit-cups, Minced-lamb, Malt-vin...
#  5  {Maris-piper-potatoes, Fajitas, Seed-style-mus...
#  6  {Maris-piper-potatoes, Fajitas, Bbq-relish, Mi...
#  7  {Asian-condiments, Vitamins, Bbq-relish, Mince...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      25     0       191             Rubio        Willenhall
#  1      25     1       191        Willenhall  Sesto Fiorentino
#  2      25     2       191  Sesto Fiorentino         Mau Aimma
#  3      25     3       191         Mau Aimma          Kamloops
#
#                                                 Items
#  0  {Unsalted-butter, Groenten, Orange-chocolate, ...
#  1  {Chia-samen, Groenten, Liquid-honey, Cucumbers...
#  2  {Peanut-in-chocolate, Cocktail-sauces, Spice-r...
#  3  {Spice-red-pepper, Chinese-cinnamon-sticks, Pr...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      26     0       772            Rochford  Middleburg Heights
#  1      26     1       772  Middleburg Heights             Redmond
#  2      26     2       772             Redmond              Lovisa
#
#                                                 Items
#  0  {Jambons-blancs, Balsamic-vinaigrette-dressing...
#  1  {Unsalted-butter, Fresh-corn, Cured-ham, Baked...
#  2  {Cafes-solubles, Unsalted-butter, Fresh-corn, ...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      27     0       111       Tiassalé        Atbasar
#  1      27     1       111        Atbasar     Willenhall
#  2      27     2       111     Willenhall   Korrewegwijk
#  3      27     3       111   Korrewegwijk  Lomas del Sur
#  4      27     4       111  Lomas del Sur         Vyborg
#  5      27     5       111         Vyborg   Hampton Park
#
#                                                 Items
#  0  {Hot-dog-mustard, Indian-sauces, Frozen-asian-...
#  1  {Jambons-blancs, Hot-dog-mustard, Milkshake, I...
#  2  {Jambons-blancs, Hot-dog-mustard, Milkshake, A...
#  3  {Jambons-blancs, Hot-dog-mustard, Asian-grocer...
#  4  {Jambons-blancs, Toppings, Hot-dog-mustard, As...
#  5  {Jambons-blancs, Cukor, Farina, Hokey-pokey-ic...  ,
#    RouteId Order TruckCode   StartCity   EndCity  \
#  0      28     0       769  Giv‘atayim  Kozyatyn
#  1      28     1       769    Kozyatyn    Neston
#  2      28     2       769      Neston      León
#
#                                                 Items
#  0  {Maris-piper-potatoes, Radish, Fromage-au-lait...
#  1  {Maris-piper-potatoes, Cordials, Bbq-relish, F...
#  2  {Roma-tomatoes, Orange-chocolate, Cordials, Tr...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      29     0       146    Victoria      La Paz
#  1      29     1       146      La Paz        Fuyo
#  2      29     2       146        Fuyo     Atbasar
#  3      29     3       146     Atbasar  Vénissieux
#  4      29     4       146  Vénissieux   Singosari
#  5      29     5       146   Singosari    Pitalito
#  6      29     6       146    Pitalito       Álamo
#
#                                                 Items
#  0  {Baking, Prepackaged-lettuce, Prosecco, Cake-m...
#  1  {Seitan-bio, Chutney, Turkey-burgers, Radish, ...
#  2  {Seitan-bio, Chutney, Kaffir-lime-leaves, Radi...
#  3  {Jambons-blancs, Fresh-prawns, Snacks, Plant-b...
#  4  {Jambons-blancs, Pet food, Fresh-lemons, Kaffi...
#  5  {Double-chocolate-milk, Jambons-blancs, Peanut...
#  6  {Double-chocolate-milk, Milkshake, Produits-ss...  ,
#    RouteId Order TruckCode  StartCity     EndCity  \
#  0      30     0       505  El Hadjar        Soma
#  1      30     1       505       Soma  Giv‘atayim
#
#                                                 Items
#  0  {Saucisses-aux-lentilles, Burrito-kit, Frozen-...
#  1  {Estragon, Saucisses-aux-lentilles, Peach-drin...  ,
#    RouteId Order TruckCode StartCity     EndCity  \
#  0      31     0       150    Kakata       Rubio
#  1      31     1       150     Rubio  Tönisvorst
#
#                                                 Items
#  0  {Fruit-sticks, Beer-batter-fries, Capsicums, M...
#  1  {Fruit-sticks, Beer-batter-fries, Capsicums, O...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      32     0       409   Puerto Aisén        Yichang
#  1      32     1       409        Yichang         Orange
#  2      32     2       409         Orange       Muskogee
#  3      32     3       409       Muskogee         Neston
#  4      32     4       409         Neston       Chawinda
#  5      32     5       409       Chawinda        Sheohar
#  6      32     6       409        Sheohar  McKinleyville
#  7      32     7       409  McKinleyville         Zouila
#
#                                                 Items
#  0  {Canned foods, Liszt, Oeufs-de-poisson, Tarama...
#  1  {Canned foods, Liszt, Pancake-syrup, Canned-be...
#  2  {Canned foods, Energy-ball, Liszt, Plastic-sur...
#  3  {Preparations-de-viande-surgelees, Chocolate-s...
#  4  {Orange-chocolate, Pancake-syrup, Gulab-jamun,...
#  5  {Lingonberry-jams, Corn-tortilla, Caramelized-...
#  6  {Lingonberry-jams, Chilli-con-carne-sauce, Gul...
#  7  {Lingonberry-jams, Creme-chocolat, Peanut-sauc...  ,
#    RouteId Order TruckCode      StartCity           EndCity  \
#  0      33     0       850        Silifke          Chawinda
#  1      33     1       850       Chawinda           Pénjamo
#  2      33     2       850        Pénjamo            Kakata
#  3      33     3       850         Kakata              León
#  4      33     4       850           León     Rocca di Papa
#  5      33     5       850  Rocca di Papa           Sheohar
#  6      33     6       850        Sheohar  Sesto Fiorentino
#
#                                                 Items
#  0  {Chocolate-muffin, Fruit-salad-in-juice, Sweet...
#  1  {Sweet-chilli-sauce, Tom-yum-soup, Chia-samen,...
#  2  {Lingonberry-jams, Chia-samen, Cheese-puffs, D...
#  3  {Beer-batter-fries, Lingonberry-jams, Capsicum...
#  4  {Artisan products, Levures, Cheese-puffs, Garl...
#  5  {Cheese-puffs, Wraps, Conservation, Artisan pr...
#  6  {Asian-condiments, Artisan products, Garlic-ma...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      34     0       382             Caracas  Middleburg Heights
#  1      34     1       382  Middleburg Heights                Desē
#  2      34     2       382                Desē            Kozyatyn
#  3      34     3       382            Kozyatyn            Chawinda
#  4      34     4       382            Chawinda             Barabai
#
#                                                 Items
#  0  {Gelati, Chia-seeds, Whisky-ecossais, Thes-ver...
#  1  {Unsalted-butter, Fresh-corn, Cured-ham, Baked...
#  2  {Unsalted-butter, Fresh-corn, Cured-ham, Baked...
#  3  {Pate, Unsalted-butter, Bbq-relish, Fajitas, F...
#  4  {Coconut-juice, Lingonberry-jams, Peanut-sauce...  ,
#    RouteId Order TruckCode     StartCity        EndCity  \
#  0      35     0         8     Rio Negro   Puerto Aisén
#  1      35     1         8  Puerto Aisén  Dar es Salaam
#
#                                                 Items
#  0  {South-african-merlot, Profiteroles, Mayonaise...
#  1  {Fish and meat and eggs, Fresh-juices, Turkey-...  ,
#    RouteId Order TruckCode  StartCity      EndCity  \
#  0      36     0       776     Shiyan    Rwamagana
#  1      36     1       776  Rwamagana  Santa Lucía
#
#                                                 Items
#  0  {Peanut-in-chocolate, Pure-chocolate, Profiter...
#  1  {Pate-feuilletee, Caramel-flavored-topping, Pr...  ,
#    RouteId Order TruckCode StartCity    EndCity  \
#  0      37     0        99   Kelowna    Caracas
#  1      37     1        99   Caracas     La Paz
#  2      37     2        99    La Paz   Zhaodong
#  3      37     3        99  Zhaodong    Pénjamo
#  4      37     4        99   Pénjamo      Álamo
#  5      37     5        99     Álamo   Kamloops
#  6      37     6        99  Kamloops   Chingola
#  7      37     7        99  Chingola  Mau Aimma
#
#                                                 Items
#  0  {Creme-caramel, Lasagne-sheets, Sandiwch, Seed...
#  1  {Creme-caramel, Lasagne-sheets, Sandiwch, Chia...
#  2  {Creme-caramel, Lasagne-sheets, Sandiwch, Chia...
#  3  {Creme-caramel, Lasagne-sheets, Sandiwch, Pean...
#  4  {Creme-caramel, Lasagne-sheets, Sandiwch, Pean...
#  5  {Creme-caramel, Ale, Sandiwch, Peanut-butter-c...
#  6  {Creme-caramel, Ale, Viande, Butter-chicken, S...
#  7  {Creme-caramel, Artisan products, Viande, Back...  ,
#    RouteId Order TruckCode      StartCity           EndCity  \
#  0      38     0        61     Giv‘atayim          Woodbury
#  1      38     1        61       Woodbury              Desē
#  2      38     2        61           Desē            Neston
#  3      38     3        61         Neston     Dar es Salaam
#  4      38     4        61  Dar es Salaam  Sesto Fiorentino
#
#                                                 Items
#  0  {Maris-piper-potatoes, Fromage-au-lait-cru, Sw...
#  1  {Maris-piper-potatoes, Fromage-au-lait-cru, Sw...
#  2  {Olive-ciabatta, Fromage-au-lait-cru, Profiter...
#  3  {Roma-tomatoes, Deshydrated-fruit, Fromage-au-...
#  4  {Roma-tomatoes, Fromage-au-lait-cru, Radish, P...  ,
#    RouteId Order TruckCode         StartCity       EndCity  \
#  0      39     0       228  Sesto Fiorentino  Hampton Park
#  1      39     1       228      Hampton Park     Haverhill
#  2      39     2       228         Haverhill      Pennādam
#  3      39     3       228          Pennādam       Polanco
#  4      39     4       228           Polanco        La Paz
#  5      39     5       228            La Paz  Puerto Aisén
#
#                                                 Items
#  0  {Peanut-in-chocolate, White-coconut-chocolate,...
#  1  {Peanut-in-chocolate, Quenelles, Frozen-prawns...
#  2  {Quenelles, Frozen-prawns, Garlic-mashed-potat...
#  3  {Baby-spinach, Blackcurrant-juice-syrup, Froma...
#  4  {Baby-spinach, Blackcurrant-juice-syrup, Baby-...
#  5  {Fromage-au-lait-cru, Smoked-mussels, Muslirie...  ,
#    RouteId Order TruckCode StartCity     EndCity  \
#  0      40     0       294    Kibiti     Redmond
#  1      40     1       294   Redmond  Port Louis
#
#                                                 Items
#  0  {Toppings, Red-seedless-grapes, Smoked-haddock...
#  1  {Toppings, Fruit-spreads, Milk-chocolate-eggs,...  ,
#    RouteId Order TruckCode  StartCity           EndCity  \
#  0      41     0       741       Desē            Mwanza
#  1      41     1       741     Mwanza           Redmond
#  2      41     2       741    Redmond          Muskogee
#  3      41     3       741   Muskogee         Chandauli
#  4      41     4       741  Chandauli           Mislata
#  5      41     5       741    Mislata          Trindade
#  6      41     6       741   Trindade  Sesto Fiorentino
#
#                                                 Items
#  0  {Olive-ciabatta, Yaourt-aux-fruits, Smoked-pap...
#  1  {Olive-ciabatta, Maris-piper-potatoes, Plato-p...
#  2  {Olive-ciabatta, Maris-piper-potatoes, Cough-l...
#  3  {Olive-ciabatta, Maris-piper-potatoes, Cough-l...
#  4  {Maris-piper-potatoes, Terrine, Caramelized-re...
#  5  {Maris-piper-potatoes, Noix-de-paprika, Sandwi...
#  6  {Toppings, Noix-de-paprika, Sandwich, Egg-whit...  ,
#    RouteId Order TruckCode    StartCity     EndCity  \
#  0      42     0        21  Perth Amboy      Zouila
#  1      42     1        21       Zouila  Port Louis
#  2      42     2        21   Port Louis        Fuyo
#
#                                                 Items
#  0  {Natural-spring-water, Instant-porridge, Sandw...
#  1  {Curry, Instant-porridge, Fresh-cabbage, Mince...
#  2  {Mixed-chillies, Corn-tortilla, Minced-lamb, S...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      43     0       471      Pénjamo   Willenhall
#  1      43     1       471   Willenhall        Aloha
#  2      43     2       471        Aloha  Perth Amboy
#  3      43     3       471  Perth Amboy      Redmond
#
#                                                 Items
#  0  {Sugar-free-confectionary, Aceite-de-coco, Vin...
#  1  {Nonpareil-capers, Skim-milk, Prepared-salads,...
#  2  {Skim-milk, Piccalilli, Olives-denoyautees, Fu...
#  3  {Skim-milk, Piccalilli, Sandwichs, Fusilli, Ho...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      44     0       816       Luoyang  Korrewegwijk
#  1      44     1       816  Korrewegwijk        Kakata
#  2      44     2       816        Kakata     Chandauli
#  3      44     3       816     Chandauli      Woodbury
#
#                                                 Items
#  0  {Cured-ham, Black-truffle-oil, Saucissons, Dri...
#  1  {Dried-pasta, Cured-ham, Asian-food, Prawn-cra...
#  2  {Dried-pasta, Cured-ham, Creme-brulee, Asian-f...
#  3  {Cured-ham, Chillies, Poissons, Caramelized-re...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      45     0       813     Acharnés       Neston
#  1      45     1       813       Neston      Caracas
#  2      45     2       813      Caracas         Ippy
#  3      45     3       813         Ippy       Shiyan
#  4      45     4       813       Shiyan        Álamo
#  5      45     5       813        Álamo     Zhaodong
#  6      45     6       813     Zhaodong  Livingstone
#  7      45     7       813  Livingstone     Tiassalé
#
#                                                 Items
#  0  {Raisin-bread, Ginseng-tea, Crackers-sans-glut...
#  1  {Crackers-sans-gluten, Ginseng-tea, Pastry-dou...
#  2  {Baking, Crackers-sans-gluten, Pastry-dough, C...
#  3  {Baking, Pastry-dough, Aoli-sauce, Prosecco, P...
#  4  {Baking, Saucisses-aux-lentilles, Scottish-sho...
#  5  {Baby-sanmarzano-tomatoes, Vin-de-californie, ...
#  6  {Baby-sanmarzano-tomatoes, Vin-de-californie, ...
#  7  {Steak-kidney-pie, Sardines-in-brine, Saucisse...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      46     0       945    Hunchun    Propriá
#  1      46     1       945    Propriá    Polanco
#  2      46     2       945    Polanco     Zouila
#  3      46     3       945     Zouila       Ippy
#  4      46     4       945       Ippy  Neryungri
#  5      46     5       945  Neryungri  Haverhill
#  6      46     6       945  Haverhill     Azazga
#  7      46     7       945     Azazga    Morales
#
#                                                 Items
#  0  {White-coconut-chocolate, Fresh-prawns, Fajita...
#  1  {Sardines-in-brine, White-coconut-chocolate, B...
#  2  {Sardines-in-brine, White-coconut-chocolate, F...
#  3  {Sardines-in-brine, White-coconut-chocolate, C...
#  4  {Sardines-in-brine, White-coconut-chocolate, M...
#  5  {Sardines-in-brine, Bread-rolls, Steak-kidney-...
#  6  {Bread-rolls, Farming products, Mineral-natura...
#  7  {Bread-rolls, Matzos, Farming products, Corian...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      47     0       169    Livingstone      Singosari
#  1      47     1       169      Singosari  Morphett Vale
#  2      47     2       169  Morphett Vale      Hoofddorp
#  3      47     3       169      Hoofddorp        Caracas
#  4      47     4       169        Caracas          Kawit
#  5      47     5       169          Kawit       Woodbury
#
#                                                 Items
#  0  {Steak-kidney-pie, Chips, Angel-hair, Fruit-cu...
#  1  {Steak-kidney-pie, Cocktail-sauces, Sweeteners...
#  2  {Steak-kidney-pie, Gluhwein, Orange-chocolate,...
#  3  {Steak-kidney-pie, Gluhwein, Semolina, Organic...
#  4  {Steak-kidney-pie, Gluhwein, Semolina, Fruit-c...
#  5  {Tarts, Cottage-cheeses, Semolina, Canned-peac...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      48     0       616            Morales  São Pedro da Cova
#  1      48     1       616  São Pedro da Cova            Polanco
#  2      48     2       616            Polanco          Haverhill
#
#                                                 Items
#  0  {Cafes-solubles, Natural-spring-water, Spice-r...
#  1  {Preparations-de-viande-surgelees, Dill-sauce,...
#  2  {Matzos, Spice-red-pepper, Dilute-drink, Sugar...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      49     0       204        Victoria           Álamo
#  1      49     1       204           Álamo       Rio Negro
#  2      49     2       204       Rio Negro  Albano Laziale
#  3      49     3       204  Albano Laziale       Mau Aimma
#
#                                                 Items
#  0  {Baking, Chutney, Redcurrant-tea, Radish, Tabb...
#  1  {Ale, Baking, Redcurrant-tea, Beetroot-juice, ...
#  2  {Baking, Beetroot-juice, Frozen-vegetable-mix,...
#  3  {Baking, Ciabatta, Redcurrant-tea, Remoulade, ...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      50     0       136    El Hadjar        Rubio
#  1      50     1       136        Rubio         Soma
#  2      50     2       136         Soma  Santa Lucía
#  3      50     3       136  Santa Lucía    Singosari
#  4      50     4       136    Singosari      Morales
#  5      50     5       136      Morales     Stamford
#
#                                                 Items
#  0  {Saucisses-aux-lentilles, Carbonated-soda-wate...
#  1  {Saucisses-aux-lentilles, Groenten, South-afri...
#  2  {Baking, Saucisses-aux-lentilles, Poivre-noir,...
#  3  {Indian-sauces, Saumon-atlantique, Pates-a-tar...
#  4  {Double-chocolate-milk, Saumon-atlantique, Dee...
#  5  {Natural-spring-water, Deep-fried, Sandwiches,...  ,
#    RouteId Order TruckCode StartCity    EndCity  \
#  0      51     0       882   Aquiraz     Kakata
#  1      51     1       882    Kakata  Haverhill
#
#                                                 Items
#  0  {Fruit-salad-in-juice, Kartoffelchips, Baguett...
#  1  {Kartoffelchips, Baguettes-de-pain, Confection...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      52     0         7                Maisí             Rochford
#  1      52     1         7             Rochford              Silifke
#  2      52     2         7              Silifke  Venustiano Carranza
#  3      52     3         7  Venustiano Carranza               La Paz
#  4      52     4         7               La Paz              Caracas
#
#                                                 Items
#  0  {Mackerel-fillets-in-sunflower-oil, Flavoured-...
#  1  {Jambons-blancs, Legumes-au-vinaigre, Flavoure...
#  2  {Jambons-blancs, Sweetelle-tomatoes, Flavoured...
#  3  {Jambons-blancs, Fruit-drinks, Sweetelle-tomat...
#  4  {Jambons-blancs, Sweetelle-tomatoes, Minced-ga...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      53     0       310        Barabai  Dar es Salaam
#  1      53     1       310  Dar es Salaam      Chandauli
#  2      53     2       310      Chandauli           León
#
#                                                 Items
#  0  {Angel-hair, Instant-mashed-potato, Frozen-dum...
#  1  {Salades-strasbourgeoises, Angel-hair, Cracker...
#  2  {Angel-hair, Frozen-vegetable-mix, Purple-spro...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      54     0       329   Perth Amboy       Luoyang
#  1      54     1       329       Luoyang        Kakata
#  2      54     2       329        Kakata  Hampton Park
#  3      54     3       329  Hampton Park      Victoria
#
#                                                 Items
#  0  {Natural-spring-water, Deshydrated-fruit, Inst...
#  1  {Natural-spring-water, Black-truffle-oil, Pear...
#  2  {Natural-spring-water, Beer-batter-fries, Blac...
#  3  {Blackcurrant-juice-syrup, Fruit-sticks, Natur...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      55     0       659    Orange  Muskogee
#  1      55     1       659  Muskogee     Rubio
#  2      55     2       659     Rubio  Tiassalé
#
#                                                 Items
#  0  {Whole-wheat-pita-bread, Amaretto, Frozen-chic...
#  1  {Plastic-surgery, Frozen-chicken, Indian-food,...
#  2  {Frozen-chicken, Plastic-surgery, South-africa...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      56     0       682       Yatağan  Hampton Park
#  1      56     1       682  Hampton Park     Hashimoto
#  2      56     2       682     Hashimoto         Álamo
#
#                                                 Items
#  0  {Hot-dog-mustard, Mackerel-fillets-in-sunflowe...
#  1  {Blackcurrant-juice-syrup, Mixed-nuts, Frozen-...
#  2  {Blackcurrant-juice-syrup, Mixed-nuts, Yaourt,...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      57     0       836        Hunchun      Chandauli
#  1      57     1       836      Chandauli  Dar es Salaam
#  2      57     2       836  Dar es Salaam       Muskogee
#  3      57     3       836       Muskogee     Port Louis
#  4      57     4       836     Port Louis       Marratxí
#
#                                                 Items
#  0  {White-coconut-chocolate, Products sold before...
#  1  {White-coconut-chocolate, Milkshake, Bottled-s...
#  2  {White-coconut-chocolate, Biere, Bottled-still...
#  3  {Milkshake, Chilli-con-carne-sauce, Instant-po...
#  4  {Chilli-con-carne-sauce, Instant-porridge, Chi...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      58     0       952  Woodbury   Álamo
#  1      58     1       952     Álamo  Lovisa
#
#                                                 Items
#  0  {Products sold before year 2000, Orange-chocol...
#  1  {Products sold before year 2000, Orange-chocol...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      59     0       610        Pitalito         Sheohar
#  1      59     1       610         Sheohar      Port Louis
#  2      59     2       610      Port Louis         Cormano
#  3      59     3       610         Cormano          Zouila
#  4      59     4       610          Zouila  Tarpon Springs
#  5      59     5       610  Tarpon Springs       Chandauli
#
#                                                 Items
#  0  {Produits-ssans-gluten, Lemon-mousse, Blueberr...
#  1  {Milk-chocolate-digestives, Peanut-in-chocolat...
#  2  {Milk-chocolate-digestives, Creme-caramel, Pea...
#  3  {Milk-chocolate-digestives, Produits-ssans-glu...
#  4  {Milk-chocolate-digestives, Produits-ssans-glu...
#  5  {Milk-chocolate-digestives, Fruit-juice-drink,...  ,
#    RouteId Order TruckCode StartCity             EndCity  \
#  0      60     0       454      León             Morales
#  1      60     1       454   Morales             Yichang
#  2      60     2       454   Yichang            Tiassalé
#  3      60     3       454  Tiassalé              Azazga
#  4      60     4       454    Azazga            Trindade
#  5      60     5       454  Trindade  Middleburg Heights
#
#                                                 Items
#  0  {Fresh-carrots, Coconut-flour, Cheese-puffs, G...
#  1  {Cheese-puffs, Sultanas, Fruit juices and nect...
#  2  {Scotch-eggs, Ground-cinnamon, Sultanas, Fresh...
#  3  {Fresh-carrots, Ground-cinnamon, Energy-ball, ...
#  4  {Pate, Piccalilli, Turkish-fermented-drink, Fr...
#  5  {Pate, Piccalilli, Hard-cooked-peeled-eggs, Fr...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      61     0       198          Kawit          Rubio
#  1      61     1       198          Rubio         Kibiti
#  2      61     2       198         Kibiti  Lomas del Sur
#  3      61     3       198  Lomas del Sur         Lovisa
#  4      61     4       198         Lovisa         Azazga
#
#                                                 Items
#  0  {Jus-d-orange, Lingonberry-jams, Hot-cross-bun...
#  1  {Unsalted-butter, South-african-merlot, Indian...
#  2  {Unsalted-butter, South-african-merlot, Mct-oi...
#  3  {Toppings, Fromage-au-lait-cru, Boissons-aux-f...
#  4  {Toppings, Fromage-au-lait-cru, Boissons-aux-f...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      62     0       875           Muskogee  São Pedro da Cova
#  1      62     1       875  São Pedro da Cova              Daura
#  2      62     2       875              Daura      Rocca di Papa
#  3      62     3       875      Rocca di Papa            Kelowna
#
#                                                 Items
#  0  {Preparations-de-viande-surgelees, Fresh-straw...
#  1  {Noix-de-paprika, Pains-d-epices, Chia-seeds, ...
#  2  {Baking, Noix-de-paprika, Cafe-moulu, Muffins,...
#  3  {Toppings, Noix-de-paprika, Sweeteners, Chilli...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      63     0       617             Luoyang             Sheohar
#  1      63     1       617             Sheohar           Rwamagana
#  2      63     2       617           Rwamagana          Tönisvorst
#  3      63     3       617          Tönisvorst       Grottaferrata
#  4      63     4       617       Grottaferrata  Middleburg Heights
#  5      63     5       617  Middleburg Heights             Yichang
#  6      63     6       617             Yichang            Chawinda
#  7      63     7       617            Chawinda           Rio Negro
#
#                                                 Items
#  0  {Swede, Orange-chocolate, Cured-ham, Black-tru...
#  1  {Mackerel-fillets-in-sunflower-oil, Bottled-st...
#  2  {Bottled-still-water, Kase, Cured-ham, Chillie...
#  3  {Bottled-still-water, Kase, Cured-ham, Gin, Ch...
#  4  {Jus-d-orange, Bottled-still-water, Kase, Gin,...
#  5  {Jus-d-orange, Bottled-still-water, Kase, Gin,...
#  6  {Jus-d-orange, Scotch-eggs, Gin, Chillies, Alm...
#  7  {Jus-d-orange, Crema-spalmabile, Whole-wheat-b...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      64     0       598     Yatağan   El Hadjar
#  1      64     1       598   El Hadjar     Caracas
#  2      64     2       598     Caracas     Barabai
#  3      64     3       598     Barabai  Port Louis
#  4      64     4       598  Port Louis    Stamford
#  5      64     5       598    Stamford    Kozyatyn
#
#                                                 Items
#  0  {Hot-dog-mustard, Mackerel-fillets-in-sunflowe...
#  1  {Hot-dog-mustard, Milkshake, Indian-sauces, Ma...
#  2  {Milkshake, Indian-sauces, Mackerel-fillets-in...
#  3  {Skim-milk, Milkshake, Fruit-spreads, Saucisse...
#  4  {Creme-caramel, Skim-milk, Fruit-spreads, Sauc...
#  5  {Creme-caramel, Saucisses-aux-lentilles, Artis...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      65     0        98    Orange  Guaiúba
#  1      65     1        98   Guaiúba   Lovisa
#  2      65     2        98    Lovisa  Pénjamo
#  3      65     3        98   Pénjamo  Hunchun
#
#                                                 Items
#  0  {Amaretto, Milchprodukt, Yellow-mustard, Syrup...
#  1  {Whole-wheat-pita-bread, Amaretto, Asian-condi...
#  2  {Amaretto, Asian-condiments, Vitamins, Brie-ch...
#  3  {Asian-condiments, Fresh-juices, Beef-jerky, I...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      66     0       355      Rio Negro        Hunchun
#  1      66     1       355        Hunchun       Stamford
#  2      66     2       355       Stamford        Pénjamo
#  3      66     3       355        Pénjamo  Lomas del Sur
#  4      66     4       355  Lomas del Sur        Mislata
#  5      66     5       355        Mislata           Fuyo
#  6      66     6       355           Fuyo       Victoria
#  7      66     7       355       Victoria        Silifke
#
#                                                 Items
#  0  {Olive-ciabatta, Scotch-eggs, South-african-me...
#  1  {White-coconut-chocolate, Fresh-prawns, South-...
#  2  {White-coconut-chocolate, Beverages, Fresh-pra...
#  3  {White-coconut-chocolate, Fresh-prawns, South-...
#  4  {White-coconut-chocolate, Fresh-prawns, Chia-s...
#  5  {White-coconut-chocolate, Asparagus-tips, Gin,...
#  6  {Asparagus-tips, White-coconut-chocolate, Gin,...
#  7  {Asparagus-tips, Matzos, Sugar-free-confection...  ,
#    RouteId Order TruckCode  StartCity        EndCity  \
#  0      67     0       523    Propriá      El Hadjar
#  1      67     1       523  El Hadjar         Lovisa
#  2      67     2       523     Lovisa  Morphett Vale
#
#                                                 Items
#  0  {Banana-chips, Tom-yum-soup, Pear-and-blackcur...
#  1  {Milkshake, Indian-sauces, Banana-chips, Pates...
#  2  {Milkshake, Banana-chips, Canned-lamb-tongue, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      68     0       968  Pennādam  Cormano
#  1      68     1       968   Cormano  Yichang
#
#                                                 Items
#  0  {Baby-spinach, Milkshake, Chicken-kievs, Froma...
#  1  {Baby-spinach, Milkshake, Chicken-kievs, Asian...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      69     0       546   Caracas  Vyborg
#  1      69     1       546    Vyborg    León
#
#                                                 Items
#  0  {Baking, Gelati, Chia-seeds, Whisky-ecossais, ...
#  1  {Baking, Fruit-confectionary, Olives-denoyaute...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      70     0       740              Cormano        Grottaferrata
#  1      70     1       740        Grottaferrata             Kozyatyn
#  2      70     2       740             Kozyatyn              Mislata
#  3      70     3       740              Mislata  Venustiano Carranza
#  4      70     4       740  Venustiano Carranza               Lovisa
#  5      70     5       740               Lovisa             Pitalito
#  6      70     6       740             Pitalito               Bariri
#  7      70     7       740               Bariri             Trindade
#
#                                                 Items
#  0  {Double-chocolate-milk, Produits-ssans-gluten,...
#  1  {Double-chocolate-milk, Produits-ssans-gluten,...
#  2  {Double-chocolate-milk, Pate, Produits-ssans-g...
#  3  {Double-chocolate-milk, Pate, Produits-ssans-g...
#  4  {Double-chocolate-milk, Pate, Fruit-drinks, Fr...
#  5  {Double-chocolate-milk, Fruit-drinks, Root-bee...
#  6  {Double-chocolate-milk, Fruit-drinks, Root-bee...
#  7  {Kauwgom, Fruit-drinks, Frozen-snacks, Cinamon...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      71     0       620    Atbasar     Zouila
#  1      71     1       620     Zouila   Acharnés
#  2      71     2       620   Acharnés  Neryungri
#  3      71     3       620  Neryungri   Pennādam
#  4      71     4       620   Pennādam   Rochford
#  5      71     5       620   Rochford  Rwamagana
#  6      71     6       620  Rwamagana  Mau Aimma
#  7      71     7       620  Mau Aimma       Desē
#
#                                                 Items
#  0  {Chesnut-mushrooms, Jambons-blancs, Ground-cin...
#  1  {Curry, Juice, Ground-cinnamon, Malt-vinegar, ...
#  2  {Curry, Chocolate-mints, Ground-cinnamon, Juic...
#  3  {Bread-rolls, Chocolate-mints, Curry, Ground-c...
#  4  {Chocolate-mints, Ground-cinnamon, Pannekoeken...
#  5  {Bread-rolls, Chocolate-mints, Ground-cinnamon...
#  6  {Bambusstreifen, Milkshake, Ground-cinnamon, F...
#  7  {Bambusstreifen, Bbq-relish, Kecap-manis, Hell...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      72     0       288            Rochford              Lovisa
#  1      72     1       288              Lovisa              Mwanza
#  2      72     2       288              Mwanza            Stamford
#  3      72     3       288            Stamford           Chandauli
#  4      72     4       288           Chandauli  Middleburg Heights
#  5      72     5       288  Middleburg Heights             Barabai
#  6      72     6       288             Barabai             Kelowna
#  7      72     7       288             Kelowna              La Paz
#
#                                                 Items
#  0  {Jambons-blancs, Tiefkuhlpizza, Fruit-cups, Di...
#  1  {Jambons-blancs, Tiefkuhlpizza, Diced-peaches-...
#  2  {Jambons-blancs, Maris-piper-potatoes, Dark-ch...
#  3  {Jambons-blancs, Beverages, Maris-piper-potato...
#  4  {Plato-preparado-precocinado, Seed-style-musta...
#  5  {Seed-style-mustard, Frozen-spring-rolls, Prof...
#  6  {Skegness-blue, Susswaren, Chinese-cinnamon-st...
#  7  {Sugar-cane-drink, Cannellini-beans, Confectio...  ,
# ...
#  3  {Unsalted-butter, Fresh-lemons, Fresh-strawber...
#  4  {Unsalted-butter, Seed-style-mustard, Fresh-le...
#  5  {Skegness-blue, Effervescent-vitamin, Fresh-st...
#  6  {Chips, Olives-denoyautees, Skegness-blue, Fre...
#  7  {Seitan-bio, Groceries, Chips, Couscous, Olive...  ,
#    RouteId Order TruckCode                StartCity           EndCity  \
#  0      75     0       191  Las Cabezas de San Juan             Aloha
#  1      75     1       191                    Aloha          Trindade
#  2      75     2       191                 Trindade  Sault Ste. Marie
#  3      75     3       191         Sault Ste. Marie          Chingola
#  4      75     4       191                 Chingola           Propriá
#  5      75     5       191                  Propriá          Muskogee
#
#                                                 Items
#  0  {Mackerel-fillets-in-sunflower-oil, Psyllium-h...
#  1  {Milk-chocolate-digestives, Fromage-au-lait-cr...
#  2  {Olive-ciabatta, Milk-chocolate-digestives, Fr...
#  3  {Pina-colada, Milk-chocolate-digestives, Olive...
#  4  {Pina-colada, Milk-chocolate-digestives, Spare...
#  5  {Pina-colada, Saumon-atlantique, Canned-lamb-t...  ,
#    RouteId Order TruckCode  StartCity     EndCity  \
#  0      76     0        48    Redmond   El Hadjar
#  1      76     1        48  El Hadjar     Kelowna
#  2      76     2        48    Kelowna  Port Louis
#
#                                                 Items
#  0  {Fruit-spreads, Minced-lamb, Absinth, Milk-cho...
#  1  {Spare-pork-ribs, Fruit-spreads, Pates-a-tarti...
#  2  {Sugar-cane-drink, Manuka-honey, Absinth, Butt...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      77     0       850     Daura  Hunchun
#  1      77     1       850   Hunchun   Dwārka
#
#                                                 Items
#  0  {Baking, Juice, Churned-cream, Chorizos, Garli...
#  1  {White-coconut-chocolate, Prepared-salads, Jui...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      78     0       295            Zhaodong            Woodbury
#  1      78     1       295            Woodbury  Brive-la-Gaillarde
#  2      78     2       295  Brive-la-Gaillarde            Tiassalé
#  3      78     3       295            Tiassalé          Vénissieux
#  4      78     4       295          Vénissieux             Yatağan
#  5      78     5       295             Yatağan             Pénjamo
#
#                                                 Items
#  0  {Peanut-butter-cup, Prepared-foods, Grattons, ...
#  1  {Peanut-butter-cup, Prepared-foods, Beef-mince...
#  2  {Iced-cookies, Crackers-sans-gluten, Chillies,...
#  3  {Iced-cookies, Asian-grocery, Crackers-sans-gl...
#  4  {Iced-cookies, Asian-grocery, Chillies, Mayona...
#  5  {Condiment-en-poudre, Milk-chocolate-filled-wi...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      79     0       190       Woodbury         Neston
#  1      79     1       190         Neston        Aquiraz
#  2      79     2       190        Aquiraz        Yichang
#  3      79     3       190        Yichang           León
#  4      79     4       190           León        Guaiúba
#  5      79     5       190        Guaiúba  McKinleyville
#  6      79     6       190  McKinleyville  Dar es Salaam
#
#                                                 Items
#  0  {Pitta-breads, Orange-chocolate, Levures, Milk...
#  1  {Roma-tomatoes, Pitta-breads, Trail-mix, Epice...
#  2  {Pralines, Roma-tomatoes, Pitta-breads, Mixed-...
#  3  {Ground-cinnamon, Baked-goods, Cactus, Fruit j...
#  4  {Pitta-breads, Mixed-nuts, Klebreiskuchen, Bak...
#  5  {Pitta-breads, Mixed-nuts, Klebreiskuchen, Cac...
#  6  {Pitta-breads, Beef-stroganoff, Hot-cross-buns...  ,
#    RouteId Order TruckCode  StartCity            EndCity  \
#  0      80     0       242  Chandauli           Rochford
#  1      80     1       242   Rochford            Mislata
#  2      80     2       242    Mislata           Chingola
#  3      80     3       242   Chingola            Sheohar
#  4      80     4       242    Sheohar               Ippy
#  5      80     5       242       Ippy            Silifke
#  6      80     6       242    Silifke  San Juan de Colón
#
#                                                 Items
#  0  {Beer-batter-fries, Fresh-lemons, Frozen-sprin...
#  1  {Beer-batter-fries, Coconut-juice, Fruit-cups,...
#  2  {Noix-de-paprika, Fruit-cups, Sandwich, Fresh-...
#  3  {Noix-de-paprika, Plato-preparado-precocinado,...
#  4  {Peanut-in-chocolate, Mackerel-fillets-in-sunf...
#  5  {Peanut-in-chocolate, Mackerel-fillets-in-sunf...
#  6  {Toppings, Mackerel-fillets-in-sunflower-oil, ...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      81     0       578          Neston        Marratxí
#  1      81     1       578        Marratxí  Albano Laziale
#  2      81     2       578  Albano Laziale         Kelowna
#
#                                                 Items
#  0  {Barbeque-sauce, Plats-prepares-surgeles, Grou...
#  1  {Piccolo-tomatoes, Barbeque-sauce, Chips, Trai...
#  2  {Trail-mix, Fresh-lamb-meat, Fruit-flavoured-d...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      82     0       797           Tiassalé  São Pedro da Cova
#  1      82     1       797  São Pedro da Cova           Victoria
#  2      82     2       797           Victoria            Caracas
#  3      82     3       797            Caracas     Albano Laziale
#  4      82     4       797     Albano Laziale  San Juan de Colón
#  5      82     5       797  San Juan de Colón            Aquiraz
#
#                                                 Items
#  0  {Hot-dog-mustard, Indian-sauces, Asian-grocery...
#  1  {Hot-dog-mustard, Asian-grocery, Noix-de-papri...
#  2  {Hot-dog-mustard, Hard-cooked-peeled-eggs, Ind...
#  3  {Hot-dog-mustard, Fruit-confectionary, Redcurr...
#  4  {Hot-dog-mustard, Baking, Levures, Redcurrant-...
#  5  {Fruit-confectionary, Levures, Thes-verts, Yog...  ,
#    RouteId Order TruckCode       StartCity   EndCity  \
#  0      83     0       317  Albano Laziale  Victoria
#  1      83     1       317        Victoria   Hunchun
#  2      83     2       317         Hunchun  Zirndorf
#  3      83     3       317        Zirndorf  Kozyatyn
#  4      83     4       317        Kozyatyn   Silifke
#  5      83     5       317         Silifke   Yichang
#
#                                                 Items
#  0  {Baking, Sandiwch, Cheese-puffs, Garlic-mashed...
#  1  {Toppings, Baking, Sandiwch, Levures, Redcurra...
#  2  {Toppings, Baking, Sandiwch, Matzos, Fat-free-...
#  3  {Toppings, Baking, Pates-a-tartiner-aux-noiset...
#  4  {Toppings, Baking, Pates-a-tartiner-aux-noiset...
#  5  {Toppings, Pates-a-tartiner-aux-noisettes-et-a...  ,
#    RouteId Order TruckCode   StartCity   EndCity  \
#  0      84     0       332  Tönisvorst     Álamo
#  1      84     1       332       Álamo  Acharnés
#
#                                                 Items
#  0  {Scotch-eggs, Gin, Preparations-de-viande-surg...
#  1  {Ale, Scotch-eggs, Redcurrant-tea, Preparation...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      85     0       120    Hunchun  Rwamagana
#  1      85     1       120  Rwamagana    Cormano
#
#                                                 Items
#  0  {Brussels-pate, Fizzy-drinks, Bieres-blondes, ...
#  1  {Dessert-lacte, Pet food, Fizzy-drinks, Mayona...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      86     0       218   Rwamagana  Willenhall
#  1      86     1       218  Willenhall    Chingola
#  2      86     2       218    Chingola    Rochford
#  3      86     3       218    Rochford     Aquiraz
#
#                                                 Items
#  0  {Prepared-salads, Sweeteners, Mature-blue-stil...
#  1  {Prepared-salads, Sweeteners, Mature-blue-stil...
#  2  {Spare-pork-ribs, Easter-buns, Mature-blue-sti...
#  3  {Spare-pork-ribs, Coconut-juice, Mature-blue-s...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      87     0       142           Ippy  McKinleyville
#  1      87     1       142  McKinleyville        Barabai
#
#                                                 Items
#  0  {Toppings, Baby-sanmarzano-tomatoes, Hot-fudge...
#  1  {Toppings, Coconut-cream, Cigarettes, Biscuits...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      88     0       301            Stamford       Dar es Salaam
#  1      88     1       301       Dar es Salaam           El Hadjar
#  2      88     2       301           El Hadjar  Brive-la-Gaillarde
#  3      88     3       301  Brive-la-Gaillarde             Caracas
#  4      88     4       301             Caracas             Mislata
#  5      88     5       301             Mislata    Sault Ste. Marie
#
#                                                 Items
#  0  {Beverages, Concombres, Biskuvi, White-plain-f...
#  1  {Biere, Concombres, Malt-vinegar, White-plain-...
#  2  {Biere, Concombres, Malt-vinegar, Frozen-dumpl...
#  3  {Biere, Concombres, Chillies, Malt-vinegar, Fr...
#  4  {Baking, Biere, Chillies, Frozen-dumpling, Boi...
#  5  {Pringles-potato-chips, Boissons, White-plain-...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      89     0        65             Chawinda            Rio Negro
#  1      89     1        65            Rio Negro  Venustiano Carranza
#  2      89     2        65  Venustiano Carranza             Tiassalé
#  3      89     3        65             Tiassalé         Korrewegwijk
#
#                                                 Items
#  0  {Coconut-juice, Lingonberry-jams, Corn-tortill...
#  1  {Asperges, Scotch-eggs, Lingonberry-jams, Skeg...
#  2  {Lingonberry-jams, Profiteroles, Dolminades, S...
#  3  {Indian-sauces, Asperges, Lingonberry-jams, Fr...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      90     0       499      Cormano     Merouana
#  1      90     1       499     Merouana  Perth Amboy
#  2      90     2       499  Perth Amboy      Kelowna
#
#                                                 Items
#  0  {Lasagne-sheets, Produits-ssans-gluten, Asian-...
#  1  {Fresh-coconut, Asian-grocery, Spices-seasonin...
#  2  {Asian-grocery, Spices-seasoning-mixes, Dry-me...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      91     0       570       Mislata        Kibiti
#  1      91     1       570        Kibiti        Zouila
#  2      91     2       570        Zouila       Luoyang
#  3      91     3       570       Luoyang      Kamloops
#  4      91     4       570      Kamloops      Muskogee
#  5      91     5       570      Muskogee        Neston
#  6      91     6       570        Neston  Puerto Aisén
#  7      91     7       570  Puerto Aisén      Pitalito
#
#                                                 Items
#  0  {Noix-de-paprika, Parve, Gin, Sandwich, Kaffir...
#  1  {Toppings, Sandwich, Kaffir-lime-leaves, Lime-...
#  2  {Juice, Minced-lamb, Malt-vinegar, Kaffir-lime...
#  3  {Juice, Malt-vinegar, Minced-lamb, Pear-cider,...
#  4  {Malt-vinegar, Cauliflower-cheese, Bhuja, Chin...
#  5  {Malt-vinegar, Fresh-strawberries, Cauliflower...
#  6  {Fruit-salad, Cauliflower-cheese, Porridge, Ge...
#  7  {Cauliflower-cheese, Banana-nut-loaf, Porridge...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      92     0        93        Rocca di Papa            Rio Negro
#  1      92     1        93            Rio Negro  Venustiano Carranza
#  2      92     2        93  Venustiano Carranza              Cormano
#  3      92     3        93              Cormano               Kakata
#  4      92     4        93               Kakata              Polanco
#  5      92     5        93              Polanco                 Soma
#  6      92     6        93                 Soma              Atbasar
#  7      92     7        93              Atbasar            Haverhill
#
#                                                 Items
#  0  {Milk-chocolate-filled-with-caramel, Pitta-bre...
#  1  {Olive-ciabatta, Frozen-asian-food, Scotch-egg...
#  2  {Olive-ciabatta, Frozen-asian-food, Gluhwein, ...
#  3  {Double-chocolate-milk, Asian-grocery, Frozen-...
#  4  {Double-chocolate-milk, Beer-batter-fries, Asi...
#  5  {Beer-batter-fries, Asian-grocery, Frozen-asia...
#  6  {Baking, Beer-batter-fries, Frozen-asian-food,...
#  7  {Jambons-blancs, Baking, Beer-batter-fries, Fr...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      93     0       310     Aquiraz       Daura
#  1      93     1       310       Daura  Port Louis
#  2      93     2       310  Port Louis     Kelowna
#  3      93     3       310     Kelowna        Fuyo
#
#                                                 Items
#  0  {Pralines, Curry, Mixed-nuts, Lime-marmalades,...
#  1  {Pralines, Churned-cream, Lime-marmalades, San...
#  2  {Creme-caramel, Baked-beans, Tortilla-chips, M...
#  3  {Tortilla-chips, Fresh-juices, Butter-chicken,...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      94     0       318      Silifke      Polanco
#  1      94     1       318      Polanco  Livingstone
#  2      94     2       318  Livingstone    El Hadjar
#  3      94     3       318    El Hadjar       Lovisa
#  4      94     4       318       Lovisa        Álamo
#  5      94     5       318        Álamo  Perth Amboy
#
#                                                 Items
#  0  {Chocolate-muffin, Sardines-in-brine, Marinara...
#  1  {Kaffee, Marinara-sauce, Deep-fried, Pear-and-...
#  2  {Marinara-sauce, Coleslaw-dressing, Low-fat-fr...
#  3  {Marinara-sauce, Crema-spalmabile, Sweeteners,...
#  4  {Marinara-sauce, Sweeteners, Crema-spalmabile,...
#  5  {Beetroot-juice, Coconut-milk-powder, Caramels...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      95     0       988  Victoria  Pennādam
#  1      95     1       988  Pennādam  Zirndorf
#
#                                                 Items
#  0  {Baking, Chutney, Redcurrant-tea, Turkey-burge...
#  1  {Baby-spinach, Baking, Strawberry-mousse, Chut...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      96     0       647   Propriá  Chawinda
#  1      96     1       647  Chawinda  Trindade
#  2      96     2       647  Trindade  Merouana
#
#                                                 Items
#  0  {Sardines-in-brine, Banana-chips, Non food pro...
#  1  {Sardines-in-brine, Banana-chips, Tom-yum-soup...
#  2  {Sardines-in-brine, Tom-yum-soup, Couscous, Pe...  ,
#    RouteId Order TruckCode     StartCity    EndCity  \
#  0      97     0       321  Hampton Park     Mwanza
#  1      97     1       321        Mwanza  Hashimoto
#  2      97     2       321     Hashimoto   Acharnés
#
#                                                 Items
#  0  {Blackcurrant-juice-syrup, Sundried-tomatoes, ...
#  1  {Cafes-solubles, Maris-piper-potatoes, Piccali...
#  2  {Cafes-solubles, Maris-piper-potatoes, Curry, ...  ,
#    RouteId Order TruckCode StartCity        EndCity  \
#  0      98     0       907    Dwārka        Yichang
#  1      98     1       907   Yichang  Morphett Vale
#
#                                                 Items
#  0  {Pralines, Turkey-bacon, Strawberry-mousse, Co...
#  1  {Aliment-pour-chevaux, Plastic-surgery, Butter...  ,
#    RouteId Order TruckCode  StartCity       EndCity  \
#  0      99     0       531      Kawit        Orange
#  1      99     1       531     Orange      Kozyatyn
#  2      99     2       531   Kozyatyn     Mau Aimma
#  3      99     3       531  Mau Aimma  Korrewegwijk
#
#                                                 Items
#  0  {Jus-d-orange, Lingonberry-jams, Hot-cross-bun...
#  1  {Amaretto, Jus-d-orange, Lingonberry-jams, Yel...
#  2  {Pate, Amaretto, Jus-d-orange, Cordials, Fajit...
#  3  {Fresh-chicken, Amaretto, Organic-and-premium-...  ]

# %%
all_trips = pd.concat(trips)

# %%
# Save the trips for the mining part
all_trips.to_csv("route_trips.csv")
