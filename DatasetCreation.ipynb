# %%
import pandas as pd
import numpy  as np
import time   # To calculate the execution time
import bisect # For the WeightedRandomGenerator
import random # For the generation of random numbers
from numpy.random import choice # For generation of ordered list based on weight
from collections import defaultdict  # For dictionary that memorize the cumulative probability of import/expor
import copy # For function deepcopy
import math # For function floor that convert float numbers in integers

# The dataset was created by using a food dataset and saved outside because the original dataset was huge (1GB).
product_list = pd.read_csv('categories.csv', 
                           delimiter = ',', 
                           encoding  = 'utf-8')

# I delete few strange strings
product_list = product_list.drop([123, 157, 440, 442])

final_product_list                     = pd.DataFrame(product_list['Name'])
final_product_list['Popularity']       = np.random.random_sample(len(final_product_list))

# Index reset due to problems with non-consecutive indexes
final_product_list.reset_index(drop    = True, 
                               inplace = True)

# %%
final_product_list["DerivativeFrom"] = np.empty((len(final_product_list), 0)).tolist()

# %%
# Set the maximum and minimum number of derivates that each product can have
def derivativeGeneration(products, end, start = 0, minDerivative = 0, maxDerivative = 2):
    global final_product_list
    rndSelection = random.sample(products, random.randint(minDerivative, maxDerivative))
    # Check with two consecutive loops which product derives from our sample and add them
    for i in range(0, 1):
        olderDerivative = [(products[i], final_product_list.loc[i, 'DerivativeFrom']) for i in range(start, end)
                           if products[i] in rndSelection]
        if olderDerivative:
            for derivative in olderDerivative:
                rndSelection.extend(derivative[1])
                rndSelection = list(set(rndSelection))
    return rndSelection

# %%
# Generate all the derivatives
derivatives = np.empty((len(final_product_list), 0)).tolist()
for i in range(0, len(final_product_list)):
    derivatives[i] = derivativeGeneration(list(product_list["Name"]), i)
    final_product_list['DerivativeFrom'] = derivatives

# %%
cities = pd.read_csv('world-cities.csv', 
                     delimiter = ',', 
                     encoding  = 'utf-8')

# Set the number of cities to 100
nCities = 100
cities  = cities.sample(nCities)

# Use of manual created list of Northern Italy cities

cities = pd.DataFrame({'name': ['Milano', 'Bergamo', "Brescia", "Verona", "Padova", "Treviso", "Venezia",
                                "Trento", "Bolzano", "Bologna", "Parma", "Mantova", "Rovigo", "Modena",
                                "Ravenna"]})


# Index reset due to problems with non-consecutive indexes
cities.reset_index(drop    = True, 
                   inplace = True)
city_list         = pd.DataFrame(cities.name)
city_list.columns = ['Name']

# %%
# Creation of a probability vector for each city based on popularity of products and random coefficient
# from 0 to 1
rand = [np.random.random_sample(len(final_product_list)) for i in range(0,len(city_list))]
popularity = final_product_list.Popularity
name = final_product_list.Name

priorityExp = [popularity * rand[i] for i in range(0,len(city_list))]
probabilityExport = [p / sum(p) for p in priorityExp]

# List of each product in order of probability and then insert it in the dataset his coefficient
productsOrderExp = [choice(name, len(final_product_list), p = prob, replace = False)
                 for prob in probabilityExport]
city_list["ImportanceExport"] = [[(l[i], (1 - i / len(l))) for i in range(0,len(l))] for l in productsOrderExp]

# Collect derivatives for each product
possibleDerivatives = [[(importance[1],
  final_product_list.loc[final_product_list.Name == importance[0], 'DerivativeFrom']) for importance in city]
                       for city in city_list.ImportanceExport]

coefficients =   [[(elements[0] * (final_product_list.loc[final_product_list.Name == el, 'Popularity']**2), el)
                 for elements in city
                 for elem in  elements[1]
                 for el in elem] 
                 for city in possibleDerivatives]
probabilityIncrease = []
for city in coefficients:
    prob = defaultdict(int)
    for value, key in city:
        prob[key] += value
    probabilityIncrease.append(prob)
priorityImp = [[probabilityIncrease[i][final_product_list.Name[n]] + (1 - rand[i][n]) for n in range(0,len(final_product_list))] for i in range(0,len(city_list))]
priorityImpCleaned = []
for p in priorityImp:
    tmp = []
    for val in p:
        tmp.append(float(val))
    priorityImpCleaned.append(tmp)
probabilityImport = [[val / sum(p) for val in p] for p in priorityImpCleaned]

productsOrderImp = [choice(name, len(final_product_list), p = prob, replace = False)
                 for prob in probabilityImport]
city_list["ImportanceImport"] = [[(l[i], (1 - i / len(l))) for i in range(0,len(l))] for l in productsOrderImp]

# %%
def standard_info(i, rid, tcd, trip, final_trip):
    final_trip.loc[i, 'RouteId']   = rid
    final_trip.loc[i, 'Order']     = i
    final_trip.loc[i, 'TruckCode'] = tcd
    final_trip.loc[i, 'StartCity'] = trip.loc[i    , 'IdCity']
    final_trip.loc[i, 'EndCity']   = trip.loc[i + 1, 'IdCity']

def first_step_creation(rid, tcd, length, trip):
    final_trip   = pd.DataFrame(columns = ['RouteId', 'Order', 'TruckCode', 'StartCity', 'EndCity', 'Items'])
    standard_info(0, rid, tcd, trip, final_trip)
    itemsToImport = [(item[0], item[1]*item2[1]) for item in trip.loc[length - 2, "ProductImportance"]
                                 for item2 in trip.loc[length - 2, "PopularImport"] if item[0] == item2[0]]
    tot = sum(i[1] for i in itemsToImport)
    itemList = [i[0] for i in itemsToImport]
    itemValues = [i[1]/tot for i in itemsToImport]
    # I set the range to be not fixed to 5-15 for the first trip cities that have few exportable items and I set
    # them to half to all the possible exportable items
    numItems = np.random.randint(5,15)
    exportedItems = choice(itemList, numItems, p = itemValues, replace = False)
    final_trip.loc[length - 2, 'Items'] = set(exportedItems)
    return final_trip
    
def trip_creation(i, rid, tcd, length, trip, final_trip):
    standard_info(i - 1, rid, tcd, trip, final_trip)
    crev            = length - i - 1
    exportPriority = city_list.loc[(list(city_list.Name).index(trip.loc[crev + 1, 'IdCity'])),
                                   'ImportanceExport']
    removeItems = [expPriority[0] for expPriority in exportPriority if random.random() < expPriority[1]]
    possibleExports = list(final_trip.loc[crev + 1, 'Items'])
    itemsToDelete   = set(possibleExports).intersection(removeItems)
    for item in itemsToDelete:
        possibleExports.remove(item)
    # Number of new exported items
    numItems = np.random.randint(3, 15)
    itemsToImport = [(item[0], item[1]*item2[1]) for item in trip.loc[length - 2, "ProductImportance"]
                                 for item2 in trip.loc[length - 2, "PopularImport"] if item[0] == item2[0]]
    tot = sum(i[1] for i in itemsToImport)
    itemList = [i[0] for i in itemsToImport]
    itemValues = [i[1]/tot for i in itemsToImport]
    exportedItems = choice(itemList, numItems, p = itemValues, replace = False)
    final_trip.loc[crev, 'Items'] = set(possibleExports).union(exportedItems)
    return final_trip

# %%
# Range of trip length setted at 3:10. We set the number of trucks to 1000
minLen   = 3
maxLen   = 10
numTruck = 50

def generate_trip(i):
    length = np.random.randint(minLen, maxLen)
    trip   = pd.DataFrame(columns = ['IdCity', 'ProductImportance', 'PopularImport'])
    Exports = defaultdict(int)
    Imports = defaultdict(int)
    cities = []
    cityInTrip = random.sample(list(range(0,len(city_list))), length)
    for c in range(0, length):
        city = cityInTrip[c]
        cities.append(city)
        trip.loc[c, 'IdCity'] = city_list.loc[city, 'Name']
        for cl in city_list.loc[city, 'ImportanceExport']:
            Exports[cl[0]] += cl[1]
        trip.loc[c, 'ProductImportance'] = [(item, Exports[item]) for item in Exports]
        trip.loc[c, 'PopularImport']   = city_list.loc[city, 'ImportanceImport']
    rid = i
    tcd = np.random.randint(0, numTruck)
    final_trip = first_step_creation(rid, tcd, length, trip)
    for c in range(2,length):
        final_trip = trip_creation(c, rid, tcd, length, trip, final_trip)
    final_trip = final_trip.sort_values('Order')
    return final_trip

# %%
# Generate n trips
def generate_trips(n):
    return [generate_trip(i) for i in range(0, n)]

# %%
numberOfRoutes = 150
routes         = generate_trips(numberOfRoutes)

# %%
routes
# Out:
# [  RouteId Order TruckCode StartCity  EndCity  \
#  0       0     0        14   Bologna   Padova
#  1       0     1        14    Padova  Brescia
#  2       0     2        14   Brescia  Bolzano
#  3       0     3        14   Bolzano   Rovigo
#  4       0     4        14    Rovigo  Ravenna
#  5       0     5        14   Ravenna   Milano
#
#                                                 Items
#  0  {Thin-mints, Mushroom-in-sunflower-oil, Hot-ch...
#  1  {Water-crackers, Gelati, Thin-mints, Formulate...
#  2  {Thin-mints, Fresh-strawberries, Gelati, Chris...
#  3  {Thin-mints, Angel-hair, Sugar-free-confection...
#  4  {Creme-chocolat, Sushis, Liquid-honey, Snack, ...
#  5  {Pale-ale, Hot-pepper-sauce, Cornichons-au-vin...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       1     0        30    Trento    Parma
#  1       1     1        30     Parma  Bolzano
#
#                                                 Items
#  0  {Water-crackers, Bruschetta, Canned-lamb-tongu...
#  1  {Mulled-wine-spice, Marinated olives, Chips, P...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       2     0         6   Bergamo  Bolzano
#  1       2     1         6   Bolzano   Padova
#  2       2     2         6    Padova   Milano
#  3       2     3         6    Milano  Brescia
#  4       2     4         6   Brescia  Bologna
#  5       2     5         6   Bologna  Mantova
#
#                                                 Items
#  0  {Rice-noodles, Brownie, Surgelati, Frozen-batt...
#  1  {Rice-noodles, Turkey-burgers, Cayenne-pepper-...
#  2  {Rice-noodles, Boissons, Beef-pie, Garlic-bagu...
#  3  {Rice-noodles, Beef-pie, Still-water, Olive-ci...
#  4  {Beef-pie, Pitta-breads, Cereales-pour-le-peti...
#  5  {Pitta-breads, Apple-juice-from-concentrate, B...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       3     0        49    Padova  Bologna
#  1       3     1        49   Bologna   Rovigo
#  2       3     2        49    Rovigo   Trento
#  3       3     3        49    Trento  Treviso
#  4       3     4        49   Treviso   Milano
#  5       3     5        49    Milano  Mantova
#
#                                                 Items
#  0  {Pina-colada, Quesos, Scones, Umbrichelli, Can...
#  1  {Pringles-potato-chips, Umbrichelli, Canned-pe...
#  2  {Dark-soy-sauce, Earl-grey, Sweetcorn, Canned-...
#  3  {Brown-onions, Gratins-de-legumes, Earl-grey, ...
#  4  {Tabbouleh, Cornish-pasties, Mackerel-fillets-...
#  5  {Dolminades, Chestnut-mushrooms, Canned foods,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       4     0        13   Bologna   Trento
#  1       4     1        13    Trento   Milano
#  2       4     2        13    Milano  Bolzano
#  3       4     3        13   Bolzano   Padova
#  4       4     4        13    Padova  Venezia
#  5       4     5        13   Venezia  Ravenna
#  6       4     6        13   Ravenna  Mantova
#
#                                                 Items
#  0  {Angel-hair, Bouillonterning, Vegan-chicken-nu...
#  1  {Mate, Bouillonterning, Pork-mince, Wasabi-hor...
#  2  {Mate, Tortilla, Fruit-spreads, Milk-chocolate...
#  3  {Frozen-asian-vegetables, Two-crust Pies, Coca...
#  4  {Turkey-burgers, Recipe-mixes, Egg-salad, Plai...
#  5  {Turkey-burgers, Recipe-mixes, Chicken-breast-...
#  6  {Turkey-burgers, Dried-spices, Sandwich, Estra...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       5     0        14    Modena  Ravenna
#  1       5     1        14   Ravenna   Rovigo
#  2       5     2        14    Rovigo    Parma
#  3       5     3        14     Parma   Milano
#
#                                                 Items
#  0  {Cordial, Chicken-meat, Tabouleh-salad, Deep-f...
#  1  {Schwarztees, Pork-mince, Turkish-fermented-dr...
#  2  {Peanut-butter-and-chocolat-chip-cereal-bar, H...
#  3  {Salads, Latticini, Fresh-apples, Drinking-cho...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       6     0        13   Bologna   Modena
#  1       6     1        13    Modena  Venezia
#  2       6     2        13   Venezia  Ravenna
#  3       6     3        13   Ravenna  Mantova
#  4       6     4        13   Mantova  Bergamo
#  5       6     5        13   Bergamo   Milano
#  6       6     6        13    Milano  Bolzano
#
#                                                 Items
#  0  {Berry-mueslis, Crossiants, Curry, Brandy-snap...
#  1  {Flavoured-milk-drink, Non food products, Cros...
#  2  {Kruidenpasta, Beef-burgers, Crossiants, Foies...
#  3  {Flavoured-milk-drink, Kruidenpasta, Porridge-...
#  4  {Kruidenpasta, Emu-jerky, Prepared-salads, Fru...
#  5  {Flavoured-milk-drink, Kruidenpasta, Emu-jerky...
#  6  {Biskuvi, Basa-fish, Emu-jerky, Glace-cherries...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       7     0        45   Ravenna   Trento
#  1       7     1        45    Trento   Verona
#  2       7     2        45    Verona  Mantova
#  3       7     3        45   Mantova   Rovigo
#  4       7     4        45    Rovigo  Brescia
#  5       7     5        45   Brescia  Bergamo
#
#                                                 Items
#  0  {White-plain-flour, Fresh-asparagus, Sambuca, ...
#  1  {Vinho-tinto, Sliced-jalapenos, Riz, Cikolata,...
#  2  {Green-salads, Aoli-sauce, Rice-candy, White-p...
#  3  {Boissons, Green-salads, Aoli-sauce, Hazelnut-...
#  4  {Piccalilli, Pringles-potato-chips, Dark-choco...
#  5  {Fruit-buns, Pringles-potato-chips, Carrot-cak...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       8     0        17    Verona   Rovigo
#  1       8     1        17    Rovigo  Bergamo
#
#                                                 Items
#  0  {Juice-drink, Coffee-ice-cream, Fresh-salads, ...
#  1  {Juice-drink, Sugarsnap-peas, Gum, Frozen-praw...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       9     0        26    Verona  Treviso
#  1       9     1        26   Treviso   Modena
#
#                                                 Items
#  0  {Wasabi-popcorn, Remoulade, Boissons, Milk-cho...
#  1  {Tortilla, Remoulade, Raspberries-in-syrup, Cr...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      10     0        21   Ravenna   Rovigo
#  1      10     1        21    Rovigo  Bergamo
#  2      10     2        21   Bergamo   Verona
#  3      10     3        21    Verona    Parma
#  4      10     4        21     Parma  Bologna
#
#                                                 Items
#  0  {Fruit-confectionary, Sweet-chilli-sauce, Boui...
#  1  {Fruit-confectionary, Fruit-drinks, Skegness-b...
#  2  {Pure-chocolate, Fruit-drinks, Juice, Peanut-b...
#  3  {Delizio-compatible-coffee-capsules, Italian-s...
#  4  {Chilisauce, Dark-soy-sauce, Fruit-buns, Sweet...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      11     0        24     Parma  Treviso
#  1      11     1        24   Treviso  Bologna
#  2      11     2        24   Bologna   Modena
#  3      11     3        24    Modena   Milano
#
#                                                 Items
#  0  {Whole-wheat-tortillas, Mixed-chillies, Smoked...
#  1  {Orange-juice-from-concentrate, Groenten, Brea...
#  2  {Groenten, Snack-mix, Semolina, Pastrami, Swee...
#  3  {Sliced-jalapenos, Concombres, Cake-mix, Doubl...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      12     0        31    Rovigo   Padova
#  1      12     1        31    Padova  Bologna
#
#                                                 Items
#  0  {Cranberry-juice-drink, Natural-yoghurts, Bay-...
#  1  {Steaks-haches-de-boeuf-frais, Coconut-macaroo...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      13     0        30    Verona    Parma
#  1      13     1        30     Parma   Padova
#  2      13     2        30    Padova  Treviso
#  3      13     3        30   Treviso  Bergamo
#  4      13     4        30   Bergamo  Brescia
#  5      13     5        30   Brescia  Venezia
#  6      13     6        30   Venezia  Bologna
#  7      13     7        30   Bologna  Mantova
#
#                                                 Items
#  0  {Purified-water, Custard-powder, Feuilletes-ch...
#  1  {Tintenfisch, Hawaiian-sweet-rolls, Fresh-sala...
#  2  {Pates, Biere, Fresh-salads, Spice-red-pepper,...
#  3  {Pates, Fruit juices and nectars, Biere, Grana...
#  4  {Blue-cheese-yogurt-dressing, Surgelati, Bottl...
#  5  {Kale, Flavoured-mineral-water-beverages, Micr...
#  6  {Icecream, Fruit juices and nectars, Baby-rock...
#  7  {Corn-kernels, Canneloni, Coffee-cake, Fruit j...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      14     0        41   Mantova  Venezia
#  1      14     1        41   Venezia    Parma
#
#                                                 Items
#  0  {Kidney-beans, Frozen-confectionary, Dried-par...
#  1  {Frozen-confectionary, Milk-chocolate-digestiv...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      15     0        34   Ravenna  Venezia
#  1      15     1        34   Venezia    Parma
#  2      15     2        34     Parma   Verona
#  3      15     3        34    Verona   Trento
#  4      15     4        34    Trento   Milano
#  5      15     5        34    Milano   Modena
#  6      15     6        34    Modena   Padova
#
#                                                 Items
#  0  {Cranberry-juice-drink, Canneloni, Slaty-snack...
#  1  {Asian-grocery, Pork-pie, Venison, Vegetarian-...
#  2  {Asian-grocery, Ravioles, Vegetarian-frozen-fo...
#  3  {Pork-crackling, Beans, Asian-grocery, Gravy, ...
#  4  {Gravy, Plaice, Golden-syrup, Dulces, Curd-che...
#  5  {Formulated-supplementary-food, Gravy, Roast-h...
#  6  {Pastry-dough, Roast-ham, Peach-drink, Thons-e...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      16     0        12    Padova  Bolzano
#  1      16     1        12   Bolzano  Mantova
#  2      16     2        12   Mantova  Bergamo
#  3      16     3        12   Bergamo   Verona
#  4      16     4        12    Verona    Parma
#
#                                                 Items
#  0  {South-african-merlot, Soupe, Splendid-artistr...
#  1  {South-african-merlot, Bouillonterning, Splend...
#  2  {Salads, Wasabi-horseradish, Sunflower-oil-spr...
#  3  {Wholemeal-bread, Lamb-breast, Cream-cheese-sp...
#  4  {Fruit-bread, Roast-ham, Hommus-dip, Curries, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      17     0        42    Milano  Mantova
#  1      17     1        42   Mantova  Venezia
#  2      17     2        42   Venezia    Parma
#  3      17     3        42     Parma  Bologna
#  4      17     4        42   Bologna  Brescia
#  5      17     5        42   Brescia  Ravenna
#
#                                                 Items
#  0  {Gnocchi, Federweisser, Confiture-biologique, ...
#  1  {Italian-sausages, Ale, Canned-peaches, Fruit-...
#  2  {Fruchtnektar, Ale, Topping, Freeze-dried food...
#  3  {Whole-wheat-pita-bread, Topping, Dr-pepper-so...
#  4  {Cooked-vegetables, Basa-fish, Rice-cakes, Sea...
#  5  {Pastilles-a-sucer, Mandarin-juice, Fruit-sala...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      18     0        29   Ravenna  Bolzano
#  1      18     1        29   Bolzano  Venezia
#  2      18     2        29   Venezia   Verona
#  3      18     3        29    Verona    Parma
#  4      18     4        29     Parma   Trento
#  5      18     5        29    Trento  Mantova
#  6      18     6        29   Mantova   Rovigo
#  7      18     7        29    Rovigo   Padova
#
#                                                 Items
#  0  {Chilisauce, Mackerel-fillets-in-sunflower-oil...
#  1  {Raisin-bread, Cayenne-pepper-sauce, Apricot-c...
#  2  {Raisin-bread, Thons-en-conserve, Natural-yogh...
#  3  {Raisin-bread, Kiwi-fruit, Coq-au-vin, Thons-e...
#  4  {Mixed-chillies, Raisin-bread, Basa-fish, Froz...
#  5  {Steaks-haches-de-boeuf-frais, Raisin-bread, B...
#  6  {Burger-relish, Earl-grey, Frozen-dumpling, Su...
#  7  {Mate, Italian-sausages, Frozen-dumpling, Plai...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      19     0        39   Bologna  Treviso
#  1      19     1        39   Treviso  Bergamo
#  2      19     2        39   Bergamo   Rovigo
#  3      19     3        39    Rovigo  Venezia
#  4      19     4        39   Venezia  Mantova
#  5      19     5        39   Mantova   Modena
#  6      19     6        39    Modena   Verona
#
#                                                 Items
#  0  {Aloe-vera-drink, Schwarztees, Marinara-sauce,...
#  1  {Artisan-bread-mix, Pork-chops, Aloe-vera-drin...
#  2  {Ale, Coffee-ice-cream, Baby-rocket, Tomkin-to...
#  3  {Milk substitute, Fruchtnektar, Ale, Coffee-ic...
#  4  {Steaks-haches-de-boeuf-frais, Berry-mueslis, ...
#  5  {Porc, Steaks-haches-de-boeuf-frais, Chocolats...
#  6  {Snacks, Biscottes, Chocolats, Fajitas, Dilute...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      20     0         0    Padova   Verona
#  1      20     1         0    Verona  Brescia
#  2      20     2         0   Brescia   Milano
#  3      20     3         0    Milano  Ravenna
#  4      20     4         0   Ravenna    Parma
#  5      20     5         0     Parma   Rovigo
#
#                                                 Items
#  0  {Frozen-dumpling, Rice-cake, Conserves, Energy...
#  1  {Cashews, Mackerel-fillets-in-sunflower-oil, R...
#  2  {Cashews, Conserves, Estragon, Jambons-blancs,...
#  3  {Pitted-prunes, Savoy-cabbage, Cashews, Macker...
#  4  {Cashews, Cured-sausage, Microwave-popcorn, Fr...
#  5  {Microwave-popcorn, Cured-sausage, Beetroot-ju...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      21     0        49    Rovigo  Mantova
#  1      21     1        49   Mantova    Parma
#  2      21     2        49     Parma   Trento
#  3      21     3        49    Trento  Ravenna
#  4      21     4        49   Ravenna   Milano
#  5      21     5        49    Milano  Treviso
#  6      21     6        49   Treviso   Verona
#
#                                                 Items
#  0  {Golden-syrup, Sliced-cheddar, Lager-beer, Cho...
#  1  {Prepackaged-lettuce, Yellow-peaches, Mature-b...
#  2  {Mix, Yellow-peaches, Crsips, Coconut-macaroon...
#  3  {Mousse-de-foie-de-porc, Mix, Fromage-au-lait-...
#  4  {Mate, Fresh-drinking-coconut, Dark-soy-sauce,...
#  5  {Mate, Pale-ale, Biscuits-chocolates, Ravioles...
#  6  {Mate, Biscuits-chocolates, Feuille-de-vigne, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      22     0        20    Rovigo  Ravenna
#  1      22     1        20   Ravenna   Verona
#  2      22     2        20    Verona  Venezia
#  3      22     3        20   Venezia  Mantova
#
#                                                 Items
#  0  {Kase, Legumes-prepares, Sundried-tomatoes, Ma...
#  1  {Flavoured-mineral-water-beverages, Burger-rel...
#  2  {Bruschetta, Flavoured-mineral-water-beverages...
#  3  {Flavoured-mineral-water-beverages, Ale, Soup-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      23     0        44   Mantova  Venezia
#  1      23     1        44   Venezia  Ravenna
#  2      23     2        44   Ravenna   Rovigo
#  3      23     3        44    Rovigo  Treviso
#  4      23     4        44   Treviso    Parma
#  5      23     5        44     Parma   Trento
#  6      23     6        44    Trento  Bolzano
#  7      23     7        44   Bolzano  Bergamo
#
#                                                 Items
#  0  {Citrus-punch, Salty snacks, Plain-tortilla-wr...
#  1  {Citrus-punch, Salty snacks, Bruschetta, Blueb...
#  2  {Fruit-confectionary, Blueberry-muffins, Plain...
#  3  {Graines, Fruit-confectionary, Whipping-cream,...
#  4  {Whipping-cream, Dried-spices, Wasabi-horserad...
#  5  {Pure-cod-liver-oil, Whipping-cream, Asian-con...
#  6  {Brawn, Umbrichelli, Saucisses-aux-lentilles, ...
#  7  {Boissons, Frozen-apple-pies, Chilli-con-carne...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      24     0        47   Venezia   Rovigo
#  1      24     1        47    Rovigo  Bolzano
#  2      24     2        47   Bolzano  Mantova
#
#                                                 Items
#  0  {Graines, Baked-goods, Mint-chocolate, Noix-de...
#  1  {Canned-precooked-meat, Graines, Gins, Baked-g...
#  2  {Gins, Baked-goods, White-plain-flour, Sauciss...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      25     0         5    Milano  Bergamo
#  1      25     1         5   Bergamo  Venezia
#  2      25     2         5   Venezia   Modena
#  3      25     3         5    Modena    Parma
#  4      25     4         5     Parma  Bologna
#  5      25     5         5   Bologna   Verona
#  6      25     6         5    Verona  Treviso
#  7      25     7         5   Treviso  Bolzano
#
#                                                 Items
#  0  {Whole-wheat-tortillas, Chicken-burgers, Cordi...
#  1  {Chicken-burgers, Gluhwein, Cordials, Wraps, M...
#  2  {Chicken-burgers, Chesnut-mushrooms, Wraps, Ga...
#  3  {Chicken-burgers, Chesnut-mushrooms, Wraps, Ga...
#  4  {Basa-fish, Chesnut-mushrooms, Potato-crips, C...
#  5  {Barritas, Basa-fish, Soup-mix, Musliriegel, V...
#  6  {Coconut-macaroons, Musliriegel, Wraps, Port, ...
#  7  {Framboises, Icecream, Wraps, Asian-food, Roma...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      26     0        23     Parma  Brescia
#  1      26     1        23   Brescia  Treviso
#  2      26     2        23   Treviso   Milano
#  3      26     3        23    Milano  Bolzano
#
#                                                 Items
#  0  {Pork-crackling, Salads, Pringles-potato-chips...
#  1  {Hot-cross-buns, Pates, Prepared-chicken, Tige...
#  2  {Frozen-apple-pies, Kiwi-fruit, Tigernuts, Cho...
#  3  {Canned-lamb-tongue, Pork-mince, Minced-garlic...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      27     0        23    Trento  Venezia
#  1      27     1        23   Venezia  Bologna
#  2      27     2        23   Bologna  Bergamo
#  3      27     3        23   Bergamo  Mantova
#  4      27     4        23   Mantova   Padova
#  5      27     5        23    Padova   Modena
#  6      27     6        23    Modena  Treviso
#  7      27     7        23   Treviso  Bolzano
#
#                                                 Items
#  0  {Chicken-burger, Fresh-cakes, Spring-roll-past...
#  1  {Tom-yum-soup, Chicken-burger, Christmas-food,...
#  2  {Fresh-juices, Coconut-creams, Chicken-burger,...
#  3  {Fresh-juices, Mix, Coconut-creams, Soup-mix, ...
#  4  {Fresh-juices, Kruidenpasta, Soup-mix, Hot-cho...
#  5  {Gravy, Kruidenpasta, Soup-mix, Hot-chocolate,...
#  6  {Medium-cheddar, Soup-mix, Saucisses-aux-lenti...
#  7  {White-peaches, Salty snacks, Microwave-popcor...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      28     0         5    Milano  Bolzano
#  1      28     1         5   Bolzano    Parma
#  2      28     2         5     Parma   Rovigo
#  3      28     3         5    Rovigo  Mantova
#
#                                                 Items
#  0  {Whole-wheat-tortillas, Beans, Frozen-confecti...
#  1  {Frozen-confectionary, Boeuf-bourguignon, Homm...
#  2  {Salted-peanuts, Remoulade, Pates-fraiches, Gr...
#  3  {Pates-fraiches, Frozen-snacks-aperitifs, Cook...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      29     0        31    Padova  Treviso
#  1      29     1        31   Treviso  Bergamo
#  2      29     2        31   Bergamo   Rovigo
#  3      29     3        31    Rovigo   Milano
#  4      29     4        31    Milano   Trento
#  5      29     5        31    Trento  Mantova
#  6      29     6        31   Mantova  Venezia
#
#                                                 Items
#  0  {Soupe, Breakfast-biscuits, Cheese-analogues, ...
#  1  {Soupe, Breakfast-biscuits, Cooked-vegetables,...
#  2  {Soupe, Breakfast-biscuits, Basa-fish, Cooked-...
#  3  {Prepared-chicken, Fresh-salads, Bay-leaves, D...
#  4  {Gelati, Breakfast-biscuits, Dried-pasta, Dilu...
#  5  {Frozen-prawn-cutlets, Dried-pasta, Dilute-dri...
#  6  {Cured-sausage, Breakfast-biscuits, Frozen-pra...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      30     0        36    Trento  Brescia
#  1      30     1        36   Brescia   Padova
#  2      30     2        36    Padova  Bologna
#  3      30     3        36   Bologna   Rovigo
#
#                                                 Items
#  0  {Milk-chocolate-filled-with-caramel, Strawberr...
#  1  {Baby-sanmarzano-tomatoes, Chilli-con-carne-sa...
#  2  {Beans, Burger-relish, Frozen-confectionary, P...
#  3  {Beans, Porridge-oats, Pitta-breads, Boxed-cho...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      31     0        27    Rovigo   Parma
#  1      31     1        27     Parma  Trento
#
#                                                 Items
#  0  {Sirloin-steak, Cordial, Prepared-salads, Comp...
#  1  {Salads, Fruit-juice-concentrate, Kartoffelchi...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      32     0        45     Parma  Bergamo
#  1      32     1        45   Bergamo  Mantova
#  2      32     2        45   Mantova  Ravenna
#  3      32     3        45   Ravenna   Rovigo
#  4      32     4        45    Rovigo  Bologna
#  5      32     5        45   Bologna   Padova
#  6      32     6        45    Padova  Brescia
#
#                                                 Items
#  0  {Mate, Basa-fish, Green-basil, Flavoured-rice-...
#  1  {Basa-fish, Green-basil, Flavoured-rice-cakes,...
#  2  {Crsips, Prune-juice, Framboises, Draje-sakız,...
#  3  {Corn-kernels, Coconut-creams, Whole-wheat-pen...
#  4  {Corn-kernels, Cured-sausage, Mct-oil, Cheese-...
#  5  {Seafood-salad, Gravy-mix, Saumon-atlantique, ...
#  6  {Delizio-compatible-coffee-capsules, Fruit-and...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      33     0        39   Bolzano   Milano
#  1      33     1        39    Milano    Parma
#  2      33     2        39     Parma  Bologna
#  3      33     3        39   Bologna   Trento
#  4      33     4        39    Trento  Treviso
#  5      33     5        39   Treviso  Bergamo
#  6      33     6        39   Bergamo  Brescia
#
#                                                 Items
#  0  {Chorizo, Foies-gras, Grana-padano, Frozen-ice...
#  1  {Milk-chocolate-filled-with-caramel, Frozen-re...
#  2  {Milk-chocolate-filled-with-caramel, Soup-mix,...
#  3  {Pasteurized-milk, Milk-chocolate-filled-with-...
#  4  {Coconut-water, Snacks, Coq-au-vin, Port, Caps...
#  5  {Coconut-water, Canned-precooked-meat, Basa-fi...
#  6  {Olives, Brick, Cactus, Cheese-singles, Chicke...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      34     0        27   Bologna  Brescia
#  1      34     1        27   Brescia  Bergamo
#  2      34     2        27   Bergamo   Padova
#  3      34     3        27    Padova   Milano
#
#                                                 Items
#  0  {Levures, Unsalted-butter, Freeze-dried foods,...
#  1  {Whole-wheat-tortillas, Rice-cakes, Unsalted-b...
#  2  {Concombres, Potato-crips, Amaretto, Rice-cake...
#  3  {Fruit-buns, Chestnut-mushrooms, Freeze-dried ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      35     0        10   Treviso    Parma
#  1      35     1        10     Parma  Brescia
#  2      35     2        10   Brescia   Modena
#  3      35     3        10    Modena  Venezia
#  4      35     4        10   Venezia   Trento
#  5      35     5        10    Trento  Ravenna
#
#                                                 Items
#  0  {Corn-kernels, Groceries, Legumes-prepares, Fr...
#  1  {Hot-cocoa-mix, Banana-flavour-mix-and-added-v...
#  2  {Hot-cocoa-mix, Fruchtnektar, Frozen-snacks, R...
#  3  {Cannellini-beans, Frozen-snacks, Pork-mince, ...
#  4  {Frozen-snacks, Beer-batter-fries, Pure-chocol...
#  5  {Dark-soy-sauce, Garlic-mashed-potatoes, Freez...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      36     0        31   Mantova   Milano
#  1      36     1        31    Milano   Trento
#  2      36     2        31    Trento  Bologna
#  3      36     3        31   Bologna  Bergamo
#  4      36     4        31   Bergamo  Bolzano
#  5      36     5        31   Bolzano   Padova
#  6      36     6        31    Padova   Rovigo
#  7      36     7        31    Rovigo  Ravenna
#
#                                                 Items
#  0  {Mate, Fruchtnektar, Thes-verts, Toppings, Sal...
#  1  {Fruchtnektar, Pates, Blueberry-muffins, Toppi...
#  2  {Fruchtnektar, Grattons, Fresh-garlic, Umbrich...
#  3  {Grattons, Garlic-mashed-potatoes, Prepared-fi...
#  4  {Corn-kernels, Flavoured-rice-cakes, Tortillas...
#  5  {Cherry-pie-filling, Quesos, Bouillonterning, ...
#  6  {Fruit-cups, Cherry-pie-filling, Almond-finger...
#  7  {Distilled-malt-vinegar, Sandwich, Sirop-de-fr...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      37     0        48   Mantova   Padova
#  1      37     1        48    Padova  Bolzano
#  2      37     2        48   Bolzano  Brescia
#
#                                                 Items
#  0  {Emu-jerky, Fromages, Sweet-chilli-sauce, Made...
#  1  {Pork-ham, Cured-sausage, Fromages, Juices, Br...
#  2  {Jus, Fromages, Sambuca, Chicken-kiev, Sweet-c...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      38     0         4   Mantova   Verona
#  1      38     1         4    Verona  Ravenna
#  2      38     2         4   Ravenna  Venezia
#  3      38     3         4   Venezia   Modena
#
#                                                 Items
#  0  {Fresh-juices, Rice-wine, Prune-juice, Reduced...
#  1  {Beans, Kits, Confitures-allegees, Chorizos, M...
#  2  {Fresh-juices, Poissons, Blueberry-muffins, Fr...
#  3  {Poissons, Bouillonterning, Frozen-prawn-cutle...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      39     0         9   Bergamo   Padova
#  1      39     1         9    Padova  Treviso
#
#                                                 Items
#  0  {Mackerel-fillets-in-sunflower-oil, Seed-mix, ...
#  1  {Biere, Pork-pie, Bieres-blondes, Vegetarische...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      40     0        12   Brescia  Bolzano
#  1      40     1        12   Bolzano  Treviso
#  2      40     2        12   Treviso  Venezia
#  3      40     3        12   Venezia   Rovigo
#  4      40     4        12    Rovigo   Modena
#  5      40     5        12    Modena   Milano
#
#                                                 Items
#  0  {Canned-oysters, Milk-chocolate-digestives, Ch...
#  1  {Green olives, Fresh-brown-onions, Coconut-wat...
#  2  {Green olives, Fresh-brown-onions, Corn-kernel...
#  3  {Beef-jerky, Medium-cheddar, Rice-cakes, Cerea...
#  4  {Medium-cheddar, Cereales-pour-le-petit-dejeun...
#  5  {Genio-tomatoes, Mineral-natural-water, Rice-c...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      41     0        16   Brescia   Rovigo
#  1      41     1        16    Rovigo   Verona
#  2      41     2        16    Verona   Padova
#  3      41     3        16    Padova  Ravenna
#  4      41     4        16   Ravenna  Venezia
#  5      41     5        16   Venezia  Bergamo
#
#                                                 Items
#  0  {Pumpkin-soup, Poissons, Chilli-con-carne-sauc...
#  1  {Pumpkin-soup, Draje-sakız, Dried-parmesan-che...
#  2  {Pumpkin-soup, Dried-parmesan-cheese, Multifru...
#  3  {Whole-wheat-penne-rigate, Frozen-confectionar...
#  4  {Pork-ham, Pasta-bake-sauces, Formulated-suppl...
#  5  {Pork-ham, Palm-sugar, Cacao-en-poudre, Citrou...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      42     0        38   Mantova  Bolzano
#  1      42     1        38   Bolzano  Treviso
#  2      42     2        38   Treviso  Venezia
#  3      42     3        38   Venezia   Padova
#  4      42     4        38    Padova  Bologna
#  5      42     5        38   Bologna   Trento
#  6      42     6        38    Trento   Rovigo
#  7      42     7        38    Rovigo  Bergamo
#
#                                                 Items
#  0  {Pina-colada, Citrouille-en-conserve, Plain-to...
#  1  {Juice-milk-drink, Golden-syrup, Plastic-surge...
#  2  {Frozen-confectionary, Juice-milk-drink, Turki...
#  3  {Chicken-burgers, Beef-burgers, Frozen-confect...
#  4  {Seafood-salad, Easter-egg, Bottled-still-wate...
#  5  {Tom-yum-soup, Peeled-plum-tomatoes, Malt-vine...
#  6  {Basa-fish, Malt-vinegar, Red-ale, Semoules-de...
#  7  {Popping-corn, Hot-cross-buns, Red-ale, Almond...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      43     0        28    Milano  Mantova
#  1      43     1        28   Mantova    Parma
#  2      43     2        28     Parma  Venezia
#  3      43     3        28   Venezia  Bologna
#  4      43     4        28   Bologna   Verona
#  5      43     5        28    Verona  Ravenna
#  6      43     6        28   Ravenna   Modena
#
#                                                 Items
#  0  {Cured-ham, Peach-juice-drink, Fruits-en-conse...
#  1  {Losenges, Fecules, Tabouleh-salad, Diced-peac...
#  2  {Blue-cheese-yogurt-dressing, Fecules, Diced-p...
#  3  {Turkey-burgers, Sourdough-bread, Frozen-ready...
#  4  {Frozen-readymeals, Cannellini-beans, Spam, Cr...
#  5  {Jaffa-cakes, Frozen-readymeals, Smoked-haddoc...
#  6  {Frozen-readymeals, Marinated olives, Frozen-b...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      44     0        46   Brescia    Parma
#  1      44     1        46     Parma  Bergamo
#  2      44     2        46   Bergamo   Trento
#  3      44     3        46    Trento   Milano
#
#                                                 Items
#  0  {Salads, Tiefkuhlpizza, Fromage-a-pate-dure, S...
#  1  {Savoy-cabbage, Brown-onions, Salads, Christma...
#  2  {Boissons-aux-fruits, Frozen-confectionary, Su...
#  3  {Apricot-conserve, Milk-chocolate-digestives, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      45     0        29   Bergamo  Bolzano
#  1      45     1        29   Bolzano  Treviso
#
#                                                 Items
#  0  {Canned-lamb-tongue, Frozen-readymeals, Apple-...
#  1  {Spare-pork-ribs, Baby-sanmarzano-tomatoes, Fr...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      46     0        25   Ravenna   Milano
#  1      46     1        25    Milano  Bergamo
#  2      46     2        25   Bergamo   Verona
#
#                                                 Items
#  0  {Feta-cheese, Berry-mueslis, Frozen-pork-buns,...
#  1  {Pasta-bake-sauces, Berry-mueslis, Frozen-swee...
#  2  {Pasta-bake-sauces, Preparations-de-viande-sur...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      47     0        24    Trento  Bergamo
#  1      47     1        24   Bergamo  Venezia
#  2      47     2        24   Venezia   Verona
#  3      47     3        24    Verona   Milano
#
#                                                 Items
#  0  {Baked-goods, Goat-cheese-log, Raw, Parve, Cre...
#  1  {Baked-goods, Blueberry-muffins, Saucisses-aux...
#  2  {Salty snacks, Goat-milk-cheese, Saucisses-aux...
#  3  {Pasta-bake-sauces, Iced-donuts, Saucisses-aux...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      48     0        30     Parma   Trento
#  1      48     1        30    Trento  Bologna
#  2      48     2        30   Bologna  Bergamo
#
#                                                 Items
#  0  {Baby-sanmarzano-tomatoes, Fresh-garlic, Crêpe...
#  1  {Linsen, Coffee-flavoured-milk, Quso-duro, Sch...
#  2  {Almond-fingers, Donuts, Chillies, Asian-food,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      49     0        26     Parma  Bologna
#  1      49     1        26   Bologna  Venezia
#  2      49     2        26   Venezia   Trento
#  3      49     3        26    Trento   Modena
#  4      49     4        26    Modena   Milano
#  5      49     5        26    Milano  Bolzano
#  6      49     6        26   Bolzano  Brescia
#  7      49     7        26   Brescia   Rovigo
#
#                                                 Items
#  0  {Graines, Emu-jerky, Canned-prawns, Avocadoes,...
#  1  {Groceries, Graines, Fruit juices, Juice-milk-...
#  2  {Groceries, Garlic-naan-breads, Breakfast-bisc...
#  3  {Groceries, Garlic-naan-breads, Breakfast-bisc...
#  4  {Pork-pie, Bakery, Wraps, Caramelized-red-onio...
#  5  {Breakfast-biscuits, Custard, Pork-pie, Bakery...
#  6  {Pates-fraiches, Horseradish-sauce, Pork-pie, ...
#  7  {Sliced-jalapenos, Prune-juice, Horseradish-sa...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      50     0        27    Rovigo  Bergamo
#  1      50     1        27   Bergamo    Parma
#  2      50     2        27     Parma  Treviso
#  3      50     3        27   Treviso  Bolzano
#  4      50     4        27   Bolzano  Mantova
#
#                                                 Items
#  0  {Angel-hair, Cardamom-pods, White-plain-flour,...
#  1  {Fruchtnektar, Hommus-dip, Fruit-and-nut-mix, ...
#  2  {Canned-lamb-tongue, Prepared-chicken, Umbrich...
#  3  {Farina, Milk-based-product, Beef-mince, Plant...
#  4  {Smoked-mussels, Slaty-snack, Concombres, Frui...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      51     0        14     Parma  Brescia
#  1      51     1        14   Brescia   Milano
#  2      51     2        14    Milano  Bologna
#  3      51     3        14   Bologna  Ravenna
#  4      51     4        14   Ravenna  Bergamo
#  5      51     5        14   Bergamo  Mantova
#  6      51     6        14   Mantova  Treviso
#
#                                                 Items
#  0  {Kidney-beans, Sugary snacks, Vegetarische-wor...
#  1  {Sugary snacks, Prepared-salads, Instant-dry-y...
#  2  {Chocolate-fudge, Strawberry-trifle, Iced-gree...
#  3  {Sandwich, Plastic-surgery, Sweetcorn-relish, ...
#  4  {Crossiants, Sweetcorn-relish, Venison-burger,...
#  5  {Premium-and-organic-pepper-from-cambodia, Gel...
#  6  {Non-alcoholic-soft-drink, Chilli-con-carne, R...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      52     0        34    Trento   Milano
#  1      52     1        34    Milano   Rovigo
#  2      52     2        34    Rovigo  Bergamo
#  3      52     3        34   Bergamo  Bolzano
#
#                                                 Items
#  0  {Nutella-biscuits, Apricot-conserve, Bay-leave...
#  1  {Bay-leaves, Fajitas, Penne, Butter-chicken, C...
#  2  {Coconut-water, South-african-merlot, Kase, Pe...
#  3  {Coconut-water, Popping-corn, South-african-me...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      53     0         6    Milano  Mantova
#  1      53     1         6   Mantova  Venezia
#  2      53     2         6   Venezia  Brescia
#  3      53     3         6   Brescia  Bologna
#
#                                                 Items
#  0  {Water-crackers, Horseradish-sauce, Frozen-dum...
#  1  {Shrimp-paste, Tuiles-salees, White-pitta-brea...
#  2  {Prepackaged-lettuce, Shrimp-paste, Tuiles-sal...
#  3  {Pickles, Cactus, Coconut-juice, Lamb-breast, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      54     0        35   Brescia  Bolzano
#  1      54     1        35   Bolzano  Venezia
#  2      54     2        35   Venezia   Rovigo
#  3      54     3        35    Rovigo  Bergamo
#  4      54     4        35   Bergamo   Padova
#  5      54     5        35    Padova  Ravenna
#  6      54     6        35   Ravenna   Modena
#
#                                                 Items
#  0  {Honey-roast-ham, Pecans, Beans, Boissons, Gla...
#  1  {Turkey-burgers, Beans, Drinking-chocolate, Po...
#  2  {Frozen-asian-food, Canned-beverages, Minced-b...
#  3  {Brownie, Easter-egg, Creme-caramel, Chicken-k...
#  4  {Icecream, Pork-pie, Non-dairy-soymilk, Easter...
#  5  {Filets-de-poulet, Fruit-bread, Cured-sausage,...
#  6  {Fruit-bread, Chorizo, Caramels-au-beurre-sale...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      55     0        18    Milano   Rovigo
#  1      55     1        18    Rovigo  Bologna
#  2      55     2        18   Bologna    Parma
#  3      55     3        18     Parma  Venezia
#  4      55     4        18   Venezia  Bergamo
#  5      55     5        18   Bergamo  Mantova
#  6      55     6        18   Mantova   Modena
#  7      55     7        18    Modena   Verona
#
#                                                 Items
#  0  {Bruschetta, Specialite-basque, Potato-crips, ...
#  1  {Specialite-basque, Viande, Epices, Hot-cocoa-...
#  2  {Beans, Ranja, Dried-sausages, Marinara-sauce,...
#  3  {Apple-and-pear-juices, Marinated olives, Chow...
#  4  {Kruidenpasta, Apple-and-pear-juices, Iced-don...
#  5  {Bruschetta, Yellow-peaches, Apple-and-pear-ju...
#  6  {Yellow-peaches, Black-truffle-oil, Bruschetta...
#  7  {Produits-laitiers, Apple-and-pear-juices, Jam...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      56     0        43   Bolzano   Trento
#  1      56     1        43    Trento  Ravenna
#  2      56     2        43   Ravenna   Modena
#  3      56     3        43    Modena  Bergamo
#  4      56     4        43   Bergamo    Parma
#  5      56     5        43     Parma  Venezia
#  6      56     6        43   Venezia  Mantova
#  7      56     7        43   Mantova   Rovigo
#
#                                                 Items
#  0  {Losenges, Golden-syrup, Bitters, Fresh-cream,...
#  1  {Losenges, Pumpkin-soup, Rice-cakes, Bitters, ...
#  2  {Losenges, Rice-cakes, Chicken-thighs-fillets,...
#  3  {Rice-cakes, Juice-milk-drink, Crevettes-roses...
#  4  {Groceries, Sultanas, Coffee-cake, Cooked-vege...
#  5  {Groceries, Coffee-cake, Chicken-burger, Tiefk...
#  6  {Bitters, Jambons-blancs, Baby-peas, Fresh-cuc...
#  7  {Tomato-ketchup, Tiefkuhlpizza, Cremes-fraiche...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      57     0         8   Mantova  Brescia
#  1      57     1         8   Brescia   Padova
#  2      57     2         8    Padova   Verona
#  3      57     3         8    Verona   Modena
#  4      57     4         8    Modena   Rovigo
#  5      57     5         8    Rovigo    Parma
#  6      57     6         8     Parma  Treviso
#  7      57     7         8   Treviso  Ravenna
#
#                                                 Items
#  0  {Vanilla-soymilk, Fromage-au-lait-cru, Cardamo...
#  1  {Vanilla-soymilk, Cardamom-pods, Green-salad-a...
#  2  {Vanilla-soymilk, Canned-peaches, Ricotta, Cof...
#  3  {Gelati, Vanilla-soymilk, Chutney, Biscuits-su...
#  4  {Vanilla-soymilk, Biscuits-sucres, Chutney, Ro...
#  5  {Boeuf-bourguignon, Syrups, Capsicums, Milk-ba...
#  6  {Boeuf-bourguignon, Estragon, Sucre, Milk-base...
#  7  {Rose-water, Beef-lasagne, Boeuf-bourguignon, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      58     0         7    Modena   Trento
#  1      58     1         7    Trento  Ravenna
#  2      58     2         7   Ravenna  Bergamo
#  3      58     3         7   Bergamo  Venezia
#  4      58     4         7   Venezia  Treviso
#  5      58     5         7   Treviso   Rovigo
#
#                                                 Items
#  0  {Meats, Muffins, Gravy, Chicken-burgers, Farin...
#  1  {Corn-kernels, Gravy, Chicken-burgers, Dr-pepp...
#  2  {Chicken-burgers, Crossiants, Cactus, Macaroni...
#  3  {Mackerel-fillets-in-sunflower-oil, Chicken-bu...
#  4  {Gluhwein, Dark-chocolate-block, Chinese-cinna...
#  5  {Cheddar-baguettes, Soymilk, Tortillas, Vanill...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      59     0         2   Bolzano  Bergamo
#  1      59     1         2   Bergamo    Parma
#  2      59     2         2     Parma   Rovigo
#
#                                                 Items
#  0  {Pitta-breads, Frozen-bread, Brownie, Food-cou...
#  1  {Prune-juice, Garlic-mashed-potatoes, Unsalted...
#  2  {Corn-kernels, Prune-juice, Juice-drink, Cerea...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      60     0         6   Bolzano  Ravenna
#  1      60     1         6   Ravenna   Trento
#  2      60     2         6    Trento  Bologna
#  3      60     3         6   Bologna  Treviso
#  4      60     4         6   Treviso  Venezia
#
#                                                 Items
#  0  {Fruit-juice-concentrate, Blueberry-muffins, T...
#  1  {Corn-kernels, Blueberry-muffins, Topping, Tui...
#  2  {Corn-kernels, Kruidenpasta, Grated-parmesan-c...
#  3  {Kruidenpasta, Tuiles-salees, Hidden-valley, M...
#  4  {Fresh-juices, South-african-merlot, Chocolate...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      61     0        25   Bergamo    Parma
#  1      61     1        25     Parma   Padova
#  2      61     2        25    Padova  Venezia
#  3      61     3        25   Venezia  Bolzano
#  4      61     4        25   Bolzano  Ravenna
#  5      61     5        25   Ravenna   Trento
#
#                                                 Items
#  0  {Minced-lamb, Glace-cherries, Pumpkin-seed-pec...
#  1  {Energy-balls, Coconut-milk-powder, Getrankewe...
#  2  {Corn-kernels, Fruit juices, Apple-blackcurran...
#  3  {Green olives, Chocolate-bunny, Fresh-carrots,...
#  4  {Green olives, Tom-yum-soup, Frozen-prawns, Ba...
#  5  {Tom-yum-soup, Pancake-mix, Sweetcorn, Baking,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      62     0        40   Brescia   Padova
#  1      62     1        40    Padova   Modena
#  2      62     2        40    Modena  Mantova
#
#                                                 Items
#  0  {Mozzarella-sticks, Multifruits, Guava-juice, ...
#  1  {Mixed-chillies, Multifruits, Guava-juice, Bla...
#  2  {Garlic-naan-breads, Nutella-biscuits, Fruit-b...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      63     0        31     Parma  Brescia
#  1      63     1        31   Brescia  Bergamo
#
#                                                 Items
#  0  {Wasabi-popcorn, Beef-pie, Frozen-dumpling, Bi...
#  1  {Beef-stroganoff, Fresh-bread, Grape-tomatoes,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      64     0        37   Bolzano    Parma
#  1      64     1        37     Parma  Bergamo
#  2      64     2        37   Bergamo  Ravenna
#  3      64     3        37   Ravenna  Brescia
#  4      64     4        37   Brescia   Milano
#  5      64     5        37    Milano  Treviso
#
#                                                 Items
#  0  {Pork-mince, Soup-mix, Fruits-secs, English-mu...
#  1  {Coconut-macaroons, Cauliflower-cheese, Cold-m...
#  2  {Medium-cheddar, Frozen-prawn-cutlets, Coconut...
#  3  {Medium-cheddar, Frozen-prawn-cutlets, Sandwic...
#  4  {Fruchtnektar, Meals, Persimmon, Conserves, Ca...
#  5  {Salty snacks, Fruit-bread, Fruchtnektar, Suga...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      65     0        32   Mantova   Verona
#  1      65     1        32    Verona  Bolzano
#  2      65     2        32   Bolzano  Bergamo
#  3      65     3        32   Bergamo   Trento
#  4      65     4        32    Trento  Treviso
#
#                                                 Items
#  0  {Losenges, Fruchtnektar, Tea-drinks, Frozen-co...
#  1  {Frozen-confectionary, Prepared-fish, Pork-pie...
#  2  {Coffee-cake, Tom-yum-soup, Shrimp-paste, Froz...
#  3  {Splendid-artistry-coffee, Boeuf-bourguignon, ...
#  4  {Corn-kernels, Snacks, Chutney, Fruit-juice-co...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      66     0         0    Modena  Mantova
#  1      66     1         0   Mantova  Bolzano
#  2      66     2         0   Bolzano   Milano
#  3      66     3         0    Milano  Bologna
#  4      66     4         0   Bologna  Venezia
#
#                                                 Items
#  0  {Steaks-haches-de-boeuf-frais, Fresh-corn, Riz...
#  1  {Corn-kernels, Asian-grocery, Fresh-corn, Ling...
#  2  {Barritas, Corn-kernels, Pumpkin-soup, Asian-g...
#  3  {Fresh-corn, Icecream, Prepared-fish, Pate-a-t...
#  4  {Formulated-supplementary-food, Fruit-buns, Ic...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      67     0        28   Ravenna  Treviso
#  1      67     1        28   Treviso   Rovigo
#
#                                                 Items
#  0  {Filets-de-poulet, Pork-ham, Raspberries-in-sy...
#  1  {Filets-de-poulet, Icecream, Green-salad-and-v...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      68     0        39    Padova   Verona
#  1      68     1        39    Verona    Parma
#  2      68     2        39     Parma  Brescia
#  3      68     3        39   Brescia   Trento
#  4      68     4        39    Trento  Treviso
#
#                                                 Items
#  0  {Dolminades, Salsa-chips, Frozen-ice-cream, Co...
#  1  {Dolminades, Frozen-ice-cream, Asian-cooking, ...
#  2  {Fudge, Minced-garlic, Frozen-ice-cream, Kale-...
#  3  {Fresh-juices, Breakfast-biscuits, Coconut-wat...
#  4  {Sun-dried-tomatoes, Biscuits-sucres, Chopped-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      69     0        47   Treviso  Bologna
#  1      69     1        47   Bologna   Verona
#  2      69     2        47    Verona  Bergamo
#  3      69     3        47   Bergamo  Venezia
#  4      69     4        47   Venezia  Ravenna
#  5      69     5        47   Ravenna  Mantova
#  6      69     6        47   Mantova   Trento
#  7      69     7        47    Trento    Parma
#
#                                                 Items
#  0  {Salty snacks, Cheese-crackers, Gnocchi, Multi...
#  1  {Cheese-crackers, Gnocchi, Bambusstreifen, Mul...
#  2  {Mint-jelly, Berry-mueslis, Draje-sakız, Chees...
#  3  {Paves-de-saumon, Draje-sakız, Chicken-kebabs,...
#  4  {Paves-de-saumon, Minced-garlic, Dilute-drink,...
#  5  {Kase, Soup-mix, Milk-chocolate-digestives, Ve...
#  6  {Biscuits-sucres, Pates, Pasteurized-milk, Sou...
#  7  {Frozen-asian-food, Creme-caramel, Samosas, So...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      70     0        20    Modena  Brescia
#  1      70     1        20   Brescia    Parma
#  2      70     2        20     Parma  Treviso
#  3      70     3        20   Treviso   Rovigo
#  4      70     4        20    Rovigo   Verona
#  5      70     5        20    Verona  Venezia
#
#                                                 Items
#  0  {Kruidenpasta, Pork-pie, Canned foods, Peanut-...
#  1  {Pastilles-a-sucer, Legumes-prepares, Beef-pie...
#  2  {Pastilles-a-sucer, Legumes-prepares, Gins, Su...
#  3  {Pastilles-a-sucer, Plain-tortilla-wraps, Spic...
#  4  {Pastilles-a-sucer, Microwave-popcorn, Bbq-rel...
#  5  {Psyllium-husk, Frozen-asian-foods, Tortillas,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      71     0        44   Bolzano   Padova
#  1      71     1        44    Padova   Rovigo
#  2      71     2        44    Rovigo   Trento
#  3      71     3        44    Trento  Bologna
#
#                                                 Items
#  0  {Canned-crab-meat, Cheese-analogues, Splendid-...
#  1  {Cranberry-juice-drink, Canned-crab-meat, Krui...
#  2  {Soupe, Milkshake, Scones, Hommus-dip, Musliri...
#  3  {Soupe, Icecream, Natural-spring-water, Hommus...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      72     0        49    Rovigo   Verona
#  1      72     1        49    Verona   Milano
#  2      72     2        49    Milano  Bolzano
#  3      72     3        49   Bolzano   Padova
#
#                                                 Items
#  0  {Water-crackers, Ribbon-noodles, Cooked-vegeta...
#  1  {Cooked-vegetables, Beef-burgers, Turkey-bacon...
#  2  {Turkey-bacon, Hommus-dip, Milk-chocolate-dige...
#  3  {Coffee-cake, Peanut-butter-cup, Chilli-con-ca...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      73     0        20     Parma   Padova
#  1      73     1        20    Padova  Treviso
#  2      73     2        20   Treviso   Rovigo
# ...
#  2     123     2         8    Modena   Rovigo
#  3     123     3         8    Rovigo  Ravenna
#  4     123     4         8   Ravenna  Treviso
#  5     123     5         8   Treviso  Mantova
#  6     123     6         8   Mantova  Bergamo
#
#                                                 Items
#  0  {Honey-roast-ham, Carbonated-soda-water, Bbq-r...
#  1  {Prepackaged-lettuce, Mousse-de-foie-de-porc, ...
#  2  {Mousse-de-foie-de-porc, Boissons, Lamb-fillet...
#  3  {Rice-crackers, Goats-butter, Ricotta, Confitu...
#  4  {Boissons, Fruit-and-nut-mix, Avocadoes, Galet...
#  5  {Thons-en-conserve, Galettes-de-polenta, Grati...
#  6  {Mixed-chillies, Aloe-vera-drink, Thons-en-con...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     124     0        40   Brescia  Bologna
#  1     124     1        40   Bologna   Padova
#  2     124     2        40    Padova   Rovigo
#  3     124     3        40    Rovigo  Bergamo
#  4     124     4        40   Bergamo    Parma
#
#                                                 Items
#  0  {Gelati, Raisin-bread, Whole-bean-sprouts-cann...
#  1  {Gateau, Sambuca, Fecules, Tortillas, Jelly-cr...
#  2  {Water-crackers, Fruit-flavored, Feta-cheese, ...
#  3  {Horseradish-sauce, Mulled-wine-spice, Gateau,...
#  4  {Kombucha, Canned-lamb-tongue, Horseradish-sau...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     125     0        31   Ravenna   Milano
#  1     125     1        31    Milano  Brescia
#  2     125     2        31   Brescia   Rovigo
#  3     125     3        31    Rovigo  Venezia
#  4     125     4        31   Venezia   Verona
#  5     125     5        31    Verona  Bergamo
#  6     125     6        31   Bergamo  Treviso
#  7     125     7        31   Treviso   Padova
#
#                                                 Items
#  0  {Corn-kernels, Whole-bean-sprouts-canned, Swee...
#  1  {Milk-chocolate-digestives, Tortillas, Articha...
#  2  {Meat-pies, Prepared-fish, Fruit-salad, Hot-ch...
#  3  {Meat-pies, Hawaiian-sweet-rolls, Icecream, Fr...
#  4  {Meat-pies, Black-truffle-oil, Icecream, Splen...
#  5  {Pork-crackling, Mackerel-fillets-in-sunflower...
#  6  {Milkshake, Natural-spring-water, Cereales, Ha...
#  7  {Red-ale, Prawn-cocktail, Bhakarwadi, Chicken-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     126     0         5    Rovigo  Bolzano
#  1     126     1         5   Bolzano  Bergamo
#
#                                                 Items
#  0  {Milk substitute, Beef-burgers, Prepared-salad...
#  1  {Flavoured-mineral-water-beverages, Amaretto, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     127     0        21   Bergamo  Treviso
#  1     127     1        21   Treviso   Milano
#
#                                                 Items
#  0  {Raspberries-in-syrup, Soupe, Chicken-meat, Su...
#  1  {Losenges, Tomato-ketchup, Sushki, Salad, Chic...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     128     0        33     Parma   Milano
#  1     128     1        33    Milano  Mantova
#  2     128     2        33   Mantova   Rovigo
#  3     128     3        33    Rovigo  Bergamo
#
#                                                 Items
#  0  {Whole-wheat-pita-bread, Christmas-food, All-s...
#  1  {Whole-wheat-pita-bread, Christmas-food, Froze...
#  2  {Pastry-dough, Gelati, Christmas-food, Fresh-c...
#  3  {Christmas-food, Pork-mince, Frozen-dumpling, ...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0     129     0        11   Venezia  Trento
#  1     129     1        11    Trento  Padova
#
#                                                 Items
#  0  {Frozen-potato-products, Brawn, Ale, Caramels-...
#  1  {Fruit juices and nectars, Ale, Reduced-fat-mi...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     130     0        39    Verona  Bolzano
#  1     130     1        39   Bolzano  Bologna
#  2     130     2        39   Bologna  Venezia
#  3     130     3        39   Venezia   Modena
#  4     130     4        39    Modena   Rovigo
#  5     130     5        39    Rovigo    Parma
#
#                                                 Items
#  0  {Sultanas, Boissons, Fresh-corn, Chilli-con-ca...
#  1  {Sultanas, Boissons, Fresh-corn, Poissons, Chi...
#  2  {Chicken-breast-fillets, Strawberries-canned, ...
#  3  {Orange-juice-from-concentrate, Crsips, Strawb...
#  4  {Milk-chocolate-filled-with-caramel, Strawberr...
#  5  {Milk-chocolate-filled-with-caramel, Milk-choc...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     131     0        49   Bologna  Brescia
#  1     131     1        49   Brescia   Rovigo
#  2     131     2        49    Rovigo  Bergamo
#
#                                                 Items
#  0  {Mais-a-popcorn, Cheese-crackers, Deshydrated-...
#  1  {Spare-pork-ribs, Soupe, Riz, Beetroot-juice, ...
#  2  {Soupe, Burger-relish, Malt-vinegar, Frozen-sn...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     132     0        26    Milano  Bergamo
#  1     132     1        26   Bergamo    Parma
#  2     132     2        26     Parma   Rovigo
#  3     132     3        26    Rovigo  Venezia
#  4     132     4        26   Venezia   Trento
#  5     132     5        26    Trento  Treviso
#
#                                                 Items
#  0  {Coleslaw-dressing, Dried-parmesan-cheese, Por...
#  1  {Gelati, Black-truffle-oil, Concombres, Gravy-...
#  2  {Pecans, Black-truffle-oil, Remoulade, Hot-coc...
#  3  {Remoulade, Hot-cocoa-mix, Gravy, Biscuits-au-...
#  4  {Meat-pies, Pasteurized-milk, Melonen, Prepare...
#  5  {Meat-pies, Lager-beer, Sucres, Boneless-pork-...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     133     0         1   Treviso  Bergamo
#  1     133     1         1   Bergamo   Milano
#  2     133     2         1    Milano   Trento
#  3     133     3         1    Trento  Bolzano
#  4     133     4         1   Bolzano   Verona
#
#                                                 Items
#  0  {Whole-wheat-pita-bread, Thin-mints, Fruit-bar...
#  1  {Pains-precuits, Vegetarische-worstjes, Chicke...
#  2  {Pains-precuits, Vegetarische-worstjes, Port, ...
#  3  {Galettes-de-polenta, Port, Olive-ciabatta, Fr...
#  4  {Dark-chocolate-block, Frozen-ice-cream, Spark...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     134     0        24    Trento  Bergamo
#  1     134     1        24   Bergamo   Rovigo
#  2     134     2        24    Rovigo  Brescia
#  3     134     3        24   Brescia  Mantova
#
#                                                 Items
#  0  {Conserves, Tarama, Corn-snacks, Baked-beans-w...
#  1  {Fresh-juices, Mackerel-fillets-in-sunflower-o...
#  2  {Fresh-juices, Salads, Bathroom, Fruit juices,...
#  3  {Fresh-juices, Salads, Indian, Frozen-asian-fo...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     135     0         9    Milano    Parma
#  1     135     1         9     Parma  Venezia
#  2     135     2         9   Venezia  Treviso
#  3     135     3         9   Treviso  Mantova
#
#                                                 Items
#  0  {Marinated olives, Fresh-chicken, Waffles, Jar...
#  1  {Tomato-ketchup, South-african-merlot, Splendi...
#  2  {Vleeswaren, Dark-soy-sauce, Berry-mueslis, Pa...
#  3  {Spare-pork-ribs, Fruit-buns, Mint-chocolate, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     136     0        31    Milano   Padova
#  1     136     1        31    Padova   Modena
#  2     136     2        31    Modena  Bologna
#  3     136     3        31   Bologna  Mantova
#  4     136     4        31   Mantova   Trento
#  5     136     5        31    Trento  Brescia
#  6     136     6        31   Brescia  Ravenna
#
#                                                 Items
#  0  {Milk-chocolate-filled-with-caramel, Prepared-...
#  1  {Fromage-au-lait-cru, Roast-ham, Aloe-vera-dri...
#  2  {Peanut-in-chocolate, Dilute-drink, Corn-snack...
#  3  {Produits-laitiers, Sweetcorn, Dilute-drink, J...
#  4  {Sushki, Natural-spring-water, Pork-pie, Mince...
#  5  {Pates-fraiches, Crsips, Sushki, Chopped-tomat...
#  6  {Black-truffle-oil, Roast-ham, Crsips, Chopped...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     137     0        27   Treviso   Verona
#  1     137     1        27    Verona   Trento
#  2     137     2        27    Trento  Bologna
#  3     137     3        27   Bologna   Rovigo
#  4     137     4        27    Rovigo   Padova
#  5     137     5        27    Padova  Ravenna
#
#                                                 Items
#  0  {Dill-sauce, Drinking-chocolate, Licensed prod...
#  1  {Italian-sausages, Bouillonterning, Frozen-dum...
#  2  {Bouillonterning, Icecream, Frozen-dumpling, I...
#  3  {Bouillonterning, Rice-cakes, Flavoured-rice-c...
#  4  {Crsips, Rice-cakes, Schwarztees, Frozen-pork-...
#  5  {Pork-pie, Instant-porridge, Fresh-cream, Yeas...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     138     0        43   Ravenna  Treviso
#  1     138     1        43   Treviso  Bolzano
#  2     138     2        43   Bolzano   Milano
#  3     138     3        43    Milano   Verona
#  4     138     4        43    Verona    Parma
#  5     138     5        43     Parma  Bergamo
#
#                                                 Items
#  0  {Pecans, Icecream, Indian-sauces, Jambons-blan...
#  1  {Fresh-brown-onions, Cornbreads, Slaty-snack, ...
#  2  {Blueberry-muffins, Chorizo, Apricot-conserve,...
#  3  {Chesnut-mushrooms, Hot-chocolate, Corn-thins,...
#  4  {Whole-wheat-tortillas, Tortilla, Soupe, Spice...
#  5  {Whole-wheat-tortillas, Tortilla, Kidney-beans...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     139     0         3    Padova  Mantova
#  1     139     1         3   Mantova    Parma
#  2     139     2         3     Parma  Brescia
#  3     139     3         3   Brescia  Bergamo
#
#                                                 Items
#  0  {Brown-onions, Formulated-supplementary-food, ...
#  1  {Feuille-de-vigne, Barbeque-sauce, Frozen-asia...
#  2  {Asian-grocery, Minced-garlic, Natural-yoghurt...
#  3  {Minced-garlic, White-quinoa, Pain-pita-sucres...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     140     0         7     Parma  Brescia
#  1     140     1         7   Brescia  Bergamo
#  2     140     2         7   Bergamo  Bologna
#  3     140     3         7   Bologna   Verona
#  4     140     4         7    Verona   Trento
#  5     140     5         7    Trento  Ravenna
#
#                                                 Items
#  0  {Chicken-breast-fillets, Gravy, Mais-a-popcorn...
#  1  {Marfona-variety, Pesce-curado, Pates-fraiches...
#  2  {Pates-fraiches, Smoked-mussels, Gravy, Toppin...
#  3  {Gins, Pates-fraiches, Smoked-mussels, Frozen-...
#  4  {Frozen-dumpling, Sliced-cheddar, Grana-padano...
#  5  {Saucissons, Frozen-dumpling, Chocolate-with-r...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     141     0        19   Bologna  Venezia
#  1     141     1        19   Venezia  Bergamo
#
#                                                 Items
#  0  {Milchprodukt, Distilled-malt-vinegar, Special...
#  1  {Feta-cheese, Hot-chocolate, Biscotti, Goats-b...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     142     0         1     Parma   Rovigo
#  1     142     1         1    Rovigo  Bergamo
#  2     142     2         1   Bergamo  Mantova
#  3     142     3         1   Mantova   Modena
#  4     142     4         1    Modena  Bologna
#  5     142     5         1   Bologna  Brescia
#
#                                                 Items
#  0  {Green olives, Chicken-tikka-masala, Minced-la...
#  1  {Green olives, Bread-rolls, Iced-donuts, Mais-...
#  2  {Green olives, Gins, Gratins-de-legumes, Lamb-...
#  3  {Gins, Pitta-breads, Iced-donuts, Sundried-tom...
#  4  {Bread-rolls, Gins, Pitta-breads, Toppings, Fr...
#  5  {Groceries, Pitta-breads, Toppings, Cake-mix, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     143     0        41   Treviso   Modena
#  1     143     1        41    Modena  Mantova
#  2     143     2        41   Mantova   Milano
#  3     143     3        41    Milano  Venezia
#  4     143     4        41   Venezia   Rovigo
#  5     143     5        41    Rovigo   Padova
#  6     143     6        41    Padova   Trento
#
#                                                 Items
#  0  {Natural-yoghurts, Sucre, Root-beer, Lime-marm...
#  1  {Prepackaged-lettuce, Black-truffle-oil, Baby-...
#  2  {Gravy, Whole-wheat-beard, Grated-parmesan-che...
#  3  {Fruit-cups, Grated-parmesan-cheese, Pork-pie,...
#  4  {Snacks, Coconut-lime-icecream, Soupe, Peels, ...
#  5  {Mate, Framboises, Grated-parmesan-cheese, Mar...
#  6  {Fruit-cups, Fruchtnektar, Seafood-salad, Fish...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     144     0        22    Padova   Modena
#  1     144     1        22    Modena  Ravenna
#
#                                                 Items
#  0  {Green-salad-and-vegetables, Confitures-allege...
#  1  {Specialite-basque, Tiefkuhlpizza, Asian-condi...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     145     0        25    Trento   Rovigo
#  1     145     1        25    Rovigo  Bolzano
#  2     145     2        25   Bolzano  Bergamo
#
#                                                 Items
#  0  {Coconut-creams, Steaks-haches-de-boeuf-frais,...
#  1  {Steaks-haches-de-boeuf-frais, Biscuits-sucres...
#  2  {Steaks-haches-de-boeuf-frais, Fresh-coconut, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     146     0        23    Padova  Venezia
#  1     146     1        23   Venezia  Treviso
#  2     146     2        23   Treviso   Trento
#
#                                                 Items
#  0  {Crêpes and galettes, Penne-rigate, Diced-peac...
#  1  {Milk substitute, Chicken-burger, Sushki, Drie...
#  2  {Sunflower-spread, Milk substitute, Chicken-bu...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     147     0        38    Trento   Milano
#  1     147     1        38    Milano  Brescia
#  2     147     2        38   Brescia   Modena
#  3     147     3        38    Modena  Bolzano
#  4     147     4        38   Bolzano  Bologna
#  5     147     5        38   Bologna  Bergamo
#  6     147     6        38   Bergamo   Verona
#  7     147     7        38    Verona  Mantova
#
#                                                 Items
#  0  {Porc, Cooking-chocolate, Kase, Goat-milk-chee...
#  1  {Kase, Pasteurized-milk, Goat-milk-cheese, Pro...
#  2  {Golden-syrup, Rice-cake, Caffe, Manuka-honey,...
#  3  {Tomato-chilli-relish, Chocolate-trifle, Micro...
#  4  {Chocolate-trifle, Noix-de-paprika, Wasabi-hor...
#  5  {Savoy-cabbage, Noix-de-paprika, Kecap-manis, ...
#  6  {Noix-de-paprika, Biscottes, Mais-a-popcorn, P...
#  7  {Reduced-fat-milks, Fruit-drinks, Sandwiches, ...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     148     0        32    Modena  Bologna
#  1     148     1        32   Bologna  Ravenna
#  2     148     2        32   Ravenna   Milano
#  3     148     3        32    Milano   Rovigo
#
#                                                 Items
#  0  {Dessert-mixes, Piccalilli, Prawn-cocktail, Fr...
#  1  {Gins, Feta-cheese, Draje-sakız, Piccalilli, P...
#  2  {Olive-ciabatta, Frozen-ice-cream, Gins, Corni...
#  3  {Gins, Indian, Frozen-dumpling, Cappuccino-swi...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     149     0        17    Padova   Trento
#  1     149     1        17    Trento  Bologna
#  2     149     2        17   Bologna   Milano
#  3     149     3        17    Milano  Treviso
#
#                                                 Items
#  0  {Salads, Cinnamon-raisin-bagels, Cous-cous, Ba...
#  1  {Salads, Muffin-mix, Cancoillottes, Cinnamon-r...
#  2  {Citrus-punch, Salads, Milk-chocolate-filled-w...
#  3  {Salads, Chilli-con-carne-sauce, Cous-cous, Ba...  ]

# %%
all_trips = pd.concat(routes)

# %%
# Save the trips for the mining part
all_trips.to_csv("route_trips.csv")
