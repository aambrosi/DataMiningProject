# %%
import pandas as pd
import numpy as np

# The dataset was created by using a food dataset and saved outside because the original dataset was huge (1GB).

product_list=pd.read_csv('categories.csv',delimiter=',',encoding='utf-8')
# I delete few strange strings
product_list = product_list.drop([123,157,440,442])

# %%
final_product_list = pd.DataFrame(product_list['Name'])
final_product_list['Popularity'] = np.random.random_sample(len(final_product_list))
final_product_list.reset_index(drop=True, inplace = True)
# Out:
# 1276

# %%
cities = pd.read_csv('world-cities.csv',delimiter=',',encoding='utf-8')

# %%
# Set the number of cities to 100
nCities = 100
cities = cities.sample(nCities)
cities.reset_index(drop=True, inplace = True)

# %%
city_list = pd.DataFrame(cities.name)
city_list.columns = ['Name']

# %%
city_list
# Out:
#                 Name
# 0             Timaru
# 1            Abū Tīj
# 2              Kogon
# 3          Goyerkāta
# 4          Millville
# 5             Kloten
# 6             Jetpur
# 7           Taşköprü
# 8              Warri
# 9            Kushtia
# 10  Krasnoperekops’k
# 11          Koksijde
# 12  Hódmezővásárhely
# 13           Bilhaur
# 14           Sadalgi
# 15          Winnipeg
# 16            Partūr
# 17         Fundación
# 18            Annino
# 19         Şanlıurfa
# 20             Khāpa
# 21         Ushirombo
# 22              Same
# 23           Needham
# 24             Mosta
# 25        Lakshmīpur
# 26     Chililabombwe
# 27            Panaji
# 28           Dixiana
# 29           Ifakara
# ..               ...
# 70             Belek
# 71           Nalhāti
# 72      Râs el Aïoun
# 73             Kunri
# 74           Horodok
# 75        Koprivnica
# 76      Rājgurunagar
# 77          Hajnówka
# 78       Romainville
# 79              Aksu
# 80      Ketanggungan
# 81             Kaédi
# 82            Kitami
# 83            Putian
# 84         Laungowāl
# 85             Tampa
# 86             Düzce
# 87     Pantai Cenang
# 88         Hitoyoshi
# 89           Lushnjë
# 90     Fontainebleau
# 91      Bukit Rambai
# 92           Sedrata
# 93            Hirara
# 94       Wernigerode
# 95             Mūlki
# 96        Manacapuru
# 97            Hotaka
# 98        Novouzensk
# 99          Cibinong
#
# [100 rows x 1 columns]

# %%
#city_list["Export"] = ""
#city_list["Import"] = ""

# %%
# range of exported and imported for each city setted respectively at 3:20 and 10:50
minExp = 5
maxExp = 40
minImp = 20
maxImp = 100
import time
# THIS PART CAN BE RUN IN PARALLEL (SPARK)
#start = time.time()
#for c in range(0,len(city_list)):
#    num_exp = np.random.randint(minExp,maxExp)
#    num_imp = np.random.randint(minImp,maxImp)
#    exp = np.unique(final_product_list.sample(num_exp, weights=final_product_list.Popularity).Name)
#    possible_imp_products = final_product_list[~final_product_list['Name'].isin(exp)]
#    imp = np.unique(possible_imp_products.sample(num_imp, weights=possible_imp_products.Popularity).Name)
#    city_list.loc[c,'Export'] = exp
#    city_list.loc[c,'Import'] = imp
#print(time.time()-start)

# %%
import bisect
class WeightedRandomGenerator(object):
    def __init__(self, weights):
        self.totals = []
        running_total = 0

        for w in weights:
            running_total += w
            self.totals.append(running_total)

    def next(self):
        rnd = random.random() * self.totals[-1]
        return bisect.bisect_right(self.totals, rnd)

    def __call__(self):
        return self.next()
    
def importExportGenerator():
    num_exp = np.random.randint(minExp,maxExp)
    num_imp = np.random.randint(minImp,maxImp)
    v = {}
    exp = []
    for ne in range(0, num_exp):
        rg = randomGenerator()
        rg = int(rg)
        rg = final_product_list.Name[rg]
        if(rg not in exp):
            exp.append(rg)
        else:
            ne -= 1
    imp = []
    for ni in range(0, num_imp):
        rg = randomGenerator()
        rg = int(rg)
        rg = final_product_list.Name[rg]
        if((rg not in imp) & (rg not in exp)):
            imp.append(rg)
        else:
            ni -= 1
    v['exp'] = exp
    v['imp'] = imp
    return v
    
start = time.time()
randomGenerator = WeightedRandomGenerator(final_product_list.Popularity)
values = [importExportGenerator() for i in range(0,len(city_list))]
a = [(value['exp'],value['imp']) for value in values]
exp = []
imp = []
for i in range(0,len(a)):
    exp.append(a[i][0])
    imp.append(a[i][1])
city_list['Export'] = exp
city_list['Import'] = imp
print(time.time()-start)
# Out:
# 0.14937329292297363

# %%
city_list
# Out:
#                 Name                                             Export  \
# 0             Timaru  [Baking, Kakaopulver, Minced-lamb, Taco-shells...
# 1            Abū Tīj  [Complements-alimentaires, Garlic-and-coriande...
# 2              Kogon  [Bhakarwadi, Caramel-popcorn, Palm-sugar, Suga...
# 3          Goyerkāta  [Sweetcorn-and-peas, Frozen-ice-creams, Chocol...
# 4          Millville  [Lasagnes-preparees, Juice-milk-drink, Peach-j...
# 5             Kloten  [Chicken-breast-fillets, Roma-tomatoes, Sweet-...
# 6             Jetpur  [Sugar-free-confectionary, Kakaopulver, Aoli-s...
# 7           Taşköprü  [Edible-decorations, Soup-mixes, Grape-juice-d...
# 8              Warri  [Agua, Mix, Peanut-in-chocolate, Multivitamin-...
# 9            Kushtia  [Mix, Rice-noodles, Frozen foods, Fresh-strawb...
# 10  Krasnoperekops’k  [Ricotta, Marfona-variety, Unsalted-butter, Ca...
# 11          Koksijde  [Plats-prepares-surgeles, Asian-food, Pralines...
# 12  Hódmezővásárhely  [Brick, Porc, Fromages, Chow-mein, Blueberry-m...
# 13           Bilhaur  [Foies-gras, Rice-cake, Kauwgom, Fresh foods, ...
# 14           Sadalgi  [Aliment-pour-chevaux, Cheese-crackers, Mozzar...
# 15          Winnipeg  [Octopus-balls, Chicken-pies, Genio-tomatoes, ...
# 16            Partūr  [Brick, Pumpkin-seed-pecan, Powder, Bruschetta...
# 17         Fundación  [Fresh-bread, Gluhwein, Viande, Liquid-honey, ...
# 18            Annino  [Topping, Caviars, Melange-d-epices-pour-guaca...
# 19         Şanlıurfa  [Glaces, Getrankeweisser, Peach-drink, Octopus...
# 20             Khāpa  [Linsen, Maris-piper-potatoes, Pitta-breads, M...
# 21         Ushirombo  [Frozen-petits-pois, Breakfast-biscuits, Produ...
# 22              Same  [Biscuits-au-chocolat-noir, Peaches-sliced-in-...
# 23           Needham  [Umbrichelli, Fresh-bread, Chicken-kebabs, Riz...
# 24             Mosta  [Whole-wheat-pita-bread, Penne, Capsicums, Fro...
# 25        Lakshmīpur  [Coconut-water, Frozen-sweetcorn, Cream-horser...
# 26     Chililabombwe  [Melange-d-epices-pour-guacamole, Muffin-mix, ...
# 27            Panaji  [Mix, Banana-flavour-mix-and-added-vitamins-an...
# 28           Dixiana  [Caramel-wafer-bars, Eaux-minerales, Dark-soy-...
# 29           Ifakara  [Precision-instruments, Fresh-lamb-meat, Tom-y...
# ..               ...                                                ...
# 70             Belek  [Wasabi-horseradish, Fish-can, Mackeral, Fresh...
# 71           Nalhāti  [Prawn-cocktail, Peach, Biscuits-au-chocolat, ...
# 72      Râs el Aïoun  [Chocolate-bunny, Easter-buns, Fresh-corn, Whi...
# 73             Kunri  [Wasabi-horseradish, Ribeye-steak, Boeuf-bourg...
# 74           Horodok  [Pizza dough, Cinnamon-roll, Crumpets, Gins, K...
# 75        Koprivnica  [Frozen-ice-cream, Baked-beans-in-tomato-sauce...
# 76      Rājgurunagar  [Kvarg, Pousses-de-bambou, Plats-prepares-surg...
# 77          Hajnówka  [Poivre-noir, Breaded products, Pitted-prunes,...
# 78       Romainville  [Dark-chocolate-block, Pitenza-tomatoes, Choco...
# 79              Aksu  [Canned-apricots, Peanut-in-chocolate, Blueber...
# 80      Ketanggungan  [Spearmint-sugarfree-gum, Iced-cookies, Chocol...
# 81             Kaédi  [Fromage-a-pate-dure, Pork-sausages, Dark-choc...
# 82            Kitami  [Chocolats-blancs, Crevettes, Soupes, Biere, G...
# 83            Putian  [Lemon-curd, Tuna-steak, Produits-laitiers, La...
# 84         Laungowāl  [Whole olives, Asian-condiments, Fish and meat...
# 85             Tampa  [Lamb-chops, Spam, Specialite-a-tartiner, Mayo...
# 86             Düzce  [Whole-chicken, Prawn-crackers, Spearmint-suga...
# 87     Pantai Cenang  [Earl-grey, Pies, Corn-tortilla-chips, Prunes,...
# 88         Hitoyoshi  [Reduced-fat-milks, Chilisauce, Sunflower-oil-...
# 89           Lushnjë  [Sweetcorn, Slaty-snack, Hot-chocolate, Granen...
# 90     Fontainebleau  [Fresh-cream, Curd-cheese, Canned-coconut-milk...
# 91      Bukit Rambai  [Sugary snacks, Crêpes and galettes, Fresh-cre...
# 92           Sedrata  [Frozen-ice-creams, Fruit-and-nut-mix, Frozen-...
# 93            Hirara  [Pork-ham, Fruits-frais, Chia-seeds, Bathroom,...
# 94       Wernigerode  [Edulcorant-avec-fruit-des-moines, Hot-chocola...
# 95             Mūlki  [Getrankeweisser, Fajitas, Spring-roll-pastry,...
# 96        Manacapuru  [Breakfast-granola, Vinaigres, Caramelized-red...
# 97            Hotaka  [Peeled-plum-tomatoes, Chorizos, Blue-cheese-y...
# 98        Novouzensk  [Protein, Dried-sausages, White-pitta-bread, A...
# 99          Cibinong  [Nectar-de-pommes, Asian-cooking, Breakfasts, ...
#
#                                                Import
# 0   [Dry-meat, Whole-wheat-beard, Apple-pear-juice...
# 1   [Seed-style-mustard, Yellow-mustard, Strawberr...
# 2   [Haferflocken, Yellow-peaches, Fresh-cakes, So...
# 3   [Fresh-cucumbers, Macaroni-cheese, Frozen-dump...
# 4   [Chili-con-carne, Spice-red-pepper, Double-cho...
# 5   [Whole-wheat-penne-rigate, Poivre-noir, Corn-t...
# 6   [Blueberry-syrup, Nans, Canned-mussels, Choux-...
# 7   [Sandwich-spread, Biscuits-with-dark-chocolate...
# 8   [Chicken-fillet-burger, Miels, Confitures-de-f...
# 9   [Stilton, Strawberry-trifle, Gulab-jamun, Tint...
# 10  [Melange-d-epices-pour-guacamole, Sugarsnap-pe...
# 11  [Dark-chocolate-block, Cold-meats, Cream-of-ta...
# 12  [Mineral-natural-water, Dried-spices, Kale-sal...
# 13  [Sweetcorn-relish, Capers, Schmelzkase, Sweet-...
# 14  [Whole-wheat-beard, Cured-sausage, Maris-piper...
# 15  [Artichauts-en-conserve, Fajitas, Chocolate-bu...
# 16  [Roasted-and-ground-coffee, Olives, Lamb-chops...
# 17  [Green-kale, Caramel-wafer-bars, Mango-drink, ...
# 18  [Pastry-dough, Snack-mix, Maple-butter, Dried ...
# 19  [Groceries, Licensed products, Vins-rouges, Mu...
# 20  [Frozen-bread, Fruit-juice-drink, Lager-beer, ...
# 21  [Schmelzkase, Fresh-brown-onions, Pancake-syru...
# 22  [Haferflocken, Beef-jerky, Tomato-chilli-relis...
# 23  [Hoki-fish-fillets, Almond-powder, Dilute-drin...
# 24  [Productos-lacteos, Sucre, Gourmet-pie, Fruit-...
# 25  [Canneloni, Dehydrated-mulberries, Whole-wheat...
# 26  [Fresh-pineapple, Dill-sauce, Dry-meat, Creme-...
# 27  [Instant-porridge, Chocolate-mousse, Flavoured...
# 28  [Cottage-cheeses, Gnocchi, Reduced-fat-milks, ...
# 29  [Sliced-jalapenos, Wortelsappen, Pralinen, Spa...
# ..                                                ...
# 70  [Nane-limon, Coca-sandwich-biscuits, Brownie, ...
# 71  [Moussakas, Trail-mix, Dill-sauce, Reduced-fat...
# 72  [Whole-wheat-penne-rigate, Ratatouille, Seafoo...
# 73  [Feuille-de-vigne, Lait, Muffin-mix, Fromage-a...
# 74  [Caramel-popcorn, Smoked-mussels, Genoa-salami...
# 75  [Chicken-pies, Sundried-tomatoes, Kase, Fresh-...
# 76  [White-coconut-chocolate, Two-crust Pies, Ghee...
# 77  [Cooked-vegetables, Freeze-dried foods, Garlic...
# 78  [Ricotta, Flour-tortillas, Oreo, Linsen, Meat-...
# 79  [Minced-beef-steak, Sweetcorn-and-peas, White-...
# 80  [Snack-mix, Liquid-honey, Rye-pale-ale, Coq-au...
# 81  [Still-water, Fish-sauce, Dumplings, Cardamom-...
# 82  [Prosciutto, Gulab-jamun, Pate, Orange-cake, B...
# 83  [Roast-ham, Frucht-und-gemusebasierte-lebensmi...
# 84  [Pies, Nutella-biscuits, Cukor, Hoisin-sauce, ...
# 85  [Melange-d-epices-pour-guacamole, Tee, Mackere...
# 86  [Frozen-pork-buns, Plats-prepares, Vanilla-waf...
# 87  [Vegetarian-mock-meat, Pure-cod-liver-oil, Cre...
# 88  [Horseradish-sauce, Chocolate-covered-muesli-b...
# 89  [Juice, Mint-jelly, Nectar-de-pommes, Malt-dri...
# 90  [Cottage-cheeses, Roquefort-cheese, Ribbon-noo...
# 91  [Spreads, Feuilletes-chevre-epinards, Pitted-p...
# 92  [Kidney-beans, Stringless-beans, White-pitta-b...
# 93  [Jelly-crystals, Umbrichelli, Blended-scotch-w...
# 94  [Specialite-a-tartiner, Mixed-chillies, Pierog...
# 95  [Fromage-a-pate-dure, Flavoured-mineral-water-...
# 96  [Cured-sausage, Faux-fromage, Rice-crackers, D...
# 97  [Coffee-flavoured-milk, Rye-pale-ale, Snack, B...
# 98  [Mini-portobello-mushrooms, Estragon, Bottled-...
# 99  [Fresh-cabbage, Penne, Piccolo-tomatoes, Smoke...
#
# [100 rows x 3 columns]

# %%
def standard_info(i, rid, tcd, trip, final_trip):
    final_trip.loc[i, 'RouteId'] = rid
    final_trip.loc[i, 'Order'] = i
    final_trip.loc[i, 'TruckCode'] = tcd
    final_trip.loc[i, 'StartCity'] = trip.loc[i,'IdCity']
    final_trip.loc[i, 'EndCity'] = trip.loc[i+1,'IdCity']

def first_step_creation(rid, tcd, length, trip):
    final_trip = pd.DataFrame(columns=['RouteId', 'Order', 'TruckCode', 'StartCity','EndCity', 'Items'])
    standard_info(0, rid, tcd, trip, final_trip)
    maxProbItems = list(set(trip.loc[length-1, "PopularImport"]).intersection(trip.loc[length-2, "ExportableItems"]))
    maxProbItems = maxProbItems * 5
    trip.loc[length-2, "ExportableItems"].extend(maxProbItems)
    # I set the range to be not fixed to 5-20 for the first trip cities that have few exportable items and I set
    # them to half to all the possible exportable items
    numItems = np.random.randint(min(5,len(trip.loc[length-2, "ExportableItems"])/2), min(15,len(trip.loc[length-2, "ExportableItems"])))
    sample = set(random.sample(trip.loc[length-2, "ExportableItems"], numItems))
    final_trip.loc[length-2, 'Items'] = sample
    return final_trip
    
def trip_creation(i, rid, tcd, length, trip, final_trip):
    standard_info(i-1, rid, tcd, trip, final_trip)
    crev = length - i - 1
    possibleExports = list(final_trip.loc[crev+1, 'Items'])
    itemsToDelete = set(possibleExports).intersection(list(city_list.loc[list(city_list.Name).index(trip.loc[crev+1, 'IdCity']), 'Export']))
    for i in itemsToDelete:
        possibleExports.remove(i)
    numItems = np.random.randint(3, min(15,len(trip.loc[crev, "ExportableItems"])))
    sample = set(random.sample(trip.loc[crev, "ExportableItems"], numItems))
    final_trip.loc[crev, 'Items'] = set(possibleExports).union(sample)
    return final_trip

# %%
# range of trip length setted at 3:15. We set the number of trucks to 10000
minLen = 3
maxLen = 10
numTruck = 1000
import random
def generate_trip(i):
    length = np.random.randint(minLen, maxLen)
    trip = pd.DataFrame(columns=['IdCity','ExportableItems', 'PopularImport'])
    items = []
    cities = []
    for c in range(0,length):
        city = np.random.randint(0,len(city_list))
        while city in cities:
            city = np.random.randint(0,len(city_list))
        cities.append(city)
        trip.loc[c, 'IdCity'] = city_list.loc[city,'Name']
        items.extend(city_list.loc[city,'Export'])
        trip.loc[c, 'ExportableItems'] = items.copy()
        trip.loc[c, 'PopularImport'] = city_list.loc[city,'Import']
    rid = i
    tcd = np.random.randint(0,numTruck)
    final_trip = first_step_creation(rid, tcd, length, trip)
    for c in range(2,length):
        final_trip = trip_creation(c, rid, tcd, length, trip, final_trip)
    final_trip = final_trip.sort_values('Order')
    return final_trip

# %%
def generate_trips(num):
    trips = [generate_trip(i) for i in range(0,num)]
    return trips

# %%
numberOfTrips = 100
trips = generate_trips(numberOfTrips)

# %%
trips
# Out:
# [  RouteId Order TruckCode        StartCity     EndCity  \
#  0       0     0       537  University City      Jetpur
#  1       0     1       537           Jetpur   Guarabira
#  2       0     2       537        Guarabira  Manacapuru
#  3       0     3       537       Manacapuru      Abaeté
#  4       0     4       537           Abaeté   Laungowāl
#
#                                                 Items
#  0  {Baked-beans-with-pork-sausages-in-tomato-sauc...
#  1  {Mache, Mate, Feta-cheese, Frozen-apple-pies, ...
#  2  {Mache, Mate, Tee, Klebreiskuchen, Purees-de-l...
#  3  {Mache, Mate, Tee, Klebreiskuchen, Granen-en-a...
#  4  {Tee, Feta-cheese, Artisan-bread-mix, Pates-a-...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0       1     0       166             Warri          Żoliborz
#  1       1     1       166          Żoliborz        Batticaloa
#  2       1     2       166        Batticaloa  Hódmezővásárhely
#  3       1     3       166  Hódmezővásárhely            Cuiabá
#  4       1     4       166            Cuiabá       Vostryakovo
#  5       1     5       166       Vostryakovo      Rio de Mouro
#
#                                                 Items
#  0  {Coconut-waters, Chocolats, Seitan-bio, Frozen...
#  1  {Goats-butter, Sweetelle-tomatoes, Goat-s-chee...
#  2  {Goats-butter, Sweetelle-tomatoes, Asian-cooki...
#  3  {Goats-butter, Sweetelle-tomatoes, Carrot-cake...
#  4  {Goats-butter, Sweetelle-tomatoes, Goat-s-chee...
#  5  {Chicken-burgers, Goat-s-cheese, Asian-condime...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0       2     0       667  Laungowāl     Annino
#  1       2     1       667     Annino   Gustavia
#  2       2     2       667   Gustavia  Gharaunda
#  3       2     3       667  Gharaunda   Monteros
#  4       2     4       667   Monteros   Hajnówka
#  5       2     5       667   Hajnówka    Bilhaur
#  6       2     6       667    Bilhaur    Horodok
#  7       2     7       667    Horodok       Aksu
#
#                                                 Items
#  0  {Sucres, Whole olives, Asian-condiments, Chest...
#  1  {Banana-flavour-mix-and-added-vitamins-and-min...
#  2  {Graines, Whole olives, Mineral-natural-water,...
#  3  {Dill-sauce, Graines, Pate-feuilletee, Semoule...
#  4  {Dill-sauce, Trail-mix, Pate-feuilletee, Biscu...
#  5  {Dill-sauce, Trail-mix, Pate-feuilletee, Biscu...
#  6  {Dill-sauce, Trail-mix, Pate-feuilletee, Biscu...
#  7  {Dill-sauce, Sushi, Chocolate-ice-cream, Plats...  ,
#    RouteId Order TruckCode StartCity      EndCity  \
#  0       3     0       368   Vichuga       Abaeté
#  1       3     1       368    Abaeté  Minneapolis
#
#                                                 Items
#  0  {Mate, Birthday-cake, Brassica, Butters-spread...
#  1  {Coffee-ice-cream, Marshmallow-creme, Spam, Br...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0       4     0       615        Aksu     Dixiana
#  1       4     1       615     Dixiana       Warri
#  2       4     2       615       Warri       Düzce
#  3       4     3       615       Düzce       Kaédi
#  4       4     4       615       Kaédi  Lakshmīpur
#  5       4     5       615  Lakshmīpur       Belek
#  6       4     6       615       Belek       Kunri
#  7       4     7       615       Kunri     Vichuga
#
#                                                 Items
#  0  {Chicken-meat, Swede, Whole olives, Organic-to...
#  1  {Fajitas, Chicken-meat, Salsa, Swede, Fish-can...
#  2  {Fajitas, Chicken-meat, Coconut-waters, Swede,...
#  3  {Fajitas, Chicken-meat, Coconut-waters, Swede,...
#  4  {Chicken-meat, Coconut-waters, Swede, Dried-sa...
#  5  {Chicken-meat, Coconut-waters, Soupes, Swede, ...
#  6  {Chicken-meat, Coconut-waters, Soupes, Dried-s...
#  7  {Chicken-meat, Pates-fraiches, Coconut-waters,...  ,
#    RouteId Order TruckCode        StartCity    EndCity  \
#  0       5     0       403  Morro do Chapéu    Lushnjë
#  1       5     1       403          Lushnjë  Gharaunda
#  2       5     2       403        Gharaunda     Timaru
#
#                                                 Items
#  0  {Grape-juice-drink, Assortiment-de-fromages, M...
#  1  {Passionfruit-pulp, Marshmallow-creme, Instant...
#  2  {Dill-sauce, Asperges-en-conserve, Gateau, Mar...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0       6     0       333       Tampa      Berlin
#  1       6     1       333      Berlin    Koch'ang
#  2       6     2       333    Koch'ang  Lakshmīpur
#  3       6     3       333  Lakshmīpur       Warri
#  4       6     4       333       Warri       Tāoru
#  5       6     5       333       Tāoru       Belek
#  6       6     6       333       Belek       Kunri
#
#                                                 Items
#  0  {Precooked-meat, Milch, Food additives, Vitami...
#  1  {Precooked-meat, Topping, Milch, Vitamins, Foo...
#  2  {Precooked-meat, Fruit-flavored, Topping, Vita...
#  3  {Fruit-flavored, Soupes, Chicken-powder, Lindt...
#  4  {Fruit-flavored, Soupes, Chicken-powder, Lindt...
#  5  {Fruit-flavored, Wholemeal-bread, Indian, Seit...
#  6  {Fruit-flavored, Maasdam-cheese, Brassica, Who...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0       7     0       881            Givors             Kunri
#  1       7     1       881             Kunri  Hódmezővásárhely
#  2       7     2       881  Hódmezővásárhely            Hotaka
#  3       7     3       881            Hotaka     Zheleznogorsk
#  4       7     4       881     Zheleznogorsk       Romainville
#  5       7     5       881       Romainville             Mūlki
#  6       7     6       881             Mūlki           Kushtia
#  7       7     7       881           Kushtia           Kālāvad
#
#                                                 Items
#  0  {Fajitas, Toppings, Asian-condiments, Pork-sau...
#  1  {Fajitas, Senate-bean-soup, Creme-caramel, Pan...
#  2  {Fajitas, Diced-tomatoes, Pastrami, Creme-cara...
#  3  {Flavoured-cranberries, Fajitas, Diced-tomatoe...
#  4  {Flavoured-cranberries, Fajitas, Diced-tomatoe...
#  5  {Flavoured-cranberries, Fajitas, Grated-parmes...
#  6  {Flavoured-cranberries, Fajitas, Gateau, Grate...
#  7  {Flavoured-cranberries, Grattons, Gateau, Grat...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0       8     0       624     Hitoyoshi  Rio de Mouro
#  1       8     1       624  Rio de Mouro       Dixiana
#  2       8     2       624       Dixiana    Cristalina
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
#  1  {Feuille-de-vigne, Asparagus-tips, Octopus-bal...
#  2  {Specialite-a-tartiner, Octopus-balls, Jaffa-c...  ,
#    RouteId Order TruckCode StartCity    EndCity  \
#  0       9     0       573  Cibinong     Haldia
#  1       9     1       573    Haldia      Tāoru
#  2       9     2       573     Tāoru   Gustavia
#  3       9     3       573  Gustavia    Kushtia
#  4       9     4       573   Kushtia     Pájara
#  5       9     5       573    Pájara   Żoliborz
#  6       9     6       573  Żoliborz  Hitoyoshi
#
#                                                 Items
#  0  {Asian-cooking, Eau-de-vie, Nectar-de-pommes, ...
#  1  {Soupes, Graines, Penne, Eau-de-vie, Alkoholis...
#  2  {Soupes, Asian-cooking, Penne, Brassica, Eau-d...
#  3  {Pringles-potato-chips, Graines, Asian-cooking...
#  4  {Pringles-potato-chips, Chocolate-trifle, Grai...
#  5  {Pringles-potato-chips, Cukor, Cafe-en-dosette...
#  6  {Goats-butter, Sussungsmittel, Brassica, Biscu...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      10     0       129              Sedrata                Mūlki
#  1      10     1       129                Mūlki          Bad Arolsen
#  2      10     2       129          Bad Arolsen                Tampa
#  3      10     3       129                Tampa                Forio
#  4      10     4       129                Forio  Pallanza-Intra-Suna
#  5      10     5       129  Pallanza-Intra-Suna              Sadalgi
#  6      10     6       129              Sadalgi               Berlin
#  7      10     7       129               Berlin            Southaven
#
#                                                 Items
#  0  {Chicken-powder, Condiment-en-poudre, Aperitif...
#  1  {Fajitas, Aliment-pour-chevaux, Specialite-bas...
#  2  {Fajitas, Aliment-pour-chevaux, Specialite-bas...
#  3  {Aliment-pour-chevaux, Lasagnes-preparees, Spe...
#  4  {Berry-mueslis, Melange-d-epices-pour-guacamol...
#  5  {Aliment-pour-chevaux, Green-bean-salad, Lasag...
#  6  {Green-bean-salad, Berry-mueslis, Granola-mix,...
#  7  {Frozen-ice-creams, Frozen-ice-cream, Vegetari...  ,
#    RouteId Order TruckCode  StartCity        EndCity  \
#  0      11     0       627     Cuiabá       Hajnówka
#  1      11     1       627   Hajnówka      Ushirombo
#  2      11     2       627  Ushirombo          Tampa
#  3      11     3       627      Tampa  Pantai Cenang
#
#                                                 Items
#  0  {Riz, Toppings, Pear-cider, Foies-gras, Apple-...
#  1  {Riz, Toppings, Fruit-confectionary, Foies-gra...
#  2  {Riz, Pancakes-and-waffles, Toppings, Fruit-co...
#  3  {Precooked-meat, Riz, Toppings, Citrouille-en-...  ,
#    RouteId Order TruckCode   StartCity        EndCity  \
#  0      12     0       416   Millville     Koprivnica
#  1      12     1       416  Koprivnica          Tāoru
#  2      12     2       416       Tāoru  Zheleznogorsk
#
#                                                 Items
#  0  {Coffee-ice-cream, Energy-balls, Sauce-cocktai...
#  1  {Asian-sauces, Porridge-oats, Peanut-butter-cu...
#  2  {Asian-sauces, Rice-crackers, Asian-food, Cinn...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      13     0       242    Kanuma  Qaţanā
#  1      13     1       242    Qaţanā   Mūlki
#  2      13     2       242     Mūlki  Putian
#
#                                                 Items
#  0  {Coconut-flour, Plastic-surgery, Fruit-cups, R...
#  1  {Pringles-potato-chips, Minced-beef-steak, Lin...
#  2  {Lindt-sea-salt-chocolate, Coconut-creams, Whi...  ,
#    RouteId Order TruckCode StartCity        EndCity  \
#  0      14     0       714    Givors          Mosta
#  1      14     1       714     Mosta         Qaţanā
#  2      14     2       714    Qaţanā        Horodok
#  3      14     3       714   Horodok           Aksu
#  4      14     4       714      Aksu  Pantai Cenang
#
#                                                 Items
#  0  {Fresh-pineapple, Chorizos, Viande, Levures, S...
#  1  {Assortiment-de-fromages, Fruits-en-conserve, ...
#  2  {Mushroom-in-sunflower-oil, Fruits-en-conserve...
#  3  {Mushroom-in-sunflower-oil, Fruits-en-conserve...
#  4  {Edam, Chinese-cabbage, Caffe, Sweetcorn-relis...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      15     0       466       Vostryakovo  Hódmezővásárhely
#  1      15     1       466  Hódmezővásárhely            Wakiso
#  2      15     2       466            Wakiso        Novouzensk
#  3      15     3       466        Novouzensk            Hirara
#  4      15     4       466            Hirara            Pájara
#  5      15     5       466            Pájara   University City
#  6      15     6       466   University City           Vichuga
#
#                                                 Items
#  0  {Coleslaw-dressing, Cream-of-tartar, Biryani, ...
#  1  {Chocolate-muffin, Carrot-cake, Kase, Butters-...
#  2  {Kase, Cream-cheese-spreads, Remoulade, Cucumb...
#  3  {Blended-scotch-whisky, Cream-cheese-spreads, ...
#  4  {Blended-scotch-whisky, White-pitta-bread, Rem...
#  5  {Gateau, Porc, Blended-scotch-whisky, Frozen-c...
#  6  {Gateau, Blended-scotch-whisky, Frozen-confect...  ,
#    RouteId Order TruckCode            StartCity       EndCity  \
#  0      16     0       616  Pallanza-Intra-Suna   Vostryakovo
#  1      16     1       616          Vostryakovo        Cuiabá
#  2      16     2       616               Cuiabá        Pájara
#  3      16     3       616               Pájara       Hibbing
#  4      16     4       616              Hibbing   Bad Arolsen
#  5      16     5       616          Bad Arolsen        Panaji
#  6      16     6       616               Panaji  Rājgurunagar
#  7      16     7       616         Rājgurunagar      Lakeland
#
#                                                 Items
#  0  {Haselnusse, Green-bean-salad, Scottish-shortb...
#  1  {Green-bean-salad, Fruit-confectionary, Biryan...
#  2  {Soupes, Cheddar-baguettes, Toppings, Green-be...
#  3  {Banana-flavour-mix-and-added-vitamins-and-min...
#  4  {Cactus, Recipe-mixes, Toppings, Soupes, Poppi...
#  5  {Soupes, Recipe-mixes, Cactus, Popping-corn, T...
#  6  {Soupes, Recipe-mixes, Cactus, Popping-corn, G...
#  7  {Soupes, Recipe-mixes, Popping-corn, Green-bea...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      17     0       499  Pruszków  Panaji
#  1      17     1       499    Panaji  Putian
#
#                                                 Items
#  0  {Cukor, Recipe-mixes, Quesos, Absinth, Ramen, ...
#  1  {Recipe-mixes, Quesos, Pasta-bake-sauces, Cann...  ,
#    RouteId Order TruckCode            StartCity        EndCity  \
#  0      18     0       879  Pallanza-Intra-Suna          Düzce
#  1      18     1       879                Düzce  Fontainebleau
#  2      18     2       879        Fontainebleau         Haldia
#  3      18     3       879               Haldia       Żoliborz
#  4      18     4       879             Żoliborz       Koch'ang
#
#                                                 Items
#  0  {Haselnusse, Bonbons-a-la-menthe, Green-bean-s...
#  1  {Dried-sausages, Green-bean-salad, Marshmallow...
#  2  {Cookies-chocolate, Diced-peaches-in-juice, Ca...
#  3  {Cookies-chocolate, Caramel-flavored-topping, ...
#  4  {Cookies-chocolate, Sussungsmittel, Caramel-fl...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      19     0       711      Panaji      Pájara
#  1      19     1       711      Pájara       Warri
#  2      19     2       711       Warri  Cristalina
#  3      19     3       711  Cristalina       Tampa
#
#                                                 Items
#  0  {Low-fat-fresh-laban, Absinth, Butter-shortbre...
#  1  {Seabass, Asian-cooking, Butter-shortbread-fin...
#  2  {Asian-cooking, Chicken-thighs-fillets, Seitan...
#  3  {Coconut-waters, Frozen-prawn-cutlets, Seabass...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      20     0       912         Belek     Şanlıurfa
#  1      20     1       912     Şanlıurfa        Haldia
#  2      20     2       912        Haldia  Ketanggungan
#  3      20     3       912  Ketanggungan       Ifakara
#  4      20     4       912       Ifakara         Mosta
#  5      20     5       912         Mosta     Laungowāl
#  6      20     6       912     Laungowāl      Gustavia
#  7      20     7       912      Gustavia      Winnipeg
#
#                                                 Items
#  0  {Wasabi-horseradish, Formulated-supplementary-...
#  1  {Fats, Mackeral, Seafood-salad, Iced-donuts, S...
#  2  {Graines, Lingonberry-jams, Penne, Mackeral, I...
#  3  {Cornish-pasties, Lingonberry-jams, Green-bean...
#  4  {Cornish-pasties, Lingonberry-jams, Green-bean...
#  5  {Assortiment-de-fromages, Cornish-pasties, Lin...
#  6  {Assortiment-de-fromages, Cornish-pasties, Lin...
#  7  {Assortiment-de-fromages, Coconut-flour, Lingo...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      21     0       571           Abaeté          Dixiana
#  1      21     1       571          Dixiana            Mūlki
#  2      21     2       571            Mūlki      Berkhamsted
#  3      21     3       571      Berkhamsted     Râs el Aïoun
#  4      21     4       571     Râs el Aïoun  University City
#  5      21     5       571  University City         Koksijde
#
#                                                 Items
#  0  {Bitters, Chocolats, Sweet-biscuits, Likor, Ti...
#  1  {Specialite-a-tartiner, Bitters, Chocolats, Li...
#  2  {Specialite-a-tartiner, Chocolats, Strawberry-...
#  3  {Carrot-cake, Specialite-a-tartiner, Green-sal...
#  4  {Carrot-cake, Specialite-a-tartiner, Green-sal...
#  5  {Smoked-haddock, Crevettes-roses, Sweetelle-to...  ,
#    RouteId Order TruckCode StartCity      EndCity  \
#  0      22     0       609     Kaédi     Lakeland
#  1      22     1       609  Lakeland  Wernigerode
#
#                                                 Items
#  0  {Golden-syrup, Canned-oysters, Gnocchi, Browni...
#  1  {Estragon, Brownie, Dark-chocolate-block, Vine...  ,
#    RouteId Order TruckCode    StartCity EndCity  \
#  0      23     0       545  Bad Arolsen  Timaru
#  1      23     1       545       Timaru   Belek
#  2      23     2       545        Belek  Kloten
#
#                                                 Items
#  0  {Senate-bean-soup, Berry-mueslis, Chicken-tikk...
#  1  {Prosciutto, Sandwich-spread, Senate-bean-soup...
#  2  {Smoked-mussels, Dulces, Lait, Getreide-und-ge...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      24     0        82        Mosta  Bad Arolsen
#  1      24     1        82  Bad Arolsen      Dixiana
#
#                                                 Items
#  0  {Savoy-cabbage, Cornbreads, Curd-cheese, Plaic...
#  1  {Fruit-cups, Berry-mueslis, Chocolate-sauces, ...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      25     0       569          Aksu  Râs el Aïoun
#  1      25     1       569  Râs el Aïoun         Annau
#
#                                                 Items
#  0  {Whole olives, Basa-fish, Organic-tomatoes, Tu...
#  1  {Whole olives, Basa-fish, Organic-tomatoes, Ap...  ,
#    RouteId Order TruckCode      StartCity   EndCity  \
#  0      26     0        18  Zheleznogorsk   Jalingo
#  1      26     1        18        Jalingo    Kanuma
#  2      26     2        18         Kanuma  Gustavia
#  3      26     3        18       Gustavia  Hajnówka
#  4      26     4        18       Hajnówka      Same
#  5      26     5        18           Same  Koksijde
#  6      26     6        18       Koksijde   Dixiana
#
#                                                 Items
#  0  {Chicken-meat, Aliment-pour-chevaux, Grated-pa...
#  1  {Biryani, Likor, Beer-batter-fries, All-steak-...
#  2  {Riz, Coconut-flour, Mixed-nuts, Hamblokjes, S...
#  3  {Riz, Grape-juice-drink, Smoked-mussels, Fruit...
#  4  {Riz, Grape-juice-drink, Whole-wheat-beard, Se...
#  5  {Whole-wheat-beard, Custard-powder, Beers-from...
#  6  {Custard-powder, Whole-wheat-beard, Beers-from...  ,
#    RouteId Order TruckCode    StartCity           EndCity  \
#  0      27     0       971        Warri          Hajnówka
#  1      27     1       971     Hajnówka           Needham
#  2      27     2       971      Needham         Guarabira
#  3      27     3       971    Guarabira       Wernigerode
#  4      27     4       971  Wernigerode             Mosta
#  5      27     5       971        Mosta           Kushtia
#  6      27     6       971      Kushtia  Krasnoperekops’k
#
#                                                 Items
#  0  {Gluhwein, Chocolats, Coconut-milk-powder, Pea...
#  1  {Fruit-confectionary, Canned-crab-meat, Breade...
#  2  {Breaded products, Fruit-confectionary, Canned...
#  3  {Gluhwein, Jus-d-orange, Fresh-bread, Natural-...
#  4  {Gluhwein, Jus-d-orange, Fresh-bread, Natural-...
#  5  {Gluhwein, Jus-d-orange, Fresh-bread, Cancoill...
#  6  {Fresh-bread, Cancoillottes, Tortilla-wraps, S...  ,
#    RouteId Order TruckCode  StartCity     EndCity  \
#  0      28     0       655      Khāpa       Tāoru
#  1      28     1       655      Tāoru     Ifakara
#  2      28     2       655    Ifakara   Southaven
#  3      28     3       655  Southaven  Lakshmīpur
#
#                                                 Items
#  0  {Pralines, Deep-fried, Natural-yoghurts, Kidne...
#  1  {Ghee, Kauwgom, Natural-yoghurts, Liquid-honey...
#  2  {Ice-tea, Ghee, Fruit-confectionary, Pure-oran...
#  3  {Hamblokjes, Chocolate-ice-cream, Cheese-crack...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      29     0        10         Jalingo     Romainville
#  1      29     1        10     Romainville           Khāpa
#  2      29     2        10           Khāpa         Horodok
#  3      29     3        10         Horodok  Puerto La Cruz
#  4      29     4        10  Puerto La Cruz      Lakshmīpur
#
#                                                 Items
#  0  {Orange-juice-from-concentrate, Beer-batter-fr...
#  1  {Passionfruit-pulp, Productos-lacteos, Kase, O...
#  2  {Deep-fried, Cinamon-donuts, Productos-lacteos...
#  3  {Rice-wine, Cinamon-donuts, Productos-lacteos,...
#  4  {Cinamon-donuts, Smoked-oysters-in-barbeque-sa...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      30     0       310           Aksu  Zheleznogorsk
#  1      30     1       310  Zheleznogorsk          Khāpa
#  2      30     2       310          Khāpa         Annino
#
#                                                 Items
#  0  {Basa-fish, Organic-tomatoes, Tuna-steak, Meat...
#  1  {Chicken-meat, White-pitta-bread, Basa-fish, G...
#  2  {Pitta-breads, Chicken-meat, Basa-fish, Kidney...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      31     0        66     Gustavia  Dharmanagar
#  1      31     1        66  Dharmanagar       Panaji
#
#                                                 Items
#  0  {Pringles-potato-chips, Graines, Mineral-natur...
#  1  {Pringles-potato-chips, Banana-flavour-mix-and...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      32     0       935    Rājgurunagar  Puerto La Cruz
#  1      32     1       935  Puerto La Cruz       Fundación
#  2      32     2       935       Fundación     Berkhamsted
#
#                                                 Items
#  0  {Kvarg, Pousses-de-bambou, Plats-prepares-surg...
#  1  {Carrot-cake, Plats-prepares-surgeles, Edam, P...
#  2  {Yoghurts-op-een-laag-fruit, Prepared-fish, Ca...  ,
#    RouteId Order TruckCode      StartCity    EndCity  \
#  0      33     0       829  Potchefstroom  Fundación
#  1      33     1       829      Fundación    Sadalgi
#  2      33     2       829        Sadalgi   Koksijde
#
#                                                 Items
#  0  {Cukor, Genio-tomatoes, Probiotic-drinks, Sucr...
#  1  {Cukor, Genio-tomatoes, Sucres, Macaroni-chees...
#  2  {Genio-tomatoes, Blueberry-muffins, Mousse-de-...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      34     0       797      Kunri       Same
#  1      34     1       797       Same     Putian
#  2      34     2       797     Putian   Koch'ang
#  3      34     3       797   Koch'ang  Ushirombo
#  4      34     4       797  Ushirombo  Southaven
#  5      34     5       797  Southaven      Mūlki
#  6      34     6       797      Mūlki   Lakeland
#
#                                                 Items
#  0  {Croissant-with-cocoa-cream, Birthday-cake, Wh...
#  1  {Fajitas, Low-fat-fresh-laban, Croissant-with-...
#  2  {Fajitas, Croissant-with-cocoa-cream, Salads, ...
#  3  {Fajitas, Croissant-with-cocoa-cream, Jus-d-or...
#  4  {Pancakes-and-waffles, Croissant-with-cocoa-cr...
#  5  {Croissant-with-cocoa-cream, Mate, Dried produ...
#  6  {Churned-cream, Citrouille-en-conserve, Still-...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      35     0       940     Laungowāl  Râs el Aïoun
#  1      35     1       940  Râs el Aïoun     Gharaunda
#  2      35     2       940     Gharaunda      Gustavia
#  3      35     3       940      Gustavia        Putian
#  4      35     4       940        Putian       Jalingo
#  5      35     5       940       Jalingo       Sadalgi
#  6      35     6       940       Sadalgi      Cibinong
#  7      35     7       940      Cibinong       Horodok
#
#                                                 Items
#  0  {Sucres, Whole olives, Asian-condiments, Chest...
#  1  {Kits, Bitters, Asian-condiments, Fresh-corn, ...
#  2  {Asperges-en-conserve, Bitters, Pate-feuillete...
#  3  {Grape-juice-drink, Bitters, Pate-feuilletee, ...
#  4  {Grape-juice-drink, Fats, Sucres, Lemon-curd, ...
#  5  {Biryani, Cured-ham, Hazelnut-chocolate-spread...
#  6  {Mozzarella-sticks, Dessert-mixes, Fats, Alime...
#  7  {Farina, Dessert-mixes, Aliment-pour-chevaux, ...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      36     0       137    Bad Arolsen  Fontainebleau
#  1      36     1       137  Fontainebleau     Batticaloa
#  2      36     2       137     Batticaloa  Zheleznogorsk
#  3      36     3       137  Zheleznogorsk   Rājgurunagar
#
#                                                 Items
#  0  {Senate-bean-soup, Berry-mueslis, Cream-of-tar...
#  1  {Cookies-chocolate, Cocktail-sauces, Senate-be...
#  2  {Cookies-chocolate, Cocktail-sauces, Cremes-gl...
#  3  {Chicken-meat, Grated-parmesan-cheese, Prepare...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      37     0       994      Millville  Chililabombwe
#  1      37     1       994  Chililabombwe        Lushnjë
#  2      37     2       994        Lushnjë      Winnenden
#  3      37     3       994      Winnenden        Dixiana
#  4      37     4       994        Dixiana        Nalhāti
#
#                                                 Items
#  0  {Frozen-chinese-spring-roll-snacks, Smoked-ham...
#  1  {Frozen-chinese-spring-roll-snacks, Smoked-ham...
#  2  {Frozen-chinese-spring-roll-snacks, Passionfru...
#  3  {Chocolate-block, Penne, Blue-stilton, Marie-r...
#  4  {Chocolate-block, Marie-rose-sauce, Hot-cocoa-...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      38     0       403     Pájara  Hitoyoshi
#  1      38     1       403  Hitoyoshi  Winnenden
#  2      38     2       403  Winnenden  Ushirombo
#  3      38     3       403  Ushirombo     Givors
#
#                                                 Items
#  0  {Cactus, Seabass, Asian-cooking, Beers-from-st...
#  1  {Banana-flavour-mix-and-added-vitamins-and-min...
#  2  {Banana-flavour-mix-and-added-vitamins-and-min...
#  3  {Fajitas, Tee, Seabass, Tejszin, Snack, Cookin...  ,
#    RouteId Order TruckCode     StartCity    EndCity  \
#  0      39     0       688  Râs el Aïoun      Kaédi
#  1      39     1       688         Kaédi     Berlin
#  2      39     2       688        Berlin    Vichuga
#  3      39     3       688       Vichuga  Winnenden
#  4      39     4       688     Winnenden     Hotaka
#  5      39     5       688        Hotaka  Southaven
#  6      39     6       688     Southaven      Belek
#
#                                                 Items
#  0  {Dolminades, Bitters, Chocolate-mints, Kvarg, ...
#  1  {Dolminades, Hamblokjes, Pork-sausages, Chocol...
#  2  {Canned-oysters, Golden-syrup, Dolminades, Fro...
#  3  {Brassica, Spices-seasoning-mixes, Easter-buns...
#  4  {Brassica, Fruits-frais, Spices-seasoning-mixe...
#  5  {Canned-oysters, Fruit-salad-in-juice, Product...
#  6  {Fruit-salad-in-juice, Churned-cream, Chocolat...  ,
#    RouteId Order TruckCode   StartCity       EndCity  \
#  0      40     0       794       Belek       Ifakara
#  1      40     1       794     Ifakara    Novouzensk
#  2      40     2       794  Novouzensk  Ketanggungan
#
#                                                 Items
#  0  {Egg-white-powder, Fish-can, Maasdam-cheese, M...
#  1  {Fish-can, Fruit-confectionary, Maasdam-cheese...
#  2  {Fish-can, Asian-condiments, Sugar-cane-drink,...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      41     0       418      Millville      Hitoyoshi
#  1      41     1       418      Hitoyoshi    Vostryakovo
#  2      41     2       418    Vostryakovo         Berlin
#  3      41     3       418         Berlin  Fontainebleau
#  4      41     4       418  Fontainebleau  Zheleznogorsk
#  5      41     5       418  Zheleznogorsk        Sadalgi
#  6      41     6       418        Sadalgi          Warri
#
#                                                 Items
#  0  {Smoked-ham, Penne, Vegetarian-fish-fillets, P...
#  1  {Asparagus-tips, Smoked-ham, Penne, Vegetarian...
#  2  {Asparagus-tips, Smoked-ham, Penne, Biryani, C...
#  3  {Asparagus-tips, Vanilla-waffles, Biryani, Por...
#  4  {Asparagus-tips, Vanilla-waffles, Biryani, Cit...
#  5  {Chicken-meat, Vanilla-waffles, Lamb-breast, C...
#  6  {Chicken-meat, Vanilla-waffles, Plaice, Cremes...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      42     0       148           Abū Tīj             Kogon
#  1      42     1       148             Kogon  Krasnoperekops’k
#  2      42     2       148  Krasnoperekops’k           Sedrata
#
#                                                 Items
#  0  {Umbrichelli, Fish-can, Goat-milk-cheese, Natu...
#  1  {Umbrichelli, Cornbreads, Natural-yoghurts, Ch...
#  2  {Cornbreads, Grana-padano, Sweet-chilli-sauce,...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      43     0         0    Berlin    Kloten
#  1      43     1         0    Kloten    Abaeté
#  2      43     2         0    Abaeté  Taşköprü
#  3      43     3         0  Taşköprü     Forio
#
#                                                 Items
#  0  {Vanilla-waffles, Groceries, Asian-condiments,...
#  1  {Labeled products, Vanilla-waffles, Chorizos, ...
#  2  {Bitters, Chocolats, Eaux-minerales, Artisan-b...
#  3  {Grape-juice-drink, Chocolats, Tiefkuhlpizza, ...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      44     0       318      Kloten      Haldia
#  1      44     1       318      Haldia  Novouzensk
#  2      44     2       318  Novouzensk       Tāoru
#  3      44     3       318       Tāoru       Kaédi
#  4      44     4       318       Kaédi      Givors
#  5      44     5       318      Givors   Ushirombo
#
#                                                 Items
#  0  {Labeled products, Dolminades, Chorizos, Meat-...
#  1  {Pringles-potato-chips, Chorizos, Green-bean-s...
#  2  {Pringles-potato-chips, Energy-ball, Dried-sau...
#  3  {Pringles-potato-chips, Energy-ball, Diced-tom...
#  4  {Cured-sausage, Diced-tomatoes, Indian, Dried-...
#  5  {Diced-tomatoes, Dried-sausages, Ghee, Asian-c...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      45     0       806        Givors         Tāoru
#  1      45     1       806         Tāoru         Kaédi
#  2      45     2       806         Kaédi         Mūlki
#  3      45     3       806         Mūlki    Cristalina
#  4      45     4       806    Cristalina   Berkhamsted
#  5      45     5       806   Berkhamsted  Râs el Aïoun
#  6      45     6       806  Râs el Aïoun          Aksu
#  7      45     7       806          Aksu       Sadalgi
#
#                                                 Items
#  0  {Fajitas, Asian-condiments, Pork-sausages, Lev...
#  1  {Fajitas, Indian, Diced-tomatoes, Ghee, Asian-...
#  2  {Ghee, Brassica, Creme-caramel, Levures, Reduc...
#  3  {Fajitas, Ghee, Brassica, Creme-caramel, Levur...
#  4  {Fajitas, Ghee, Creme-caramel, Levures, Chips ...
#  5  {Fajitas, Canned-precooked-meat, Creme-caramel...
#  6  {Dulces, Tarts, Golden-syrup, Bitters, Frozen-...
#  7  {Hamblokjes, Organic-tomatoes, Prepackaged-san...  ,
#    RouteId Order TruckCode    StartCity EndCity  \
#  0      46     0       597  Minneapolis   Kaédi
#  1      46     1       597        Kaédi  Abaeté
#
#                                                 Items
#  0  {Fresh-asparagus, Tartar-sauce, Custard-tarts,...
#  1  {Pork-sausages, Fresh-raspberries, Chocolate-c...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      47     0       800         Şanlıurfa  Krasnoperekops’k
#  1      47     1       800  Krasnoperekops’k    Puerto La Cruz
#  2      47     2       800    Puerto La Cruz      Rājgurunagar
#  3      47     3       800      Rājgurunagar           Abū Tīj
#
#                                                 Items
#  0  {Assortiment-de-fromages, Biryani, Skegness-bl...
#  1  {Assortiment-de-fromages, Biryani, Skegness-bl...
#  2  {Assortiment-de-fromages, Carrot-cake, Skegnes...
#  3  {Assortiment-de-fromages, Citrouille-en-conser...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      48     0       464      Gharaunda          Kogon
#  1      48     1       464          Kogon   Rājgurunagar
#  2      48     2       464   Rājgurunagar      Ushirombo
#  3      48     3       464      Ushirombo         Jetpur
#  4      48     4       464         Jetpur  Zheleznogorsk
#  5      48     5       464  Zheleznogorsk        Sedrata
#  6      48     6       464        Sedrata    Dharmanagar
#
#                                                 Items
#  0  {Semoules-de-ble-dur-pour-couscous, Chocolats,...
#  1  {Cornbreads, Capers, Chocolats, Burrito-kit, B...
#  2  {Cornbreads, Capers, Chocolats, Plats-prepares...
#  3  {Fajitas, Cornbreads, Capers, Meat-paste, Choc...
#  4  {Cornbreads, Mate, Capers, Meat-paste, Chocola...
#  5  {Cornbreads, Mate, Capers, Plats-prepares-surg...
#  6  {Capers, Pitted-prunes, Kase, Seed-style-musta...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      49     0       324     Manacapuru  Fontainebleau
#  1      49     1       324  Fontainebleau          Mosta
#  2      49     2       324          Mosta     Cristalina
#  3      49     3       324     Cristalina       Winnipeg
#
#                                                 Items
#  0  {Fresh-asparagus, Diced-tomatoes, Lingonberry-...
#  1  {Fresh-asparagus, Curd-cheese, Diced-tomatoes,...
#  2  {Fresh-asparagus, Diced-tomatoes, Penne, Froze...
#  3  {Cookies-chocolate, Diced-tomatoes, Cocktail-s...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      50     0        63         Jetpur     Koprivnica
#  1      50     1        63     Koprivnica          Belek
#  2      50     2        63          Belek  Potchefstroom
#  3      50     3        63  Potchefstroom     Manacapuru
#  4      50     4        63     Manacapuru          Warri
#  5      50     5        63          Warri      Hitoyoshi
#
#                                                 Items
#  0  {Mate, Aoli-sauce, Smoked-mussels, Cinnamon-ro...
#  1  {Aoli-sauce, Cinnamon-roll, Dindes, Vinaigres,...
#  2  {Aoli-sauce, Rice-crackers, Viande, Dindes, Fr...
#  3  {Low-fat-fresh-laban, Genio-tomatoes, Sucres, ...
#  4  {Low-fat-fresh-laban, Chocolats, Fresh-corn, K...
#  5  {Low-fat-fresh-laban, Bambusstreifen, Chocolat...  ,
#    RouteId Order TruckCode      StartCity     EndCity  \
#  0      51     0       755  Chililabombwe     Jalingo
#  1      51     1       755        Jalingo  Lakshmīpur
#  2      51     2       755     Lakshmīpur     Kushtia
#  3      51     3       755        Kushtia      Kitami
#  4      51     4       755         Kitami  Koprivnica
#  5      51     5       755     Koprivnica     Abū Tīj
#  6      51     6       755        Abū Tīj     Dixiana
#
#                                                 Items
#  0  {Fresh-garlic, Cherry-pie-filling, Vegetable-f...
#  1  {Biryani, Beer-batter-fries, Vegetable-pate, O...
#  2  {Legumes-au-vinaigre, Biryani, Beer-batter-fri...
#  3  {Hot-dog-mustard, Radish, Beer-batter-fries, B...
#  4  {Hot-dog-mustard, Radish, Beer-batter-fries, B...
#  5  {Hot-dog-mustard, Food additives, Popping-corn...
#  6  {Popping-corn, Mixed-nuts, Groceries, Asian-co...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      52     0       564    Zheleznogorsk        Şanlıurfa
#  1      52     1       564        Şanlıurfa           Berlin
#  2      52     2       564           Berlin           Hirara
#  3      52     3       564           Hirara  Morro do Chapéu
#  4      52     4       564  Morro do Chapéu          Dixiana
#  5      52     5       564          Dixiana            Kogon
#
#                                                 Items
#  0  {Grape-juice-drink, Grated-parmesan-cheese, Al...
#  1  {Grape-juice-drink, Assortiment-de-fromages, G...
#  2  {Grape-juice-drink, Skegness-blue, Lamb-chops,...
#  3  {Pannekoeken, All-steak-pie, Lamb-chops, Fruit...
#  4  {Grape-juice-drink, Assortiment-de-fromages, P...
#  5  {Grape-juice-drink, Pannekoeken, Aliment-pour-...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      53     0       962         Khāpa   Dharmanagar
#  1      53     1       962   Dharmanagar  Bukit Rambai
#  2      53     2       962  Bukit Rambai        Kanuma
#  3      53     3       962        Kanuma        Kloten
#  4      53     4       962        Kloten      Monteros
#  5      53     5       962      Monteros          Same
#  6      53     6       962          Same      Pruszków
#
#                                                 Items
#  0  {Deep-fried, Cinamon-donuts, Choux-fleurs-en-f...
#  1  {Chicken-meat, Cinamon-donuts, Choux-fleurs-en...
#  2  {Fajitas, Chicken-meat, Cinamon-donuts, Instan...
#  3  {Fajitas, Chicken-meat, Cinamon-donuts, Natura...
#  4  {Pralines, Chicken-meat, Smoked-haddock, Cinam...
#  5  {Chicken-meat, Egg-salad, Herring-fillets, All...
#  6  {Chicken-meat, Cake-mix, Peaches-sliced-in-syr...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      54     0       202   Cristalina       Givors
#  1      54     1       202       Givors    Goyerkāta
#  2      54     2       202    Goyerkāta    Hitoyoshi
#  3      54     3       202    Hitoyoshi  Vostryakovo
#  4      54     4       202  Vostryakovo       Haldia
#  5      54     5       202       Haldia        Warri
#
#                                                 Items
#  0  {Cayenne-pepper-sauce, Coconut-waters, Cardamo...
#  1  {Flavoured-cranberries, Coconut-waters, Cayenn...
#  2  {Coconut-waters, Energy-ball, Chorizos, Canned...
#  3  {Banana-flavour-mix-and-added-vitamins-and-min...
#  4  {Dulces, Coconut-waters, Marshmallow-creme, Ch...
#  5  {Marshmallow-creme, Pates-a-tartiner-aux-noise...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      55     0       164       Koch'ang  Zheleznogorsk
#  1      55     1       164  Zheleznogorsk     Cristalina
#  2      55     2       164     Cristalina      Guarabira
#  3      55     3       164      Guarabira          Kaédi
#
#                                                 Items
#  0  {Fruit-flavored, Chicken-pies, Shredded-cheese...
#  1  {Estragon, Genio-tomatoes, Hamblokjes, Still-w...
#  2  {Citrus-punch, Frozen-bread, Hamblokjes, Still...
#  3  {Still-water, Penne, Apple-cider, Citrus-punch...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      56     0       888   Nalhāti  Wakiso
#  1      56     1       888    Wakiso  Jetpur
#  2      56     2       888    Jetpur    Aksu
#
#                                                 Items
#  0  {Peach, Fresh-coconut, Gateau, Herring-fillets...
#  1  {Grape-juice-drink, Peach, Fresh-coconut, Anch...
#  2  {Grape-juice-drink, Peach, Aoli-sauce, Anchovy...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      57     0       676   Ifakara    Putian
#  1      57     1       676    Putian   Hibbing
#  2      57     2       676   Hibbing  Pruszków
#
#                                                 Items
#  0  {Ice-tea, Brie-cheese, Fruit-confectionary, Fr...
#  1  {Ice-tea, Instant-porridge, Pannekoeken, Plaic...
#  2  {Corn-thins, Ice-tea, Pannekoeken, Instant-por...  ,
#    RouteId Order TruckCode      StartCity          EndCity  \
#  0      58     0       106       Pruszków            Annau
#  1      58     1       106          Annau        Guarabira
#  2      58     2       106      Guarabira    Fontainebleau
#  3      58     3       106  Fontainebleau  University City
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
#  1  {Banana-flavour-mix-and-added-vitamins-and-min...
#  2  {Banana-flavour-mix-and-added-vitamins-and-min...
#  3  {Banana-flavour-mix-and-added-vitamins-and-min...  ,
#    RouteId Order TruckCode     StartCity        EndCity  \
#  0      59     0       847      Monteros      Winnenden
#  1      59     1       847     Winnenden          Tāoru
#  2      59     2       847         Tāoru   Ketanggungan
#  3      59     3       847  Ketanggungan       Cibinong
#  4      59     4       847      Cibinong  Chililabombwe
#
#                                                 Items
#  0  {Donuts, Lamb-breast, Fruit-mince-pies, Tandoo...
#  1  {Chicken-meat, Pate-feuilletee, Blue-stilton, ...
#  2  {Pate-feuilletee, Green olives, Blue-stilton, ...
#  3  {Pate-feuilletee, Green olives, Cereales-pour-...
#  4  {Cured-sausage, Trail-mix, Pate-feuilletee, Ch...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      60     0       779     Koch'ang       Kloten
#  1      60     1       779       Kloten  Vostryakovo
#  2      60     2       779  Vostryakovo    Guarabira
#  3      60     3       779    Guarabira      Ifakara
#  4      60     4       779      Ifakara       Qaţanā
#  5      60     5       779       Qaţanā  Romainville
#  6      60     6       779  Romainville      Dixiana
#
#                                                 Items
#  0  {Fruit-flavored, Chicken-pies, Hokey-pokey-ice...
#  1  {Labeled products, Fruit-flavored, Chicken-pie...
#  2  {Labeled products, Fruit-flavored, Biryani, Ch...
#  3  {Labeled products, Fruit-flavored, Biryani, Ch...
#  4  {Labeled products, Fruit-flavored, Fruit-confe...
#  5  {Labeled products, Fruit-flavored, Sandiwch, C...
#  6  {Labeled products, Fruit-flavored, Cake-mix, C...  ,
#    RouteId Order TruckCode      StartCity     EndCity  \
#  0      61     0       150  Pantai Cenang     Sedrata
#  1      61     1       150        Sedrata   Millville
#  2      61     2       150      Millville    Gustavia
#  3      61     3       150       Gustavia  Batticaloa
#  4      61     4       150     Batticaloa      Panaji
#
#                                                 Items
#  0  {Corn-tortilla-chips, Mint-chocolate, Aliments...
#  1  {Cured-sausage, Whipping-fresh-cream, Corn-tor...
#  2  {Olives, Corn-tortilla-chips, Kidney-beans, Mi...
#  3  {Olives, Grape-juice-drink, Corn-tortilla-chip...
#  4  {Cured-sausage, Grape-juice-drink, Sweeteners,...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      62     0       792        Zheleznogorsk                Annau
#  1      62     1       792                Annau               Givors
#  2      62     2       792               Givors             Żoliborz
#  3      62     3       792             Żoliborz      Morro do Chapéu
#  4      62     4       792      Morro do Chapéu  Pallanza-Intra-Suna
#  5      62     5       792  Pallanza-Intra-Suna               Abaeté
#  6      62     6       792               Abaeté                Warri
#
#                                                 Items
#  0  {Grape-juice-drink, Chicken-meat, Grated-parme...
#  1  {Grape-juice-drink, Grated-parmesan-cheese, Al...
#  2  {Flavoured-cranberries, Toppings, Grated-parme...
#  3  {Toppings, Grated-parmesan-cheese, Asian-cooki...
#  4  {Assortiment-de-fromages, Toppings, Grated-par...
#  5  {Assortiment-de-fromages, Jus-d-orange, Toppin...
#  6  {Honey-ham, Readymeals, Fruit-juice-concentrat...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      63     0       866      Żoliborz      Gustavia
#  1      63     1       866      Gustavia  Rio de Mouro
#  2      63     2       866  Rio de Mouro   Vostryakovo
#  3      63     3       866   Vostryakovo        Annino
#  4      63     4       866        Annino        Panaji
#
#                                                 Items
#  0  {Sweetelle-tomatoes, Fish-can, Asian-cooking, ...
#  1  {Pringles-potato-chips, Graines, Fish-can, Min...
#  2  {Pringles-potato-chips, Baking-powder, Graines...
#  3  {Pringles-potato-chips, Baking-powder, Mineral...
#  4  {Pringles-potato-chips, Baking-powder, Mineral...  ,
#    RouteId Order TruckCode  StartCity      EndCity  \
#  0      64     0       689     Jetpur      Vichuga
#  1      64     1       689    Vichuga       Qaţanā
#  2      64     2       689     Qaţanā    Goyerkāta
#  3      64     3       689  Goyerkāta    Millville
#  4      64     4       689  Millville     Gustavia
#  5      64     5       689   Gustavia  Romainville
#
#                                                 Items
#  0  {Sugar-free-confectionary, Smoked-mussels, Din...
#  1  {Brassica, Butters-spreads, Getranke, Dindes, ...
#  2  {Brassica, Lindt-sea-salt-chocolate, Getranke,...
#  3  {Energy-ball, Brassica, Getranke, Pumpkin-soup...
#  4  {Olives, Coffee-ice-cream, Energy-ball, Smoked...
#  5  {Olives, Coffee-ice-cream, Energy-ball, Brusch...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      65     0       393   Hibbing   Abaeté
#  1      65     1       393    Abaeté  Kālāvad
#  2      65     2       393   Kālāvad    Warri
#  3      65     3       393     Warri  Kushtia
#
#                                                 Items
#  0  {Popping-corn, Tomkin-tomatoes, Gins, Grana-pa...
#  1  {Popping-corn, Chorizos, Crumpets, Sweet-biscu...
#  2  {Chorizos, Crumpets, Sweet-biscuits, Rye-pale-...
#  3  {Chorizos, Crumpets, Chocolats, Cooking-chocol...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      66     0       690        Wakiso  Rio de Mouro
#  1      66     1       690  Rio de Mouro     Ushirombo
#  2      66     2       690     Ushirombo       Sedrata
#  3      66     3       690       Sedrata         Kunri
#  4      66     4       690         Kunri       Sadalgi
#  5      66     5       690       Sadalgi        Kloten
#
#                                                 Items
#  0  {Bouillonterning, Grape-juice-drink, Thes-vert...
#  1  {Bouillonterning, Baking-powder, Spam, Snack-s...
#  2  {Corn-thins, Bouillonterning, Fajitas, Edam, B...
#  3  {Corn-thins, Fajitas, Bouillonterning, Fruit-a...
#  4  {Corn-thins, Baking-powder, Senate-bean-soup, ...
#  5  {Corn-thins, Citrouille-en-conserve, Green oli...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      67     0       756          Winnipeg  Krasnoperekops’k
#  1      67     1       756  Krasnoperekops’k         Goyerkāta
#  2      67     2       756         Goyerkāta          Taşköprü
#  3      67     3       756          Taşköprü           Sedrata
#
#                                                 Items
#  0  {Whipping-fresh-cream, Senate-bean-soup, Pates...
#  1  {Pates, Honey-roasted-sliced-almonds, Macaroni...
#  2  {Snacks, Pates, Crems-glacees, Berry-mueslis, ...
#  3  {Snacks, Pates, Berry-mueslis, Fruit-and-nut-m...  ,
#    RouteId Order TruckCode StartCity       EndCity  \
#  0      68     0       247    Partūr      Żoliborz
#  1      68     1       247  Żoliborz      Monteros
#  2      68     2       247  Monteros  Rājgurunagar
#
#                                                 Items
#  0  {Cured-sausage, Chocolate-muffin, Kombucha, Ap...
#  1  {Pringles-potato-chips, Chocolate-muffin, Goat...
#  2  {Jus-d-orange, Cocktail-sauces, Gins, Feuillet...  ,
#    RouteId Order TruckCode    StartCity     EndCity  \
#  0      69     0       538  Romainville   Fundación
#  1      69     1       538    Fundación       Mosta
#  2      69     2       538        Mosta  Batticaloa
#  3      69     3       538   Batticaloa    Winnipeg
#  4      69     4       538     Winnipeg       Khāpa
#  5      69     5       538        Khāpa    Pruszków
#
#                                                 Items
#  0  {Chocolate-muffin, Psyllium-husk, Passionfruit...
#  1  {Yoghurts-op-een-laag-fruit, Chocolate-muffin,...
#  2  {Chocolate-muffin, Passionfruit-pulp, Fresh-ga...
# ...
#  3  {Fresh-pineapple, Gluhwein, Haferflocken, Trim...
#  4  {Fresh-pineapple, Gluhwein, Peeled-plum-tomato...  ,
#    RouteId Order TruckCode    StartCity          EndCity  \
#  0      81     0       556    Hitoyoshi      Berkhamsted
#  1      81     1       556  Berkhamsted      Minneapolis
#  2      81     2       556  Minneapolis         Koksijde
#  3      81     3       556     Koksijde         Cibinong
#  4      81     4       556     Cibinong  University City
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
#  1  {Banana-flavour-mix-and-added-vitamins-and-min...
#  2  {Banana-flavour-mix-and-added-vitamins-and-min...
#  3  {Frozen-asian-vegetables, Natural-spring-water...
#  4  {Frozen-asian-vegetables, Pain-pita-sucres, Na...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      82     0        83        Manacapuru  Krasnoperekops’k
#  1      82     1        83  Krasnoperekops’k         Millville
#  2      82     2        83         Millville         Southaven
#  3      82     3        83         Southaven           Dixiana
#  4      82     4        83           Dixiana            Kitami
#  5      82     5        83            Kitami           Horodok
#  6      82     6        83           Horodok      Bukit Rambai
#
#                                                 Items
#  0  {Diced-tomatoes, Radish, Lingonberry-jams, Goa...
#  1  {Radish, Capers, Diced-tomatoes, Ghee, Goat-s-...
#  2  {Radish, Sweetcorn-and-peas, Diced-tomatoes, C...
#  3  {Corn-thins, Radish, Capers, Diced-tomatoes, G...
#  4  {Corn-thins, Fats, Baby-beetroot, Ghee, Sauce-...
#  5  {Corn-thins, Fats, Baby-beetroot, Ghee, Chocol...
#  6  {Baby-beetroot, Ghee, Breakfast-granola, Choco...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      83     0       877   University City  Hódmezővásárhely
#  1      83     1       877  Hódmezővásárhely             Düzce
#  2      83     2       877             Düzce          Koch'ang
#  3      83     3       877          Koch'ang       Wernigerode
#  4      83     4       877       Wernigerode           Ifakara
#  5      83     5       877           Ifakara           Vichuga
#  6      83     6       877           Vichuga   Morro do Chapéu
#  7      83     7       877   Morro do Chapéu         Ushirombo
#
#                                                 Items
#  0  {Recipe-mixes, Crevettes-roses, Balsamic-vinai...
#  1  {Chocolate-muffin, Carrot-cake, Recipe-mixes, ...
#  2  {Chocolate-muffin, Carrot-cake, Recipe-mixes, ...
#  3  {Chocolate-muffin, Carrot-cake, Diced-tomatoes...
#  4  {Chocolate-muffin, Carrot-cake, Diced-tomatoes...
#  5  {Carrot-cake, Diced-tomatoes, Fruit-confection...
#  6  {Carrot-cake, Taco-shells, Fruit-confectionary...
#  7  {Prawn-crackers, Porc, Taco-shells, Hamblokjes...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      84     0       621       Pruszków  Fontainebleau
#  1      84     1       621  Fontainebleau         Hotaka
#
#                                                 Items
#  0  {Quesos, Absinth, Salsa, Citrouille-en-conserv...
#  1  {Citrouille-en-conserve, Coleslaw-dressing, Ge...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      85     0       863     Mūlki    Khāpa
#  1      85     1       863     Khāpa   Haldia
#  2      85     2       863    Haldia  Sadalgi
#  3      85     3       863   Sadalgi   Jetpur
#
#                                                 Items
#  0  {Fajitas, Mango-chutney, Spring-roll-pastry, C...
#  1  {Deep-fried, Fajitas, Mayonaise, Madeleines-au...
#  2  {Deep-fried, Cafe-en-dosettes-compatible-nespr...
#  3  {Deep-fried, Cinamon-donuts, Cornichons-au-vin...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      86     0       388     Pantai Cenang           Dixiana
#  1      86     1       388           Dixiana      Ketanggungan
#  2      86     2       388      Ketanggungan  Krasnoperekops’k
#  3      86     3       388  Krasnoperekops’k            Annino
#  4      86     4       388            Annino       Bad Arolsen
#  5      86     5       388       Bad Arolsen            Cuiabá
#
#                                                 Items
#  0  {Corn-tortilla-chips, Blackcurrent-juice-drink...
#  1  {Specialite-a-tartiner, Fish-can, Blackcurrent...
#  2  {Specialite-a-tartiner, Fish-can, Blackcurrent...
#  3  {Specialite-a-tartiner, Fish-can, Canned-crab-...
#  4  {Banana-flavour-mix-and-added-vitamins-and-min...
#  5  {Banana-flavour-mix-and-added-vitamins-and-min...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      87     0       885         Winnenden         Şanlıurfa
#  1      87     1       885         Şanlıurfa          Pruszków
#  2      87     2       885          Pruszków            Hotaka
#  3      87     3       885            Hotaka  Hódmezővásárhely
#  4      87     4       885  Hódmezővásárhely       Romainville
#
#                                                 Items
#  0  {Chocolate-trifle, Asian-cooking, Blue-stilton...
#  1  {Assortiment-de-fromages, Chocolate-trifle, Bl...
#  2  {Assortiment-de-fromages, Recipe-mixes, Quesos...
#  3  {Assortiment-de-fromages, Recipe-mixes, Desser...
#  4  {Assortiment-de-fromages, Churned-cream, Froma...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      88     0       869        Lushnjë  Potchefstroom
#  1      88     1       869  Potchefstroom       Gustavia
#  2      88     2       869       Gustavia          Forio
#  3      88     3       869          Forio        Nalhāti
#  4      88     4       869        Nalhāti         Jetpur
#  5      88     5       869         Jetpur          Düzce
#  6      88     6       869          Düzce          Tampa
#  7      88     7       869          Tampa      Hitoyoshi
#
#                                                 Items
#  0  {Passionfruit-pulp, Hot-chocolate, Sweetcorn, ...
#  1  {Deep-fried, Low-fat-fresh-laban, Passionfruit...
#  2  {Low-fat-fresh-laban, Graines, Mineral-natural...
#  3  {Low-fat-fresh-laban, Mineral-natural-water, G...
#  4  {Low-fat-fresh-laban, Mineral-natural-water, G...
#  5  {Low-fat-fresh-laban, Mineral-natural-water, M...
#  6  {Low-fat-fresh-laban, Dried-sausages, Melange-...
#  7  {Fresh-pineapple, Dried-sausages, Seed-style-m...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      89     0       338              Horodok               Wakiso
#  1      89     1       338               Wakiso          Romainville
#  2      89     2       338          Romainville  Pallanza-Intra-Suna
#  3      89     3       338  Pallanza-Intra-Suna            Hitoyoshi
#  4      89     4       338            Hitoyoshi             Winnipeg
#  5      89     5       338             Winnipeg        Fontainebleau
#
#                                                 Items
#  0  {Raspberry-conserve, Cinnamon-roll, Liquid-hon...
#  1  {Grape-juice-drink, Raspberry-conserve, Cinnam...
#  2  {Grape-juice-drink, Chocolate-muffin, Producto...
#  3  {Chocolate-muffin, Productos-lacteos, Whole-be...
#  4  {Chocolate-muffin, Productos-lacteos, Liquid-h...
#  5  {Chocolate-muffin, Gluhwein, Senate-bean-soup,...  ,
#    RouteId Order TruckCode   StartCity           EndCity  \
#  0      90     0       355      Givors            Timaru
#  1      90     1       355      Timaru          Koksijde
#  2      90     2       355    Koksijde             Warri
#  3      90     3       355       Warri           Sedrata
#  4      90     4       355     Sedrata          Winnipeg
#  5      90     5       355    Winnipeg        Cristalina
#  6      90     6       355  Cristalina          Pruszków
#  7      90     7       355    Pruszków  Hódmezővásárhely
#
#                                                 Items
#  0  {Fajitas, Flavoured-cranberries, Toppings, Cho...
#  1  {Fajitas, Sandwich-spread, Toppings, Chorizos,...
#  2  {Fajitas, Sandwich-spread, Toppings, Graines, ...
#  3  {Coconut-waters, Sandwich-spread, Toppings, As...
#  4  {Coconut-waters, Toppings, Graines, Chorizos, ...
#  5  {Toppings, Miels, Asian-condiments, Chocolats,...
#  6  {Toppings, Asian-condiments, Chocolats, Kase, ...
#  7  {Whipping-fresh-cream, Chocolats, Cooking-choc...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      91     0       889         Aksu  Berkhamsted
#  1      91     1       889  Berkhamsted      Sedrata
#  2      91     2       889      Sedrata     Cibinong
#  3      91     3       889     Cibinong    Hitoyoshi
#  4      91     4       889    Hitoyoshi     Winnipeg
#  5      91     5       889     Winnipeg      Sadalgi
#  6      91     6       889      Sadalgi     Monteros
#
#                                                 Items
#  0  {Chicken-thighs, Organic-tomatoes, Maasdam-che...
#  1  {Olives, Choux-fleurs-en-fleurettes-surgeles, ...
#  2  {Choux-fleurs-en-fleurettes-surgeles, Chicken-...
#  3  {Choux-fleurs-en-fleurettes-surgeles, Maasdam-...
#  4  {Farina, Rice-wine, Gluhwein, Asparagus-tips, ...
#  5  {Chicken-powder, Honey-roasted-sliced-almonds,...
#  6  {Honey-roasted-sliced-almonds, Chicken-powder,...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      92     0       667     Cibinong  Berkhamsted
#  1      92     1       667  Berkhamsted    Winnenden
#  2      92     2       667    Winnenden    Laungowāl
#  3      92     3       667    Laungowāl    Hitoyoshi
#  4      92     4       667    Hitoyoshi      Nalhāti
#  5      92     5       667      Nalhāti        Tāoru
#  6      92     6       667        Tāoru  Minneapolis
#  7      92     7       667  Minneapolis        Belek
#
#                                                 Items
#  0  {Breakfasts, Asian-cooking, Nectar-de-pommes, ...
#  1  {Snacks, Carrot-cake, Kase, Chips, Products wi...
#  2  {Chicken-meat, Carrot-cake, Chocolate-trifle, ...
#  3  {Chicken-meat, Carrot-cake, Chocolate-trifle, ...
#  4  {Chicken-meat, Carrot-cake, Kase, Chips, Cured...
#  5  {Chicken-meat, Chips, Dried-spices, Whole-whea...
#  6  {Cured-sausage, Asian-cooking, Fresh-herbs, Ne...
#  7  {Gateau, Fresh-herbs, Grana-padano, Milkshake,...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      93     0       313          Sedrata         Winnipeg
#  1      93     1       313         Winnipeg            Khāpa
#  2      93     2       313            Khāpa  University City
#  3      93     3       313  University City          Hibbing
#  4      93     4       313          Hibbing     Bukit Rambai
#  5      93     5       313     Bukit Rambai     Ketanggungan
#  6      93     6       313     Ketanggungan            Annau
#  7      93     7       313            Annau        Hitoyoshi
#
#                                                 Items
#  0  {Chicken-powder, Condiment-en-poudre, Aperitif...
#  1  {Miels, Senate-bean-soup, Pork-ham, Aperitif, ...
#  2  {Miels, Senate-bean-soup, Cinamon-donuts, Chou...
#  3  {Miels, Cinamon-donuts, Senate-bean-soup, Chou...
#  4  {Miels, Cinamon-donuts, Choux-fleurs-en-fleure...
#  5  {Energy-ball, Croissant-with-cocoa-cream, Miel...
#  6  {Energy-ball, Croissant-with-cocoa-cream, Miel...
#  7  {Energy-ball, Croissant-with-cocoa-cream, Miel...  ,
#    RouteId Order TruckCode  StartCity     EndCity  \
#  0      94     0       579      Mosta       Khāpa
#  1      94     1       579      Khāpa      Timaru
#  2      94     2       579     Timaru   Hitoyoshi
#  3      94     3       579  Hitoyoshi      Kitami
#  4      94     4       579     Kitami  Batticaloa
#
#                                                 Items
#  0  {Savoy-cabbage, Assortiment-de-fromages, Trail...
#  1  {Deep-fried, Savoy-cabbage, Canned-crab-meat, ...
#  2  {Savoy-cabbage, Sandwich-spread, Canned-precoo...
#  3  {Fruits-en-conserve, Canned-precooked-meat, Ca...
#  4  {Dulces, Fruits-en-conserve, Canned-crab-meat,...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      95     0       539           Needham  Krasnoperekops’k
#  1      95     1       539  Krasnoperekops’k           Sedrata
#  2      95     2       539           Sedrata             Tampa
#  3      95     3       539             Tampa          Żoliborz
#  4      95     4       539          Żoliborz           Bilhaur
#  5      95     5       539           Bilhaur            Qaţanā
#  6      95     6       539            Qaţanā          Lakeland
#  7      95     7       539          Lakeland            Kloten
#
#                                                 Items
#  0  {Umbrichelli, Riz, Fresh-bread, Chicken-kebabs...
#  1  {Umbrichelli, Christmas-food, Riz, Fresh-bread...
#  2  {Umbrichelli, Christmas-food, Riz, Fresh-bread...
#  3  {Christmas-food, Kale, Specialite-a-tartiner, ...
#  4  {Sweetelle-tomatoes, Specialite-a-tartiner, As...
#  5  {Fresh-drinking-coconut, Christmas-food, Sweet...
#  6  {Pringles-potato-chips, Christmas-food, Fresh-...
#  7  {Pringles-potato-chips, Prosciutto, Specialite...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      96     0       384    Partūr    Timaru
#  1      96     1       384    Timaru    Kloten
#  2      96     2       384    Kloten  Monteros
#
#                                                 Items
#  0  {Cured-sausage, Chocolate-muffin, Chorizos, Cr...
#  1  {Prosciutto, Sandwich-spread, Gulab-jamun, Dri...
#  2  {Prosciutto, Gulab-jamun, Dried products, Meat...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      97     0       329            Givors        Lakshmīpur
#  1      97     1       329        Lakshmīpur         Ushirombo
#  2      97     2       329         Ushirombo          Lakeland
#  3      97     3       329          Lakeland  Hódmezővásárhely
#  4      97     4       329  Hódmezővásárhely        Novouzensk
#
#                                                 Items
#  0  {Flavoured-cranberries, Tarts, Canned-precooke...
#  1  {Pale-ale, Pain-pita-sucres, Noix-de-paprika, ...
#  2  {Fajitas, Mate, Pale-ale, Sushi, Frozen-vegeta...
#  3  {Prosciutto, Estragon, Mate, Pale-ale, Scotch-...
#  4  {Prosciutto, Pale-ale, Salad, Levures, Breakfa...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      98     0       867  Fontainebleau          Mūlki
#  1      98     1       867          Mūlki      Goyerkāta
#  2      98     2       867      Goyerkāta  Potchefstroom
#  3      98     3       867  Potchefstroom        Sedrata
#  4      98     4       867        Sedrata       Gustavia
#  5      98     5       867       Gustavia    Dharmanagar
#
#                                                 Items
#  0  {Minced-beef-steak, Getranke, Roma-tomatoes, V...
#  1  {Fajitas, Minced-beef-steak, Coffee-flavoured-...
#  2  {Fajitas, Sweetcorn-and-peas, Green-bean-salad...
#  3  {Fajitas, Deep-fried, Sweetcorn-and-peas, Gree...
#  4  {Absinth, Aliment-pour-chevaux, Green-bean-sal...
#  5  {Absinth, Mineral-natural-water, Green-bean-sa...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      99     0       404       Jalingo  Rājgurunagar
#  1      99     1       404  Rājgurunagar       Ifakara
#  2      99     2       404       Ifakara       Sedrata
#  3      99     3       404       Sedrata       Kushtia
#  4      99     4       404       Kushtia        Partūr
#  5      99     5       404        Partūr          Same
#  6      99     6       404          Same        Hirara
#
#                                                 Items
#  0  {Mixed-nuts, Smoked-mussels, Biryani, Beer-bat...
#  1  {Mixed-nuts, Smoked-mussels, Plats-prepares-su...
#  2  {Ice-tea, Fruit-confectionary, Plats-prepares-...
#  3  {Ice-tea, Fruit-confectionary, Beer-batter-fri...
#  4  {Ice-tea, Hot-dog-mustard, Fruit-confectionary...
#  5  {Ice-tea, Hot-dog-mustard, Pumpkin-seed-pecan,...
#  6  {Ice-tea, Grape-juice-drink, Plato-preparado-p...  ]

# %%
all_trips = pd.concat(trips)

# %%
all_trips.to_csv("route_trips.csv")
