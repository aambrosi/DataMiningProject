# %%
import pandas as pd
import numpy as np

# The dataset was created by using a food dataset and saved outside because the original dataset was huge (1GB).

product_list=pd.read_csv('categories.csv',delimiter=',',encoding='utf-8')
# I delete few strange strings
product_list = product_list.drop([123,157,440,442])

# %%
final_product_list = pd.DataFrame(product_list['Name'])
final_product_list['Popularity'] = np.random.random_sample(len(final_product_list))
final_product_list.reset_index(drop=True, inplace = True)
# Out:
# 1276

# %%
cities = pd.read_csv('world-cities.csv',delimiter=',',encoding='utf-8')

# %%
# Set the number of cities to 100
nCities = 100
cities = cities.sample(nCities)
cities.reset_index(drop=True, inplace = True)

# %%
city_list = pd.DataFrame(cities.name)
city_list.columns = ['Name']

# %%
city_list
# Out:
#                 Name
# 0             Timaru
# 1            Abū Tīj
# 2              Kogon
# 3          Goyerkāta
# 4          Millville
# 5             Kloten
# 6             Jetpur
# 7           Taşköprü
# 8              Warri
# 9            Kushtia
# 10  Krasnoperekops’k
# 11          Koksijde
# 12  Hódmezővásárhely
# 13           Bilhaur
# 14           Sadalgi
# 15          Winnipeg
# 16            Partūr
# 17         Fundación
# 18            Annino
# 19         Şanlıurfa
# 20             Khāpa
# 21         Ushirombo
# 22              Same
# 23           Needham
# 24             Mosta
# 25        Lakshmīpur
# 26     Chililabombwe
# 27            Panaji
# 28           Dixiana
# 29           Ifakara
# ..               ...
# 70             Belek
# 71           Nalhāti
# 72      Râs el Aïoun
# 73             Kunri
# 74           Horodok
# 75        Koprivnica
# 76      Rājgurunagar
# 77          Hajnówka
# 78       Romainville
# 79              Aksu
# 80      Ketanggungan
# 81             Kaédi
# 82            Kitami
# 83            Putian
# 84         Laungowāl
# 85             Tampa
# 86             Düzce
# 87     Pantai Cenang
# 88         Hitoyoshi
# 89           Lushnjë
# 90     Fontainebleau
# 91      Bukit Rambai
# 92           Sedrata
# 93            Hirara
# 94       Wernigerode
# 95             Mūlki
# 96        Manacapuru
# 97            Hotaka
# 98        Novouzensk
# 99          Cibinong
#
# [100 rows x 1 columns]

# %%
#city_list["Export"] = ""
#city_list["Import"] = ""

# %%
# range of exported and imported for each city setted respectively at 3:20 and 10:50
minExp = 5
maxExp = 40
minImp = 20
maxImp = 100
import time
# THIS PART CAN BE RUN IN PARALLEL (SPARK)
#start = time.time()
#for c in range(0,len(city_list)):
#    num_exp = np.random.randint(minExp,maxExp)
#    num_imp = np.random.randint(minImp,maxImp)
#    exp = np.unique(final_product_list.sample(num_exp, weights=final_product_list.Popularity).Name)
#    possible_imp_products = final_product_list[~final_product_list['Name'].isin(exp)]
#    imp = np.unique(possible_imp_products.sample(num_imp, weights=possible_imp_products.Popularity).Name)
#    city_list.loc[c,'Export'] = exp
#    city_list.loc[c,'Import'] = imp
#print(time.time()-start)

# %%
import bisect
class WeightedRandomGenerator(object):
    def __init__(self, weights):
        self.totals = []
        running_total = 0

        for w in weights:
            running_total += w
            self.totals.append(running_total)

    def next(self):
        rnd = random.random() * self.totals[-1]
        return bisect.bisect_right(self.totals, rnd)

    def __call__(self):
        return self.next()
    
def importExportGenerator():
    num_exp = np.random.randint(minExp,maxExp)
    num_imp = np.random.randint(minImp,maxImp)
    v = {}
    exp = []
    for ne in range(0, num_exp):
        rg = randomGenerator()
        rg = int(rg)
        rg = final_product_list.Name[rg]
        if(rg not in exp):
            exp.append(rg)
        else:
            ne -= 1
    imp = []
    for ni in range(0, num_imp):
        rg = randomGenerator()
        rg = int(rg)
        rg = final_product_list.Name[rg]
        if((rg not in imp) & (rg not in exp)):
            imp.append(rg)
        else:
            ni -= 1
    v['exp'] = exp
    v['imp'] = imp
    return v
    
start = time.time()
randomGenerator = WeightedRandomGenerator(final_product_list.Popularity)
values = [importExportGenerator() for i in range(0,len(city_list))]
a = [(value['exp'],value['imp']) for value in values]
exp = []
imp = []
for i in range(0,len(a)):
    exp.append(a[i][0])
    imp.append(a[i][1])
city_list['Export'] = exp
city_list['Import'] = imp
print(time.time()-start)
# Out:
# 0.14937329292297363

# %%
city_list
# Out:
#                 Name                                             Export  \
# 0             Timaru  [Baking, Kakaopulver, Minced-lamb, Taco-shells...
# 1            Abū Tīj  [Complements-alimentaires, Garlic-and-coriande...
# 2              Kogon  [Bhakarwadi, Caramel-popcorn, Palm-sugar, Suga...
# 3          Goyerkāta  [Sweetcorn-and-peas, Frozen-ice-creams, Chocol...
# 4          Millville  [Lasagnes-preparees, Juice-milk-drink, Peach-j...
# 5             Kloten  [Chicken-breast-fillets, Roma-tomatoes, Sweet-...
# 6             Jetpur  [Sugar-free-confectionary, Kakaopulver, Aoli-s...
# 7           Taşköprü  [Edible-decorations, Soup-mixes, Grape-juice-d...
# 8              Warri  [Agua, Mix, Peanut-in-chocolate, Multivitamin-...
# 9            Kushtia  [Mix, Rice-noodles, Frozen foods, Fresh-strawb...
# 10  Krasnoperekops’k  [Ricotta, Marfona-variety, Unsalted-butter, Ca...
# 11          Koksijde  [Plats-prepares-surgeles, Asian-food, Pralines...
# 12  Hódmezővásárhely  [Brick, Porc, Fromages, Chow-mein, Blueberry-m...
# 13           Bilhaur  [Foies-gras, Rice-cake, Kauwgom, Fresh foods, ...
# 14           Sadalgi  [Aliment-pour-chevaux, Cheese-crackers, Mozzar...
# 15          Winnipeg  [Octopus-balls, Chicken-pies, Genio-tomatoes, ...
# 16            Partūr  [Brick, Pumpkin-seed-pecan, Powder, Bruschetta...
# 17         Fundación  [Fresh-bread, Gluhwein, Viande, Liquid-honey, ...
# 18            Annino  [Topping, Caviars, Melange-d-epices-pour-guaca...
# 19         Şanlıurfa  [Glaces, Getrankeweisser, Peach-drink, Octopus...
# 20             Khāpa  [Linsen, Maris-piper-potatoes, Pitta-breads, M...
# 21         Ushirombo  [Frozen-petits-pois, Breakfast-biscuits, Produ...
# 22              Same  [Biscuits-au-chocolat-noir, Peaches-sliced-in-...
# 23           Needham  [Umbrichelli, Fresh-bread, Chicken-kebabs, Riz...
# 24             Mosta  [Whole-wheat-pita-bread, Penne, Capsicums, Fro...
# 25        Lakshmīpur  [Coconut-water, Frozen-sweetcorn, Cream-horser...
# 26     Chililabombwe  [Melange-d-epices-pour-guacamole, Muffin-mix, ...
# 27            Panaji  [Mix, Banana-flavour-mix-and-added-vitamins-an...
# 28           Dixiana  [Caramel-wafer-bars, Eaux-minerales, Dark-soy-...
# 29           Ifakara  [Precision-instruments, Fresh-lamb-meat, Tom-y...
# ..               ...                                                ...
# 70             Belek  [Wasabi-horseradish, Fish-can, Mackeral, Fresh...
# 71           Nalhāti  [Prawn-cocktail, Peach, Biscuits-au-chocolat, ...
# 72      Râs el Aïoun  [Chocolate-bunny, Easter-buns, Fresh-corn, Whi...
# 73             Kunri  [Wasabi-horseradish, Ribeye-steak, Boeuf-bourg...
# 74           Horodok  [Pizza dough, Cinnamon-roll, Crumpets, Gins, K...
# 75        Koprivnica  [Frozen-ice-cream, Baked-beans-in-tomato-sauce...
# 76      Rājgurunagar  [Kvarg, Pousses-de-bambou, Plats-prepares-surg...
# 77          Hajnówka  [Poivre-noir, Breaded products, Pitted-prunes,...
# 78       Romainville  [Dark-chocolate-block, Pitenza-tomatoes, Choco...
# 79              Aksu  [Canned-apricots, Peanut-in-chocolate, Blueber...
# 80      Ketanggungan  [Spearmint-sugarfree-gum, Iced-cookies, Chocol...
# 81             Kaédi  [Fromage-a-pate-dure, Pork-sausages, Dark-choc...
# 82            Kitami  [Chocolats-blancs, Crevettes, Soupes, Biere, G...
# 83            Putian  [Lemon-curd, Tuna-steak, Produits-laitiers, La...
# 84         Laungowāl  [Whole olives, Asian-condiments, Fish and meat...
# 85             Tampa  [Lamb-chops, Spam, Specialite-a-tartiner, Mayo...
# 86             Düzce  [Whole-chicken, Prawn-crackers, Spearmint-suga...
# 87     Pantai Cenang  [Earl-grey, Pies, Corn-tortilla-chips, Prunes,...
# 88         Hitoyoshi  [Reduced-fat-milks, Chilisauce, Sunflower-oil-...
# 89           Lushnjë  [Sweetcorn, Slaty-snack, Hot-chocolate, Granen...
# 90     Fontainebleau  [Fresh-cream, Curd-cheese, Canned-coconut-milk...
# 91      Bukit Rambai  [Sugary snacks, Crêpes and galettes, Fresh-cre...
# 92           Sedrata  [Frozen-ice-creams, Fruit-and-nut-mix, Frozen-...
# 93            Hirara  [Pork-ham, Fruits-frais, Chia-seeds, Bathroom,...
# 94       Wernigerode  [Edulcorant-avec-fruit-des-moines, Hot-chocola...
# 95             Mūlki  [Getrankeweisser, Fajitas, Spring-roll-pastry,...
# 96        Manacapuru  [Breakfast-granola, Vinaigres, Caramelized-red...
# 97            Hotaka  [Peeled-plum-tomatoes, Chorizos, Blue-cheese-y...
# 98        Novouzensk  [Protein, Dried-sausages, White-pitta-bread, A...
# 99          Cibinong  [Nectar-de-pommes, Asian-cooking, Breakfasts, ...
#
#                                                Import
# 0   [Dry-meat, Whole-wheat-beard, Apple-pear-juice...
# 1   [Seed-style-mustard, Yellow-mustard, Strawberr...
# 2   [Haferflocken, Yellow-peaches, Fresh-cakes, So...
# 3   [Fresh-cucumbers, Macaroni-cheese, Frozen-dump...
# 4   [Chili-con-carne, Spice-red-pepper, Double-cho...
# 5   [Whole-wheat-penne-rigate, Poivre-noir, Corn-t...
# 6   [Blueberry-syrup, Nans, Canned-mussels, Choux-...
# 7   [Sandwich-spread, Biscuits-with-dark-chocolate...
# 8   [Chicken-fillet-burger, Miels, Confitures-de-f...
# 9   [Stilton, Strawberry-trifle, Gulab-jamun, Tint...
# 10  [Melange-d-epices-pour-guacamole, Sugarsnap-pe...
# 11  [Dark-chocolate-block, Cold-meats, Cream-of-ta...
# 12  [Mineral-natural-water, Dried-spices, Kale-sal...
# 13  [Sweetcorn-relish, Capers, Schmelzkase, Sweet-...
# 14  [Whole-wheat-beard, Cured-sausage, Maris-piper...
# 15  [Artichauts-en-conserve, Fajitas, Chocolate-bu...
# 16  [Roasted-and-ground-coffee, Olives, Lamb-chops...
# 17  [Green-kale, Caramel-wafer-bars, Mango-drink, ...
# 18  [Pastry-dough, Snack-mix, Maple-butter, Dried ...
# 19  [Groceries, Licensed products, Vins-rouges, Mu...
# 20  [Frozen-bread, Fruit-juice-drink, Lager-beer, ...
# 21  [Schmelzkase, Fresh-brown-onions, Pancake-syru...
# 22  [Haferflocken, Beef-jerky, Tomato-chilli-relis...
# 23  [Hoki-fish-fillets, Almond-powder, Dilute-drin...
# 24  [Productos-lacteos, Sucre, Gourmet-pie, Fruit-...
# 25  [Canneloni, Dehydrated-mulberries, Whole-wheat...
# 26  [Fresh-pineapple, Dill-sauce, Dry-meat, Creme-...
# 27  [Instant-porridge, Chocolate-mousse, Flavoured...
# 28  [Cottage-cheeses, Gnocchi, Reduced-fat-milks, ...
# 29  [Sliced-jalapenos, Wortelsappen, Pralinen, Spa...
# ..                                                ...
# 70  [Nane-limon, Coca-sandwich-biscuits, Brownie, ...
# 71  [Moussakas, Trail-mix, Dill-sauce, Reduced-fat...
# 72  [Whole-wheat-penne-rigate, Ratatouille, Seafoo...
# 73  [Feuille-de-vigne, Lait, Muffin-mix, Fromage-a...
# 74  [Caramel-popcorn, Smoked-mussels, Genoa-salami...
# 75  [Chicken-pies, Sundried-tomatoes, Kase, Fresh-...
# 76  [White-coconut-chocolate, Two-crust Pies, Ghee...
# 77  [Cooked-vegetables, Freeze-dried foods, Garlic...
# 78  [Ricotta, Flour-tortillas, Oreo, Linsen, Meat-...
# 79  [Minced-beef-steak, Sweetcorn-and-peas, White-...
# 80  [Snack-mix, Liquid-honey, Rye-pale-ale, Coq-au...
# 81  [Still-water, Fish-sauce, Dumplings, Cardamom-...
# 82  [Prosciutto, Gulab-jamun, Pate, Orange-cake, B...
# 83  [Roast-ham, Frucht-und-gemusebasierte-lebensmi...
# 84  [Pies, Nutella-biscuits, Cukor, Hoisin-sauce, ...
# 85  [Melange-d-epices-pour-guacamole, Tee, Mackere...
# 86  [Frozen-pork-buns, Plats-prepares, Vanilla-waf...
# 87  [Vegetarian-mock-meat, Pure-cod-liver-oil, Cre...
# 88  [Horseradish-sauce, Chocolate-covered-muesli-b...
# 89  [Juice, Mint-jelly, Nectar-de-pommes, Malt-dri...
# 90  [Cottage-cheeses, Roquefort-cheese, Ribbon-noo...
# 91  [Spreads, Feuilletes-chevre-epinards, Pitted-p...
# 92  [Kidney-beans, Stringless-beans, White-pitta-b...
# 93  [Jelly-crystals, Umbrichelli, Blended-scotch-w...
# 94  [Specialite-a-tartiner, Mixed-chillies, Pierog...
# 95  [Fromage-a-pate-dure, Flavoured-mineral-water-...
# 96  [Cured-sausage, Faux-fromage, Rice-crackers, D...
# 97  [Coffee-flavoured-milk, Rye-pale-ale, Snack, B...
# 98  [Mini-portobello-mushrooms, Estragon, Bottled-...
# 99  [Fresh-cabbage, Penne, Piccolo-tomatoes, Smoke...
#
# [100 rows x 3 columns]

# %%
def standard_info(i, rid, tcd, trip, final_trip):
    final_trip.loc[i, 'RouteId'] = rid
    final_trip.loc[i, 'Order'] = i
    final_trip.loc[i, 'TruckCode'] = tcd
    final_trip.loc[i, 'StartCity'] = trip.loc[i,'IdCity']
    final_trip.loc[i, 'EndCity'] = trip.loc[i+1,'IdCity']

def first_step_creation(rid, tcd, length, trip):
    final_trip = pd.DataFrame(columns=['RouteId', 'Order', 'TruckCode', 'StartCity','EndCity', 'Items'])
    standard_info(0, rid, tcd, trip, final_trip)
    maxProbItems = list(set(trip.loc[length-1, "PopularImport"]).intersection(trip.loc[length-2, "ExportableItems"]))
    maxProbItems = maxProbItems * 5
    trip.loc[length-2, "ExportableItems"].extend(maxProbItems)
    # I set the range to be not fixed to 5-20 for the first trip cities that have few exportable items and I set
    # them to half to all the possible exportable items
    numItems = np.random.randint(min(5,len(trip.loc[length-2, "ExportableItems"])/2), min(15,len(trip.loc[length-2, "ExportableItems"])))
    sample = set(random.sample(trip.loc[length-2, "ExportableItems"], numItems))
    final_trip.loc[length-2, 'Items'] = sample
    return final_trip
    
def trip_creation(i, rid, tcd, length, trip, final_trip):
    standard_info(i-1, rid, tcd, trip, final_trip)
    crev = length - i - 1
    possibleExports = list(final_trip.loc[crev+1, 'Items'])
    itemsToDelete = set(possibleExports).intersection(list(city_list.loc[list(city_list.Name).index(trip.loc[crev+1, 'IdCity']), 'Export']))
    for i in itemsToDelete:
        possibleExports.remove(i)
    numItems = np.random.randint(0, min(15,len(trip.loc[crev, "ExportableItems"])))
    sample = set(random.sample(trip.loc[crev, "ExportableItems"], numItems))
    final_trip.loc[crev, 'Items'] = set(possibleExports).union(sample)
    return final_trip

# %%
# range of trip length setted at 3:15. We set the number of trucks to 10000
minLen = 3
maxLen = 10
numTruck = 1000
import random
def generate_trip(i):
    length = np.random.randint(minLen, maxLen)
    trip = pd.DataFrame(columns=['IdCity','ExportableItems', 'PopularImport'])
    items = []
    for c in range(0,length):
        city = np.random.randint(0,len(city_list))
        trip.loc[c, 'IdCity'] = city_list.loc[city,'Name']
        items.extend(city_list.loc[city,'Export'])
        trip.loc[c, 'ExportableItems'] = items.copy()
        trip.loc[c, 'PopularImport'] = city_list.loc[city,'Import']
    rid = i
    tcd = np.random.randint(0,numTruck)
    final_trip = first_step_creation(rid, tcd, length, trip)
    for c in range(2,length):
        final_trip = trip_creation(c, rid, tcd, length, trip, final_trip)
    final_trip = final_trip.sort_values('Order')
    return final_trip

# %%
def generate_trips(num):
    trips = [generate_trip(i) for i in range(0,num)]
    return trips

# %%
numberOfTrips = 100
trips = generate_trips(numberOfTrips)

# %%
trips
# Out:
# [  RouteId Order TruckCode         StartCity       EndCity  \
#  0       0     0       333  Krasnoperekops’k         Tāoru
#  1       0     1       333             Tāoru  Ketanggungan
#  2       0     2       333      Ketanggungan     Goyerkāta
#  3       0     3       333         Goyerkāta        Givors
#
#                                                 Items
#  0  {Sweetcorn-and-peas, Muffin-mix, Marfona-varie...
#  1  {Almond-powder, Cukor, Ghee, Vegetable-fat-spr...
#  2  {Almond-powder, Ghee, Canned-crab-meat, Farmin...
#  3  {Almond-powder, Chocolate-coins, Kruidentheeen...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0       1     0       473      Jalingo  Minneapolis
#  1       1     1       473  Minneapolis       Cuiabá
#  2       1     2       473       Cuiabá       Berlin
#  3       1     3       473       Berlin      Ifakara
#  4       1     4       473      Ifakara       Cuiabá
#  5       1     5       473       Cuiabá       Kanuma
#
#                                                 Items
#  0  {Milk-chocolate-filled-with-caramel, Mixed-nut...
#  1  {Orange-juice-from-concentrate, Tartar-sauce, ...
#  2  {Orange-juice-from-concentrate, Tartar-sauce, ...
#  3  {Milch, Topping, Tartar-sauce, Aloe-vera-drink...
#  4  {Milch, Salty snacks, Fruit-spread, Canned-mus...
#  5  {Soupes, Frozen-asian-vegetables, Pear-cider, ...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0       2     0       546    Manacapuru    Lakshmīpur
#  1       2     1       546    Lakshmīpur  Rājgurunagar
#  2       2     2       546  Rājgurunagar     Ushirombo
#  3       2     3       546     Ushirombo   Minneapolis
#
#                                                 Items
#  0  {Lingonberry-jams, Breakfasts, Chocolate-coins...
#  1  {Pear-cider, Groceries, Chicken-powder, Trimme...
#  2  {Pear-cider, Groceries, Chicken-powder, Trimme...
#  3  {Pear-cider, Groceries, Chicken-powder, Trimme...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0       3     0       754   Bukit Rambai        Sadalgi
#  1       3     1       754        Sadalgi       Żoliborz
#  2       3     2       754       Żoliborz      Fundación
#  3       3     3       754      Fundación  Zheleznogorsk
#  4       3     4       754  Zheleznogorsk         Annino
#
#                                                 Items
#  0  {Energy-ball, Croissant-with-cocoa-cream, Suga...
#  1  {Low-fat-fresh-laban, Croissant-with-cocoa-cre...
#  2  {Sugary snacks, Instant-porridge, Fish-can, Go...
#  3  {Sugary snacks, Instant-porridge, Fish-can, Go...
#  4  {Sugary snacks, Fish-can, Instant-porridge, Go...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0       4     0       937  Cristalina     Sedrata
#  1       4     1       937     Sedrata       Tampa
#  2       4     2       937       Tampa  Manacapuru
#  3       4     3       937  Manacapuru      Cuiabá
#
#                                                 Items
#  0  {Coconut-waters, Cayenne-pepper-sauce, Frozen-...
#  1  {Coconut-waters, Cardamom-pods, Penne, Wasabi-...
#  2  {Coconut-waters, Specialite-a-tartiner, Wasabi...
#  3  {Vegetarian-chicken-fillets, Wasabi-popcorn, D...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0       5     0       908   Chililabombwe         Nalhāti
#  1       5     1       908         Nalhāti         Dixiana
#  2       5     2       908         Dixiana  Puerto La Cruz
#  3       5     3       908  Puerto La Cruz         Vichuga
#
#                                                 Items
#  0  {Fresh-garlic, Cold-meats, Bottled-water, Feui...
#  1  {Deep-fried, Fresh-coconut, Gateau, Bottled-wa...
#  2  {Fresh-coconut, Gateau, Fresh-garlic, Foies-gr...
#  3  {Gateau, Fresh-garlic, Apple-cider, Bottled-wa...  ,
#    RouteId Order TruckCode StartCity      EndCity  \
#  0       6     0       202   Lushnjë     Koch'ang
#  1       6     1       202  Koch'ang       Hirara
#  2       6     2       202    Hirara  Berkhamsted
#
#                                                 Items
#  0                  {Sweetcorn, Granen-en-aardappels}
#  1  {Ribbon-noodles, Sweetcorn, Manuka-honey, Sunf...
#  2  {Coconut-flour, Sunflower-oil-spread, Pork-ham...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0       7     0       753      Kunri    Vichuga
#  1       7     1       753    Vichuga    Jalingo
#  2       7     2       753    Jalingo  Gharaunda
#  3       7     3       753  Gharaunda     Jetpur
#
#                                                 Items
#  0  {Croissant-with-cocoa-cream, Senate-bean-soup,...
#  1  {Croissant-with-cocoa-cream, Jus-d-orange, Fre...
#  2  {Bruschetta, Croissant-with-cocoa-cream, Jus-d...
#  3  {Asperges-en-conserve, Croissant-with-cocoa-cr...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0       8     0       492      Ifakara  Vostryakovo
#  1       8     1       492  Vostryakovo    Winnenden
#  2       8     2       492    Winnenden        Kogon
#  3       8     3       492        Kogon        Kogon
#
#                                                 Items
#  0  {Ice-tea, Fruit-confectionary, Precision-instr...
#  1  {Frucht-und-gemusebasierte-lebensmittel, Vlees...
#  2  {Chicken-meat, Pastrami, Biryani, Precision-in...
#  3  {Sucres, Churned-cream, Precision-instruments,...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0       9     0       131         Rājgurunagar  Pallanza-Intra-Suna
#  1       9     1       131  Pallanza-Intra-Suna                Tāoru
#  2       9     2       131                Tāoru              Horodok
#  3       9     3       131              Horodok                Kogon
#  4       9     4       131                Kogon          Bad Arolsen
#  5       9     5       131          Bad Arolsen                Annau
#  6       9     6       131                Annau               Kanuma
#  7       9     7       131               Kanuma               Givors
#
#                                                 Items
#  0  {Kvarg, Pousses-de-bambou, Plats-prepares-surg...
#  1  {Bonbons-a-la-menthe, Plats-prepares-surgeles,...
#  2  {Almond-powder, Asian-cooking, Green olives, K...
#  3  {Almond-powder, Asian-cooking, Green olives, K...
#  4  {Almond-powder, Asian-cooking, Green olives, K...
#  5  {Almond-powder, Asian-cooking, Green olives, K...
#  6  {Asian-cooking, Green olives, Kauwgom, Melk, C...
#  7  {Energy-balls, Chilli-con-carne-sauce, Coconut...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      10     0       808     Cristalina       Taşköprü
#  1      10     1       808       Taşköprü    Dharmanagar
#  2      10     2       808    Dharmanagar      Winnenden
#  3      10     3       808      Winnenden          Kogon
#  4      10     4       808          Kogon  Pantai Cenang
#  5      10     5       808  Pantai Cenang      Southaven
#  6      10     6       808      Southaven     Manacapuru
#  7      10     7       808     Manacapuru         Berlin
#
#                                                 Items
#  0  {Cayenne-pepper-sauce, Coconut-waters, Almond-...
#  1  {Semolina, Frozen-prawn-cutlets, Semoules-de-b...
#  2  {Semolina, Surgelati, Semoules-de-ble-dur-pour...
#  3  {Semolina, Chicken-meat, Chocolate-trifle, Sur...
#  4  {Chicken-meat, Chocolate-trifle, Semoules-de-b...
#  5  {Chicken-meat, Chocolate-trifle, Semoules-de-b...
#  6  {Food additives, Chocolate-trifle, Gratins-de-...
#  7  {Food additives, Chocolate-trifle, Gateau-chin...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      11     0       335          Khāpa  Potchefstroom
#  1      11     1       335  Potchefstroom   Râs el Aïoun
#  2      11     2       335   Râs el Aïoun        Hibbing
#  3      11     3       335        Hibbing      Fundación
#  4      11     4       335      Fundación    Wernigerode
#
#                                                 Items
#  0  {Pralines, Smoked-haddock, Pitta-breads, Smoke...
#  1  {Smoked-haddock, Pitta-breads, Pizza-bases, Na...
#  2  {Pitta-breads, Smoked-haddock, Chocolate-mints...
#  3  {Fresh-corn, Pizza-bases, Sandwich, Chocolate-...
#  4  {Feta-cheese, Chocolate-mints, Pizza dough, Ap...  ,
#    RouteId Order TruckCode      StartCity    EndCity  \
#  0      12     0       390  Potchefstroom     Jetpur
#  1      12     1       390         Jetpur      Belek
#  2      12     2       390          Belek    Ifakara
#  3      12     3       390        Ifakara  Winnenden
#
#                                                 Items
#  0  {Low-fat-fresh-laban, Chocolats, Apricot-conse...
#  1  {Sugar-free-confectionary, Aoli-sauce, Chocola...
#  2  {Fish-can, Aoli-sauce, Chocolats, Maasdam-chee...
#  3  {Farina, Tom-yum-soup, Absinth, Aoli-sauce, Me...  ,
#    RouteId Order TruckCode  StartCity        EndCity  \
#  0      13     0       928  Millville          Düzce
#  1      13     1       928      Düzce  Fontainebleau
#
#                                                 Items
#  0  {Lasagnes-preparees, Minestrone, Frozen-apple-...
#  1  {Marshmallow-creme, Lasagnes-preparees, Minest...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      14     0       359         Annau    Batticaloa
#  1      14     1       359    Batticaloa  Rio de Mouro
#  2      14     2       359  Rio de Mouro   Romainville
#  3      14     3       359   Romainville        Pájara
#  4      14     4       359        Pájara       Nalhāti
#  5      14     5       359       Nalhāti       Sedrata
#  6      14     6       359       Sedrata     Ushirombo
#
#                                                 Items
#  0  {Fresh-apples, Food additives, Remoulade, Birt...
#  1  {Farina, Kale, Food additives, Chicken-burgers...
#  2  {Birthday-cake, Tuna-steak, Mango, Drinking-ch...
#  3  {Productos-lacteos, Birthday-cake, Kase, Tuna-...
#  4  {Productos-lacteos, Basa-fish, Beers-from-stra...
#  5  {Productos-lacteos, Basa-fish, Frozen-peas, Sw...
#  6  {Chicken-powder, Sweetcorn, Charcuteries, Fres...  ,
#    RouteId Order TruckCode   StartCity   EndCity  \
#  0      15     0       405  Koprivnica  Pruszków
#  1      15     1       405    Pruszków  Lakeland
#  2      15     2       405    Lakeland     Mosta
#
#                                                 Items
#  0  {Gluhwein, Porridge-oats, Peanut-butter-cup, V...
#  1  {Peanut-butter-cup, Viande, Readymeals, Pork-c...
#  2  {Peanut-butter-cup, Mix, Frozen-baby-octopus, ...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      16     0       961           Ifakara      Râs el Aïoun
#  1      16     1       961      Râs el Aïoun         Ushirombo
#  2      16     2       961         Ushirombo            Kitami
#  3      16     3       961            Kitami             Annau
#  4      16     4       961             Annau  Hódmezővásárhely
#  5      16     5       961  Hódmezővásárhely          Pruszków
#
#                                                 Items
#  0  {Tom-yum-soup, Brie-cheese, Fruit-confectionar...
#  1  {Tom-yum-soup, Brie-cheese, Fruit-confectionar...
#  2  {Mate, Fruit-confectionary, Chocolate-mints, M...
#  3  {Soupes, Mate, Fruit-confectionary, Chocolate-...
#  4  {Tom-yum-soup, Mate, Soupes, Energy-balls, Fru...
#  5  {Tom-yum-soup, Mate, Soupes, Chicken-thighs-fi...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      17     0        93  Wernigerode     Lakeland
#  1      17     1        93     Lakeland  Bad Arolsen
#  2      17     2        93  Bad Arolsen        Warri
#  3      17     3        93        Warri      Bilhaur
#  4      17     4        93      Bilhaur      Abū Tīj
#  5      17     5        93      Abū Tīj     Gustavia
#  6      17     6        93     Gustavia    Goyerkāta
#
#                                                 Items
#  0  {Carots, Taco-shells, Fruit-and-nut-mix, Lamb-...
#  1  {Wholefood, Crêpes and galettes, Tuna-steak, L...
#  2  {Wholefood, Crêpes and galettes, Frozen-chicke...
#  3  {Wholefood, Frozen-chicken, Tuna-steak, Fruit-...
#  4  {Wholefood, Fresh-drinking-coconut, Estragon, ...
#  5  {Fresh-drinking-coconut, Fruit-salad-in-juice,...
#  6  {Fruit-salad-in-juice, Honey-ham, Tuna-steak, ...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      18     0       217      Lushnjë        Belek
#  1      18     1       217        Belek      Kushtia
#  2      18     2       217      Kushtia  Dharmanagar
#  3      18     3       217  Dharmanagar    Ushirombo
#
#                                                 Items
#  0  {Passionfruit-pulp, Musliriegel, Hot-chocolate...
#  1  {Passionfruit-pulp, Maasdam-cheese, Mackeral, ...
#  2  {Fresh-coconut, Basa-fish, Plaice, Hot-chocola...
#  3  {Fresh-coconut, Surgelati, Gateau-chinois, Maa...  ,
#    RouteId Order TruckCode StartCity        EndCity  \
#  0      19     0       219     Annau        Ifakara
#  1      19     1       219   Ifakara        Hibbing
#  2      19     2       219   Hibbing         Putian
#  3      19     3       219    Putian         Kitami
#  4      19     4       219    Kitami  Chililabombwe
#
#                                                 Items
#  0  {Fresh-apples, Food additives, Remoulade, Birt...
#  1  {Tom-yum-soup, Food additives, Brie-cheese, Fr...
#  2  {Corn-thins, Tom-yum-soup, Food additives, Bri...
#  3  {Corn-thins, Food additives, Lemon-curd, Poppi...
#  4  {Food additives, Popping-corn, Fruit-confectio...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      20     0       741        Hotaka  Ketanggungan
#  1      20     1       741  Ketanggungan       Jalingo
#  2      20     2       741       Jalingo     Southaven
#  3      20     3       741     Southaven      Winnipeg
#  4      20     4       741      Winnipeg  Ketanggungan
#
#                                                 Items
#  0  {Flavoured-cranberries, Productos-lacteos, Pat...
#  1  {Flavoured-cranberries, Pate-feuilletee, Produ...
#  2  {Pate-feuilletee, Farming products, Orange-jui...
#  3  {Pralines, Riz, Food additives, Pate-feuillete...
#  4  {Pate-feuilletee, Pitted-prunes, Orange-juice-...  ,
#    RouteId Order TruckCode StartCity      EndCity  \
#  0      21     0        43   Vichuga        Kaédi
#  1      21     1        43     Kaédi  Bad Arolsen
#
#                                                 Items
#  0  {Jus-d-orange, Fruit-salad-in-juice, Marshmall...
#  1  {Fruit-salad-in-juice, Brassica, Canned-oyster...  ,
#    RouteId Order TruckCode     StartCity     EndCity  \
#  0      22     0       970  Ketanggungan      Haldia
#  1      22     1       970        Haldia    Winnipeg
#  2      22     2       970      Winnipeg  Cristalina
#
#                                                 Items
#  0  {Cornish-pasties, Green-bean-salad, Canned-cra...
#  1  {Cured-sausage, Soupes, Graines, Canned-crab-m...
#  2  {Cured-sausage, Graines, Honey-roasted-sliced-...  ,
#    RouteId Order TruckCode StartCity      EndCity  \
#  0      23     0       168   Kālāvad     Cibinong
#  1      23     1       168  Cibinong       Hotaka
#  2      23     2       168    Hotaka      Jalingo
#  3      23     3       168   Jalingo  Bad Arolsen
#
#                                                 Items
#  0  {Bitters, Juice-from-concentrate, Premium-and-...
#  1  {Bitters, Breakfasts, Juice-from-concentrate, ...
#  2  {Vanilla-waffles, Bitters, Productos-lacteos, ...
#  3  {Vanilla-waffles, Productos-lacteos, Hidden-va...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      24     0       772    Timaru  Hajnówka
#  1      24     1       772  Hajnówka    Wakiso
#
#                                                 Items
#  0  {Kakaopulver, Prosciutto, Smoked-mussels, Gins...
#  1  {Chicken-meat, Coffee-ice-cream, Beers-from-st...  ,
#    RouteId Order TruckCode     StartCity     EndCity  \
#  0      25     0       980  Ketanggungan  Novouzensk
#  1      25     1       980    Novouzensk      Abaeté
#  2      25     2       980        Abaeté      Berlin
#  3      25     3       980        Berlin      Timaru
#  4      25     4       980        Timaru     Hibbing
#  5      25     5       980       Hibbing       Tāoru
#  6      25     6       980         Tāoru    Żoliborz
#
#                                                 Items
#  0  {Cornish-pasties, Green-bean-salad, Canned-cra...
#  1  {Frozen-battered-fish, Energy-ball, Cornish-pa...
#  2  {Energy-ball, Cornish-pasties, Green-bean-sala...
#  3  {Cornish-pasties, Green-bean-salad, Canned-cra...
#  4  {Green-bean-salad, Asian-condiments, Chocolate...
#  5  {Canned-crab-meat, Gulab-jamun, Chocolate-mint...
#  6  {Ghee, Canned-crab-meat, Rice-crackers, Vegeta...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      26     0       750       Kogon  Lakshmīpur
#  1      26     1       750  Lakshmīpur   Guarabira
#  2      26     2       750   Guarabira     Needham
#  3      26     3       750     Needham    Taşköprü
#  4      26     4       750    Taşköprü      Kloten
#  5      26     5       750      Kloten    Gustavia
#
#                                                 Items
#  0  {Cactus, Sucres, Nectar-de-pommes, Orange-juic...
#  1  {Cactus, Orange-juice-from-concentrate, Likor,...
#  2  {Cactus, Klebreiskuchen, Natural-spring-water,...
#  3  {Cactus, Klebreiskuchen, Natural-spring-water,...
#  4  {Coffee-ice-cream, Senate-bean-soup, Natural-s...
#  5  {Frozen-ice-creams, Pineapple-slices-in-juice,...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      27     0       869            Annino           Vichuga
#  1      27     1       869           Vichuga     Fontainebleau
#  2      27     2       869     Fontainebleau             Düzce
#  3      27     3       869             Düzce  Hódmezővásárhely
#  4      27     4       869  Hódmezővásárhely         Guarabira
#  5      27     5       869         Guarabira           Abū Tīj
#  6      27     6       869           Abū Tīj      Rājgurunagar
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
#  1          {Rice-crackers, Samosas, English-mustard}
#  2  {Topping, Samosas, Rice-crackers, Canned-cocon...
#  3  {Topping, Dried-sausages, Red-seedless-grapes,...
#  4  {Topping, Salads, Marshmallow-creme, Salad, Re...
#  5  {Topping, Red-seedless-grapes, Salad, Marshmal...
#  6  {Rice-crackers, Chicken-thighs-fillets, Whole-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      28     0       211   Hitoyoshi  Novouzensk
#  1      28     1       211  Novouzensk       Forio
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
#  1  {Energy-ball, Graines, Sunflower-oil-spread, D...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      29     0       738  Krasnoperekops’k  Krasnoperekops’k
#  1      29     1       738  Krasnoperekops’k             Khāpa
#  2      29     2       738             Khāpa       Wernigerode
#  3      29     3       738       Wernigerode      Ketanggungan
#  4      29     4       738      Ketanggungan          Żoliborz
#  5      29     5       738          Żoliborz           Sadalgi
#
#                                                 Items
#  0  {Christmas-food, Muffin-mix, Capers, Macaroni,...
#  1  {Christmas-food, Muffin-mix, Macaroni, Grana-p...
#  2  {Cinamon-donuts, Cremes-desserts, Natural-yogh...
#  3  {Smoked-haddock, Christmas-food, Cinamon-donut...
#  4  {Smoked-haddock, Christmas-food, Cinamon-donut...
#  5  {Taco-shells, Macaroni, Cremes-desserts, Fruit...  ,
#    RouteId Order TruckCode    StartCity     EndCity  \
#  0      30     0       974  Vostryakovo      Kitami
#  1      30     1       974       Kitami  Batticaloa
#
#                                                 Items
#  0  {Cold-meats, Pasteurized-milk, Fruit-confectio...
#  1  {Fruit-confectionary, Cream-of-tartar, Cold-me...  ,
#    RouteId Order TruckCode      StartCity     EndCity  \
#  0      31     0       618  Fontainebleau  Cristalina
#  1      31     1       618     Cristalina    Koksijde
#  2      31     2       618       Koksijde   Gharaunda
#
#                                                 Items
#  0  {Cookies-chocolate, Absinth, Quiches-lorraines...
#  1  {Fruit-bread, Bee products, Groceries, Chocola...
#  2  {Groceries, Liquid-honey, Magarines, Bee produ...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      32     0       125          Kitami  Puerto La Cruz
#  1      32     1       125  Puerto La Cruz          Kitami
#  2      32     2       125          Kitami      Batticaloa
#  3      32     3       125      Batticaloa         Abū Tīj
#  4      32     4       125         Abū Tīj         Dixiana
#
#                                                 Items
#  0                                 {Chocolats-blancs}
#  1  {Chocolats-blancs, Melk, Purified-water, Flavo...
#  2     {Flavoured-rice-cakes, Chocolats-blancs, Melk}
#  3  {Purple-sprouting-broccoli, Chocolats-blancs, ...
#  4  {Purple-sprouting-broccoli, Chicken-burgers, C...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      33     0       584             Annau  Krasnoperekops’k
#  1      33     1       584  Krasnoperekops’k            Kloten
#  2      33     2       584            Kloten         Şanlıurfa
#  3      33     3       584         Şanlıurfa        Koprivnica
#
#                                                 Items
#  0                                    {Birthday-cake}
#  1  {Birthday-cake, Macaroni, Italian-sausages, Po...
#  2  {Luice, Unsalted-butter, Birthday-cake, Meat-p...
#  3  {Birthday-cake, Meat-pies, Octopus-balls, Ital...  ,
#    RouteId Order TruckCode      StartCity    EndCity  \
#  0      34     0       289  Zheleznogorsk  Şanlıurfa
#  1      34     1       289      Şanlıurfa     Hirara
#
#                                                 Items
#  0  {Seed-style-mustard, Cosmetics, Pasteurized-mi...
#  1  {Fats, Aliment-pour-chevaux, Seed-style-mustar...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      35     0       753      Cibinong      Koksijde
#  1      35     1       753      Koksijde       Sedrata
#  2      35     2       753       Sedrata  Râs el Aïoun
#  3      35     3       753  Râs el Aïoun       Jalingo
#  4      35     4       753       Jalingo         Forio
#
#                                                 Items
#  0  {Farina, Breakfasts, Asian-cooking, Eau-de-vie...
#  1  {Graines, Asian-cooking, Breakfasts, Plats-pre...
#  2  {Graines, Aliment-pour-chevaux, Plats-prepares...
#  3  {Dolminades, Graines, Aliment-pour-chevaux, Bi...
#  4  {Mixed-nuts, Smoked-mussels, Raisin-bread, Bur...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      36     0       260           Lushnjë           Ifakara
#  1      36     1       260           Ifakara  Hódmezővásárhely
#  2      36     2       260  Hódmezővásárhely            Timaru
#  3      36     3       260            Timaru       Bad Arolsen
#  4      36     4       260       Bad Arolsen            Hotaka
#  5      36     5       260            Hotaka          Pruszków
#
#                                                 Items
#  0              {Sweetcorn, Musliriegel, Slaty-snack}
#  1  {Ice-tea, Tom-yum-soup, Brie-cheese, Fruit-con...
#  2  {Ice-tea, Chocolate-muffin, Gateau, Spaghetti-...
#  3  {Chocolate-muffin, Gateau, Smoked-mussels, Spa...
#  4  {Chocolate-muffin, Gateau, Smoked-mussels, Spa...
#  5  {Chocolate-muffin, Pate-feuilletee, Hidden-val...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      37     0        28     Partūr     Haldia
#  1      37     1        28     Haldia  Hitoyoshi
#  2      37     2        28  Hitoyoshi     Givors
#  3      37     3        28     Givors      Belek
#  4      37     4        28      Belek    Sadalgi
#
#                                                 Items
#  0  {Vanilla-soymilk, Pumpkin-seed-pecan, Nutella-...
#  1  {Soupes, Pumpkin-seed-pecan, Graines, Green-be...
#  2  {Bruschetta, Pumpkin-seed-pecan, Green-bean-sa...
#  3  {Pumpkin-seed-pecan, Green-bean-salad, Asian-c...
#  4  {Pumpkin-seed-pecan, Green-bean-salad, Asian-c...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      38     0       354    Bad Arolsen  Fontainebleau
#  1      38     1       354  Fontainebleau          Annau
#  2      38     2       354          Annau           Aksu
#
#                                                 Items
#  0  {Canned-oysters, Berry-mueslis, Cream-of-tarta...
#  1  {Cookies-chocolate, Cocktail-sauces, Quiches-l...
#  2  {Food additives, Quiches-lorraines, Biscuits-a...  ,
#    RouteId Order TruckCode    StartCity EndCity  \
#  0      39     0       173  Vostryakovo   Mūlki
#  1      39     1       173        Mūlki   Tāoru
#
#                                                 Items
#  0  {Pasteurized-milk, Fruit-confectionary, Biryan...
#  1  {Fajitas, Biryani, Chocolate-ice-cream, Cold-m...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      40     0       781       Koch'ang       Winnipeg
#  1      40     1       781       Winnipeg  Chililabombwe
#  2      40     2       781  Chililabombwe        Dixiana
#
#                                                 Items
#  0  {Marie-rose-sauce, Chopped-tomatoes, Tintenfis...
#  1  {Chopped-tomatoes, Tintenfisch, Chutney, Pains...
#  2  {Biscuits-with-dark-chocolate, Chopped-tomatoe...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      41     0       411  Zheleznogorsk  Potchefstroom
#  1      41     1       411  Potchefstroom        Horodok
#  2      41     2       411        Horodok          Kaédi
#  3      41     3       411          Kaédi          Warri
#  4      41     4       411          Warri    Romainville
#
#                                                 Items
#  0  {Chicken-meat, Grape-juice-drink, Two-crust Pi...
#  1  {Chicken-meat, Low-fat-fresh-laban, Cukor, Two...
#  2  {Chicken-meat, Low-fat-fresh-laban, Raspberry-...
#  3  {Chicken-meat, Two-crust Pies, Beers-from-stra...
#  4  {Chicken-meat, Two-crust Pies, Beers-from-stra...  ,
#    RouteId Order TruckCode   StartCity    EndCity  \
#  0      42     0       471  Novouzensk     Wakiso
#  1      42     1       471      Wakiso      Mūlki
#  2      42     2       471       Mūlki    Lushnjë
#  3      42     3       471     Lushnjë  Ushirombo
#
#                                                 Items
#  0  {Frozen-battered-fish, Energy-ball, Chocolate-...
#  1  {Frozen-battered-fish, Energy-ball, Chocolate-...
#  2  {Fajitas, Energy-ball, Fruit-bar, Chocolate-bl...
#  3  {Energy-ball, Yellow-peaches, Canned-fruit-sal...  ,
#    RouteId Order TruckCode   StartCity       EndCity  \
#  0      43     0       677    Koksijde    Novouzensk
#  1      43     1       677  Novouzensk  Bukit Rambai
#
#                                                 Items
#  0        {Pralines, Graines, Asian-food, Hamblokjes}
#  1  {Graines, Blended-scotch-whisky, Hamblokjes, C...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      44     0       598               Wakiso        Potchefstroom
#  1      44     1       598        Potchefstroom               Pájara
#  2      44     2       598               Pájara                Tampa
#  3      44     3       598                Tampa               Partūr
#  4      44     4       598               Partūr  Pallanza-Intra-Suna
#  5      44     5       598  Pallanza-Intra-Suna            Ushirombo
#
#                                                 Items
#  0  {Bouillonterning, Frozen-confectionary, Grape-...
#  1  {Deep-fried, Bouillonterning, Green-salads, Ch...
#  2  {Banana-flavour-mix-and-added-vitamins-and-min...
#  3  {Banana-flavour-mix-and-added-vitamins-and-min...
#  4  {Banana-flavour-mix-and-added-vitamins-and-min...
#  5  {Banana-flavour-mix-and-added-vitamins-and-min...  ,
#    RouteId Order TruckCode        StartCity        EndCity  \
#  0      45     0       658  Morro do Chapéu       Winnipeg
#  1      45     1       658         Winnipeg  Pantai Cenang
#  2      45     2       658    Pantai Cenang         Abaeté
#  3      45     3       658           Abaeté         Hirara
#
#                                                 Items
#  0  {Marshmallow-creme, Dindes, Sparkling-water-be...
#  1  {Whipping-fresh-cream, Pie dough, Tartar-sauce...
#  2  {Corn-tortilla-chips, Seed-style-mustard, Shri...
#  3  {Corn-tortilla-chips, Coleslaw-dressing, Eaux-...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      46     0       684         Qaţanā  Pantai Cenang
#  1      46     1       684  Pantai Cenang    Minneapolis
#
#                                                 Items
#  0  {Pringles-potato-chips, Crackers-sans-gluten, ...
#  1  {Fresh-bread, Corn-tortilla-chips, Cancoillott...  ,
#    RouteId Order TruckCode    StartCity        EndCity  \
#  0      47     0       376     Koch'ang    Minneapolis
#  1      47     1       376  Minneapolis          Kogon
#  2      47     2       376        Kogon         Cuiabá
#  3      47     3       376       Cuiabá          Khāpa
#  4      47     4       376        Khāpa         Haldia
#  5      47     5       376       Haldia    Vostryakovo
#  6      47     6       376  Vostryakovo  Potchefstroom
#
#                                                 Items
#  0  {Fresh-bread, Quiches-lorraines, Sunflower-oil...
#  1  {Pains-burger, Quiches-lorraines, Sunflower-oi...
#  2  {Cornbreads, Likor, Tartar-sauce, Hokey-pokey-...
#  3  {Cornbreads, Asian-condiments, Crems-glacees, ...
#  4  {Asian-condiments, Crems-glacees, Likor, Tarta...
#  5  {Asian-condiments, Tartar-sauce, Likor, Roquef...
#  6  {Smoked-haddock, Riz, Tartar-sauce, Roquefort-...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      48     0       270  Ushirombo      Annau
#  1      48     1       270      Annau   Taşköprü
#  2      48     2       270   Taşköprü  Ushirombo
#  3      48     3       270  Ushirombo     Givors
#
#                                                 Items
#  0  {Fajitas, Frozen-vegetable-mix, Lait-de-vache-...
#  1  {Fajitas, Pancakes-and-waffles, Pitted-prunes,...
#  2  {Fajitas, Senate-bean-soup, Pate-feuilletee, F...
#  3  {Energy-balls, Tortilla-chips, Canneloni, Pump...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      49     0       682    Kālāvad  Laungowāl
#  1      49     1       682  Laungowāl    Ifakara
#
#                                                 Items
#  0  {Chicken-burgers, Bitters, Semoules-de-ble-dur...
#  1  {Chicken-burgers, Semoules-de-ble-dur-pour-cou...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      50     0       914                Düzce               Berlin
#  1      50     1       914               Berlin               Kitami
#  2      50     2       914               Kitami               Wakiso
#  3      50     3       914               Wakiso              Lushnjë
#  4      50     4       914              Lushnjë  Pallanza-Intra-Suna
#  5      50     5       914  Pallanza-Intra-Suna          Romainville
#  6      50     6       914          Romainville                Warri
#  7      50     7       914                Warri            Fundación
#
#                                                 Items
#  0  {Senate-bean-soup, Dried-sausages, Minced-beef...
#  1  {Senate-bean-soup, Dried-sausages, Minced-beef...
#  2  {Soupes, Dried-sausages, Minced-beef-steak, Al...
#  3  {Soupes, Dried-sausages, Minced-beef-steak, Po...
#  4  {Soupes, Minced-beef-steak, Shredded-cheese, S...
#  5  {Soupes, Haselnusse, Prawn-crackers, Topping, ...
#  6  {Soupes, Passionfruit-pulp, Green-bean-salad, ...
#  7  {Haselnusse, Gluhwein, Spam, Pear-and-blackcur...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      51     0       636          Mūlki          Khāpa
#  1      51     1       636          Khāpa         Annino
#  2      51     2       636         Annino          Khāpa
#  3      51     3       636          Khāpa  Fontainebleau
#  4      51     4       636  Fontainebleau       Żoliborz
#  5      51     5       636       Żoliborz      Şanlıurfa
#  6      51     6       636      Şanlıurfa         Timaru
#
#                                                 Items
#  0                                    {Mango-chutney}
#  1  {Deep-fried, Smoked-haddock, Pralines, Fresh-b...
#  2  {Topping, Boeuf-bourguignon, Breakfast-biscuit...
#  3  {Pralines, Smoked-haddock, Fresh-bread, Gateau...
#  4  {Pralines, Smoked-haddock, Gravy-mix, Cocktail...
#  5  {Pringles-potato-chips, Pralines, Smoked-haddo...
#  6  {Pringles-potato-chips, Pralines, Cocktail-sau...  ,
#    RouteId Order TruckCode  StartCity  EndCity  \
#  0      52     0       325  Gharaunda    Mosta
#  1      52     1       325      Mosta    Forio
#  2      52     2       325      Forio  Hibbing
#
#                                                 Items
#  0  {Pate-feuilletee, Semoules-de-ble-dur-pour-cou...
#  1  {Savoy-cabbage, Pate-feuilletee, Semoules-de-b...
#  2  {Holunder-bluten-sirup, Fruits-en-conserve, Se...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      53     0       277  Wernigerode       Kanuma
#  1      53     1       277       Kanuma      Ifakara
#  2      53     2       277      Ifakara    Fundación
#  3      53     3       277    Fundación  Berkhamsted
#  4      53     4       277  Berkhamsted      Sedrata
#
#                                                 Items
#  0  {Carots, Taco-shells, Lamb-chops, Edulcorant-a...
#  1  {Taco-shells, Edulcorant-avec-fruit-des-moines...
#  2  {Ice-tea, Salty snacks, Fruit-confectionary, W...
#  3  {Yoghurts-op-een-laag-fruit, Frozen-ice-creams...
#  4  {Crêpes and galettes, Carrot-cake, Choux-fleur...  ,
#    RouteId Order TruckCode   StartCity       EndCity  \
#  0      54     0        52   Hitoyoshi    Batticaloa
#  1      54     1        52  Batticaloa       Ifakara
#  2      54     2        52     Ifakara  Bukit Rambai
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
#  1  {Banana-flavour-mix-and-added-vitamins-and-min...
#  2  {Banana-flavour-mix-and-added-vitamins-and-min...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      55     0       101        Belek    Gharaunda
#  1      55     1       101    Gharaunda  Dharmanagar
#  2      55     2       101  Dharmanagar     Cibinong
#  3      55     3       101     Cibinong       Pájara
#  4      55     4       101       Pájara   Cristalina
#
#                                                 Items
#  0  {Egg-white-powder, Fish-can, Mackeral, Skegnes...
#  1  {Asperges-en-conserve, Dill-sauce, Fish-can, P...
#  2  {Banana-flavour-mix-and-added-vitamins-and-min...
#  3  {Chicken-meat, Asperges-en-conserve, Semoules-...
#  4  {Chicken-meat, Recipe-mixes, Semoules-de-ble-d...  ,
#    RouteId Order TruckCode     StartCity        EndCity  \
#  0      56     0       359  Rio de Mouro         Kitami
#  1      56     1       359        Kitami     Koprivnica
#  2      56     2       359    Koprivnica  Pantai Cenang
#
#                                                 Items
#  0  {Chocolate-chip-cookies, Kruidenpasta, Snack-s...
#  1  {Chocolate-chip-cookies, Chocolats-blancs, Cre...
#  2  {Asian-sauces, Kidney-beans, Chocolate-chip-co...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      57     0       216         Forio        Givors
#  1      57     1       216        Givors      Pruszków
#  2      57     2       216      Pruszków  Ketanggungan
#  3      57     3       216  Ketanggungan       Horodok
#
#                                                 Items
#  0                               {Seed-style-mustard}
#  1  {Fajitas, Dulces, Pains-de-mie, Toppings, Chor...
#  2  {Garlic-and-coriander-naans, Protein, Pork-cho...
#  3  {Garlic-and-coriander-naans, Iced-cookies, Pro...  ,
#    RouteId Order TruckCode      StartCity           EndCity  \
#  0      58     0       445         Kanuma            Partūr
#  1      58     1       445         Partūr     Zheleznogorsk
#  2      58     2       445  Zheleznogorsk       Minneapolis
#  3      58     3       445    Minneapolis            Qaţanā
#  4      58     4       445         Qaţanā         Gharaunda
#  5      58     5       445      Gharaunda         Millville
#  6      58     6       445      Millville           Needham
#  7      58     7       445        Needham  Krasnoperekops’k
#
#                                                 Items
#  0  {Bottled-water, Plastic-surgery, Fruit-cups, S...
#  1  {Pumpkin-seed-pecan, Cranberry-juice-drink, Fr...
#  2  {Grated-parmesan-cheese, Aliment-pour-chevaux,...
#  3  {Fresh-asparagus, Grated-parmesan-cheese, Frui...
#  4  {Fresh-asparagus, Grated-parmesan-cheese, Frui...
#  5  {Fresh-asparagus, Tartar-sauce, Lindt-sea-salt...
#  6  {Fresh-asparagus, Milch, Gateau, Trail-mix, Fa...
#  7  {Trail-mix, Fats, Gateau, Hamblokjes, Fruit-cu...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      59     0        26          Sedrata  University City
#  1      59     1        26  University City          Sedrata
#  2      59     2        26          Sedrata           Cuiabá
#  3      59     3        26           Cuiabá         Hajnówka
#  4      59     4        26         Hajnówka            Kaédi
#  5      59     5        26            Kaédi          Kushtia
#
#                                                 Items
#  0  {Aperitif, Whipping-fresh-cream, Fresh-brown-o...
#  1  {Mache, Maple-butter, Sweetelle-tomatoes, Bals...
#  2  {Sweetelle-tomatoes, Fruit-and-nut-mix, Condim...
#  3  {Whipping-fresh-cream, Sweetelle-tomatoes, Chi...
#  4  {Beers-from-stralsund, Fruit-confectionary, Ch...
#  5  {Beers-from-stralsund, Fruit-confectionary, Po...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      60     0       155       Berlin  Dharmanagar
#  1      60     1       155  Dharmanagar       Kloten
#  2      60     2       155       Kloten   Cristalina
#  3      60     3       155   Cristalina        Mūlki
#  4      60     4       155        Mūlki        Annau
#
#                                                 Items
#  0  {Canned-mussels, Vanilla-waffles, Asian-condim...
#  1  {Banana-flavour-mix-and-added-vitamins-and-min...
#  2  {Banana-flavour-mix-and-added-vitamins-and-min...
#  3  {Asian-condiments, Gaufres, Meat-pies, Caviar ...
#  4  {Asian-condiments, Caviar substitutes, Frozen-...  ,
#    RouteId Order TruckCode     StartCity          EndCity  \
#  0      61     0       976   Romainville             Same
#  1      61     1       976          Same        Millville
#  2      61     2       976     Millville      Wernigerode
#  3      61     3       976   Wernigerode     Râs el Aïoun
#  4      61     4       976  Râs el Aïoun         Taşköprü
#  5      61     5       976      Taşköprü  Morro do Chapéu
#
#                                                 Items
#  0  {Gluhwein, Cake-mix, Spam, Kase, Sweetcorn, Co...
#  1  {Fajitas, Gluhwein, Spam, Chicken-powder, Coco...
#  2  {Gluhwein, Baby-beetroot, Energy-balls, Spam, ...
#  3  {Chocolats, Fruit-and-nut-mix, Edulcorant-avec...
#  4  {Kits, Gluhwein, Spam, Non food products, Choc...
#  5  {Kits, Pate-feuilletee, Spam, Chocolats, Drink...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      62     0       744            Givors            Hotaka
#  1      62     1       744            Hotaka     Potchefstroom
#  2      62     2       744     Potchefstroom        Novouzensk
#  3      62     3       744        Novouzensk         Southaven
#  4      62     4       744         Southaven            Jetpur
#  5      62     5       744            Jetpur             Kaédi
#  6      62     6       744             Kaédi  Hódmezővásárhely
#  7      62     7       744  Hódmezővásárhely            Kloten
#
#                                                 Items
#  0  {Asian-condiments, Pork-sausages, Chocolats, C...
#  1  {Chorizos, Asian-condiments, Pork-sausages, Ba...
#  2  {Low-fat-fresh-laban, Chorizos, Asian-condimen...
#  3  {Chorizos, Asian-condiments, Pork-sausages, Tr...
#  4  {Food additives, Chicken-burgers, Chorizos, As...
#  5  {Food additives, Chorizos, Asian-condiments, G...
#  6  {Food additives, Asian-condiments, Getranke, M...
#  7  {Food additives, Asian-condiments, Getranke, M...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      63     0       283          Monteros             Tāoru
#  1      63     1       283             Tāoru         Ushirombo
#  2      63     2       283         Ushirombo      Bukit Rambai
#  3      63     3       283      Bukit Rambai  Hódmezővásárhely
#  4      63     4       283  Hódmezővásárhely         Ushirombo
#  5      63     5       283         Ushirombo           Dixiana
#
#                                                 Items
#  0  {Soupes, Banana-nut-loaf, Tandoori-chicken-mas...
#  1  {Lamb-breast, Green olives, Tandoori-chicken-m...
#  2  {Corn-thins, Multifruits, Green olives, Tandoo...
#  3  {Corn-thins, Energy-ball, Lamb-breast, Beef-pi...
#  4  {Energy-ball, Instant-porridge, Beef-pie, Sala...
#  5  {Instant-porridge, Green olives, Vegetable-fat...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      64     0       639     Kloten  Fundación
#  1      64     1       639  Fundación  Laungowāl
#
#                                                 Items
#  0                                                 {}
#  1  {Cooking-chocolate, Peeled-plum-tomatoes, Mint...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      65     0       248          Romainville        Chililabombwe
#  1      65     1       248        Chililabombwe            Fundación
#  2      65     2       248            Fundación              Jalingo
#  3      65     3       248              Jalingo              Dixiana
#  4      65     4       248              Dixiana            Hitoyoshi
#  5      65     5       248            Hitoyoshi  Pallanza-Intra-Suna
#  6      65     6       248  Pallanza-Intra-Suna         Rio de Mouro
#
#                                                 Items
#  0  {Psyllium-husk, Chocolate-muffin, Passionfruit...
#  1  {Chocolate-muffin, Passionfruit-pulp, Marie-ro...
#  2  {Savoy-cabbage, Chocolate-muffin, Passionfruit...
#  3  {Savoy-cabbage, Psyllium-husk, Chocolate-muffi...
#  4  {Savoy-cabbage, Strawberry-mousse, Vegetable-p...
#  5  {Psyllium-husk, Fruit-cups, Hot-fudge-topping,...
#  6  {Fruit-cups, Hot-fudge-topping, Strawberry-mou...  ,
#    RouteId Order TruckCode     StartCity              EndCity  \
#  0      66     0       350  Bukit Rambai                Forio
#  1      66     1       350         Forio  Pallanza-Intra-Suna
#
#                                                 Items
#  0  {Fajitas, Coconut-milk-powder, Egg-salad, Fres...
#  1  {Fajitas, Seed-style-mustard, Egg-salad, Fresh...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      67     0        41      Taşköprü  Bukit Rambai
#  1      67     1        41  Bukit Rambai   Berkhamsted
#  2      67     2        41   Berkhamsted     Guarabira
#  3      67     3        41     Guarabira       Hibbing
#  4      67     4        41       Hibbing  Râs el Aïoun
#
#                                                 Items
#  0  {Semolina, Grape-juice-drink, Senate-bean-soup...
#  1  {Croissant-with-cocoa-cream, Sugary snacks, Sm...
#  2  {Crêpes and galettes, Croissant-with-cocoa-cre...
#  3  {Crêpes and galettes, Plaice, Kase, Minced-bee...
#  4  {Plaice, Kase, Apple-cider, Kidney-beans, Nane...  ,
#    RouteId Order TruckCode StartCity      EndCity  \
#  0      68     0       824     Forio     Hajnówka
#  1      68     1       824  Hajnówka  Romainville
#
#                                                 Items
#  0  {Melange-d-epices-pour-guacamole, Pitenza-toma...
#  1  {Coffee-ice-cream, Schmelzkase, Canned-crab-me...  ,
#    RouteId Order TruckCode   StartCity          EndCity  \
#  0      69     0       513   Laungowāl             Same
#  1      69     1       513        Same         Pruszków
#  2      69     2       513    Pruszków       Manacapuru
#  3      69     3       513  Manacapuru        Goyerkāta
#  4      69     4       513   Goyerkāta  University City
#
#                                                 Items
#  0  {Sucres, Whole olives, Pork-ham, Smoked-paprik...
#  1  {Muffin-mix, Magarines, Sucres, Peaches-sliced...
#  2  {Recipe-mixes, Muffin-mix, Citrouille-en-conse...
#  3  {Magarines, Goat-milk, Pitenza-tomatoes, Kaffi...
#  4  {Green-bean-salad, Marshmallow-creme, Dairies,...  ,
#    RouteId Order TruckCode   StartCity      EndCity  \
#  0      70     0       513   Millville         Same
#  1      70     1       513        Same   Koprivnica
#  2      70     2       513  Koprivnica       Hirara
#  3      70     3       513      Hirara     Lakeland
#  4      70     4       513    Lakeland  Wernigerode
#
#                                                 Items
#  0  {Olives, Smoked-ham, Chocolate-block, Chocolat...
#  1  {Olives, Custard-powder, Energy-balls, Peaches...
#  2  {Gluhwein, Asian-sauces, Custard-powder, Peach...
#  3  {Gluhwein, Asian-sauces, Custard-powder, Peach...
#  4  {Estragon, Gluhwein, Asian-sauces, Peaches-sli...  ,
#    RouteId Order TruckCode    StartCity    EndCity  \
#  0      71     0       429  Berkhamsted     Abaeté
#  1      71     1       429       Abaeté   Monteros
#  2      71     2       429     Monteros     Pájara
#  3      71     3       429       Pájara     Pájara
#  4      71     4       429       Pájara     Abaeté
#  5      71     5       429       Abaeté     Panaji
#  6      71     6       429       Panaji  Goyerkāta
#
#                                                 Items
#  0  {Olives, Plaice, Natural-spring-water, Asian-c...
#  1  {Olives, Bitters, Plaice, Asian-condiments, Na...
#  2  {Cocktail-sauces, Bitters, Malt-drink, Biscuit...
#  3  {Bitters, Plaice, Asian-condiments, Biscuits-a...
#  4  {Dried-sausages, Biscuits-aperitifs-sales, Asi...
#  5  {Asian-cooking, Biscuits-aperitifs-sales, Crum...
#  6  {Biscuits-aperitifs-sales, Crumpets, Asian-coo...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      72     0       549           Givors           Partūr
#  1      72     1       549           Partūr       Cristalina
#  2      72     2       549       Cristalina          Abū Tīj
#  3      72     3       549          Abū Tīj         Lakeland
#  4      72     4       549         Lakeland           Annino
#  5      72     5       549           Annino           Wakiso
#  6      72     6       549           Wakiso  University City
#  7      72     7       549  University City   Puerto La Cruz
#
#                                                 Items
#  0  {Fajitas, Canned-precooked-meat, Levures, Mayo...
#  1  {Fajitas, Chocolate-muffin, Pumpkin-seed-pecan...
#  2  {Fajitas, Chocolate-muffin, Pumpkin-seed-pecan...
#  3  {Fajitas, Bonbons-a-la-menthe, Vanilla-waffles...
#  4  {Wholefood, Vanilla-waffles, Wasabi-popcorn, N...
#  5  {Wholefood, Banana-flavour-mix-and-added-vitam...
#  6  {Wholefood, Banana-flavour-mix-and-added-vitam...
#  7  {Coleslaw-dressing, Kombucha, Frozen-confectio...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      73     0       294          Annino  Puerto La Cruz
#  1      73     1       294  Puerto La Cruz           Tampa
#  2      73     2       294           Tampa          Putian
#  3      73     3       294          Putian          Pájara
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
# ...
#  0  {Umbrichelli, Chicken-kebabs, Peanut-sauce, Br...
#  1  {Umbrichelli, Recipe-mixes, Dried-sausages, Mu...
#  2  {Umbrichelli, Red-ale, Dessert-mixes, Dried-sa...
#  3  {Dessert-mixes, Dried-sausages, Multiseeded-sl...
#  4  {Mozzarella-sticks, Peach, Mixed-nuts, Multise...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      79     0       245          Warri  Pantai Cenang
#  1      79     1       245  Pantai Cenang          Kogon
#  2      79     2       245          Kogon         Berlin
#  3      79     3       245         Berlin   Rājgurunagar
#  4      79     4       245   Rājgurunagar        Vichuga
#
#                                                 Items
#  0  {Coconut-waters, Gluhwein, Chocolats, Coconut-...
#  1  {Cured-sausage, Fresh-bread, Corn-tortilla-chi...
#  2  {Cured-sausage, Sucres, Fresh-bread, Corn-tort...
#  3  {Cured-sausage, Sucres, Corn-tortilla-chips, G...
#  4  {Sucres, Corn-tortilla-chips, Groceries, Chill...  ,
#    RouteId Order TruckCode     StartCity           EndCity  \
#  0      80     0       196  Rājgurunagar             Belek
#  1      80     1       196         Belek      Rio de Mouro
#  2      80     2       196  Rio de Mouro             Kogon
#  3      80     3       196         Kogon             Belek
#  4      80     4       196         Belek             Forio
#  5      80     5       196         Forio            Berlin
#  6      80     6       196        Berlin            Abaeté
#  7      80     7       196        Abaeté  Hódmezővásárhely
#
#                                                 Items
#  0       {Kvarg, Plats-prepares-surgeles, Seitan-bio}
#  1  {Kvarg, Plats-prepares-surgeles, Seitan-bio, M...
#  2  {Feuille-de-vigne, Spam, Snack-sale, Crumpets,...
#  3  {Feuille-de-vigne, Cactus, Snack-sale, Plats-p...
#  4  {Feuille-de-vigne, Fish-can, Snack-sale, Plats...
#  5  {Feuille-de-vigne, Snack-sale, Melange-d-epice...
#  6  {Feuille-de-vigne, Snack-sale, Melange-d-epice...
#  7  {Feuille-de-vigne, Spam, Rice-crackers, Melang...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      81     0       699     Lakeland       Givors
#  1      81     1       699       Givors   Lakshmīpur
#  2      81     2       699   Lakshmīpur  Dharmanagar
#  3      81     3       699  Dharmanagar   Novouzensk
#  4      81     4       699   Novouzensk   Lakshmīpur
#  5      81     5       699   Lakshmīpur    Ushirombo
#
#                                                 Items
#  0  {Recipe-mixes, Crêpes and galettes, Tuna-steak...
#  1  {Flavoured-cranberries, Recipe-mixes, Asian-co...
#  2  {Flavoured-cranberries, Soupes, Chocolats, Chi...
#  3  {Fresh-pineapple, Estragon, Kaffir-lime-leaves...
#  4  {Fresh-pineapple, Kaffir-lime-leaves, Trimmed-...
#  5  {Fresh-pineapple, Soupes, Pear-cider, Trimmed-...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      82     0       338   Kālāvad    Aksu
#  1      82     1       338      Aksu  Hotaka
#
#                                                 Items
#  0  {Bitters, Chicken-burgers, Juice-from-concentr...
#  1  {Barbeque-sauce, Rye-pale-ale, Juice-from-conc...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      83     0       943       Kushtia     Şanlıurfa
#  1      83     1       943     Şanlıurfa  Rājgurunagar
#  2      83     2       943  Rājgurunagar         Kunri
#  3      83     3       943         Kunri    Novouzensk
#  4      83     4       943    Novouzensk          Same
#  5      83     5       943          Same       Sadalgi
#  6      83     6       943       Sadalgi      Lakeland
#  7      83     7       943      Lakeland  Rio de Mouro
#
#                                                 Items
#  0  {Grattons, Food additives, Fresh-coconut, Whip...
#  1  {Grattons, Frozen foods, Biscuits-au-chocolat,...
#  2  {Grattons, Plats-prepares-surgeles, Seitan-bio...
#  3  {Grattons, Birthday-cake, Farming products, Pl...
#  4  {Grattons, Energy-ball, Birthday-cake, Asian-c...
#  5  {Grattons, Low-fat-fresh-laban, Asian-condimen...
#  6  {Grattons, Low-fat-fresh-laban, Birthday-cake,...
#  7  {Marshmallow-creme, Basa-fish, Honey-ham, Asia...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      84     0       846   Winnenden  Koprivnica
#  1      84     1       846  Koprivnica   Southaven
#  2      84     2       846   Southaven    Cibinong
#
#                                                 Items
#  0  {Chocolate-trifle, Asian-cooking, Blue-stilton...
#  1  {Absinth, Chocolate-trifle, Blue-stilton, Past...
#  2  {Absinth, Blue-stilton, Pastrami, Whole-wheat-...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      85     0       367   Chililabombwe      Batticaloa
#  1      85     1       367      Batticaloa  Puerto La Cruz
#  2      85     2       367  Puerto La Cruz        Żoliborz
#  3      85     3       367        Żoliborz         Vichuga
#  4      85     4       367         Vichuga          Panaji
#  5      85     5       367          Panaji          Qaţanā
#  6      85     6       367          Qaţanā         Sadalgi
#  7      85     7       367         Sadalgi    Ketanggungan
#
#                                                 Items
#  0  {Melange-d-epices-pour-guacamole, Vegetable-pa...
#  1  {Breaded products, Tuna-steak, Purified-water,...
#  2  {Carrot-cake, Marie-rose-sauce, Rose-water, Dr...
#  3  {Carrot-cake, Aceite-de-coco, Marie-rose-sauce...
#  4  {Carrot-cake, Aceite-de-coco, Marie-rose-sauce...
#  5  {Topping, Coffee-ice-cream, Losenges, Marshmal...
#  6  {Pringles-potato-chips, Losenges, Chilli-con-c...
#  7  {Pringles-potato-chips, Losenges, Chilli-con-c...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      86     0       916         Koch'ang          Hibbing
#  1      86     1       916          Hibbing           Hotaka
#  2      86     2       916           Hotaka       Batticaloa
#  3      86     3       916       Batticaloa            Düzce
#  4      86     4       916            Düzce           Givors
#  5      86     5       916           Givors  Morro do Chapéu
#  6      86     6       916  Morro do Chapéu         Winnipeg
#
#                                                 Items
#  0  {Fruit-flavored, Jus-d-orange, Quiches-lorrain...
#  1  {Fruit-flavored, Quiches-lorraines, Sunflower-...
#  2  {Fruit-flavored, Gulab-jamun, Peeled-plum-toma...
#  3  {Fruit-flavored, Sussungsmittel, Chicken-burge...
#  4  {Fruit-flavored, Senate-bean-soup, Chicken-bur...
#  5  {Fruit-flavored, Senate-bean-soup, Peeled-plum...
#  6  {Chicken-burgers, Peaches-sliced-in-syrup, Ins...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      87     0       367        Vichuga         Berlin
#  1      87     1       367         Berlin        Jalingo
#  2      87     2       367        Jalingo  Chililabombwe
#  3      87     3       367  Chililabombwe        Hibbing
#
#                                                 Items
#  0  {Coffee-ice-cream, Mate, Fruit-salad-in-juice,...
#  1  {Mate, Vanilla-waffles, Birthday-cake, Getrank...
#  2  {Coffee-ice-cream, Vanilla-waffles, Spam, Hamb...
#  3  {Coffee-ice-cream, Vanilla-waffles, Spam, Hamb...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      88     0       193          Mūlki        Dixiana
#  1      88     1       193        Dixiana  Zheleznogorsk
#  2      88     2       193  Zheleznogorsk       Pruszków
#  3      88     3       193       Pruszków  Zheleznogorsk
#
#                                                 Items
#  0                 {Green-salads, Spring-roll-pastry}
#  1  {Fajitas, Gluhwein, Fish-can, Juice-from-conce...
#  2  {Fajitas, Gluhwein, Apple-cider, Jaffa-cakes, ...
#  3  {Fajitas, Quesos, Gluhwein, Garlic-bread, Frui...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      89     0       743         Monteros    Zheleznogorsk
#  1      89     1       743    Zheleznogorsk         Koch'ang
#  2      89     2       743         Koch'ang  Morro do Chapéu
#  3      89     3       743  Morro do Chapéu          Bilhaur
#  4      89     4       743          Bilhaur        Şanlıurfa
#
#                                                 Items
#  0  {Schmelzkase, Blueberry-muffins, Roquefort-che...
#  1  {Donuts, Two-crust Pies, Schmelzkase, Seed-sty...
#  2  {Fresh-bread, Two-crust Pies, Schmelzkase, Blu...
#  3  {Blueberry-muffins, Nane-limon, Fresh-bread, T...
#  4  {Fresh-drinking-coconut, Fresh-bread, Two-crus...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      90     0       941       Kushtia    Lakshmīpur
#  1      90     1       941    Lakshmīpur  Râs el Aïoun
#  2      90     2       941  Râs el Aïoun     Goyerkāta
#  3      90     3       941     Goyerkāta        Berlin
#  4      90     4       941        Berlin          Aksu
#  5      90     5       941          Aksu         Kogon
#
#                                                 Items
#  0  {Chocolate-trifle, Frozen foods, Melk, Saumon-...
#  1  {Fresh-coconut, Peach-juice-drink, Protein, Me...
#  2  {Fresh-coconut, Peach-juice-drink, Powder, Pro...
#  3  {Fresh-coconut, Protein, Microwave-popcorn, Sa...
#  4  {Pork-crackling, Citrus-punch, Frozen-ice-crea...
#  5  {Pork-crackling, Citrus-punch, Canned-apricots...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      91     0       372     Zheleznogorsk           Dixiana
#  1      91     1       372           Dixiana            Wakiso
#  2      91     2       372            Wakiso             Mosta
#  3      91     3       372             Mosta   University City
#  4      91     4       372   University City  Hódmezővásárhely
#  5      91     5       372  Hódmezővásárhely        Batticaloa
#
#                                                 Items
#  0  {Chicken-meat, Grated-parmesan-cheese, All-ste...
#  1  {Fajitas, Specialite-a-tartiner, Tee, Dark-soy...
#  2  {Fajitas, Grape-juice-drink, Bouillonterning, ...
#  3  {Fajitas, Grape-juice-drink, Bouillonterning, ...
#  4  {Fajitas, Grape-juice-drink, Bouillonterning, ...
#  5  {Fajitas, Grape-juice-drink, Gateau, Porc, Tig...  ,
#    RouteId Order TruckCode     StartCity EndCity  \
#  0      92     0       855  Rio de Mouro  Kanuma
#  1      92     1       855        Kanuma  Pájara
#
#                                                 Items
#  0  {Feuille-de-vigne, Baking-powder, Spam, Crumpe...
#  1  {Raisin-bread, Salty snacks, Coconut-creams, P...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      93     0       112    Hitoyoshi     Taşköprü
#  1      93     1       112     Taşköprü       Timaru
#  2      93     2       112       Timaru     Monteros
#  3      93     3       112     Monteros       Hirara
#  4      93     4       112       Hirara       Givors
#  5      93     5       112       Givors  Berkhamsted
#  6      93     6       112  Berkhamsted      Sadalgi
#  7      93     7       112      Sadalgi   Novouzensk
#
#                                                 Items
#  0  {Asparagus-tips, Fruit-cups, Reduced-fat-milks...
#  1  {Asparagus-tips, Pate-feuilletee, Peanut-butte...
#  2  {Asparagus-tips, Pate-feuilletee, Taco-shells,...
#  3  {Asparagus-tips, Taco-shells, Pate-feuilletee,...
#  4  {Asparagus-tips, Pate-feuilletee, Taco-shells,...
#  5  {Asparagus-tips, Toppings, Pate-feuilletee, Ch...
#  6  {Asparagus-tips, Pate-feuilletee, Sunflower-oi...
#  7  {Pate-feuilletee, Asian-condiments, Peanut-but...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      94     0       373         Hotaka       Żoliborz
#  1      94     1       373       Żoliborz      Millville
#  2      94     2       373      Millville       Monteros
#  3      94     3       373       Monteros  Fontainebleau
#  4      94     4       373  Fontainebleau        Horodok
#
#                                                 Items
#  0  {Pate-feuilletee, Frozen-asian-vegetables, Chu...
#  1  {Goats-butter, Sweetelle-tomatoes, Fish-can, P...
#  2  {Olives, Sweetelle-tomatoes, Pate-feuilletee, ...
#  3  {Sweetelle-tomatoes, Pate-feuilletee, Frozen-a...
#  4  {Churned-cream, Premium-and-organic-pepper-fro...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      95     0       254   University City            Kanuma
#  1      95     1       254            Kanuma        Manacapuru
#  2      95     2       254        Manacapuru          Pruszków
#  3      95     3       254          Pruszków  Hódmezővásárhely
#  4      95     4       254  Hódmezővásárhely             Mosta
#
#                                                 Items
#  0  {Recipe-mixes, Mayonaise, Coffee-flavoured-mil...
#  1  {Mache, Recipe-mixes, Gluhwein, Coconut-flour,...
#  2  {Fresh-asparagus, Recipe-mixes, Radish, Dairie...
#  3  {Fresh-asparagus, Recipe-mixes, Radish, Dairie...
#  4  {Fresh-asparagus, Diced-tomatoes, Granola-mix,...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      96     0       882          Kaédi          Kaédi
#  1      96     1       882          Kaédi  Fontainebleau
#  2      96     2       882  Fontainebleau         Haldia
#
#                                                 Items
#  0                                    {Pork-sausages}
#  1  {Brownie, Beef-lasagne, Chesnut-mushrooms, Can...
#  2  {Brownie, Coffee-flavoured-milk, Beef-lasagne,...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      97     0       896       Kanuma     Monteros
#  1      97     1       896     Monteros  Vostryakovo
#  2      97     2       896  Vostryakovo       Haldia
#  3      97     3       896       Haldia       Kitami
#  4      97     4       896       Kitami      Dixiana
#  5      97     5       896      Dixiana      Jalingo
#  6      97     6       896      Jalingo       Wakiso
#  7      97     7       896       Wakiso  Dharmanagar
#
#                                                 Items
#  0  {Coconut-flour, Fruit-cups, Raisin-bread, Whit...
#  1  {Lamb-breast, Banana-nut-loaf, Tandoori-chicke...
#  2  {Coconut-flour, Lamb-breast, Biscuits-aperitif...
#  3  {Pringles-potato-chips, Graines, Breakfasts, B...
#  4  {Pringles-potato-chips, Soupes, Breakfasts, Ba...
#  5  {Pringles-potato-chips, Soupes, Breakfasts, Kv...
#  6  {Soupes, Breakfasts, Kvarg, Vegetarian-frozen-...
#  7  {Poivre-noir, Herring-fillets, Biscuits-au-cho...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      98     0       460      Mūlki     Panaji
#  1      98     1       460     Panaji  Southaven
#  2      98     2       460  Southaven   Cibinong
#  3      98     3       460   Cibinong     Abaeté
#  4      98     4       460     Abaeté       Same
#  5      98     5       460       Same      Kaédi
#
#                                                 Items
#  0  {Fajitas, Mango-chutney, Getrankeweisser, Gree...
#  1  {Fajitas, Cafe-en-dosettes-compatible-nespress...
#  2  {Pralines, Riz, Pates-fraiches, Corn-thins, Ch...
#  3  {Pralines, Riz, Pates-fraiches, Chicken-burger...
#  4  {Groundnut-bar, Riz, Pates-fraiches, Chicken-b...
#  5  {Riz, Chicken-burgers, Groundnut-bar, Canned f...  ,
#    RouteId Order TruckCode     StartCity      EndCity  \
#  0      99     0       456  Rio de Mouro      Sedrata
#  1      99     1       456       Sedrata  Romainville
#  2      99     2       456   Romainville    Gharaunda
#  3      99     3       456     Gharaunda       Partūr
#  4      99     4       456        Partūr       Qaţanā
#  5      99     5       456        Qaţanā      Hibbing
#
#                                                 Items
#  0  {Spam, Brawn, Cornichons, Edam, Mousse-de-foie...
#  1  {Plato-preparado-precocinado, Kruidenpasta, Br...
#  2  {Plato-preparado-precocinado, Psyllium-husk, S...
#  3  {Chestnut-mushrooms, Fruit-and-nut-mix, Eggpla...
#  4  {Sweetcorn, Pumpkin-seed-pecan, Gateau, Kruide...
#  5  {Hamblokjes, Chestnut-mushrooms, Sweetcorn, Kr...  ]

# %%
all_trips = pd.concat(trips)

# %%
all_trips.to_csv("route_trips.csv")
