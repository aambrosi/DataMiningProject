# %%
import pandas as pd
import numpy  as np
import time   # To calculate the execution time
import bisect # For the WeightedRandomGenerator
import random # For the generation of random numbers
from numpy.random import choice # For generation of ordered list based on weight
from collections import defaultdict  # For dictionary that memorize the cumulative probability of import/expor
import copy # For function deepcopy

# The dataset was created by using a food dataset and saved outside because the original dataset was huge (1GB).
product_list = pd.read_csv('categories.csv', 
                           delimiter = ',', 
                           encoding  = 'utf-8')

# I delete few strange strings
product_list = product_list.drop([123, 157, 440, 442])

final_product_list                     = pd.DataFrame(product_list['Name'])
final_product_list['Popularity']       = np.random.random_sample(len(final_product_list))

# Index reset due to problems with non-consecutive indexes
final_product_list.reset_index(drop    = True, 
                               inplace = True)

# %%
cities = pd.read_csv('world-cities.csv', 
                     delimiter = ',', 
                     encoding  = 'utf-8')

# Set the number of cities to 100
nCities = 100
cities  = cities.sample(nCities)

# Index reset due to problems with non-consecutive indexes
cities.reset_index(drop    = True, 
                   inplace = True)
city_list         = pd.DataFrame(cities.name)
city_list.columns = ['Name']

# %%
#city_list["Export"] = ""
#city_list["Import"] = ""

# %%
# range of exported and imported for each city setted respectively at 3:20 and 10:50
minExp = 5
maxExp = 40
minImp = 20
maxImp = 100

# THIS PART CAN BE RUN IN PARALLEL (SPARK)
#start = time.time()
#for c in range(0,len(city_list)):
#    num_exp = np.random.randint(minExp,maxExp)
#    num_imp = np.random.randint(minImp,maxImp)
#    exp = np.unique(final_product_list.sample(num_exp, weights=final_product_list.Popularity).Name)
#    possible_imp_products = final_product_list[~final_product_list['Name'].isin(exp)]
#    imp = np.unique(possible_imp_products.sample(num_imp, weights=possible_imp_products.Popularity).Name)
#    city_list.loc[c,'Export'] = exp
#    city_list.loc[c,'Import'] = imp
#print(time.time()-start)

# %%
# Creation of a probability vector for each city based on popularity of products and random coefficient
# from 0 to 1
rand = [np.random.random_sample(len(final_product_list)) for i in range(0,len(city_list))]
popularity = final_product_list.Popularity
name = final_product_list.Name

priority = [((popularity * rand[i]), (popularity**2 * (1-rand[i])))
            for i in range(0,len(city_list))]
probabilityExport = [p[0] / sum(p[0]) for p in priority]
probabilityImport = [p[1] / sum(p[1]) for p in priority]

# List of each product in order of probability and then insert it in the dataset his coefficient
productsOrderExp = [choice(name, len(final_product_list), p = prob, replace = False)
                 for prob in probabilityExport]
city_list["ImportanceExport"] = [[(l[i], (1 - i / len(l))) for i in range(0,len(l))] for l in productsOrderExp]

productsOrderImp = [choice(name, len(final_product_list), p = prob, replace = False)
                 for prob in probabilityImport]
city_list["ImportanceImport"] = [[(l[i], (1 - i / len(l))) for i in range(0,len(l))] for l in productsOrderImp]

# %%
city_list
# Out:
#                    Name                                   ImportanceExport  \
# 0           Tegucigalpa  [(Milk-chocolate-digestives, 1.0), (Corn-snack...
# 1                 Deoli  [(Fruit-sticks, 1.0), (Complements-alimentaire...
# 2            Enterprise  [(Fat-free-milk, 1.0), (Fruit-sticks, 0.999216...
# 3              Adjumani  [(Muffin-mix, 1.0), (Fecules, 0.99921630094043...
# 4              Muskegon  [(Hot-pepper-sauce, 1.0), (Chicken-kiev, 0.999...
# 5             Toamasina  [(Yaourt-aux-fruits, 1.0), (Tiefkuhlpizza, 0.9...
# 6                Iradan  [(Churned-cream, 1.0), (Corn-snacks, 0.9992163...
# 7            Guanajuato  [(Coconut-cream, 1.0), (Pancake-syrup, 0.99921...
# 8                Luqiao  [(Levure, 1.0), (Schwarztees, 0.99921630094043...
# 9         Katima Mulilo  [(Still-water, 1.0), (Gnocchi, 0.9992163009404...
# 10            Sonneberg  [(Gratin-de-chou-fleur, 1.0), (Cold-meats, 0.9...
# 11            Dashtobod  [(Melange-d-epices-pour-guacamole, 1.0), (Fecu...
# 12             Pariaman  [(Frozen-potato-products, 1.0), (Tomato-chilli...
# 13                 Guye  [(Vegan-chicken-nuggets, 1.0), (Crab-pate, 0.9...
# 14  Tomaszów Mazowiecki  [(Cake-mix, 1.0), (Fresh-cream, 0.999216300940...
# 15             Diamante  [(Chocolate-chip-cookies, 1.0), (Asparagus-tip...
# 16            Bhāndāria  [(Blended-scotch-whisky, 1.0), (Roasted-garlic...
# 17                 Ordu  [(Green-salad-and-vegetables, 1.0), (Fresh-cab...
# 18     Farmington Hills  [(Cannellini-beans, 1.0), (Capsicums, 0.999216...
# 19              Mauganj  [(Jaffa-cakes, 1.0), (Bison, 0.999216300940438...
# 20                  Huy  [(Fresh-cabbage, 1.0), (Milk-chocolate-filled-...
# 21            Zhanjiang  [(Milchprodukt, 1.0), (Soft-cheeses, 0.9992163...
# 22          Dania Beach  [(Tarts, 1.0), (Cottage-cheese, 0.999216300940...
# 23               Fushun  [(Nans, 1.0), (Thons-en-conserve, 0.9992163009...
# 24           Ponta Porã  [(Caffe, 1.0), (Semolina, 0.9992163009404389),...
# 25                  Bor  [(Asian-food, 1.0), (Stilton, 0.99921630094043...
# 26              Rucphen  [(Eggplant-dip, 1.0), (Fresh-coconut, 0.999216...
# 27            Vorgashor  [(Sandwichs, 1.0), (Yaourt, 0.9992163009404389...
# 28             Peterhof  [(Whole-wheat-beard, 1.0), (Fresh-coconut, 0.9...
# 29            São Bento  [(Pork-chipolatas, 1.0), (Snack-mix, 0.9992163...
# ..                  ...                                                ...
# 70              Phulpur  [(Pizza dough, 1.0), (Crab-pate, 0.99921630094...
# 71              Midland  [(Babycorn, 1.0), (Effervescent-vitamin, 0.999...
# 72           Wellington  [(Green-bean-salad, 1.0), (Likor, 0.9992163009...
# 73                Hamme  [(Saumon-atlantique, 1.0), (Chocolate-coins, 0...
# 74              Yashiro  [(Lamb-breast, 1.0), (Mango-chutney, 0.9992163...
# 75            Kingstown  [(Frozen-asian-foods, 1.0), (Milk-based-produc...
# 76                Gadag  [(Umbrichelli, 1.0), (Fresh-lamb-meat, 0.99921...
# 77          Ath Thawrah  [(Mixed-nuts, 1.0), (Fresh-brown-onions, 0.999...
# 78         Wade Hampton  [(Almond-fingers, 1.0), (Pains-precuits, 0.999...
# 79   Santiago Ixcuintla  [(Cherry-pie-filling, 1.0), (Cucumbers-in-brin...
# 80                Tanda  [(Copeaux-de-chocolat-noir, 1.0), (Peeled-plum...
# 81               Włochy  [(Organic-and-premium-pepper-cambodia, 1.0), (...
# 82             Osinniki  [(Food additives, 1.0), (Prawn-cocktail, 0.999...
# 83              Fontana  [(Coffee-ice-cream, 1.0), (Framboises, 0.99921...
# 84               Salamá  [(Jus, 1.0), (Paves-de-saumon, 0.9992163009404...
# 85                Içara  [(Bonbons-a-la-menthe, 1.0), (Scotch-eggs, 0.9...
# 86                Minas  [(Mushroom-in-sunflower-oil, 1.0), (Dietary su...
# 87           Santo Tomé  [(Fruit-drinks, 1.0), (Frozen-chicken, 0.99921...
# 88        Land O' Lakes  [(Port, 1.0), (Meats, 0.9992163009404389), (St...
# 89               Quetta  [(Garlic-bread, 1.0), (Mashed-potatoes, 0.9992...
# 90              Newport  [(Snack-sale, 1.0), (Organic-and-premium-peppe...
# 91                Ikeja  [(Mature-blue-stilton, 1.0), (Trimmed-beans, 0...
# 92                Apomu  [(Pan-di-spagna, 1.0), (Prepared-foods, 0.9992...
# 93              Manaoag  [(Kale, 1.0), (Flour-tortillas, 0.999216300940...
# 94           Akonolinga  [(Coconut-water, 1.0), (Coffee-flavoured-milk,...
# 95              Rāmgarh  [(Power-drink, 1.0), (Chocolate-trifle, 0.9992...
# 96            Pocatello  [(Meta-category, 1.0), (Pains-precuits, 0.9992...
# 97             Rāmnagar  [(Dolce-gusto-compatible-coffee-capsules, 1.0)...
# 98                 Koga  [(Baked-beans-in-tomato-sauce, 1.0), (Crems-gl...
# 99               Sunset  [(Carbonated-soda-water, 1.0), (Coconut-macaro...
#
#                                      ImportanceImport
# 0   [(Grated-parmesan-cheese, 1.0), (Pumpkin-seed-...
# 1   [(Churned-cream, 1.0), (Fresh-coconut, 0.99921...
# 2   [(Organic-and-premium-pepper-cambodia, 1.0), (...
# 3   [(Fruit-bread, 1.0), (Grattons, 0.999216300940...
# 4   [(Tarama, 1.0), (Wholefood, 0.9992163009404389...
# 5   [(Milk substitute, 1.0), (Wheatflour, 0.999216...
# 6   [(Brie-cheese, 1.0), (Bakery, 0.99921630094043...
# 7   [(Frozen-potato-products, 1.0), (Dilute-drink,...
# 8   [(Cinnamon-roll, 1.0), (Hommus, 0.999216300940...
# 9   [(Pate-a-tartiner-pomme-poire, 1.0), (Mais-a-p...
# 10  [(Cremes-fraiches-epaisses, 1.0), (Breaded pro...
# 11  [(Ciabatta, 1.0), (Confitures-de-fraises, 0.99...
# 12  [(Pecans, 1.0), (Ciabatta, 0.9992163009404389)...
# 13  [(Sandwichs, 1.0), (Medium-cheddar, 0.99921630...
# 14  [(Mineral-natural-water, 1.0), (Capers, 0.9992...
# 15  [(Hot-chocolate, 1.0), (Vinho-tinto, 0.9992163...
# 16  [(Schokoladen, 1.0), (Chocolate-with-raspberri...
# 17  [(Vleeswaren, 1.0), (Canned-lamb-tongue, 0.999...
# 18  [(Muffin-mix, 1.0), (Emu-jerky, 0.999216300940...
# 19  [(Vanilla-waffles, 1.0), (Pain-pita-sucres, 0....
# 20  [(Grattons, 1.0), (Crevettes, 0.99921630094043...
# 21  [(Vins-rouges, 1.0), (Kit-pour-fajitas, 0.9992...
# 22  [(Sourdough-bread, 1.0), (Milk-chocolate-diges...
# 23  [(Griechische-joghurt, 1.0), (Canned-crab-meat...
# 24  [(Frozen-pork-buns, 1.0), (Multiseeded-sliced-...
# 25  [(Toppings, 1.0), (Mais-a-popcorn, 0.999216300...
# 26  [(Soup-mixes, 1.0), (Breaded-chicken, 0.999216...
# 27  [(Non-dairy-soymilk, 1.0), (Breakfast-biscuits...
# 28  [(Fruits-secs, 1.0), (Bison, 0.999216300940438...
# 29  [(Tea-lemonade, 1.0), (Chocolate-trifle, 0.999...
# ..                                                ...
# 70  [(Saucisses-aux-lentilles, 1.0), (Jarred-aspar...
# 71  [(Pastrami, 1.0), (Pancakes-and-waffles, 0.999...
# 72  [(Dindes, 1.0), (Tortilla, 0.9992163009404389)...
# 73  [(Strawberries-canned, 1.0), (Chocolate-chunks...
# 74  [(Mushroom-in-sunflower-oil, 1.0), (Crab-pate,...
# 75  [(Bitters, 1.0), (Baked-goods, 0.9992163009404...
# 76  [(Baked-beans-with-pork-sausages-in-tomato-sau...
# 77  [(Iced-donuts, 1.0), (Mandarin-juice, 0.999216...
# 78  [(Herring-fillets, 1.0), (Garlic-baguettes, 0....
# 79  [(Potato-crips, 1.0), (Frozen-asian-snack-food...
# 80  [(Jus, 1.0), (Cornichons-au-vinaigre-pasteuris...
# 81  [(Milch, 1.0), (Babycorn, 0.9992163009404389),...
# 82  [(Beers-from-stralsund, 1.0), (Capsicums, 0.99...
# 83  [(Goat-cheese-log, 1.0), (Groceries, 0.9992163...
# 84  [(Jus-de-fruits, 1.0), (Mango-chutney, 0.99921...
# 85  [(Multiseeded-sliced-bread, 1.0), (Capers, 0.9...
# 86  [(Fruit-sticks, 1.0), (Sambuca, 0.999216300940...
# 87  [(Cordial, 1.0), (Mate, 0.9992163009404389), (...
# 88  [(Pumpkin-seed-pecan, 1.0), (Food additives, 0...
# 89  [(Schmelzkase, 1.0), (Chips, 0.999216300940438...
# 90  [(Garlic-bread, 1.0), (Tejszin, 0.999216300940...
# 91  [(Juice-beverage, 1.0), (Pate-a-tartiner-pomme...
# 92  [(Strawberry-topping, 1.0), (Salsa, 0.99921630...
# 93  [(Fresh-raspberries, 1.0), (Dolce-gusto-compat...
# 94  [(Cooking-chocolate, 1.0), (Pains-au-chocolat,...
# 95  [(Steak-kidney-pie, 1.0), (Yoghurts-op-een-laa...
# 96  [(Spearmint-sugarfree-gum, 1.0), (Spices-seaso...
# 97  [(Aliments-d-origine-vegetale, 1.0), (Non food...
# 98  [(Crems-glacees, 1.0), (Productos-lacteos, 0.9...
# 99  [(Almond-milk-yogurt, 1.0), (Fruit juices, 0.9...
#
# [100 rows x 3 columns]

# %%
def standard_info(i, rid, tcd, trip, final_trip):
    final_trip.loc[i, 'RouteId']   = rid
    final_trip.loc[i, 'Order']     = i
    final_trip.loc[i, 'TruckCode'] = tcd
    final_trip.loc[i, 'StartCity'] = trip.loc[i    , 'IdCity']
    final_trip.loc[i, 'EndCity']   = trip.loc[i + 1, 'IdCity']

def first_step_creation(rid, tcd, length, trip):
    final_trip   = pd.DataFrame(columns = ['RouteId', 'Order', 'TruckCode', 'StartCity', 'EndCity', 'Items'])
    standard_info(0, rid, tcd, trip, final_trip)
    itemsToImport = [(item[0], item[1]*item2[1]) for item in trip.loc[length - 2, "ProductImportance"]
                                 for item2 in trip.loc[length - 2, "PopularImport"] if item[0] == item2[0]]
    tot = sum(i[1] for i in itemsToImport)
    itemList = [i[0] for i in itemsToImport]
    itemValues = [i[1]/tot for i in itemsToImport]
    # I set the range to be not fixed to 5-20 for the first trip cities that have few exportable items and I set
    # them to half to all the possible exportable items
    numItems = np.random.randint(5,15)
    exportedItems = choice(itemList, numItems, p = itemValues, replace = False)
    final_trip.loc[length - 2, 'Items'] = set(exportedItems)
    return final_trip
    
def trip_creation(i, rid, tcd, length, trip, final_trip):
    standard_info(i - 1, rid, tcd, trip, final_trip)
    crev            = length - i - 1
    exportPriority = city_list.loc[(list(city_list.Name).index(trip.loc[crev + 1, 'IdCity'])),
                                   'ImportanceExport']
    removeItems = [expPriority[0] for expPriority in exportPriority if random.random() < expPriority[1]]
    possibleExports = list(final_trip.loc[crev + 1, 'Items'])
    itemsToDelete   = set(possibleExports).intersection(removeItems)
    for item in itemsToDelete:
        possibleExports.remove(item)
    # Number of new exported items
    numItems = np.random.randint(3, 15)
    itemsToImport = [(item[0], item[1]*item2[1]) for item in trip.loc[length - 2, "ProductImportance"]
                                 for item2 in trip.loc[length - 2, "PopularImport"] if item[0] == item2[0]]
    tot = sum(i[1] for i in itemsToImport)
    itemList = [i[0] for i in itemsToImport]
    itemValues = [i[1]/tot for i in itemsToImport]
    exportedItems = choice(itemList, numItems, p = itemValues, replace = False)
    final_trip.loc[crev, 'Items'] = set(possibleExports).union(exportedItems)
    return final_trip

# %%
# Range of trip length setted at 3:10. We set the number of trucks to 1000
minLen   = 3
maxLen   = 10
numTruck = 50

def generate_trip(i):
    length = np.random.randint(minLen, maxLen)
    trip   = pd.DataFrame(columns = ['IdCity', 'ProductImportance', 'PopularImport'])
    Exports = defaultdict(int)
    cities = []
    for c in range(0, length):
        city     = np.random.randint(0, len(city_list))
        while city in cities:
            city = np.random.randint(0, len(city_list))
        cities.append(city)
        trip.loc[c, 'IdCity'] = city_list.loc[city, 'Name']
        for cl in city_list.loc[city, 'ImportanceExport']:
            Exports[cl[0]] += cl[1]
        trip.loc[c, 'ProductImportance'] = [(item, Exports[item]) for item in Exports]
        trip.loc[c, 'PopularImport']   = city_list.loc[city, 'ImportanceImport']
    rid = i
    tcd = np.random.randint(0, numTruck)
    final_trip = first_step_creation(rid, tcd, length, trip)
    for c in range(2,length):
        final_trip = trip_creation(c, rid, tcd, length, trip, final_trip)
    final_trip = final_trip.sort_values('Order')
    return final_trip

# %%
# Range of trip length setted at 3:10. We set the number of trucks to 1000
minLen   = 3
maxLen   = 10
numTruck = 50
length = np.random.randint(minLen, maxLen)
trip   = pd.DataFrame(columns = ['IdCity', 'ProductImportance', 'PopularImport'])
Exports = defaultdict(int)
cities = []
for c in range(0, length):
    city     = np.random.randint(0, len(city_list))
    while city in cities:
        city = np.random.randint(0, len(city_list))
    cities.append(city)
    trip.loc[c, 'IdCity'] = city_list.loc[city, 'Name']
    for cl in city_list.loc[city, 'ImportanceExport']:
        Exports[cl[0]] += cl[1]
    trip.loc[c, 'ProductImportance'] = [(item, Exports[item]) for item in Exports]
    trip.loc[c, 'PopularImport']   = city_list.loc[city, 'ImportanceImport']

# %%
# Generate n trips
def generate_trips(n):
    return [generate_trip(i) for i in range(0, n)]

# %%
numberOfRoutes = 150
routes         = generate_trips(numberOfRoutes)

# %%
routes
# Out:
# [  RouteId Order TruckCode    StartCity      EndCity  \
#  0       0     0        26      Midland    Pocatello
#  1       0     1        26    Pocatello  Srīrāmnagar
#  2       0     2        26  Srīrāmnagar       Lorica
#  3       0     3        26       Lorica     Adjumani
#  4       0     4        26     Adjumani      Stebnyk
#
#                                                 Items
#  0  {Goat-milk-cheese, Kartoffelchips, Chocolate-b...
#  1  {Goat-milk-cheese, Whole-bean-coffee, Nectar-d...
#  2  {Soupes, Whole-bean-coffee, Chocolate-block, M...
#  3  {Orange-chocolate, Seabass, Soupes, Whole-bean...
#  4  {Citrus-punch, Chocolate-block, Pork-chipolata...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0       1     0        29            Griffith             Jaunpur
#  1       1     1        29             Jaunpur              Quetta
#  2       1     2        29              Quetta            Rāmnagar
#  3       1     3        29            Rāmnagar                 Bor
#  4       1     4        29                 Bor  Santiago Ixcuintla
#  5       1     5        29  Santiago Ixcuintla            Pariaman
#  6       1     6        29            Pariaman           Dashtobod
#  7       1     7        29           Dashtobod              Luqiao
#
#                                                 Items
#  0  {Bircarbonate-of-soda, Flavoured-cranberries, ...
#  1  {Apple-blackcurrant-drink, Strawberry-trifle, ...
#  2  {Ratatouille, Cheddar-baguettes, Fruit-spread,...
#  3  {Cheddar-baguettes, Canneloni, Green-kale, Pea...
#  4  {Strawberry-trifle, Nans, Canneloni, Pickles, ...
#  5  {Custard-tarts, Prunes, Galettes-de-polenta, R...
#  6  {Fruchtnektar, Custard-tarts, Prunes, Pitted-p...
#  7  {Baking, Custard-tarts, Chutney, Pitted-prunes...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0       2     0         2  Chilecito   Griffith
#  1       2     1         2   Griffith    Huizhou
#  2       2     2         2    Huizhou    Goražde
#  3       2     3         2    Goražde   Sablayan
#  4       2     4         2   Sablayan  Sonneberg
#  5       2     5         2  Sonneberg   Podujeva
#
#                                                 Items
#  0  {Susswaren, Onion-relish, Peanut-in-chocolate,...
#  1  {Peanut-in-chocolate, Seitan-bio, Burrito-kit,...
#  2  {Rice-candy, Peanut-in-chocolate, Cold-meats, ...
#  3  {Canned-precooked-meat, Malt-vinegar, Pitted-p...
#  4  {Danette-chocolate-dessert, Freeze-dried foods...
#  5  {Danette-chocolate-dessert, Algues-et-derives,...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0       3     0        46     Hornsby     Phulpur
#  1       3     1        46     Phulpur         Bor
#  2       3     2        46         Bor       Tanda
#  3       3     3        46       Tanda     Stebnyk
#  4       3     4        46     Stebnyk  Guanajuato
#  5       3     5        46  Guanajuato     Manaoag
#  6       3     6        46     Manaoag    Podujeva
#
#                                                 Items
#  0  {Frozen-battered-fish, Salads, Bakery, Tortill...
#  1  {Brassica, Bbq-relish, Specialite-basque, Bana...
#  2  {Losenges, Sweetcorn, Steak-kidney-pie, Brassi...
#  3  {Sugary snacks, Losenges, Brassica, Wasabi, En...
#  4  {Mineral-natural-water, Sugary snacks, Goat-mi...
#  5  {Goat-milk-butter, Tiefkuhlpizza, Bottled-wate...
#  6  {Chutney, Tiefkuhlpizza, Jaffa-cakes, Banana-n...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0       4     0        20     Katima Mulilo         Kingstown
#  1       4     1        20         Kingstown  Farmington Hills
#  2       4     2        20  Farmington Hills        Queenstown
#  3       4     3        20        Queenstown           Midland
#  4       4     4        20           Midland             Içara
#  5       4     5        20             Içara          Sablayan
#  6       4     6        20          Sablayan       Tegucigalpa
#  7       4     7        20       Tegucigalpa             Hamme
#
#                                                 Items
#  0  {Dried-sausages, Vinho-tinto, Cremes-vegetales...
#  1  {Ratatouille, Indian, Dried-sausages, Vinho-ti...
#  2  {Biscottes, Ratatouille, Dried-sausages, Vinho...
#  3  {Dried-sausages, Paves-de-saumon, Danette-choc...
#  4  {Sweetcorn-and-peas, Gratin-de-chou-fleur, Dri...
#  5  {Dehydrated-mulberries, Liquid-honey, Dried-sa...
#  6  {Dehydrated-mulberries, Granen-en-aardappels, ...
#  7  {Dehydrated-mulberries, Vanilla-waffles, Soft-...  ,
#    RouteId Order TruckCode StartCity    EndCity  \
#  0       5     0         0  Eberbach       Ordu
#  1       5     1         0      Ordu  Kingstown
#
#                                                 Items
#  0  {Gratin-de-chou-fleur, Schwarztees, Fruit-stic...
#  1  {Baked-beans, Gratin-de-chou-fleur, Frozen-sna...  ,
#    RouteId Order TruckCode  StartCity   EndCity  \
#  0       6     0        23  São Bento  Eberbach
#  1       6     1        23   Eberbach   Manaoag
#  2       6     2        23    Manaoag  Adjumani
#  3       6     3        23   Adjumani     Gadag
#
#                                                 Items
#  0  {Herring-fillets, Sushi, Malt-drink, Prawn-coc...
#  1  {Pork-chops, Strawberry-trifle, Spearmint-suga...
#  2  {Sun-dried-tomatoes, Mais-a-popcorn, Crossiant...
#  3  {Sun-dried-tomatoes, Corn-snacks, Whole-wheat-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0       7     0        12    Khairpur     Newport
#  1       7     1        12     Newport   Pocatello
#  2       7     2        12   Pocatello  Enterprise
#  3       7     3        12  Enterprise   Sonneberg
#
#                                                 Items
#  0  {Mackerel-filets-in-sunflower-oil, Baked-beans...
#  1  {Mackerel-filets-in-sunflower-oil, Sushki, Uns...
#  2  {Green-salads, Mackerel-filets-in-sunflower-oi...
#  3  {Green-salads, Mackerel-filets-in-sunflower-oi...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0       8     0        46    Yashiro  Vorgashor
#  1       8     1        46  Vorgashor    Huizhou
#  2       8     2        46    Huizhou    Imperia
#
#                                                 Items
#  0  {Gateau-chinois, Sunflower-oil-spread, Eau-de-...
#  1  {Faux-fromage, Algues-et-derives, Stilton, Fre...
#  2  {Vegetarian-frozen-food, Green-kale, Faux-from...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0       9     0        36       Huy      Marl
#  1       9     1        36      Marl   Jaunpur
#  2       9     2        36   Jaunpur  Griffith
#
#                                                 Items
#  0  {Soymilk, Plaice, Lamb-ribs, Potato-salad, Roa...
#  1  {Liquid-honey, Chicken-kiev, Chicken-mushroom-...
#  2  {Baked-beans, Chicken-kiev, Specialite-a-tarti...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      10     0        43        Midland       Griffith
#  1      10     1        43       Griffith      Zhangatas
#  2      10     2        43      Zhangatas       Sablayan
#  3      10     3        43       Sablayan      Chilecito
#  4      10     4        43      Chilecito         Abadan
#  5      10     5        43         Abadan  Katima Mulilo
#  6      10     6        43  Katima Mulilo        Rucphen
#
#                                                 Items
#  0  {Sun-dried-tomatoes, Garden-peas, Cremes-fraic...
#  1  {Grape-tomatoes, Cancoillottes, Cremes-fraiche...
#  2  {Grape-tomatoes, Tejszin, Frozen-readymeals, F...
#  3  {Grape-tomatoes, Haferflocken, Tejszin, Pate-a...
#  4  {Aliments-d-origine-vegetale, Haferflocken, Po...
#  5  {Cheddar-baguettes, Haferflocken, Brussels-pat...
#  6  {Haferflocken, Cheddar-baguettes, Frozen-donut...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      11     0        29  Batu Pahat      Quetta
#  1      11     1        29      Quetta  South Bend
#  2      11     2        29  South Bend   Toamasina
#  3      11     3        29   Toamasina        Guye
#
#                                                 Items
#  0  {Cheddar-baguettes, Minced-garlic, Dolminades,...
#  1  {Semoules-de-ble, Egg-lasagne, Dumplings, Minc...
#  2  {Semoules-de-ble, Minced-lamb, Farina, Fresh-t...
#  3  {Plastic-surgery, Minced-lamb, Boneless-pork-l...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      12     0         6    Abadan    Ikeja
#  1      12     1         6     Ikeja  Mauganj
#
#                                                 Items
#  0  {Strawberries-canned, Confiture-biologique, Cr...
#  1  {Sunstream-tomatoes, Strawberries-canned, Caps...  ,
#    RouteId Order TruckCode StartCity     EndCity  \
#  0      13     0        39   Mauganj     Rāmgarh
#  1      13     1        39   Rāmgarh    Eberbach
#  2      13     2        39  Eberbach  Akonolinga
#
#                                                 Items
#  0  {Cafes-solubles, Bieres, Low-fat-fresh-laban, ...
#  1  {Low-fat-fresh-laban, Peanut-in-chocolate, Cou...
#  2  {Churned-cream, Nutrition-bar, Coriandre, Bier...  ,
#    RouteId Order TruckCode                StartCity                  EndCity  \
#  0      14     0        11                   Nattam  Marechal Cândido Rondon
#  1      14     1        11  Marechal Cândido Rondon               Batu Pahat
#  2      14     2        11               Batu Pahat            Katima Mulilo
#  3      14     3        11            Katima Mulilo                 Sector 2
#  4      14     4        11                 Sector 2                Zhanjiang
#  5      14     5        11                Zhanjiang                  Stebnyk
#
#                                                 Items
#  0  {Noix-de-paprika, Indian-food-mixes, Coconut-l...
#  1  {Power-drink, Sushi, Coconut-lime-icecream, Ar...
#  2  {Power-drink, Sushi, Lager-beer, Turkey-burger...
#  3  {Venison, Fresh-cakes, Artisan-bread-mix, Choc...
#  4  {Desserts, Fish and meat and eggs, Hot-fudge, ...
#  5  {Desserts, Lamb-fillet-shoulder, Bhuja, Orange...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      15     0         9       Zittau    Vorgashor
#  1      15     1         9    Vorgashor    Dashtobod
#  2      15     2         9    Dashtobod      Veendam
#  3      15     3         9      Veendam        Tanda
#  4      15     4         9        Tanda      Phulpur
#  5      15     5         9      Phulpur  Orangeville
#  6      15     6         9  Orangeville        Minas
#
#                                                 Items
#  0  {Sunflower-oil-spread, Aperitif, Wholefood, Ch...
#  1  {Pork-chops, Breaded products, Seafood-salad, ...
#  2  {Pork-chops, Parve, Filets-de-poulet, Products...
#  3  {Plats-prepares, Filets-de-poulet, Black-truff...
#  4  {Herring-fillets, Baked-beans, Plats-prepares,...
#  5  {Plats-prepares, Black-truffle-oil, Fruit-spre...
#  6  {Plats-prepares, Chocolate-sultanas, Ghee, Sul...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      16     0        11          Huy      Goražde
#  1      16     1        11      Goražde        Gadag
#  2      16     2        11        Gadag       Gualán
#  3      16     3        11       Gualán  Srīrāmnagar
#  4      16     4        11  Srīrāmnagar      Granada
#  5      16     5        11      Granada       Iradan
#  6      16     6        11       Iradan        Içara
#
#                                                 Items
#  0  {Seafood-salad, Honey-roast-ham, Fruit-cups, P...
#  1  {Aliment-pour-chevaux, Fresh-tomatoes, Bison, ...
#  2  {Griechische-joghurt, Mais-a-popcorn, Grocerie...
#  3  {Griechische-joghurt, Tea-lemonade, Fish-can, ...
#  4  {Tea-lemonade, Minced-garlic, Hot-fudge-toppin...
#  5  {Tea-lemonade, Brie-cheese, Hot-fudge-topping,...
#  6  {Musliriegel, Tea-lemonade, Brie-cheese, Leite...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      17     0        37             Sector 2         Dorcheh Pīāz
#  1      17     1        37         Dorcheh Pīāz              Jaunpur
#  2      17     2        37              Jaunpur           Batu Pahat
#  3      17     3        37           Batu Pahat  Tomaszów Mazowiecki
#  4      17     4        37  Tomaszów Mazowiecki               Fushun
#
#                                                 Items
#  0  {Losenges, Rice-cake, Danette-chocolate-desser...
#  1  {Losenges, Biscuits-chocolates, Whole-wheat-to...
#  2  {Whole-wheat-tortillas, Jus, Canned-apricots, ...
#  3  {Scottish-shortbread, Rice-candy, Whole-wheat-...
#  4  {Rice-candy, Whole-wheat-tortillas, Bircarbona...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      18     0        36             Minas            Iradan
#  1      18     1        36            Iradan        Wellington
#  2      18     2        36        Wellington            Włochy
#  3      18     3        36            Włochy            Poissy
#  4      18     4        36            Poissy  Farmington Hills
#  5      18     5        36  Farmington Hills           Manaoag
#  6      18     6        36           Manaoag             Hamme
#  7      18     7        36             Hamme        South Bend
#
#                                                 Items
#  0  {Fruit-confectionary, Garlic-naan-breads, Fudg...
#  1  {Cheese-singles, Fudge, Bread-mix, Fish-can, H...
#  2  {Edible-decorations, Sugary snacks, Suppenwurf...
#  3  {Edible-decorations, Vins-rouges, Meat-pies, F...
#  4  {Edible-decorations, Salty snacks, Dried-sausa...
#  5  {Herring-fillets, Bread-mix, Indian-food, Drie...
#  6  {Indian-food, Parve, Bircarbonate-of-soda, Sea...
#  7  {Quesos, Indian-food, Parve, Bircarbonate-of-s...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      19     0        33      Fontana     Pariaman
#  1      19     1        33     Pariaman       Quetta
#  2      19     2        33       Quetta      Imperia
#  3      19     3        33      Imperia    Toamasina
#  4      19     4        33    Toamasina    Kingstown
#  5      19     5        33    Kingstown  Dania Beach
#  6      19     6        33  Dania Beach      Phulpur
#  7      19     7        33      Phulpur      Midland
#
#                                                 Items
#  0  {Meals, Custard-powder, Pina-colada, Fruit-min...
#  1  {Sirloin-steak, Meals, Custard-powder, Poisson...
#  2  {Sirloin-steak, Custard-powder, Poissons, Coff...
#  3  {Tortillas, Breaded products, Caramelized-red-...
#  4  {Sirloin-steak, Custard-powder, Fruit-flavoure...
#  5  {Custard-powder, Gateau-chinois, Penne-rigate,...
#  6  {Semolina, Pumpkin-seed-pecan, Wasabi-popcorn,...
#  7  {Pumpkin-seed-pecan, Peach, Soeppoeder, Wasabi...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      20     0         0       Eberbach     Enterprise
#  1      20     1         0     Enterprise          Içara
#  2      20     2         0          Içara        Fontana
#  3      20     3         0        Fontana      Bhāndāria
#  4      20     4         0      Bhāndāria  Katima Mulilo
#  5      20     5         0  Katima Mulilo       Peterhof
#  6      20     6         0       Peterhof     Akonolinga
#  7      20     7         0     Akonolinga   Wade Hampton
#
#                                                 Items
#  0  {Berries-preserve, Tortilla-chips, Vegetarisch...
#  1  {Berries-preserve, Tortilla-chips, Fresh-juice...
#  2  {Berries-preserve, Tortilla-chips, Garden-peas...
#  3  {Berries-preserve, Jus, Filets-de-poulet, Chop...
#  4  {Berries-preserve, Pains-precuits, Marinated o...
#  5  {Berries-preserve, Biscuits-sucres, Breakfasts...
#  6  {Basa-fish, Yaourt-aux-fruits, Chips and fries...
#  7  {Mousse-de-foie-de-porc, Cremes-vegetales-a-ba...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      21     0         3        Koga   Vorgashor
#  1      21     1         3   Vorgashor      Sunset
#  2      21     2         3      Sunset  Wellington
#  3      21     3         3  Wellington     Newport
#  4      21     4         3     Newport       Gadag
#  5      21     5         3       Gadag    Sector 2
#  6      21     6         3    Sector 2  Santo Tomé
#
#                                                 Items
#  0  {Vinho-tinto, Fizzy-drinks, Peach, Sandwich, M...
#  1  {Spring-roll-pastry, Losenges, Artichauts-en-c...
#  2  {Losenges, Artichauts-en-conserve, Milch, Samo...
#  3  {Biscuits-sucres, Samosas, Mayonaise, Croissan...
#  4  {Fresh-lemons, Klebreiskuchen, Couscous, Ciocc...
#  5  {Baked-beans, Alkoholische-getranke, Snow-peas...
#  6  {Baked-beans, Alkoholische-getranke, Preparati...  ,
#    RouteId Order TruckCode         StartCity        EndCity  \
#  0      22     0        48  Farmington Hills            Bor
#  1      22     1        48               Bor  Katima Mulilo
#  2      22     2        48     Katima Mulilo       Griffith
#  3      22     3        48          Griffith    Hobaramachi
#  4      22     4        48       Hobaramachi      Adh Dhayd
#
#                                                 Items
#  0  {Fruchtnektar, Pate, Onion-relish, Wholefood, ...
#  1  {Fruchtnektar, Latticini, Algues-et-derives, B...
#  2  {Dehydrated-mulberries, Lamb-ribs, Cones, Oran...
#  3  {Sweetcorn-and-peas, Baked-beans, Chicken-pies...
#  4  {Baked-beans, Parve, Seafood, San-choy-bao, Ch...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      23     0         1        Luqiao       Imperia
#  1      23     1         1       Imperia     Vorgashor
#  2      23     2         1     Vorgashor   Orangeville
#  3      23     3         1   Orangeville      Rāmnagar
#  4      23     4         1      Rāmnagar        Nattam
#  5      23     5         1        Nattam  Dorcheh Pīāz
#  6      23     6         1  Dorcheh Pīāz        Quetta
#
#                                                 Items
#  0  {Fresh-strawberries, Tortillas, Hot-fudge, Sna...
#  1  {Fresh-strawberries, Snow-peas, Snack, Chocola...
#  2  {Fresh-strawberries, Snow-peas, Snack, Fizzy-d...
#  3  {Fresh-strawberries, Salsa-chips, Plats-prepar...
#  4  {Dried-sausages, Rose-water, Fresh-juices, Cou...
#  5  {Sweetcorn-and-peas, Vanilla-waffles, Churned-...
#  6  {Vanilla-waffles, Milk-based-product, Blended-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      24     0        11      Sunset      Włochy
#  1      24     1        11      Włochy  Santo Tomé
#  2      24     2        11  Santo Tomé   Sonneberg
#  3      24     3        11   Sonneberg  Ponta Porã
#  4      24     4        11  Ponta Porã   Pocatello
#
#                                                 Items
#  0  {Strawberries-canned, Soup-mixes, Genio-tomato...
#  1  {Hot-fudge, Kombucha, Soup-mixes, Fruit-drink,...
#  2  {Pear-and-blackcurrant-juice, Hot-fudge, Sauci...
#  3  {Fresh-strawberries, Edible-decorations, Sushi...
#  4  {Fresh-strawberries, Edible-decorations, Chick...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      25     0        25      Granada     Podujeva
#  1      25     1        25     Podujeva  Ath Thawrah
#  2      25     2        25  Ath Thawrah       Gualán
#
#                                                 Items
#  0  {Noix-de-paprika, Minced-lamb, Tomato-ketchup,...
#  1  {Noix-de-paprika, Mango, Brie-cheese, Peanut-b...
#  2  {Power-drink, Mango, Chicken-breast-curry-with...  ,
#    RouteId Order TruckCode                StartCity                  EndCity  \
#  0      26     0        47                  Manaoag                  Midland
#  1      26     1        47                  Midland                 Rāmnagar
#  2      26     2        47                 Rāmnagar                    Minas
#  3      26     3        47                    Minas  Marechal Cândido Rondon
#  4      26     4        47  Marechal Cândido Rondon               Guanajuato
#  5      26     5        47               Guanajuato                  Rucphen
#  6      26     6        47                  Rucphen      Tomaszów Mazowiecki
#
#                                                 Items
#  0  {Olives-denoyautees, Popping-corn, Fresh-prawn...
#  1  {Olives-denoyautees, Mousse-de-foie-de-porc, S...
#  2  {Mousse-de-foie-de-porc, Sushi, Goat-milk-butt...
#  3  {Chorizos, Sweetelle-tomatoes, Mousse-de-foie-...
#  4  {Aliments-d-origine-vegetale, Chick-peas, Mous...
#  5  {Aliments-d-origine-vegetale, Nans, Soft-chees...
#  6  {Minced-garlic, Chicken-tikka-masala, Prawn-cr...  ,
#    RouteId Order TruckCode    StartCity        EndCity  \
#  0      27     0        17      Fontana     Guanajuato
#  1      27     1        17   Guanajuato      Sonneberg
#  2      27     2        17    Sonneberg       Eberbach
#  3      27     3        17     Eberbach    Dania Beach
#  4      27     4        17  Dania Beach      Zhanjiang
#  5      27     5        17    Zhanjiang  Land O' Lakes
#
#                                                 Items
#  0  {Fruit-confectionary, Sandwiches, Seafood, Pas...
#  1  {Brassica, Mackerel-fillets-in-brine, Sandwich...
#  2  {Roasted-eggplant, Hazelnut-chocolate-spread, ...
#  3  {Lemon-curd, Jus-de-fruits, Prepackaged-lettuc...
#  4  {Lasagne-sheets, Splendid-artistry-coffee, Bre...
#  5  {Condiment-en-poudre, Peach-drink, Pasta-bake-...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      28     0        18        Apomu  Hobaramachi
#  1      28     1        18  Hobaramachi    Zhangatas
#  2      28     2        18    Zhangatas      Stebnyk
#  3      28     3        18      Stebnyk     Osinniki
#  4      28     4        18     Osinniki       Gualán
#
#                                                 Items
#  0  {Pasteurized-milk, Raspberry-conserve, Chicken...
#  1  {Chinese, Raspberry-conserve, Roasted-eggplant...
#  2  {Microwave-popcorn, Peach, Mais-a-popcorn, Vin...
#  3  {Garlic-and-coriander-naan, White-pitta-bread,...
#  4  {White-pitta-bread, Microwave-popcorn, Grana-p...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0      29     0        38              Koga         Zhangatas
#  1      29     1        38         Zhangatas  Farmington Hills
#  2      29     2        38  Farmington Hills           Huizhou
#  3      29     3        38           Huizhou            Quetta
#
#                                                 Items
#  0  {Blinis, Alkoholische-getranke, Chicken-kiev, ...
#  1  {Blinis, Alkoholische-getranke, Christmas-food...
#  2  {Alkoholische-getranke, Christmas-food, Confit...
#  3  {Alkoholische-getranke, Christmas-food, Seabas...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      30     0         2            São Bento  Tomaszów Mazowiecki
#  1      30     1         2  Tomaszów Mazowiecki              Rucphen
#  2      30     2         2              Rucphen          Srīrāmnagar
#  3      30     3         2          Srīrāmnagar                Içara
#
#                                                 Items
#  0  {Peach-drink, Paves-de-saumon, Sirop-de-fruits...
#  1  {Beetroot-juice, Sirop-de-fruits, Organic-toma...
#  2  {Aliments-d-origine-vegetale, Dr-pepper-soft-d...
#  3  {Baked-beans, Garlic-mashed-potatoes, Fruchtne...  ,
#    RouteId Order TruckCode      StartCity       EndCity  \
#  0      31     0        42  Katima Mulilo       Veendam
#  1      31     1        42        Veendam      Bezhetsk
#  2      31     2        42       Bezhetsk  Dorcheh Pīāz
#  3      31     3        42   Dorcheh Pīāz        Guaçuí
#
#                                                 Items
#  0  {Sun-dried-tomatoes, Fresh-strawberries, Juice...
#  1  {Bakery, Products sold before year 2000, Gratt...
#  2  {Mixed-chillies, Products sold before year 200...
#  3  {Mixed-chillies, Couscous, Mandarins-in-syrup,...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      32     0        25   Muskegon  Kingstown
#  1      32     1        25  Kingstown      Gadag
#
#                                                 Items
#  0  {Tortillas, Diet-colas, Fruits-en-conserve, St...
#  1  {Smoked-mussels, Condiment-en-poudre, Tortilla...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      33     0        41        Imperia   Wade Hampton
#  1      33     1        41   Wade Hampton     Batu Pahat
#  2      33     2        41     Batu Pahat   Dorcheh Pīāz
#  3      33     3        41   Dorcheh Pīāz  Katima Mulilo
#  4      33     4        41  Katima Mulilo    Orangeville
#
#                                                 Items
#  0  {Ratatouille, Cafes-solubles, Snow-peas, Biere...
#  1  {Apple-juice-from-concentrate, Baked-beans, Ca...
#  2  {Cafes-solubles, Products sold before year 200...
#  3  {Cafes-solubles, Almond-chocolate, Coq-au-vin,...
#  4  {Semoules-de-ble-dur-pour-couscous, Sushis, Ch...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      34     0        34        Goražde     Batu Pahat
#  1      34     1        34     Batu Pahat        Imperia
#  2      34     2        34        Imperia  Katima Mulilo
#  3      34     3        34  Katima Mulilo            Bor
#  4      34     4        34            Bor         Nattam
#
#                                                 Items
#  0  {Cancoillottes, Premium-and-organic-pepper-fro...
#  1  {Barres-de-cereales, Seabass, Milch, Pastrami,...
#  2  {Barres-de-cereales, Pastrami, Fruchtschnitte,...
#  3  {Suppenwurfel, Biryani, Edam, Asian-cooking, P...
#  4  {Edam, Asian-cooking, Prawn-cocktail, Fruchtsc...  ,
#    RouteId Order TruckCode  StartCity              EndCity  \
#  0      35     0        30    Newport               Zittau
#  1      35     1        30     Zittau            Kingstown
#  2      35     2        30  Kingstown             Pariaman
#  3      35     3        30   Pariaman                  Bor
#  4      35     4        30        Bor  Tomaszów Mazowiecki
#
#                                                 Items
#  0  {Biscottes, Fish and meat and eggs, Christmas-...
#  1  {Legumes-prepares, Schokoladen, Tartar-sauce, ...
#  2  {Jelly-crystals, Spreads, Legumes-prepares, Sc...
#  3  {Sunstream-tomatoes, Jus, Spreads, Boxed-choco...
#  4  {Dehydrated-mulberries, Sunstream-tomatoes, Ju...  ,
#    RouteId Order TruckCode StartCity EndCity  \
#  0      36     0        29   Hornsby   Tanda
#  1      36     1        29     Tanda   Leigh
#
#                                                 Items
#  0  {Meta-category, Wheatflour, Sunflower-spread, ...
#  1  {Meta-category, Sunflower-spread, Tandoori-chi...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      37     0        18               Deoli  Tixtla de Guerrero
#  1      37     1        18  Tixtla de Guerrero          Akonolinga
#  2      37     2        18          Akonolinga           Adh Dhayd
#  3      37     3        18           Adh Dhayd            Vavuniya
#  4      37     4        18            Vavuniya              Guaçuí
#
#                                                 Items
#  0  {Seabass, Dilute-drink, Poissons, Fresh-coconu...
#  1  {Blueberry-muffins, Biscuits-chocolates, Choco...
#  2  {Scottish-shortbread, Baked-beans, Chicken-mus...
#  3  {Sweetelle-tomatoes, Cremes-desserts, Apple-ci...
#  4  {Bieres-blondes, Chicken-mushroom-pie, Smoked-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      38     0        26     Veendam     Imperia
#  1      38     1        26     Imperia  Queenstown
#  2      38     2        26  Queenstown   Adh Dhayd
#  3      38     3        26   Adh Dhayd   Kingstown
#
#                                                 Items
#  0  {Pains-d-epices, Apple-blackcurrant-drink, Fre...
#  1  {Aliments-d-origine-vegetale, Milch, Preparati...
#  2  {Salads, Aliments-d-origine-vegetale, Pains-d-...
#  3  {Salads, Aliments-d-origine-vegetale, Pet food...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      39     0        34  Ponta Porã   Bhāndāria
#  1      39     1        34   Bhāndāria       Gadag
#  2      39     2        34       Gadag      Salamá
#  3      39     3        34      Salamá    Eberbach
#  4      39     4        34    Eberbach  Enterprise
#
#                                                 Items
#  0  {Sun-dried-tomatoes, Fresh-brown-onions, Froze...
#  1  {Liquid-honey, Turkish-delight, Faux-fromage, ...
#  2  {Producto-de-aperitivo, Vegetarische-kazen, Me...
#  3  {Marinara-sauce, Cancoillottes, Freeze-dried f...
#  4  {Whole-wheat-tortillas, Marinara-sauce, Natura...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      40     0        46      Rucphen        Ikeja
#  1      40     1        46        Ikeja        Gadag
#  2      40     2        46        Gadag    Vorgashor
#  3      40     3        46    Vorgashor  Ath Thawrah
#  4      40     4        46  Ath Thawrah     Muskegon
#  5      40     5        46     Muskegon      Midland
#  6      40     6        46      Midland      Veendam
#
#                                                 Items
#  0  {Blinis, Ratatouille, Whole-wheat-tortillas, C...
#  1  {Ratatouille, Chicken-eggs, Fresh-tomatoes, Gr...
#  2  {Olives-denoyautees, Garden-peas, Cremes-fraic...
#  3  {Olives-denoyautees, Cremes-fraiches-epaisses,...
#  4  {Apple-blackcurrant-drink, Olives-denoyautees,...
#  5  {Olives-denoyautees, Cremes-fraiches-epaisses,...
#  6  {Confitures-de-fraises, Peach-drink, Minced-la...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      41     0        27        Veendam         Sunset
#  1      41     1        27         Sunset         Luqiao
#  2      41     2        27         Luqiao    Ath Thawrah
#  3      41     3        27    Ath Thawrah        Mauganj
#  4      41     4        27        Mauganj  Kazincbarcika
#  5      41     5        27  Kazincbarcika        Granada
#  6      41     6        27        Granada            Bor
#  7      41     7        27            Bor      Chilecito
#
#                                                 Items
#  0  {Herring-fillets, Meat-pies, Susswaren, Maple-...
#  1  {Producto-de-aperitivo, Fruit-confectionary, M...
#  2  {Producto-de-aperitivo, Fruit-confectionary, P...
#  3  {Apple-blackcurrant-drink, Vanilla-waffles, Le...
#  4  {Vanilla-waffles, Plats-prepares, Seabass, Fru...
#  5  {Chicken-breast-fillets, Dr-pepper-soft-drink,...
#  6  {Chicken-breast-fillets, Frozen-donuts, Baking...
#  7  {Melk, Pates-a-tartiner-aux-noisettes-et-au-ca...  ,
#    RouteId Order TruckCode StartCity      EndCity  \
#  0      42     0        49      Marl      Rucphen
#  1      42     1        49   Rucphen      Huizhou
#  2      42     2        49   Huizhou      Rāmgarh
#  3      42     3        49   Rāmgarh        Ikeja
#  4      42     4        49     Ikeja  Orangeville
#
#                                                 Items
#  0  {Fruit-confectionary, Olives-denoyautees, Legu...
#  1  {Mixed-chillies, Dr-pepper-soft-drink, Caramel...
#  2  {Mixed-chillies, Dr-pepper-soft-drink, Aperiti...
#  3  {Biscottes, Olives-denoyautees, Christmas-food...
#  4  {Biscottes, Olives-denoyautees, Pear-and-black...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      43     0        47     Vavuniya   Wellington
#  1      43     1        47   Wellington      Midland
#  2      43     2        47      Midland       Fushun
#  3      43     3        47       Fushun     Peterhof
#  4      43     4        47     Peterhof   South Bend
#  5      43     5        47   South Bend   Ponta Porã
#  6      43     6        47   Ponta Porã  Tegucigalpa
#  7      43     7        47  Tegucigalpa     Adjumani
#
#                                                 Items
#  0  {Chicken-pies, Grape-tomatoes, Fizzy-drinks, C...
#  1  {Chicken-burger, Fizzy-drinks, Carbonated-soda...
#  2  {Bread-mix, Sweetcorn, Dindes, Canned-precooke...
#  3  {Bread-mix, Marinara-sauce, Baby-rocket, Honey...
#  4  {Ratatouille, Sushki, Gravy, Biscuits-aperitif...
#  5  {Sushki, Hot-fudge-topping, Biscuits-aperitifs...
#  6  {Sushki, Pitted-prunes, Honey-roast-ham, Crems...
#  7  {Sushki, Infant-powder-milk, Faux-fromage, Riz...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      44     0        28  Ath Thawrah  Hobaramachi
#  1      44     1        28  Hobaramachi        Gadag
#  2      44     2        28        Gadag        Ikeja
#  3      44     3        28        Ikeja       Zittau
#  4      44     4        28       Zittau     Adjumani
#
#                                                 Items
#  0  {Magarines, Strawberry-topping, Fresh-asparagu...
#  1  {Magarines, Sucre, Lamb-chops, Klebreiskuchen,...
#  2  {Pumpkin-seed-pecan, Chicken-eggs, Sunflower-o...
#  3  {Pasta-bake-sauces, Magarines, Sirop, Breakfas...
#  4  {Mango, Chutney, Medium-cheddar, White-quinoa,...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      45     0        48              Salamá           Toamasina
#  1      45     1        48           Toamasina               Apomu
#  2      45     2        48               Apomu           Kingstown
#  3      45     3        48           Kingstown             Imperia
#  4      45     4        48             Imperia              Quetta
#  5      45     5        48              Quetta  Tixtla de Guerrero
#  6      45     6        48  Tixtla de Guerrero             Jaunpur
#
#                                                 Items
#  0  {Genoa-salami, Farina, Vegetable-pate, Feta-ch...
#  1  {Griechische-joghurt, Scottish-shortbread, Fru...
#  2  {Griechische-joghurt, Fruit juices, Genoa-sala...
#  3  {Griechische-joghurt, Genoa-salami, Frozen-veg...
#  4  {Cremes-desserts, Pumpkin-seed-pecan, Frozen-v...
#  5  {Pumpkin-seed-pecan, Sushi, Frozen-vegetables-...
#  6  {Frozen-vegetables-mix, Saumons-fumes, Complem...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      46     0        31          Bor  Tegucigalpa
#  1      46     1        31  Tegucigalpa      Granada
#  2      46     2        31      Granada     Rāmnagar
#  3      46     3        31     Rāmnagar    Chilecito
#
#                                                 Items
#  0  {Sushki, Redcurrant-tea, Apple-pear-juice, Pre...
#  1  {Fresh-bread, Olives-noires, Extractos-de-leva...
#  2  {Tortillas, Cheddar-baguettes, Fresh-bread, Ar...
#  3  {White-plain-flour, Tortillas, Cheddar-baguett...  ,
#    RouteId Order TruckCode    StartCity        EndCity  \
#  0      47     0        18   Akonolinga    Tegucigalpa
#  1      47     1        18  Tegucigalpa      Zhanjiang
#  2      47     2        18    Zhanjiang        Veendam
#  3      47     3        18      Veendam  Land O' Lakes
#
#                                                 Items
#  0  {Vanilla-waffles, Egg-lasagne, Peanut-butter-a...
#  1  {Peanut-butter-and-chocolat-chip-cereal-bar, N...
#  2  {Whole-wheat-pita-bread, Sundried-tomatoes, Fr...
#  3  {Peanut-butter-and-chocolat-chip-cereal-bar, N...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      48     0        33           Guye  Kazincbarcika
#  1      48     1        33  Kazincbarcika            Huy
#
#                                                 Items
#  0  {Breaded-chicken, Boxed-chocolates, Topping, M...
#  1  {All-steak-pie, Crevettes-roses, Bhuja, Baby f...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      49     0        27  Sector 2   Włochy
#  1      49     1        27    Włochy    Tanda
#  2      49     2        27     Tanda  Phulpur
#
#                                                 Items
#  0  {Aliments-d-origine-vegetale, Sweetcorn, Sauci...
#  1  {Lingonberry-jams, Bieres, Saucisses-aux-lenti...
#  2  {White-pitta-bread, Soymilk, Fruit-sticks, Tar...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0      50     0        10    Poissy   Salamá
#  1      50     1        10    Salamá  Guanare
#  2      50     2        10   Guanare   Iradan
#
#                                                 Items
#  0  {Genoa-salami, Semoules-de-ble-dur-pour-cousco...
#  1  {Vins-rouges, Churned-cream, Fudge, Chicken-mu...
#  2  {Fudge, Chicken-mushroom-pie, Orange-juice-fro...  ,
#    RouteId Order TruckCode      StartCity    EndCity  \
#  0      51     0        43  Kazincbarcika      Hamme
#  1      51     1        43          Hamme    Jaunpur
#  2      51     2        43        Jaunpur       Ordu
#  3      51     3        43           Ordu     Guaçuí
#  4      51     4        43         Guaçuí     Sunset
#  5      51     5        43         Sunset    Mauganj
#  6      51     6        43        Mauganj  Zhanjiang
#  7      51     7        43      Zhanjiang     Włochy
#
#                                                 Items
#  0  {Deep-fried, Meat-pies, Tuna-steak, Fresh-praw...
#  1  {Flour-tortillas, Fresh-prawns, Indian-sauces,...
#  2  {Seabass, Pure-australian-honey, Bbq-relish, F...
#  3  {Lemon-curd, Liquid-honey, Wheatflour, Cremes-...
#  4  {Lemon-curd, Pure-australian-honey, Thes-verts...
#  5  {Lemon-curd, Frozen-donuts, Rice-cake, Mexican...
#  6  {Mexican-sauces, Baby foods, Samosas, Caviar s...
#  7  {Chestnut-mushrooms, Filets-de-poulet, Green-s...  ,
#    RouteId Order TruckCode   StartCity    EndCity  \
#  0      52     0        27  Wellington    Stebnyk
#  1      52     1        27     Stebnyk    Rucphen
#  2      52     2        27     Rucphen   Eberbach
#  3      52     3        27    Eberbach  Dashtobod
#  4      52     4        27   Dashtobod   Peterhof
#  5      52     5        27    Peterhof  Zhangatas
#  6      52     6        27   Zhangatas   Bezhetsk
#  7      52     7        27    Bezhetsk   Sablayan
#
#                                                 Items
#  0  {Cashews, Algues-et-derives, Artisan products,...
#  1  {Sliced-cheddar, Sunstream-tomatoes, Goat-milk...
#  2  {Sliced-cheddar, Probiotic-drinks, Green-beans...
#  3  {Dumplings, Artisan products, Pineapple-slices...
#  4  {Bread-mix, Hot-fudge, Brie-cheese, Dumplings,...
#  5  {Ratatouille, Rice-crackers, Hot-fudge, Brie-c...
#  6  {Fromage-a-pate-dure, Matzos, Chick-peas, Stra...
#  7  {Parve, Green-salad-and-vegetables, Nectar-de-...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      53     0        27   Phulpur  Vavuniya
#  1      53     1        27  Vavuniya      Ordu
#  2      53     2        27      Ordu  Sablayan
#  3      53     3        27  Sablayan   Granada
#  4      53     4        27   Granada  Sector 2
#  5      53     5        27  Sector 2   Goražde
#
#                                                 Items
#  0  {Mackerel-filets-in-sunflower-oil, Pasta-bake-...
#  1  {Burger-relish, Meals, Pappardelle, Fruchtnekt...
#  2  {Burger-relish, Freeze-dried foods, Sandwich, ...
#  3  {Burger-relish, Sun-dried-tomatoes, Pappardell...
#  4  {Burger-relish, Sun-dried-tomatoes, Root-beer,...
#  5  {Burger-relish, Whole-wheat-beard, Snack, Coco...  ,
#    RouteId Order TruckCode                StartCity                  EndCity  \
#  0      54     0        11                    Minas  Marechal Cândido Rondon
#  1      54     1        11  Marechal Cândido Rondon                 Adjumani
#  2      54     2        11                 Adjumani                     Guye
#  3      54     3        11                     Guye               Wellington
#  4      54     4        11               Wellington              Srīrāmnagar
#  5      54     5        11              Srīrāmnagar                   Poissy
#  6      54     6        11                   Poissy                 Osinniki
#  7      54     7        11                 Osinniki                    Leigh
#
#                                                 Items
#  0  {Cheddar-baguettes, Brie-cheese, Dolminades, S...
#  1  {Chinese-cinnamon-sticks, Cheddar-baguettes, P...
#  2  {Fish and meat and eggs, Chinese-cinnamon-stic...
#  3  {Fish and meat and eggs, Pates, Gravy, Organic...
#  4  {Sourdough-bread, Apple-and-pear-juices, Pates...
#  5  {Roasted-eggplant, Lentil-soup, Hazelnut-choco...
#  6  {Sweetelle-tomatoes, Beef-broth, Melk, Fruit-j...
#  7  {Breaded-chicken, Christmas-food, Beef-broth, ...  ,
#    RouteId Order TruckCode StartCity    EndCity  \
#  0      55     0        31  Diamante    Mauganj
#  1      55     1        31   Mauganj  Chilecito
#
#                                                 Items
#  0  {Snackfoods, Rice-cake, Microwave-popcorn, Pra...
#  1  {Snackfoods, Low-fat-high-calcium-milk, Pate, ...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      56     0        31            Sablayan          Enterprise
#  1      56     1        31          Enterprise             Granada
#  2      56     2        31             Granada           São Bento
#  3      56     3        31           São Bento  Tixtla de Guerrero
#  4      56     4        31  Tixtla de Guerrero             Veendam
#  5      56     5        31             Veendam         Ath Thawrah
#
#                                                 Items
#  0  {Spring-roll-pastry, Meals, Chick-peas, Confit...
#  1  {Paves-de-saumon, Pralinen, Cardamom-pods, Har...
#  2  {Spring-roll-pastry, Chinese-cinnamon-sticks, ...
#  3  {Aliments-d-origine-vegetale, Dumplings, Baked...
#  4  {Aliments-d-origine-vegetale, Smoked-mussels, ...
#  5  {Food-coulouring, Duck-breast-filets, Peach, M...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      57     0        22           Adh Dhayd         Tegucigalpa
#  1      57     1        22         Tegucigalpa            Vavuniya
#  2      57     2        22            Vavuniya               Minas
#  3      57     3        22               Minas            Khairpur
#  4      57     4        22            Khairpur  Tixtla de Guerrero
#  5      57     5        22  Tixtla de Guerrero                Koga
#  6      57     6        22                Koga             Veendam
#
#                                                 Items
#  0  {Marie-rose-sauce, Frozen-vegetables-mix, Whol...
#  1  {Marie-rose-sauce, Dried-sausages, Kartoffelch...
#  2  {Probiotic-drinks, Strawberry-trifle, Gaufres,...
#  3  {Strawberry-trifle, Pates-a-tartiner-aux-noise...
#  4  {Meat-pies, Snack-mix, Chutney, Milchprodukt, ...
#  5  {Lemon-extract, Getreide-und-getreideprodukte,...
#  6  {Chutney, Apple-cider-vinegar, Milchprodukt, P...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      58     0        30         Kitami        Huizhou
#  1      58     1        30        Huizhou         Luqiao
#  2      58     2        30         Luqiao        Stebnyk
#  3      58     3        30        Stebnyk  Katima Mulilo
#  4      58     4        30  Katima Mulilo      Kingstown
#
#                                                 Items
#  0  {Thes-verts, Klebreiskuchen, Sandwichs, Canned...
#  1  {Diced-tomatoes, Dessert-lacte, Milk-chocolate...
#  2  {Snackfoods, Donut, Canned-prawns, Cured-sausa...
#  3  {Almond-chocolate, Canneloni, Indian-meals, Pr...
#  4  {Canneloni, Pecans, Canned-prawns, Flavoured-c...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      59     0        37        Granada     Queenstown
#  1      59     1        37     Queenstown         Nattam
#  2      59     2        37         Nattam      Dashtobod
#  3      59     3        37      Dashtobod      Sonneberg
#  4      59     4        37      Sonneberg       Podujeva
#  5      59     5        37       Podujeva  Kazincbarcika
#  6      59     6        37  Kazincbarcika         Fushun
#  7      59     7        37         Fushun    Ath Thawrah
#
#                                                 Items
#  0  {Power-drink, Products sold before year 2000, ...
#  1  {Meals, Chocolate-bunny, Melonen, Products sol...
#  2  {Meals, Fresh-bread, Cafes-solubles, Ricotta, ...
#  3  {Fresh-bread, Chicken-breast-fillets, Minced-l...
#  4  {Fresh-bread, Chicken-eggs, Minced-lamb, Baby ...
#  5  {Fresh-bread, Coconut-macaroons, Orange-cake, ...
#  6  {Fresh-bread, Fish-can, Coconut-macaroons, Lai...
#  7  {Confitures-de-fraises, Fresh-bread, Bakery, B...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      60     0        16  Bhāndāria   Sector 2
#  1      60     1        16   Sector 2     Luqiao
#  2      60     2        16     Luqiao  Chilecito
#
#                                                 Items
#  0  {Slaty-snack, Plats-prepares, Green-beans, Soy...
#  1  {Snackfoods, Slaty-snack, Fizzy-drinks, Frozen...
#  2  {Snackfoods, Sandwich-spread, Backpulver, Prec...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      61     0        16        Newport           Guye
#  1      61     1        16           Guye        Mauganj
#  2      61     2        16        Mauganj        Stebnyk
#  3      61     3        16        Stebnyk  Katima Mulilo
#  4      61     4        16  Katima Mulilo       Podujeva
#  5      61     5        16       Podujeva      São Bento
#
#                                                 Items
#  0  {Canned-oysters, Apple-cider, Parve, Saucisses...
#  1  {Glaces, Kvarg, Flavoured-cranberries, Indian-...
#  2  {Low-fat-fresh-laban, Glaces, Indian-readymeal...
#  3  {Edible-decorations, Low-fat-fresh-laban, Glac...
#  4  {Low-fat-fresh-laban, Seafood, Quso-duro, Roqu...
#  5  {Olives-denoyautees, Brie-cheese, Biryani, Pat...  ,
#    RouteId Order TruckCode     StartCity      EndCity  \
#  0      62     0        47  Dorcheh Pīāz    Bhāndāria
#  1      62     1        47     Bhāndāria    Kingstown
#  2      62     2        47     Kingstown  Hobaramachi
#  3      62     3        47   Hobaramachi       Zittau
#
#                                                 Items
#  0  {Power-drink, Mineral-natural-water, Gratin-de...
#  1  {Power-drink, Milk-chocolate-spread, Salty sna...
#  2  {Edible-decorations, Kaffee, Nane-limon, Salty...
#  3  {Edible-decorations, Salty snacks, Gelee-de-gr...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      63     0        21      Gadag   Eberbach
#  1      63     1        21   Eberbach  Dashtobod
#  2      63     2        21  Dashtobod      Ikeja
#
#                                                 Items
#  0  {Smoked-mussels, Nane-limon, Marinara-sauce, S...
#  1  {Smoked-mussels, Nane-limon, Coriandre, Chocol...
#  2  {Smoked-mussels, Nane-limon, Churned-cream, Pl...  ,
#    RouteId Order TruckCode StartCity    EndCity  \
#  0      64     0         5   Hornsby   Khairpur
#  1      64     1         5  Khairpur  Vorgashor
#
#                                                 Items
#  0  {Chick-peas, Glaces, Hoki-fish-fillets, Hamblo...
#  1  {Marinated olives, Glaces, Cous-cous, Octopus-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      65     0        27    Rāmnagar    Adjumani
#  1      65     1        27    Adjumani  Guanajuato
#  2      65     2        27  Guanajuato      Iradan
#  3      65     3        27      Iradan   Chilecito
#
#                                                 Items
#  0  {Tea-lemonade, Sparkling-mineral-waters, Peach...
#  1  {Herring-fillets, Tea-lemonade, Caramelized-re...
#  2  {Herring-fillets, Fish and meat and eggs, Plas...
#  3  {Herring-fillets, Vanilla-waffles, Sweetcorn, ...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      66     0        36     Nattam    Guanare
#  1      66     1        36    Guanare     Sunset
#  2      66     2        36     Sunset    Manaoag
#  3      66     3        36    Manaoag      Hamme
#  4      66     4        36      Hamme  Zhanjiang
#  5      66     5        36  Zhanjiang     Fushun
#
#                                                 Items
#  0  {Mineral-natural-water, Meals, Alkoholische-ge...
#  1  {Mineral-natural-water, Vegetarische-kazen, Fi...
#  2  {Mineral-natural-water, Custard-tarts, Breaded...
#  3  {Natural-spring-water, Carbonated-soda-water, ...
#  4  {Breaded-chicken, Venison, Diced-tomatoes, Pra...
#  5  {Breaded-chicken, Skim-milk, Peach-drink, All-...  ,
# ...
#  4     126     4        35   Adh Dhayd               Ponta Porã
#  5     126     5        35  Ponta Porã  Marechal Cândido Rondon
#
#                                                 Items
#  0  {Cottage-cheese, Soymilk, Genio-tomatoes, Fram...
#  1  {Cafes-solubles, Seabass, Fruit-sticks, Tortil...
#  2  {Peach-drink, Chicken-mushroom-pie, Lager-beer...
#  3  {Carbonated-soda-water, Boxed-chocolates, Farm...
#  4  {Fruit-confectionary, Marfona-variety, Chicken...
#  5  {Chicken-meat, Chicken-mushroom-pie, Nans, Bro...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0     127     0        42     Vavuniya        Gadag
#  1     127     1        42        Gadag          Bor
#  2     127     2        42          Bor   Akonolinga
#  3     127     3        42   Akonolinga       Salamá
#  4     127     4        42       Salamá  Ath Thawrah
#  5     127     5        42  Ath Thawrah         Ordu
#  6     127     6        42         Ordu      Newport
#
#                                                 Items
#  0  {Minestrone, Blinis, Sun-dried-tomatoes, Meat-...
#  1  {Coca-sandwich-biscuits, Eggplant-dip, Muffin-...
#  2  {Edible-decorations, Dried-sausages, Coca-sand...
#  3  {Edible-decorations, Ratatouille, Rice-cracker...
#  4  {Edible-decorations, Ratatouille, Pumpkin-seed...
#  5  {Ratatouille, Cremes-desserts, Meat-pie, Lindt...
#  6  {Sweetelle-tomatoes, Tortillas, Juice-milk-dri...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0     128     0        44          Sector 2           Goražde
#  1     128     1        44           Goražde            Iradan
#  2     128     2        44            Iradan         Zhanjiang
#  3     128     3        44         Zhanjiang            Nattam
#  4     128     4        44            Nattam        Guanajuato
#  5     128     5        44        Guanajuato  Farmington Hills
#  6     128     6        44  Farmington Hills           Manaoag
#
#                                                 Items
#  0  {Aliments-d-origine-vegetale, Musliriegel, Dri...
#  1  {Aliments-d-origine-vegetale, Dumplings, Dairi...
#  2  {Bruschetta, Sundried-tomatoes, Tartar-sauce, ...
#  3  {Tortilla-chips, Carbonated-soda-water, Fresh-...
#  4  {Tortilla-chips, Carbonated-soda-water, Fresh-...
#  5  {Tortilla-chips, Coriandre, Cremes-fraiches-ep...
#  6  {Tortilla-chips, Cancoillottes, Fresh-chicken,...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0     129     0        37        Fontana        Hornsby
#  1     129     1        37        Hornsby        Phulpur
#  2     129     2        37        Phulpur      São Bento
#  3     129     3        37      São Bento  Kazincbarcika
#  4     129     4        37  Kazincbarcika          Deoli
#  5     129     5        37          Deoli       Diamante
#  6     129     6        37       Diamante          Içara
#
#                                                 Items
#  0  {Snackfoods, Coriandre, Chicken-burger, Meat-p...
#  1  {Chicken-eggs, Meat-pie, Whipping-fresh-cream,...
#  2  {Chicken-eggs, Instant-dry-yeast, Bee products...
#  3  {Biscotti, Instant-dry-yeast, Bee products, Ro...
#  4  {Fruit-confectionary, Biscotti, Strawberries-c...
#  5  {Blinis, Fruit-confectionary, Pet food, Strawb...
#  6  {Blinis, Fruit-confectionary, Dried-sausages, ...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0     130     0        32      Muskegon          Guye
#  1     130     1        32          Guye     Kingstown
#  2     130     2        32     Kingstown  Dorcheh Pīāz
#  3     130     3        32  Dorcheh Pīāz      Podujeva
#  4     130     4        32      Podujeva      Eberbach
#  5     130     5        32      Eberbach         Gadag
#
#                                                 Items
#  0  {Nectar-de-fruit, Diced-tomatoes, Plaice, Kauw...
#  1  {Dindes, Goat-milk-cheese, Nectar-de-fruit, Su...
#  2  {Skim-milk, Chicken-kiev, Dindes, Crossiants, ...
#  3  {Dindes, Saucisses-aux-lentilles, Bread-rolls,...
#  4  {Aliments-d-origine-vegetale, Chicken-kiev, Di...
#  5  {Aliments-d-origine-vegetale, Jelly-crystals, ...  ,
#    RouteId Order TruckCode    StartCity     EndCity  \
#  0     131     0        11  Srīrāmnagar       Leigh
#  1     131     1        11        Leigh        Marl
#  2     131     2        11         Marl     Newport
#  3     131     3        11      Newport    Bezhetsk
#  4     131     4        11     Bezhetsk  Guanajuato
#  5     131     5        11   Guanajuato       Gadag
#  6     131     6        11        Gadag   Zhangatas
#
#                                                 Items
#  0  {Sirloin-steak, Cremes-desserts, Pitta-breads,...
#  1  {Confiture-biologique, Asparagus-tips, Wholeme...
#  2  {Chocolate-covered-muesli-bar, Pitta-breads, V...
#  3  {Chocolate-covered-muesli-bar, Caviars, Confit...
#  4  {Baked-beans, Pitta-breads, Fish-can, Baked-go...
#  5  {Rice-crackers, Flavoured-rice-cakes, Vitamins...
#  6  {Biscottes, Rice-crackers, Whole-wheat-beard, ...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0     132     0        24      Khairpur     Chilecito
#  1     132     1        24     Chilecito       Guanare
#  2     132     2        24       Guanare  Wade Hampton
#  3     132     3        24  Wade Hampton       Imperia
#  4     132     4        24       Imperia        Salamá
#  5     132     5        24        Salamá     Zhangatas
#  6     132     6        24     Zhangatas      Griffith
#  7     132     7        24      Griffith     Pocatello
#
#                                                 Items
#  0  {Cottage-cheese, Cake-mix, Abricots-secs, Tejs...
#  1  {Tejszin, Chinese-cinnamon-sticks, Blueberry-m...
#  2  {Strawberries-canned, Rose-water, Radish, Pitt...
#  3  {Strawberries-canned, Cordial, Blueberry-muffi...
#  4  {Chicken-eggs, Strawberries-canned, Onion-reli...
#  5  {Snack, Wasabi, Blended-scotch-whisky, Chocola...
#  6  {Confitures-de-fraises, Snack, Wasabi, Freeze-...
#  7  {Whole-wheat-beard, Wasabi, Fresh-brown-onions...  ,
#    RouteId Order TruckCode    StartCity                  EndCity  \
#  0     133     0        25      Huizhou              Orangeville
#  1     133     1        25  Orangeville  Marechal Cândido Rondon
#
#                                                 Items
#  0  {Fresh-strawberries, Vanilla-waffles, Salty sn...
#  1  {Fresh-strawberries, Marinara-sauce, Sunflower...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0     134     0        22       Adjumani       Muskegon
#  1     134     1        22       Muskegon     Akonolinga
#  2     134     2        22     Akonolinga      São Bento
#  3     134     3        22      São Bento  Kazincbarcika
#  4     134     4        22  Kazincbarcika         Guaçuí
#  5     134     5        22         Guaçuí       Sector 2
#
#                                                 Items
#  0  {Kaffee, Caviars, Nans, Dr-pepper-soft-drink, ...
#  1  {Dr-pepper-soft-drink, Honey-roast-ham, Lamb-r...
#  2  {Dr-pepper-soft-drink, Dumplings, Fresh-juices...
#  3  {Blinis, Egg-lasagne, Dr-pepper-soft-drink, Sa...
#  4  {Dumplings, Honey-roast-ham, Coconut-juice, Pa...
#  5  {Sauce-cocktail, Chopeed-tomatoes, Pork-sausag...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0     135     0        13        Ikeja  Tegucigalpa
#  1     135     1        13  Tegucigalpa      Hornsby
#  2     135     2        13      Hornsby     Rāmnagar
#
#                                                 Items
#  0  {Breaded products, Conservation, Cigarettes, F...
#  1  {Long-life-milk, Snack, Dumplings, Microwave-p...
#  2  {Cake-icing, Dumplings, Microwave-popcorn, Kit...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0     136     0         6   Osinniki    Goražde
#  1     136     1         6    Goražde  Dashtobod
#  2     136     2         6  Dashtobod    Veendam
#
#                                                 Items
#  0  {Semoules-de-ble-dur-pour-couscous, Onion-reli...
#  1  {Chinese-cinnamon-sticks, Chicken-burger, Semo...
#  2  {Chinese-cinnamon-sticks, Semoules-de-ble-dur-...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0     137     0        30          Huy      Rāmgarh
#  1     137     1        30      Rāmgarh  Dania Beach
#  2     137     2        30  Dania Beach    Sonneberg
#  3     137     3        30    Sonneberg       Salamá
#
#                                                 Items
#  0  {Producto-de-aperitivo, Flavoured-rice-cakes, ...
#  1  {Vegetarische-kazen, Peach-drink, Dried-sausag...
#  2  {Sugary snacks, Chinese-cinnamon-sticks, Melk,...
#  3  {Alkoholische-getranke, Soupes, Whole-bean-spr...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0     138     0        22  Rāmnagar   Włochy
#  1     138     1        22    Włochy  Hornsby
#
#                                                 Items
#  0  {Bonbons-a-la-menthe, Fruit juices, Sunflower-...
#  1  {Sunflower-oil-spread, Danette-chocolate-desse...  ,
#    RouteId Order TruckCode                StartCity             EndCity  \
#  0     139     0        37  Marechal Cândido Rondon          Ponta Porã
#  1     139     1        37               Ponta Porã  Santiago Ixcuintla
#  2     139     2        37       Santiago Ixcuintla               Tanda
#  3     139     3        37                    Tanda         Ath Thawrah
#  4     139     4        37              Ath Thawrah            Khairpur
#  5     139     5        37                 Khairpur         Srīrāmnagar
#  6     139     6        37              Srīrāmnagar             Newport
#
#                                                 Items
#  0  {Milk-chocolate-spread, Fudge, Juice, Frozen-d...
#  1  {Meals, Fruchtnektar, Fudge, Juice, Dumplings,...
#  2  {Dumplings, Dilute-drink, Wheat-cereals, Ciocc...
#  3  {Fruit-juice-concentrate, Prunes, Spreads, Bab...
#  4  {Meta-category, Kecap-manis, Fresh-tomatoes, F...
#  5  {Fruit-juice-concentrate, Boneless-pork-loin-s...
#  6  {Peach-drink, Fruit-juice-concentrate, Boneles...  ,
#    RouteId Order TruckCode  StartCity   EndCity  \
#  0     140     0        34  Sonneberg   Fontana
#  1     140     1        34    Fontana  Muskegon
#  2     140     2        34   Muskegon   Rāmgarh
#  3     140     3        34    Rāmgarh     Içara
#  4     140     4        34      Içara     Ikeja
#
#                                                 Items
#  0  {Fromage-a-pate-dure, Glaces, Cheese-puffs, Mi...
#  1  {Food-coulouring, Cheese-puffs, Whole-bean-spr...
#  2  {Food-coulouring, Cheese-puffs, Seafood, Whole...
#  3  {Croque-monsieur, Fruchtnektar, Food-coulourin...
#  4  {Croque-monsieur, White-pitta-bread, Food-coul...  ,
#    RouteId Order TruckCode    StartCity                  EndCity  \
#  0     141     0        41  Dania Beach              Orangeville
#  1     141     1        41  Orangeville                  Yashiro
#  2     141     2        41      Yashiro                   Gualán
#  3     141     3        41       Gualán                   Abadan
#  4     141     4        41       Abadan              Srīrāmnagar
#  5     141     5        41  Srīrāmnagar                Sonneberg
#  6     141     6        41    Sonneberg  Marechal Cândido Rondon
#
#                                                 Items
#  0  {Suppenwurfel, Gratins-de-legumes, Soupes, Qus...
#  1  {Faux-fromage, Fresh-garlic, Wasabi, Aperitif,...
#  2  {Power-drink, Corned-beef, Chicken-pies, Custa...
#  3  {Power-drink, Sunstream-tomatoes, Cottage-chee...
#  4  {Power-drink, Griechische-joghurt, Sunstream-t...
#  5  {Power-drink, Griechische-joghurt, Absinth, Pa...
#  6  {Churned-cream, Crsips, Dark-chocolate-block, ...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0     142     0        20        Gadag    Dashtobod
#  1     142     1        20    Dashtobod  Hobaramachi
#  2     142     2        20  Hobaramachi          Bor
#
#                                                 Items
#  0  {Pitta-breads, Fruit-flavoured-drink, Sirop-de...
#  1  {Fruit-flavoured-drink, Sirop-de-fruits, Diet-...
#  2  {Cremes-desserts, Nutrition-bar, Fruit-flavour...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0     143     0         2     Iradan  Toamasina
#  1     143     1         2  Toamasina   Podujeva
#
#                                                 Items
#  0  {Sunflower-spread, Soup-mixes, Popping-corn, C...
#  1  {Sunflower-spread, Milchprodukt, Popping-corn,...  ,
#    RouteId Order TruckCode StartCity     EndCity  \
#  0     144     0        15  Peterhof     Huizhou
#  1     144     1        15   Huizhou  Batu Pahat
#
#                                                 Items
#  0  {Babycorn, Barres-de-cereales, Lamb-chops, Spa...
#  1  {Chorizos, Sables, Chicken-kiev, Lamb-chops, C...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0     145     0        28   Guanare  Eberbach
#  1     145     1        28  Eberbach      Ordu
#  2     145     2        28      Ordu  Griffith
#
#                                                 Items
#  0  {Herring-fillets, Dindes, Surgelati, Sunflower...
#  1  {Pates, Cured-sausage, Corn-tortilla-chips, Bi...
#  2  {Natural-spring-water, Pates, Instant-porridge...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0     146     0        21   Bhāndāria        Ordu
#  1     146     1        21        Ordu      Luqiao
#  2     146     2        21      Luqiao   Toamasina
#  3     146     3        21   Toamasina     Hornsby
#  4     146     4        21     Hornsby  Batu Pahat
#  5     146     5        21  Batu Pahat         Bor
#
#                                                 Items
#  0  {Mackerel-filets-in-sunflower-oil, Fish and me...
#  1  {Mackerel-filets-in-sunflower-oil, Fish and me...
#  2  {Mackerel-filets-in-sunflower-oil, Saucisses-a...
#  3  {Saucisses-aux-lentilles, Turkish-delight, Mil...
#  4  {Saucisses-aux-lentilles, Vleeswaren, Artifici...
#  5  {Bread-mix, Saucisses-aux-lentilles, Kecap-man...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0     147     0         9     Pariaman  Srīrāmnagar
#  1     147     1         9  Srīrāmnagar        Deoli
#  2     147     2         9        Deoli      Goražde
#
#                                                 Items
#  0  {Ratatouille, Saucisses-aux-lentilles, Vleeswa...
#  1  {Ratatouille, Gratin-de-chou-fleur, Saucisses-...
#  2  {Citrouille-en-conserve, Gratin-de-chou-fleur,...  ,
#    RouteId Order TruckCode         StartCity           EndCity  \
#  0     148     0        20       Hobaramachi               Bor
#  1     148     1        20               Bor  Farmington Hills
#  2     148     2        20  Farmington Hills       Orangeville
#
#                                                 Items
#  0  {Kidney-beans, Lait-de-vache-concentre-non-suc...
#  1  {Marfona-variety, Fat-free-milk, Pate, Cake-mi...
#  2  {Quenelles, Fresh-raspberries, Preparations-de...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0     149     0         8             Guanare               Leigh
#  1     149     1         8               Leigh           Dashtobod
#  2     149     2         8           Dashtobod             Jaunpur
#  3     149     3         8             Jaunpur         Ath Thawrah
#  4     149     4         8         Ath Thawrah            Diamante
#  5     149     5         8            Diamante  Tixtla de Guerrero
#  6     149     6         8  Tixtla de Guerrero          Santo Tomé
#
#                                                 Items
#  0  {Fruit-confectionary, Prunes, Complements-alim...
#  1  {Fruit-confectionary, Milk substitute, Herring...
#  2  {Fruit-confectionary, Parve, Frozen-vegetables...
#  3  {Frozen-vegetables-mix, Soymilk, Whole-bean-sp...
#  4  {Sushi, Soymilk, Caviar substitutes, Aloe-vera...
#  5  {Ratatouille, Sushi, Sourdough-bread, Sandwich...
#  6  {Gratin-de-chou-fleur, Rice-candy, Diced-tomat...  ]

# %%
all_trips = pd.concat(routes)

# %%
# Save the trips for the mining part
all_trips.to_csv("route_trips.csv")
