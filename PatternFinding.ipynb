# %%
import pandas as pd
import numpy  as np
import re                              # Used for splitting the Items with multiple delimiters
from   collections import Counter      # To count items in dictionaries
from   itertools   import combinations # To generate combinations of items
import functools

# The dataset was created with the notebook "DatasetCreation.ipynb".

routes = pd.read_csv('route_trips.csv', 
                     delimiter = ',', 
                     encoding  = 'utf-8')

routes.drop(routes.columns[0], 
            axis    = 1, 
            inplace = True)

# %%
# Prepare the delimiters for splitting the items
delimiters   = ",", "{", "}", "'"
regexPattern = '|'.join(map(re.escape, delimiters))

# %%
# Produce a new column for the Items
newItemsColumn = []
for index in range(0, len(routes)):
    tmp = list(filter(None, re.split(regexPattern, routes.Items[index])))
    newItemsColumn.append([item for item in tmp 
                                   if item.strip()])
routes.Items = newItemsColumn

# %%
# Set the threshold for the support of Frequent itemset theory
support = 8
items   = []
items   = [item for items in routes.Items 
                   for item in items]

# Count the occurrencies of each item in the whole dataset
# ("items" now contains a list of all the products for each trip)
itemCount = Counter(items)

# Select only those items that appear more than the support
frequentItems = [(item,) for item in itemCount 
                         if itemCount[item] >= support]

#len(frequentItems)

# %%
# Now we remove from the Items those that are not frequentItems
routes.Items = [list(filter(lambda i: i in [f for ft in frequentItems for f in ft], items)) for items in routes.Items]

# %%
# Here we generate combinations of 2 frequent items 
combination   = [list(combinations(items, 2)) for items in routes.Items]
comb          = [comb for combs in combination 
                         for comb in combs]

# %%
# Count how many pairs there are for each combination
pairCount     = Counter(comb)
# and select only those that appear more than the support
frequentPairs = [comb for comb in pairCount 
                         if pairCount[comb] >= support]

# %%
# then sort them for next operations
frequentPairs = [sorted(fp) for fp in frequentPairs]
frequentPairs = list(set([tuple(fp) for fp in frequentPairs]))
#frequentPairs

# %%
itemInPairs = set(f for fp in frequentPairs for f in fp)

# %%
# Now we remove from the Items those that are not frequentItems
itemsithStep = [list(filter(lambda i: i in itemInPairs, items)) for items in routes.Items]

# %%
#def Remove(duplicate): 
#    final_list = [] 
#    for num in duplicate: 
#        if num not in final_list: 
#            final_list.append(num) 
#    return final_list

# %%
# Max depth for frequent tuples
#depth = 6
#frequentTuples = []
#for i in range(2,depth):
#    subset = []
#    for sl in range(0,len(frequentPairs)):
#        tryitems = frequentPairs[sl][:-1]
#        possibleitems = []
#        for asl in frequentPairs[:sl]+frequentPairs[sl+1:]:
#            if (len(set(tryitems).intersection(set(asl))) == len(tryitems)):
#                possibleitems.append(list(set(asl).difference(set(tryitems))))
#        if possibleitems != []:
#            for ssl in list(combinations(frequentPairs[sl], len(frequentPairs[sl])-1)):
#                if ssl != tryitems:
#                    for el in possibleitems:
#                        elem = el
#                        elem.extend(ssl)
#                        c = tuple(set(elem))
#                        if(set(c) in [set(fp) for fp in frequentPairs]):
#                            c = list(c)
#                            c.extend(list(item for item in tryitems))
#                            subset.append(tuple(set(c)))
#    subset = [tuple(s) for s in Remove(list(set(sb) for sb in subset))]
#    combination = [list(combinations(items, i+1)) for items in routes.Items]
#    comb = [tuple(comb) for combs in combination 
#                for comb in combs]
#    tuplesCount = Counter(comb)
    # and select only those that appear more than the support
#    frequentT = [tuples for tuples in tuplesCount 
#                        if tuplesCount[tuples] >= support]
#    frequentTuples.append(frequentT)
#    frequentPairs = frequentT

# %%
# Max depth for frequent tuples
depth = 6
frequentTuples = []
for i in range(2,depth):
    subset = []
    combination = [list(combinations(items, i+1)) for items in itemsithStep]
    comb = [tuple(comb) for combs in combination 
                for comb in combs]
    tuplesCount = Counter(comb)
    frequentT = [tuples for tuples in tuplesCount 
                            if tuplesCount[tuples] >= support]
    frequentTuples.append(frequentT)
    itemInTuples = set(f for fp in frequentT for f in fp)
    itemsithStep = [list(filter(lambda i: i in itemInTuples, items)) for items in itemsithStep]

# %%
frequentTuples
# Out:
# [[('Frozen-spring-rolls', 'Groceries', 'Snack-bar'),
#   ('Malt-vinegar', 'Coleslaw-dressing', 'Helles-schankbier'),
#   ('Malt-vinegar', 'Coleslaw-dressing', 'Chocolat-au-lait'),
#   ('Malt-vinegar', 'Coleslaw-dressing', 'Soeppoeder'),
#   ('Malt-vinegar', 'Chocolat-au-lait', 'Soeppoeder'),
#   ('Coleslaw-dressing', 'Helles-schankbier', 'Soeppoeder'),
#   ('Coleslaw-dressing', 'Chocolat-au-lait', 'Soeppoeder'),
#   ('Mixed-nuts', 'Lime-marmalades', 'Cooking-oil'),
#   ('Mixed-nuts', 'Cooking-oil', 'Kartoffelchips'),
#   ('Jus-d-orange', 'Crossiants', 'Indian-food'),
#   ('Jus-d-orange', 'Indian-food', 'Gelati'),
#   ('Jus-d-orange', 'Indian-food', 'Dried-parmesan-cheese'),
#   ('Indian-food', 'Gelati', 'Dried-parmesan-cheese'),
#   ('Fruit-drinks', 'Frozen-snacks', 'Kauwgom'),
#   ('Fruit-drinks', 'Frozen-snacks', 'Coffee-cake'),
#   ('Fruit-drinks', 'Kauwgom', 'Coffee-cake'),
#   ('Frozen-snacks', 'Kauwgom', 'Coffee-cake'),
#   ('Produits-ssans-gluten', 'Kauwgom', 'Coffee-cake'),
#   ('Pates-a-tartiner-aux-noisettes-et-au-cacao',
#    'Beef-stroganoff',
#    'Manuka-honey'),
#   ('Saucisses-aux-lentilles', 'Beef-stroganoff', 'Coconut-cream'),
#   ('Saucisses-aux-lentilles', 'Beef-stroganoff', 'Manuka-honey'),
#   ('Saucisses-aux-lentilles', 'Schokoladen', 'Roasted-garlic'),
#   ('Beef-stroganoff', 'Manuka-honey', 'Rice-noodles'),
#   ('Caramelized-red-onion-chutney', 'Recipe-mixes', 'Groceries'),
#   ('Creme-caramel', 'Hoki-fish-fillets', 'Basa-fish'),
#   ('White-coconut-chocolate', 'Strawberry-licorice', 'Bieres-blondes'),
#   ('White-coconut-chocolate', 'Strawberry-licorice', 'White-plain-flour'),
#   ('White-coconut-chocolate',
#    'Strawberry-licorice',
#    'Sparkling-mineral-waters'),
#   ('White-coconut-chocolate', 'Strawberry-licorice', 'Roasted-garlic'),
#   ('White-coconut-chocolate', 'Strawberry-licorice', 'Syrups'),
#   ('White-coconut-chocolate', 'Sparkling-mineral-waters', 'Roasted-garlic'),
#   ('White-coconut-chocolate', 'Soup-mixes', 'Dried-pasta'),
#   ('White-coconut-chocolate', 'Syrups', 'Dried-pasta'),
#   ('Strawberry-licorice', 'Sparkling-mineral-waters', 'Roasted-garlic'),
#   ('Brussels-pate', 'Mexican-food', 'Dried-pasta'),
#   ('White-coconut-chocolate', 'Syrups', 'Matzos'),
#   ('White-coconut-chocolate', 'Cheese-crackers', 'Strawberry-licorice'),
#   ('Kauwgom', 'Plats-prepares-surgeles', 'Chopeed-tomatoes'),
#   ('Double-chocolate-milk', 'Fruit-drinks', 'Frozen-dumpling'),
#   ('Double-chocolate-milk', 'Fruit-drinks', 'Kauwgom'),
#   ('Double-chocolate-milk', 'Fruit-drinks', 'Canned-pineapple'),
#   ('Double-chocolate-milk', 'Frozen-snacks', 'Coffee-cake'),
#   ('Double-chocolate-milk', 'Frozen-dumpling', 'Kauwgom'),
#   ('Double-chocolate-milk', 'Frozen-dumpling', 'Canned-pineapple'),
#   ('Double-chocolate-milk', 'Kauwgom', 'Canned-pineapple'),
#   ('Fruit-drinks', 'Frozen-snacks', 'Frozen-dumpling'),
#   ('Fruit-drinks', 'Frozen-dumpling', 'Kauwgom'),
#   ('Fruit-drinks', 'Frozen-dumpling', 'Canned-pineapple'),
#   ('Fruit-drinks', 'Kauwgom', 'Canned-pineapple'),
#   ('Frozen-snacks', 'Frozen-dumpling', 'Kauwgom'),
#   ('Frozen-snacks', 'Frozen-dumpling', 'Coffee-cake'),
#   ('Frozen-dumpling', 'Kauwgom', 'Plats-prepares-surgeles'),
#   ('Frozen-dumpling', 'Kauwgom', 'Coffee-cake'),
#   ('Frozen-dumpling', 'Kauwgom', 'Chopeed-tomatoes'),
#   ('Frozen-dumpling', 'Kauwgom', 'Canned-pineapple'),
#   ('Fresh-lemons', 'Groceries', 'Sugar-cane-drink'),
#   ('Groceries', 'Sugar-cane-drink', 'Hamblokjes')],
#  [('Malt-vinegar', 'Coleslaw-dressing', 'Chocolat-au-lait', 'Soeppoeder'),
#   ('Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake'),
#   ('White-coconut-chocolate',
#    'Strawberry-licorice',
#    'Sparkling-mineral-waters',
#    'Roasted-garlic'),
#   ('Double-chocolate-milk', 'Fruit-drinks', 'Frozen-dumpling', 'Kauwgom'),
#   ('Double-chocolate-milk',
#    'Fruit-drinks',
#    'Frozen-dumpling',
#    'Canned-pineapple'),
#   ('Double-chocolate-milk', 'Fruit-drinks', 'Kauwgom', 'Canned-pineapple'),
#   ('Double-chocolate-milk', 'Frozen-dumpling', 'Kauwgom', 'Canned-pineapple'),
#   ('Fruit-drinks', 'Frozen-dumpling', 'Kauwgom', 'Canned-pineapple'),
#   ('Frozen-snacks', 'Frozen-dumpling', 'Kauwgom', 'Coffee-cake')],
#  [('Double-chocolate-milk',
#    'Fruit-drinks',
#    'Frozen-dumpling',
#    'Kauwgom',
#    'Canned-pineapple')],
#  []]

# %%
# popularTuples will be our container for interesting objects. 
# Now we can find inside popular items and popular pairs but it is going to be extended.
popularTuples = frequentItems
popularTuples.extend(frequentPairs)
for ft in frequentTuples:
    popularTuples.extend(ft)

#popularTuples

# %%
def matches(rid, order, popularTuples):
    itemList   = []
    orderItems = routes.Items[(routes.RouteId == rid) & 
                              (routes.Order   == order)
                             ].tolist()[0]
    for obj in popularTuples:
        # If the object is a pair (so it is saved as list)
        check = True
        for item in obj:
            if item not in orderItems:
                check = False
        if check:
            itemList.append(list(obj))
    return itemList
    

def nextTuple(rid, order, popularTuples):
    # If the next does exist
    if(not routes[(routes.RouteId == rid) & 
                  (routes.Order   == order)
                 ].empty):
        return matches(rid, order, popularTuples)
    else:
    # Otherwise return an empty list
        return []

def divideOrder(keys, popularTuples):
    route = -1
    order = -1
    itemsOrdered = []
    itemsBrown = []
    for key in keys:
        if(key[0] == route):
            t = nextTuple(key[0], key[1], popularTuples)
            for i in range(0, key[1]-order+1):
                itemsBrown.append(tuple([i,t]))
        else:
            if route != -1:
                itemsOrdered.extend(itemsBrown)
                itemsBrown = []
            route = key[0]
            order = key[1]
            t = nextTuple(key[0], key[1], popularTuples)
            itemsBrown.append(tuple([0,t]))
    itemsOrdered.extend(itemsBrown)
    return itemsOrdered
            
    
def searchNext(tuples, popularTuples):
    keys      = [(routes.RouteId[row], routes.Order[row]) 
                 for row in range(0, len(routes)) 
                     if set(tuples).intersection(set(routes.Items[row])) == set(tuples)]
    newTuples = divideOrder(keys, popularTuples)
    return newTuples

# %%
popularPatterns = [(pop, searchNext(pop, popularTuples)) for pop in popularTuples]
#popularPatterns

# %%
# Limit of classification for frequent Patterns
limit = 10
patterns = []
for pattern in popularPatterns:
    patternLevel = [[(x[0], y), 1] for x in pattern[1] for y in x[1]]
    for lvl1 in range(0,len(patternLevel)):
        for lvl2 in range(0,len(patternLevel)):
            if (patternLevel[lvl1][0] == patternLevel[lvl2][0]) & (lvl1 != lvl2):
                patternLevel[lvl1][1] += patternLevel[lvl2][1]
                patternLevel[lvl2][1] = 0
    finalPattern = []
    for i in range(0,len(patternLevel)):
        if patternLevel[i][1] > limit:
            finalPattern.append(patternLevel[i])
    patterns.append((pattern[0],finalPattern))

# %%
patterns
# Out:
# [(('Scottish-shortbread',), []),
#  (('Olives-denoyautees',), []),
#  (('Miels',), [[(0, ['Miels']), 16], [(1, ['Miels']), 11]]),
#  (('Pasteurized-milk',), [[(0, ['Pasteurized-milk']), 14]]),
#  (('Indian-food-mixes',), []),
#  (('Fat-free-milk',), [[(0, ['Fat-free-milk']), 11]]),
#  (('Brussels-pate',),
#   [[(0, ['White-plain-flour']), 13],
#    [(0, ['Brussels-pate', 'White-plain-flour']), 13],
#    [(1, ['Brussels-pate']), 17],
#    [(2, ['Brussels-pate']), 12],
#    [(0, ['Brussels-pate']), 24],
#    [(0, ['Chicken-thighs']), 12],
#    [(0, ['Brussels-pate', 'Chicken-thighs']), 12]]),
#  (('Balsamic-vinaigrette',), []),
#  (('Organic-tomatoes',), [[(0, ['Organic-tomatoes']), 13]]),
#  (('Pesce-curado',), [[(0, ['Pesce-curado']), 15]]),
#  (('White-coconut-chocolate',),
#   [[(0, ['Syrups']), 11],
#    [(0, ['Strawberry-licorice']), 12],
#    [(0, ['Strawberry-licorice', 'White-coconut-chocolate']), 12],
#    [(0, ['Syrups', 'White-coconut-chocolate']), 11],
#    [(1, ['White-coconut-chocolate']), 12],
#    [(0, ['White-coconut-chocolate']), 19]]),
#  (('Aliments-d-origine-vegetale',), []),
#  (('Green-kale',), [[(0, ['Green-kale']), 22], [(1, ['Green-kale']), 12]]),
#  (('Banana-nut-loaf',),
#   [[(0, ['Faux-fromage']), 11],
#    [(0, ['Banana-nut-loaf', 'Faux-fromage']), 11],
#    [(0, ['Banana-nut-loaf']), 42],
#    [(1, ['Banana-nut-loaf']), 30],
#    [(2, ['Banana-nut-loaf']), 21],
#    [(3, ['Banana-nut-loaf']), 13]]),
#  (('Cake-mix',), [[(0, ['Cake-mix']), 13]]),
#  (('Coriandre',), []),
#  (('Baby-sanmarzano-tomatoes',), [[(0, ['Baby-sanmarzano-tomatoes']), 12]]),
#  (('Piccalilli',), [[(0, ['Piccalilli']), 11]]),
#  (('Peanut-in-chocolate',), []),
#  (('Thes-verts',), [[(0, ['Thes-verts']), 32], [(1, ['Thes-verts']), 20]]),
#  (('Cocktail-sauces',), []),
#  (('Baking',), [[(0, ['Baking']), 25], [(1, ['Baking']), 12]]),
#  (('Gelati',), [[(0, ['Gelati']), 21], [(1, ['Gelati']), 13]]),
#  (('Chia-seeds',), [[(0, ['Chia-seeds']), 19], [(1, ['Chia-seeds']), 11]]),
#  (('Whisky-ecossais',), [[(0, ['Whisky-ecossais']), 12]]),
#  (('Sweet-chilli-sauce',), []),
#  (('Steak-kidney-pie',), []),
#  (('Asian-grocery',),
#   [[(0, ['Asian-grocery']), 23], [(1, ['Asian-grocery']), 15]]),
#  (('Asian-food',), [[(0, ['Asian-food']), 19], [(1, ['Asian-food']), 14]]),
#  (('Prawn-crackers',), []),
#  (('All-steak-pie',), []),
#  (('Damn-if-i-know',), []),
#  (('Beef-mince',), [[(0, ['Beef-mince']), 23]]),
#  (('Butter-shortbread-fingers',), [[(0, ['Butter-shortbread-fingers']), 13]]),
#  (('Redcurrant-tea',),
#   [[(1, ['Redcurrant-tea']), 13], [(0, ['Redcurrant-tea']), 24]]),
#  (('Vinho-tinto',), []),
#  (('Dried-pasta',), [[(0, ['Dried-pasta']), 18], [(1, ['Dried-pasta']), 11]]),
#  (('Frozen-spring-rolls',),
#   [[(0, ['Frozen-spring-rolls']), 18],
#    [(0, ['Groceries']), 12],
#    [(0, ['Frozen-spring-rolls', 'Groceries']), 12],
#    [(1, ['Frozen-spring-rolls']), 12]]),
#  (('Hot-pepper-sauce',), []),
#  (('Groceries',),
#   [[(0, ['Frozen-spring-rolls']), 12],
#    [(0, ['Snack-bar']), 13],
#    [(0, ['Groceries', 'Snack-bar']), 13],
#    [(0, ['Frozen-spring-rolls', 'Groceries']), 12],
#    [(0, ['Groceries']), 26],
#    [(1, ['Groceries']), 18],
#    [(2, ['Groceries']), 11]]),
#  (('Corn-snacks',), [[(0, ['Corn-snacks']), 11]]),
#  (('Flour-tortillas',), [[(0, ['Flour-tortillas']), 15]]),
#  (('Snack-bar',),
#   [[(0, ['Groceries']), 13],
#    [(0, ['Groceries', 'Snack-bar']), 13],
#    [(0, ['Snack-bar']), 23],
#    [(1, ['Snack-bar']), 14]]),
#  (('Chia-samen',), [[(0, ['Chia-samen']), 12]]),
#  (('Corn-tortilla',), [[(0, ['Corn-tortilla']), 14]]),
#  (('Multivitamin-supplement',),
#   [[(0, ['Multivitamin-supplement']), 22],
#    [(1, ['Multivitamin-supplement']), 13]]),
#  (('Mint-jellies',), [[(0, ['Mint-jellies']), 16]]),
#  (('Faux-fromage',),
#   [[(0, ['Banana-nut-loaf']), 11],
#    [(0, ['Faux-fromage']), 25],
#    [(0, ['Banana-nut-loaf', 'Faux-fromage']), 11],
#    [(1, ['Faux-fromage']), 17],
#    [(2, ['Faux-fromage']), 13]]),
#  (('Pineapple-slices-in-juice',), [[(0, ['Pineapple-slices-in-juice']), 15]]),
#  (('Rice-cakes',), []),
#  (('Cioccolatini',), []),
#  (('Chocolats',), []),
#  (('Canned-precooked-meat',), []),
#  (('Pringles-potato-chips',), [[(0, ['Pringles-potato-chips']), 17]]),
#  (('Choux-farcis',),
#   [[(0, ['Choux-farcis']), 23], [(1, ['Choux-farcis']), 12]]),
#  (('Mushroom-in-sunflower-oil',), [[(0, ['Mushroom-in-sunflower-oil']), 12]]),
#  (('Crackers-sans-gluten',), [[(0, ['Crackers-sans-gluten']), 14]]),
#  (('Malt-vinegar',),
#   [[(0, ['Malt-vinegar']), 27],
#    [(1, ['Malt-vinegar']), 19],
#    [(2, ['Malt-vinegar']), 12]]),
#  (('Protein-powder-drink-mix',), [[(0, ['Protein-powder-drink-mix']), 13]]),
#  (('Complements-alimentaires',), []),
#  (('Paste',), [[(0, ['Paste']), 12]]),
#  (('Sugar-cane-drink',),
#   [[(0, ['Fresh-juices']), 12],
#    [(0, ['Fresh-juices', 'Sugar-cane-drink']), 12],
#    [(0, ['Sugar-cane-drink']), 34],
#    [(1, ['Sugar-cane-drink']), 19],
#    [(2, ['Sugar-cane-drink']), 12]]),
#  (('Indian-readymeals',), []),
#  (('Venison',), [[(0, ['Venison']), 20]]),
#  (('Cremes-vegetales-a-base-de-coco-pour-cuisiner',),
#   [[(0, ['Cremes-vegetales-a-base-de-coco-pour-cuisiner']), 12]]),
#  (('Strawberry-topping',), []),
#  (('Peels',), [[(0, ['Peels']), 14]]),
#  (('Asian-sauces',), [[(0, ['Asian-sauces']), 11]]),
#  (('Easter-buns',),
#   [[(0, ['Fresh-juices']), 12],
#    [(0, ['Easter-buns', 'Fresh-juices']), 12],
#    [(1, ['Fresh-juices']), 11],
#    [(1, ['Easter-buns', 'Fresh-juices']), 11],
#    [(1, ['Easter-buns']), 15],
#    [(2, ['Easter-buns']), 13],
#    [(3, ['Easter-buns']), 11],
#    [(0, ['Easter-buns']), 21]]),
#  (('Seafood',), []),
#  (('Root-beer',), [[(0, ['Root-beer']), 11]]),
#  (('Plant-based foods and beverages',), []),
#  (('Cheese-singles',), [[(0, ['Cheese-singles']), 11]]),
#  (('Garlic-mashed-potatoes',),
#   [[(0, ['Conservation']), 11],
#    [(0, ['Conservation', 'Garlic-mashed-potatoes']), 11],
#    [(1, ['Garlic-mashed-potatoes']), 11],
#    [(0, ['Garlic-mashed-potatoes']), 18]]),
#  (('Fruit-and-nut-mix',), [[(0, ['Fruit-and-nut-mix']), 14]]),
#  (('Fresh-juices',),
#   [[(0, ['Easter-buns']), 12],
#    [(0, ['Easter-buns', 'Fresh-juices']), 12],
#    [(2, ['Fresh-juices']), 16],
#    [(3, ['Fresh-juices']), 11],
#    [(0, ['Sugar-cane-drink']), 12],
#    [(0, ['Fresh-juices', 'Sugar-cane-drink']), 12],
#    [(1, ['Fresh-juices']), 25],
#    [(0, ['Fresh-juices']), 38]]),
#  (('Green-salads',),
#   [[(0, ['Green-salads']), 18], [(1, ['Green-salads']), 12]]),
#  (('Tabbouleh',), []),
#  (('Kiwi-fruit',), [[(0, ['Kiwi-fruit']), 12]]),
#  (('Conservation',),
#   [[(0, ['Garlic-mashed-potatoes']), 11],
#    [(0, ['Conservation']), 17],
#    [(0, ['Conservation', 'Garlic-mashed-potatoes']), 11],
#    [(1, ['Conservation']), 12]]),
#  (('Beer-batter-fries',),
#   [[(0, ['Beer-batter-fries']), 20],
#    [(0, ['Pastrami']), 11],
#    [(0, ['Beer-batter-fries', 'Pastrami']), 11],
#    [(1, ['Beer-batter-fries']), 11]]),
#  (('Creme-brulee',), []),
#  (('Pastrami',),
#   [[(0, ['Beer-batter-fries']), 11],
#    [(0, ['Pastrami']), 18],
#    [(0, ['Beer-batter-fries', 'Pastrami']), 11]]),
#  (('Cordials',), [[(0, ['Cordials']), 14]]),
#  (('Backpulver',), []),
#  (('Coffee-ice-cream',), [[(0, ['Coffee-ice-cream']), 11]]),
#  (('Kartoffelchips',),
#   [[(1, ['Kartoffelchips']), 14],
#    [(0, ['Kartoffelchips']), 22],
#    [(0, ['Lime-marmalades']), 11],
#    [(0, ['Cooking-oil']), 13],
#    [(0, ['Cooking-oil', 'Kartoffelchips']), 13],
#    [(0, ['Cooking-oil', 'Lime-marmalades']), 11]]),
#  (('Multiseeded-sliced-bread',),
#   [[(0, ['Multiseeded-sliced-bread']), 21],
#    [(1, ['Multiseeded-sliced-bread']), 15]]),
#  (('Pitta-breads',),
#   [[(1, ['Pitta-breads']), 11], [(0, ['Pitta-breads']), 17]]),
#  (('Tortilla-chips',), [[(0, ['Tortilla-chips']), 12]]),
#  (('Toppings',), [[(0, ['Toppings']), 35], [(1, ['Toppings']), 20]]),
#  (('Corn-kernels',), [[(0, ['Corn-kernels']), 12]]),
#  (('Capsicums',), []),
#  (('Powder',), []),
#  (('Pear-cider',), [[(0, ['Pear-cider']), 12]]),
#  (('Aoli-sauce',), [[(0, ['Aoli-sauce']), 13]]),
#  (('Fecules',),
#   [[(2, ['Fecules']), 13], [(0, ['Fecules']), 30], [(1, ['Fecules']), 19]]),
#  (('Cream-of-tartar',), [[(0, ['Cream-of-tartar']), 17]]),
#  (('Cous-cous',), [[(0, ['Cous-cous']), 16]]),
#  (('Skim-milk',), [[(0, ['Skim-milk']), 13]]),
#  (('Indian-sauces',), [[(0, ['Indian-sauces']), 17]]),
#  (('Sugar-free-confectionary',), [[(0, ['Sugar-free-confectionary']), 11]]),
#  (('Prepackaged-sandwiches',),
#   [[(0, ['Prepackaged-sandwiches']), 16],
#    [(1, ['Prepackaged-sandwiches']), 12]]),
#  (('Farina',), []),
#  (('Spice-red-pepper',),
#   [[(1, ['Spice-red-pepper']), 16], [(0, ['Spice-red-pepper']), 26]]),
#  (('Schwarztees',), [[(0, ['Schwarztees']), 17], [(1, ['Schwarztees']), 12]]),
#  (('Concombres',), [[(0, ['Concombres']), 19], [(1, ['Concombres']), 13]]),
#  (('Sliced-beetroot',),
#   [[(0, ['Sliced-beetroot']), 17], [(1, ['Sliced-beetroot']), 12]]),
#  (('Thes-glaces',), [[(0, ['Thes-glaces']), 11]]),
#  (('Crema-spalmabile',),
#   [[(0, ['Crema-spalmabile']), 21], [(1, ['Crema-spalmabile']), 14]]),
#  (('Danette-chocolate-dessert',), []),
#  (('Artisan products',),
#   [[(1, ['Artisan products']), 14], [(0, ['Artisan products']), 27]]),
#  (('Confectioner',), [[(0, ['Confectioner']), 12]]),
#  (('Diced-tomatoes',), []),
#  (('Orange-cake',), []),
#  (('Lamb-breast',), []),
#  (('Susswaren',), [[(0, ['Susswaren']), 14]]),
#  (('Flavouring-extract',), [[(0, ['Flavouring-extract']), 11]]),
#  (('Gateau-chinois',),
#   [[(0, ['Gateau-chinois']), 28],
#    [(0, ['Sweeteners']), 12],
#    [(0, ['Gateau-chinois', 'Sweeteners']), 12],
#    [(1, ['Gateau-chinois']), 18],
#    [(2, ['Gateau-chinois']), 11]]),
#  (('Snow-peas',), []),
#  (('Sparkling-mineral-waters',),
#   [[(1, ['Sparkling-mineral-waters']), 24],
#    [(2, ['Sparkling-mineral-waters']), 15],
#    [(0, ['Sparkling-mineral-waters']), 36]]),
#  (('Balsamic-vinaigrette-dressing',),
#   [[(0, ['Balsamic-vinaigrette-dressing']), 20]]),
#  (('Barbeque-sauce',), [[(0, ['Barbeque-sauce']), 12]]),
#  (('Water-crackers',), [[(0, ['Water-crackers']), 16]]),
#  (('Mixed-nuts',),
#   [[(1, ['Mixed-nuts']), 14],
#    [(0, ['Mixed-nuts']), 21],
#    [(0, ['Cooking-oil']), 11],
#    [(0, ['Cooking-oil', 'Mixed-nuts']), 11]]),
#  (('Gelee-de-groseille',), []),
#  (('Biscuits-with-dark-chocolate',),
#   [[(0, ['Biscuits-with-dark-chocolate']), 11]]),
#  (('Amaretto',), [[(0, ['Amaretto']), 11]]),
#  (('Milchprodukt',), []),
#  (('Yellow-mustard',), [[(0, ['Yellow-mustard']), 12]]),
#  (('Syrups',),
#   [[(0, ['White-coconut-chocolate']), 11],
#    [(0, ['Syrups', 'White-coconut-chocolate']), 11],
#    [(1, ['Syrups']), 14],
#    [(0, ['Syrups']), 20]]),
#  (('Frozen-chicken',),
#   [[(1, ['Frozen-chicken']), 11], [(0, ['Frozen-chicken']), 16]]),
#  (('Plastic-surgery',), [[(0, ['Plastic-surgery']), 17]]),
#  (('Garlic-bread',), []),
#  (('Lasagne-sheets',), []),
#  (('Produits-ssans-gluten',),
#   [[(0, ['Produits-ssans-gluten']), 15],
#    [(0, ['Coffee-cake']), 12],
#    [(0, ['Coffee-cake', 'Produits-ssans-gluten']), 12]]),
#  (('Carrot-cake',), [[(0, ['Carrot-cake']), 23], [(1, ['Carrot-cake']), 16]]),
#  (('Chopeed-tomatoes',),
#   [[(0, ['Kauwgom']), 11],
#    [(0, ['Chopeed-tomatoes', 'Kauwgom']), 11],
#    [(0, ['Chopeed-tomatoes']), 16]]),
#  (('Latticini',), []),
#  (('Coffee-cake',),
#   [[(0, ['Fruit-drinks']), 12],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 12],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Produits-ssans-gluten']), 12],
#    [(0, ['Kauwgom']), 14],
#    [(0, ['Coffee-cake', 'Kauwgom']), 14],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 12],
#    [(0, ['Coffee-cake', 'Produits-ssans-gluten']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 12],
#    [(0, ['Frozen-snacks']), 15],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 15],
#    [(0, ['Coffee-cake']), 25],
#    [(1, ['Coffee-cake']), 16],
#    [(2, ['Coffee-cake']), 11]]),
#  (('Tomkin-tomatoes',), [[(0, ['Tomkin-tomatoes']), 15]]),
#  (('Gravy',), [[(0, ['Gravy']), 21], [(1, ['Gravy']), 13]]),
#  (('Prosecco',),
#   [[(3, ['Prosecco']), 14],
#    [(2, ['Prosecco']), 19],
#    [(0, ['Prosecco']), 36],
#    [(1, ['Prosecco']), 26]]),
#  (('Curry',), []),
#  (('Minced-lamb',), [[(0, ['Minced-lamb']), 18], [(1, ['Minced-lamb']), 12]]),
#  (('Coleslaw-dressing',),
#   [[(0, ['Soeppoeder']), 12],
#    [(0, ['Coleslaw-dressing', 'Soeppoeder']), 12],
#    [(0, ['Coleslaw-dressing']), 26],
#    [(1, ['Coleslaw-dressing']), 15]]),
#  (('Helles-schankbier',), [[(0, ['Helles-schankbier']), 11]]),
#  (('White-pitta-bread',), [[(0, ['White-pitta-bread']), 15]]),
#  (('Fresh-cabbage',), [[(0, ['Fresh-cabbage']), 15]]),
#  (('Emu-jerky',), []),
#  (('Chocolat-au-lait',), []),
#  (('Soeppoeder',),
#   [[(0, ['Coleslaw-dressing']), 12],
#    [(0, ['Coleslaw-dressing', 'Soeppoeder']), 12],
#    [(0, ['Soeppoeder']), 19]]),
#  (('Parve',), []),
#  (('Pralinen',), []),
#  (('Croissant-with-cocoa-cream',),
#   [[(0, ['Croissant-with-cocoa-cream']), 14]]),
#  (('Terrine',), [[(0, ['Terrine']), 16]]),
#  (('Cauliflower-cheese',), []),
#  (('Noix-de-paprika',), [[(0, ['Noix-de-paprika']), 16]]),
#  (('Gin',), [[(0, ['Gin']), 13]]),
#  (('Kaffir-lime-leaves',), [[(0, ['Kaffir-lime-leaves']), 14]]),
#  (('Mayonaise',), [[(0, ['Mayonaise']), 13]]),
#  (('Chinese-cinnamon-sticks',),
#   [[(0, ['Chinese-cinnamon-sticks']), 24],
#    [(1, ['Chinese-cinnamon-sticks']), 14]]),
#  (('Canned-fruit-salad',), [[(0, ['Canned-fruit-salad']), 13]]),
#  (('Carots',), []),
#  (('Schokoladen',),
#   [[(0, ['Schokoladen']), 19],
#    [(0, ['Saucisses-aux-lentilles']), 14],
#    [(0, ['Saucisses-aux-lentilles', 'Schokoladen']), 14],
#    [(1, ['Schokoladen']), 12]]),
#  (('Eau-de-vie',), [[(0, ['Eau-de-vie']), 12]]),
#  (('Swede',), []),
#  (('Produits-laitiers',), [[(0, ['Produits-laitiers']), 18]]),
#  (('Graines',), []),
#  (('Aliment-pour-chevaux',), [[(0, ['Aliment-pour-chevaux']), 11]]),
#  (('Pork-pies',), [[(0, ['Pork-pies']), 11]]),
#  (('Sweeteners',),
#   [[(0, ['Gateau-chinois']), 12],
#    [(0, ['Sweeteners']), 23],
#    [(0, ['Gateau-chinois', 'Sweeteners']), 12],
#    [(1, ['Sweeteners']), 14]]),
#  (('Fruit-cups',),
#   [[(0, ['Fruit-cups']), 20],
#    [(1, ['Fruit-cups']), 15],
#    [(2, ['Fruit-cups']), 11]]),
#  (('Steaks-haches-de-boeuf-frais',), []),
#  (('Seed-mix',), []),
#  (('Olive-ciabatta',), [[(0, ['Olive-ciabatta']), 12]]),
#  (('Profiteroles',), [[(0, ['Profiteroles']), 19]]),
#  (('Ciabatta',), [[(0, ['Ciabatta']), 17], [(1, ['Ciabatta']), 11]]),
#  (('Sweetcorn-and-peas',),
#   [[(1, ['Sweetcorn-and-peas']), 12], [(0, ['Sweetcorn-and-peas']), 21]]),
#  (('Cottage-cheese',), [[(0, ['Cottage-cheese']), 13]]),
#  (('Baguettes-de-pain',), []),
#  (('Microwave-popcorn',), [[(0, ['Microwave-popcorn']), 11]]),
#  (('Hokey-pokey-ice-cream-tubs',), []),
#  (('Lime-marmalades',),
#   [[(0, ['Kartoffelchips']), 11],
#    [(0, ['Cooking-oil']), 11],
#    [(0, ['Cooking-oil', 'Kartoffelchips']), 11],
#    [(0, ['Cooking-oil', 'Lime-marmalades']), 11],
#    [(0, ['Lime-marmalades']), 27],
#    [(1, ['Lime-marmalades']), 19],
#    [(2, ['Lime-marmalades']), 13]]),
#  (('Cooking-oil',),
#   [[(1, ['Cooking-oil']), 14],
#    [(0, ['Kartoffelchips']), 13],
#    [(0, ['Mixed-nuts']), 11],
#    [(0, ['Lime-marmalades']), 11],
#    [(0, ['Cooking-oil']), 23],
#    [(0, ['Cooking-oil', 'Kartoffelchips']), 13],
#    [(0, ['Cooking-oil', 'Lime-marmalades']), 11],
#    [(0, ['Cooking-oil', 'Mixed-nuts']), 11]]),
#  (('Turkey-burgers',),
#   [[(1, ['Turkey-burgers']), 13], [(0, ['Turkey-burgers']), 27]]),
#  (('Bbq-relish',), [[(1, ['Bbq-relish']), 11], [(0, ['Bbq-relish']), 17]]),
#  (('Edible-decorations',), []),
#  (('Scones',), [[(0, ['Scones']), 11]]),
#  (('Hoki-fish-fillets',),
#   [[(2, ['Hoki-fish-fillets']), 11],
#    [(0, ['Hoki-fish-fillets']), 22],
#    [(1, ['Hoki-fish-fillets']), 15]]),
#  (('Fromages',), [[(0, ['Fromages']), 11]]),
#  (('Nectar-de-pommes',), []),
#  (('Frozen-chinese-spring-roll-snacks',), []),
#  (('Indian-food',), [[(0, ['Indian-food']), 26], [(1, ['Indian-food']), 17]]),
#  (('Cinamon-donuts',), [[(0, ['Cinamon-donuts']), 13]]),
#  (('Cayenne-pepper-sauce',), [[(0, ['Cayenne-pepper-sauce']), 16]]),
#  (('Lingonberry-jams',), [[(0, ['Lingonberry-jams']), 17]]),
#  (('Cheese-puffs',), [[(0, ['Cheese-puffs']), 14]]),
#  (('Vinaigres',), []),
#  (('Kaffee',), []),
#  (('Muffin-mix',),
#   [[(0, ['Muffin-mix']), 24],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Kauwgom', 'Muffin-mix']), 11],
#    [(1, ['Muffin-mix']), 12]]),
#  (('Canned-lamb-tongue',), [[(0, ['Canned-lamb-tongue']), 14]]),
#  (('Fruit-confectionary',), []),
#  (('Iced-green-tea',), [[(0, ['Iced-green-tea']), 14]]),
#  (('Sandwichs',), [[(0, ['Sandwichs']), 18]]),
#  (('Biscuits-au-chocolat-noir',), []),
#  (('Crossiants',), [[(0, ['Crossiants']), 12]]),
#  (('Beef-stroganoff',),
#   [[(0, ['Beef-stroganoff']), 16],
#    [(0, ['Manuka-honey']), 11],
#    [(0, ['Beef-stroganoff', 'Manuka-honey']), 11]]),
#  (('Coconut-cream',),
#   [[(1, ['Coconut-cream']), 13], [(0, ['Coconut-cream']), 22]]),
#  (('Chocolate-bunny',),
#   [[(1, ['Chocolate-bunny']), 14], [(0, ['Chocolate-bunny']), 22]]),
#  (('Orange-chocolate',), [[(0, ['Orange-chocolate']), 24]]),
#  (('Sandwiches',), [[(0, ['Sandwiches']), 12]]),
#  (('Jus-d-orange',),
#   [[(0, ['Jus-d-orange']), 18], [(1, ['Jus-d-orange']), 13]]),
#  (('Hot-cross-buns',), []),
#  (('Fish-can',), []),
#  (('Mct-oil',), []),
#  (('Dried-parmesan-cheese',),
#   [[(0, ['Dried-parmesan-cheese']), 19],
#    [(1, ['Dried-parmesan-cheese']), 14]]),
#  (('Fruit-drinks',),
#   [[(0, ['Coffee-cake']), 12],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 12],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks']), 15],
#    [(0, ['Kauwgom']), 13],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 13],
#    [(1, ['Fruit-drinks']), 11]]),
#  (('Frozen-snacks',),
#   [[(0, ['Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Kauwgom']), 12],
#    [(0, ['Coffee-cake', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 12],
#    [(0, ['Coffee-cake']), 15],
#    [(0, ['Frozen-snacks']), 15],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 15]]),
#  (('Roasted-garlic',),
#   [[(0, ['Roasted-garlic']), 24], [(1, ['Roasted-garlic']), 15]]),
#  (('Kauwgom',),
#   [[(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Coffee-cake']), 14],
#    [(0, ['Frozen-snacks']), 12],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 12],
#    [(0, ['Coffee-cake', 'Kauwgom']), 14],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 12],
#    [(0, ['Fruit-drinks']), 13],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 13],
#    [(0, ['Canned-pineapple']), 12],
#    [(0, ['Canned-pineapple', 'Kauwgom']), 12],
#    [(0, ['Chopeed-tomatoes']), 11],
#    [(0, ['Muffin-mix']), 11],
#    [(0, ['Kauwgom']), 21],
#    [(0, ['Frozen-dumpling']), 13],
#    [(0, ['Chopeed-tomatoes', 'Kauwgom']), 11],
#    [(0, ['Kauwgom', 'Muffin-mix']), 11],
#    [(0, ['Frozen-dumpling', 'Kauwgom']), 13],
#    [(1, ['Kauwgom']), 14]]),
#  (('Hamblokjes',), [[(0, ['Hamblokjes']), 17]]),
#  (('Fresh-drinking-coconut',), []),
#  (('Coconut-milk-powder',),
#   [[(1, ['Coconut-milk-powder']), 11], [(0, ['Coconut-milk-powder']), 20]]),
#  (('Lemon-mousse',), []),
#  (('Pate',), []),
#  (('Fresh-lemons',), [[(0, ['Fresh-lemons']), 16]]),
#  (('Caramel-popcorn',), []),
#  (('Prepared-foods',), [[(0, ['Prepared-foods']), 15]]),
#  (('Beef-jerky',), [[(0, ['Beef-jerky']), 14]]),
#  (('Bhuja',), [[(0, ['Bhuja']), 19]]),
#  (('Plats-prepares-surgeles',), [[(0, ['Plats-prepares-surgeles']), 20]]),
#  (('Energy-balls',), []),
#  (('Sultanas',), [[(0, ['Sultanas']), 12]]),
#  (('Fresh-lamb-meat',), [[(0, ['Fresh-lamb-meat']), 12]]),
#  (('Oatcakes',), [[(0, ['Oatcakes']), 17], [(1, ['Oatcakes']), 12]]),
#  (('Food additives',), []),
#  (('Peanut-sauce',), [[(0, ['Peanut-sauce']), 14]]),
#  (('Meta-category',), [[(0, ['Meta-category']), 13]]),
#  (('Double-chocolate-milk',),
#   [[(0, ['Double-chocolate-milk']), 16],
#    [(0, ['Frozen-dumpling']), 11],
#    [(0, ['Double-chocolate-milk', 'Frozen-dumpling']), 11]]),
#  (('Scotch-eggs',), [[(0, ['Scotch-eggs']), 12]]),
#  (('Preparations-de-viande-surgelees',),
#   [[(0, ['Preparations-de-viande-surgelees']), 14]]),
#  (('Gourmet-pie',), []),
#  (('Sweetelle-tomatoes',), [[(0, ['Sweetelle-tomatoes']), 13]]),
#  (('Carbonated-soda-water',), [[(0, ['Carbonated-soda-water']), 14]]),
#  (('Milkshake',), [[(0, ['Milkshake']), 27], [(1, ['Milkshake']), 17]]),
#  (('Spare-pork-ribs',), [[(0, ['Spare-pork-ribs']), 11]]),
#  (('Pates-a-tartiner-aux-noisettes-et-au-cacao',),
#   [[(0, ['Pates-a-tartiner-aux-noisettes-et-au-cacao']), 14]]),
#  (('Saucisses-aux-lentilles',),
#   [[(0, ['Schokoladen']), 14],
#    [(0, ['Saucisses-aux-lentilles', 'Schokoladen']), 14],
#    [(1, ['Saucisses-aux-lentilles']), 15],
#    [(0, ['Saucisses-aux-lentilles']), 23]]),
#  (('Manuka-honey',),
#   [[(0, ['Beef-stroganoff']), 11],
#    [(0, ['Beef-stroganoff', 'Manuka-honey']), 11],
#    [(1, ['Manuka-honey']), 11],
#    [(0, ['Manuka-honey']), 17]]),
#  (('Burrito-kit',), [[(0, ['Burrito-kit']), 13]]),
#  (('Rice-noodles',), [[(0, ['Rice-noodles']), 11]]),
#  (('Natural-spring-water',), []),
#  (('Instant-porridge',),
#   [[(0, ['Instant-porridge']), 16], [(0, ['Strawberry-licorice']), 11]]),
#  (('Dietary supplements',),
#   [[(0, ['Dietary supplements']), 18], [(1, ['Dietary supplements']), 11]]),
#  (('Milk-chocolate-digestives',), []),
#  (('Asian-condiments',), [[(0, ['Asian-condiments']), 13]]),
#  (('Whole-wheat-beard',), [[(0, ['Whole-wheat-beard']), 11]]),
#  (('Beef-burgers',), [[(0, ['Beef-burgers']), 11]]),
#  (('Bottled-still-water',),
#   [[(0, ['Bottled-still-water']), 15], [(1, ['Bottled-still-water']), 11]]),
#  (('Caramelized-red-onion-chutney',),
#   [[(1, ['Caramelized-red-onion-chutney']), 11],
#    [(0, ['Caramelized-red-onion-chutney']), 18]]),
#  (('Boissons',), []),
#  (('Semoules-de-ble-dur-pour-couscous',),
#   [[(0, ['Semoules-de-ble-dur-pour-couscous']), 24]]),
#  (('Cardamom-pods',), []),
#  (('Recipe-mixes',), [[(0, ['Recipe-mixes']), 12]]),
#  (('Poissons',), []),
#  (('Fresh-strawberries',), [[(0, ['Fresh-strawberries']), 12]]),
#  (('Tomato-ketchup',), [[(0, ['Tomato-ketchup']), 17]]),
#  (('Hommus-dip',), [[(0, ['Hommus-dip']), 17]]),
#  (('Juice-beverage',), []),
#  (('Dessert-lacte',), [[(0, ['Dessert-lacte']), 14]]),
#  (('Cake-icing',), []),
#  (('Dark-soy-sauce',), [[(0, ['Dark-soy-sauce']), 13]]),
#  (('Baked-beans',), [[(0, ['Baked-beans']), 17], [(1, ['Baked-beans']), 12]]),
#  (('Mackerel-fillets-in-sunflower-oil',),
#   [[(0, ['Mackerel-fillets-in-sunflower-oil']), 16]]),
#  (('Ravioles',), []),
#  (('Bread-rolls',), []),
#  (('Cured-sausage',), []),
#  (('Chilli-con-carne-sauce',),
#   [[(0, ['Chilli-con-carne-sauce']), 18],
#    [(0, ['Chillies']), 11],
#    [(0, ['Chilli-con-carne-sauce', 'Chillies']), 11],
#    [(1, ['Chilli-con-carne-sauce']), 12]]),
#  (('Coconut-waters',), []),
#  (('Barres-de-cereales',), []),
#  (('Canned-pineapple',),
#   [[(0, ['Kauwgom']), 12],
#    [(0, ['Canned-pineapple']), 12],
#    [(0, ['Canned-pineapple', 'Kauwgom']), 12]]),
#  (('Maris-piper-potatoes',), [[(0, ['Maris-piper-potatoes']), 17]]),
#  (('Frozen-asian-food',), [[(0, ['Frozen-asian-food']), 12]]),
#  (('Plato-preparado-precocinado',), []),
#  (('Canned-peaches',), []),
#  (('Chicken-thighs',),
#   [[(0, ['Brussels-pate']), 12],
#    [(0, ['Brussels-pate', 'Chicken-thighs']), 12],
#    [(0, ['Chicken-thighs']), 14]]),
#  (('Hot-chocolate',), []),
#  (('Soup-mixes',), [[(0, ['Soup-mixes']), 12]]),
#  (('Pale-ale',), []),
#  (('Goat-s-cheese',), []),
#  (('Absinth',), [[(0, ['Absinth']), 13]]),
#  (('Tuna-steaks',), [[(1, ['Tuna-steaks']), 12], [(0, ['Tuna-steaks']), 17]]),
#  (('Bathroom',), []),
#  (('Frozen-vegetable-mix',), []),
#  (('Hard-cooked-peeled-eggs',),
#   [[(1, ['Hard-cooked-peeled-eggs']), 11],
#    [(0, ['Hard-cooked-peeled-eggs']), 18]]),
#  (('Snackfoods',), [[(0, ['Snackfoods']), 14]]),
#  (('Fajitas',), [[(0, ['Fajitas']), 18]]),
#  (('Seed-style-mustard',), [[(0, ['Seed-style-mustard']), 11]]),
#  (('Rice-candy',), [[(0, ['Rice-candy']), 14]]),
#  (('Sucre',), [[(0, ['Sucre']), 12]]),
#  (('Unsalted-butter',), [[(0, ['Unsalted-butter']), 11]]),
#  (('Cucumbers-in-brine',),
#   [[(0, ['Cucumbers-in-brine']), 17], [(1, ['Cucumbers-in-brine']), 11]]),
#  (('Liquid-honey',), [[(0, ['Liquid-honey']), 15]]),
#  (('Prepared-salads',), [[(0, ['Prepared-salads']), 11]]),
#  (('Tarama',), []),
#  (('Elegance-tomatoes',),
#   [[(0, ['Elegance-tomatoes']), 19], [(1, ['Elegance-tomatoes']), 12]]),
#  (('Spring-roll-pastry',), [[(0, ['Spring-roll-pastry']), 11]]),
#  (('Milk substitute',), [[(0, ['Milk substitute']), 17]]),
#  (('Jambons-blancs',),
#   [[(1, ['Jambons-blancs']), 13], [(0, ['Jambons-blancs']), 20]]),
#  (('Tiefkuhlpizza',), []),
#  (('Fresh-corn',), []),
#  (('Cured-ham',), [[(0, ['Cured-ham']), 11]]),
#  (('Hot-dog-mustard',), [[(0, ['Hot-dog-mustard']), 13]]),
#  (('Fresh-prawns',), []),
#  (('Frozen-asian-foods',), []),
#  (('Wheat-cereals',), []),
#  (('Radish',), [[(0, ['Radish']), 13]]),
#  (('Fromage-au-lait-cru',), [[(0, ['Fromage-au-lait-cru']), 14]]),
#  (('Levures',), [[(1, ['Levures']), 12], [(0, ['Levures']), 19]]),
#  (('Pasta-bake-sauces',), []),
#  (('Prepackaged-lettuce',), []),
#  (('Marinated olives',), []),
#  (('Chutney',), []),
#  (('Seitan-bio',), [[(0, ['Seitan-bio']), 12]]),
#  (('Soft-cheese',), []),
#  (('Cosmetics',), [[(0, ['Cosmetics']), 11]]),
#  (('Frozen-dumpling',),
#   [[(0, ['Double-chocolate-milk']), 11],
#    [(0, ['Double-chocolate-milk', 'Frozen-dumpling']), 11],
#    [(0, ['Kauwgom']), 13],
#    [(0, ['Frozen-dumpling']), 25],
#    [(0, ['Frozen-dumpling', 'Kauwgom']), 13],
#    [(1, ['Frozen-dumpling']), 15]]),
#  (('Canned foods',),
#   [[(0, ['Canned foods']), 20],
#    [(1, ['Canned foods']), 15],
#    [(2, ['Canned foods']), 12]]),
#  (('Soup-mix',), []),
#  (('Coffee-flavoured-milk',), [[(0, ['Coffee-flavoured-milk']), 11]]),
#  (('Fusilli',),
#   [[(0, ['Fusilli']), 26], [(1, ['Fusilli']), 19], [(2, ['Fusilli']), 13]]),
#  (('Meats',), []),
#  (('Minced-garlic',), [[(0, ['Minced-garlic']), 11]]),
#  (('Yellow-peaches',), []),
#  (('Juice-milk-drink',), [[(0, ['Juice-milk-drink']), 13]]),
#  (('Cornichons',), [[(0, ['Cornichons']), 12]]),
#  (('Nonpareil-capers',), []),
#  (('Gins',), []),
#  (('Salad',), [[(1, ['Salad']), 11], [(0, ['Salad']), 16]]),
#  (('Babycorn',), []),
#  (('Yaourt-aux-fruits',), [[(0, ['Yaourt-aux-fruits']), 11]]),
#  (('South-african-merlot',), []),
#  (('Pitted-prunes',), [[(0, ['Pitted-prunes']), 11]]),
#  (('Fish and meat and eggs',), [[(0, ['Fish and meat and eggs']), 15]]),
#  (('Fruit-salad',), [[(1, ['Fruit-salad']), 12], [(0, ['Fruit-salad']), 20]]),
#  (('Creme-caramel',), [[(0, ['Creme-caramel']), 12]]),
#  (('Sandiwch',), [[(0, ['Sandiwch']), 11]]),
#  (('Butter-chicken',), []),
#  (('Mackeral',), []),
#  (('Smoked-oysters-in-barbeque-sauce',), []),
#  (('Gaufres',), [[(0, ['Gaufres']), 15]]),
#  (('Basa-fish',), [[(0, ['Basa-fish']), 12]]),
#  (('Grattons',), []),
#  (('Smoked-cheese',), [[(0, ['Smoked-cheese']), 13]]),
#  (('Ground-cinnamon',), [[(0, ['Ground-cinnamon']), 15]]),
#  (('Kale',), [[(0, ['Kale']), 12]]),
#  (('Blackcurrant-juice-syrup',), []),
#  (('Red-seedless-grapes',), []),
#  (('Caramels-au-beurre-sale',), []),
#  (('Crems-glacees',), [[(0, ['Crems-glacees']), 11]]),
#  (('Sandwich',), []),
#  (('Dried-mango',), []),
#  (('Chestnut-mushrooms',), [[(0, ['Chestnut-mushrooms']), 11]]),
#  (('Chillies',),
#   [[(0, ['Chilli-con-carne-sauce']), 11],
#    [(0, ['Chilli-con-carne-sauce', 'Chillies']), 11],
#    [(2, ['Chillies']), 11],
#    [(0, ['Chillies']), 22],
#    [(1, ['Chillies']), 16]]),
#  (('Pannekoeken',), [[(0, ['Pannekoeken']), 18], [(1, ['Pannekoeken']), 13]]),
#  (('Prunes',), []),
#  (('Sardines-in-brine',), []),
#  (('Chicken-stock',), []),
#  (('Fizzy-drinks',), [[(0, ['Fizzy-drinks']), 14]]),
#  (('Strawberry-licorice',),
#   [[(0, ['Instant-porridge']), 11],
#    [(0, ['White-coconut-chocolate']), 12],
#    [(0, ['Strawberry-licorice']), 14],
#    [(0, ['Strawberry-licorice', 'White-coconut-chocolate']), 12],
#    [(1, ['Strawberry-licorice']), 11]]),
#  (('Bieres-blondes',), []),
#  (('White-plain-flour',),
#   [[(0, ['Brussels-pate']), 13],
#    [(0, ['Brussels-pate', 'White-plain-flour']), 13],
#    [(0, ['White-plain-flour']), 21],
#    [(1, ['White-plain-flour']), 16],
#    [(2, ['White-plain-flour']), 11]]),
#  (('Products sold before year 2000',), []),
#  (('Mexican-food',), []),
#  (('Losenges',), [[(0, ['Losenges']), 14]]),
#  (('Mineral-natural-water',), []),
#  (('Sambuca',), []),
#  (('Matzos',), [[(1, ['Matzos']), 11], [(0, ['Matzos']), 15]]),
#  (('Fresh-cakes',), []),
#  (('Gluhwein',), []),
#  (('Alimentos-de-origen-vegetal',), []),
#  (('Frozen-apple-pies',), [[(0, ['Frozen-apple-pies']), 14]]),
#  (('Cheese-crackers',), []),
#  (('Gratins-de-legumes',), []),
#  (('Vegetarian-mock-meat',), []),
#  (('Eaux-minerales',), [[(0, ['Eaux-minerales']), 13]]),
#  (('Juice',), []),
#  (('Fruit juices and nectars',), []),
#  (('Fish-sauce',), []),
#  (('Olives-noires',), []),
#  (('Almond-milk-yogurt',), []),
#  (('Pousses-de-bambou',), []),
#  (('Infant-powder-milk',), []),
#  (('Salted-snack',), []),
#  (('Skegness-blue',), []),
#  (('Milk-chocolate-filled-with-caramel',), []),
#  (('Hard-cooked-peeled-eggs', 'Hot-dog-mustard'), []),
#  (('Gateau-chinois', 'Sweeteners'),
#   [[(0, ['Gateau-chinois']), 12],
#    [(0, ['Sweeteners']), 12],
#    [(0, ['Gateau-chinois', 'Sweeteners']), 12]]),
#  (('Coleslaw-dressing', 'Soeppoeder'),
#   [[(0, ['Coleslaw-dressing']), 12],
#    [(0, ['Soeppoeder']), 12],
#    [(0, ['Coleslaw-dressing', 'Soeppoeder']), 12]]),
#  (('Malt-vinegar', 'White-pitta-bread'), []),
#  (('Dried-parmesan-cheese', 'Jus-d-orange'), []),
#  (('Beef-stroganoff', 'Pates-a-tartiner-aux-noisettes-et-au-cacao'), []),
#  (('Beef-stroganoff', 'Rice-noodles'), []),
#  (('Cooking-oil', 'Kartoffelchips'),
#   [[(0, ['Kartoffelchips']), 13],
#    [(0, ['Lime-marmalades']), 11],
#    [(0, ['Cooking-oil']), 13],
#    [(0, ['Cooking-oil', 'Kartoffelchips']), 13],
#    [(0, ['Cooking-oil', 'Lime-marmalades']), 11]]),
#  (('Crossiants', 'Indian-food'), []),
#  (('Brussels-pate', 'Dried-pasta'), []),
#  (('Cosmetics', 'Thes-verts'), []),
#  (('Fecules', 'Pousses-de-bambou'), []),
#  (('Frozen-spring-rolls', 'Pineapple-slices-in-juice'), []),
#  (('Chopeed-tomatoes', 'Frozen-dumpling'), []),
#  (('Bieres-blondes', 'Strawberry-licorice'), []),
#  (('Crema-spalmabile', 'Sparkling-mineral-waters'), []),
#  (('Manuka-honey', 'Saucisses-aux-lentilles'), []),
#  (('Chocolat-au-lait', 'Coleslaw-dressing'), []),
#  (('Caramelized-red-onion-chutney', 'Recipe-mixes'), []),
#  (('Fresh-juices', 'Sugar-cane-drink'),
#   [[(0, ['Sugar-cane-drink']), 12],
#    [(0, ['Fresh-juices']), 12],
#    [(0, ['Fresh-juices', 'Sugar-cane-drink']), 12]]),
#  (('Helles-schankbier', 'Malt-vinegar'), []),
#  (('Infant-powder-milk', 'Losenges'), []),
#  (('Frozen-spring-rolls', 'Semoules-de-ble-dur-pour-couscous'), []),
#  (('Basa-fish', 'Hoki-fish-fillets'), []),
#  (('Malt-vinegar', 'Soeppoeder'), []),
#  (('Dried-pasta', 'White-coconut-chocolate'), []),
#  (('Prepared-foods', 'Prosecco'), []),
#  (('Caramelized-red-onion-chutney', 'Groceries'), []),
#  (('Saucisses-aux-lentilles', 'Schokoladen'),
#   [[(0, ['Schokoladen']), 14],
#    [(0, ['Saucisses-aux-lentilles']), 14],
#    [(0, ['Saucisses-aux-lentilles', 'Schokoladen']), 14]]),
#  (('Coffee-cake', 'Frozen-snacks'),
#   [[(0, ['Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Kauwgom']), 12],
#    [(0, ['Coffee-cake', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 12],
#    [(0, ['Coffee-cake']), 15],
#    [(0, ['Frozen-snacks']), 15],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 15]]),
#  (('Cinamon-donuts', 'Pasta-bake-sauces'), []),
#  (('Fresh-juices', 'Groceries'), []),
#  (('Coffee-cake', 'Frozen-dumpling'), []),
#  (('Brussels-pate', 'White-coconut-chocolate'), []),
#  (('Chopeed-tomatoes', 'Kauwgom'),
#   [[(0, ['Chopeed-tomatoes']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Chopeed-tomatoes', 'Kauwgom']), 11]]),
#  (('Kauwgom', 'Muffin-mix'),
#   [[(0, ['Muffin-mix']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Kauwgom', 'Muffin-mix']), 11]]),
#  (('Fresh-juices', 'Pannekoeken'), []),
#  (('Brussels-pate', 'Chicken-thighs'),
#   [[(0, ['Brussels-pate']), 12],
#    [(0, ['Chicken-thighs']), 12],
#    [(0, ['Brussels-pate', 'Chicken-thighs']), 12]]),
#  (('Bieres-blondes', 'White-coconut-chocolate'), []),
#  (('Roasted-garlic', 'Sparkling-mineral-waters'), []),
#  (('Cosmetics', 'Fresh-juices'), []),
#  (('Canned-fruit-salad', 'Snackfoods'), []),
#  (('Dried-pasta', 'Syrups'), []),
#  (('Plats-prepares-surgeles', 'Prosecco'), []),
#  (('Fajitas', 'White-coconut-chocolate'), []),
#  (('Fecules', 'Strawberry-licorice'), []),
#  (('Chia-seeds', 'Thes-verts'), []),
#  (('Dried-parmesan-cheese', 'Mct-oil'), []),
#  (('Fecules', 'Fresh-juices'), []),
#  (('Fruit-drinks', 'Kauwgom'),
#   [[(0, ['Coffee-cake']), 11],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks']), 13],
#    [(0, ['Kauwgom']), 13],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 13]]),
#  (('Double-chocolate-milk', 'Fruit-drinks'), []),
#  (('Coffee-cake', 'Kauwgom'),
#   [[(0, ['Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Coffee-cake']), 14],
#    [(0, ['Frozen-snacks']), 12],
#    [(0, ['Kauwgom']), 14],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 12],
#    [(0, ['Coffee-cake', 'Kauwgom']), 14],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 12]]),
#  (('Matzos', 'Sugar-free-confectionary'), []),
#  (('Matzos', 'White-coconut-chocolate'), []),
#  (('Cheese-crackers', 'Strawberry-licorice'), []),
#  (('Brussels-pate', 'White-plain-flour'),
#   [[(0, ['Brussels-pate']), 13],
#    [(0, ['White-plain-flour']), 13],
#    [(0, ['Brussels-pate', 'White-plain-flour']), 13]]),
#  (('Kauwgom', 'Plats-prepares-surgeles'), []),
#  (('Roasted-garlic', 'Schokoladen'), []),
#  (('Bbq-relish', 'Malt-vinegar'), []),
#  (('Chocolat-au-lait', 'Soeppoeder'), []),
#  (('Cooking-oil', 'Lime-marmalades'),
#   [[(0, ['Kartoffelchips']), 11],
#    [(0, ['Lime-marmalades']), 11],
#    [(0, ['Cooking-oil']), 11],
#    [(0, ['Cooking-oil', 'Kartoffelchips']), 11],
#    [(0, ['Cooking-oil', 'Lime-marmalades']), 11]]),
#  (('Sparkling-mineral-waters', 'White-coconut-chocolate'), []),
#  (('Coffee-cake', 'Double-chocolate-milk'), []),
#  (('Dried-pasta', 'Matzos'), []),
#  (('Banana-nut-loaf', 'Turkey-burgers'), []),
#  (('Asian-food', 'Prawn-crackers'), []),
#  (('Groceries', 'Snack-bar'),
#   [[(0, ['Groceries']), 13],
#    [(0, ['Snack-bar']), 13],
#    [(0, ['Groceries', 'Snack-bar']), 13]]),
#  (('Dried-parmesan-cheese', 'Indian-food'), []),
#  (('Groceries', 'Recipe-mixes'), []),
#  (('Hard-cooked-peeled-eggs', 'Tuna-steaks'), []),
#  (('Frozen-dumpling', 'Frozen-snacks'), []),
#  (('Strawberry-licorice', 'Syrups'), []),
#  (('Helles-schankbier', 'Soeppoeder'), []),
#  (('Cremes-vegetales-a-base-de-coco-pour-cuisiner', 'Prosecco'), []),
#  (('Kartoffelchips', 'Redcurrant-tea'), []),
#  (('Strawberry-licorice', 'White-coconut-chocolate'),
#   [[(0, ['White-coconut-chocolate']), 12],
#    [(0, ['Strawberry-licorice']), 12],
#    [(0, ['Strawberry-licorice', 'White-coconut-chocolate']), 12]]),
#  (('Dried-pasta', 'Soup-mixes'), []),
#  (('Brussels-pate', 'Matzos'), []),
#  (('Canned foods', 'Sparkling-mineral-waters'), []),
#  (('Canned-pineapple', 'Fruit-drinks'), []),
#  (('Ciabatta', 'Cottage-cheese'), []),
#  (('Faux-fromage', 'Fruit-and-nut-mix'), []),
#  (('Dried-pasta', 'Schwarztees'), []),
#  (('Frozen-spring-rolls', 'Groceries'),
#   [[(0, ['Frozen-spring-rolls']), 12],
#    [(0, ['Groceries']), 12],
#    [(0, ['Frozen-spring-rolls', 'Groceries']), 12]]),
#  (('Frozen-dumpling', 'Plats-prepares-surgeles'), []),
#  (('White-coconut-chocolate', 'White-plain-flour'), []),
#  (('Chocolate-bunny', 'Fruit-cups'), []),
#  (('Coconut-cream', 'Saucisses-aux-lentilles'), []),
#  (('Indian-food', 'Jus-d-orange'), []),
#  (('Manuka-honey', 'Pates-a-tartiner-aux-noisettes-et-au-cacao'), []),
#  (('Hamblokjes', 'Sugar-cane-drink'), []),
#  (('Fresh-cabbage', 'Soeppoeder'), []),
#  (('Minced-lamb', 'Terrine'), []),
#  (('Dried-parmesan-cheese', 'Gelati'), []),
#  (('Fresh-lemons', 'Groceries'), []),
#  (('Lime-marmalades', 'Produits-laitiers'), []),
#  (('Chicken-thighs', 'White-plain-flour'), []),
#  (('Coleslaw-dressing', 'Malt-vinegar'), []),
#  (('Easter-buns', 'Fresh-juices'),
#   [[(0, ['Easter-buns']), 12],
#    [(0, ['Fresh-juices']), 12],
#    [(0, ['Easter-buns', 'Fresh-juices']), 12]]),
#  (('Fish-sauce', 'Fruit juices and nectars'), []),
#  (('Canned-pineapple', 'Double-chocolate-milk'), []),
#  (('Crossiants', 'Jus-d-orange'), []),
#  (('Pork-pies', 'Profiteroles'), []),
#  (('Gelati', 'Indian-food'), []),
#  (('Banana-nut-loaf', 'Faux-fromage'),
#   [[(0, ['Banana-nut-loaf']), 11],
#    [(0, ['Faux-fromage']), 11],
#    [(0, ['Banana-nut-loaf', 'Faux-fromage']), 11]]),
#  (('Groceries', 'Hamblokjes'), []),
#  (('Elegance-tomatoes', 'Fish and meat and eggs'), []),
#  (('Frozen-dumpling', 'Roasted-garlic'), []),
#  (('Roasted-garlic', 'Strawberry-licorice'), []),
#  (('Asian-sauces', 'Carrot-cake'), []),
#  (('Coleslaw-dressing', 'Helles-schankbier'), []),
#  (('Frozen-snacks', 'Fruit-drinks'),
#   [[(0, ['Coffee-cake']), 11],
#    [(0, ['Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11]]),
#  (('Gravy', 'Hamblokjes'), []),
#  (('Kauwgom', 'Produits-ssans-gluten'), []),
#  (('Concombres', 'Crema-spalmabile'), []),
#  (('Frozen-dumpling', 'Kauwgom'),
#   [[(0, ['Kauwgom']), 13],
#    [(0, ['Frozen-dumpling']), 13],
#    [(0, ['Frozen-dumpling', 'Kauwgom']), 13]]),
#  (('Frozen-snacks', 'Kauwgom'),
#   [[(0, ['Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Coffee-cake']), 12],
#    [(0, ['Frozen-snacks']), 12],
#    [(0, ['Kauwgom']), 12],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 12],
#    [(0, ['Coffee-cake', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 12]]),
#  (('Frozen-spring-rolls', 'Snack-bar'), []),
#  (('Syrups', 'White-coconut-chocolate'),
#   [[(0, ['White-coconut-chocolate']), 11],
#    [(0, ['Syrups']), 11],
#    [(0, ['Syrups', 'White-coconut-chocolate']), 11]]),
#  (('Frozen-dumpling', 'Fruit-drinks'), []),
#  (('Beef-stroganoff', 'Saucisses-aux-lentilles'), []),
#  (('Chillies', 'Fecules'), []),
#  (('Basa-fish', 'Creme-caramel'), []),
#  (('Fresh-juices', 'Thes-verts'), []),
#  (('Double-chocolate-milk', 'Frozen-dumpling'),
#   [[(0, ['Double-chocolate-milk']), 11],
#    [(0, ['Frozen-dumpling']), 11],
#    [(0, ['Double-chocolate-milk', 'Frozen-dumpling']), 11]]),
#  (('Coleslaw-dressing', 'Minced-lamb'), []),
#  (('Chopeed-tomatoes', 'Green-salads'), []),
#  (('Soup-mixes', 'White-coconut-chocolate'), []),
#  (('Fajitas', 'Sparkling-mineral-waters'), []),
#  (('Instant-porridge', 'White-coconut-chocolate'), []),
#  (('Double-chocolate-milk', 'Frozen-snacks'), []),
#  (('Fresh-lemons', 'Sugar-cane-drink'), []),
#  (('Beef-stroganoff', 'Coconut-cream'), []),
#  (('Beef-stroganoff', 'Manuka-honey'),
#   [[(0, ['Beef-stroganoff']), 11],
#    [(0, ['Manuka-honey']), 11],
#    [(0, ['Beef-stroganoff', 'Manuka-honey']), 11]]),
#  (('Fresh-cabbage', 'Malt-vinegar'), []),
#  (('Matzos', 'Syrups'), []),
#  (('Manuka-honey', 'Rice-noodles'), []),
#  (('Chicken-thighs', 'White-coconut-chocolate'), []),
#  (('Banana-nut-loaf', 'Bottled-still-water'), []),
#  (('Banana-nut-loaf', 'Lime-marmalades'), []),
#  (('Gelati', 'Jus-d-orange'), []),
#  (('Brussels-pate', 'Mexican-food'), []),
#  (('Cream-of-tartar', 'Yellow-mustard'), []),
#  (('Hamblokjes', 'Muffin-mix'), []),
#  (('Roasted-garlic', 'Saucisses-aux-lentilles'), []),
#  (('Cooking-oil', 'Mixed-nuts'),
#   [[(0, ['Mixed-nuts']), 11],
#    [(0, ['Cooking-oil']), 11],
#    [(0, ['Cooking-oil', 'Mixed-nuts']), 11]]),
#  (('Baking', 'Prosecco'), []),
#  (('Roasted-garlic', 'White-coconut-chocolate'), []),
#  (('Canned foods', 'Ciabatta'), []),
#  (('Chopeed-tomatoes', 'Plats-prepares-surgeles'), []),
#  (('Cheese-crackers', 'White-coconut-chocolate'), []),
#  (('Dried-pasta', 'Mexican-food'), []),
#  (('Double-chocolate-milk', 'Kauwgom'), []),
#  (('Hot-chocolate', 'Thes-glaces'), []),
#  (('Caramelized-red-onion-chutney', 'Cardamom-pods'), []),
#  (('Canned-pineapple', 'Kauwgom'),
#   [[(0, ['Kauwgom']), 12],
#    [(0, ['Canned-pineapple']), 12],
#    [(0, ['Canned-pineapple', 'Kauwgom']), 12]]),
#  (('Coffee-cake', 'Fruit-drinks'),
#   [[(0, ['Coffee-cake']), 12],
#    [(0, ['Fruit-drinks']), 12],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 12],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11]]),
#  (('Sardines-in-brine', 'Smoked-cheese'), []),
#  (('Kartoffelchips', 'Mixed-nuts'), []),
#  (('Strawberry-licorice', 'White-plain-flour'), []),
#  (('Sparkling-mineral-waters', 'Strawberry-licorice'), []),
#  (('Brussels-pate', 'Schwarztees'), []),
#  (('Groceries', 'Sugar-cane-drink'), []),
#  (('Canned foods', 'Chia-seeds'), []),
#  (('Beer-batter-fries', 'Pastrami'),
#   [[(0, ['Beer-batter-fries']), 11],
#    [(0, ['Pastrami']), 11],
#    [(0, ['Beer-batter-fries', 'Pastrami']), 11]]),
#  (('Cheese-puffs', 'Yellow-peaches'), []),
#  (('Gin', 'Sparkling-mineral-waters'), []),
#  (('Lime-marmalades', 'Mixed-nuts'), []),
#  (('Elegance-tomatoes', 'Fecules'), []),
#  (('Chilli-con-carne-sauce', 'Chillies'),
#   [[(0, ['Chilli-con-carne-sauce']), 11],
#    [(0, ['Chillies']), 11],
#    [(0, ['Chilli-con-carne-sauce', 'Chillies']), 11]]),
#  (('Coffee-cake', 'Produits-ssans-gluten'),
#   [[(0, ['Produits-ssans-gluten']), 12],
#    [(0, ['Coffee-cake']), 12],
#    [(0, ['Coffee-cake', 'Produits-ssans-gluten']), 12]]),
#  (('Caramelized-red-onion-chutney', 'Gravy'), []),
#  (('Chocolat-au-lait', 'Malt-vinegar'), []),
#  (('Fusilli', 'Tomato-ketchup'), []),
#  (('Baking', 'Redcurrant-tea'), []),
#  (('Canned-pineapple', 'Frozen-dumpling'), []),
#  (('Creme-caramel', 'Hoki-fish-fillets'), []),
#  (('Pineapple-slices-in-juice', 'Semoules-de-ble-dur-pour-couscous'), []),
#  (('Conservation', 'Garlic-mashed-potatoes'),
#   [[(0, ['Garlic-mashed-potatoes']), 11],
#    [(0, ['Conservation']), 11],
#    [(0, ['Conservation', 'Garlic-mashed-potatoes']), 11]]),
#  (('Coffee-cake', 'Jus-d-orange'), []),
#  (('Frozen-spring-rolls', 'Groceries', 'Snack-bar'), []),
#  (('Malt-vinegar', 'Coleslaw-dressing', 'Helles-schankbier'), []),
#  (('Malt-vinegar', 'Coleslaw-dressing', 'Chocolat-au-lait'), []),
#  (('Malt-vinegar', 'Coleslaw-dressing', 'Soeppoeder'), []),
#  (('Malt-vinegar', 'Chocolat-au-lait', 'Soeppoeder'), []),
#  (('Coleslaw-dressing', 'Helles-schankbier', 'Soeppoeder'), []),
#  (('Coleslaw-dressing', 'Chocolat-au-lait', 'Soeppoeder'), []),
#  (('Mixed-nuts', 'Lime-marmalades', 'Cooking-oil'), []),
#  (('Mixed-nuts', 'Cooking-oil', 'Kartoffelchips'), []),
#  (('Jus-d-orange', 'Crossiants', 'Indian-food'), []),
#  (('Jus-d-orange', 'Indian-food', 'Gelati'), []),
#  (('Jus-d-orange', 'Indian-food', 'Dried-parmesan-cheese'), []),
#  (('Indian-food', 'Gelati', 'Dried-parmesan-cheese'), []),
#  (('Fruit-drinks', 'Frozen-snacks', 'Kauwgom'),
#   [[(0, ['Coffee-cake']), 11],
#    [(0, ['Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11]]),
#  (('Fruit-drinks', 'Frozen-snacks', 'Coffee-cake'),
#   [[(0, ['Coffee-cake']), 11],
#    [(0, ['Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11]]),
#  (('Fruit-drinks', 'Kauwgom', 'Coffee-cake'),
#   [[(0, ['Coffee-cake']), 11],
#    [(0, ['Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11]]),
#  (('Frozen-snacks', 'Kauwgom', 'Coffee-cake'),
#   [[(0, ['Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Coffee-cake']), 12],
#    [(0, ['Frozen-snacks']), 12],
#    [(0, ['Kauwgom']), 12],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 12],
#    [(0, ['Coffee-cake', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 12],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 12]]),
#  (('Produits-ssans-gluten', 'Kauwgom', 'Coffee-cake'), []),
#  (('Pates-a-tartiner-aux-noisettes-et-au-cacao',
#    'Beef-stroganoff',
#    'Manuka-honey'),
#   []),
#  (('Saucisses-aux-lentilles', 'Beef-stroganoff', 'Coconut-cream'), []),
#  (('Saucisses-aux-lentilles', 'Beef-stroganoff', 'Manuka-honey'), []),
#  (('Saucisses-aux-lentilles', 'Schokoladen', 'Roasted-garlic'), []),
#  (('Beef-stroganoff', 'Manuka-honey', 'Rice-noodles'), []),
#  (('Caramelized-red-onion-chutney', 'Recipe-mixes', 'Groceries'), []),
#  (('Creme-caramel', 'Hoki-fish-fillets', 'Basa-fish'), []),
#  (('White-coconut-chocolate', 'Strawberry-licorice', 'Bieres-blondes'), []),
#  (('White-coconut-chocolate', 'Strawberry-licorice', 'White-plain-flour'), []),
#  (('White-coconut-chocolate',
#    'Strawberry-licorice',
#    'Sparkling-mineral-waters'),
#   []),
#  (('White-coconut-chocolate', 'Strawberry-licorice', 'Roasted-garlic'), []),
#  (('White-coconut-chocolate', 'Strawberry-licorice', 'Syrups'), []),
#  (('White-coconut-chocolate', 'Sparkling-mineral-waters', 'Roasted-garlic'),
#   []),
#  (('White-coconut-chocolate', 'Soup-mixes', 'Dried-pasta'), []),
#  (('White-coconut-chocolate', 'Syrups', 'Dried-pasta'), []),
#  (('Strawberry-licorice', 'Sparkling-mineral-waters', 'Roasted-garlic'), []),
#  (('Brussels-pate', 'Mexican-food', 'Dried-pasta'), []),
#  (('White-coconut-chocolate', 'Syrups', 'Matzos'), []),
#  (('White-coconut-chocolate', 'Cheese-crackers', 'Strawberry-licorice'), []),
#  (('Kauwgom', 'Plats-prepares-surgeles', 'Chopeed-tomatoes'), []),
#  (('Double-chocolate-milk', 'Fruit-drinks', 'Frozen-dumpling'), []),
#  (('Double-chocolate-milk', 'Fruit-drinks', 'Kauwgom'), []),
#  (('Double-chocolate-milk', 'Fruit-drinks', 'Canned-pineapple'), []),
#  (('Double-chocolate-milk', 'Frozen-snacks', 'Coffee-cake'), []),
#  (('Double-chocolate-milk', 'Frozen-dumpling', 'Kauwgom'), []),
#  (('Double-chocolate-milk', 'Frozen-dumpling', 'Canned-pineapple'), []),
#  (('Double-chocolate-milk', 'Kauwgom', 'Canned-pineapple'), []),
#  (('Fruit-drinks', 'Frozen-snacks', 'Frozen-dumpling'), []),
#  (('Fruit-drinks', 'Frozen-dumpling', 'Kauwgom'), []),
#  (('Fruit-drinks', 'Frozen-dumpling', 'Canned-pineapple'), []),
#  (('Fruit-drinks', 'Kauwgom', 'Canned-pineapple'), []),
#  (('Frozen-snacks', 'Frozen-dumpling', 'Kauwgom'), []),
#  (('Frozen-snacks', 'Frozen-dumpling', 'Coffee-cake'), []),
#  (('Frozen-dumpling', 'Kauwgom', 'Plats-prepares-surgeles'), []),
#  (('Frozen-dumpling', 'Kauwgom', 'Coffee-cake'), []),
#  (('Frozen-dumpling', 'Kauwgom', 'Chopeed-tomatoes'), []),
#  (('Frozen-dumpling', 'Kauwgom', 'Canned-pineapple'), []),
#  (('Fresh-lemons', 'Groceries', 'Sugar-cane-drink'), []),
#  (('Groceries', 'Sugar-cane-drink', 'Hamblokjes'), []),
#  (('Malt-vinegar', 'Coleslaw-dressing', 'Chocolat-au-lait', 'Soeppoeder'), []),
#  (('Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake'),
#   [[(0, ['Coffee-cake']), 11],
#    [(0, ['Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks']), 11],
#    [(0, ['Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Frozen-snacks']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Kauwgom']), 11],
#    [(0, ['Frozen-snacks', 'Fruit-drinks']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Coffee-cake', 'Fruit-drinks']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11],
#    [(0, ['Fruit-drinks', 'Frozen-snacks', 'Kauwgom', 'Coffee-cake']), 11]]),
#  (('White-coconut-chocolate',
#    'Strawberry-licorice',
#    'Sparkling-mineral-waters',
#    'Roasted-garlic'),
#   []),
#  (('Double-chocolate-milk', 'Fruit-drinks', 'Frozen-dumpling', 'Kauwgom'), []),
#  (('Double-chocolate-milk',
#    'Fruit-drinks',
#    'Frozen-dumpling',
#    'Canned-pineapple'),
#   []),
#  (('Double-chocolate-milk', 'Fruit-drinks', 'Kauwgom', 'Canned-pineapple'),
#   []),
#  (('Double-chocolate-milk', 'Frozen-dumpling', 'Kauwgom', 'Canned-pineapple'),
#   []),
#  (('Fruit-drinks', 'Frozen-dumpling', 'Kauwgom', 'Canned-pineapple'), []),
#  (('Frozen-snacks', 'Frozen-dumpling', 'Kauwgom', 'Coffee-cake'), []),
#  (('Double-chocolate-milk',
#    'Fruit-drinks',
#    'Frozen-dumpling',
#    'Kauwgom',
#    'Canned-pineapple'),
#   [])]

# %%
[((x[0], y), 1) for x in popularPatterns[0][1] for y in x[1]]
# Out:
# [((0, ['Scottish-shortbread']), 1),
#  ((0, ['Olives-denoyautees']), 1),
#  ((0, ['Miels']), 1),
#  ((0, ['Pasteurized-milk']), 1),
#  ((0, ['Indian-food-mixes']), 1),
#  ((0, ['Fat-free-milk']), 1),
#  ((0, ['Brussels-pate']), 1),
#  ((0, ['Balsamic-vinaigrette']), 1),
#  ((0, ['Organic-tomatoes']), 1),
#  ((0, ['Pesce-curado']), 1),
#  ((0, ['Scottish-shortbread']), 1),
#  ((0, ['Olives-denoyautees']), 1),
#  ((0, ['Miels']), 1),
#  ((0, ['Pasteurized-milk']), 1),
#  ((0, ['Fat-free-milk']), 1),
#  ((0, ['Brussels-pate']), 1),
#  ((0, ['Balsamic-vinaigrette']), 1),
#  ((0, ['Organic-tomatoes']), 1),
#  ((0, ['White-coconut-chocolate']), 1),
#  ((0, ['Aliments-d-origine-vegetale']), 1),
#  ((0, ['Brussels-pate', 'White-coconut-chocolate']), 1),
#  ((1, ['Scottish-shortbread']), 1),
#  ((1, ['Olives-denoyautees']), 1),
#  ((1, ['Miels']), 1),
#  ((1, ['Pasteurized-milk']), 1),
#  ((1, ['Fat-free-milk']), 1),
#  ((1, ['Brussels-pate']), 1),
#  ((1, ['Balsamic-vinaigrette']), 1),
#  ((1, ['Organic-tomatoes']), 1),
#  ((1, ['White-coconut-chocolate']), 1),
#  ((1, ['Aliments-d-origine-vegetale']), 1),
#  ((1, ['Brussels-pate', 'White-coconut-chocolate']), 1),
#  ((0, ['Scottish-shortbread']), 1),
#  ((0, ['Olives-denoyautees']), 1),
#  ((0, ['Miels']), 1),
#  ((0, ['Pasteurized-milk']), 1),
#  ((0, ['Fat-free-milk']), 1),
#  ((0, ['Balsamic-vinaigrette']), 1),
#  ((0, ['White-coconut-chocolate']), 1),
#  ((0, ['Green-kale']), 1),
#  ((0, ['Banana-nut-loaf']), 1),
#  ((0, ['Cake-mix']), 1),
#  ((0, ['Coriandre']), 1),
#  ((0, ['Baby-sanmarzano-tomatoes']), 1),
#  ((1, ['Scottish-shortbread']), 1),
#  ((1, ['Olives-denoyautees']), 1),
#  ((1, ['Miels']), 1),
#  ((1, ['Pasteurized-milk']), 1),
#  ((1, ['Fat-free-milk']), 1),
#  ((1, ['Balsamic-vinaigrette']), 1),
#  ((1, ['White-coconut-chocolate']), 1),
#  ((1, ['Green-kale']), 1),
#  ((1, ['Banana-nut-loaf']), 1),
#  ((1, ['Cake-mix']), 1),
#  ((1, ['Coriandre']), 1),
#  ((1, ['Baby-sanmarzano-tomatoes']), 1),
#  ((2, ['Scottish-shortbread']), 1),
#  ((2, ['Olives-denoyautees']), 1),
#  ((2, ['Miels']), 1),
#  ((2, ['Pasteurized-milk']), 1),
#  ((2, ['Fat-free-milk']), 1),
#  ((2, ['Balsamic-vinaigrette']), 1),
#  ((2, ['White-coconut-chocolate']), 1),
#  ((2, ['Green-kale']), 1),
#  ((2, ['Banana-nut-loaf']), 1),
#  ((2, ['Cake-mix']), 1),
#  ((2, ['Coriandre']), 1),
#  ((2, ['Baby-sanmarzano-tomatoes']), 1),
#  ((0, ['Scottish-shortbread']), 1),
#  ((0, ['Miels']), 1),
#  ((0, ['Balsamic-vinaigrette']), 1),
#  ((0, ['Banana-nut-loaf']), 1),
#  ((0, ['Coriandre']), 1),
#  ((0, ['Baby-sanmarzano-tomatoes']), 1),
#  ((0, ['Piccalilli']), 1),
#  ((1, ['Scottish-shortbread']), 1),
#  ((1, ['Miels']), 1),
#  ((1, ['Balsamic-vinaigrette']), 1),
#  ((1, ['Banana-nut-loaf']), 1),
#  ((1, ['Coriandre']), 1),
#  ((1, ['Baby-sanmarzano-tomatoes']), 1),
#  ((1, ['Piccalilli']), 1),
#  ((2, ['Scottish-shortbread']), 1),
#  ((2, ['Miels']), 1),
#  ((2, ['Balsamic-vinaigrette']), 1),
#  ((2, ['Banana-nut-loaf']), 1),
#  ((2, ['Coriandre']), 1),
#  ((2, ['Baby-sanmarzano-tomatoes']), 1),
#  ((2, ['Piccalilli']), 1),
#  ((3, ['Scottish-shortbread']), 1),
#  ((3, ['Miels']), 1),
#  ((3, ['Balsamic-vinaigrette']), 1),
#  ((3, ['Banana-nut-loaf']), 1),
#  ((3, ['Coriandre']), 1),
#  ((3, ['Baby-sanmarzano-tomatoes']), 1),
#  ((3, ['Piccalilli']), 1),
#  ((0, ['Scottish-shortbread']), 1),
#  ((0, ['Miels']), 1),
#  ((0, ['Pasteurized-milk']), 1),
#  ((0, ['Fat-free-milk']), 1),
#  ((0, ['Organic-tomatoes']), 1),
#  ((0, ['Pesce-curado']), 1),
#  ((0, ['Banana-nut-loaf']), 1),
#  ((0, ['Baby-sanmarzano-tomatoes']), 1),
#  ((0, ['Baking']), 1),
#  ((0, ['Gelati']), 1),
#  ((0, ['Multivitamin-supplement']), 1),
#  ((0, ['Cremes-vegetales-a-base-de-coco-pour-cuisiner']), 1),
#  ((0, ['Easter-buns']), 1),
#  ((0, ['Fresh-juices']), 1),
#  ((0, ['Aoli-sauce']), 1),
#  ((0, ['Prosecco']), 1),
#  ((0, ['Coleslaw-dressing']), 1),
#  ((0, ['Graines']), 1),
#  ((0, ['Plats-prepares-surgeles']), 1),
#  ((0, ['Saucisses-aux-lentilles']), 1),
#  ((0, ['Pannekoeken']), 1),
#  ((0, ['Prunes']), 1),
#  ((0, ['Fresh-juices', 'Pannekoeken']), 1),
#  ((0, ['Plats-prepares-surgeles', 'Prosecco']), 1),
#  ((0, ['Cremes-vegetales-a-base-de-coco-pour-cuisiner', 'Prosecco']), 1),
#  ((0, ['Easter-buns', 'Fresh-juices']), 1),
#  ((0, ['Baking', 'Prosecco']), 1),
#  ((0, ['Scottish-shortbread']), 1),
#  ((0, ['Miels']), 1),
#  ((0, ['Pesce-curado']), 1),
#  ((0, ['Banana-nut-loaf']), 1),
#  ((0, ['Baby-sanmarzano-tomatoes']), 1),
#  ((0, ['Gelati']), 1),
#  ((0, ['Multivitamin-supplement']), 1),
#  ((0, ['Easter-buns']), 1),
#  ((0, ['Fresh-juices']), 1),
#  ((0, ['Prosecco']), 1),
#  ((0, ['Coleslaw-dressing']), 1),
#  ((0, ['Saucisses-aux-lentilles']), 1),
#  ((0, ['Pannekoeken']), 1),
#  ((0, ['Fresh-juices', 'Pannekoeken']), 1),
#  ((0, ['Easter-buns', 'Fresh-juices']), 1),
#  ((1, ['Scottish-shortbread']), 1),
#  ((1, ['Miels']), 1),
#  ((1, ['Pesce-curado']), 1),
#  ((1, ['Banana-nut-loaf']), 1),
#  ((1, ['Baby-sanmarzano-tomatoes']), 1),
#  ((1, ['Gelati']), 1),
#  ((1, ['Multivitamin-supplement']), 1),
#  ((1, ['Easter-buns']), 1),
#  ((1, ['Fresh-juices']), 1),
#  ((1, ['Prosecco']), 1),
#  ((1, ['Coleslaw-dressing']), 1),
#  ((1, ['Saucisses-aux-lentilles']), 1),
#  ((1, ['Pannekoeken']), 1),
#  ((1, ['Fresh-juices', 'Pannekoeken']), 1),
#  ((1, ['Easter-buns', 'Fresh-juices']), 1),
#  ((0, ['Scottish-shortbread']), 1),
#  ((0, ['Pesce-curado']), 1),
#  ((0, ['Banana-nut-loaf']), 1),
#  ((0, ['Baby-sanmarzano-tomatoes']), 1),
#  ((0, ['Multivitamin-supplement']), 1),
#  ((0, ['Easter-buns']), 1),
#  ((0, ['Prosecco']), 1),
#  ((0, ['Prepared-foods']), 1),
#  ((0, ['Saucisses-aux-lentilles']), 1),
#  ((0, ['Grattons']), 1),
#  ((0, ['Prepared-foods', 'Prosecco']), 1),
#  ((1, ['Scottish-shortbread']), 1),
#  ((1, ['Pesce-curado']), 1),
#  ((1, ['Banana-nut-loaf']), 1),
#  ((1, ['Baby-sanmarzano-tomatoes']), 1),
#  ((1, ['Multivitamin-supplement']), 1),
#  ((1, ['Easter-buns']), 1),
#  ((1, ['Prosecco']), 1),
#  ((1, ['Prepared-foods']), 1),
#  ((1, ['Saucisses-aux-lentilles']), 1),
#  ((1, ['Grattons']), 1),
#  ((1, ['Prepared-foods', 'Prosecco']), 1),
#  ((2, ['Scottish-shortbread']), 1),
#  ((2, ['Pesce-curado']), 1),
#  ((2, ['Banana-nut-loaf']), 1),
#  ((2, ['Baby-sanmarzano-tomatoes']), 1),
#  ((2, ['Multivitamin-supplement']), 1),
#  ((2, ['Easter-buns']), 1),
#  ((2, ['Prosecco']), 1),
#  ((2, ['Prepared-foods']), 1),
#  ((2, ['Saucisses-aux-lentilles']), 1),
#  ((2, ['Grattons']), 1),
#  ((2, ['Prepared-foods', 'Prosecco']), 1),
#  ((0, ['Scottish-shortbread']), 1),
#  ((0, ['Banana-nut-loaf']), 1),
#  ((0, ['Steak-kidney-pie']), 1),
#  ((0, ['Prosecco']), 1),
#  ((0, ['Sweeteners']), 1),
#  ((0, ['Saucisses-aux-lentilles']), 1),
#  ((0, ['Grattons']), 1),
#  ((0, ['Sardines-in-brine']), 1),
#  ((1, ['Scottish-shortbread']), 1),
#  ((1, ['Banana-nut-loaf']), 1),
#  ((1, ['Steak-kidney-pie']), 1),
#  ((1, ['Prosecco']), 1),
#  ((1, ['Sweeteners']), 1),
#  ((1, ['Saucisses-aux-lentilles']), 1),
#  ((1, ['Grattons']), 1),
#  ((1, ['Sardines-in-brine']), 1),
#  ((2, ['Scottish-shortbread']), 1),
#  ((2, ['Banana-nut-loaf']), 1),
#  ((2, ['Steak-kidney-pie']), 1),
#  ((2, ['Prosecco']), 1),
#  ((2, ['Sweeteners']), 1),
#  ((2, ['Saucisses-aux-lentilles']), 1),
#  ((2, ['Grattons']), 1),
#  ((2, ['Sardines-in-brine']), 1),
#  ((3, ['Scottish-shortbread']), 1),
#  ((3, ['Banana-nut-loaf']), 1),
#  ((3, ['Steak-kidney-pie']), 1),
#  ((3, ['Prosecco']), 1),
#  ((3, ['Sweeteners']), 1),
#  ((3, ['Saucisses-aux-lentilles']), 1),
#  ((3, ['Grattons']), 1),
#  ((3, ['Sardines-in-brine']), 1)]

# %%
popularPatterns[0]
# Out:
# (('Scottish-shortbread',),
#  [(0,
#    [['Scottish-shortbread'],
#     ['Olives-denoyautees'],
#     ['Miels'],
#     ['Pasteurized-milk'],
#     ['Indian-food-mixes'],
#     ['Fat-free-milk'],
#     ['Brussels-pate'],
#     ['Balsamic-vinaigrette'],
#     ['Organic-tomatoes'],
#     ['Pesce-curado']]),
#   (0,
#    [['Scottish-shortbread'],
#     ['Olives-denoyautees'],
#     ['Miels'],
#     ['Pasteurized-milk'],
#     ['Fat-free-milk'],
#     ['Brussels-pate'],
#     ['Balsamic-vinaigrette'],
#     ['Organic-tomatoes'],
#     ['White-coconut-chocolate'],
#     ['Aliments-d-origine-vegetale'],
#     ['Brussels-pate', 'White-coconut-chocolate']]),
#   (1,
#    [['Scottish-shortbread'],
#     ['Olives-denoyautees'],
#     ['Miels'],
#     ['Pasteurized-milk'],
#     ['Fat-free-milk'],
#     ['Brussels-pate'],
#     ['Balsamic-vinaigrette'],
#     ['Organic-tomatoes'],
#     ['White-coconut-chocolate'],
#     ['Aliments-d-origine-vegetale'],
#     ['Brussels-pate', 'White-coconut-chocolate']]),
#   (0,
#    [['Scottish-shortbread'],
#     ['Olives-denoyautees'],
#     ['Miels'],
#     ['Pasteurized-milk'],
#     ['Fat-free-milk'],
#     ['Balsamic-vinaigrette'],
#     ['White-coconut-chocolate'],
#     ['Green-kale'],
#     ['Banana-nut-loaf'],
#     ['Cake-mix'],
#     ['Coriandre'],
#     ['Baby-sanmarzano-tomatoes']]),
#   (1,
#    [['Scottish-shortbread'],
#     ['Olives-denoyautees'],
#     ['Miels'],
#     ['Pasteurized-milk'],
#     ['Fat-free-milk'],
#     ['Balsamic-vinaigrette'],
#     ['White-coconut-chocolate'],
#     ['Green-kale'],
#     ['Banana-nut-loaf'],
#     ['Cake-mix'],
#     ['Coriandre'],
#     ['Baby-sanmarzano-tomatoes']]),
#   (2,
#    [['Scottish-shortbread'],
#     ['Olives-denoyautees'],
#     ['Miels'],
#     ['Pasteurized-milk'],
#     ['Fat-free-milk'],
#     ['Balsamic-vinaigrette'],
#     ['White-coconut-chocolate'],
#     ['Green-kale'],
#     ['Banana-nut-loaf'],
#     ['Cake-mix'],
#     ['Coriandre'],
#     ['Baby-sanmarzano-tomatoes']]),
#   (0,
#    [['Scottish-shortbread'],
#     ['Miels'],
#     ['Balsamic-vinaigrette'],
#     ['Banana-nut-loaf'],
#     ['Coriandre'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Piccalilli']]),
#   (1,
#    [['Scottish-shortbread'],
#     ['Miels'],
#     ['Balsamic-vinaigrette'],
#     ['Banana-nut-loaf'],
#     ['Coriandre'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Piccalilli']]),
#   (2,
#    [['Scottish-shortbread'],
#     ['Miels'],
#     ['Balsamic-vinaigrette'],
#     ['Banana-nut-loaf'],
#     ['Coriandre'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Piccalilli']]),
#   (3,
#    [['Scottish-shortbread'],
#     ['Miels'],
#     ['Balsamic-vinaigrette'],
#     ['Banana-nut-loaf'],
#     ['Coriandre'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Piccalilli']]),
#   (0,
#    [['Scottish-shortbread'],
#     ['Miels'],
#     ['Pasteurized-milk'],
#     ['Fat-free-milk'],
#     ['Organic-tomatoes'],
#     ['Pesce-curado'],
#     ['Banana-nut-loaf'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Baking'],
#     ['Gelati'],
#     ['Multivitamin-supplement'],
#     ['Cremes-vegetales-a-base-de-coco-pour-cuisiner'],
#     ['Easter-buns'],
#     ['Fresh-juices'],
#     ['Aoli-sauce'],
#     ['Prosecco'],
#     ['Coleslaw-dressing'],
#     ['Graines'],
#     ['Plats-prepares-surgeles'],
#     ['Saucisses-aux-lentilles'],
#     ['Pannekoeken'],
#     ['Prunes'],
#     ['Fresh-juices', 'Pannekoeken'],
#     ['Plats-prepares-surgeles', 'Prosecco'],
#     ['Cremes-vegetales-a-base-de-coco-pour-cuisiner', 'Prosecco'],
#     ['Easter-buns', 'Fresh-juices'],
#     ['Baking', 'Prosecco']]),
#   (0,
#    [['Scottish-shortbread'],
#     ['Miels'],
#     ['Pesce-curado'],
#     ['Banana-nut-loaf'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Gelati'],
#     ['Multivitamin-supplement'],
#     ['Easter-buns'],
#     ['Fresh-juices'],
#     ['Prosecco'],
#     ['Coleslaw-dressing'],
#     ['Saucisses-aux-lentilles'],
#     ['Pannekoeken'],
#     ['Fresh-juices', 'Pannekoeken'],
#     ['Easter-buns', 'Fresh-juices']]),
#   (1,
#    [['Scottish-shortbread'],
#     ['Miels'],
#     ['Pesce-curado'],
#     ['Banana-nut-loaf'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Gelati'],
#     ['Multivitamin-supplement'],
#     ['Easter-buns'],
#     ['Fresh-juices'],
#     ['Prosecco'],
#     ['Coleslaw-dressing'],
#     ['Saucisses-aux-lentilles'],
#     ['Pannekoeken'],
#     ['Fresh-juices', 'Pannekoeken'],
#     ['Easter-buns', 'Fresh-juices']]),
#   (0,
#    [['Scottish-shortbread'],
#     ['Pesce-curado'],
#     ['Banana-nut-loaf'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Multivitamin-supplement'],
#     ['Easter-buns'],
#     ['Prosecco'],
#     ['Prepared-foods'],
#     ['Saucisses-aux-lentilles'],
#     ['Grattons'],
#     ['Prepared-foods', 'Prosecco']]),
#   (1,
#    [['Scottish-shortbread'],
#     ['Pesce-curado'],
#     ['Banana-nut-loaf'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Multivitamin-supplement'],
#     ['Easter-buns'],
#     ['Prosecco'],
#     ['Prepared-foods'],
#     ['Saucisses-aux-lentilles'],
#     ['Grattons'],
#     ['Prepared-foods', 'Prosecco']]),
#   (2,
#    [['Scottish-shortbread'],
#     ['Pesce-curado'],
#     ['Banana-nut-loaf'],
#     ['Baby-sanmarzano-tomatoes'],
#     ['Multivitamin-supplement'],
#     ['Easter-buns'],
#     ['Prosecco'],
#     ['Prepared-foods'],
#     ['Saucisses-aux-lentilles'],
#     ['Grattons'],
#     ['Prepared-foods', 'Prosecco']]),
#   (0,
#    [['Scottish-shortbread'],
#     ['Banana-nut-loaf'],
#     ['Steak-kidney-pie'],
#     ['Prosecco'],
#     ['Sweeteners'],
#     ['Saucisses-aux-lentilles'],
#     ['Grattons'],
#     ['Sardines-in-brine']]),
#   (1,
#    [['Scottish-shortbread'],
#     ['Banana-nut-loaf'],
#     ['Steak-kidney-pie'],
#     ['Prosecco'],
#     ['Sweeteners'],
#     ['Saucisses-aux-lentilles'],
#     ['Grattons'],
#     ['Sardines-in-brine']]),
#   (2,
#    [['Scottish-shortbread'],
#     ['Banana-nut-loaf'],
#     ['Steak-kidney-pie'],
#     ['Prosecco'],
#     ['Sweeteners'],
#     ['Saucisses-aux-lentilles'],
#     ['Grattons'],
#     ['Sardines-in-brine']]),
#   (3,
#    [['Scottish-shortbread'],
#     ['Banana-nut-loaf'],
#     ['Steak-kidney-pie'],
#     ['Prosecco'],
#     ['Sweeteners'],
#     ['Saucisses-aux-lentilles'],
#     ['Grattons'],
#     ['Sardines-in-brine']])])
