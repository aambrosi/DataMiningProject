# %%
import pandas as pd
import numpy  as np
import re                              # Used for splitting the Items with multiple delimiters
from   collections import Counter      # To count items in dictionaries
from   itertools   import combinations # To generate combinations of items
from   itertools   import permutations # To generate permutations of items
import functools
from collections import defaultdict  

routeID        = -1 # initialized to -1 in order to force the first execution to the "else"
orderID        = -1
tmp = [None] * 15

# The dataset was created with the notebook "DatasetCreation.ipynb".

routes = pd.read_csv('route_trips.csv', 
                     delimiter = ',', 
                     encoding  = 'utf-8')

routes.drop(routes.columns[0], 
            axis    = 1, 
            inplace = True)

# %%
# Prepare the delimiters for splitting the items
delimiters   = ",", "{", "}", "'"
regexPattern = '|'.join(map(re.escape, delimiters))

# %%
# Produce a new column for the Items
newItemsColumn = []
for index in range(0, len(routes)):
    tmp = list(filter(None, re.split(regexPattern, routes.Items[index])))
    newItemsColumn.append([item for item in tmp 
                                   if item.strip()])
routes.Items = newItemsColumn

# %%
# Save in a dictionary the number of trip for each order 
routeDimension = defaultdict(list)
for route in routes.RouteId:
    routeDimension[route] = max([order for order in routes[routes.RouteId == route].Order]) + 1

# %%
# Set the threshold for the support of Frequent itemset theory
supportThreshold = 5

items   = [item for items in routes.Items 
                   for item in items]

# Count the occurrencies of each item in the whole dataset
# ("items" now contains a list of all the products for each trip)
itemCount = Counter([(item,) for item in items])
support = itemCount

# Select only those items that appear more than the support
frequentItems = [item for item in itemCount 
                    if itemCount[item] >= supportThreshold]

# %%
routes.Items
# Out:
# 0      [Goat-milk-cheese, Kartoffelchips, Chocolate-b...
# 1      [Goat-milk-cheese, Whole-bean-coffee, Nectar-d...
# 2      [Soupes, Whole-bean-coffee, Chocolate-block, M...
# 3      [Orange-chocolate, Seabass, Soupes, Whole-bean...
# 4      [Citrus-punch, Chocolate-block, Pork-chipolata...
# 5      [Bircarbonate-of-soda, Flavoured-cranberries, ...
# 6      [Apple-blackcurrant-drink, Strawberry-trifle, ...
# 7      [Ratatouille, Cheddar-baguettes, Fruit-spread,...
# 8      [Cheddar-baguettes, Canneloni, Green-kale, Pea...
# 9      [Strawberry-trifle, Nans, Canneloni, Pickles, ...
# 10     [Custard-tarts, Prunes, Galettes-de-polenta, R...
# 11     [Fruchtnektar, Custard-tarts, Prunes, Pitted-p...
# 12     [Baking, Custard-tarts, Chutney, Pitted-prunes...
# 13     [Susswaren, Onion-relish, Peanut-in-chocolate,...
# 14     [Peanut-in-chocolate, Seitan-bio, Burrito-kit,...
# 15     [Rice-candy, Peanut-in-chocolate, Cold-meats, ...
# 16     [Canned-precooked-meat, Malt-vinegar, Pitted-p...
# 17     [Danette-chocolate-dessert, Freeze-dried foods...
# 18     [Danette-chocolate-dessert, Algues-et-derives,...
# 19     [Frozen-battered-fish, Salads, Bakery, Tortill...
# 20     [Brassica, Bbq-relish, Specialite-basque, Bana...
# 21     [Losenges, Sweetcorn, Steak-kidney-pie, Brassi...
# 22     [Sugary snacks, Losenges, Brassica, Wasabi, En...
# 23     [Mineral-natural-water, Sugary snacks, Goat-mi...
# 24     [Goat-milk-butter, Tiefkuhlpizza, Bottled-wate...
# 25     [Chutney, Tiefkuhlpizza, Jaffa-cakes, Banana-n...
# 26     [Dried-sausages, Vinho-tinto, Cremes-vegetales...
# 27     [Ratatouille, Indian, Dried-sausages, Vinho-ti...
# 28     [Biscottes, Ratatouille, Dried-sausages, Vinho...
# 29     [Dried-sausages, Paves-de-saumon, Danette-choc...
#                              ...
# 722    [Churned-cream, Crsips, Dark-chocolate-block, ...
# 723    [Pitta-breads, Fruit-flavoured-drink, Sirop-de...
# 724    [Fruit-flavoured-drink, Sirop-de-fruits, Diet-...
# 725    [Cremes-desserts, Nutrition-bar, Fruit-flavour...
# 726    [Sunflower-spread, Soup-mixes, Popping-corn, C...
# 727    [Sunflower-spread, Milchprodukt, Popping-corn,...
# 728    [Babycorn, Barres-de-cereales, Lamb-chops, Spa...
# 729    [Chorizos, Sables, Chicken-kiev, Lamb-chops, C...
# 730    [Herring-fillets, Dindes, Surgelati, Sunflower...
# 731    [Pates, Cured-sausage, Corn-tortilla-chips, Bi...
# 732    [Natural-spring-water, Pates, Instant-porridge...
# 733    [Mackerel-filets-in-sunflower-oil, Fish and me...
# 734    [Mackerel-filets-in-sunflower-oil, Fish and me...
# 735    [Mackerel-filets-in-sunflower-oil, Saucisses-a...
# 736    [Saucisses-aux-lentilles, Turkish-delight, Mil...
# 737    [Saucisses-aux-lentilles, Vleeswaren, Artifici...
# 738    [Bread-mix, Saucisses-aux-lentilles, Kecap-man...
# 739    [Ratatouille, Saucisses-aux-lentilles, Vleeswa...
# 740    [Ratatouille, Gratin-de-chou-fleur, Saucisses-...
# 741    [Citrouille-en-conserve, Gratin-de-chou-fleur,...
# 742    [Kidney-beans, Lait-de-vache-concentre-non-suc...
# 743    [Marfona-variety, Fat-free-milk, Pate, Cake-mi...
# 744    [Quenelles, Fresh-raspberries, Preparations-de...
# 745    [Fruit-confectionary, Prunes, Complements-alim...
# 746    [Fruit-confectionary, Milk substitute, Herring...
# 747    [Fruit-confectionary, Parve, Frozen-vegetables...
# 748    [Frozen-vegetables-mix, Soymilk, Whole-bean-sp...
# 749    [Sushi, Soymilk, Caviar substitutes, Aloe-vera...
# 750    [Ratatouille, Sushi, Sourdough-bread, Sandwich...
# 751    [Gratin-de-chou-fleur, Rice-candy, Diced-tomat...
# Name: Items, Length: 752, dtype: object

# %%
[f for ft in frequentItems for f in ft]
# Out:
# ['Goat-milk-cheese',
#  'Kartoffelchips',
#  'Chocolate-block',
#  'Pate-a-tartiner-pomme-poire',
#  'Organic-spelt-flour',
#  'Plats-prepares',
#  'Whipping-fresh-cream',
#  'Confiseries',
#  'Couscous',
#  'Juice-milk-drink',
#  'Formulated-supplementary-food',
#  'Lime-pickle',
#  'Sandiwch',
#  'Whole-bean-coffee',
#  'Nectar-de-fruit',
#  'Orange-chocolate',
#  'Preparation-for-dessert',
#  'Hommus',
#  'Soupes',
#  'Corn-tortilla',
#  'Graines',
#  'Redcurrant-tea',
#  'Mango',
#  'Levure',
#  'Vegetarian-mock-meat',
#  'Seed-style-mustard',
#  'Multivitamin-supplement',
#  'Kiwi-fruit',
#  'Pralines',
#  'Oatcakes',
#  'Seabass',
#  'Waffles',
#  'Breakfast-biscuits',
#  'Nutella-biscuits',
#  'Choux-fleurs-en-fleurettes-surgeles',
#  'Milk substitute',
#  'Citrus-punch',
#  'Pork-chipolatas',
#  'Bircarbonate-of-soda',
#  'Flavoured-cranberries',
#  'Pumpkin-soup',
#  'Fruit-spread',
#  'Rice-flakes-sheet',
#  'Cones',
#  'Indian-sauces',
#  'Strawberry-trifle',
#  'Mulled-wine',
#  'Sourdough-bread',
#  'Purple-sprouting-broccoli',
#  'Mate',
#  'Seafood',
#  'Artisan-bread-mix',
#  'Boissons-aux-fruits',
#  'Non food products',
#  'Apple-blackcurrant-drink',
#  'Bieres',
#  'Fresh-apples',
#  'Green-bean-salad',
#  'Sushi',
#  'Soymilk',
#  'Raw-organic-honey',
#  'Caviar substitutes',
#  'Chocolate-mints',
#  'Turkish-fermented-drink',
#  'Products without gluten',
#  'Red-ale',
#  'Peeled-plum-tomatoes',
#  'Salades-strasbourgeoises',
#  'Ratatouille',
#  'Cheddar-baguettes',
#  'Cannellini-beans',
#  'Vegetable-fat-spread',
#  'Chocolat-au-lait',
#  'Frozen-asian-snack-foods',
#  'Peanut-butter-bliss',
#  'Snack',
#  'Pastrami',
#  'Schokoladen',
#  'Pitenza-tomatoes',
#  'Tarama',
#  'Canneloni',
#  'Green-kale',
#  'Custard-tarts',
#  'Steaks-haches-de-boeuf-frais',
#  'Frozen-pork-buns',
#  'Delizio-compatible-coffee-capsules',
#  'Malt-drink',
#  'Milk-based-product',
#  'Grape-juice-drink',
#  'Smoked-oysters-in-barbeque-sauce',
#  'Nans',
#  'Minced-garlic',
#  'Prunes',
#  'Pralinen',
#  'Specialite-a-tartiner',
#  'Juice-drinks',
#  'Galettes-de-polenta',
#  'Riz',
#  'Green-basil',
#  'Fruchtnektar',
#  'Pitted-prunes',
#  'Baking',
#  'Chutney',
#  'Susswaren',
#  'Onion-relish',
#  'Peanut-in-chocolate',
#  'Vegetable-pate',
#  'Burrito-kit',
#  'Licensed products',
#  'Baking-powder',
#  'Boisson-sucree-non-alcoolisee',
#  'Coconut-cream',
#  'Seitan-bio',
#  'Senate-bean-soup',
#  'Fruit juices and nectars',
#  'Rice-candy',
#  'Black-rice',
#  'Canned-precooked-meat',
#  'Pale-ale',
#  'Mache',
#  'Danette-chocolate-dessert',
#  'Freeze-dried foods',
#  'Readymeals',
#  'Crevettes',
#  'Algues-et-derives',
#  'Frozen-battered-fish',
#  'Salads',
#  'Bakery',
#  'Tortilla',
#  'Boneless-pork-loin-steak',
#  'Grattons',
#  'Umbrichelli',
#  'Bbq-relish',
#  'Banana-chips',
#  'Dolce-gusto-compatible-coffee-capsules',
#  'Bay-leaves',
#  'Chia-samen',
#  'Mct-oil',
#  'Brassica',
#  'Almond-milk-yogurt',
#  'Sugary snacks',
#  'Saumons-fumes',
#  'Losenges',
#  'Sweetcorn',
#  'Steak-kidney-pie',
#  'Wasabi',
#  'Mais-a-popcorn',
#  'Farming products',
#  'Mix',
#  'Fresh foods',
#  'Fruit-cups',
#  'Whisky-ecossais',
#  'Sweet-chilli-sauce',
#  'Energy-ball',
#  'Prune-juice',
#  'Fresh-drinking-coconut',
#  'Palm-sugar',
#  'Mineral-natural-water',
#  'Goat-milk-butter',
#  'Cocktail-sauces',
#  'Mushroom-in-sunflower-oil',
#  'Peels',
#  'Bottled-water',
#  'Banana-nut-loaf',
#  'Confitures-allegees',
#  'Fecules',
#  'Jaffa-cakes',
#  'Piccolo-tomatoes',
#  'Dried-sausages',
#  'Vinho-tinto',
#  'Cremes-vegetales-a-base-de-coco-pour-cuisiner',
#  'Passionfruit-pulp',
#  'Nonpareil-capers',
#  'Dietary supplements',
#  'Bouillonterning',
#  'Coconut-flour',
#  'Indian',
#  'Liquid-honey',
#  'Deshydrated-fruit',
#  'Fudge',
#  'Curries',
#  'Fresh-raspberries',
#  'Biscottes',
#  'Chicken-mushroom-pie',
#  'Paves-de-saumon',
#  'Apple-cider-vinegar',
#  'Cooking-chocolate',
#  'Spaghetti-in-tomato-sauce',
#  'Stilton',
#  'Beef-lasagne',
#  'White-pitta-bread',
#  'Caffe',
#  'Confectioner',
#  'Kase',
#  'Poivre-noir',
#  'Crossiants',
#  'Sweet-biscuits',
#  'Strawberry-licorice',
#  'Pork-chops',
#  'Tortillas',
#  'Confiture-biologique',
#  'Sweetcorn-and-peas',
#  'Gratin-de-chou-fleur',
#  'Bison',
#  'Coconut-macaroons',
#  'Caramels-au-beurre-sale',
#  'Grated-parmesan-cheese',
#  'Chicken-meat',
#  'Melk',
#  'Dehydrated-mulberries',
#  'Fresh-mango',
#  'Breakfasts',
#  'Porridge',
#  'Sweetelle-tomatoes',
#  'Vanilla-waffles',
#  'Fruit-spreads',
#  'Granen-en-aardappels',
#  'Cereales-pour-le-petit-dejeuner',
#  'Soft-cheese',
#  'Barritas',
#  'Gourmet-pie',
#  'Orange-juice-from-concentrate',
#  'Chocolate-chip-cookies',
#  'Citrouille-en-conserve',
#  'Coq-au-vin',
#  'Wasabi-popcorn',
#  'Schwarztees',
#  'Fruit-sticks',
#  'Sweeteners',
#  'Baby-sanmarzano-tomatoes',
#  'Corn-snacks',
#  'Sparkling-water-beverage',
#  'Pate',
#  'Hokey-pokey-ice-cream-tubs',
#  'Milk-chocolate-filled-with-caramel',
#  'Spice-red-pepper',
#  'Baked-beans',
#  'Frozen-snacks-aperitifs',
#  'Flavoured-milk-drink',
#  'Oeufs-de-poisson',
#  'Herring-fillets',
#  'Prawn-cocktail',
#  'Chicken-breast-curry-with-tomato-spinach-sauce',
#  'Aoli-sauce',
#  'Carrot-coriander-soup',
#  'Beef-burgers',
#  'Mashed-potatoes',
#  'Pains-d-epices',
#  'Cordial',
#  'Spearmint-sugarfree-gum',
#  'Kale',
#  'Raspberry-preserve',
#  'Chicken-powder',
#  'Sables',
#  'Bhakarwadi',
#  'Sun-dried-tomatoes',
#  'Tejszin',
#  'Hamblokjes',
#  'Salsa',
#  'Whole-wheat-penne-rigate',
#  'Sirop',
#  'Emu-jerky',
#  'Mackerel-filets-in-sunflower-oil',
#  'Asian-cooking',
#  'White-coconut-chocolate',
#  'Terrine',
#  'Sushki',
#  'Cranberry-drink',
#  'Sandwich-spread',
#  'Green-salads',
#  'Chocolate-rice-cakes',
#  'Chilli-con-carne',
#  'Canned-mussels',
#  'Kits',
#  'Frozen-asian-foods',
#  'Chips',
#  'Thes-verts',
#  'Butter-chicken',
#  'Smoked-mussels',
#  'Sunflower-oil-spread',
#  'Eau-de-vie',
#  'Marinated olives',
#  'Lindt-sea-salt-chocolate',
#  'Macaroni-cheese',
#  'Berry-mueslis',
#  'Caramel-dessert',
#  'Faux-fromage',
#  'Fresh-lamb-meat',
#  'Lager-beer',
#  'Plaice',
#  'Lamb-ribs',
#  'Potato-salad',
#  'Roast-ham',
#  'Yeast',
#  'Desserts',
#  'Bieres-blondes',
#  'Non-alcoholic-soft-drink',
#  'Marshmallow-creme',
#  'Pauillac',
#  'Chicken-kiev',
#  'Whole-wheat-pita-bread',
#  'Grana-padano',
#  'Dried-meat',
#  'Garden-peas',
#  'Cremes-fraiches-epaisses',
#  'Pineapple-slices-in-juice',
#  'Blueberry-syrup',
#  'Asparagus-tips',
#  'Snow-peas',
#  'Almond-powder',
#  'Persimmon',
#  'Quinoa-and-rice',
#  'Grape-tomatoes',
#  'Surgelati',
#  'Boxed-chocolates',
#  'Fresh-cakes',
#  'Biskuvi',
#  'Frozen-readymeals',
#  'Feuilletes-chevre-epinards',
#  'Biscuits-with-dark-chocolate',
#  'Crems-glacees',
#  'Fresh-cabbage',
#  'Framboises',
#  'Corn-kernels',
#  'Haferflocken',
#  'Cappuccino-swiss-roll',
#  'Peach-drink',
#  'Aliments-d-origine-vegetale',
#  'Poissons',
#  'Biscuits-au-chocolat',
#  'Guava-juice',
#  'Wholefood',
#  'Mint-jellies',
#  'Brussels-pate',
#  'Hot-fudge',
#  'Sirop-de-fruits',
#  'Samosas',
#  'Indian-readymeals',
#  'Natural-spring-water',
#  'Frozen-donuts',
#  'Bee products',
#  'Frozen-corn-cobs',
#  'Dolminades',
#  'Eggplant-dip',
#  'Gratins-de-legumes',
#  'Semoules-de-ble',
#  'Egg-lasagne',
#  'Dumplings',
#  'Kauwgom',
#  'Eaux-minerales',
#  'Minced-lamb',
#  'Farina',
#  'Fresh-tomatoes',
#  'Pates',
#  'Blended-scotch-whisky',
#  'Aperitif',
#  'Beef-stroganoff',
#  'Cordials',
#  'Tarts',
#  'Plastic-surgery',
#  'Cacao-en-poudre',
#  'Strawberries-canned',
#  'Creme-brulee',
#  'Tranches-de-saumon',
#  'Mulled-wine-spice',
#  'Pancakes-and-waffles',
#  'Capsicums',
#  'Christmas-food',
#  'Fresh-chicken',
#  'Snack-sale',
#  'Fuet-met-zwarte-peper',
#  'Paste',
#  'Sunstream-tomatoes',
#  'Colorants-alimentaires',
#  'Cafe-moulu',
#  'Beef-mince',
#  'Cafes-solubles',
#  'Low-fat-fresh-laban',
#  'Crevettes-roses',
#  'Cottage-cheeses',
#  'Fresh-coconut',
#  'Chilli-con-carne-sauce',
#  'Soft-cheeses',
#  'Kaffir-lime-leaves',
#  'Viande',
#  'Cough-lozenges',
#  'Soupe',
#  'Honey-ham',
#  'Cooking-oil',
#  'Nutrition-bar',
#  'Frozen-baby-octopus',
#  'Churned-cream',
#  'Coriandre',
#  'Bread-rolls',
#  'Capers',
#  'Noix-de-paprika',
#  'Indian-food-mixes',
#  'Coconut-lime-icecream',
#  'Lemongrass-paste',
#  'Spreads',
#  'Chicken-feet',
#  'Garlic-naan-breads',
#  'Canned-lamb-tongue',
#  'Raspberries-in-syrup',
#  'Power-drink',
#  'Tea-drinks',
#  'Raspberry-conserve',
#  'Havarti-cheese',
#  'Venison',
#  'Chili-con-carne',
#  'Fish and meat and eggs',
#  'Gins',
#  'Tomato-chilli-relish',
#  'Pina-colada',
#  'Crab-pate',
#  'Abricots-secs',
#  'Tabouleh-salad',
#  'Bhuja',
#  'White-quinoa',
#  'Roasted-garlic',
#  'Water-crackers',
#  'Breaded products',
#  'Seafood-salad',
#  'Saucissons',
#  'South-african-merlot',
#  'Filets-de-poulet',
#  'Hot-chocolate',
#  'Productos-lacteos',
#  'Parve',
#  'Products sold before year 2000',
#  'Crêpes and galettes',
#  'Roasted-eggplant',
#  'Vegetarian-fish-fillets',
#  'Packaged-pancakes',
#  'Harengs',
#  'Beef-pie',
#  'Creme-caramel',
#  'Salted-snack',
#  'Fruits-frais',
#  'Popping-corn',
#  'Frozen-chicken',
#  'Vitamins',
#  'Frozen-dumplings',
#  'Produits-laitiers',
#  'Ghee',
#  'Biscuits-aperitifs-sales',
#  'Sultanas',
#  'Honey-roast-ham',
#  'Apple-cider',
#  'Damn-if-i-know',
#  'Rice-paper',
#  'Griechische-joghurt',
#  'Groceries',
#  'Vin-de-californie',
#  'Cake-mix',
#  'Garlic-bread',
#  'Nectar-de-pommes',
#  'Tea-lemonade',
#  'Fish-can',
#  'Canned-beverages',
#  'Granola-mix',
#  'Pure-australian-honey',
#  'Asian-food',
#  'Hot-fudge-topping',
#  'Holunder-bluten-sirup',
#  'Brie-cheese',
#  'Organic-tomatoes',
#  'Mayonaise',
#  'Diet-colas',
#  'Cured-sausage',
#  'Corn-tortilla-chips',
#  'Flavoured-mineral-water-beverages',
#  'All-steak-pie',
#  'Leite',
#  'Musliriegel',
#  'Maple-butter',
#  'Rice-cake',
#  'Baby foods',
#  'Prawn-crackers',
#  'Legumes-prepares',
#  'Frozen-asian-vegetables',
#  'Chocolate-chunks',
#  'Biscuits-chocolates',
#  'Whole-wheat-tortillas',
#  'Cornichons-au-vinaigre-pasteurises',
#  'Chicken-breast-fillets',
#  'Roma-tomatoes',
#  'Jus',
#  'Aloe-vera-drink',
#  'Cayenne-pepper-sauce',
#  'Scottish-shortbread',
#  'Cardamom-pods',
#  'Schmelzkase',
#  'Canned foods',
#  'Fruit-confectionary',
#  'Hot-pepper-sauce',
#  'Dindes',
#  'Sunflower-spread',
#  'Pumpkin-seed-pecan',
#  'Green olives',
#  'Tabbouleh',
#  'Prepackaged-sandwiches',
#  'Asperges',
#  'Bread-mix',
#  'Sandwichs',
#  'Edible-decorations',
#  'Suppenwurfel',
#  'Vins-rouges',
#  'Sweetcorn-relish',
#  'Meat-pies',
#  'Salted-peanuts',
#  'Broden',
#  'Salty snacks',
#  'Poudres-cacao',
#  'Indian-food',
#  'Precooked-meat',
#  'Chinese-food',
#  'Pains-au-chocolat',
#  'Basa-fish',
#  'Plats-prepares-surgeles',
#  'Quesos',
#  'Peach',
#  'Meals',
#  'Custard-powder',
#  'Fruit-mince-pies',
#  'Klebreiskuchen',
#  'Olives-noires',
#  'Sirloin-steak',
#  'Coffee-substitute',
#  'Pumpernickel',
#  'Tartar-sauce',
#  'Crumpets',
#  'Caramelized-red-onion-chutney',
#  'Instant-dry-yeast',
#  'Remoulade',
#  'Port',
#  'Fruit-flavoured-drink',
#  'Pain-pita-sucres',
#  'Cream-cheese-spreads',
#  'Penne-rigate',
#  'Sucre',
#  'Semolina',
#  'Wasabi-horseradish',
#  'Yaourt',
#  'Soeppoeder',
#  'Frozen-calamari',
#  'Berries-preserve',
#  'Tortilla-chips',
#  'Vegetarische-kazen',
#  'Jelly-crystals',
#  'Semoules-de-ble-dur-pour-couscous',
#  'Mexican-sauces',
#  'Corn-thins',
#  'Canned-oysters',
#  'Fresh-juices',
#  'Jus-d-orange',
#  'Sandwich',
#  'Penne',
#  'Frozen-petits-pois',
#  'Moussakas',
#  'Assortiment-de-fromages',
#  'Mousse-de-foie-de-porc',
#  'Chopeed-tomatoes',
#  'Blackcurrant-juice-syrup',
#  'Purees-de-legumes',
#  'Wheat-cereals',
#  'Vegetarian-chicken-fillets',
#  'Pains-precuits',
#  'Biscuits-sucres',
#  'Cinnamon-roll',
#  'Psyllium-husk',
#  'Yaourt-aux-fruits',
#  'Slaty-snack',
#  'Chicken-fillet-burger',
#  'Ribeye-steak',
#  'Fizzy-drinks',
#  'Croissant-with-cocoa-cream',
#  'Hazelnut-chocolate-spread',
#  'Raw',
#  'Steak-pie',
#  'Spring-roll-pastry',
#  'Fresh-garlic',
#  'Milch',
#  'Pan-di-spagna',
#  'Fresh-lemons',
#  'Cioccolatini',
#  'Organic-and-premium-pepper-cambodia',
#  'Ice-tea',
#  'Alkoholische-getranke',
#  'Gnocchi',
#  'White-plain-flour',
#  'Latticini',
#  'Snack-bar',
#  'Food additives',
#  'Minced-beef-steak',
#  'Chicken-pies',
#  'San-choy-bao',
#  'Trimmed-beans',
#  'Fresh-strawberries',
#  'Pasta-bake-sauces',
#  'Complements-alimentaires',
#  'Copeaux-de-chocolat-noir',
#  'Tortilla-wraps',
#  'Non-dairy-soymilk',
#  'Cardamom-tea',
#  'Sushis',
#  'Genio-tomatoes',
#  'Almond-flavouring',
#  'Rose-water',
#  'Cous-cous',
#  'Blended-scotch-whiskey',
#  'Soup-mixes',
#  'Compota',
#  'Pappardelle',
#  'Pork-sausages',
#  'Hagelslag',
#  'Kombucha',
#  'Chorizos',
#  'Cream-horseradish',
#  'Fruit-drinks',
#  'Saucisses-aux-lentilles',
#  'Brown-onions',
#  'Chocolats',
#  'Pork-mince',
#  'Mango-drink',
#  'Mango-chutney',
#  'Hoki-fish-fillets',
#  'Lait',
#  'Fruit-flavored',
#  'Chick-peas',
#  'Tomato-ketchup',
#  'Fresh-brown-onions',
#  'Choux-farcis',
#  'Coconut-juice',
#  'Olives-denoyautees',
#  'Fresh-prawns',
#  'Bottled-still-water',
#  'Butter-shortbread-fingers',
#  'Skegness-blue',
#  'Coca-cola',
#  'Luice',
#  'Goat-s-cheese',
#  'Mixed-chillies',
#  'Canned-fruit-salad',
#  'Jarred-asparagus',
#  'Hoisin-sauce',
#  'Coconut-waters',
#  'Bitters',
#  'Sardines-in-brine',
#  'Wheatflour',
#  'Wholemeal-bread',
#  'Chicken-tikka-masala',
#  'Baby-beetroot',
#  'Sandwiches',
#  'Preparations-de-viande-surgelees',
#  'Hawaiian-sweet-rolls',
#  'Splendid-artistry-coffee',
#  'Dulces',
#  'Octopus-balls',
#  'Mackerel-fillets-in-brine',
#  'Curry',
#  'Prepackaged-lettuce',
#  'Absinth',
#  'Fruit-salad',
#  'Getranke',
#  'Lemon-curd',
#  'Jus-de-fruits',
#  'Chinese',
#  'Milk-chocolate-digestives',
#  'Microwave-popcorn',
#  'Vinegars',
#  'Garlic-and-coriander-naan',
#  'Pays-d-oc',
#  'Blinis',
#  'Whole-bean-sprouts-canned',
#  'Chicken-kebabs',
#  'Filo-dough',
#  'Polenta',
#  'Confitures-de-fraises',
#  'Balsamic-vinaigrette',
#  'Beetroot-juice',
#  'Dr-pepper-soft-drink',
#  'Cornish-pasties',
#  'Potato-crips',
#  'Juice-beverage',
#  'Fresh-dates',
#  'Charcuteries',
#  'Mandarins-in-syrup',
#  'Yaourts-aux-fruits',
#  'Fruits-en-conserve',
#  'Dessert-lacte',
#  'Pecans',
#  'Apple-juice-from-concentrate',
#  'Meta-category',
#  'Duck-breast-filets',
#  'Almond-chocolate',
#  'Cheese-analogues',
#  'Smoked-cheese',
#  'Blackcurrent-juice-drink',
#  'Goat-milk',
#  'Premium-and-organic-pepper-from-cambodia',
#  'Asian-condiments',
#  'Baby-rocket',
#  'Ciabatta',
#  'Barres-de-cereales',
#  'Balsamic-vinaigrette-dressing',
#  'Fruchtschnitte',
#  'Biryani',
#  'Edam',
#  'Frozen-chinese-spring-roll-snacks',
#  'Tuna-steak',
#  'Peanut-butter-cup',
#  'Frozen-vegetables-mix',
#  'Chesnut-mushrooms',
#  'Tandoori-chicken-masala',
#  'Dilute-drink',
#  'Blueberry-muffins',
#  'Estragon',
#  'Salmon-in-spring-water',
#  'Cremes-desserts',
#  'Olive-ciabatta',
#  'Hommus-dip',
#  'Pet food',
#  'Frozen-sweetcorn',
#  'Gelati',
#  'Sambuca',
#  'Turkish-delight',
#  'Frozen-asian-food',
#  'Strawberry-preserves',
#  'Chocolate-ice-cream',
#  'Producto-de-aperitivo',
#  'Whole olives',
#  'Tee',
#  'Marinara-sauce',
#  'Cosmetics',
#  'Chicken-eggs',
#  'Gravy',
#  'Magarines',
#  'Getreide-und-getreideprodukte',
#  'Plato-preparado-precocinado',
#  'Green-salad-and-vegetables',
#  'Saumon-atlantique',
#  'Low-fat-high-calcium-milk',
#  'Powder',
#  'Whole-wheat-beard',
#  'Boissons',
#  'Whipping-cream',
#  'Levures',
#  'Peach-juice-drink',
#  'Fruit-juice-concentrate',
#  'Dried-mango',
#  'Cactus',
#  'Pates-a-tartiner-aux-noisettes-et-au-cacao',
#  'Stir-fry-sauce',
#  'Roquefort-cheese',
#  'Prepared-foods',
#  'Carbonated-soda-water',
#  'Milchprodukt',
#  'Syrups',
#  'Chicken-burger',
#  'Strawberry-topping',
#  'Bathroom',
#  'Hot-cocoa-powder',
#  'Lamb-chops',
#  'Pitta-breads',
#  'Medium-cheddar',
#  'Juices',
#  'Genoa-salami',
#  'Feta-cheese',
#  'Golden-syrup',
#  'Beverages',
#  'Fruit juices',
#  'Canned-prawns',
#  'Fresh-bread',
#  'Tuiles-salees',
#  'Vleeswaren',
#  'Sundried-tomatoes',
#  'Melange-d-epices-pour-guacamole',
#  'Breaded-chicken',
#  'Fusilli',
#  'Apple-and-pear-juices',
#  'Stringless-beans',
#  'Liszt',
#  'Draje-sakız',
#  'Deep-fried',
#  'Toppings',
#  'Flour-tortillas',
#  'Beers-from-stralsund',
#  'Protein-powder-drink-mix',
#  'Caramel-popcorn',
#  'Caramel-wafer-bars',
#  'Fruits-secs',
#  'Diced-tomatoes',
#  'Turkey-bacon',
#  'Sliced-cheddar',
#  'Edulcorant-avec-fruit-des-moines',
#  'Strawberry-mousse',
#  'Green-beans',
#  'Probiotic-drinks',
#  'Frozen-snacks',
#  'Rice-crackers',
#  'Fromage-a-pate-dure',
#  'Matzos',
#  'Egg-white-powder',
#  'Minestrone',
#  'Burger-relish',
#  'Vegan-chicken-nuggets',
#  'Fromage-frais',
#  'Rice-wine',
#  'Cherry-pie-filling',
#  'Chinese-cinnamon-sticks',
#  'Pizza dough',
#  'Canned-tuna-in-lemon',
#  'Chocolate-trifle',
#  'Aceite-de-coco',
#  'Groenten',
#  'Beef-broth',
#  'Snackfoods',
#  'Cornichons',
#  'Birthday-cake',
#  'Baked-goods',
#  'Coconut-creams',
#  'Food-coulouring',
#  'Bonbons-a-la-menthe',
#  'Lemon-extract',
#  'Spices-seasoning-mixes',
#  'Cucumbers-in-brine',
#  'Earl-grey',
#  'Melonen',
#  'Custard',
#  'Ricotta',
#  'Cukor',
#  'Beer-batter-fries',
#  'Bruschetta',
#  'Kvarg',
#  'Backpulver',
#  'Glaces',
#  'Bean-flour',
#  'Yoghurts-op-een-laag-fruit',
#  'Quso-duro',
#  'Kaffee',
#  'Nane-limon',
#  'Reduced-fat-milks',
#  'Chilisauce',
#  'Organic-certified',
#  'Pates-fraiches',
#  'Fat-free-milk',
#  'Jambons-blancs',
#  'Conservation',
#  'Oreo',
#  'Skim-milk',
#  'Fresh-corn',
#  'Easter-egg',
#  'Chilli-sauce',
#  'Sugarsnap-peas',
#  'Soap',
#  'Crackers-sans-gluten',
#  'Croque-monsieur',
#  'Chocolate-coins',
#  'Cottage-cheese',
#  'Ranja',
#  'Roasted-and-ground-coffee',
#  'Pear-cider',
#  'Kidney-beans',
#  'Epices',
#  'Rice-noodles',
#  'Radish',
#  'Blue-cheese-yogurt-dressing',
#  'Quenelles',
#  'Marfona-variety',
#  'Breaded-ham',
#  'Juice-drink',
#  'Glace-cherries',
#  'Red-onions',
#  'Cereales',
#  'Ground-cinnamon',
#  'Cigarettes',
#  'Lamb-breast',
#  'Shredded-cheese',
#  'Savoy-cabbage',
#  'Caviars',
#  'Canned-crab-meat',
#  'Kruidentheeen',
#  'Pure-orange-juice-not-from-concentrate',
#  'Iced-cookies',
#  'Tom-yum-soup',
#  'Scotch-eggs',
#  'Thes-glaces',
#  'Caesar-dressing',
#  'Hot-cocoa-mix',
#  'Madeira-cake',
#  'Hard-cooked-peeled-eggs',
#  'Muffin-mix',
#  'Salad',
#  'Coca-sandwich-biscuits',
#  'Flavoured-rice-cakes',
#  'Frozen-dumpling',
#  'Pancake-syrup',
#  'Pure-cod-liver-oil',
#  'Iced-donuts',
#  'Instant-porridge',
#  'Feuille-de-vigne',
#  'Likor',
#  'Linsen',
#  'Meat-pie']

# %%
# Now we remove from the Items those that are not frequentItems
routes.Items = [list(filter(lambda i: i in [f for ft in frequentItems for f in ft], items)) for items in routes.Items]

# %%
routes.Items
# Out:
# 0      [Goat-milk-cheese, Kartoffelchips, Chocolate-b...
# 1      [Goat-milk-cheese, Whole-bean-coffee, Nectar-d...
# 2      [Soupes, Whole-bean-coffee, Chocolate-block, C...
# 3      [Orange-chocolate, Seabass, Soupes, Whole-bean...
# 4      [Citrus-punch, Chocolate-block, Pork-chipolata...
# 5      [Bircarbonate-of-soda, Flavoured-cranberries, ...
# 6      [Apple-blackcurrant-drink, Strawberry-trifle, ...
# 7      [Ratatouille, Cheddar-baguettes, Fruit-spread,...
# 8      [Cheddar-baguettes, Canneloni, Green-kale, Pea...
# 9      [Strawberry-trifle, Nans, Canneloni, Custard-t...
# 10     [Custard-tarts, Prunes, Galettes-de-polenta, R...
# 11     [Fruchtnektar, Custard-tarts, Prunes, Pitted-p...
# 12     [Baking, Custard-tarts, Chutney, Pitted-prunes...
# 13     [Susswaren, Onion-relish, Peanut-in-chocolate,...
# 14     [Peanut-in-chocolate, Seitan-bio, Burrito-kit,...
# 15     [Rice-candy, Peanut-in-chocolate, Senate-bean-...
# 16     [Canned-precooked-meat, Pitted-prunes, Senate-...
# 17     [Danette-chocolate-dessert, Freeze-dried foods...
# 18     [Danette-chocolate-dessert, Algues-et-derives,...
# 19     [Frozen-battered-fish, Salads, Bakery, Tortill...
# 20     [Brassica, Bbq-relish, Banana-chips, Almond-mi...
# 21     [Losenges, Sweetcorn, Steak-kidney-pie, Brassi...
# 22     [Sugary snacks, Losenges, Brassica, Wasabi, En...
# 23     [Mineral-natural-water, Sugary snacks, Goat-mi...
# 24     [Goat-milk-butter, Bottled-water, Banana-nut-l...
# 25     [Chutney, Jaffa-cakes, Banana-nut-loaf, Piccol...
# 26     [Dried-sausages, Vinho-tinto, Cremes-vegetales...
# 27     [Ratatouille, Indian, Dried-sausages, Vinho-ti...
# 28     [Biscottes, Ratatouille, Dried-sausages, Vinho...
# 29     [Dried-sausages, Paves-de-saumon, Danette-choc...
#                              ...
# 722    [Churned-cream, Sandwiches, Paves-de-saumon, P...
# 723    [Pitta-breads, Fruit-flavoured-drink, Sirop-de...
# 724    [Fruit-flavoured-drink, Sirop-de-fruits, Diet-...
# 725    [Cremes-desserts, Nutrition-bar, Fruit-flavour...
# 726    [Sunflower-spread, Soup-mixes, Popping-corn, C...
# 727    [Sunflower-spread, Milchprodukt, Popping-corn,...
# 728    [Barres-de-cereales, Lamb-chops, Spaghetti-in-...
# 729    [Chorizos, Sables, Chicken-kiev, Lamb-chops, C...
# 730    [Herring-fillets, Dindes, Surgelati, Sunflower...
# 731    [Pates, Cured-sausage, Corn-tortilla-chips, Bi...
# 732    [Natural-spring-water, Pates, Instant-porridge...
# 733    [Mackerel-filets-in-sunflower-oil, Fish and me...
# 734    [Mackerel-filets-in-sunflower-oil, Fish and me...
# 735    [Mackerel-filets-in-sunflower-oil, Saucisses-a...
# 736    [Saucisses-aux-lentilles, Turkish-delight, Mil...
# 737    [Saucisses-aux-lentilles, Vleeswaren, Fresh fo...
# 738    [Bread-mix, Saucisses-aux-lentilles, Tortilla,...
# 739    [Ratatouille, Saucisses-aux-lentilles, Vleeswa...
# 740    [Ratatouille, Gratin-de-chou-fleur, Saucisses-...
# 741    [Citrouille-en-conserve, Gratin-de-chou-fleur,...
# 742    [Kidney-beans, Non food products, Fruit-cups, ...
# 743    [Marfona-variety, Fat-free-milk, Pate, Cake-mi...
# 744    [Quenelles, Fresh-raspberries, Preparations-de...
# 745    [Fruit-confectionary, Prunes, Complements-alim...
# 746    [Fruit-confectionary, Milk substitute, Herring...
# 747    [Fruit-confectionary, Parve, Frozen-vegetables...
# 748    [Frozen-vegetables-mix, Soymilk, Whole-bean-sp...
# 749    [Sushi, Soymilk, Caviar substitutes, Aloe-vera...
# 750    [Ratatouille, Sushi, Sourdough-bread, Sandwich...
# 751    [Gratin-de-chou-fleur, Rice-candy, Diced-tomat...
# Name: Items, Length: 752, dtype: object

# %%
# Here we generate combinations of 2 frequent items 
# and we count how many pairs there are for each combination
pairCount     = Counter([comb for combs in [list(permutations(items, 2)) for items in routes.Items] 
                                 for comb in combs])
support = support + pairCount

# and select only those that appear more than the support
frequentPairs = [comb for comb in pairCount 
                         if pairCount[comb] >= supportThreshold]

# %%
# then sort them for next operations and reduce them to a set for removing duplicates  
frequentPairs = list(set( [ tuple(fp) for fp in [sorted(fp) for fp in frequentPairs ] ] ) )

# %%
# Here we remove the duplicates from the frequentPairs
itemInPairs = set(f for fp in frequentPairs for f in fp)

# %%
# This is used to keep track of the tuples at the i-th step
itemsithStep = [list(filter(lambda i: i in itemInPairs, items)) for items in routes.Items]

# %%
#def Remove(duplicate): 
#    final_list = [] 
#    for num in duplicate: 
#        if num not in final_list: 
#            final_list.append(num) 
#    return final_list

# %%
# Max depth for frequent tuples
#depth = 6
#frequentTuples = []
#for i in range(2,depth):
#    subset = []
#    for sl in range(0,len(frequentPairs)):
#        tryitems = frequentPairs[sl][:-1]
#        possibleitems = []
#        for asl in frequentPairs[:sl]+frequentPairs[sl+1:]:
#            if (len(set(tryitems).intersection(set(asl))) == len(tryitems)):
#                possibleitems.append(list(set(asl).difference(set(tryitems))))
#        if possibleitems != []:
#            for ssl in list(combinations(frequentPairs[sl], len(frequentPairs[sl])-1)):
#                if ssl != tryitems:
#                    for el in possibleitems:
#                        elem = el
#                        elem.extend(ssl)
#                        c = tuple(set(elem))
#                        if(set(c) in [set(fp) for fp in frequentPairs]):
#                            c = list(c)
#                            c.extend(list(item for item in tryitems))
#                            subset.append(tuple(set(c)))
#    subset = [tuple(s) for s in Remove(list(set(sb) for sb in subset))]
#    combination = [list(combinations(items, i+1)) for items in routes.Items]
#    comb = [tuple(comb) for combs in combination 
#                for comb in combs]
#    tuplesCount = Counter(comb)
    # and select only those that appear more than the support
#    frequentT = [tuples for tuples in tuplesCount 
#                        if tuplesCount[tuples] >= support]
#    frequentTuples.append(frequentT)
#    frequentPairs = frequentT

# %%
# Max depth for frequent tuples
depth            = 6
frequentTuples   = []
for i in range(2, depth):
    subset       = []
    combination  = [list(permutations(items, i + 1)) for items in itemsithStep]
    comb         = [tuple(comb) for combs in combination 
                                   for comb in combs]
    tuplesCount  = Counter(comb)
    support = support + tuplesCount
    frequentT    = [tuples for tuples in tuplesCount 
                            if tuplesCount[tuples] >= supportThreshold]
    frequentTuples.append(frequentT)
    itemInTuples = set(f for fp in frequentT for f in fp)
    itemsithStep = [list(filter(lambda i: i in itemInTuples, items)) for items in itemsithStep]

# %%
# popularTuples will be our container for interesting objects. 
# Now we can find inside popular items and popular pairs but it is going to be extended.
popularTuples = [ft for ft in frequentItems]
popularTuples.extend(frequentPairs)
for ft in frequentTuples:
    popularTuples.extend(ft)

# %%
def matches(rid, order, popularTuples):
    itemList   = []
    orderItems = routes.Items[(routes.RouteId == rid) & 
                              (routes.Order   == order)
                             ].tolist()[0]
    for obj in popularTuples:
        check = True # here we check if none of the object is inside the orderItems
        for item in obj:
            if item not in orderItems:
                check = False
                break
        if check:    # in that case we add it to the itemList
            itemList.append(list(obj))
    return itemList

def anyOrder(rid, oid, start, popularTuples):
    global orderID
    global tmp
    t = []
    if tmp[oid] == None:
        t = matches(rid, oid, popularTuples)
        tmp[oid] = t
    else:
        t = tmp[oid]
    
    return tuple([oid - start - 1, t])
    
def divideOrder(rid, order, popularTuples):
    global orderID
    global routeID
    global tmp
    dim = routeDimension[rid]
    if (order + 1 < dim):
        if(rid != routeID):
            routeID = rid
            orderID = order
            tmp = [None] * 15
        return [anyOrder(rid, oid, order, popularTuples) for oid in range(order + 1, dim)]
    else:
        return [(-1, [])]

def searchNext(tuples, popularTuples):
    keys        = [(routes.RouteId[row], routes.Order[row]) 
                 for row in range(0, len(routes)) 
                     if set(tuples).intersection(set(routes.Items[row])) == set(tuples)]
    newTuples   = [divideOrder(key[0], key[1], popularTuples) for key in keys]
    return newTuples

# %%
import time
a = time.time()
popularPatterns = [(pop, searchNext(pop, popularTuples)) for pop in popularTuples]
print(time.time()-a)
# Out:
# 48.448314905166626

# %%
# Confidence and Interest level
confidence = 0.5
interest = 0.5

def patternSum(pattern):
    finalPattern = [(i, sum(val for val in pattern[i])) for i in pattern]
    return finalPattern
        
def patternReduce(pattern):
    d = defaultdict(list)
    for key, value in pattern:
        t = tuple([key[0], tuple(key[1])])
        d[t].append(value)
    return d

def patternCount(pattern):
    reduction = patternReduce(pattern)
    count = patternSum(reduction)
    return count

# Limit of classification for frequent Patterns
def patternExtraction(pattern, limit = 5):
    patternLevel = [[(x[0], y), 1] for pat in pattern[1] for x in pat for y in x[1]]
    patternLevel = patternCount(patternLevel)
    finalPattern = [pat for pat in patternLevel if ((pat[1]/support[pattern[0]]) >= confidence) &
                                                   (abs((pat[1]/support[pattern[0]] -
                                                      (support[pat[0][1]]/len(routes)))) >= interest)] 
    return (pattern[0], finalPattern)

# %%
patterns = [patternExtraction(pattern) for pattern in popularPatterns]

# %%
patterns
# Out:
# [(('Goat-milk-cheese',), []),
#  (('Kartoffelchips',), []),
#  (('Chocolate-block',), [((0, ('Chocolate-block',)), 9)]),
#  (('Pate-a-tartiner-pomme-poire',), []),
#  (('Organic-spelt-flour',), []),
#  (('Plats-prepares',), []),
#  (('Whipping-fresh-cream',), []),
#  (('Confiseries',), []),
#  (('Couscous',), []),
#  (('Juice-milk-drink',), []),
#  (('Formulated-supplementary-food',), []),
#  (('Lime-pickle',), []),
#  (('Sandiwch',), []),
#  (('Whole-bean-coffee',), []),
#  (('Nectar-de-fruit',), []),
#  (('Orange-chocolate',), []),
#  (('Preparation-for-dessert',), []),
#  (('Hommus',), []),
#  (('Soupes',), []),
#  (('Corn-tortilla',), []),
#  (('Graines',), []),
#  (('Redcurrant-tea',), []),
#  (('Mango',), []),
#  (('Levure',),
#   [((0, ('Levure',)), 5),
#    ((0, ('Fresh-bread',)), 5),
#    ((0, ('Fresh-bread', 'Levure')), 5)]),
#  (('Vegetarian-mock-meat',), []),
#  (('Seed-style-mustard',), []),
#  (('Multivitamin-supplement',), []),
#  (('Kiwi-fruit',), []),
#  (('Pralines',), []),
#  (('Oatcakes',), []),
#  (('Seabass',), []),
#  (('Waffles',), []),
#  (('Breakfast-biscuits',), []),
#  (('Nutella-biscuits',), []),
#  (('Choux-fleurs-en-fleurettes-surgeles',), []),
#  (('Milk substitute',), []),
#  (('Citrus-punch',), []),
#  (('Pork-chipolatas',), []),
#  (('Bircarbonate-of-soda',), []),
#  (('Flavoured-cranberries',), []),
#  (('Pumpkin-soup',), []),
#  (('Fruit-spread',), []),
#  (('Rice-flakes-sheet',), []),
#  (('Cones',),
#   [((0, ('Seafood',)), 3),
#    ((0, ('Cones',)), 3),
#    ((1, ('Pale-ale',)), 3),
#    ((0, ('Pale-ale',)), 3)]),
#  (('Indian-sauces',), []),
#  (('Strawberry-trifle',), []),
#  (('Mulled-wine',), []),
#  (('Sourdough-bread',), []),
#  (('Purple-sprouting-broccoli',), [((0, ('Purple-sprouting-broccoli',)), 8)]),
#  (('Mate',), []),
#  (('Seafood',), [((0, ('Seafood',)), 17)]),
#  (('Artisan-bread-mix',), []),
#  (('Boissons-aux-fruits',), []),
#  (('Non food products',), []),
#  (('Apple-blackcurrant-drink',), []),
#  (('Bieres',), []),
#  (('Fresh-apples',), []),
#  (('Green-bean-salad',), []),
#  (('Sushi',), []),
#  (('Soymilk',), []),
#  (('Raw-organic-honey',), []),
#  (('Caviar substitutes',), []),
#  (('Chocolate-mints',), []),
#  (('Turkish-fermented-drink',), []),
#  (('Products without gluten',), []),
#  (('Red-ale',), []),
#  (('Peeled-plum-tomatoes',), []),
#  (('Salades-strasbourgeoises',), []),
#  (('Ratatouille',), []),
#  (('Cheddar-baguettes',), []),
#  (('Cannellini-beans',), []),
#  (('Vegetable-fat-spread',), []),
#  (('Chocolat-au-lait',), []),
#  (('Frozen-asian-snack-foods',), []),
#  (('Peanut-butter-bliss',), []),
#  (('Snack',), []),
#  (('Pastrami',), []),
#  (('Schokoladen',), []),
#  (('Pitenza-tomatoes',), []),
#  (('Tarama',), []),
#  (('Canneloni',), [((0, ('Canneloni',)), 5)]),
#  (('Green-kale',), []),
#  (('Custard-tarts',), []),
#  (('Steaks-haches-de-boeuf-frais',), []),
#  (('Frozen-pork-buns',), []),
#  (('Delizio-compatible-coffee-capsules',), []),
#  (('Malt-drink',), []),
#  (('Milk-based-product',), [((0, ('Milk-based-product',)), 7)]),
#  (('Grape-juice-drink',), []),
#  (('Smoked-oysters-in-barbeque-sauce',), []),
#  (('Nans',), []),
#  (('Minced-garlic',), []),
#  (('Prunes',), []),
#  (('Pralinen',), []),
#  (('Specialite-a-tartiner',), []),
#  (('Juice-drinks',), []),
#  (('Galettes-de-polenta',), []),
#  (('Riz',), []),
#  (('Green-basil',), []),
#  (('Fruchtnektar',), []),
#  (('Pitted-prunes',), []),
#  (('Baking',), []),
#  (('Chutney',), []),
#  (('Susswaren',), []),
#  (('Onion-relish',), []),
#  (('Peanut-in-chocolate',), []),
#  (('Vegetable-pate',), []),
#  (('Burrito-kit',), []),
#  (('Licensed products',), []),
#  (('Baking-powder',), []),
#  (('Boisson-sucree-non-alcoolisee',), []),
#  (('Coconut-cream',), []),
#  (('Seitan-bio',), []),
#  (('Senate-bean-soup',), []),
#  (('Fruit juices and nectars',), []),
#  (('Rice-candy',), []),
#  (('Black-rice',), []),
#  (('Canned-precooked-meat',), []),
#  (('Pale-ale',), [((0, ('Pale-ale',)), 8)]),
#  (('Mache',), []),
#  (('Danette-chocolate-dessert',), []),
#  (('Freeze-dried foods',), []),
#  (('Readymeals',), []),
#  (('Crevettes',), []),
#  (('Algues-et-derives',), []),
#  (('Frozen-battered-fish',), []),
#  (('Salads',), []),
#  (('Bakery',), []),
#  (('Tortilla',), []),
#  (('Boneless-pork-loin-steak',), []),
#  (('Grattons',), []),
#  (('Umbrichelli',), []),
#  (('Bbq-relish',), []),
#  (('Banana-chips',), []),
#  (('Dolce-gusto-compatible-coffee-capsules',), []),
#  (('Bay-leaves',), []),
#  (('Chia-samen',), []),
#  (('Mct-oil',), [((0, ('Mct-oil',)), 5), ((0, ('Sugary snacks',)), 4)]),
#  (('Brassica',), []),
#  (('Almond-milk-yogurt',), []),
#  (('Sugary snacks',), []),
#  (('Saumons-fumes',), []),
#  (('Losenges',), [((0, ('Losenges',)), 6)]),
#  (('Sweetcorn',), []),
#  (('Steak-kidney-pie',), []),
#  (('Wasabi',), []),
#  (('Mais-a-popcorn',), []),
#  (('Farming products',), []),
#  (('Mix',), []),
#  (('Fresh foods',), []),
#  (('Fruit-cups',), []),
#  (('Whisky-ecossais',), []),
#  (('Sweet-chilli-sauce',), []),
#  (('Energy-ball',), [((0, ('Energy-ball',)), 6)]),
#  (('Prune-juice',),
#   [((0, ('Snack',)), 3),
#    ((0, ('Wasabi',)), 3),
#    ((0, ('Prune-juice',)), 3),
#    ((0, ('Prune-juice', 'Wasabi')), 3)]),
#  (('Fresh-drinking-coconut',), []),
#  (('Palm-sugar',), []),
#  (('Mineral-natural-water',), []),
#  (('Goat-milk-butter',), []),
#  (('Cocktail-sauces',), []),
#  (('Mushroom-in-sunflower-oil',), []),
#  (('Peels',), []),
#  (('Bottled-water',), []),
#  (('Banana-nut-loaf',), []),
#  (('Confitures-allegees',), []),
#  (('Fecules',), []),
#  (('Jaffa-cakes',), []),
#  (('Piccolo-tomatoes',), []),
#  (('Dried-sausages',), [((0, ('Dried-sausages',)), 9)]),
#  (('Vinho-tinto',), [((0, ('Vinho-tinto',)), 7)]),
#  (('Cremes-vegetales-a-base-de-coco-pour-cuisiner',), []),
#  (('Passionfruit-pulp',),
#   [((0, ('Dried-sausages',)), 4),
#    ((0, ('Vinho-tinto',)), 4),
#    ((0, ('Passionfruit-pulp',)), 4),
#    ((1, ('Vinho-tinto',)), 4),
#    ((3, ('Apple-cider-vinegar',)), 4),
#    ((4, ('Apple-cider-vinegar',)), 4)]),
#  (('Nonpareil-capers',), [((0, ('Galettes-de-polenta',)), 4)]),
#  (('Dietary supplements',), []),
#  (('Bouillonterning',), []),
#  (('Coconut-flour',), []),
#  (('Indian',), []),
#  (('Liquid-honey',), []),
#  (('Deshydrated-fruit',), []),
#  (('Fudge',), [((0, ('Fudge',)), 6)]),
#  (('Curries',), []),
#  (('Fresh-raspberries',), []),
#  (('Biscottes',), []),
#  (('Chicken-mushroom-pie',), []),
#  (('Paves-de-saumon',), []),
#  (('Apple-cider-vinegar',), []),
#  (('Cooking-chocolate',), []),
#  (('Spaghetti-in-tomato-sauce',), []),
#  (('Stilton',), []),
#  (('Beef-lasagne',), []),
#  (('White-pitta-bread',), []),
#  (('Caffe',), [((0, ('Caffe',)), 8)]),
#  (('Confectioner',), []),
#  (('Kase',), []),
#  (('Poivre-noir',), []),
#  (('Crossiants',), []),
#  (('Sweet-biscuits',), []),
#  (('Strawberry-licorice',), []),
#  (('Pork-chops',), []),
#  (('Tortillas',), []),
#  (('Confiture-biologique',), []),
#  (('Sweetcorn-and-peas',), []),
#  (('Gratin-de-chou-fleur',), []),
#  (('Bison',), []),
#  (('Coconut-macaroons',), []),
#  (('Caramels-au-beurre-sale',), []),
#  (('Grated-parmesan-cheese',), [((0, ('Grated-parmesan-cheese',)), 4)]),
#  (('Chicken-meat',), []),
#  (('Melk',), []),
#  (('Dehydrated-mulberries',), []),
#  (('Fresh-mango',), []),
#  (('Breakfasts',), []),
#  (('Porridge',), []),
#  (('Sweetelle-tomatoes',), []),
#  (('Vanilla-waffles',), []),
#  (('Fruit-spreads',), []),
#  (('Granen-en-aardappels',), []),
#  (('Cereales-pour-le-petit-dejeuner',), []),
#  (('Soft-cheese',), []),
#  (('Barritas',), []),
#  (('Gourmet-pie',), []),
#  (('Orange-juice-from-concentrate',), []),
#  (('Chocolate-chip-cookies',), []),
#  (('Citrouille-en-conserve',), []),
#  (('Coq-au-vin',), []),
#  (('Wasabi-popcorn',), []),
#  (('Schwarztees',), []),
#  (('Fruit-sticks',), []),
#  (('Sweeteners',), []),
#  (('Baby-sanmarzano-tomatoes',), [((1, ('Minced-garlic',)), 4)]),
#  (('Corn-snacks',), []),
#  (('Sparkling-water-beverage',), []),
#  (('Pate',), []),
#  (('Hokey-pokey-ice-cream-tubs',), []),
#  (('Milk-chocolate-filled-with-caramel',), []),
#  (('Spice-red-pepper',), []),
#  (('Baked-beans',), []),
#  (('Frozen-snacks-aperitifs',), []),
#  (('Flavoured-milk-drink',), []),
#  (('Oeufs-de-poisson',), []),
#  (('Herring-fillets',), []),
#  (('Prawn-cocktail',), []),
#  (('Chicken-breast-curry-with-tomato-spinach-sauce',), []),
#  (('Aoli-sauce',), []),
#  (('Carrot-coriander-soup',), []),
#  (('Beef-burgers',), []),
#  (('Mashed-potatoes',), []),
#  (('Pains-d-epices',), []),
#  (('Cordial',), []),
#  (('Spearmint-sugarfree-gum',), []),
#  (('Kale',), []),
#  (('Raspberry-preserve',), []),
#  (('Chicken-powder',), [((0, ('Chicken-powder',)), 4)]),
#  (('Sables',), []),
#  (('Bhakarwadi',), []),
#  (('Sun-dried-tomatoes',), []),
#  (('Tejszin',), [((0, ('Tejszin',)), 10)]),
#  (('Hamblokjes',), []),
#  (('Salsa',), []),
#  (('Whole-wheat-penne-rigate',), []),
#  (('Sirop',), []),
#  (('Emu-jerky',), []),
#  (('Mackerel-filets-in-sunflower-oil',),
#   [((0, ('Mackerel-filets-in-sunflower-oil',)), 6)]),
#  (('Asian-cooking',), []),
#  (('White-coconut-chocolate',), []),
#  (('Terrine',), [((0, ('Terrine',)), 8)]),
#  (('Sushki',), []),
#  (('Cranberry-drink',), []),
#  (('Sandwich-spread',), []),
#  (('Green-salads',), []),
#  (('Chocolate-rice-cakes',),
#   [((0, ('Chocolate-rice-cakes',)), 4), ((1, ('Chocolat-au-lait',)), 4)]),
#  (('Chilli-con-carne',), []),
#  (('Canned-mussels',), []),
#  (('Kits',), []),
#  (('Frozen-asian-foods',), []),
#  (('Chips',), []),
#  (('Thes-verts',), []),
#  (('Butter-chicken',), []),
#  (('Smoked-mussels',), []),
#  (('Sunflower-oil-spread',), []),
#  (('Eau-de-vie',), []),
#  (('Marinated olives',), []),
#  (('Lindt-sea-salt-chocolate',), []),
#  (('Macaroni-cheese',), []),
#  (('Berry-mueslis',), []),
#  (('Caramel-dessert',), []),
#  (('Faux-fromage',), []),
#  (('Fresh-lamb-meat',), []),
#  (('Lager-beer',), []),
#  (('Plaice',), []),
#  (('Lamb-ribs',), []),
#  (('Potato-salad',), []),
#  (('Roast-ham',), []),
#  (('Yeast',), [((0, ('Yeast',)), 3)]),
#  (('Desserts',), [((0, ('Desserts',)), 5)]),
#  (('Bieres-blondes',), []),
#  (('Non-alcoholic-soft-drink',), []),
#  (('Marshmallow-creme',), []),
#  (('Pauillac',), []),
#  (('Chicken-kiev',), []),
#  (('Whole-wheat-pita-bread',), []),
#  (('Grana-padano',), []),
#  (('Dried-meat',), [((0, ('Dried-meat',)), 4)]),
#  (('Garden-peas',), []),
#  (('Cremes-fraiches-epaisses',), []),
#  (('Pineapple-slices-in-juice',), []),
#  (('Blueberry-syrup',), []),
#  (('Asparagus-tips',), []),
#  (('Snow-peas',), []),
#  (('Almond-powder',),
#   [((0, ('Almond-powder',)), 6),
#    ((1, ('Tejszin',)), 5),
#    ((1, ('Almond-powder',)), 5),
#    ((1, ('Almond-powder', 'Tejszin')), 5),
#    ((0, ('Tejszin',)), 5),
#    ((0, ('Almond-powder', 'Tejszin')), 5)]),
#  (('Persimmon',), []),
#  (('Quinoa-and-rice',), []),
#  (('Grape-tomatoes',),
#   [((0, ('Grape-tomatoes',)), 4),
#    ((4, ('Bee products',)), 4),
#    ((2, ('Natural-spring-water',)), 4),
#    ((3, ('Bee products',)), 4)]),
#  (('Surgelati',), []),
#  (('Boxed-chocolates',), []),
#  (('Fresh-cakes',), []),
#  (('Biskuvi',), []),
#  (('Frozen-readymeals',), []),
#  (('Feuilletes-chevre-epinards',), []),
#  (('Biscuits-with-dark-chocolate',), []),
#  (('Crems-glacees',), []),
#  (('Fresh-cabbage',), []),
#  (('Framboises',), []),
#  (('Corn-kernels',), []),
#  (('Haferflocken',), [((0, ('Haferflocken',)), 4)]),
#  (('Cappuccino-swiss-roll',), []),
#  (('Peach-drink',), []),
#  (('Aliments-d-origine-vegetale',), []),
#  (('Poissons',), []),
#  (('Biscuits-au-chocolat',), [((0, ('Biscuits-au-chocolat',)), 6)]),
#  (('Guava-juice',), [((0, ('Guava-juice',)), 4)]),
#  (('Wholefood',), []),
#  (('Mint-jellies',), []),
#  (('Brussels-pate',),
#   [((1, ('Frozen-chinese-spring-roll-snacks',)), 4),
#    ((2, ('Frozen-chinese-spring-roll-snacks',)), 4)]),
#  (('Hot-fudge',), []),
#  (('Sirop-de-fruits',), []),
#  (('Samosas',), []),
#  (('Indian-readymeals',), []),
#  (('Natural-spring-water',), []),
#  (('Frozen-donuts',), []),
#  (('Bee products',), []),
#  (('Frozen-corn-cobs',), []),
#  (('Dolminades',), []),
#  (('Eggplant-dip',), []),
#  (('Gratins-de-legumes',), []),
#  (('Semoules-de-ble',), [((0, ('Semoules-de-ble',)), 7)]),
#  (('Egg-lasagne',), []),
#  (('Dumplings',), []),
#  (('Kauwgom',), []),
#  (('Eaux-minerales',), []),
#  (('Minced-lamb',), []),
#  (('Farina',), []),
#  (('Fresh-tomatoes',), []),
#  (('Pates',), []),
#  (('Blended-scotch-whisky',), []),
#  (('Aperitif',), []),
#  (('Beef-stroganoff',), []),
#  (('Cordials',), []),
#  (('Tarts',), []),
#  (('Plastic-surgery',), []),
#  (('Cacao-en-poudre',), []),
#  (('Strawberries-canned',), []),
#  (('Creme-brulee',), []),
#  (('Tranches-de-saumon',), []),
#  (('Mulled-wine-spice',), []),
#  (('Pancakes-and-waffles',), []),
#  (('Capsicums',), []),
#  (('Christmas-food',), []),
#  (('Fresh-chicken',), []),
#  (('Snack-sale',), []),
#  (('Fuet-met-zwarte-peper',), []),
#  (('Paste',), []),
#  (('Sunstream-tomatoes',), []),
#  (('Colorants-alimentaires',), []),
#  (('Cafe-moulu',), []),
#  (('Beef-mince',), []),
#  (('Cafes-solubles',), []),
#  (('Low-fat-fresh-laban',), [((0, ('Low-fat-fresh-laban',)), 8)]),
#  (('Crevettes-roses',), []),
#  (('Cottage-cheeses',), []),
#  (('Fresh-coconut',), []),
#  (('Chilli-con-carne-sauce',), []),
#  (('Soft-cheeses',), []),
#  (('Kaffir-lime-leaves',), []),
#  (('Viande',), []),
#  (('Cough-lozenges',), []),
#  (('Soupe',), []),
#  (('Honey-ham',), []),
#  (('Cooking-oil',), []),
#  (('Nutrition-bar',), []),
#  (('Frozen-baby-octopus',), []),
#  (('Churned-cream',), []),
#  (('Coriandre',), []),
#  (('Bread-rolls',), []),
#  (('Capers',), []),
#  (('Noix-de-paprika',), []),
#  (('Indian-food-mixes',), []),
#  (('Coconut-lime-icecream',), []),
#  (('Lemongrass-paste',), []),
#  (('Spreads',), [((0, ('Spreads',)), 8)]),
#  (('Chicken-feet',), []),
#  (('Garlic-naan-breads',), []),
#  (('Canned-lamb-tongue',), []),
#  (('Raspberries-in-syrup',), [((0, ('Raspberries-in-syrup',)), 7)]),
#  (('Power-drink',), []),
#  (('Tea-drinks',), []),
#  (('Raspberry-conserve',), []),
#  (('Havarti-cheese',), []),
#  (('Venison',), []),
#  (('Chili-con-carne',), []),
#  (('Fish and meat and eggs',), [((0, ('Fish and meat and eggs',)), 11)]),
#  (('Gins',), [((0, ('Desserts',)), 3), ((1, ('Desserts',)), 3)]),
#  (('Tomato-chilli-relish',), []),
#  (('Pina-colada',), []),
#  (('Crab-pate',), []),
#  (('Abricots-secs',), []),
#  (('Tabouleh-salad',), []),
#  (('Bhuja',), []),
#  (('White-quinoa',), [((0, ('White-quinoa',)), 10)]),
#  (('Roasted-garlic',), []),
#  (('Water-crackers',), []),
#  (('Breaded products',), []),
#  (('Seafood-salad',), []),
#  (('Saucissons',), []),
#  (('South-african-merlot',), []),
#  (('Filets-de-poulet',), []),
#  (('Hot-chocolate',), []),
#  (('Productos-lacteos',), []),
#  (('Parve',), []),
#  (('Products sold before year 2000',), []),
#  (('Crêpes and galettes',), []),
#  (('Roasted-eggplant',), []),
#  (('Vegetarian-fish-fillets',), []),
#  (('Packaged-pancakes',), []),
#  (('Harengs',), []),
#  (('Beef-pie',), []),
#  (('Creme-caramel',), []),
#  (('Salted-snack',), []),
#  (('Fruits-frais',), []),
#  (('Popping-corn',), []),
#  (('Frozen-chicken',), []),
#  (('Vitamins',), []),
#  (('Frozen-dumplings',), []),
#  (('Produits-laitiers',), []),
#  (('Ghee',), []),
#  (('Biscuits-aperitifs-sales',), []),
#  (('Sultanas',), []),
#  (('Honey-roast-ham',), []),
#  (('Apple-cider',), []),
#  (('Damn-if-i-know',), [((0, ('Damn-if-i-know',)), 9)]),
#  (('Rice-paper',), []),
#  (('Griechische-joghurt',), []),
#  (('Groceries',), []),
#  (('Vin-de-californie',), []),
#  (('Cake-mix',), []),
#  (('Garlic-bread',), []),
#  (('Nectar-de-pommes',), []),
#  (('Tea-lemonade',), [((0, ('Tea-lemonade',)), 6)]),
#  (('Fish-can',), []),
#  (('Canned-beverages',),
#   [((0, ('Canned-beverages',)), 4), ((0, ('Custard-powder',)), 4)]),
#  (('Granola-mix',), []),
#  (('Pure-australian-honey',), []),
#  (('Asian-food',), []),
#  (('Hot-fudge-topping',), []),
#  (('Holunder-bluten-sirup',), []),
#  (('Brie-cheese',), []),
#  (('Organic-tomatoes',), []),
#  (('Mayonaise',), []),
#  (('Diet-colas',), []),
#  (('Cured-sausage',), []),
#  (('Corn-tortilla-chips',), []),
#  (('Flavoured-mineral-water-beverages',), []),
#  (('All-steak-pie',), []),
#  (('Leite',), []),
#  (('Musliriegel',), []),
#  (('Maple-butter',), []),
#  (('Rice-cake',), []),
#  (('Baby foods',), []),
#  (('Prawn-crackers',), []),
#  (('Legumes-prepares',), []),
#  (('Frozen-asian-vegetables',), []),
#  (('Chocolate-chunks',), []),
#  (('Biscuits-chocolates',), []),
#  (('Whole-wheat-tortillas',), []),
#  (('Cornichons-au-vinaigre-pasteurises',), []),
#  (('Chicken-breast-fillets',), []),
#  (('Roma-tomatoes',), []),
#  (('Jus',), []),
#  (('Aloe-vera-drink',), []),
#  (('Cayenne-pepper-sauce',), []),
#  (('Scottish-shortbread',), []),
#  (('Cardamom-pods',), []),
#  (('Schmelzkase',), []),
#  (('Canned foods',),
#   [((0, ('Indian-sauces',)), 3),
#    ((0, ('Savoy-cabbage',)), 3),
#    ((0, ('Kruidentheeen',)), 3),
#    ((1, ('Indian-sauces',)), 3),
#    ((1, ('Sunstream-tomatoes',)), 3)]),
#  (('Fruit-confectionary',), []),
#  (('Hot-pepper-sauce',), []),
#  (('Dindes',), []),
#  (('Sunflower-spread',), []),
#  (('Pumpkin-seed-pecan',), []),
#  (('Green olives',),
#   [((0, ('Green olives',)), 4),
#    ((3, ('Indian-food',)), 5),
#    ((2, ('Indian-food',)), 4)]),
#  (('Tabbouleh',), []),
#  (('Prepackaged-sandwiches',), []),
#  (('Asperges',), [((0, ('Asperges',)), 7)]),
#  (('Bread-mix',), []),
#  (('Sandwichs',), []),
#  (('Edible-decorations',), []),
#  (('Suppenwurfel',), []),
#  (('Vins-rouges',), []),
#  (('Sweetcorn-relish',), []),
#  (('Meat-pies',), []),
#  (('Salted-peanuts',), []),
#  (('Broden',), []),
#  (('Salty snacks',), []),
#  (('Poudres-cacao',), [((0, ('Poudres-cacao',)), 10)]),
#  (('Indian-food',), []),
#  (('Precooked-meat',), []),
#  (('Chinese-food',), []),
#  (('Pains-au-chocolat',), []),
#  (('Basa-fish',), []),
#  (('Plats-prepares-surgeles',), []),
#  (('Quesos',), []),
#  (('Peach',), []),
#  (('Meals',), []),
#  (('Custard-powder',), [((0, ('Custard-powder',)), 6)]),
#  (('Fruit-mince-pies',), []),
#  (('Klebreiskuchen',), []),
#  (('Olives-noires',), []),
#  (('Sirloin-steak',),
#   [((0, ('Canned-beverages',)), 3),
#    ((0, ('Custard-powder',)), 4),
#    ((0, ('Sirloin-steak',)), 3),
#    ((0, ('Coffee-substitute',)), 3),
#    ((1, ('Custard-powder',)), 3),
#    ((1, ('Remoulade',)), 3),
#    ((3, ('Sucre',)), 3),
#    ((0, ('Remoulade',)), 3),
#    ((2, ('Sucre',)), 3)]),
#  (('Coffee-substitute',), []),
#  (('Pumpernickel',), []),
#  (('Tartar-sauce',), []),
#  (('Crumpets',), []),
#  (('Caramelized-red-onion-chutney',), []),
#  (('Instant-dry-yeast',), []),
#  (('Remoulade',), [((1, ('Sucre',)), 3)]),
#  (('Port',), []),
#  (('Fruit-flavoured-drink',), []),
#  (('Pain-pita-sucres',), []),
#  (('Cream-cheese-spreads',), []),
#  (('Penne-rigate',), []),
#  (('Sucre',), [((0, ('Sucre',)), 8)]),
#  (('Semolina',), []),
#  (('Wasabi-horseradish',), []),
#  (('Yaourt',), []),
#  (('Soeppoeder',), []),
#  (('Frozen-calamari',), []),
#  (('Berries-preserve',),
#   [((0, ('Berries-preserve',)), 7),
#    ((1, ('Fresh-cabbage',)), 6),
#    ((1, ('Wheat-cereals',)), 6),
#    ((1, ('Fresh-cabbage', 'Wheat-cereals')), 6)]),
#  (('Tortilla-chips',), [((0, ('Tortilla-chips',)), 5)]),
#  (('Vegetarische-kazen',), []),
#  (('Jelly-crystals',), []),
#  (('Semoules-de-ble-dur-pour-couscous',), []),
#  (('Mexican-sauces',), []),
#  (('Corn-thins',), []),
#  (('Canned-oysters',), []),
#  (('Fresh-juices',), []),
#  (('Jus-d-orange',), []),
#  (('Sandwich',), [((0, ('Sandwich',)), 6)]),
#  (('Penne',), []),
#  (('Frozen-petits-pois',), []),
#  (('Moussakas',), [((0, ('Moussakas',)), 5)]),
#  (('Assortiment-de-fromages',), []),
#  (('Mousse-de-foie-de-porc',), []),
#  (('Chopeed-tomatoes',),
#   [((0, ('Fresh-cabbage',)), 5),
#    ((0, ('Chopeed-tomatoes',)), 5),
#    ((0, ('Wheat-cereals',)), 5),
#    ((0, ('Fresh-cabbage', 'Wheat-cereals')), 5)]),
#  (('Blackcurrant-juice-syrup',), []),
#  (('Purees-de-legumes',), []),
#  (('Wheat-cereals',), [((0, ('Wheat-cereals',)), 7)]),
#  (('Vegetarian-chicken-fillets',), []),
#  (('Pains-precuits',), []),
#  (('Biscuits-sucres',), []),
#  (('Cinnamon-roll',), [((0, ('Cinnamon-roll',)), 8)]),
#  (('Psyllium-husk',), []),
#  (('Yaourt-aux-fruits',), []),
#  (('Slaty-snack',), []),
#  (('Chicken-fillet-burger',), []),
#  (('Ribeye-steak',), []),
#  (('Fizzy-drinks',), []),
#  (('Croissant-with-cocoa-cream',), []),
#  (('Hazelnut-chocolate-spread',), []),
#  (('Raw',), []),
#  (('Steak-pie',), []),
#  (('Spring-roll-pastry',), []),
#  (('Fresh-garlic',), []),
#  (('Milch',), []),
#  (('Pan-di-spagna',), []),
#  (('Fresh-lemons',), [((0, ('Fresh-lemons',)), 4)]),
#  (('Cioccolatini',), []),
#  (('Organic-and-premium-pepper-cambodia',),
#   [((0, ('Organic-and-premium-pepper-cambodia',)), 9)]),
#  (('Ice-tea',), []),
#  (('Alkoholische-getranke',), []),
#  (('Gnocchi',), []),
#  (('White-plain-flour',), []),
#  (('Latticini',), []),
#  (('Snack-bar',), []),
#  (('Food additives',), [((0, ('Food additives',)), 5)]),
#  (('Minced-beef-steak',), []),
#  (('Chicken-pies',), []),
#  (('San-choy-bao',),
#   [((0, ('San-choy-bao',)), 4),
#    ((0, ('Mousse-de-foie-de-porc',)), 4),
#    ((0, ('Luice',)), 4)]),
#  (('Trimmed-beans',), []),
#  (('Fresh-strawberries',), []),
#  (('Pasta-bake-sauces',),
#   [((0, ('Olives-noires',)), 4), ((2, ('Salsa',)), 4)]),
#  (('Complements-alimentaires',), []),
#  (('Copeaux-de-chocolat-noir',), []),
#  (('Tortilla-wraps',), []),
#  (('Non-dairy-soymilk',), []),
#  (('Cardamom-tea',), []),
#  (('Sushis',), []),
#  (('Genio-tomatoes',), []),
#  (('Almond-flavouring',), []),
#  (('Rose-water',), []),
#  (('Cous-cous',), [((0, ('Cous-cous',)), 4), ((0, ('Backpulver',)), 4)]),
#  (('Blended-scotch-whiskey',), []),
#  (('Soup-mixes',), []),
#  (('Compota',), []),
#  (('Pappardelle',), []),
#  (('Pork-sausages',), []),
#  (('Hagelslag',), []),
#  (('Kombucha',),
#   [((0, ('Kombucha',)), 4),
#    ((0, ('Feuille-de-vigne',)), 4),
#    ((0, ('Likor',)), 4),
#    ((0, ('Feuille-de-vigne', 'Likor')), 4),
#    ((1, ('Red-onions',)), 4),
#    ((1, ('Feuille-de-vigne',)), 4),
#    ((1, ('Likor',)), 4),
#    ((1, ('Feuille-de-vigne', 'Likor')), 4),
#    ((2, ('Feuille-de-vigne',)), 4)]),
#  (('Chorizos',), []),
#  (('Cream-horseradish',), [((0, ('Cream-horseradish',)), 5)]),
#  (('Fruit-drinks',), []),
#  (('Saucisses-aux-lentilles',), []),
#  (('Brown-onions',), []),
#  (('Chocolats',), []),
#  (('Pork-mince',), []),
#  (('Mango-drink',), []),
#  (('Mango-chutney',), []),
#  (('Hoki-fish-fillets',), []),
#  (('Lait',), []),
#  (('Fruit-flavored',), []),
#  (('Chick-peas',), []),
#  (('Tomato-ketchup',), []),
#  (('Fresh-brown-onions',), []),
#  (('Choux-farcis',), []),
#  (('Coconut-juice',), []),
#  (('Olives-denoyautees',), []),
#  (('Fresh-prawns',), []),
#  (('Bottled-still-water',), []),
#  (('Butter-shortbread-fingers',), []),
#  (('Skegness-blue',), []),
#  (('Coca-cola',), []),
#  (('Luice',), []),
#  (('Goat-s-cheese',), []),
#  (('Mixed-chillies',), []),
#  (('Canned-fruit-salad',), []),
#  (('Jarred-asparagus',), []),
#  (('Hoisin-sauce',), [((0, ('Crossiants',)), 3)]),
#  (('Coconut-waters',), []),
#  (('Bitters',), []),
#  (('Sardines-in-brine',), []),
#  (('Wheatflour',), []),
#  (('Wholemeal-bread',),
#   [((0, ('Wholemeal-bread',)), 3),
#    ((0, ('Confiture-biologique',)), 3),
#    ((0, ('Pitta-breads',)), 3),
#    ((1, ('Pitta-breads',)), 3),
#    ((1, ('Baked-goods',)), 3),
#    ((2, ('Pitta-breads',)), 3)]),
#  (('Chicken-tikka-masala',), []),
#  (('Baby-beetroot',), []),
#  (('Sandwiches',), []),
#  (('Preparations-de-viande-surgelees',), []),
#  (('Hawaiian-sweet-rolls',), []),
#  (('Splendid-artistry-coffee',), []),
#  (('Dulces',), []),
#  (('Octopus-balls',), []),
#  (('Mackerel-fillets-in-brine',),
#   [((0, ('Hazelnut-chocolate-spread',)), 3),
#    ((0, ('Splendid-artistry-coffee',)), 4),
#    ((0, ('Mackerel-fillets-in-brine',)), 4),
#    ((0, ('Prepackaged-lettuce',)), 4),
#    ((0, ('Mackerel-fillets-in-brine', 'Splendid-artistry-coffee')), 4),
#    ((1, ('Splendid-artistry-coffee',)), 3),
#    ((1, ('Mackerel-fillets-in-brine',)), 3),
#    ((1, ('Prepackaged-lettuce',)), 3),
#    ((1, ('Mackerel-fillets-in-brine', 'Splendid-artistry-coffee')), 3)]),
#  (('Curry',), [((0, ('Curry',)), 6)]),
#  (('Prepackaged-lettuce',), []),
#  (('Absinth',), []),
#  (('Fruit-salad',), []),
#  (('Getranke',), []),
#  (('Lemon-curd',), [((0, ('Lemon-curd',)), 4)]),
#  (('Jus-de-fruits',), []),
#  (('Chinese',), []),
#  (('Milk-chocolate-digestives',), []),
#  (('Microwave-popcorn',), []),
#  (('Vinegars',), []),
#  (('Garlic-and-coriander-naan',), []),
#  (('Pays-d-oc',), []),
#  (('Blinis',), []),
#  (('Whole-bean-sprouts-canned',), []),
#  (('Chicken-kebabs',), []),
#  (('Filo-dough',), []),
#  (('Polenta',),
#   [((0, ('Corn-kernels',)), 3),
#    ((0, ('Christmas-food',)), 3),
#    ((0, ('Vegetarian-fish-fillets',)), 3),
#    ((0, ('Alkoholische-getranke',)), 3),
#    ((0, ('Chicken-kebabs',)), 3),
#    ((0, ('Filo-dough',)), 3)]),
#  (('Confitures-de-fraises',), []),
#  (('Balsamic-vinaigrette',), []),
#  (('Beetroot-juice',), []),
#  (('Dr-pepper-soft-drink',), [((0, ('Dr-pepper-soft-drink',)), 9)]),
#  (('Cornish-pasties',), []),
#  (('Potato-crips',), []),
#  (('Juice-beverage',), []),
#  (('Fresh-dates',), []),
#  (('Charcuteries',), []),
#  (('Mandarins-in-syrup',), []),
#  (('Yaourts-aux-fruits',), []),
#  (('Fruits-en-conserve',), []),
#  (('Dessert-lacte',), []),
#  (('Pecans',), []),
#  (('Apple-juice-from-concentrate',),
#   [((0, ('Apple-juice-from-concentrate',)), 4)]),
#  (('Meta-category',), []),
#  (('Duck-breast-filets',), [((0, ('Duck-breast-filets',)), 7)]),
#  (('Almond-chocolate',), []),
#  (('Cheese-analogues',), []),
#  (('Smoked-cheese',), []),
#  (('Blackcurrent-juice-drink',), []),
#  (('Goat-milk',), []),
#  (('Premium-and-organic-pepper-from-cambodia',), []),
#  (('Asian-condiments',), []),
#  (('Baby-rocket',), [((0, ('Baby-rocket',)), 10)]),
#  (('Ciabatta',), []),
#  (('Barres-de-cereales',), []),
#  (('Balsamic-vinaigrette-dressing',),
#   [((0, ('Hot-pepper-sauce',)), 3),
#    ((1, ('Salted-snack',)), 3),
#    ((1, ('Frozen-petits-pois',)), 3),
#    ((1, ('Canned-prawns',)), 3)]),
#  (('Fruchtschnitte',), [((0, ('Fruchtschnitte',)), 3)]),
#  (('Biryani',), []),
#  (('Edam',), []),
#  (('Frozen-chinese-spring-roll-snacks',),
#   [((0, ('Frozen-chinese-spring-roll-snacks',)), 7)]),
#  (('Tuna-steak',), [((0, ('Tuna-steak',)), 5)]),
#  (('Peanut-butter-cup',), []),
#  (('Frozen-vegetables-mix',), []),
#  (('Chesnut-mushrooms',), []),
#  (('Tandoori-chicken-masala',), [((0, ('Tandoori-chicken-masala',)), 5)]),
#  (('Dilute-drink',), []),
#  (('Blueberry-muffins',), []),
#  (('Estragon',), [((1, ('Smoked-cheese',)), 3)]),
#  (('Salmon-in-spring-water',), []),
#  (('Cremes-desserts',), []),
#  (('Olive-ciabatta',), [((0, ('Olive-ciabatta',)), 4)]),
#  (('Hommus-dip',), []),
#  (('Pet food',), []),
#  (('Frozen-sweetcorn',), [((0, ('Frozen-sweetcorn',)), 5)]),
#  (('Gelati',), []),
#  (('Sambuca',), []),
#  (('Turkish-delight',), []),
#  (('Frozen-asian-food',), []),
#  (('Strawberry-preserves',), []),
#  (('Chocolate-ice-cream',), []),
#  (('Producto-de-aperitivo',), [((0, ('Porridge',)), 3)]),
#  (('Whole olives',), []),
#  (('Tee',), []),
#  (('Marinara-sauce',), []),
#  (('Cosmetics',), []),
#  (('Chicken-eggs',), []),
#  (('Gravy',),
#   [((1, ('Cremes-fraiches-epaisses',)), 4),
#    ((1, ('Olives-denoyautees',)), 4)]),
#  (('Magarines',), [((0, ('Magarines',)), 7)]),
#  (('Getreide-und-getreideprodukte',), []),
#  (('Plato-preparado-precocinado',), []),
#  (('Green-salad-and-vegetables',), []),
#  (('Saumon-atlantique',), []),
#  (('Low-fat-high-calcium-milk',), []),
#  (('Powder',), []),
#  (('Whole-wheat-beard',), []),
#  (('Boissons',), []),
#  (('Whipping-cream',), [((0, ('Whipping-cream',)), 5)]),
#  (('Levures',), []),
#  (('Peach-juice-drink',), []),
#  (('Fruit-juice-concentrate',), [((0, ('Fruit-juice-concentrate',)), 6)]),
#  (('Dried-mango',), []),
#  (('Cactus',), []),
#  (('Pates-a-tartiner-aux-noisettes-et-au-cacao',), []),
#  (('Stir-fry-sauce',), []),
#  (('Roquefort-cheese',), []),
#  (('Prepared-foods',), []),
#  (('Carbonated-soda-water',), []),
#  (('Milchprodukt',), []),
#  (('Syrups',), []),
#  (('Chicken-burger',), []),
#  (('Strawberry-topping',), []),
#  (('Bathroom',), []),
#  (('Hot-cocoa-powder',), []),
#  (('Lamb-chops',),
#   [((0, ('Sucre',)), 3),
#    ((0, ('Food additives',)), 3),
#    ((0, ('Magarines',)), 3),
#    ((0, ('Lamb-chops',)), 3),
#    ((1, ('Sirop',)), 3),
#    ((1, ('Food additives',)), 3)]),
#  (('Pitta-breads',), [((0, ('Pitta-breads',)), 10)]),
#  (('Medium-cheddar',), []),
#  (('Juices',), []),
#  (('Genoa-salami',), []),
#  (('Feta-cheese',),
#   [((0, ('Pizza dough',)), 3),
#    ((0, ('Groenten',)), 3),
#    ((1, ('Chips',)), 3),
#    ((3, ('Frozen-baby-octopus',)), 3),
#    ((3, ('Psyllium-husk',)), 3),
#    ((4, ('Psyllium-husk',)), 3)]),
#  (('Golden-syrup',), []),
#  (('Beverages',), [((0, ('Beverages',)), 6)]),
#  (('Fruit juices',), []),
#  (('Canned-prawns',), []),
#  (('Fresh-bread',),
#   [((0, ('Fresh-bread',)), 6),
#    ((0, ('Levure',)), 5),
#    ((0, ('Fresh-bread', 'Levure')), 5)]),
#  (('Tuiles-salees',), []),
#  (('Vleeswaren',), []),
#  (('Sundried-tomatoes',), []),
#  (('Melange-d-epices-pour-guacamole',), []),
#  (('Breaded-chicken',), []),
#  (('Fusilli',), [((0, ('Fusilli',)), 6)]),
#  (('Apple-and-pear-juices',), []),
#  (('Stringless-beans',), []),
#  (('Liszt',),
#   [((0, ('Pork-mince',)), 3),
#    ((0, ('Curry',)), 3),
#    ((0, ('Food-coulouring',)), 3),
#    ((1, ('Food-coulouring',)), 3)]),
#  (('Draje-sakız',), []),
#  (('Deep-fried',), []),
#  (('Toppings',), []),
#  (('Flour-tortillas',), [((0, ('Flour-tortillas',)), 4)]),
#  (('Beers-from-stralsund',), []),
#  (('Protein-powder-drink-mix',), []),
#  (('Caramel-popcorn',),
#   [((0, ('Caramel-popcorn',)), 3),
#    ((1, ('Pan-di-spagna',)), 3),
#    ((0, ('Pan-di-spagna',)), 4),
#    ((0, ('Flavoured-cranberries',)), 3),
#    ((0, ('Chilli-con-carne-sauce',)), 3),
#    ((0, ('Cough-lozenges',)), 3)]),
#  (('Caramel-wafer-bars',), []),
#  (('Fruits-secs',), []),
#  (('Diced-tomatoes',), []),
#  (('Turkey-bacon',),
#   [((0, ('Caffe',)), 4),
#    ((0, ('Turkey-bacon',)), 5),
#    ((0, ('Caffe', 'Turkey-bacon')), 4),
#    ((1, ('Turkey-bacon',)), 4),
#    ((3, ('Pains-au-chocolat',)), 4),
#    ((3, ('Frozen-snacks',)), 4),
#    ((2, ('Pains-au-chocolat',)), 4),
#    ((2, ('Frozen-snacks',)), 4),
#    ((1, ('Pains-au-chocolat',)), 4),
#    ((1, ('Frozen-snacks',)), 4)]),
#  (('Sliced-cheddar',),
#   [((0, ('Caffe',)), 4),
#    ((0, ('Turkey-bacon',)), 4),
#    ((0, ('Caffe', 'Turkey-bacon')), 4),
#    ((1, ('Turkey-bacon',)), 4),
#    ((3, ('Pains-au-chocolat',)), 4),
#    ((3, ('Frozen-snacks',)), 4)]),
#  (('Edulcorant-avec-fruit-des-moines',),
#   [((0, ('Caffe',)), 4),
#    ((0, ('Turkey-bacon',)), 4),
#    ((0, ('Edulcorant-avec-fruit-des-moines',)), 4),
#    ((0, ('Caffe', 'Turkey-bacon')), 4),
#    ((1, ('Turkey-bacon',)), 4),
#    ((3, ('Pains-au-chocolat',)), 4),
#    ((3, ('Frozen-snacks',)), 4)]),
#  (('Strawberry-mousse',), []),
#  (('Green-beans',), []),
#  (('Probiotic-drinks',), []),
#  (('Frozen-snacks',), [((0, ('Frozen-snacks',)), 4)]),
#  (('Rice-crackers',), []),
#  (('Fromage-a-pate-dure',), []),
#  (('Matzos',), []),
#  (('Egg-white-powder',), []),
#  (('Minestrone',), []),
#  (('Burger-relish',), [((0, ('Burger-relish',)), 5)]),
#  (('Vegan-chicken-nuggets',), []),
#  (('Fromage-frais',),
#   [((0, ('Fromage-frais',)), 3),
#    ((1, ('Grated-parmesan-cheese',)), 3),
#    ((1, ('Roasted-eggplant',)), 3),
#    ((0, ('Grated-parmesan-cheese',)), 3),
#    ((0, ('Roasted-eggplant',)), 3)]),
#  (('Rice-wine',), [((0, ('Rice-wine',)), 8)]),
#  (('Cherry-pie-filling',), []),
#  (('Chinese-cinnamon-sticks',), []),
#  (('Pizza dough',),
#   [((0, ('Pizza dough',)), 3),
#    ((1, ('Groenten',)), 3),
#    ((0, ('Groenten',)), 3),
#    ((0, ('Chips',)), 3),
#    ((2, ('Frozen-baby-octopus',)), 3),
#    ((2, ('Psyllium-husk',)), 3),
#    ((3, ('Psyllium-husk',)), 3)]),
#  (('Canned-tuna-in-lemon',), []),
#  (('Chocolate-trifle',),
#   [((0, ('Levure',)), 3),
#    ((0, ('Frozen-sweetcorn',)), 3),
#    ((0, ('Fresh-bread',)), 3),
#    ((0, ('Melonen',)), 3),
#    ((0, ('Fresh-bread', 'Levure')), 3),
#    ((1, ('Levure',)), 3),
#    ((1, ('Moussakas',)), 3),
#    ((1, ('Fresh-bread',)), 3),
#    ((1, ('Fresh-bread', 'Levure')), 3),
#    ((2, ('Levure',)), 3),
#    ((2, ('Lait',)), 3),
#    ((2, ('Fresh-bread',)), 3),
#    ((2, ('Fresh-bread', 'Levure')), 3),
#    ((3, ('Levure',)), 3),
#    ((3, ('Baking-powder',)), 3),
#    ((3, ('Coconut-macaroons',)), 3),
#    ((3, ('Lait',)), 3),
#    ((3, ('Fresh-bread',)), 3),
#    ((3, ('Fresh-bread', 'Levure')), 3)]),
#  (('Aceite-de-coco',), []),
#  (('Groenten',), []),
#  (('Beef-broth',), [((0, ('Beef-broth',)), 5)]),
#  (('Snackfoods',), []),
#  (('Cornichons',), []),
#  (('Birthday-cake',), [((0, ('Birthday-cake',)), 6)]),
#  (('Baked-goods',), []),
#  (('Coconut-creams',), []),
#  (('Food-coulouring',), [((0, ('Food-coulouring',)), 4)]),
#  (('Bonbons-a-la-menthe',), [((0, ('Popping-corn',)), 6)]),
#  (('Lemon-extract',), [((0, ('Lemon-extract',)), 4)]),
#  (('Spices-seasoning-mixes',), []),
#  (('Cucumbers-in-brine',), []),
#  (('Earl-grey',), [((5, ('Baking-powder',)), 3)]),
#  (('Melonen',), [((0, ('Melonen',)), 5)]),
#  (('Custard',), []),
#  (('Ricotta',), []),
#  (('Cukor',), []),
#  (('Beer-batter-fries',),
#   [((0, ('Beer-batter-fries',)), 5),
#    ((0, ('Aliments-d-origine-vegetale',)), 5)]),
#  (('Bruschetta',), []),
#  (('Kvarg',), []),
#  (('Backpulver',), []),
#  (('Glaces',), []),
#  (('Bean-flour',), []),
#  (('Yoghurts-op-een-laag-fruit',), []),
#  (('Quso-duro',), []),
#  (('Kaffee',), []),
#  (('Nane-limon',),
#   [((0, ('Nane-limon',)), 5), ((0, ('Marfona-variety',)), 5)]),
#  (('Reduced-fat-milks',),
#   [((0, ('Seafood',)), 3),
#    ((0, ('Edam',)), 3),
#    ((0, ('Reduced-fat-milks',)), 3),
#    ((0, ('Conservation',)), 3),
#    ((0, ('Rice-noodles',)), 3)]),
#  (('Chilisauce',), []),
#  (('Organic-certified',),
#   [((0, ('Organic-certified',)), 5),
#    ((0, ('Cinnamon-roll',)), 4),
#    ((0, ('Cinnamon-roll', 'Organic-certified')), 4),
#    ((1, ('Pitted-prunes',)), 4),
#    ((0, ('Pitted-prunes',)), 4)]),
#  (('Pates-fraiches',), []),
#  (('Fat-free-milk',), []),
#  (('Jambons-blancs',),
#   [((0, ('Jambons-blancs',)), 5),
#    ((0, ('Meat-pie',)), 4),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 4)]),
#  (('Conservation',), []),
#  (('Oreo',), [((0, ('Oreo',)), 4)]),
#  (('Skim-milk',),
#   [((0, ('Dindes',)), 3),
#    ((0, ('Poudres-cacao',)), 3),
#    ((0, ('Whipping-cream',)), 3),
#    ((1, ('Chicken-kiev',)), 3),
#    ((1, ('Dindes',)), 3),
#    ((1, ('Poudres-cacao',)), 3),
#    ((1, ('Whipping-cream',)), 3),
#    ((2, ('Mix',)), 3),
#    ((2, ('Chicken-kiev',)), 3),
#    ((2, ('Whipping-cream',)), 3)]),
#  (('Fresh-corn',), []),
#  (('Easter-egg',), [((0, ('Biscuits-chocolates',)), 3)]),
#  (('Chilli-sauce',), []),
#  (('Sugarsnap-peas',), [((0, ('Sugarsnap-peas',)), 4)]),
#  (('Soap',),
#   [((0, ('Soap',)), 5),
#    ((0, ('Seafood',)), 5),
#    ((0, ('Seafood', 'Soap')), 4),
#    ((1, ('Seafood',)), 4),
#    ((1, ('Reduced-fat-milks',)), 4),
#    ((0, ('Reduced-fat-milks',)), 4)]),
#  (('Crackers-sans-gluten',), []),
#  (('Croque-monsieur',), []),
#  (('Chocolate-coins',), []),
#  (('Cottage-cheese',), []),
#  (('Ranja',), []),
#  (('Roasted-and-ground-coffee',),
#   [((0, ('Organic-and-premium-pepper-cambodia',)), 4),
#    ((2, ('Fresh-cabbage',)), 3),
#    ((0, ('Brussels-pate',)), 3),
#    ((0, ('Roasted-and-ground-coffee',)), 3),
#    ((1, ('Biscottes',)), 3),
#    ((1, ('Frozen-chinese-spring-roll-snacks',)), 4),
#    ((1, ('Biscottes', 'Frozen-chinese-spring-roll-snacks')), 3),
#    ((2, ('Frozen-chinese-spring-roll-snacks',)), 4),
#    ((3, ('Frozen-chinese-spring-roll-snacks',)), 3),
#    ((0, ('Biscottes',)), 3),
#    ((0, ('Frozen-chinese-spring-roll-snacks',)), 3),
#    ((0, ('Biscottes', 'Frozen-chinese-spring-roll-snacks')), 3)]),
#  (('Pear-cider',),
#   [((0, ('Seafood',)), 3),
#    ((0, ('Spaghetti-in-tomato-sauce',)), 3),
#    ((0, ('Soap',)), 3),
#    ((0, ('Pear-cider',)), 3),
#    ((0, ('Epices',)), 3),
#    ((0, ('Seafood', 'Spaghetti-in-tomato-sauce')), 3),
#    ((0, ('Seafood', 'Soap')), 3),
#    ((1, ('Seafood',)), 3),
#    ((1, ('Coconut-waters',)), 3),
#    ((1, ('Reduced-fat-milks',)), 3),
#    ((1, ('Soap',)), 3),
#    ((1, ('Seafood', 'Soap')), 3),
#    ((2, ('Seafood',)), 3),
#    ((2, ('Edam',)), 3),
#    ((2, ('Reduced-fat-milks',)), 3),
#    ((2, ('Conservation',)), 3),
#    ((2, ('Rice-noodles',)), 3),
#    ((3, ('Rice-noodles',)), 3)]),
#  (('Kidney-beans',), []),
#  (('Epices',), [((1, ('Conservation',)), 4)]),
#  (('Rice-noodles',), []),
#  (('Radish',),
#   [((0, ('Strawberries-canned',)), 3),
#    ((0, ('Radish',)), 3),
#    ((1, ('Mix',)), 3),
#    ((2, ('Grape-juice-drink',)), 3),
#    ((2, ('Wasabi',)), 4),
#    ((2, ('Prune-juice',)), 4),
#    ((2, ('Prune-juice', 'Wasabi')), 4),
#    ((3, ('Wasabi',)), 3),
#    ((3, ('Prune-juice',)), 3),
#    ((3, ('Prune-juice', 'Wasabi')), 3),
#    ((0, ('Mix',)), 3),
#    ((1, ('Grape-juice-drink',)), 3),
#    ((1, ('Wasabi',)), 3),
#    ((1, ('Prune-juice',)), 3),
#    ((1, ('Prune-juice', 'Wasabi')), 3)]),
#  (('Blue-cheese-yogurt-dressing',),
#   [((0, ('Dumplings',)), 3),
#    ((1, ('Kits',)), 3),
#    ((1, ('Pork-sausages',)), 3)]),
#  (('Quenelles',), []),
#  (('Marfona-variety',), []),
#  (('Breaded-ham',), []),
#  (('Juice-drink',), [((0, ('Juice-drink',)), 4)]),
#  (('Glace-cherries',),
#   [((0, ('White-quinoa',)), 7),
#    ((0, ('Glace-cherries',)), 6),
#    ((0, ('Glace-cherries', 'White-quinoa')), 6),
#    ((1, ('White-quinoa',)), 5)]),
#  (('Red-onions',),
#   [((0, ('Red-onions',)), 4), ((0, ('Feuille-de-vigne',)), 4)]),
#  (('Cereales',), []),
#  (('Ground-cinnamon',), []),
#  (('Cigarettes',), []),
#  (('Lamb-breast',), []),
#  (('Shredded-cheese',), [((0, ('Shredded-cheese',)), 4)]),
#  (('Savoy-cabbage',), [((0, ('Savoy-cabbage',)), 5)]),
#  (('Caviars',), []),
#  (('Canned-crab-meat',), [((0, ('Canned-crab-meat',)), 7)]),
#  (('Kruidentheeen',),
#   [((0, ('Indian-sauces',)), 4), ((0, ('Kruidentheeen',)), 4)]),
#  (('Pure-orange-juice-not-from-concentrate',), []),
#  (('Iced-cookies',), []),
#  (('Tom-yum-soup',),
#   [((0, ('Tom-yum-soup',)), 3),
#    ((1, ('Roasted-garlic',)), 3),
#    ((1, ('Easter-egg',)), 3),
#    ((2, ('Biscuits-chocolates',)), 3)]),
#  (('Scotch-eggs',), []),
#  (('Thes-glaces',),
#   [((0, ('Fish and meat and eggs',)), 4),
#    ((1, ('Saucisses-aux-lentilles',)), 4)]),
#  (('Caesar-dressing',), [((0, ('Tarama',)), 3)]),
#  (('Hot-cocoa-mix',), [((0, ('Pork-mince',)), 4)]),
#  (('Madeira-cake',), [((0, ('Golden-syrup',)), 3)]),
#  (('Hard-cooked-peeled-eggs',),
#   [((0, ('Green-basil',)), 4),
#    ((0, ('Syrups',)), 4),
#    ((0, ('Hard-cooked-peeled-eggs',)), 4),
#    ((0, ('Green-basil', 'Hard-cooked-peeled-eggs')), 4)]),
#  (('Muffin-mix',), []),
#  (('Salad',), []),
#  (('Coca-sandwich-biscuits',),
#   [((0, ('Pauillac',)), 4),
#    ((0, ('Jambons-blancs',)), 5),
#    ((0, ('Coca-sandwich-biscuits',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 5),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((0, ('Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 4),
#    ((0, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((1, ('Jambons-blancs',)), 4),
#    ((1, ('Meat-pie',)), 4),
#    ((1, ('Jambons-blancs', 'Meat-pie')), 4)]),
#  (('Flavoured-rice-cakes',), []),
#  (('Frozen-dumpling',),
#   [((0, ('Frozen-dumpling',)), 5), ((1, ('Frozen-dumpling',)), 4)]),
#  (('Pancake-syrup',), []),
#  (('Pure-cod-liver-oil',), []),
#  (('Iced-donuts',), []),
#  (('Instant-porridge',),
#   [((0, ('Marfona-variety',)), 4), ((0, ('Instant-porridge',)), 4)]),
#  (('Feuille-de-vigne',),
#   [((0, ('Feuille-de-vigne',)), 6),
#    ((0, ('Likor',)), 5),
#    ((0, ('Feuille-de-vigne', 'Likor')), 5),
#    ((1, ('Red-onions',)), 4),
#    ((1, ('Feuille-de-vigne',)), 5),
#    ((1, ('Likor',)), 4),
#    ((1, ('Feuille-de-vigne', 'Likor')), 4),
#    ((2, ('Feuille-de-vigne',)), 4),
#    ((0, ('Red-onions',)), 4)]),
#  (('Likor',),
#   [((0, ('Feuille-de-vigne',)), 6),
#    ((0, ('Likor',)), 5),
#    ((0, ('Feuille-de-vigne', 'Likor')), 5),
#    ((1, ('Red-onions',)), 4),
#    ((1, ('Feuille-de-vigne',)), 5),
#    ((1, ('Likor',)), 4),
#    ((1, ('Feuille-de-vigne', 'Likor')), 4),
#    ((2, ('Feuille-de-vigne',)), 4),
#    ((0, ('Red-onions',)), 4)]),
#  (('Linsen',), []),
#  (('Meat-pie',), [((0, ('Meat-pie',)), 8), ((1, ('Meat-pie',)), 6)]),
#  (('Curry', 'Seafood'),
#   [((0, ('Seafood',)), 3),
#    ((0, ('Hazelnut-chocolate-spread',)), 3),
#    ((0, ('Splendid-artistry-coffee',)), 3),
#    ((0, ('Mackerel-fillets-in-brine',)), 3),
#    ((0, ('Curry',)), 3),
#    ((0, ('Prepackaged-lettuce',)), 3),
#    ((0, ('Mackerel-fillets-in-brine', 'Splendid-artistry-coffee')), 3),
#    ((1, ('Splendid-artistry-coffee',)), 3),
#    ((1, ('Mackerel-fillets-in-brine',)), 3),
#    ((1, ('Prepackaged-lettuce',)), 3),
#    ((1, ('Mackerel-fillets-in-brine', 'Splendid-artistry-coffee')), 3)]),
#  (('Cereales-pour-le-petit-dejeuner', 'Terrine'),
#   [((0, ('Cereales-pour-le-petit-dejeuner',)), 3),
#    ((0, ('Terrine',)), 3),
#    ((0, ('Cereales-pour-le-petit-dejeuner', 'Terrine')), 3),
#    ((1, ('Aloe-vera-drink',)), 3),
#    ((0, ('Sunstream-tomatoes',)), 3),
#    ((0, ('Aloe-vera-drink',)), 3),
#    ((0, ('Soymilk',)), 3),
#    ((0, ('Confectioner',)), 3)]),
#  (('Curries', 'Seafood'),
#   [((0, ('Seafood',)), 4),
#    ((0, ('Curries',)), 3),
#    ((0, ('Spaghetti-in-tomato-sauce',)), 4),
#    ((0, ('Curries', 'Seafood')), 3),
#    ((0, ('Seafood', 'Spaghetti-in-tomato-sauce')), 4),
#    ((0, ('Soap',)), 3),
#    ((0, ('Epices',)), 3),
#    ((0, ('Seafood', 'Soap')), 3),
#    ((1, ('Seafood',)), 3),
#    ((1, ('Coconut-waters',)), 3),
#    ((1, ('Reduced-fat-milks',)), 3),
#    ((1, ('Soap',)), 3),
#    ((1, ('Seafood', 'Soap')), 3),
#    ((2, ('Seafood',)), 3),
#    ((2, ('Edam',)), 3),
#    ((2, ('Reduced-fat-milks',)), 3),
#    ((2, ('Conservation',)), 3),
#    ((2, ('Rice-noodles',)), 3)]),
#  (('Baby-rocket', 'Honey-roast-ham'),
#   [((0, ('Honey-roast-ham',)), 5),
#    ((0, ('Bottled-still-water',)), 3),
#    ((0, ('Baby-rocket',)), 4),
#    ((0, ('Baby-rocket', 'Honey-roast-ham')), 4),
#    ((1, ('Honey-roast-ham',)), 5),
#    ((1, ('Baby-rocket',)), 3),
#    ((1, ('Baby-rocket', 'Honey-roast-ham')), 3),
#    ((2, ('Honey-roast-ham',)), 4),
#    ((3, ('Sushki',)), 4),
#    ((3, ('Honey-roast-ham',)), 3),
#    ((4, ('Pitted-prunes',)), 3),
#    ((4, ('Sushki',)), 3),
#    ((2, ('Sushki',)), 4),
#    ((3, ('Pitted-prunes',)), 3),
#    ((1, ('Sushki',)), 3),
#    ((2, ('Pitted-prunes',)), 3)]),
#  (('Blinis', 'Plato-preparado-precocinado'),
#   [((0, ('Plaice',)), 3),
#    ((0, ('Blinis',)), 3),
#    ((0, ('Premium-and-organic-pepper-from-cambodia',)), 3),
#    ((0, ('Plato-preparado-precocinado',)), 5),
#    ((0, ('Beer-batter-fries',)), 3),
#    ((0, ('Blinis', 'Plato-preparado-precocinado')), 3),
#    ((1, ('Smoked-cheese',)), 3),
#    ((1, ('Premium-and-organic-pepper-from-cambodia',)), 3),
#    ((1, ('Plato-preparado-precocinado',)), 3),
#    ((1, ('Beer-batter-fries',)), 3),
#    ((2, ('Aliments-d-origine-vegetale',)), 3)]),
#  (('Bee products', 'Meat-pie'),
#   [((0, ('Bee products',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Bee products', 'Meat-pie')), 4),
#    ((1, ('Kase',)), 4)]),
#  (('Capers', 'Cinnamon-roll'),
#   [((0, ('Capers',)), 5),
#    ((0, ('Cinnamon-roll',)), 5),
#    ((0, ('Organic-certified',)), 4),
#    ((0, ('Capers', 'Cinnamon-roll')), 4),
#    ((0, ('Cinnamon-roll', 'Organic-certified')), 4),
#    ((1, ('Pitted-prunes',)), 4)]),
#  (('Fresh-cabbage', 'Wheat-cereals'),
#   [((0, ('Fresh-cabbage',)), 5),
#    ((0, ('Chopeed-tomatoes',)), 4),
#    ((0, ('Wheat-cereals',)), 5),
#    ((0, ('Fresh-cabbage', 'Wheat-cereals')), 5),
#    ((0, ('Chopeed-tomatoes', 'Wheat-cereals')), 4),
#    ((0, ('Chopeed-tomatoes', 'Fresh-cabbage')), 4),
#    ((0, ('Chopeed-tomatoes', 'Wheat-cereals', 'Fresh-cabbage')), 4),
#    ((0, ('Chopeed-tomatoes', 'Fresh-cabbage', 'Wheat-cereals')), 4),
#    ((0, ('Wheat-cereals', 'Chopeed-tomatoes', 'Fresh-cabbage')), 4),
#    ((0, ('Wheat-cereals', 'Fresh-cabbage', 'Chopeed-tomatoes')), 4),
#    ((0, ('Fresh-cabbage', 'Chopeed-tomatoes', 'Wheat-cereals')), 4),
#    ((0, ('Fresh-cabbage', 'Wheat-cereals', 'Chopeed-tomatoes')), 4),
#    ((1, ('Fresh-cabbage',)), 4),
#    ((1, ('Basa-fish',)), 4),
#    ((1, ('Wheat-cereals',)), 4),
#    ((1, ('Fresh-cabbage', 'Wheat-cereals')), 4),
#    ((0, ('Basa-fish',)), 4)]),
#  (('Chopeed-tomatoes', 'Wheat-cereals'),
#   [((0, ('Fresh-cabbage',)), 5),
#    ((0, ('Beef-mince',)), 3),
#    ((0, ('Packaged-pancakes',)), 3),
#    ((0, ('Berries-preserve',)), 3),
#    ((0, ('Chopeed-tomatoes',)), 4),
#    ((0, ('Wheat-cereals',)), 5),
#    ((0, ('Fresh-cabbage', 'Wheat-cereals')), 5),
#    ((0, ('Chopeed-tomatoes', 'Wheat-cereals')), 4),
#    ((0, ('Chopeed-tomatoes', 'Fresh-cabbage')), 4),
#    ((0, ('Chopeed-tomatoes', 'Packaged-pancakes')), 3),
#    ((0, ('Chopeed-tomatoes', 'Wheat-cereals', 'Fresh-cabbage')), 4),
#    ((0, ('Chopeed-tomatoes', 'Fresh-cabbage', 'Wheat-cereals')), 4),
#    ((0, ('Wheat-cereals', 'Chopeed-tomatoes', 'Fresh-cabbage')), 4),
#    ((0, ('Wheat-cereals', 'Fresh-cabbage', 'Chopeed-tomatoes')), 4),
#    ((0, ('Fresh-cabbage', 'Chopeed-tomatoes', 'Wheat-cereals')), 4),
#    ((0, ('Fresh-cabbage', 'Wheat-cereals', 'Chopeed-tomatoes')), 4),
#    ((1, ('Fresh-cabbage',)), 4),
#    ((1, ('Basa-fish',)), 4),
#    ((1, ('Chopeed-tomatoes',)), 3),
#    ((1, ('Wheat-cereals',)), 4),
#    ((1, ('Fresh-cabbage', 'Wheat-cereals')), 4),
#    ((1, ('Chopeed-tomatoes', 'Wheat-cereals')), 3),
#    ((1, ('Chopeed-tomatoes', 'Fresh-cabbage')), 3),
#    ((1, ('Chopeed-tomatoes', 'Wheat-cereals', 'Fresh-cabbage')), 3),
#    ((1, ('Chopeed-tomatoes', 'Fresh-cabbage', 'Wheat-cereals')), 3),
#    ((1, ('Wheat-cereals', 'Chopeed-tomatoes', 'Fresh-cabbage')), 3),
#    ((1, ('Wheat-cereals', 'Fresh-cabbage', 'Chopeed-tomatoes')), 3),
#    ((1, ('Fresh-cabbage', 'Chopeed-tomatoes', 'Wheat-cereals')), 3),
#    ((1, ('Fresh-cabbage', 'Wheat-cereals', 'Chopeed-tomatoes')), 3),
#    ((2, ('Fresh-cabbage',)), 3),
#    ((2, ('Basa-fish',)), 3),
#    ((2, ('Wheat-cereals',)), 3),
#    ((2, ('Cinnamon-roll',)), 3),
#    ((2, ('Fresh-cabbage', 'Wheat-cereals')), 3),
#    ((0, ('Basa-fish',)), 4),
#    ((1, ('Cinnamon-roll',)), 3),
#    ((0, ('Cinnamon-roll',)), 3)]),
#  (('Glace-cherries', 'White-quinoa'),
#   [((0, ('White-quinoa',)), 7),
#    ((0, ('Glace-cherries',)), 6),
#    ((0, ('Glace-cherries', 'White-quinoa')), 6),
#    ((1, ('White-quinoa',)), 5)]),
#  (('Biscuits-au-chocolat', 'Wholefood'),
#   [((0, ('Biscuits-au-chocolat',)), 3),
#    ((0, ('Wholefood',)), 3),
#    ((0, ('Biscuits-au-chocolat', 'Wholefood')), 3)]),
#  (('Glace-cherries', 'Snack'),
#   [((0, ('Snack',)), 4),
#    ((0, ('Milk-chocolate-filled-with-caramel',)), 3),
#    ((0, ('Sirop',)), 3),
#    ((0, ('Cremes-fraiches-epaisses',)), 3),
#    ((0, ('White-quinoa',)), 5),
#    ((0, ('Glace-cherries',)), 5),
#    ((0, ('Glace-cherries', 'White-quinoa')), 5),
#    ((0, ('Glace-cherries', 'Snack')), 4),
#    ((0, ('Sirop', 'White-quinoa')), 3),
#    ((0, ('Snack', 'White-quinoa')), 4),
#    ((0, ('White-quinoa', 'Snack', 'Glace-cherries')), 4),
#    ((0, ('White-quinoa', 'Glace-cherries', 'Snack')), 4),
#    ((0, ('Snack', 'White-quinoa', 'Glace-cherries')), 4),
#    ((0, ('Snack', 'Glace-cherries', 'White-quinoa')), 4),
#    ((0, ('Glace-cherries', 'White-quinoa', 'Snack')), 4),
#    ((0, ('Glace-cherries', 'Snack', 'White-quinoa')), 4),
#    ((1, ('Snack',)), 3),
#    ((1, ('White-quinoa',)), 5),
#    ((1, ('Glace-cherries',)), 4),
#    ((1, ('Glace-cherries', 'White-quinoa')), 4),
#    ((1, ('Glace-cherries', 'Snack')), 3),
#    ((1, ('Snack', 'White-quinoa')), 3),
#    ((1, ('White-quinoa', 'Snack', 'Glace-cherries')), 3),
#    ((1, ('White-quinoa', 'Glace-cherries', 'Snack')), 3),
#    ((1, ('Snack', 'White-quinoa', 'Glace-cherries')), 3),
#    ((1, ('Snack', 'Glace-cherries', 'White-quinoa')), 3),
#    ((1, ('Glace-cherries', 'White-quinoa', 'Snack')), 3),
#    ((1, ('Glace-cherries', 'Snack', 'White-quinoa')), 3),
#    ((2, ('White-quinoa',)), 4),
#    ((2, ('Glace-cherries',)), 3),
#    ((2, ('Glace-cherries', 'White-quinoa')), 3),
#    ((3, ('White-quinoa',)), 3),
#    ((4, ('Hazelnut-chocolate-spread',)), 3),
#    ((3, ('Hazelnut-chocolate-spread',)), 3),
#    ((2, ('Hazelnut-chocolate-spread',)), 3)]),
#  (('Biscottes', 'Frozen-chinese-spring-roll-snacks'),
#   [((0, ('Biscottes',)), 3),
#    ((0, ('Frozen-chinese-spring-roll-snacks',)), 5),
#    ((0, ('Biscottes', 'Frozen-chinese-spring-roll-snacks')), 3),
#    ((1, ('Frozen-chinese-spring-roll-snacks',)), 4)]),
#  (('Feuille-de-vigne', 'Likor'),
#   [((0, ('Feuille-de-vigne',)), 6),
#    ((0, ('Likor',)), 5),
#    ((0, ('Feuille-de-vigne', 'Likor')), 5),
#    ((1, ('Red-onions',)), 4),
#    ((1, ('Feuille-de-vigne',)), 5),
#    ((1, ('Likor',)), 4),
#    ((1, ('Feuille-de-vigne', 'Likor')), 4),
#    ((2, ('Feuille-de-vigne',)), 4),
#    ((0, ('Red-onions',)), 4)]),
#  (('Sirop', 'White-quinoa'),
#   [((0, ('Snack',)), 3),
#    ((0, ('White-quinoa',)), 3),
#    ((0, ('Glace-cherries',)), 3),
#    ((0, ('Glace-cherries', 'White-quinoa')), 3),
#    ((0, ('Glace-cherries', 'Snack')), 3),
#    ((0, ('Snack', 'White-quinoa')), 3),
#    ((0, ('White-quinoa', 'Snack', 'Glace-cherries')), 3),
#    ((0, ('White-quinoa', 'Glace-cherries', 'Snack')), 3),
#    ((0, ('Snack', 'White-quinoa', 'Glace-cherries')), 3),
#    ((0, ('Snack', 'Glace-cherries', 'White-quinoa')), 3),
#    ((0, ('Glace-cherries', 'White-quinoa', 'Snack')), 3),
# ...
#    ((0, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala', 'Soupe')), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Soupe', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Tandoori-chicken-masala', 'Dr-pepper-soft-drink', 'Soupe')), 4),
#    ((0, ('Tandoori-chicken-masala', 'Soupe', 'Dr-pepper-soft-drink')), 4),
#    ((0, ('Soupe', 'Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Soupe', 'Tandoori-chicken-masala', 'Dr-pepper-soft-drink')), 4),
#    ((1, ('Soupe',)), 3),
#    ((1, ('Dr-pepper-soft-drink',)), 3),
#    ((1, ('Tandoori-chicken-masala',)), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Soupe')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Soupe', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala', 'Soupe')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Soupe', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Tandoori-chicken-masala', 'Dr-pepper-soft-drink', 'Soupe')), 3),
#    ((1, ('Tandoori-chicken-masala', 'Soupe', 'Dr-pepper-soft-drink')), 3),
#    ((1, ('Soupe', 'Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Soupe', 'Tandoori-chicken-masala', 'Dr-pepper-soft-drink')), 3)]),
#  (('Soupe', 'Dr-pepper-soft-drink', 'Tandoori-chicken-masala'),
#   [((0, ('Soupe',)), 4),
#    ((0, ('Dr-pepper-soft-drink',)), 4),
#    ((0, ('Tandoori-chicken-masala',)), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Soupe')), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Soupe', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala', 'Soupe')), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Soupe', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Tandoori-chicken-masala', 'Dr-pepper-soft-drink', 'Soupe')), 4),
#    ((0, ('Tandoori-chicken-masala', 'Soupe', 'Dr-pepper-soft-drink')), 4),
#    ((0, ('Soupe', 'Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Soupe', 'Tandoori-chicken-masala', 'Dr-pepper-soft-drink')), 4),
#    ((1, ('Soupe',)), 3),
#    ((1, ('Dr-pepper-soft-drink',)), 3),
#    ((1, ('Tandoori-chicken-masala',)), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Soupe')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Soupe', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala', 'Soupe')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Soupe', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Tandoori-chicken-masala', 'Dr-pepper-soft-drink', 'Soupe')), 3),
#    ((1, ('Tandoori-chicken-masala', 'Soupe', 'Dr-pepper-soft-drink')), 3),
#    ((1, ('Soupe', 'Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Soupe', 'Tandoori-chicken-masala', 'Dr-pepper-soft-drink')), 3)]),
#  (('Soupe', 'Tandoori-chicken-masala', 'Dr-pepper-soft-drink'),
#   [((0, ('Soupe',)), 4),
#    ((0, ('Dr-pepper-soft-drink',)), 4),
#    ((0, ('Tandoori-chicken-masala',)), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Soupe')), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Soupe', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala', 'Soupe')), 4),
#    ((0, ('Dr-pepper-soft-drink', 'Soupe', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Tandoori-chicken-masala', 'Dr-pepper-soft-drink', 'Soupe')), 4),
#    ((0, ('Tandoori-chicken-masala', 'Soupe', 'Dr-pepper-soft-drink')), 4),
#    ((0, ('Soupe', 'Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 4),
#    ((0, ('Soupe', 'Tandoori-chicken-masala', 'Dr-pepper-soft-drink')), 4),
#    ((1, ('Soupe',)), 3),
#    ((1, ('Dr-pepper-soft-drink',)), 3),
#    ((1, ('Tandoori-chicken-masala',)), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Soupe')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Soupe', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Tandoori-chicken-masala', 'Soupe')), 3),
#    ((1, ('Dr-pepper-soft-drink', 'Soupe', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Tandoori-chicken-masala', 'Dr-pepper-soft-drink', 'Soupe')), 3),
#    ((1, ('Tandoori-chicken-masala', 'Soupe', 'Dr-pepper-soft-drink')), 3),
#    ((1, ('Soupe', 'Dr-pepper-soft-drink', 'Tandoori-chicken-masala')), 3),
#    ((1, ('Soupe', 'Tandoori-chicken-masala', 'Dr-pepper-soft-drink')), 3)]),
#  (('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac'),
#   [((0, ('Pauillac',)), 4),
#    ((0, ('Jambons-blancs',)), 5),
#    ((0, ('Coca-sandwich-biscuits',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 5),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((0, ('Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 4),
#    ((0, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((1, ('Pauillac',)), 3),
#    ((1, ('Edible-decorations',)), 3),
#    ((1, ('Jambons-blancs',)), 4),
#    ((1, ('Coca-sandwich-biscuits',)), 3),
#    ((1, ('Meat-pie',)), 4),
#    ((1, ('Jambons-blancs', 'Meat-pie')), 4),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((1, ('Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 3),
#    ((1, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((2, ('Ratatouille',)), 3),
#    ((2, ('Jambons-blancs',)), 3),
#    ((2, ('Meat-pie',)), 3),
#    ((2, ('Jambons-blancs', 'Meat-pie')), 3),
#    ((3, ('Whisky-ecossais',)), 3),
#    ((3, ('Coconut-waters',)), 3),
#    ((0, ('Edible-decorations',)), 3),
#    ((1, ('Ratatouille',)), 3),
#    ((2, ('Whisky-ecossais',)), 3),
#    ((2, ('Coconut-waters',)), 3),
#    ((0, ('Ratatouille',)), 3),
#    ((1, ('Whisky-ecossais',)), 3),
#    ((1, ('Coconut-waters',)), 3)]),
#  (('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits'),
#   [((0, ('Pauillac',)), 4),
#    ((0, ('Jambons-blancs',)), 5),
#    ((0, ('Coca-sandwich-biscuits',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 5),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((0, ('Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 4),
#    ((0, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((1, ('Pauillac',)), 3),
#    ((1, ('Edible-decorations',)), 3),
#    ((1, ('Jambons-blancs',)), 4),
#    ((1, ('Coca-sandwich-biscuits',)), 3),
#    ((1, ('Meat-pie',)), 4),
#    ((1, ('Jambons-blancs', 'Meat-pie')), 4),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((1, ('Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 3),
#    ((1, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((2, ('Ratatouille',)), 3),
#    ((2, ('Jambons-blancs',)), 3),
#    ((2, ('Meat-pie',)), 3),
#    ((2, ('Jambons-blancs', 'Meat-pie')), 3),
#    ((3, ('Whisky-ecossais',)), 3),
#    ((3, ('Coconut-waters',)), 3),
#    ((0, ('Edible-decorations',)), 3),
#    ((1, ('Ratatouille',)), 3),
#    ((2, ('Whisky-ecossais',)), 3),
#    ((2, ('Coconut-waters',)), 3),
#    ((0, ('Ratatouille',)), 3),
#    ((1, ('Whisky-ecossais',)), 3),
#    ((1, ('Coconut-waters',)), 3)]),
#  (('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac'),
#   [((0, ('Pauillac',)), 4),
#    ((0, ('Jambons-blancs',)), 5),
#    ((0, ('Coca-sandwich-biscuits',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 5),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((0, ('Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 4),
#    ((0, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((1, ('Pauillac',)), 3),
#    ((1, ('Edible-decorations',)), 3),
#    ((1, ('Jambons-blancs',)), 4),
#    ((1, ('Coca-sandwich-biscuits',)), 3),
#    ((1, ('Meat-pie',)), 4),
#    ((1, ('Jambons-blancs', 'Meat-pie')), 4),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((1, ('Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 3),
#    ((1, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((2, ('Ratatouille',)), 3),
#    ((2, ('Jambons-blancs',)), 3),
#    ((2, ('Meat-pie',)), 3),
#    ((2, ('Jambons-blancs', 'Meat-pie')), 3),
#    ((3, ('Whisky-ecossais',)), 3),
#    ((3, ('Coconut-waters',)), 3),
#    ((0, ('Edible-decorations',)), 3),
#    ((1, ('Ratatouille',)), 3),
#    ((2, ('Whisky-ecossais',)), 3),
#    ((2, ('Coconut-waters',)), 3),
#    ((0, ('Ratatouille',)), 3),
#    ((1, ('Whisky-ecossais',)), 3),
#    ((1, ('Coconut-waters',)), 3)]),
#  (('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie'),
#   [((0, ('Pauillac',)), 4),
#    ((0, ('Jambons-blancs',)), 5),
#    ((0, ('Coca-sandwich-biscuits',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 5),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((0, ('Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 4),
#    ((0, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((1, ('Pauillac',)), 3),
#    ((1, ('Edible-decorations',)), 3),
#    ((1, ('Jambons-blancs',)), 4),
#    ((1, ('Coca-sandwich-biscuits',)), 3),
#    ((1, ('Meat-pie',)), 4),
#    ((1, ('Jambons-blancs', 'Meat-pie')), 4),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((1, ('Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 3),
#    ((1, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((2, ('Ratatouille',)), 3),
#    ((2, ('Jambons-blancs',)), 3),
#    ((2, ('Meat-pie',)), 3),
#    ((2, ('Jambons-blancs', 'Meat-pie')), 3),
#    ((3, ('Whisky-ecossais',)), 3),
#    ((3, ('Coconut-waters',)), 3),
#    ((0, ('Edible-decorations',)), 3),
#    ((1, ('Ratatouille',)), 3),
#    ((2, ('Whisky-ecossais',)), 3),
#    ((2, ('Coconut-waters',)), 3),
#    ((0, ('Ratatouille',)), 3),
#    ((1, ('Whisky-ecossais',)), 3),
#    ((1, ('Coconut-waters',)), 3)]),
#  (('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits'),
#   [((0, ('Pauillac',)), 4),
#    ((0, ('Jambons-blancs',)), 5),
#    ((0, ('Coca-sandwich-biscuits',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 5),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((0, ('Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 4),
#    ((0, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((1, ('Pauillac',)), 3),
#    ((1, ('Edible-decorations',)), 3),
#    ((1, ('Jambons-blancs',)), 4),
#    ((1, ('Coca-sandwich-biscuits',)), 3),
#    ((1, ('Meat-pie',)), 4),
#    ((1, ('Jambons-blancs', 'Meat-pie')), 4),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((1, ('Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 3),
#    ((1, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((2, ('Ratatouille',)), 3),
#    ((2, ('Jambons-blancs',)), 3),
#    ((2, ('Meat-pie',)), 3),
#    ((2, ('Jambons-blancs', 'Meat-pie')), 3),
#    ((3, ('Whisky-ecossais',)), 3),
#    ((3, ('Coconut-waters',)), 3),
#    ((0, ('Edible-decorations',)), 3),
#    ((1, ('Ratatouille',)), 3),
#    ((2, ('Whisky-ecossais',)), 3),
#    ((2, ('Coconut-waters',)), 3),
#    ((0, ('Ratatouille',)), 3),
#    ((1, ('Whisky-ecossais',)), 3),
#    ((1, ('Coconut-waters',)), 3)]),
#  (('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie'),
#   [((0, ('Pauillac',)), 4),
#    ((0, ('Jambons-blancs',)), 5),
#    ((0, ('Coca-sandwich-biscuits',)), 4),
#    ((0, ('Meat-pie',)), 5),
#    ((0, ('Jambons-blancs', 'Meat-pie')), 5),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((0, ('Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 4),
#    ((0, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 4),
#    ((0, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 4),
#    ((0, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 4),
#    ((0, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 4),
#    ((1, ('Pauillac',)), 3),
#    ((1, ('Edible-decorations',)), 3),
#    ((1, ('Jambons-blancs',)), 4),
#    ((1, ('Coca-sandwich-biscuits',)), 3),
#    ((1, ('Meat-pie',)), 4),
#    ((1, ('Jambons-blancs', 'Meat-pie')), 4),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((1, ('Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Coca-sandwich-biscuits', 'Pauillac')), 3),
#    ((1, ('Meat-pie', 'Pauillac', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Meat-pie', 'Pauillac')), 3),
#    ((1, ('Coca-sandwich-biscuits', 'Pauillac', 'Meat-pie')), 3),
#    ((1, ('Pauillac', 'Meat-pie', 'Coca-sandwich-biscuits')), 3),
#    ((1, ('Pauillac', 'Coca-sandwich-biscuits', 'Meat-pie')), 3),
#    ((2, ('Ratatouille',)), 3),
#    ((2, ('Jambons-blancs',)), 3),
#    ((2, ('Meat-pie',)), 3),
#    ((2, ('Jambons-blancs', 'Meat-pie')), 3),
#    ((3, ('Whisky-ecossais',)), 3),
#    ((3, ('Coconut-waters',)), 3),
#    ((0, ('Edible-decorations',)), 3),
#    ((1, ('Ratatouille',)), 3),
#    ((2, ('Whisky-ecossais',)), 3),
#    ((2, ('Coconut-waters',)), 3),
#    ((0, ('Ratatouille',)), 3),
#    ((1, ('Whisky-ecossais',)), 3),
#    ((1, ('Coconut-waters',)), 3)])]

# %%
#stampo solo quelli che poi hanno dei livelli oltre all'elemento corrente
for p in patterns:
    c = 0
    if p[1] != []:
        print("-> ", p[0][0])
        for item in p[1]:
            s = "\t"
            if item != []:
                p = ""
                for i in range(0, item[0][0]):
                    s += "\t"
                for k in range(0,len(item[0][1])):
                    if k == (len(item[0][1])-1):
                        p += "\t"+item[0][1][k]
                    else:
                        p += "\t"+item[0][1][k] + ","
                print(s, item[0][0],"->", p)
        print()
# Out:
# ->  Oatcakes
# 	 0 -> 	Oatcakes
#
# ->  Flavouring-extract
# 	 0 -> 	Flavouring-extract
#
# ->  Prepared-salads
# 	 0 -> 	Prepared-salads
#
# ->  Quinoa-and-rice
# 	 0 -> 	Quinoa-and-rice
#
# ->  Frozen-spring-rolls
# 	 0 -> 	Frozen-spring-rolls
#
# ->  Peanut-butter-cup
# 	 0 -> 	Peanut-butter-cup
#
# ->  Caramel-dessert
# 	 0 -> 	Baguettes-de-pain
# 	 0 -> 	Mayonaise
# 	 0 -> 	Caramel-dessert
#
# ->  Baguettes-de-pain
# 	 0 -> 	Baguettes-de-pain
#
# ->  Pays-d-oc
# 	 0 -> 	Baguettes-de-pain
# 	 0 -> 	Pays-d-oc
# 	 0 -> 	Prunes
# 	 0 -> 	Multifruits
# 	 0 -> 	Caramel-dessert
#
# ->  Prunes
# 	 0 -> 	Prunes
#
# ->  Mayonaise
# 	 0 -> 	Mayonaise
#
# ->  Carots
# 	 0 -> 	Carots
#
# ->  Chopped-tomatoes
# 	 0 -> 	Chopped-tomatoes
# 	 0 -> 	Chopeed-tomatoes
# 	 0 -> 	Chopeed-tomatoes,	Chopped-tomatoes
#
# ->  Pizza-bases
# 	 0 -> 	Pizza-bases
# 	 0 -> 	Schwarztees
# 	 0 -> 	Nectar-de-pommes
#
# ->  Cornbreads
# 	 0 -> 	Cornbreads
#
# ->  Fudge
# 	 0 -> 	Fudge
#
# ->  Bitters
# 	 0 -> 	Bitters
#
# ->  Tigernuts
# 	 0 -> 	Tigernuts
#
# ->  Aperitif
# 	 0 -> 	Aperitif
#
# ->  Beef-mince
# 	 0 -> 	Beef-mince
#
# ->  Mushroom-in-sunflower-oil
# 	 0 -> 	Mushroom-in-sunflower-oil
#
# ->  Frozen-asian-food
# 	 0 -> 	Frozen-asian-food
#
# ->  Burrito-kit
# 	 0 -> 	Burrito-kit
#
# ->  Pork-crackling
# 	 0 -> 	Pork-crackling
# 	 0 -> 	Chopeed-tomatoes
# 	 0 -> 	Ranja
# 	 0 -> 	Frozen-sweetcorn
#
# ->  Chopeed-tomatoes
# 	 0 -> 	Chopeed-tomatoes
#
# ->  Milch
# 	 0 -> 	Milch
#
# ->  Fresh-salads
# 	 0 -> 	Fresh-salads
#
# ->  Red-onions
# 	 0 -> 	Red-onions
#
# ->  Multifruits
# 	 0 -> 	Multifruits
# 	 0 -> 	Caramel-dessert
#
# ->  Plain-tortilla-wraps
# 	 0 -> 	Prunes
# 	 0 -> 	Multifruits
#
# ->  Cardamom-tea
# 	 0 -> 	Cardamom-tea
#
# ->  Swiss-chocolate-wafer
# 	 0 -> 	Swiss-chocolate-wafer
#
# ->  Coconut-waters
# 	 0 -> 	Coconut-waters
#
# ->  Fruit juices and nectars
# 	 0 -> 	Fruit juices and nectars
#
# ->  Avocadoes
# 	 0 -> 	Avocadoes
#
# ->  Cacao-en-poudre
# 	 0 -> 	Cacao-en-poudre
#
# ->  Oeufs-de-poisson
# 	 0 -> 	Oeufs-de-poisson
#
# ->  Bambusstreifen
# 	 0 -> 	Bambusstreifen
#
# ->  Pappardelle
# 	 0 -> 	Pappardelle
#
# ->  Baby-rocket
# 	 0 -> 	Baby-rocket
#
# ->  Chicken-eggs
# 	 0 -> 	Chicken-eggs
#
# ->  Elegance-tomatoes
# 	 0 -> 	Elegance-tomatoes
#
# ->  Kruidentheeen
# 	 0 -> 	Kruidentheeen
#
# ->  Probiotic-drinks
# 	 0 -> 	Salsa-chips
#
# ->  Medium-cheddar
# 	 0 -> 	Medium-cheddar
#
# ->  Hommus
# 	 0 -> 	Hommus
#
# ->  Strawberry-preserves
# 	 0 -> 	Strawberry-preserves
#
# ->  Granen-en-aardappels
# 	 0 -> 	Granen-en-aardappels
#
# ->  Beef-sausages
# 	 0 -> 	Beef-sausages
#
# ->  Turkish-fermented-drink
# 	 0 -> 	Turkish-fermented-drink
#
# ->  Coca-sandwich-biscuits
# 	 0 -> 	Coca-sandwich-biscuits
#
# ->  Kits
# 	 0 -> 	Kits
#
# ->  Framboises
# 	 0 -> 	Framboises
#
# ->  Brassica
# 	 0 -> 	Framboises
# 	 0 -> 	Brassica
#
# ->  Berry-mueslis
# 	 0 -> 	Berry-mueslis
#
# ->  Cigarettes
# 	 0 -> 	Cigarettes
#
# ->  Soft-cheeses
# 	 0 -> 	Soft-cheeses
#
# ->  Fusilli
# 	 0 -> 	Fusilli
#
# ->  Soupes
# 	 0 -> 	Soupes
#
# ->  Epices
# 	 0 -> 	Epices
# 	 0 -> 	Fruit-flavoured-drink
#
# ->  Tabbouleh
# 	 0 -> 	Tabbouleh
#
# ->  Beef-jerky
# 	 0 -> 	Beef-jerky
#
# ->  Hot-dog-mustard
# 	 0 -> 	Hot-dog-mustard
#
# ->  Savoy-cabbage
# 	 0 -> 	Savoy-cabbage
#
# ->  Sun-dried-tomatoes
# 	 0 -> 	Sun-dried-tomatoes
#
# ->  Chilli-sauce
# 	 0 -> 	Chilli-sauce
#
# ->  Strawberry-mousse
# 	 0 -> 	Strawberry-mousse
#
# ->  Faux-fromage
# 	 0 -> 	Faux-fromage
#
# ->  Mashed-potatoes
# 	 0 -> 	Mashed-potatoes
# 	 0 -> 	Juice-from-concentrate
# 	 0 -> 	Juice-from-concentrate,	Mashed-potatoes
#
# ->  Mache
# 	 0 -> 	Mache
# 		 1 -> 	Mache
#
# ->  Maple-butter
# 	 0 -> 	Maple-butter
#
# ->  Hawaiian-sweet-rolls
# 	 0 -> 	Hawaiian-sweet-rolls
#
# ->  Whole-wheat-tortillas
# 	 0 -> 	Whole-wheat-tortillas
# 	 0 -> 	Almond-flavouring
#
# ->  Tomkin-tomatoes
# 	 0 -> 	Cardamom-tea
# 	 0 -> 	Tomkin-tomatoes
#
# ->  Rice-noodles
# 	 0 -> 	Rice-noodles
#
# ->  Canned-peaches
# 	 0 -> 	Canned-peaches
#
# ->  Grape-tomatoes
# 	 0 -> 	Grape-tomatoes
#
# ->  Peach
# 	 0 -> 	Peach
#
# ->  Canned-coconut-milk
# 	 0 -> 	Canned-coconut-milk
#
# ->  Lingonberry-jams
# 	 0 -> 	Lingonberry-jams
#
# ->  Juice-from-concentrate
# 	 0 -> 	Juice-from-concentrate
#
# ->  Aoli-sauce
# 	 0 -> 	Aoli-sauce
#
# ->  Almond-flavouring
# 	 0 -> 	Almond-flavouring
#
# ->  Poivre-noir
# 	 0 -> 	Poivre-noir
#
# ->  Assortiment-de-fromages
# 	 0 -> 	Burrito-kit
# 	 0 -> 	Cardamom-tea
# 	 0 -> 	Assortiment-de-fromages
# 		 1 -> 	Burrito-kit
#
# ->  Raspberry-conserve
# 	 0 -> 	Raspberry-conserve
#
# ->  Chilisauce
# 	 0 -> 	Chilisauce
#
# ->  Minced-garlic
# 	 0 -> 	Prepared-salads
# 	 0 -> 	Minced-garlic
#
# ->  Iced-green-tea
# 	 0 -> 	Iced-green-tea
#
# ->  Baby-beetroot
# 	 0 -> 	Prepared-salads
# 	 0 -> 	Chilisauce
# 	 0 -> 	Baby-beetroot
#
# ->  Infant-powder-milk
# 	 0 -> 	Infant-powder-milk
#
# ->  Plats-prepares-surgeles
# 	 0 -> 	Schwarztees
#
# ->  Brownie
# 	 0 -> 	Chopped-tomatoes
# 	 0 -> 	Chopeed-tomatoes
# 	 0 -> 	Brownie
# 	 0 -> 	Brownie,	Chopped-tomatoes
#
# ->  Maris-piper-potatoes
# 	 0 -> 	Maris-piper-potatoes
#
# ->  Schwarztees
# 	 0 -> 	Schwarztees
#
# ->  Cauliflower-cheese
# 	 0 -> 	Chopped-tomatoes
# 	 0 -> 	Cauliflower-cheese
#
# ->  Bread-mix
# 	 0 -> 	Bread-mix
# 		 1 -> 	Bread-mix
#
# ->  Vinegars
# 	 0 -> 	Vinegars
#
# ->  Dry-meat
# 	 0 -> 	Dry-meat
#
# ->  Likor
# 	 0 -> 	Ghee
# 	 0 -> 	Likor
# 		 1 -> 	Likor
#
# ->  Flavoured-cranberries
# 	 0 -> 	Flavoured-cranberries
#
# ->  Vin-de-californie
# 	 0 -> 	Vin-de-californie
# 	 0 -> 	Ghee
# 	 0 -> 	Ghee,	Vin-de-californie
#
# ->  Gin
# 	 0 -> 	Gin
#
# ->  Pork-ham
# 	 0 -> 	Pork-ham
#
# ->  Boeuf
# 	 0 -> 	Boeuf
#
# ->  Breaded-chicken
# 	 0 -> 	Breaded-chicken
#
# ->  Green-salads
# 	 0 -> 	Vin-de-californie
# 	 0 -> 	Green-salads
# 	 0 -> 	Ghee
# 	 0 -> 	Frozen-readymeals
#
# ->  Ghee
# 	 0 -> 	Ghee
# 		 1 -> 	Ghee
#
# ->  Cooking-chocolate
# 	 0 -> 	Cooking-chocolate
#
# ->  Canned-tuna-in-lemon
# 	 0 -> 	Canned-tuna-in-lemon
#
# ->  Beef-pie
# 	 0 -> 	Beef-pie
#
# ->  Sardines-in-brine
# 	 0 -> 	Sardines-in-brine
#
# ->  Purified-water
# 	 0 -> 	Chicken-breast-curry-with-tomato-spinach-sauce
# 	 0 -> 	Purified-water
#
# ->  Fruit-juice-concentrate
# 	 0 -> 	Fruit-juice-concentrate
#
# ->  Frozen-confectionary
# 	 0 -> 	Frozen-confectionary
#
# ->  Brandy-snaps
# 	 0 -> 	Brandy-snaps
#
# ->  Chicken-breast-curry-with-tomato-spinach-sauce
# 	 0 -> 	Chicken-breast-curry-with-tomato-spinach-sauce
#
# ->  Purple-sprouting-broccoli
# 	 0 -> 	Purple-sprouting-broccoli
#
# ->  Ranja
# 	 0 -> 	Ranja
#
# ->  Fruit-spreads
# 		 1 -> 	Fruit-spreads
# 	 0 -> 	Fruit-spreads
#
# ->  Garden-peas
# 	 0 -> 	Garden-peas
#
# ->  Blended-scotch-whiskey
# 	 0 -> 	Blended-scotch-whiskey
#
# ->  Ribeye-steak
# 	 0 -> 	Ribeye-steak
#
# ->  Pastilles-a-sucer
# 	 0 -> 	Pastilles-a-sucer
#
# ->  Biere
# 	 0 -> 	Biere
#
# ->  Hoisin-sauce
# 	 0 -> 	Hoisin-sauce
#
# ->  Gateau
# 	 0 -> 	Gateau
#
# ->  Frozen-chicken
# 	 0 -> 	Frozen-chicken
#
# ->  Croque-monsieur
# 	 0 -> 	Croque-monsieur
#
# ->  Multivitamin-supplement
# 	 0 -> 	Multivitamin-supplement
#
# ->  Barritas
# 	 0 -> 	Tabbouleh
#
# ->  Vegetable-pate
# 	 0 -> 	Vegetable-pate
# 	 0 -> 	Juice-milk-drink
#
# ->  Sweet-chilli-sauce
# 	 0 -> 	Sweet-chilli-sauce
#
# ->  Garlic-and-coriander-naan
# 	 0 -> 	Garlic-and-coriander-naan
#
# ->  Brown-onions
# 	 0 -> 	Brown-onions
#
# ->  Cremes-fraiches-epaisses
# 	 0 -> 	Cremes-fraiches-epaisses
#
# ->  Roma-tomatoes
# 	 0 -> 	Roma-tomatoes
#
# ->  Cones
# 	 0 -> 	Cones
# 			 2 -> 	Red-salmon
#
# ->  Chocolate-covered-muesli-bar
# 	 0 -> 	Chocolate-covered-muesli-bar
#
# ->  Lamb-breast
# 	 0 -> 	Lamb-breast
#
# ->  Crisp-rolls
# 	 0 -> 	Crisp-rolls
#
# ->  Baked-beans
# 	 0 -> 	Baked-beans
#
# ->  Taco-shells
# 	 0 -> 	Taco-shells
#
# ->  Slaty-snack
# 	 0 -> 	Slaty-snack
#
# ->  Juice-milk-drink
# 	 0 -> 	Juice-milk-drink
#
# ->  Filets-de-poulet
# 	 0 -> 	Filets-de-poulet
#
# ->  Suppenwurfel
# 	 0 -> 	Suppenwurfel
#
# ->  Frozen-sweetcorn
# 	 0 -> 	Frozen-sweetcorn
#
# ->  Baby foods
# 	 0 -> 	Baby foods
#
# ->  Crsips
# 	 0 -> 	Crsips
#
# ->  Orange-chocolate
# 	 0 -> 	Orange-chocolate
#
# ->  Sandwiches
# 	 0 -> 	Sandwiches
#
# ->  Nectar-de-pommes
# 	 0 -> 	Nectar-de-pommes
#
# ->  Flavoured-milk-drink
# 	 0 -> 	Flavoured-milk-drink
#
# ->  Meat-pie
# 	 0 -> 	Meat-pie
#
# ->  Tartar-sauce
# 	 0 -> 	Tartar-sauce
#
# ->  Tea-drinks
# 	 0 -> 	Tea-drinks
#
# ->  Lime-pickle
# 	 0 -> 	Lime-pickle
#
# ->  Blended-scotch-whisky
# 	 0 -> 	Blended-scotch-whisky
#
# ->  Turkey-bacon
# 	 0 -> 	Turkey-bacon
#
# ->  Fizzy-drinks
# 	 0 -> 	Fizzy-drinks
#
# ->  Nutella-biscuits
# 	 0 -> 	Nutella-biscuits
#
# ->  Mixed-chillies
# 	 0 -> 	Mixed-chillies
#
# ->  Conserves
# 	 0 -> 	Conserves
#
# ->  Biscottes
# 	 0 -> 	Cornbreads
# 	 0 -> 	Biscottes
# 	 0 -> 	Prepared-fish
# 		 1 -> 	Prepared-fish
#
# ->  Organic-tomatoes
# 	 0 -> 	Organic-tomatoes
#
# ->  Griechische-joghurt
# 	 0 -> 	Griechische-joghurt
#
# ->  Gulab-jamun
# 	 0 -> 	Gulab-jamun
#
# ->  Mexican-sauces
# 	 0 -> 	Mexican-sauces
#
# ->  Wholefood
# 	 0 -> 	Bitters
# 	 0 -> 	Wholefood
#
# ->  Baked-beans-in-tomato-sauce
# 	 0 -> 	Baked-beans-in-tomato-sauce
#
# ->  Almond-milk-yogurt
# 	 0 -> 	Almond-milk-yogurt
#
# ->  Sucre
# 	 0 -> 	Sucre
#
# ->  Diced-pork
# 	 0 -> 	Diced-pork
#
# ->  Smoked-oysters-in-barbeque-sauce
# 	 0 -> 	Smoked-oysters-in-barbeque-sauce
#
# ->  Bonbons-au-chocolat
# 	 0 -> 	Bonbons-au-chocolat
#
# ->  Producto-de-aperitivo
# 	 0 -> 	Producto-de-aperitivo
#
# ->  Barres-de-cereales
# 	 0 -> 	Tabbouleh
# 	 0 -> 	Barres-de-cereales
# 		 1 -> 	Tabbouleh
#
# ->  Peach-juice-drink
# 	 0 -> 	Peach-juice-drink
#
# ->  Peaches-sliced-in-syrup
# 	 0 -> 	Peaches-sliced-in-syrup
#
# ->  Farming products
# 	 0 -> 	Farming products
#
# ->  Frozen-asian-vegetables
# 	 0 -> 	Faux-fromage
# 	 0 -> 	Frozen-asian-vegetables
#
# ->  Canned-crab-meat
# 	 0 -> 	Canned-crab-meat
#
# ->  Frozen-potato-products
# 	 0 -> 	Frozen-potato-products
#
# ->  Chia-seeds
# 	 0 -> 	Chia-seeds
# 	 0 -> 	Persimmon
#
# ->  Nans
# 	 0 -> 	Nans
#
# ->  Premium-and-organic-pepper-from-cambodia
# 	 0 -> 	Premium-and-organic-pepper-from-cambodia
#
# ->  Dairies
# 	 0 -> 	Dairies
#
# ->  Boneless-pork-loin-steak
# 	 0 -> 	Boneless-pork-loin-steak
#
# ->  Stuffing
# 	 0 -> 	Stuffing
#
# ->  Blinis
# 	 0 -> 	Blinis
#
# ->  Spring-roll-pastry
# 	 0 -> 	Spring-roll-pastry
#
# ->  Plant-based foods and beverages
# 	 0 -> 	Plant-based foods and beverages
#
# ->  Strawberry-licorice
# 	 0 -> 	Strawberry-licorice
#
# ->  Almond-chocolate
# 	 0 -> 	Strawberry-licorice
# 	 0 -> 	Almond-chocolate
#
# ->  Hagelslag
# 	 0 -> 	Hagelslag
#
# ->  Sandwich-spread
# 	 0 -> 	Sandwich-spread
#
# ->  Seafood-salad
# 	 0 -> 	Seafood-salad
#
# ->  Gnocchi
# 	 0 -> 	Gnocchi
# 	 0 -> 	Cheese-analogues
# 	 0 -> 	Fruit-flavoured-drink
#
# ->  Confectioner
# 	 0 -> 	Confectioner
#
# ->  Haselnusse
# 	 0 -> 	Confectioner
# 	 0 -> 	Haselnusse
#
# ->  Parve
# 	 0 -> 	Parve
#
# ->  Seafood
# 	 0 -> 	Seafood
#
# ->  Prepared-fish
# 	 0 -> 	Prepared-fish
# 		 1 -> 	Prepared-fish
#
# ->  Bakery
# 	 0 -> 	Bakery
#
# ->  Groenten
# 	 0 -> 	Groenten
#
# ->  Raisin-bread
# 	 0 -> 	Raisin-bread
# 	 0 -> 	Biscuits-aperitifs-sales
#
# ->  Alkoholische-getranke
# 	 0 -> 	Alkoholische-getranke
#
# ->  Capsicums
# 	 0 -> 	Groenten
# 	 0 -> 	Capsicums
#
# ->  Biscuits-aperitifs-sales
# 	 0 -> 	Biscuits-aperitifs-sales
#
# ->  Hoki-fish-fillets
# 	 0 -> 	Flavoured-cranberries
# 	 0 -> 	Hoki-fish-fillets
# 	 0 -> 	Flavoured-cranberries,	Hoki-fish-fillets
#
# ->  Sweetcorn-relish
# 	 0 -> 	Sweetcorn-relish
#
# ->  Goat-milk
# 	 0 -> 	Goat-milk
#
# ->  Estragon
# 	 0 -> 	Estragon
#
# ->  Gaufres
# 	 0 -> 	Gaufres
#
# ->  Baby-sanmarzano-tomatoes
# 	 0 -> 	Baby-sanmarzano-tomatoes
#
# ->  Salmon-in-spring-water
# 	 0 -> 	Salmon-in-spring-water
# 	 0 -> 	Boeuf
#
# ->  Cactus
# 	 0 -> 	Cactus
#
# ->  Chocolat-au-lait
# 	 0 -> 	Chocolat-au-lait
#
# ->  Biscuits-au-chocolat-noir
# 	 0 -> 	Biscuits-au-chocolat-noir
#
# ->  Gateau-chinois
# 	 0 -> 	Gateau-chinois
#
# ->  Broden
# 	 0 -> 	Broden
# 	 0 -> 	Fruit-flavoured-drink
# 	 0 -> 	Cream-cheese-spreads
#
# ->  Apple-and-pear-juices
# 	 0 -> 	Apple-and-pear-juices
# 		 1 -> 	Apple-and-pear-juices
# 	 0 -> 	Basa-fish
# 	 0 -> 	Apple-and-pear-juices,	Basa-fish
#
# ->  Long-life-milk
# 	 0 -> 	Long-life-milk
#
# ->  Fruit-flavoured-drink
# 	 0 -> 	Fruit-flavoured-drink
#
# ->  Scotch-eggs
# 	 0 -> 	Fruit-flavoured-drink
# 	 0 -> 	Scotch-eggs
# 	 0 -> 	Fruit-flavoured-drink,	Scotch-eggs
# 		 1 -> 	Fruit-flavoured-drink
# 	 0 -> 	Gnocchi
#
# ->  Cream-cheese-spreads
# 	 0 -> 	Fruit-flavoured-drink
# 	 0 -> 	Cream-cheese-spreads
#
# ->  Cheese-analogues
# 	 0 -> 	Cheese-analogues
#
# ->  Sweet-biscuits
# 	 0 -> 	Sweet-biscuits
#
# ->  Milk substitute
# 	 0 -> 	Mushroom-in-sunflower-oil
# 	 0 -> 	Horseradish-sauce
# 	 0 -> 	Milk substitute
# 	 0 -> 	Horseradish-sauce,	Milk substitute
#
# ->  Spices-seasoning-mixes
# 	 0 -> 	Spices-seasoning-mixes
#
# ->  Microwave-popcorn
# 	 0 -> 	Microwave-popcorn
#
# ->  Tortillas
# 	 0 -> 	Tortillas
#
# ->  Flavoured-mineral-water-beverages
# 	 0 -> 	Flavoured-mineral-water-beverages
# 	 0 -> 	Surgelati
#
# ->  Fruit-drinks
# 	 0 -> 	Fruit-drinks
#
# ->  Natural-spring-water
# 	 0 -> 	Natural-spring-water
#
# ->  Canned-lamb-tongue
# 	 0 -> 	Canned-lamb-tongue
#
# ->  Bruschetta
# 	 0 -> 	Canned-lamb-tongue
# 	 0 -> 	Bruschetta
#
# ->  Surgelati
# 	 0 -> 	Surgelati
#
# ->  Fromage-au-lait-cru
# 	 0 -> 	Fromage-au-lait-cru
#
# ->  Chocolate-ice-cream
# 	 0 -> 	Chocolate-ice-cream
#
# ->  Steak-kidney-pie
# 	 0 -> 	Steak-kidney-pie
#
# ->  Liquid-honey
# 	 0 -> 	Liquid-honey
#
# ->  Shrimp-paste
# 	 0 -> 	Shrimp-paste
#
# ->  Sirloin-steak
# 	 0 -> 	Sirloin-steak
#
# ->  Sweet-olives
# 	 0 -> 	Sweet-olives
#
# ->  Creme-chocolat
# 	 0 -> 	Creme-chocolat
#
# ->  Breakfasts
# 	 0 -> 	Soft-cheeses
# 	 0 -> 	Chocolate-rice-cakes
# 	 0 -> 	Breakfasts
# 	 0 -> 	Kaffee
# 		 1 -> 	Soft-cheeses
#
# ->  Chocolate-rice-cakes
# 	 0 -> 	Chocolate-rice-cakes
#
# ->  Cornichons
# 	 0 -> 	Berry-mueslis
# 	 0 -> 	Turkey-bacon
# 	 0 -> 	Cornichons
#
# ->  Frozen-readymeals
# 	 0 -> 	Ghee
# 	 0 -> 	Frozen-readymeals
#
# ->  Mineral-natural-water
# 	 0 -> 	Mineral-natural-water
#
# ->  Glace-cherries
# 	 0 -> 	Glace-cherries
# 	 0 -> 	Raspberry-conserve
# 	 0 -> 	Nectar-de-pommes
#
# ->  Strawberries-canned
# 	 0 -> 	Strawberries-canned
#
# ->  Cucumbers-in-brine
# 	 0 -> 	Swiss-chocolate-wafer
# 	 0 -> 	Cucumbers-in-brine
# 	 0 -> 	Cucumbers-in-brine,	Swiss-chocolate-wafer
#
# ->  Kvarg
# 	 0 -> 	Kvarg
# 		 1 -> 	Kvarg
#
# ->  Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce,	Food additives
#
# ->  Fish-sauce
# 	 0 -> 	Fish-sauce
#
# ->  Condiment-en-poudre
# 	 0 -> 	Condiment-en-poudre
#
# ->  Coffee-creamer
# 	 0 -> 	Coffee-creamer
# 		 1 -> 	Coffee-creamer
#
# ->  Curries
# 	 0 -> 	Curries
#
# ->  Moutardes
# 	 0 -> 	Moutardes
#
# ->  Indian-meals
# 	 0 -> 	Indian-meals
#
# ->  Corn-kernels
# 	 0 -> 	Corn-kernels
#
# ->  Banana-chips
# 	 0 -> 	Banana-chips
#
# ->  Genio-tomatoes
# 	 0 -> 	Genio-tomatoes
#
# ->  Swede
# 	 0 -> 	Swede
#
# ->  Muffins
# 	 0 -> 	Muffins
#
# ->  Beer-batter-fries
# 	 0 -> 	Beer-batter-fries
#
# ->  Chicken-kebabs
# 	 0 -> 	Chicken-kebabs
#
# ->  Asian-foods
# 	 0 -> 	Asian-foods
#
# ->  Fruit-sticks
# 	 0 -> 	Fruit-sticks
# 		 1 -> 	Fruit-sticks
#
# ->  Dumplings
# 	 0 -> 	Dumplings
#
# ->  Pancake-mix
# 	 0 -> 	Pancake-mix
#
# ->  Licensed products
# 	 0 -> 	Licensed products
#
# ->  All-steak-pie
# 	 0 -> 	Crisp-rolls
# 	 0 -> 	All-steak-pie
# 	 0 -> 	Bhuja
# 	 0 -> 	Frozen-corn-cobs
# 		 1 -> 	Crisp-rolls
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Cornbreads,	Peanut-butter-cup
#
# ->  Crab-pate
# 	 0 -> 	Aoli-sauce
# 	 0 -> 	Sirloin-steak
# 	 0 -> 	Crab-pate
# 	 0 -> 	Aoli-sauce,	Sirloin-steak
# 	 0 -> 	Salsa-chips
#
# ->  Wheatflour
# 	 0 -> 	Wheatflour
# 	 0 -> 	Aoli-sauce,	Sirloin-steak
#
# ->  Products sold before year 2000
# 	 0 -> 	Products sold before year 2000
# 		 1 -> 	Products sold before year 2000
#
# ->  Minestrone
# 	 0 -> 	Products sold before year 2000
# 	 0 -> 	Minestrone
# 	 0 -> 	Dry-seasoning-mix
#
# ->  Dry-seasoning-mix
# 	 0 -> 	Dry-seasoning-mix
#
# ->  Persimmon
# 	 0 -> 	Aoli-sauce
# 	 0 -> 	Persimmon
# 	 0 -> 	Plant-based foods and beverages
# 		 1 -> 	Plant-based foods and beverages
#
# ->  Pate-feuilletee
# 	 0 -> 	Pate-feuilletee
#
# ->  Granola-mix
# 	 0 -> 	Granola-mix
#
# ->  Ricotta
# 	 0 -> 	Ricotta
#
# ->  Chicken-breast-fillets
# 	 0 -> 	Chicken-breast-fillets
#
# ->  Gelee-de-groseille
# 	 0 -> 	Gelee-de-groseille
#
# ->  Coconut-flour
# 	 0 -> 	Coconut-flour
#
# ->  Fresh-garlic
# 	 0 -> 	Fresh-garlic
#
# ->  Hot-fudge-topping
# 	 0 -> 	Hot-fudge-topping
#
# ->  Energy-ball
# 	 0 -> 	Energy-ball
#
# ->  Asian-cooking
# 	 0 -> 	Asian-cooking
# 		 1 -> 	Asian-cooking
#
# ->  Bhuja
# 	 0 -> 	Bhuja
# 	 0 -> 	Basa-fish
# 	 0 -> 	Basa-fish,	Bhuja
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Basa-fish
#
# ->  Frozen-corn-cobs
# 	 0 -> 	Frozen-corn-cobs
#
# ->  Basa-fish
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Bhuja
# 	 0 -> 	Basa-fish
# 	 0 -> 	Basa-fish,	Bhuja
# 	 0 -> 	Cornbreads,	Peanut-butter-cup
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Peanut-butter-cup
# 		 1 -> 	Cornbreads
# 		 1 -> 	Basa-fish
# 		 1 -> 	Cornbreads,	Peanut-butter-cup
# 		 1 -> 	Basa-fish,	Peanut-butter-cup
#
# ->  Holunder-bluten-sirup
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Beef-mince
# 	 0 -> 	Biscottes
# 	 0 -> 	Prepared-fish
# 	 0 -> 	Apple-and-pear-juices
# 	 0 -> 	Chocolate-ice-cream
# 	 0 -> 	Basa-fish
# 	 0 -> 	Holunder-bluten-sirup
# 	 0 -> 	Apple-and-pear-juices,	Basa-fish
# 	 0 -> 	Cornbreads,	Prepared-fish
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Apple-and-pear-juices
# 		 1 -> 	Basa-fish
# 		 1 -> 	Apple-and-pear-juices,	Basa-fish
# 			 2 -> 	Apple-and-pear-juices
#
# ->  Fruit-confectionary
# 	 0 -> 	Fruit-confectionary
#
# ->  Pains-precuits
# 	 0 -> 	Cornbreads
# 		 1 -> 	Cornbreads
# 	 0 -> 	Pains-precuits
#
# ->  Ratatouille
# 	 0 -> 	Ratatouille
#
# ->  Minced-beef-steak
# 	 0 -> 	Minced-beef-steak
#
# ->  Bread-rolls
# 	 0 -> 	Bread-rolls
#
# ->  Potato-crips
# 	 0 -> 	Potato-crips
#
# ->  Ribbon-noodles
# 	 0 -> 	Ribbon-noodles
#
# ->  Spare-pork-ribs
# 	 0 -> 	Spare-pork-ribs
# 	 0 -> 	Fruchtnektar
#
# ->  Indian-food-mixes
# 	 0 -> 	Indian-food-mixes
#
# ->  Viande
# 	 0 -> 	Viande
# 		 1 -> 	Viande
#
# ->  Conservation
# 	 0 -> 	Conservation
#
# ->  Sandiwch
# 	 0 -> 	Genio-tomatoes
# 	 0 -> 	Sandiwch
# 	 0 -> 	Ciabatta
# 	 0 -> 	Ciabatta,	Sandiwch
# 		 1 -> 	Sandiwch
# 	 0 -> 	Oatcakes
#
# ->  Ciabatta
# 	 0 -> 	Genio-tomatoes
# 	 0 -> 	Sandiwch
# 	 0 -> 	Ciabatta
# 	 0 -> 	Ciabatta,	Sandiwch
# 		 1 -> 	Sandiwch
#
# ->  Fruchtnektar
# 	 0 -> 	Fruchtnektar
#
# ->  Cukor
# 	 0 -> 	Cukor
#
# ->  Cured-ham
# 	 0 -> 	Cured-ham
# 	 0 -> 	Fruit-flavored
#
# ->  Raw-organic-honey
# 	 0 -> 	Raw-organic-honey
# 	 0 -> 	Fruit-spreads
#
# ->  Feuille-de-vigne
# 	 0 -> 	Feuille-de-vigne
#
# ->  Fruit-flavored
# 	 0 -> 	Fruit-flavored
#
# ->  Losenges
# 	 0 -> 	Biskuvi
# 	 0 -> 	Stuffing
# 	 0 -> 	Spices-seasoning-mixes
# 	 0 -> 	Losenges
# 	 0 -> 	Spices-seasoning-mixes,	Stuffing
# 		 1 -> 	Stuffing
# 			 2 -> 	Stuffing
#
# ->  Fruit-juice-drink
# 	 0 -> 	Fruit-juice-drink
# 	 0 -> 	Beef-sausages
# 	 0 -> 	Fruit-flavoured-drink
#
# ->  Butters-spreads
# 	 0 -> 	Gulab-jamun
# 	 0 -> 	Butters-spreads
#
# ->  Red-ale
# 	 0 -> 	Beef-jerky
# 	 0 -> 	Red-ale
# 		 1 -> 	Red-ale
#
# ->  Cafes-solubles
# 	 0 -> 	Cafes-solubles
#
# ->  Malt-vinegar
# 	 0 -> 	Sun-dried-tomatoes
# 	 0 -> 	Malt-vinegar
#
# ->  Distilled-malt-vinegar
# 	 0 -> 	Chicken-breast-curry-with-tomato-spinach-sauce
# 	 0 -> 	Distilled-malt-vinegar
# 	 0 -> 	Chicken-breast-curry-with-tomato-spinach-sauce,	Distilled-malt-vinegar
# 		 1 -> 	Chicken-breast-curry-with-tomato-spinach-sauce
#
# ->  Fecules
# 	 0 -> 	Asian-cooking
# 		 1 -> 	Asian-cooking
#
# ->  Cured-sausage
# 	 0 -> 	Cured-sausage
#
# ->  Pasteurized-milk
# 	 0 -> 	Pasteurized-milk
#
# ->  Pale-ale
# 	 0 -> 	Pale-ale
#
# ->  Soup-mix
# 	 0 -> 	Milch
# 	 0 -> 	Raspberry-conserve
# 	 0 -> 	Dairies
# 	 0 -> 	Curries
# 	 0 -> 	Soup-mix
# 	 0 -> 	Milch,	Raspberry-conserve
# 	 0 -> 	Curries,	Raspberry-conserve
#
# ->  Organic-certified
# 	 0 -> 	Organic-certified
#
# ->  Pate-a-tartiner-pomme-poire
# 	 0 -> 	Pate-a-tartiner-pomme-poire
# 	 0 -> 	Fruit-sticks
#
# ->  Kaffee
# 	 0 -> 	Kaffee
# 		 1 -> 	Kaffee
# 			 2 -> 	Kaffee
#
# ->  Cordial
# 	 0 -> 	Cordial
#
# ->  Ramen
# 	 0 -> 	Ramen
#
# ->  Pies
# 	 0 -> 	Fruit-spreads
# 	 0 -> 	Pies
# 	 0 -> 	Multivitamin-supplement
#
# ->  Garlic-bread
# 	 0 -> 	Garlic-bread
#
# ->  Miels
# 	 0 -> 	Bhuja
# 	 0 -> 	Basa-fish
# 	 0 -> 	Pasteurized-milk
# 	 0 -> 	Miels
# 	 0 -> 	Whole-wheat-pita-bread
# 	 0 -> 	Bhuja,	Pasteurized-milk
# 	 0 -> 	Basa-fish,	Bhuja
# 		 1 -> 	Basa-fish
# 	 0 -> 	Granola-mix
# 		 1 -> 	Granola-mix
#
# ->  Whole-wheat-pita-bread
# 	 0 -> 	Whole-wheat-pita-bread
# 		 1 -> 	Whole-wheat-pita-bread
#
# ->  Fresh-juices
# 	 0 -> 	Fresh-juices
# 		 1 -> 	Fresh-juices
#
# ->  Sliced-cheddar
# 	 0 -> 	Sliced-cheddar
# 	 0 -> 	Popping-corn
# 	 0 -> 	Conservation
#
# ->  Chick-peas
# 	 0 -> 	Chick-peas
#
# ->  Fromage-au-lait-cru
# 	 0 -> 	Caramel-dessert
# 	 0 -> 	Mayonaise
# 	 0 -> 	Multifruits
# 	 0 -> 	Canned-lamb-tongue
# 	 0 -> 	Fromage-au-lait-cru
# 	 0 -> 	Fromage-au-lait-cru,	Mayonaise
# 	 0 -> 	Caramel-dessert,	Mayonaise
# 		 1 -> 	Caramel-dessert
#
# ->  Beef-sausages
# 	 0 -> 	Beef-sausages
# 	 0 -> 	Peach-juice-drink
# 	 0 -> 	Confectioner
# 	 0 -> 	Beef-sausages,	Confectioner
# 		 1 -> 	Confectioner
#
# ->  Fish-sauce
# 	 0 -> 	Filets-de-poulet
# 	 0 -> 	Stuffing
# 	 0 -> 	Fish-sauce
# 		 1 -> 	Stuffing
#
# ->  Stuffing
# 	 0 -> 	Sunflower-oil-spread
# 	 0 -> 	Stuffing
# 	 0 -> 	Stuffing,	Sunflower-oil-spread
# 		 1 -> 	Sunflower-oil-spread
#
# ->  All-steak-pie
# 	 0 -> 	Crisp-rolls
# 	 0 -> 	All-steak-pie
# 	 0 -> 	Bhuja
# 	 0 -> 	Frozen-corn-cobs
# 	 0 -> 	All-steak-pie,	Bhuja
# 		 1 -> 	Crisp-rolls
# 		 1 -> 	All-steak-pie
# 		 1 -> 	Frozen-corn-cobs
# 			 2 -> 	Crisp-rolls
# 			 2 -> 	Frozen-corn-cobs
# 				 3 -> 	Crisp-rolls
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Basa-fish
# 	 0 -> 	Basa-fish,	Bhuja
# 	 0 -> 	Cornbreads,	Peanut-butter-cup
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Peanut-butter-cup
# 		 1 -> 	Cornbreads
# 		 1 -> 	Bhuja
# 		 1 -> 	Basa-fish
# 		 1 -> 	Basa-fish,	Bhuja
# 		 1 -> 	Cornbreads,	Peanut-butter-cup
# 		 1 -> 	Basa-fish,	Peanut-butter-cup
# 			 2 -> 	Peanut-butter-cup
# 			 2 -> 	Cornbreads
# 			 2 -> 	Basa-fish
# 			 2 -> 	Cornbreads,	Peanut-butter-cup
# 			 2 -> 	Basa-fish,	Peanut-butter-cup
# 				 3 -> 	Cornbreads
# 				 3 -> 	Cornbreads,	Peanut-butter-cup
#
# ->  Cigarettes
# 	 0 -> 	Bitters
# 	 0 -> 	Mexican-sauces
# 	 0 -> 	Cigarettes
# 	 0 -> 	Cigarettes,	Mexican-sauces
# 		 1 -> 	Mexican-sauces
#
# ->  Protein
# 	 0 -> 	Semoules-de-ble
# 	 0 -> 	Protein
# 	 0 -> 	Protein,	Semoules-de-ble
# 		 1 -> 	Protein
#
# ->  Bitters
# 	 0 -> 	Bitters
# 	 0 -> 	Kits
# 	 0 -> 	Wholefood
# 	 0 -> 	Bitters,	Wholefood
# 	 0 -> 	Bitters,	Kits
# 		 1 -> 	Kits
# 		 1 -> 	Bitters
#
# ->  Hawaiian-sweet-rolls
# 	 0 -> 	Hawaiian-sweet-rolls
# 	 0 -> 	Sweet-chilli-sauce
# 	 0 -> 	Hawaiian-sweet-rolls,	Sweet-chilli-sauce
# 		 1 -> 	Hawaiian-sweet-rolls
# 		 1 -> 	Sweet-chilli-sauce
#
# ->  Gateau-chinois
# 	 0 -> 	Hawaiian-sweet-rolls
# 	 0 -> 	Icecream
# 	 0 -> 	Gateau-chinois
# 	 0 -> 	Gateau-chinois,	Hawaiian-sweet-rolls
# 	 0 -> 	Gateau-chinois,	Icecream
# 		 1 -> 	Gateau-chinois
#
# ->  Cucumbers-in-brine
# 	 0 -> 	Swiss-chocolate-wafer
# 	 0 -> 	Cucumbers-in-brine
# 	 0 -> 	Cucumbers-in-brine,	Swiss-chocolate-wafer
# 		 1 -> 	Swiss-chocolate-wafer
# 		 1 -> 	Cucumbers-in-brine
# 		 1 -> 	Cucumbers-in-brine,	Swiss-chocolate-wafer
#
# ->  Fish-sauce
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Sunflower-oil-spread
# 	 0 -> 	Fish-sauce,	Sunflower-oil-spread
# 		 1 -> 	Fish-sauce
#
# ->  Aoli-sauce
# 	 0 -> 	Aoli-sauce
# 	 0 -> 	Chia-seeds
# 	 0 -> 	Aoli-sauce,	Chia-seeds
# 	 0 -> 	Persimmon
# 	 0 -> 	Chia-seeds,	Persimmon
# 	 0 -> 	Aoli-sauce,	Persimmon
# 		 1 -> 	Persimmon
# 	 0 -> 	Plant-based foods and beverages
# 		 1 -> 	Plant-based foods and beverages
# 			 2 -> 	Plant-based foods and beverages
#
# ->  Bitters
# 	 0 -> 	Bitters
# 	 0 -> 	Kits
# 	 0 -> 	Wholefood
# 	 0 -> 	Bitters,	Kits
# 		 1 -> 	Kits
#
# ->  Elegance-tomatoes
# 	 0 -> 	Elegance-tomatoes
# 	 0 -> 	Kruidentheeen
# 	 0 -> 	Elegance-tomatoes,	Kruidentheeen
#
# ->  Spices-seasoning-mixes
# 	 0 -> 	Stuffing
#
# ->  Chia-seeds
# 	 0 -> 	Aoli-sauce
# 	 0 -> 	Chia-seeds
# 	 0 -> 	Aoli-sauce,	Chia-seeds
# 	 0 -> 	Persimmon
# 	 0 -> 	Chia-seeds,	Persimmon
# 	 0 -> 	Aoli-sauce,	Persimmon
# 		 1 -> 	Persimmon
# 	 0 -> 	Plant-based foods and beverages
# 		 1 -> 	Plant-based foods and beverages
# 			 2 -> 	Plant-based foods and beverages
#
# ->  Chopeed-tomatoes
# 	 0 -> 	Chopped-tomatoes
# 	 0 -> 	Chopeed-tomatoes
# 	 0 -> 	Brownie
# 	 0 -> 	Chopeed-tomatoes,	Chopped-tomatoes
# 	 0 -> 	Brownie,	Chopped-tomatoes
# 		 1 -> 	Chopped-tomatoes
#
# ->  Hawaiian-sweet-rolls
# 	 0 -> 	Tabbouleh
# 	 0 -> 	Hawaiian-sweet-rolls
# 	 0 -> 	Hawaiian-sweet-rolls,	Tabbouleh
# 		 1 -> 	Tabbouleh
# 		 1 -> 	Hawaiian-sweet-rolls
#
# ->  Cigarettes
# 		 1 -> 	Tartar-sauce
# 	 0 -> 	Tartar-sauce
#
# ->  Biskuvi
# 	 0 -> 	Popping-corn
# 	 0 -> 	Biskuvi
# 	 0 -> 	Biskuvi,	Popping-corn
#
# ->  Fish-sauce
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
#
# ->  Milch
# 	 0 -> 	Milch
# 	 0 -> 	Raspberry-conserve
# 	 0 -> 	Curries
# 	 0 -> 	Milch,	Raspberry-conserve
# 	 0 -> 	Curries,	Raspberry-conserve
# 		 1 -> 	Milch
# 		 1 -> 	Raspberry-conserve
# 		 1 -> 	Curries
# 		 1 -> 	Milch,	Raspberry-conserve
# 		 1 -> 	Curries,	Raspberry-conserve
# 			 2 -> 	Milch
# 	 0 -> 	Orange-chocolate
# 		 1 -> 	Orange-chocolate
#
# ->  Chopeed-tomatoes
# 	 0 -> 	Chopeed-tomatoes
# 	 0 -> 	Maple-butter
# 	 0 -> 	Chopeed-tomatoes,	Maple-butter
# 		 1 -> 	Chopeed-tomatoes
# 	 0 -> 	Frozen-sweetcorn
#
# ->  Lager-beer
# 	 0 -> 	Pates-a-tartiner-aux-noisettes-et-au-cacao
# 	 0 -> 	Gelee-de-groseille
#
# ->  Caramel-dessert
# 	 0 -> 	Baguettes-de-pain
# 	 0 -> 	Pays-d-oc
# 	 0 -> 	Multifruits
# 	 0 -> 	Baguettes-de-pain,	Pays-d-oc
# 	 0 -> 	Caramel-dessert
# 	 0 -> 	Caramel-dessert,	Pays-d-oc
#
# ->  Cacao-en-poudre
# 	 0 -> 	Cacao-en-poudre
# 	 0 -> 	Mashed-potatoes
# 	 0 -> 	Juice-from-concentrate
# 	 0 -> 	Licensed products
# 	 0 -> 	Cacao-en-poudre,	Juice-from-concentrate
# 	 0 -> 	Juice-from-concentrate,	Mashed-potatoes
# 	 0 -> 	Cacao-en-poudre,	Licensed products
# 		 1 -> 	Juice-from-concentrate
# 		 1 -> 	Licensed products
#
# ->  Juice-from-concentrate
# 	 0 -> 	Cacao-en-poudre
# 	 0 -> 	Mashed-potatoes
# 	 0 -> 	Juice-from-concentrate
# 	 0 -> 	Cacao-en-poudre,	Juice-from-concentrate
# 	 0 -> 	Juice-from-concentrate,	Mashed-potatoes
# 		 1 -> 	Mashed-potatoes
# 		 1 -> 	Juice-from-concentrate
#
# ->  Spices-seasoning-mixes
# 	 0 -> 	Tabbouleh
# 		 1 -> 	Tabbouleh
# 	 0 -> 	Spices-seasoning-mixes
# 	 0 -> 	Spices-seasoning-mixes,	Tabbouleh
# 		 1 -> 	Spices-seasoning-mixes
# 		 1 -> 	Spices-seasoning-mixes,	Tabbouleh
# 	 0 -> 	Spices-seasoning-mixes,	Stuffing
#
# ->  Bhuja
# 	 0 -> 	Cardamom-tea
# 	 0 -> 	Bhuja
# 	 0 -> 	Basa-fish
# 	 0 -> 	Pasteurized-milk
# 	 0 -> 	Miels
# 	 0 -> 	Bhuja,	Pasteurized-milk
# 	 0 -> 	Basa-fish,	Bhuja
# 		 1 -> 	Bhuja
# 		 1 -> 	Basa-fish
# 		 1 -> 	Pasteurized-milk
#
# ->  Cremes-fraiches-epaisses
# 	 0 -> 	Cremes-fraiches-epaisses
# 	 0 -> 	Tartar-sauce
# 	 0 -> 	Pale-ale
# 	 0 -> 	Cremes-fraiches-epaisses,	Pale-ale
# 		 1 -> 	Cremes-fraiches-epaisses
#
# ->  Ghee
# 	 0 -> 	Vin-de-californie
# 	 0 -> 	Ghee
# 	 0 -> 	Ghee,	Vin-de-californie
# 		 1 -> 	Vin-de-californie
# 		 1 -> 	Ghee
# 		 1 -> 	Ghee,	Vin-de-californie
#
# ->  Framboises
# 	 0 -> 	Coca-sandwich-biscuits
# 	 0 -> 	Framboises
# 	 0 -> 	Griechische-joghurt
# 	 0 -> 	Framboises,	Griechische-joghurt
# 	 0 -> 	Coca-sandwich-biscuits,	Framboises
# 		 1 -> 	Framboises
# 		 1 -> 	Griechische-joghurt
#
# ->  Fromage-au-lait-cru
# 	 0 -> 	Raspberry-conserve
# 	 0 -> 	Fromage-au-lait-cru
# 	 0 -> 	Curries
# 	 0 -> 	Fromage-au-lait-cru,	Raspberry-conserve
# 	 0 -> 	Curries,	Raspberry-conserve
# 		 1 -> 	Raspberry-conserve
# 		 1 -> 	Curries
# 		 1 -> 	Curries,	Raspberry-conserve
# 			 2 -> 	Raspberry-conserve
#
# ->  Basa-fish
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Apple-and-pear-juices
# 	 0 -> 	Bhuja
# 	 0 -> 	Basa-fish
# 	 0 -> 	Basa-fish,	Bhuja
# 	 0 -> 	Cornbreads,	Peanut-butter-cup
# 	 0 -> 	Apple-and-pear-juices,	Basa-fish
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Peanut-butter-cup
# 		 1 -> 	Cornbreads
# 		 1 -> 	Bhuja
# 		 1 -> 	Basa-fish
# 		 1 -> 	Basa-fish,	Bhuja
# 		 1 -> 	Cornbreads,	Peanut-butter-cup
# 		 1 -> 	Basa-fish,	Peanut-butter-cup
# 			 2 -> 	Peanut-butter-cup
# 			 2 -> 	Cornbreads
# 			 2 -> 	Basa-fish
# 			 2 -> 	Cornbreads,	Peanut-butter-cup
# 	 0 -> 	Pasteurized-milk
#
# ->  Brownie
# 	 0 -> 	Chopped-tomatoes
# 	 0 -> 	Chopeed-tomatoes
# 	 0 -> 	Brownie
# 	 0 -> 	Schwarztees
# 	 0 -> 	Chopeed-tomatoes,	Chopped-tomatoes
# 	 0 -> 	Brownie,	Chopped-tomatoes
# 		 1 -> 	Chopped-tomatoes
# 		 1 -> 	Nectar-de-pommes
# 	 0 -> 	Nectar-de-pommes
#
# ->  Caramel-dessert
# 	 0 -> 	Baguettes-de-pain
# 	 0 -> 	Mayonaise
# 	 0 -> 	Caramel-dessert
# 	 0 -> 	Multifruits
# 	 0 -> 	Canned-lamb-tongue
# 	 0 -> 	Caramel-dessert,	Mayonaise
# 		 1 -> 	Caramel-dessert
#
# ->  Tartar-sauce
# 	 0 -> 	Turkey-bacon
# 		 1 -> 	Turkey-bacon
#
# ->  Cornbreads
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Cornbreads,	Peanut-butter-cup
# 		 1 -> 	Peanut-butter-cup
# 		 1 -> 	Cornbreads
# 		 1 -> 	Cornbreads,	Peanut-butter-cup
# 	 0 -> 	Basa-fish
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
#
# ->  Fish-sauce
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives
#
# ->  Apple-and-pear-juices
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Biscottes
# 	 0 -> 	Stuffing
# 	 0 -> 	Prepared-fish
# 	 0 -> 	Apple-and-pear-juices
# 	 0 -> 	Chocolate-ice-cream
# 	 0 -> 	Bhuja
# 	 0 -> 	Basa-fish
# 	 0 -> 	Holunder-bluten-sirup
# 	 0 -> 	Basa-fish,	Bhuja
# 	 0 -> 	Apple-and-pear-juices,	Basa-fish
# 	 0 -> 	Cornbreads,	Prepared-fish
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Apple-and-pear-juices
# 		 1 -> 	Basa-fish
# 		 1 -> 	Apple-and-pear-juices,	Basa-fish
# 			 2 -> 	Apple-and-pear-juices
#
# ->  Aoli-sauce
# 	 0 -> 	Aoli-sauce
# 	 0 -> 	Chia-seeds
# 	 0 -> 	Aoli-sauce,	Chia-seeds
# 	 0 -> 	Persimmon
# 	 0 -> 	Chia-seeds,	Persimmon
# 	 0 -> 	Aoli-sauce,	Persimmon
# 		 1 -> 	Persimmon
# 	 0 -> 	Plant-based foods and beverages
# 		 1 -> 	Aoli-sauce
# 		 1 -> 	Plant-based foods and beverages
# 			 2 -> 	Plant-based foods and beverages
#
# ->  Cremes-fraiches-epaisses
# 	 0 -> 	Soupes
# 	 0 -> 	Cremes-fraiches-epaisses
# 	 0 -> 	Cremes-fraiches-epaisses,	Soupes
# 		 1 -> 	Soupes
# 		 1 -> 	Cremes-fraiches-epaisses
#
# ->  Bitters
# 	 0 -> 	Bitters
# 	 0 -> 	Tea-drinks
# 	 0 -> 	Lime-pickle
# 	 0 -> 	Kits
# 	 0 -> 	Mexican-sauces
# 	 0 -> 	Bitters,	Kits
# 		 1 -> 	Kits
# 	 0 -> 	Cigarettes
# 	 0 -> 	Cigarettes,	Mexican-sauces
# 		 1 -> 	Bitters
#
# ->  Baguettes-de-pain
# 	 0 -> 	Baguettes-de-pain
# 	 0 -> 	Pays-d-oc
# 	 0 -> 	Multifruits
# 	 0 -> 	Baguettes-de-pain,	Pays-d-oc
# 	 0 -> 	Caramel-dessert
# 	 0 -> 	Caramel-dessert,	Pays-d-oc
#
# ->  Dried products
# 	 0 -> 	Tabbouleh
# 	 0 -> 	Dried products
# 	 0 -> 	Dried products,	Tabbouleh
# 		 1 -> 	Tabbouleh
#
# ->  Gateau-chinois
# 	 0 -> 	Icecream
# 	 0 -> 	Gateau-chinois
# 	 0 -> 	Gateau-chinois,	Icecream
# 	 0 -> 	Hawaiian-sweet-rolls
#
# ->  Barres-de-cereales
# 	 0 -> 	Tabbouleh
# 	 0 -> 	Barres-de-cereales
# 	 0 -> 	Barres-de-cereales,	Tabbouleh
# 		 1 -> 	Tabbouleh
#
# ->  Brandy-snaps
# 	 0 -> 	Brandy-snaps
# 	 0 -> 	Gateau-chinois
# 	 0 -> 	Brandy-snaps,	Gateau-chinois
#
# ->  Fruit-flavoured-drink
# 	 0 -> 	Fruit-flavoured-drink
# 	 0 -> 	Scotch-eggs
# 	 0 -> 	Fruit-flavoured-drink,	Scotch-eggs
# 		 1 -> 	Fruit-flavoured-drink
# 	 0 -> 	Gnocchi
#
# ->  Filets-de-poulet
# 	 0 -> 	Filets-de-poulet
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Food additives
# 	 0 -> 	Filets-de-poulet,	Food additives
#
# ->  Coca-sandwich-biscuits
# 	 0 -> 	Coca-sandwich-biscuits
# 	 0 -> 	Framboises
# 	 0 -> 	Coca-sandwich-biscuits,	Framboises
# 		 1 -> 	Framboises
#
# ->  Curries
# 	 0 -> 	Milch
# 	 0 -> 	Raspberry-conserve
# 	 0 -> 	Curries
# 	 0 -> 	Milch,	Raspberry-conserve
# 	 0 -> 	Curries,	Raspberry-conserve
# 		 1 -> 	Raspberry-conserve
# 			 2 -> 	Raspberry-conserve
#
# ->  Cigarettes
# 	 0 -> 	Kits
# 	 0 -> 	Cigarettes
# 	 0 -> 	Bitters
#
# ->  Stuffing
# 	 0 -> 	Sucre
# 	 0 -> 	Stuffing
# 	 0 -> 	Stuffing,	Sucre
# 		 1 -> 	Stuffing
#
# ->  Aoli-sauce
# 	 0 -> 	Aoli-sauce
# 	 0 -> 	Long-life-milk
# 	 0 -> 	Aoli-sauce,	Long-life-milk
#
# ->  Horseradish-sauce
# 	 0 -> 	Mushroom-in-sunflower-oil
# 	 0 -> 	Horseradish-sauce
# 	 0 -> 	Milk substitute
# 	 0 -> 	Horseradish-sauce,	Milk substitute
# 	 0 -> 	Hommus
# 	 0 -> 	Banana-nut-loaf
# 		 1 -> 	Milk substitute
#
# ->  Boneless-pork-loin-steak
# 	 0 -> 	Boneless-pork-loin-steak
# 	 0 -> 	Spices-seasoning-mixes
# 	 0 -> 	Boneless-pork-loin-steak,	Spices-seasoning-mixes
# 		 1 -> 	Spices-seasoning-mixes
#
# ->  Aoli-sauce
# 	 0 -> 	Aoli-sauce
# 	 0 -> 	Sirloin-steak
# 	 0 -> 	Crab-pate
# 	 0 -> 	Aoli-sauce,	Sirloin-steak
# 		 1 -> 	Aoli-sauce
# 		 1 -> 	Sirloin-steak
# 		 1 -> 	Aoli-sauce,	Sirloin-steak
#
# ->  Chicken-breast-curry-with-tomato-spinach-sauce
# 	 0 -> 	Chicken-breast-curry-with-tomato-spinach-sauce
# 	 0 -> 	Distilled-malt-vinegar
# 	 0 -> 	Chicken-breast-curry-with-tomato-spinach-sauce,	Distilled-malt-vinegar
# 		 1 -> 	Chicken-breast-curry-with-tomato-spinach-sauce
# 		 1 -> 	Distilled-malt-vinegar
# 		 1 -> 	Chicken-breast-curry-with-tomato-spinach-sauce,	Distilled-malt-vinegar
#
# ->  Biscuits-aperitifs-sales
# 	 0 -> 	Stuffing
# 	 0 -> 	Biscuits-aperitifs-sales
# 	 0 -> 	Biscuits-aperitifs-sales,	Stuffing
# 		 1 -> 	Stuffing
# 		 1 -> 	Biscuits-aperitifs-sales
# 		 1 -> 	Biscuits-aperitifs-sales,	Stuffing
# 	 0 -> 	Chocolate-ice-cream
# 		 1 -> 	Chocolate-ice-cream
#
# ->  Almond-chocolate
# 	 0 -> 	Strawberry-licorice
# 	 0 -> 	Almond-chocolate
# 	 0 -> 	Almond-chocolate,	Strawberry-licorice
#
# ->  Granola-mix
# 	 0 -> 	Juice-milk-drink
# 	 0 -> 	Granola-mix
# 	 0 -> 	Granola-mix,	Juice-milk-drink
#
# ->  Ciabatta
# 	 0 -> 	Genio-tomatoes
# 	 0 -> 	Sandiwch
# 	 0 -> 	Ciabatta
# 	 0 -> 	Ciabatta,	Sandiwch
# 		 1 -> 	Sandiwch
# 	 0 -> 	Oatcakes
#
# ->  Multifruits
# 	 0 -> 	Baguettes-de-pain
# 	 0 -> 	Pays-d-oc
# 	 0 -> 	Prunes
# 	 0 -> 	Multifruits
# 	 0 -> 	Baguettes-de-pain,	Pays-d-oc
# 	 0 -> 	Multifruits,	Pays-d-oc
# 	 0 -> 	Caramel-dessert
# 	 0 -> 	Caramel-dessert,	Pays-d-oc
#
# ->  Cacao-en-poudre
# 	 0 -> 	Cacao-en-poudre
# 	 0 -> 	Licensed products
# 	 0 -> 	Cacao-en-poudre,	Licensed products
#
# ->  Cornbreads
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Prepared-fish
# 	 0 -> 	Cornbreads,	Peanut-butter-cup
# 	 0 -> 	Cornbreads,	Prepared-fish
# 		 1 -> 	Prepared-fish
# 	 0 -> 	Beef-mince
# 	 0 -> 	Chocolate-ice-cream
#
# ->  Food additives
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives
#
# ->  Berry-mueslis
# 	 0 -> 	Kits
# 	 0 -> 	Framboises
# 	 0 -> 	Bitters
# 	 0 -> 	Turkey-bacon
# 	 0 -> 	Berry-mueslis
# 	 0 -> 	Mexican-sauces
# 	 0 -> 	Wholefood
# 	 0 -> 	Berry-mueslis,	Framboises
# 	 0 -> 	Berry-mueslis,	Turkey-bacon
#
# ->  Mexican-sauces
# 	 0 -> 	Bitters
# 	 0 -> 	Kits
# 	 0 -> 	Framboises
# 	 0 -> 	Berry-mueslis
# 	 0 -> 	Mexican-sauces
# 	 0 -> 	Wholefood
# 	 0 -> 	Bitters,	Kits
# 	 0 -> 	Berry-mueslis,	Framboises
# 	 0 -> 	Mexican-sauces,	Wholefood
# 		 1 -> 	Kits
# 		 1 -> 	Wholefood
# 		 1 -> 	Mexican-sauces
#
# ->  Flavoured-cranberries
# 	 0 -> 	Flavoured-cranberries
# 	 0 -> 	Hoki-fish-fillets
# 	 0 -> 	Flavoured-cranberries,	Hoki-fish-fillets
# 	 0 -> 	Gateau-chinois
# 	 0 -> 	Pies
#
# ->  Basa-fish
# 	 0 -> 	Peanut-butter-cup
# 	 0 -> 	Cornbreads
# 	 0 -> 	Crisp-rolls
# 	 0 -> 	Bhuja
# 	 0 -> 	Basa-fish
# 	 0 -> 	Basa-fish,	Bhuja
# 	 0 -> 	Cornbreads,	Peanut-butter-cup
# 	 0 -> 	Basa-fish,	Peanut-butter-cup
# 		 1 -> 	Peanut-butter-cup
# 		 1 -> 	Cornbreads
# 		 1 -> 	Basa-fish
# 		 1 -> 	Cornbreads,	Peanut-butter-cup
# 		 1 -> 	Basa-fish,	Peanut-butter-cup
# 			 2 -> 	Peanut-butter-cup
# 			 2 -> 	Cornbreads
# 			 2 -> 	Cornbreads,	Peanut-butter-cup
#
# ->  Cream-cheese-spreads
# 	 0 -> 	Fruit-flavoured-drink
# 	 0 -> 	Cream-cheese-spreads
# 	 0 -> 	Cream-cheese-spreads,	Fruit-flavoured-drink
# 		 1 -> 	Fruit-flavoured-drink
#
# ->  Cardamom-tea
# 	 0 -> 	Cardamom-tea
# 	 0 -> 	Tomkin-tomatoes
# 	 0 -> 	Almond-flavouring
# 	 0 -> 	Cardamom-tea,	Tomkin-tomatoes
# 		 1 -> 	Cardamom-tea
# 		 1 -> 	Tomkin-tomatoes
# 		 1 -> 	Almond-flavouring
# 		 1 -> 	Cardamom-tea,	Tomkin-tomatoes
# 	 0 -> 	Bhuja
#
# ->  Cacao-en-poudre
# 	 0 -> 	Cacao-en-poudre
# 	 0 -> 	Licensed products
# 	 0 -> 	Granola-mix
# 	 0 -> 	Cacao-en-poudre,	Licensed products
# 	 0 -> 	Cacao-en-poudre,	Granola-mix
# 		 1 -> 	Cacao-en-poudre
# 		 1 -> 	Licensed products
# 		 1 -> 	Cacao-en-poudre,	Licensed products
#
# ->  Almond-chocolate
# 	 0 -> 	Tartar-sauce
# 	 0 -> 	Almond-chocolate
# 	 0 -> 	Almond-chocolate,	Tartar-sauce
#
# ->  Bruschetta
# 	 0 -> 	Mayonaise
# 	 0 -> 	Fruit-drinks
# 	 0 -> 	Canned-lamb-tongue
# 	 0 -> 	Bruschetta
# 	 0 -> 	Bruschetta,	Canned-lamb-tongue
#
# ->  Biskuvi
# 	 0 -> 	Biskuvi
# 	 0 -> 	Chicken-eggs
# 	 0 -> 	Stuffing
# 	 0 -> 	Microwave-popcorn
# 	 0 -> 	Biskuvi,	Microwave-popcorn
# 		 1 -> 	Biskuvi
# 		 1 -> 	Stuffing
# 		 1 -> 	Microwave-popcorn
# 		 1 -> 	Biskuvi,	Microwave-popcorn
# 			 2 -> 	Stuffing
#
# ->  Berry-mueslis
# 	 0 -> 	Turkey-bacon
# 	 0 -> 	Framboises
# 	 0 -> 	Berry-mueslis
# 	 0 -> 	Mexican-sauces
# 	 0 -> 	Berry-mueslis,	Framboises
# 	 0 -> 	Berry-mueslis,	Turkey-bacon
# 		 1 -> 	Turkey-bacon
# 			 2 -> 	Turkey-bacon
#
# ->  Capsicums
# 	 0 -> 	Groenten
# 	 0 -> 	Capsicums
# 	 0 -> 	Capsicums,	Groenten
# 		 1 -> 	Groenten
# 			 2 -> 	Groenten
#
# ->  Food additives
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives
#
# ->  Food additives
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives
#
# ->  Fish-sauce
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives
#
# ->  Fish-sauce
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives
#
# ->  Sucre
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives
#
# ->  Sucre
# 	 0 -> 	Sucre
# 	 0 -> 	Food additives
# 	 0 -> 	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives
# 	 0 -> 	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre
# 	 0 -> 	Food additives,	Fish-sauce,	Sucre
# 	 0 -> 	Food additives,	Sucre,	Fish-sauce
# 	 0 -> 	Fish-sauce,	Food additives,	Sucre
# 	 0 -> 	Fish-sauce,	Sucre,	Food additives
# 	 0 -> 	Sucre,	Food additives,	Fish-sauce
# 	 0 -> 	Sucre,	Fish-sauce,	Food additives
# 		 1 -> 	Sucre
# 		 1 -> 	Food additives
# 		 1 -> 	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives
# 		 1 -> 	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre
# 		 1 -> 	Food additives,	Fish-sauce,	Sucre
# 		 1 -> 	Food additives,	Sucre,	Fish-sauce
# 		 1 -> 	Fish-sauce,	Food additives,	Sucre
# 		 1 -> 	Fish-sauce,	Sucre,	Food additives
# 		 1 -> 	Sucre,	Food additives,	Fish-sauce
# 		 1 -> 	Sucre,	Fish-sauce,	Food additives

# %%
from copy import deepcopy
p2 = deepcopy(patterns)#####################################da eliminare alla fine

# %%
patterns = deepcopy(p2)#####################################da togliere alla fine
patNewLevel = []
for pattern in [p for p in patterns if p[1] != []]:
    l = [pattern[0][0],[]]
    for items in pattern[1]:
        level = items[0][0]
        item  = items[0][1]
        check = False
        for couple in l[1]:
            if couple[0] == level:
                couple[1].append(item)
                check = True
        if not check:
            l[1].append([level,[item]])
    patNewLevel.append(l)
patNewLevel = sorted(patNewLevel)

# %%
# Return the length of a model (in terms of depth levels)
def howManyLevels(pattern):
    return len(pattern[1])

#Return the length of a route starting from the passed order
def howManyOrders(route, order): #remaining orders after the one selected
    length = 0
    before  = False
    check   = False
    end     = False
    index = 0
    while (not end) & (index < len(routes)):
        if routes.RouteId[index] == route:
            before = True
            if routes.Order[index] > order:     
                length += 1
        else:
            before = False
            
        if before == True:
            if check == False:
                check = True
        else:
            if check == True:
                end = True
        index += 1
    return length

# Return the sorted levels of a pattern
def getLevels(pattern):
    return sorted(pattern[1])

# Return the orders inside a route
def getRoute(routeId):
    route = []
    before  = False
    check   = False
    end     = False
    i = 0
    while (not end) & (i < len(routes)):
        if routes.RouteId[i] == routeId:
            before = True
            route.append(routes.iloc[i])
        else:
            before = False
        if before == True:
            if check == False:
                check = True
        else:
            if check == True:
                end = True
        i += 1
    return route

# Return the index in the dataframe of a couple (route, order)
def getIndex(route, order):
    for index in range(0, len(routes)):
        if (routes.RouteId[index] == route) & (routes.Order[index] == order):
            return index
    return -1

# %%
import time
a = time.time()
foundInRoute = {}
for r in range(0, max(routes.RouteId)):
    for trip in getRoute(r):
        for pattern in patNewLevel:
            # If in this trip we have the head of the pattern
            if pattern[0] in trip.Items:
                # Go ahead only if there are at least the same number of orders and levels of the pattern
                if howManyLevels(pattern) <= howManyOrders(trip.RouteId, trip.Order): 
                    for level in getLevels(pattern):  
                        for item in level[1]:
                            if set(item).intersection(set(routes.Items[getIndex(trip.RouteId, 
                                                                                trip.Order) 
                                                                       + level[0] 
                                                                       + 1])) == set(item):
                                if foundInRoute.get((trip.RouteId, 
                                                     trip.Order), 
                                                    "ORDER") == "ORDER":
                                    foundInRoute[(trip.RouteId, trip.Order)] = {level[0]: set((item,))}
                                else:
                                    if foundInRoute.get((trip.RouteId, 
                                                         trip.Order)).get(level[0], 
                                                                          "LEVEL") == "LEVEL":
                                        foundInRoute[(trip.RouteId, 
                                                      trip.Order)][level[0]] = set((item,))
                                    else:
                                        foundInRoute.get((trip.RouteId,
                                                          trip.Order)).get(level[0]).add(item)
print()
print(time.time()-a)
print()
foundInRoute
