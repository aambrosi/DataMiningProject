# %%
import pandas as pd
import numpy  as np
import time   # To calculate the execution time
import bisect # For the WeightedRandomGenerator
import random # For the generation of random numbers

# The dataset was created by using a food dataset and saved outside because the original dataset was huge (1GB).
product_list = pd.read_csv('categories.csv', 
                           delimiter = ',', 
                           encoding  = 'utf-8')

# I delete few strange strings
product_list = product_list.drop([123, 157, 440, 442])

final_product_list                     = pd.DataFrame(product_list['Name'])
final_product_list['Popularity']       = np.random.random_sample(len(final_product_list))

# Index reset due to problems with non-consecutive indexes
final_product_list.reset_index(drop    = True, 
                               inplace = True)

# %%
cities = pd.read_csv('world-cities.csv', 
                     delimiter = ',', 
                     encoding  = 'utf-8')

# Set the number of cities to 100
nCities = 100
cities  = cities.sample(nCities)

# Index reset due to problems with non-consecutive indexes
cities.reset_index(drop    = True, 
                   inplace = True)
city_list         = pd.DataFrame(cities.name)
city_list.columns = ['Name']

# %%
#city_list["Export"] = ""
#city_list["Import"] = ""

# %%
# range of exported and imported for each city setted respectively at 3:20 and 10:50
minExp = 5
maxExp = 40
minImp = 20
maxImp = 100

# THIS PART CAN BE RUN IN PARALLEL (SPARK)
#start = time.time()
#for c in range(0,len(city_list)):
#    num_exp = np.random.randint(minExp,maxExp)
#    num_imp = np.random.randint(minImp,maxImp)
#    exp = np.unique(final_product_list.sample(num_exp, weights=final_product_list.Popularity).Name)
#    possible_imp_products = final_product_list[~final_product_list['Name'].isin(exp)]
#    imp = np.unique(possible_imp_products.sample(num_imp, weights=possible_imp_products.Popularity).Name)
#    city_list.loc[c,'Export'] = exp
#    city_list.loc[c,'Import'] = imp
#print(time.time()-start)

# %%
# A class for the generation of random weighted lists of products
class WeightedRandomGenerator(object):
    def __init__(self, weights):
        self.totals   = []
        running_total = 0
        for weight in weights:
            running_total += weight
            self.totals.append(running_total)

    def next(self):
        rnd = random.random() * self.totals[-1]
        return bisect.bisect_right(self.totals, rnd)

    def __call__(self):
        return self.next()

# Produce a list of import and export for a trip
def importExportGenerator():
    num_exp = np.random.randint(minExp, maxExp) # How many export
    num_imp = np.random.randint(minImp, maxImp) # How many import
    result  = {} # The final result to return
    exp     = [] # Export
    imp     = [] # Import
    
    # Generate a list of indexes of product to export
    for ne in range(0, num_exp):
        rg = final_product_list.Name[int(randomGenerator())]
        if(rg not in exp):
            exp.append(rg)
        else:
            ne -= 1
    
    # Generate a list of indexes of product to import
    for ni in range(0, num_imp):
        rg = final_product_list.Name[int(randomGenerator())]
        # We check if the products are already in the export list 
        # in order to avoid the import of them
        if((rg not in imp) & (rg not in exp)):
            imp.append(rg)
        else:
            ni -= 1
            
    result['exp'] = exp
    result['imp'] = imp
    return result
    
start           = time.time()
randomGenerator = WeightedRandomGenerator(final_product_list.Popularity)
values          = [(value['exp'], value['imp'])
                   for value in [importExportGenerator()
                                 for i in range(0, len(city_list))]]
exp             = []
imp             = []

for index in range(0, len(values)):
    exp.append(values[index][0])
    imp.append(values[index][1])
city_list['Export'] = exp
city_list['Import'] = imp

print(time.time() - start)
# Out:
# 0.19832301139831543

# %%
def standard_info(i, rid, tcd, trip, final_trip):
    final_trip.loc[i, 'RouteId']   = rid
    final_trip.loc[i, 'Order']     = i
    final_trip.loc[i, 'TruckCode'] = tcd
    final_trip.loc[i, 'StartCity'] = trip.loc[i    , 'IdCity']
    final_trip.loc[i, 'EndCity']   = trip.loc[i + 1, 'IdCity']

def first_step_creation(rid, tcd, length, trip):
    final_trip   = pd.DataFrame(columns = ['RouteId', 'Order', 'TruckCode', 'StartCity', 'EndCity', 'Items'])
    standard_info(0, rid, tcd, trip, final_trip)
    maxProbItems = list(set(trip.loc[length - 1, "PopularImport"]).intersection(trip.loc[length - 2, "ExportableItems"]))
    maxProbItems = maxProbItems * 5
    trip.loc[length - 2, "ExportableItems"].extend(maxProbItems)
    # I set the range to be not fixed to 5-20 for the first trip cities that have few exportable items and I set
    # them to half to all the possible exportable items
    numItems = np.random.randint(min(5, len(trip.loc[length - 2, "ExportableItems"]) / 2), 
                                 min(15, len(trip.loc[length - 2, "ExportableItems"])))
    sample   = set(random.sample(trip.loc[length - 2, "ExportableItems"], numItems))
    final_trip.loc[length - 2, 'Items'] = sample
    return final_trip
    
def trip_creation(i, rid, tcd, length, trip, final_trip):
    standard_info(i - 1, rid, tcd, trip, final_trip)
    crev            = length - i - 1
    possibleExports = list(final_trip.loc[crev + 1, 'Items'])
    itemsToDelete   = set(possibleExports).intersection(list(city_list.loc[list(city_list.Name).index(trip.loc[crev + 1, 
                                                                                                               'IdCity']), 
                                                                           'Export']))
    for item in itemsToDelete:
        possibleExports.remove(item)
        
        
    #############
    ############# 3 e 15 da mettere come variabili?
    #############
    numItems = np.random.randint(3, min(15, len(trip.loc[crev, "ExportableItems"])))
    #############
    sample   = set(random.sample(trip.loc[crev, "ExportableItems"], numItems))
    final_trip.loc[crev, 'Items'] = set(possibleExports).union(sample)
    return final_trip

# %%
# Range of trip length setted at 3:10. We set the number of trucks to 1000
minLen   = 3
maxLen   = 10
numTruck = 1000

def generate_trip(i):
    length = np.random.randint(minLen, maxLen)
    trip   = pd.DataFrame(columns = ['IdCity', 'ExportableItems', 'PopularImport'])
    items  = []
    cities = []
    for c in range(0, length):
        city     = np.random.randint(0, len(city_list))
        while city in cities:
            city = np.random.randint(0, len(city_list))
        cities.append(city)
        trip.loc[c, 'IdCity'] = city_list.loc[city, 'Name']
        items.extend(city_list.loc[city, 'Export'])
        trip.loc[c, 'ExportableItems'] = items.copy()
        trip.loc[c, 'PopularImport']   = city_list.loc[city, 'Import']
    rid = i
    tcd = np.random.randint(0, numTruck)
    final_trip = first_step_creation(rid, tcd, length, trip)
    for c in range(2,length):
        final_trip = trip_creation(c, rid, tcd, length, trip, final_trip)
    final_trip = final_trip.sort_values('Order')
    return final_trip

# %%
# Generate n trips
def generate_trips(n):
    return [generate_trip(i) for i in range(0, n)]

# %%
numberOfTrips = 100
trips         = generate_trips(numberOfTrips)

# %%
trips
# Out:
# [  RouteId Order TruckCode StartCity                 EndCity  \
#  0       0     0       711     Merke                Bhātpāra
#  1       0     1       711  Bhātpāra                   Cairo
#  2       0     2       711     Cairo                  Prigen
#  3       0     3       711    Prigen  San Jorge Pueblo Nuevo
#
#                                                 Items
#  0  {Pina-colada, Sardines-in-brine, Mini-portobel...
#  1  {Pina-colada, Mini-portobello-mushrooms, Slaty...
#  2  {Wholemeal-bread, Skegness-blue, Chicken-meat,...
#  3  {Red-salmon, Coriandre, Chicken-meat, Canned-f...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0       1     0       658           Weesp       Timişoara
#  1       1     1       658       Timişoara  Székesfehérvár
#  2       1     2       658  Székesfehérvár           Dukku
#  3       1     3       658           Dukku         Newport
#  4       1     4       658         Newport         Helmond
#
#                                                 Items
#  0  {Pastilles-a-sucer, Octopus-balls, Semoules-de...
#  1  {Ale, Pastilles-a-sucer, Ginseng-tea, Hokey-po...
#  2  {Ale, Chocolate-mints, Quenelles, Haferflocken...
#  3  {Rye-pale-ale, Ale, Chocolate-mints, Ground-ci...
#  4  {Rye-pale-ale, Chocolate-mints, Ground-cinnamo...  ,
#    RouteId Order TruckCode            StartCity             EndCity  \
#  0       2     0       398  Weinzierl bei Krems              Chatra
#  1       2     1       398               Chatra               Dukku
#  2       2     2       398                Dukku             Alkmaar
#  3       2     3       398              Alkmaar  Freiberg am Neckar
#  4       2     4       398   Freiberg am Neckar            Jiangyan
#  5       2     5       398             Jiangyan           Khirdalan
#
#                                                 Items
#  0  {Cornbreads, Frozen-prawns, Port, Meat-paste, ...
#  1  {Creme-caramel, Cornbreads, Wholemeal-bread, M...
#  2  {Creme-caramel, Cornbreads, Mexican-sauces, Ge...
#  3  {Mexican-sauces, Riz, Custard-powder, Cordials...
#  4  {Dry-seasoning-mix, Chicken-eggs, Mexican-sauc...
#  5  {Mexican-sauces, Gin, Vins-rouges, Egg-salad, ...  ,
#    RouteId Order TruckCode                        StartCity  \
#  0       3     0       397                       Heusweiler
#  1       3     1       397                       Kapfenberg
#  2       3     2       397                           Vernon
#  3       3     3       397                            Cairo
#  4       3     4       397           San Jorge Pueblo Nuevo
#  5       3     5       397  Chak Two Hundred Forty-Nine TDA
#  6       3     6       397                         Midsayap
#
#                             EndCity  \
#  0                       Kapfenberg
#  1                           Vernon
#  2                            Cairo
#  3           San Jorge Pueblo Nuevo
#  4  Chak Two Hundred Forty-Nine TDA
#  5                         Midsayap
#  6                          Shahrak
#
#                                                 Items
#  0  {Banana-flavour-mix-and-added-vitamins-and-min...
#  1  {Banana-flavour-mix-and-added-vitamins-and-min...
#  2  {Cinnamon-cookies, Chocolats-blancs, Instant-m...
#  3  {Sandiwch, Cinnamon-cookies, Chips, Chocolats-...
#  4  {Baby-spinach, Fish-can, Octopus-balls, Sandiw...
#  5  {Rye-pale-ale, Baby-spinach, Coconut-juice, Ca...
#  6  {Rye-pale-ale, Baby-spinach, Asperges, Mais, P...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0       4     0       890   Khirdalan  Māvelikara
#  1       4     1       890  Māvelikara     Walkden
#
#                                                 Items
#  0  {Strawberry-mousse, Pralinen, Haferflocken, Pa...
#  1  {Whole-wheat-beard, Poissons, Turkish-delight,...  ,
#    RouteId Order TruckCode StartCity  EndCity  \
#  0       5     0       837     Albal     Aral
#  1       5     1       837      Aral    Abhar
#  2       5     2       837     Abhar  Sarandë
#
#                                                 Items
#  0  {Sugarsnap-peas, Gluhwein, Pains-d-epices, Org...
#  1  {Stilton, Gluhwein, Fruit juices and nectars, ...
#  2  {Semoules-de-ble, Fruit juices and nectars, Ve...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0       6     0       246            Shahrak           Désarmes
#  1       6     1       246           Désarmes  Gustavo A. Madero
#  2       6     2       246  Gustavo A. Madero               Pita
#  3       6     3       246               Pita           Makakilo
#  4       6     4       246           Makakilo           Rājmahal
#
#                                                 Items
#  0  {Genoa-salami, Bruschetta, Dessert-mixes, Asia...
#  1  {Bambusstreifen, Pitta-breads, Bruschetta, App...
#  2  {Creme-caramel, Bambusstreifen, Pitta-breads, ...
#  3  {Bambusstreifen, Juice, Bruschetta, Chocolate-...
#  4  {Legumes-au-vinaigre, Juice, Bruschetta, Choco...  ,
#    RouteId Order TruckCode     StartCity            EndCity  \
#  0       7     0        15    Wellington       Carrum Downs
#  1       7     1        15  Carrum Downs           Jamālpur
#  2       7     2        15      Jamālpur  Gustavo A. Madero
#
#                                                 Items
#  0  {Whole-wheat-beard, Bbq-relish, Smoked-ham, Pa...
#  1  {Gnocchi, Frozen-asian-food, Pains-d-epices, B...
#  2  {Gnocchi, Groenten, Rice-cakes, Brussels-pate,...  ,
#    RouteId Order TruckCode   StartCity          EndCity  \
#  0       8     0       137   Frosinone       Busembatia
#  1       8     1       137  Busembatia            Ávila
#  2       8     2       137       Ávila          Wanxian
#  3       8     3       137     Wanxian         Berriane
#  4       8     4       137    Berriane            Dukku
#  5       8     5       137       Dukku          Shahrak
#  6       8     6       137     Shahrak  Curtea de Argeş
#
#                                                 Items
#  0  {White-pitta-bread, Bambusstreifen, Chicken-pi...
#  1  {Roasted-and-ground-coffee, Concombres, Golden...
#  2  {Banana-chips, Riz, Roasted-and-ground-coffee,...
#  3  {Banana-chips, Riz, Roasted-and-ground-coffee,...
#  4  {Ale, Banana-chips, Roasted-and-ground-coffee,...
#  5  {Ale, Banana-chips, Roasted-and-ground-coffee,...
#  6  {Ale, Octopus-balls, Roasted-and-ground-coffee...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0       9     0       289    Timişoara       Oswego
#  1       9     1       289       Oswego         Pita
#  2       9     2       289         Pita     Berriane
#  3       9     3       289     Berriane   Wellington
#  4       9     4       289   Wellington  San Mariano
#  5       9     5       289  San Mariano         Aral
#  6       9     6       289         Aral      Bamusso
#  7       9     7       289      Bamusso  Sam Roi Yot
#
#                                                 Items
#  0  {Ginseng-tea, Griechische-joghurt, Marfona-var...
#  1  {Chicken-pies, Ginseng-tea, Griechische-joghur...
#  2  {Chicken-pies, Ginseng-tea, Chocolate-ice-crea...
#  3  {Ginseng-tea, Mineral-natural-water, Lamb-brea...
#  4  {Custard-powder, Ginseng-tea, Mineral-natural-...
#  5  {Custard-powder, Ginseng-tea, Mineral-natural-...
#  6  {Rice-cake, Sunflower-spread, Pralinen, Pasta-...
#  7  {Sunflower-spread, Aliments-d-origine-vegetale...  ,
#    RouteId Order TruckCode                        StartCity  \
#  0      10     0       944                          Raigarh
#  1      10     1       944  Chak Two Hundred Forty-Nine TDA
#  2      10     2       944           San Jorge Pueblo Nuevo
#
#                             EndCity  \
#  0  Chak Two Hundred Forty-Nine TDA
#  1           San Jorge Pueblo Nuevo
#  2                            Lages
#
#                                                 Items
#  0  {Bread-rolls, Strawberries-canned, Lamb-breast...
#  1  {Canned-lamb-tongue, Bread-rolls, Strawberries...
#  2  {Octopus-balls, Bread-rolls, Strawberries-cann...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      11     0       777            Rājmahal          Perumpāvūr
#  1      11     1       777          Perumpāvūr           Mukacheve
#  2      11     2       777           Mukacheve  Freiberg am Neckar
#  3      11     3       777  Freiberg am Neckar               Abhar
#  4      11     4       777               Abhar     Orekhovo-Zuyevo
#
#                                                 Items
#  0  {Rye-pale-ale, Rose-water, Pates, Kase, Instan...
#  1  {Rye-pale-ale, Amaretto, Raisin-bread, Port, S...
#  2  {Amaretto, Raisin-bread, Canned-crab-meat, Org...
#  3  {Raisin-bread, Chicken-eggs, Crema-spalmabile,...
#  4  {White-coconut-chocolate, Chicken-eggs, Fromag...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      12     0       398       Carrum Downs  North Druid Hills
#  1      12     1       398  North Druid Hills         Busembatia
#  2      12     2       398         Busembatia            Sarandë
#  3      12     3       398            Sarandë    Curtea de Argeş
#  4      12     4       398    Curtea de Argeş              Lages
#  5      12     5       398              Lages        Vaniyambadi
#  6      12     6       398        Vaniyambadi              Depok
#
#                                                 Items
#  0  {Pains-d-epices, Rice-cakes, Proposed for dele...
#  1  {Pains-d-epices, Spaghetti-in-tomato-sauce, Te...
#  2  {Pains-d-epices, Spaghetti-in-tomato-sauce, Eg...
#  3  {Semoules-de-ble, Pains-d-epices, Spaghetti-in...
#  4  {Semoules-de-ble, Farming products, Spaghetti-...
#  5  {Farming products, Pork-chipolatas, Cheese-ana...
#  6  {Proposed for deletion, Pork-chipolatas, Purif...  ,
#    RouteId Order TruckCode                  StartCity  \
#  0      13     0       486                    Newport
#  1      13     1       486            Curtea de Argeş
#  2      13     2       486  Santo Amaro da Imperatriz
#  3      13     3       486                    Walkden
#  4      13     4       486         Freiberg am Neckar
#
#                       EndCity  \
#  0            Curtea de Argeş
#  1  Santo Amaro da Imperatriz
#  2                    Walkden
#  3         Freiberg am Neckar
#  4                    Tarakan
#
#                                                 Items
#  0  {Canned-crab-meat, Corn-tortilla, Getreide-und...
#  1  {Confiture-biologique, Iced-cookies, Corn-tort...
#  2  {Confiture-biologique, Iced-cookies, Cordials,...
#  3  {Coca-sandwich-biscuits, Instant-mashed-potato...
#  4  {Madeleines-au-chocolat, Tisane, Gin, Viande, ...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      14     0       344     Chelsea  Yasnogorsk
#  1      14     1       344  Yasnogorsk       Merke
#
#                                                 Items
#  0  {Olive-ciabatta, Frozen-potato-products, Pates...
#  1  {Frozen-potato-products, Pates, Dried-sausages...  ,
#    RouteId Order TruckCode     StartCity         EndCity  \
#  0      15     0       791      Désarmes          Prigen
#  1      15     1       791        Prigen           Weesp
#  2      15     2       791         Weesp    Altstadt Sud
#  3      15     3       791  Altstadt Sud  Martina Franca
#
#                                                 Items
#  0  {Quso-duro, Chicken-eggs, Chips, Pates-fraiche...
#  1  {Vegetarian-frozen-food, Passionfruit-pulp, Fa...
#  2  {Juice-drink, Vegetarian-frozen-food, Pork-sau...
#  3  {Spices-seasoning-mixes, Farming products, Kaf...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      16     0       783      Raigarh     Kruševac
#  1      16     1       783     Kruševac      Dāmghān
#  2      16     2       783      Dāmghān  San Mariano
#  3      16     3       783  San Mariano         Aral
#
#                                                 Items
#  0  {Steak-kidney-pie, Bread-rolls, Strawberries-c...
#  1  {Steak-kidney-pie, Bottled-still-water, Strawb...
#  2  {Steak-kidney-pie, Bottled-still-water, Lamb-b...
#  3  {Steak-kidney-pie, Grape-juice-drink, Cranberr...  ,
#    RouteId Order TruckCode    StartCity     EndCity  \
#  0      17     0       260  Sakaiminato       Dukku
#  1      17     1       260        Dukku     Bamusso
#  2      17     2       260      Bamusso  Wellington
#
#                                                 Items
#  0  {Pates-a-tartiner-aux-noisettes-et-au-cacao, C...
#  1  {Pates-a-tartiner-aux-noisettes-et-au-cacao, R...
#  2  {Muffin-mix, Tisane, Frozen-prawns, Ricotta, S...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      18     0       768        Nevel’      Kruševac
#  1      18     1       768      Kruševac    Parksville
#  2      18     2       768    Parksville    Melitopol’
#  3      18     3       768    Melitopol’  Carrum Downs
#  4      18     4       768  Carrum Downs       Bamusso
#  5      18     5       768       Bamusso       Helmond
#
#                                                 Items
#  0  {Cornbreads, Cheese-puffs, Breaded-ham, Baked-...
#  1  {Cheese-puffs, Mulled-wine-spice, Pizza dough,...
#  2  {Coconut-lime-icecream, Pure-orange-juice-not-...
#  3  {Pure-orange-juice-not-from-concentrate, Taram...
#  4  {Sucre, Tarama, Spaghetti-in-tomato-sauce, Fro...
#  5  {Chicken-kievs, Lamb-ribs, Minced-garlic, Spag...  ,
#    RouteId Order TruckCode   StartCity   EndCity  \
#  0      19     0       443  Parksville    Oswego
#  1      19     1       443      Oswego   Tarakan
#  2      19     2       443     Tarakan     Abhar
#  3      19     3       443       Abhar   Yerevan
#  4      19     4       443     Yerevan  Abingdon
#  5      19     5       443    Abingdon     Dukku
#
#                                                 Items
#  0  {Coconut-lime-icecream, Chocolate-muffin, Kit-...
#  1  {Milk-chocolate-digestives, Coconut-lime-icecr...
#  2  {Milk-chocolate-digestives, Coconut-lime-icecr...
#  3  {Milk-chocolate-digestives, Coconut-lime-icecr...
#  4  {Milk-chocolate-digestives, Sandiwch, Fromage-...
#  5  {Milk-chocolate-digestives, Kit-pour-fajitas, ...  ,
#    RouteId Order TruckCode                        StartCity  \
#  0      20     0       558                        Khirdalan
#  1      20     1       558                            Onoda
#  2      20     2       558                          Tarakan
#  3      20     3       558                             Pita
#  4      20     4       558              Weinzierl bei Krems
#  5      20     5       558                          Conyers
#  6      20     6       558  Chak Two Hundred Forty-Nine TDA
#  7      20     7       558                           Ponnur
#
#                             EndCity  \
#  0                            Onoda
#  1                          Tarakan
#  2                             Pita
#  3              Weinzierl bei Krems
#  4                          Conyers
#  5  Chak Two Hundred Forty-Nine TDA
#  6                           Ponnur
#  7                     Khagrachhari
#
#                                                 Items
#  0  {Strawberry-mousse, Pralinen, Haferflocken, Ta...
#  1  {Salad, Fat-free-milk, Pralinen, Haferflocken,...
#  2  {Sardines-in-brine, Chicken-pies, Churned-crea...
#  3  {Custard-tarts, Sardines-in-brine, Chicken-pie...
#  4  {Custard-tarts, Cornbreads, Sardines-in-brine,...
#  5  {Filets-de-poulet, Hard-cooked-peeled-eggs, Qu...
#  6  {Custard-tarts, Filets-de-poulet, Quso-duro, C...
#  7  {Custard-tarts, Hard-cooked-peeled-eggs, Quso-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      21     0       856       Albal  Melitopol’
#  1      21     1       856  Melitopol’    Makakilo
#  2      21     2       856    Makakilo       Fichē
#  3      21     3       856       Fichē     Newport
#  4      21     4       856     Newport       Depok
#
#                                                 Items
#  0  {Sugarsnap-peas, Gluhwein, Organic-spelt-flour...
#  1  {Amaretto, Sugarsnap-peas, Organic-spelt-flour...
#  2  {Amaretto, Sugarsnap-peas, Fruit juices and ne...
#  3  {Amaretto, Fruit juices and nectars, Meat-past...
#  4  {Pure-cod-liver-oil, Plastic-surgery, Cancoill...  ,
#    RouteId Order TruckCode   StartCity             EndCity  \
#  0      22     0       537     Walkden          Eldersburg
#  1      22     1       537  Eldersburg                Pita
#  2      22     2       537        Pita  Freiberg am Neckar
#
#                                                 Items
#  0  {Pina-colada, Raspberry-preserve, Brie-cheese,...
#  1  {Pina-colada, Pork-sausages, Brie-cheese, Fres...
#  2  {Filets-de-poulet, Pina-colada, Pork-sausages,...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      23     0       164    Bhātpāra        Sète
#  1      23     1       164        Sète     Bamusso
#  2      23     2       164     Bamusso  Oberasbach
#  3      23     3       164  Oberasbach   Antwerpen
#
#                                                 Items
#  0  {Beer-batter-fries, Coconut-juice, Saucisses-a...
#  1  {Pure-cod-liver-oil, Saucisses-aux-lentilles, ...
#  2  {Pure-cod-liver-oil, Quenelles, Multifruits, A...
#  3  {Pure-cod-liver-oil, Fresh foods, Harengs, Con...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      24     0       425    Raigarh  Antwerpen
#  1      24     1       425  Antwerpen      Ávila
#  2      24     2       425      Ávila    Newport
#
#                                                 Items
#  0  {Steak-kidney-pie, Bread-rolls, Whole-chicken,...
#  1  {Steak-kidney-pie, Whole-chicken, Creme-chocol...
#  2  {Whole-chicken, Red-salmon, Fresh-juices, Hone...  ,
#    RouteId Order TruckCode                  StartCity        EndCity  \
#  0      25     0       201  Santo Amaro da Imperatriz       Makakilo
#  1      25     1       201                   Makakilo      Prestwich
#  2      25     2       201                  Prestwich  Chililabombwe
#  3      25     3       201              Chililabombwe        Yerevan
#  4      25     4       201                    Yerevan         Bingöl
#
#                                                 Items
#  0  {Toppings, Prepared-salads, Cordials, Dill-sau...
#  1  {Toppings, Pastilles-a-sucer, Prepared-salads,...
#  2  {Salsa-chips, Pastilles-a-sucer, Haselnusse, A...
#  3  {Salsa-chips, Trail-mix, Haselnusse, Asian-foo...
#  4  {Salsa-chips, Prepared-salads, Ribeye-steak, H...  ,
#    RouteId Order TruckCode                  StartCity  \
#  0      26     0       816                    Newport
#  1      26     1       816                     Bingöl
#  2      26     2       816  Santo Amaro da Imperatriz
#  3      26     3       816          Gustavo A. Madero
#  4      26     4       816                       Aral
#  5      26     5       816                    Sarandë
#
#                       EndCity  \
#  0                     Bingöl
#  1  Santo Amaro da Imperatriz
#  2          Gustavo A. Madero
#  3                       Aral
#  4                    Sarandë
#  5                 Melitopol’
#
#                                                 Items
#  0  {Wholemeal-bread, Corn-tortilla, Crevettes, Sl...
#  1  {Wholemeal-bread, Corn-tortilla, Honey-roasted...
#  2  {Wholemeal-bread, Corn-tortilla, Dill-sauce, H...
#  3  {Lemongrass-paste, Madeleines-au-chocolat, Leg...
#  4  {Madeleines-au-chocolat, Tomato-chilli-relish,...
#  5  {Chicken-kievs, Multifruits, Biskuvi, Energy-b...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      27     0       280    Frosinone      Hernani
#  1      27     1       280      Hernani  Sam Roi Yot
#  2      27     2       280  Sam Roi Yot     Désarmes
#  3      27     3       280     Désarmes        Cairo
#  4      27     4       280        Cairo     Stoneham
#  5      27     5       280     Stoneham  San Mariano
#
#                                                 Items
#  0  {White-pitta-bread, Bambusstreifen, Chicken-pi...
#  1  {White-pitta-bread, Chicken-pies, Mint-jelly, ...
#  2  {Steak-kidney-pie, Barbeque-sauce, Mini-portob...
#  3  {Pitta-breads, Chicken-pies, Avocadoes, Mulled...
#  4  {Baby-spinach, Sirop, Quso-duro, Chicken-eggs,...
#  5  {Chicken-eggs, Chicken-pies, Fruit-bread, Pate...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      28     0        17             Ponnur            Newport
#  1      28     1        17            Newport        Vaniyambadi
#  2      28     2        17        Vaniyambadi  Gustavo A. Madero
#  3      28     3        17  Gustavo A. Madero         Perumpāvūr
#
#                                                 Items
#  0  {Coffee-ice-cream, Mint-jelly, Biscuits-au-cho...
#  1  {Milkshake, Banana-flavour-mix-and-added-vitam...
#  2  {Milkshake, Banana-flavour-mix-and-added-vitam...
#  3  {Milkshake, Sweetcorn-relish, Banana-flavour-m...  ,
#    RouteId Order TruckCode           StartCity      EndCity  \
#  0      29     0       942  Boissy-Saint-Léger      Chelsea
#  1      29     1       942             Chelsea      Shahrak
#  2      29     2       942             Shahrak       Nevel’
#  3      29     3       942              Nevel’        Fichē
#  4      29     4       942               Fichē   Parksville
#  5      29     5       942          Parksville  San Mariano
#
#                                                 Items
#  0  {Two-crust Pies, Corn-snacks, Brick, Asian-foods}
#  1  {Pates, Dried-sausages, Crackers-sans-gluten, ...
#  2  {Dried-sausages, Pains-d-epices, Crackers-sans...
#  3  {Semoules-de-ble, Dried-sausages, Nectar-de-fr...
#  4  {Semoules-de-ble, Dried-sausages, Pains-d-epic...
#  5  {Dried-sausages, Pains-d-epices, Egg-white-pow...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      30     0       566               Fichē            Désarmes
#  1      30     1       566            Désarmes             Wanxian
#  2      30     2       566             Wanxian            Jiangyan
#  3      30     3       566            Jiangyan  San Rafael Oriente
#  4      30     4       566  San Rafael Oriente             Dāmghān
#
#                                                 Items
#  0  {Apple-cider, Fizzy-drinks, Asian-sauces, Mela...
#  1  {Bambusstreifen, Pitta-breads, Apple-cider, Ap...
#  2  {Bambusstreifen, Pitta-breads, Apple-cider, Ch...
#  3  {Bambusstreifen, Pitta-breads, Poissons, Fizzy...
#  4  {Bambusstreifen, Pitta-breads, Chicken-thighs-...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      31     0       140              Merke             Bingöl
#  1      31     1       140             Bingöl  North Druid Hills
#  2      31     2       140  North Druid Hills    Curtea de Argeş
#  3      31     3       140    Curtea de Argeş           Midsayap
#  4      31     4       140           Midsayap          Spremberg
#  5      31     5       140          Spremberg          Prestwich
#  6      31     6       140          Prestwich            Conyers
#  7      31     7       140            Conyers         Parksville
#
#                                                 Items
#  0  {Sardines-in-brine, Slaty-snack, Biscuits-au-c...
#  1  {Biscuits-au-chocolat, Honey-roasted-sliced-al...
#  2  {Skegness-blue, Sambuca, Creme-chocolat, Asian...
#  3  {Iced-cookies, Farming products, Creme-chocola...
#  4  {Iced-cookies, Prune-juice, Farming products, ...
#  5  {Raspberry-conserve, Lemongrass-paste, Kidney-...
#  6  {Amaretto, Lemongrass-paste, Kidney-beans, Her...
#  7  {Amaretto, Cinamon-donuts, Tee, Cioccolatini, ...  ,
#    RouteId Order TruckCode  StartCity         EndCity  \
#  0      32     0       792  Khirdalan         Alkmaar
#  1      32     1       792    Alkmaar         Chelsea
#  2      32     2       792    Chelsea  Martina Franca
#
#                                                 Items
#  0  {Strawberry-mousse, Pralinen, Haferflocken, Pa...
#  1  {Strawberry-mousse, Bottled-still-water, Custa...
#  2  {Christmas-food, Crackers-sans-gluten, Tabboul...  ,
#    RouteId Order TruckCode               StartCity                 EndCity  \
#  0      33     0        69               Mukacheve  San Jorge Pueblo Nuevo
#  1      33     1        69  San Jorge Pueblo Nuevo                 Walkden
#  2      33     2        69                 Walkden              Parksville
#  3      33     3        69              Parksville                Albstadt
#
#                                                 Items
#  0  {Chesnut-mushrooms, Dilute-drink, Organic-spel...
#  1  {Organic-spelt-flour, Ramen, Hokey-pokey-ice-c...
#  2  {Kidney-beans, Prepared-salads, Dilute-drink, ...
#  3  {Kidney-beans, Prepared-salads, Dilute-drink, ...  ,
#    RouteId Order TruckCode               StartCity                 EndCity  \
#  0      34     0       851      Boissy-Saint-Léger                Désarmes
#  1      34     1       851                Désarmes                 Sarandë
#  2      34     2       851                 Sarandë  San Jorge Pueblo Nuevo
#  3      34     3       851  San Jorge Pueblo Nuevo              Busembatia
#  4      34     4       851              Busembatia                   Lages
#  5      34     5       851                   Lages                Midsayap
#  6      34     6       851                Midsayap      San Rafael Oriente
#
#                                                 Items
#  0  {Cinnamon-roll, Two-crust Pies, Corn-snacks, B...
#  1  {Bambusstreifen, Pitta-breads, Apple-cider-vin...
#  2  {Bambusstreifen, Chicken-kievs, Pitta-breads, ...
#  3  {Bambusstreifen, Chicken-kievs, Pitta-breads, ...
#  4  {Hot-dog-mustard, Bambusstreifen, Chicken-kiev...
#  5  {Hot-dog-mustard, Fruit-sticks, Bambusstreifen...
#  6  {Bambusstreifen, Fruit-sticks, Pitta-breads, F...  ,
#    RouteId Order TruckCode   StartCity         EndCity  \
#  0      35     0       447     Bamusso      Parksville
#  1      35     1       447  Parksville  Donaueschingen
#
#                                                 Items
#  0  {Cake-mix, Mackerel-fillets-in-brine, Chicken-...
#  1  {Frozen-dumplings, Tomkin-tomatoes, Mango-drin...  ,
#    RouteId Order TruckCode  StartCity    EndCity  \
#  0      36     0       799      Weesp  Khirdalan
#  1      36     1       799  Khirdalan      Dukku
#  2      36     2       799      Dukku     Prigen
#
#                                                 Items
#  0  {Semoules-de-ble, Mixed-nuts, Jus-d-orange, Pl...
#  1  {Strawberry-mousse, Semoules-de-ble, Mixed-nut...
#  2  {Octopus-balls, Strawberry-mousse, Lamb-breast...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      37     0       663            Albstadt             Hernani
#  1      37     1       663             Hernani             Yerevan
#  2      37     2       663             Yerevan  Freiberg am Neckar
#  3      37     3       663  Freiberg am Neckar     Orekhovo-Zuyevo
#  4      37     4       663     Orekhovo-Zuyevo               Lages
#
#                                                 Items
#  0  {Herring-fillets, Fajitas, Dill-sauce, Chocola...
#  1  {Pitta-breads, Flavoured-rice-cakes, Fajitas, ...
#  2  {Melonen, Dill-sauce, Honey-roasted-sliced-alm...
#  3  {Melonen, Honey-roasted-sliced-almonds, Garlic...
#  4  {Melonen, Groceries, Red-salmon, Levures, Hone...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      38     0       200           Jiangyan  Ban Huai Thalaeng
#  1      38     1       200  Ban Huai Thalaeng             Nevel’
#  2      38     2       200             Nevel’       Wethersfield
#  3      38     3       200       Wethersfield           Bhātpāra
#  4      38     4       200           Bhātpāra       Altstadt Sud
#
#                                                 Items
#  0  {Hot-fudge, Indian, Boxed-chocolates, Spearmin...
#  1  {Roma-tomatoes, Pates, English-mustard, Hokey-...
#  2  {Roma-tomatoes, Pates, English-mustard, Hot-fu...
#  3  {Organic-and-premium-pepper-cambodia, Mais, Ch...
#  4  {Chicoree, Confitures-de-fraises, Raw-organic-...  ,
#    RouteId Order TruckCode            StartCity          EndCity  \
#  0      39     0       321  Weinzierl bei Krems  Muang Phônsavan
#  1      39     1       321      Muang Phônsavan            Abhar
#  2      39     2       321                Abhar          Conyers
#  3      39     3       321              Conyers          Bamusso
#  4      39     4       321              Bamusso   Martina Franca
#  5      39     5       321       Martina Franca          Alkmaar
#  6      39     6       321              Alkmaar           Nevel’
#  7      39     7       321               Nevel’       Eldersburg
#
#                                                 Items
#  0  {Genio-tomatoes, Cornbreads, Frozen-prawns, Po...
#  1  {Roma-tomatoes, Cornbreads, Plato-preparado-pr...
#  2  {Cornbreads, Roma-tomatoes, White-coconut-choc...
#  3  {Cornbreads, Milk-based-product, Sugarsnap-pea...
#  4  {Cornbreads, Pizza-bases, Sugarsnap-peas, Plat...
#  5  {Cornbreads, Milk-based-product, Pizza-bases, ...
#  6  {Milk-based-product, Quso-duro, Plato-preparad...
#  7  {Milk-based-product, Milchprodukt, Beef-broth,...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      40     0       161        Bingöl         Weesp
#  1      40     1       161         Weesp       Bamusso
#  2      40     2       161       Bamusso  Wethersfield
#  3      40     3       161  Wethersfield       Hernani
#  4      40     4       161       Hernani    Parksville
#  5      40     5       161    Parksville        Nevel’
#  6      40     6       161        Nevel’       Chelsea
#  7      40     7       161       Chelsea         Depok
#
#                                                 Items
#  0  {Honey-roasted-sliced-almonds, Green-basil, No...
#  1  {Pastilles-a-sucer, Semoules-de-ble, Lamb-brea...
#  2  {Pastilles-a-sucer, Trail-mix, Frozen-dumpling...
#  3  {Trail-mix, Frozen-prawns, Frozen-dumplings, J...
#  4  {Flavoured-rice-cakes, Trail-mix, Frozen-prawn...
#  5  {Flavoured-rice-cakes, Trail-mix, Frozen-prawn...
#  6  {Kit-pour-fajitas, Mackerel-fillets-in-brine, ...
#  7  {Kit-pour-fajitas, Trail-mix, Caviars, Butter-...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      41     0       275  Heusweiler      Nevel’
#  1      41     1       275      Nevel’  Kapfenberg
#  2      41     2       275  Kapfenberg     Walkden
#  3      41     3       275     Walkden       Cairo
#  4      41     4       275       Cairo      Chatra
#  5      41     5       275      Chatra   Timişoara
#  6      41     6       275   Timişoara       Lages
#
#                                                 Items
#  0    {Ricotta, Instant-porridge, Freeze-dried foods}
#  1  {Cornbreads, Semoules-de-ble, Beef-jerky, Grap...
#  2  {Cornbreads, Semoules-de-ble, Beef-jerky, Raw-...
#  3  {Cornbreads, Bottled-still-water, Raw-organic-...
#  4  {Premium-and-organic-pepper-from-cambodia, Bal...
#  5  {Premium-and-organic-pepper-from-cambodia, Ins...
#  6  {Premium-and-organic-pepper-from-cambodia, Gri...  ,
#    RouteId Order TruckCode     StartCity       EndCity  \
#  0      42     0       289         Ávila    Perumpāvūr
#  1      42     1       289    Perumpāvūr        Vernon
#  2      42     2       289        Vernon     Timişoara
#  3      42     3       289     Timişoara       Hernani
#  4      42     4       289       Hernani  Khagrachhari
#  5      42     5       289  Khagrachhari        Prigen
#
#                                                 Items
#  0  {Banana-chips, Genoa-salami, Riz, Cured-ham, F...
#  1  {Banana-chips, Sandiwch, Genoa-salami, Cured-h...
#  2  {Sandiwch, Banana-chips, Genoa-salami, Frozen-...
#  3  {Banana-chips, Sandiwch, Genoa-salami, Jelly-c...
#  4  {Sandiwch, Banana-chips, Genoa-salami, Jelly-c...
#  5  {Mackerel-fillets-in-sunflower-oil, Genoa-sala...  ,
#    RouteId Order TruckCode            StartCity              EndCity  \
#  0      43     0       924        Chililabombwe               Chaman
#  1      43     1       924               Chaman  Weinzierl bei Krems
#  2      43     2       924  Weinzierl bei Krems           Kapfenberg
#
#                                                 Items
#  0  {Federweisser, Filo-dough, Ramen, Trail-mix, C...
#  1  {Confiture-biologique, Filo-dough, Hazelnut-ch...
#  2  {Filo-dough, English-mustard, Dill-sauce, Pesc...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      44     0       973      Belmont  Sakaiminato
#  1      44     1       973  Sakaiminato        Depok
#
#                                                 Items
#  0  {Confiture-biologique, Croque-monsieur, Smoked...
#  1  {Pate-feuilletee, Penne-rigate, Hokey-pokey-ic...  ,
#    RouteId Order TruckCode                 StartCity                   EndCity  \
#  0      45     0       105                Māvelikara                     Lages
#  1      45     1       105                     Lages           Curtea de Argeş
#  2      45     2       105           Curtea de Argeş              Peterborough
#  3      45     3       105              Peterborough                Busembatia
#  4      45     4       105                Busembatia                      Pita
#  5      45     5       105                      Pita                  Jamālpur
#  6      45     6       105                  Jamālpur  Nossa Senhora do Socorro
#  7      45     7       105  Nossa Senhora do Socorro                  Berriane
#
#                                                 Items
#  0  {Unsalted-butter, Poivre-noir, Pet food, Hafer...
#  1  {Unsalted-butter, Wholemeal-bread, Banana-chip...
#  2  {Unsalted-butter, Iced-cookies, Confiseries, I...
#  3  {Iced-cookies, Root-beer, Dried-sausages, Orga...
#  4  {Iced-cookies, Root-beer, Dried-sausages, Orga...
#  5  {Iced-cookies, Root-beer, Dried-sausages, Conf...
#  6  {Iced-cookies, Vin-de-californie, Root-beer, D...
#  7  {Tarts, Mixed-chillies, Cheese-analogues, Savo...  ,
#    RouteId Order TruckCode        StartCity             EndCity  \
#  0      46     0         2            Dukku          Oberasbach
#  1      46     1         2       Oberasbach               Albal
#  2      46     2         2            Albal     Orekhovo-Zuyevo
#  3      46     3         2  Orekhovo-Zuyevo  San Rafael Oriente
#
#                                                 Items
#  0  {Rye-pale-ale, Gnocchi, Klebreiskuchen, Genoa-...
#  1  {Amaretto, Fish-can, Apple-cider, Crema-spalma...
#  2  {Amaretto, Sugarsnap-peas, Crema-spalmabile, C...
#  3  {Sugarsnap-peas, Crema-spalmabile, Levures, Co...  ,
#    RouteId Order TruckCode StartCity          EndCity  \
#  0      47     0       706     Weesp            Albal
#  1      47     1       706     Albal  Curtea de Argeş
#
#                                                 Items
#  0  {Pastilles-a-sucer, Boisson-sucree-non-alcooli...
#  1  {Octopus-balls, Pains-d-epices, Pork-chipolata...  ,
#    RouteId Order TruckCode          StartCity              EndCity  \
#  0      48     0       100       Khagrachhari                 Pita
#  1      48     1       100               Pita    Gustavo A. Madero
#  2      48     2       100  Gustavo A. Madero              Yerevan
#  3      48     3       100            Yerevan         Carrum Downs
#  4      48     4       100       Carrum Downs            Khirdalan
#  5      48     5       100          Khirdalan  Weinzierl bei Krems
#
#                                                 Items
#  0  {Corned-beef, Mackerel-fillets-in-sunflower-oi...
#  1  {Custard-tarts, Minced-garlic, Ginseng-tea, Ch...
#  2  {Custard-tarts, Pralines, Juice, Minced-garlic...
#  3  {Custard-tarts, Pralines, Sandiwch, Juice, Min...
#  4  {Custard-tarts, Pralines, Legumes-au-vinaigre,...
#  5  {Custard-tarts, Pralines, Legumes-au-vinaigre,...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      49     0       573    Altstadt Sud        Rājmahal
#  1      49     1       573        Rājmahal  Martina Franca
#  2      49     2       573  Martina Franca       Timişoara
#  3      49     3       573       Timişoara       Khirdalan
#
#                                                 Items
#  0  {Jus-d-orange, Snacks, Biskuvi, Aoli-sauce, Sp...
#  1  {Biscottes, Pates, Jus-d-orange, Deep-fried, C...
#  2  {Lemongrass-paste, Premium-and-organic-pepper-...
#  3  {Premium-and-organic-pepper-from-cambodia, Col...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      50     0       364      Chelsea        Depok
#  1      50     1       364        Depok  Sakaiminato
#  2      50     2       364  Sakaiminato      Hernani
#  3      50     3       364      Hernani    Timişoara
#  4      50     4       364    Timişoara   Melitopol’
#
#                                                 Items
#  0  {Asparagus-tips, Frozen-potato-products, Sunfl...
#  1  {Asparagus-tips, Fruit-cups, Potato-salad, Car...
#  2  {Asparagus-tips, Crackers-sans-gluten, Fruit-c...
#  3  {Pina-colada, Asparagus-tips, Meta-category, C...
#  4  {Pina-colada, Meta-category, Potato-salad, Pic...  ,
#    RouteId Order TruckCode                  StartCity  \
#  0      51     0       858          North Druid Hills
#  1      51     1       858  Santo Amaro da Imperatriz
#  2      51     2       858                     Ponnur
#  3      51     3       858        Weinzierl bei Krems
#  4      51     4       858                  Almuñécar
#  5      51     5       858                    Belmont
#  6      51     6       858          Vranov nad Topľou
#
#                       EndCity  \
#  0  Santo Amaro da Imperatriz
#  1                     Ponnur
#  2        Weinzierl bei Krems
#  3                  Almuñécar
#  4                    Belmont
#  5          Vranov nad Topľou
#  6                 Busembatia
#
#                                                 Items
#  0  {Creme-chocolat, Egg-salad, Asian-food, Carame...
#  1  {Cordials, Dill-sauce, Asian-foods, Caramelize...
#  2  {Cordials, Biscuits-au-chocolat, Caramelized-r...
#  3  {Genio-tomatoes, Cornbreads, Cordials, Biscuit...
#  4  {Genio-tomatoes, Cornbreads, Cordials, Biscuit...
#  5  {Madeleines-au-chocolat, Klebreiskuchen, Non f...
#  6  {Madeleines-au-chocolat, Chicoree, Melk, Guava...  ,
#    RouteId Order TruckCode   StartCity      EndCity  \
#  0      52     0         9    Berriane   Oberasbach
#  1      52     1         9  Oberasbach       Oswego
#  2      52     2         9      Oswego         Pita
#  3      52     3         9        Pita  Sam Roi Yot
#
#                                                 Items
#  0  {Maple-butter, Coconut-cream, Pain-pita-sucres...
#  1  {Waffles, Apple-cider, Bruschetta, Pain-pita-s...
#  2  {Crema-spalmabile, Bruschetta, Fruit-confectio...
#  3  {Filets-de-poulet, Crema-spalmabile, Bruschett...  ,
#    RouteId Order TruckCode   StartCity         EndCity  \
#  0      53     0       960      Oswego         Newport
#  1      53     1       960     Newport      Kapfenberg
#  2      53     2       960  Kapfenberg         Chelsea
#  3      53     3       960     Chelsea        Artemisa
#  4      53     4       960    Artemisa  Martina Franca
#
#                                                 Items
#  0  {Milk-chocolate-digestives, Chicken-pies, Coco...
#  1  {Wholemeal-bread, Corn-tortilla, Getreide-und-...
#  2  {Wholemeal-bread, Corn-tortilla, Raw-organic-h...
#  3  {Wholemeal-bread, Pates, Dried-sausages, Fruit...
#  4  {Sunflower-oil-spread, Sliced-jalapenos, Hagel...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      54     0       930     Chelsea       Dukku
#  1      54     1       930       Dukku  Parksville
#  2      54     2       930  Parksville     Newport
#  3      54     3       930     Newport   Mukacheve
#
#                                                 Items
#  0  {Olive-ciabatta, Asparagus-tips, Pates, Strawb...
#  1  {Olive-ciabatta, Asparagus-tips, Pates, Klebre...
#  2  {Olive-ciabatta, Pates, Christmas-food, Klebre...
#  3  {Olive-ciabatta, Christmas-food, Strawberries-...  ,
#    RouteId Order TruckCode StartCity    EndCity  \
#  0      55     0       330  Kruševac      Abhar
#  1      55     1       330     Abhar   Artemisa
#  2      55     2       330  Artemisa  Almuñécar
#
#                                                 Items
#  0  {Condiment-en-poudre, Mini-portobello-mushroom...
#  1  {Condiment-en-poudre, White-coconut-chocolate,...
#  2  {Sirop, Mini-portobello-mushrooms, Tarama, Cav...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      56     0       436            Wanxian              Abhar
#  1      56     1       436              Abhar           Kruševac
#  2      56     2       436           Kruševac             Nevel’
#  3      56     3       436             Nevel’  Ban Huai Thalaeng
#  4      56     4       436  Ban Huai Thalaeng            Bamusso
#  5      56     5       436            Bamusso         Eldersburg
#
#                                                 Items
#  0  {Honey-roasted-sliced-almonds, Pickles, Macaro...
#  1  {White-coconut-chocolate, Tortilla-chips, Fres...
#  2  {White-coconut-chocolate, Wholemeal-bread, Man...
#  3  {White-coconut-chocolate, Wholemeal-bread, Sem...
#  4  {White-coconut-chocolate, Wholemeal-bread, Cor...
#  5  {Condiment-en-poudre, Toppings, Wholemeal-brea...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      57     0       598          Prestwich        Sam Roi Yot
#  1      57     1       598        Sam Roi Yot           Midsayap
#  2      57     2       598           Midsayap  Gustavo A. Madero
#  3      57     3       598  Gustavo A. Madero              Albal
#  4      57     4       598              Albal         Melitopol’
#  5      57     5       598         Melitopol’          Khirdalan
#  6      57     6       598          Khirdalan           Abingdon
#
#                                                 Items
#  0  {Snack-bar, Tortilla-chips, Aceite-de-coco, Al...
#  1  {Barbeque-sauce, Tortilla-chips, Genoa-salami,...
#  2  {Hot-dog-mustard, Genoa-salami, Prune-juice, A...
#  3  {Hot-dog-mustard, Prune-juice, Multifruits, Co...
#  4  {Sweetcorn-relish, Tortilla-chips, Prune-juice...
#  5  {Amaretto, Sweetcorn-relish, Prune-juice, Bagu...
#  6  {Amaretto, Sweetcorn-relish, Baguettes-de-pain...  ,
#    RouteId Order TruckCode   StartCity      EndCity  \
#  0      58     0       714      Nevel’        Fichē
#  1      58     1       714       Fichē      Walkden
#  2      58     2       714     Walkden   Yasnogorsk
#  3      58     3       714  Yasnogorsk    Almuñécar
#  4      58     4       714   Almuñécar      Sarandë
#  5      58     5       714     Sarandë  Sam Roi Yot
#
#                                                 Items
#  0  {Cornbreads, Semoules-de-ble, Mango-drink, Ste...
#  1  {Cornbreads, Semoules-de-ble, Apple-cider, Can...
#  2  {Cornbreads, Semoules-de-ble, Plato-preparado-...
#  3  {Semoules-de-ble, Apple-cider, Bruschetta, Coc...
#  4  {Apple-cider, Bruschetta, Coca-sandwich-biscui...
#  5  {Kit-pour-fajitas, Apple-cider, Bruschetta, Co...  ,
#    RouteId Order TruckCode    StartCity      EndCity  \
#  0      59     0       951      Bamusso        Merke
#  1      59     1       951        Merke  Vaniyambadi
#  2      59     2       951  Vaniyambadi     Stoneham
#  3      59     3       951     Stoneham      Newport
#
#                                                 Items
#  0  {Chicken-kievs, Chocolats-blancs, Pralinen, Fr...
#  1  {Sardines-in-brine, Chocolats-blancs, Skegness...
#  2  {Sardines-in-brine, Red-salmon, Penne-rigate, ...
#  3  {Penne-rigate, Frozen-dumplings, Infant-powder...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      60     0        34        Carrum Downs            Bhātpāra
#  1      60     1        34            Bhātpāra             Dāmghān
#  2      60     2        34             Dāmghān  Freiberg am Neckar
#  3      60     3        34  Freiberg am Neckar             Hernani
#  4      60     4        34             Hernani           Almuñécar
#  5      60     5        34           Almuñécar          Wellington
#
#                                                 Items
#  0  {Rice-cakes, Pains-d-epices, Smoked-ham, Canne...
#  1  {Coconut-juice, Sambuca, Cacao-en-poudre, Chic...
#  2  {Condiment-en-poudre, Coconut-juice, Reduced-f...
#  3  {Condiment-en-poudre, Coconut-juice, Dilute-dr...
#  4  {Condiment-en-poudre, Dilute-drink, Coconut-fl...
#  5  {Dilute-drink, Coconut-flour, Caviars, Gulab-j...  ,
#    RouteId Order TruckCode                        StartCity  \
#  0      61     0       336                         Berriane
#  1      61     1       336                          Dāmghān
#  2      61     2       336                           Nevel’
#  3      61     3       336                         Jamālpur
#  4      61     4       336                          Conyers
#  5      61     5       336  Chak Two Hundred Forty-Nine TDA
#  6      61     6       336                         Désarmes
#
#                             EndCity  \
#  0                          Dāmghān
#  1                           Nevel’
#  2                         Jamālpur
#  3                          Conyers
#  4  Chak Two Hundred Forty-Nine TDA
#  5                         Désarmes
#  6                      Vaniyambadi
#
#                                                 Items
#  0  {Ale, Maple-butter, Prune-juice, Mineral-natur...
#  1  {Mint-chocolate, Ale, Maple-butter, Prune-juic...
#  2  {Mint-chocolate, Semoules-de-ble, Energy-ball,...
#  3  {Semoules-de-ble, Energy-ball, Groenten, Canne...
#  4  {Semoules-de-ble, Sugarsnap-peas, Energy-ball,...
#  5  {Rye-pale-ale, Semoules-de-ble, Mexican-sauces...
#  6  {Mexican-sauces, Tintenfisch, Pancakes-and-waf...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      62     0       800          Dāmghān  Curtea de Argeş
#  1      62     1       800  Curtea de Argeş            Abhar
#
#                                                 Items
#  0  {Mint-chocolate, Fruit-bread, Pays-d-oc, Sushi...
#  1  {Fruit-bread, Pays-d-oc, Sushis, Mayonaise, Ge...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      63     0       180         Sakaiminato               Dukku
#  1      63     1       180               Dukku             Hernani
#  2      63     2       180             Hernani  Freiberg am Neckar
#  3      63     3       180  Freiberg am Neckar               Cairo
#  4      63     4       180               Cairo              Prigen
#  5      63     5       180              Prigen               Merke
#  6      63     6       180               Merke            Artemisa
#
#                                                 Items
#  0  {Saucisses-aux-lentilles, Pate-feuilletee, See...
#  1  {Gnocchi, Saucisses-aux-lentilles, Root-beer, ...
#  2  {Gnocchi, Pitta-breads, Saucisses-aux-lentille...
#  3  {Pitta-breads, Saucisses-aux-lentilles, Flavou...
#  4  {Pitta-breads, Flavoured-rice-cakes, Pork-chip...
#  5  {Pitta-breads, Flavoured-rice-cakes, Pains-d-e...
#  6  {Pitta-breads, Fruit-bread, Cioccolatini, Baby...  ,
#    RouteId Order TruckCode           StartCity          EndCity  \
#  0      64     0       304  Hato Mayor del Rey         Désarmes
#  1      64     1       304            Désarmes  Orekhovo-Zuyevo
#
#                                                 Items
#  0                 {Pate, Prepared-salads, Bread-mix}
#  1  {Bambusstreifen, Chicken-eggs, Pitta-breads, P...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      65     0       700             Walkden            Jamālpur
#  1      65     1       700            Jamālpur  San Rafael Oriente
#  2      65     2       700  San Rafael Oriente          Perumpāvūr
# ...
#
#                                                 Items
#  0  {Federweisser, Filo-dough, Fruit-buns, Dried p...
#  1  {Filo-dough, Trail-mix, Frozen-dumplings, Spam...
#  2  {Cake-mix, Kvarg, Harengs, Penne-rigate, Trail...
#  3  {Frozen-dumplings, Canned-peaches, White-peach...  ,
#    RouteId Order TruckCode           StartCity       EndCity  \
#  0      77     0       216  Boissy-Saint-Léger      Désarmes
#  1      77     1       216            Désarmes      Berriane
#  2      77     2       216            Berriane  Altstadt Sud
#  3      77     3       216        Altstadt Sud  Carrum Downs
#
#                                                 Items
#  0  {Cinnamon-roll, Two-crust Pies, Corn-snacks, B...
#  1  {Pitta-breads, Chips, Corn-snacks, Pates-fraic...
#  2  {Pitta-breads, Chips, Pain-pita-sucres, Mulled...
#  3  {Pitta-breads, Pain-pita-sucres, Pates-fraiche...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      78     0       714           Albal    Khagrachhari
#  1      78     1       714    Khagrachhari  Székesfehérvár
#  2      78     2       714  Székesfehérvár      Perumpāvūr
#  3      78     3       714      Perumpāvūr      Eldersburg
#
#                                                 Items
#  0  {Dessert-lacte, Sweet-biscuits, Plats-prepares...
#  1  {Dessert-lacte, Sweet-biscuits, Mackerel-fille...
#  2  {Pains-d-epices, Rice-wine, Ginseng-tea, Rhum,...
#  3  {Sandiwch, Cukor, Ginseng-tea, Coriandre, Frui...  ,
#    RouteId Order TruckCode        StartCity          EndCity  \
#  0      79     0       958      San Mariano  Curtea de Argeş
#  1      79     1       958  Curtea de Argeş         Kruševac
#
#                                                 Items
#  0  {Coconut-lime-icecream, Frozen-asian-food, Haf...
#  1  {Meat-paste, Chocolats, Fruit-and-nut-mix, Pum...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      80     0        89       Altstadt Sud  North Druid Hills
#  1      80     1        89  North Druid Hills         Yasnogorsk
#  2      80     2        89         Yasnogorsk       Peterborough
#  3      80     3        89       Peterborough          Antwerpen
#  4      80     4        89          Antwerpen           Abingdon
#  5      80     5        89           Abingdon            Sarandë
#  6      80     6        89            Sarandë            Alkmaar
#
#                                                 Items
#  0  {Jus-d-orange, Riz, Snacks, Fresh-strawberries...
#  1  {Jus-d-orange, Riz, Fresh-strawberries, Biskuv...
#  2  {Riz, Fresh-strawberries, Creme-chocolat, Bisk...
#  3  {Pate, Riz, Dried-sausages, Fresh-strawberries...
#  4  {Pate, Whipping-cream, Riz, Minced-lamb, Fresh...
#  5  {Pate, Riz, Creme-chocolat, Cookies-chocolate,...
#  6  {Matzos, Chicken-kievs, Colorants-alimentaires...  ,
#    RouteId Order TruckCode               StartCity                 EndCity  \
#  0      81     0       995                Artemisa  San Jorge Pueblo Nuevo
#  1      81     1       995  San Jorge Pueblo Nuevo              Melitopol’
#  2      81     2       995              Melitopol’                Stoneham
#  3      81     3       995                Stoneham               Prestwich
#  4      81     4       995               Prestwich             Sam Roi Yot
#  5      81     5       995             Sam Roi Yot                 Tarakan
#  6      81     6       995                 Tarakan                 Yerevan
#
#                                                 Items
#  0  {Waffles, Onion-relish, Port, Marfona-variety,...
#  1  {Onion-relish, Seed-style-mustard, Hot-cross-b...
#  2  {Onion-relish, Seed-style-mustard, Hot-cross-b...
#  3  {Onion-relish, Seed-style-mustard, Hot-cross-b...
#  4  {Salsa-chips, Herring-fillets, Onion-relish, S...
#  5  {Salsa-chips, Herring-fillets, Onion-relish, B...
#  6  {Salsa-chips, Fresh-carrots, Fresh-cucumbers, ...  ,
#    RouteId Order TruckCode   StartCity     EndCity  \
#  0      82     0       218        Pita  Kapfenberg
#  1      82     1       218  Kapfenberg     Shahrak
#
#                                                 Items
#  0  {Custard-tarts, Fruit-sticks, Filets-de-poulet...
#  1  {Custard-tarts, Fruit-sticks, Filets-de-poulet...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      83     0       956        Abingdon           Abhar
#  1      83     1       956           Abhar  Donaueschingen
#  2      83     2       956  Donaueschingen           Merke
#
#                                                 Items
#  0  {Fruit-juice-drink, Quso-duro, Chocolate-muffi...
#  1  {Fruit-juice-drink, Chocolate-muffin, Quso-dur...
#  2  {Fruit-juice-drink, Dilute-drink, Boeuf-bourgu...  ,
#    RouteId Order TruckCode          StartCity             EndCity  \
#  0      84     0       990     Donaueschingen           Mukacheve
#  1      84     1       990          Mukacheve          Wellington
#  2      84     2       990         Wellington        Khagrachhari
#  3      84     3       990       Khagrachhari   Gustavo A. Madero
#  4      84     4       990  Gustavo A. Madero               Abhar
#  5      84     5       990              Abhar              Vernon
#  6      84     6       990             Vernon  Hato Mayor del Rey
#
#                                                 Items
#  0  {Semoules-de-ble, Tiefkuhlpizza, Boeuf-bourgui...
#  1  {Chesnut-mushrooms, Semoules-de-ble, Rice-pape...
#  2  {Custard-powder, Rice-paper, Canned-oysters, P...
#  3  {Slaty-snack, Custard-powder, Poudres-cacao, S...
#  4  {Slaty-snack, Poudres-cacao, Semoules-de-ble-d...
#  5  {Poudres-cacao, Semoules-de-ble-dur-pour-cousc...
#  6  {Frozen-apple-pies, Custard, Beers-from-strals...  ,
#    RouteId Order TruckCode           StartCity     EndCity  \
#  0      85     0       498  Freiberg am Neckar  Busembatia
#  1      85     1       498          Busembatia    Makakilo
#
#                                                 Items
#  0  {Shredded-cheese, Milk-based-product, Kruident...
#  1  {Hot-dog-mustard, Shredded-cheese, Milk-based-...  ,
#    RouteId Order TruckCode       StartCity              EndCity  \
#  0      86     0       895    Peterborough       Székesfehérvár
#  1      86     1       895  Székesfehérvár              Yerevan
#  2      86     2       895         Yerevan             Artemisa
#  3      86     3       895        Artemisa              Tarakan
#  4      86     4       895         Tarakan          Sakaiminato
#  5      86     5       895     Sakaiminato              Newport
#  6      86     6       895         Newport  Weinzierl bei Krems
#
#                                                 Items
#  0  {Pralines, Mint-chocolate, Root-beer, Dried-sa...
#  1  {Pralines, Mint-chocolate, Chocolate-mints, Ro...
#  2  {Pralines, Chocolate-mints, Root-beer, Dried-s...
#  3  {Root-beer, Dried-sausages, Red-salmon, Quenel...
#  4  {Spices-seasoning-mixes, Root-beer, Red-salmon...
#  5  {Saucisses-aux-lentilles, Root-beer, Frozen-pr...
#  6  {Spices-seasoning-mixes, Red-salmon, Tisane, F...  ,
#    RouteId Order TruckCode           StartCity          EndCity  \
#  0      87     0       753  Freiberg am Neckar          Walkden
#  1      87     1       753             Walkden       Busembatia
#  2      87     2       753          Busembatia  Curtea de Argeş
#  3      87     3       753     Curtea de Argeş            Jelcz
#
#                                                 Items
#  0  {Shredded-cheese, Corned-beef, Crema-spalmabil...
#  1  {Shredded-cheese, Plato-preparado-precocinado,...
#  2  {Hot-dog-mustard, Shredded-cheese, Fruit-stick...
#  3  {Shredded-cheese, Plato-preparado-precocinado,...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      88     0       657   North Druid Hills               Lages
#  1      88     1       657               Lages                Pita
#  2      88     2       657                Pita          Parksville
#  3      88     3       657          Parksville             Newport
#  4      88     4       657             Newport  San Rafael Oriente
#  5      88     5       657  San Rafael Oriente              Oswego
#
#                                                 Items
#  0  {Egg-salad, Asian-food, Asian-sauces, Caramels...
#  1  {Confiseries, Pork-chipolatas, Creme-chocolat,...
#  2  {Custard-tarts, Confiseries, Chocolate-ice-cre...
#  3  {Custard-tarts, Chocolate-muffin, Chocolate-ic...
#  4  {Custard-tarts, Pure-cod-liver-oil, Creme-choc...
#  5  {Lemon-mousse, Banana-flavour-mix-and-added-vi...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      89     0       549            Shahrak          Khirdalan
#  1      89     1       549          Khirdalan           Désarmes
#  2      89     2       549           Désarmes            Conyers
#  3      89     3       549            Conyers       Carrum Downs
#  4      89     4       549       Carrum Downs  North Druid Hills
#  5      89     5       549  North Druid Hills  Vranov nad Topľou
#  6      89     6       549  Vranov nad Topľou    Curtea de Argeş
#
#                                                 Items
#  0  {Bruschetta, Genoa-salami, Pains-d-epices, Vit...
#  1  {Bruschetta, Pains-d-epices, Pralinen, Potato-...
#  2  {Bruschetta, Whole-wheat-beard, Pralinen, Mull...
#  3  {Sugarsnap-peas, Strawberry-mousse, Bruschetta...
#  4  {Sugarsnap-peas, Strawberry-mousse, Bruschetta...
#  5  {Bruschetta, Pains-d-epices, Mulled-wine-spice...
#  6  {Bruschetta, Radish, Goat-milk, Potato-salad, ...  ,
#    RouteId Order TruckCode     StartCity     EndCity  \
#  0      90     0       176  Peterborough  Wellington
#  1      90     1       176    Wellington    Artemisa
#  2      90     2       176      Artemisa    Abingdon
#  3      90     3       176      Abingdon     Yerevan
#
#                                                 Items
#  0  {Mint-chocolate, Pina-colada, Coffee-flavoured...
#  1  {Mint-chocolate, Pina-colada, Sweet-biscuits, ...
#  2  {Mint-chocolate, Pina-colada, Sweet-biscuits, ...
#  3  {Mint-chocolate, Dilute-drink, Sweet-biscuits,...  ,
#    RouteId Order TruckCode   StartCity       EndCity  \
#  0      91     0       952  Parksville        Vernon
#  1      91     1       952      Vernon      Jiangyan
#  2      91     2       952    Jiangyan    Perumpāvūr
#  3      91     3       952  Perumpāvūr  Carrum Downs
#
#                                                 Items
#  0  {Coconut-lime-icecream, Chocolate-muffin, Kit-...
#  1  {Coconut-lime-icecream, Nutrition-bar, Propose...
#  2  {Coconut-lime-icecream, Mousse-de-foie-de-porc...
#  3  {Coconut-lime-icecream, Sandiwch, Nutrition-ba...  ,
#    RouteId Order TruckCode StartCity   EndCity  \
#  0      92     0       667     Depok      Aral
#  1      92     1       667      Aral   Shahrak
#  2      92     2       667   Shahrak  Rājmahal
#
#                                                 Items
#  0  {Prepackaged-sandwiches, Malt-vinegar, Caramel...
#  1  {Iced-cookies, Caramelized-red-onion-chutney, ...
#  2  {Oeufs-de-poisson, Caramelized-red-onion-chutn...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      93     0       272          Yasnogorsk  San Rafael Oriente
#  1      93     1       272  San Rafael Oriente          Busembatia
#  2      93     2       272          Busembatia         Sam Roi Yot
#  3      93     3       272         Sam Roi Yot          Perumpāvūr
#
#                                                 Items
#  0  {Dried-sausages, Aloe-vera-drink, Frozen-prawn...
#  1  {Coffee-flavoured-milk, Aloe-vera-drink, Froze...
#  2  {Octopus-balls, Coffee-flavoured-milk, Aloe-ve...
#  3  {Steak-kidney-pie, Genoa-salami, Concombres, P...  ,
#    RouteId Order TruckCode      StartCity        EndCity  \
#  0      94     0        55       Makakilo           Aral
#  1      94     1        55           Aral      Mukacheve
#  2      94     2        55      Mukacheve         Chaman
#  3      94     3        55         Chaman         Oswego
#  4      94     4        55         Oswego        Newport
#  5      94     5        55        Newport  Chililabombwe
#  6      94     6        55  Chililabombwe     Māvelikara
#
#                                                 Items
#  0  {Pastilles-a-sucer, Coffee-cake, Coconut-water...
#  1  {Pralines, Pastilles-a-sucer, Feuilletes-chevr...
#  2  {Pastilles-a-sucer, Feuilletes-chevre-epinards...
#  3  {Confiture-biologique, Pastilles-a-sucer, Natu...
#  4  {Milk-chocolate-digestives, Pitta-breads, Chic...
#  5  {Milk-chocolate-digestives, Pitta-breads, Chic...
#  6  {Indian-sauces, Canned-crab-meat, Getreide-und...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      95     0       957               Dukku  Freiberg am Neckar
#  1      95     1       957  Freiberg am Neckar        Peterborough
#  2      95     2       957        Peterborough     Curtea de Argeş
#  3      95     3       957     Curtea de Argeş         Vaniyambadi
#  4      95     4       957         Vaniyambadi               Fichē
#  5      95     5       957               Fichē        Altstadt Sud
#
#                                                 Items
#  0  {Gnocchi, Genoa-salami, Ground-cinnamon, Cordi...
#  1  {Shredded-cheese, Milk-based-product, Frozen-p...
#  2  {Double-chocolate-milk, Shredded-cheese, Mint-...
#  3  {Double-chocolate-milk, Shredded-cheese, Matzo...
#  4  {Shredded-cheese, Matzos, Cardamom-pods, Red-s...
#  5  {Shredded-cheese, Matzos, Polenta, Frozen-praw...  ,
#    RouteId Order TruckCode          StartCity            EndCity  \
#  0      96     0       921           Désarmes  Vranov nad Topľou
#  1      96     1       921  Vranov nad Topľou               Pita
#
#                                                 Items
#  0  {Bambusstreifen, Pitta-breads, Chips, Apple-ci...
#  1  {Fruit-sticks, Pitta-breads, Chips, Soupe, Chi...  ,
#    RouteId Order TruckCode           StartCity             EndCity  \
#  0      97     0       169          Wellington           Almuñécar
#  1      97     1       169           Almuñécar           Mukacheve
#  2      97     2       169           Mukacheve               Abhar
#  3      97     3       169               Abhar               Depok
#  4      97     4       169               Depok     Curtea de Argeş
#  5      97     5       169     Curtea de Argeş  Freiberg am Neckar
#  6      97     6       169  Freiberg am Neckar        Carrum Downs
#
#                                                 Items
#  0  {Genoa-salami, Bbq-relish, Canned-oysters, Pra...
#  1  {Pralines, Genoa-salami, Pate-feuilletee, Cann...
#  2  {Pralines, Genoa-salami, Canned-crab-meat, Pat...
#  3  {Pralines, Tom-yum-soup, Genoa-salami, Canned-...
#  4  {Pralines, Tom-yum-soup, Genoa-salami, Canned-...
#  5  {Tom-yum-soup, Genoa-salami, Canned-crab-meat,...
#  6  {Chicken-eggs, Dilute-drink, Genoa-salami, Can...  ,
#    RouteId Order TruckCode  StartCity  EndCity  \
#  0      98     0       979  Almuñécar  Raigarh
#  1      98     1       979    Raigarh    Dukku
#  2      98     2       979      Dukku     Sète
#
#                                                 Items
#  0  {Double-chocolate-milk, Pralines, Pate-feuille...
#  1  {Double-chocolate-milk, Strawberries-canned, P...
#  2  {Double-chocolate-milk, Root-beer, Strawberrie...  ,
#    RouteId Order TruckCode       StartCity         EndCity  \
#  0      99     0       781         Raigarh     Sakaiminato
#  1      99     1       781     Sakaiminato           Ávila
#  2      99     2       781           Ávila  Martina Franca
#  3      99     3       781  Martina Franca  Székesfehérvár
#
#                                                 Items
#  0  {Steak-kidney-pie, Whole-chicken, Strawberries...
#  1  {Custard-tarts, Steak-kidney-pie, Strawberries...
#  2  {Steak-kidney-pie, Dilute-drink, Genoa-salami,...
#  3  {Steak-kidney-pie, Dilute-drink, Genoa-salami,...  ]

# %%
all_trips = pd.concat(trips)

# %%
# Save the trips for the mining part
all_trips.to_csv("route_trips.csv")
